# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # Personal Construct Theory (PCT)<a class="anchor" id="PTMD_page_15"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# ## **Personal Construct Theory (PCT): Understanding the Building Blocks of Personality**
#
# Personal Construct Theory (PCT) is a fascinating psychological framework that dives deep into the core of human personality, helping us unravel the intricate tapestry of who we are. Developed by the American psychologist George Kelly in the mid-20th century, PCT is a unique approach to understanding the human psyche. It posits that each of us creates our own mental constructs—distinctive ways of perceiving and categorizing the world around us.
#
# Imagine your mind as a library filled with countless books, and each book represents a construct—an abstract concept that helps you make sense of your experiences. These constructs are the lenses through which you view and interpret the world. They are deeply personal, reflecting your individual values, beliefs, and experiences. For example, you might have a construct of "trustworthiness" that influences how you perceive people. If someone aligns with your concept of trustworthiness, you're more likely to trust them.
#
# Now, let's delve into the pct_dataset. It's like a treasure trove of these constructs, carefully organized and categorized. Each construct is a unique aspect of personality, ranging from cognitive and emotional traits to behavioral and moral dimensions. Consider "Conflict Resolution" as an example. Within this construct, you find various factors like "Mediation skills," "Negotiation strategies," "Conflict de-escalation," "Problem-solving in conflicts," and "Communication in conflicts."
#
# Within each factor, there are adjectives and synonyms that provide richer detail. For "Mediation skills," you'll discover words like "Conflict mediation," "Dispute resolution," "Mediation techniques," and more. These adjectives and synonyms allow us to pinpoint and articulate the nuances of personality traits associated with each construct.
#
# Why is this important? Imagine a recommender system that can understand your unique constructs, the building blocks of your personality. By analyzing your preferences and interactions, it can recommend products, services, or experiences tailored precisely to your individuality. PCT, with its dataset, opens up exciting possibilities in fields like marketing, psychology, and artificial intelligence. It helps us better understand and respect the diversity of human personality, ultimately leading to more personalized and meaningful interactions in our increasingly complex world.
#
#
# ### Personal Construct Theory (PCT) Timeline and Reference Table
#
# | Year | Milestone                                       | Contributor(s)                      | Original Work Reference                                                                                 | Key Contributions                                            | Additional Information                                        |
# |------|-------------------------------------------------|-------------------------------------|--------------------------------------------------------------------------------------------------------|--------------------------------------------------------------|---------------------------------------------------------------|
# | 1955 | Introduction of PCT and the Repertory Grid Technique. | George Kelly                        | Kelly, G. A. (1955). "The Psychology of Personal Constructs". New York: Norton.                         | Foundational work in PCT, introducing personal constructs and the Repertory Grid Technique for assessing them. | Laid the groundwork for PCT and its applications in psychology. |
# | 1968 | Significant contribution to PCT in clinical settings. | Bannister, D., & Mair, J. M. M.     | Bannister, D., & Mair, J. M. M. (1968). "The Evaluation of Personal Constructs". London: Academic Press. | Explored PCT applications in clinical psychology, emphasizing its therapeutic potential. | Helped establish PCT in clinical and counseling psychology.      |
# | 1985 | Advancement of PCT and constructivist therapy. | Robert A. Neimeyer                  | Neimeyer, R. A. (1985). "The development of personal construct psychology". Lincoln: University of Nebraska Press. | Elaborated on the development and therapeutic applications of PCT. | Provided a deeper understanding of PCT's role in constructivist therapy. |
# | 2004 | Comprehensive overview of PCT and its developments. | Fransella, F., Bell, R., & Bannister, D. | Fransella, F., Bell, R., & Bannister, D. (2004). "A Manual for Repertory Grid Technique". (2nd ed.). John Wiley & Sons. | Offered a detailed guide on the Repertory Grid Technique and its applications. | Significantly contributed to the understanding and practical use of PCT. |
# | 2008 | Modern interpretation and integration of PCT.   | Trevor Butt                          | Butt, T. (2008). "George Kelly: The Psychology of Personal Constructs". Palgrave Macmillan.               | Provided modern perspectives and interpretations of PCT.      | Highlighted the enduring relevance of PCT in contemporary psychology. |
#
# This table succinctly organizes the milestones related to the development and influence of Personal Construct Theory (PCT), highlighting the contributions and additional context for each significant development. If there are more details or other modifications needed, feel free to let me know!
#
# This table presents a detailed view of the key milestones in the development and application of Personal Construct Theory, highlighting specific contributors and their significant works. Each row represents a pivotal event or contribution in the history of PCT, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# PCT has evolved over the years, maintaining its relevance and adaptability to various psychological and therapeutic contexts. This timeline showcases the theory's progression from its foundational concepts to modern applications and interpretations.
#
# PCT has been influential in the field of psychology, particularly in understanding how personal experiences and perceptions shape individual behavior and cognition. Its impact is seen across various areas including clinical psychology, counseling, and personality research.
#
# | ID   | Author                                                    | Year | Title                                                                                                                     | Journal                                                               | Volume | Pages      | DOI                                                                                                 |
# |------|-----------------------------------------------------------|------|---------------------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------|--------|------------|-----------------------------------------------------------------------------------------------------|
# | 94   | E. Murray                                                 | 1953 | THEORY OF PERSONALITY                                                                                                      | The Personnel and Guidance Journal                                    | 31     | 298-303    | [10.1002/J.2164-4918.1953.TB01464.X](https://doi.org/10.1002/J.2164-4918.1953.TB01464.X)             |
# | 71   | G. Kelly                                                  | 1955 | The psychology of personal constructs. Vol. 1. A theory of personality. Vol. 2. Clinical diagnosis and psychotherapy.      | -                                                                     | -      | -          | -                                                                                                   |
# | 102  | G. Kelly                                                  | 1955 | Clinical diagnosis and psychotherapy                                                                                       | -                                                                     | -      | -          | -                                                                                                   |
# | 79   | G. Kelly                                                  | 1964 | The language of hypothesis: Man’s psychological instrument                                                                 | The Journal of Individual Psychology                                  | 20     | 137-152    | -                                                                                                   |
# | 75   | G. Gardner                                                | 1964 | THE PSYCHOTHERAPEUTIC RELATIONSHIP.                                                                                        | Psychological bulletin                                                | 61     | 426-37     | [10.1037/H0044091](https://doi.org/10.1037/H0044091)                     |
# | 97   | G. Kelly, B. Maher                                        | 1969 | Clinical Psychology and Personality: The Selected Papers of George Kelly                                                    | -                                                                     | -      | -          | -                                                                                                   |
# | 98   | D. Bannister                                              | 1970 | Perspectives in personal construct theory                                                                                  | -                                                                     | -      | -          | -                                                                                                   |
# | 106  | A. Landfield                                              | 1971 | Personal construct systems in psychotherapy                                                                                | -                                                                     | -      | -          | -                                                                                                   |
# | 99   | F. Fransella, R. Bell, D. Bannister                        | 1977 | A manual for repertory grid technique                                                                                      | -                                                                     | -      | -          | -                                                                                                   |
# | 72   | D. Bannister                                              | 1977 | New perspectives in personal construct theory                                                                              | -                                                                     | -      | -          | -                                                                                                   |
# | 86   | A. Landfield, L. Leitner                                   | 1980 | Personal construct psychology: psychotherapy and personality                                                               | -                                                                     | -      | -          | -                                                                                                   |
# | 100  | F. Epting                                                 | 1984 | Personal construct counseling and psychotherapy                                                                            | -                                                                     | -      | -          | -                                                                                                   |
# | 88   | M. Mahoney                                                | 1988 | Constructive Metatheory: 1. Basic Features and Historical Foundations                                                      | -                                                                     | -      | -          | [10.1080/10720538808412762](https://doi.org/10.1080/10720538808412762)   |
# | 105  | F. Fransella, L. Thomas                                   | 1988 | Experimenting with personal construct psychology                                                                           | -                                                                     | -      | -          | -                                                                                                   |
# | 77   | G. Kelly                                                  | 1991 | The Psychology of Personal Constructs: Volume Two: Clinical Diagnosis and Psychotherapy                                     | -                                                                     | -      | -          | [10.4324/9780203405987](https://doi.org/10.4324/9780203405987)           |
# | 83   | E. Jones                                                  | 1993 | Personal Construct Psychology in Clinical Practice: Theory, Research and Applications                                      | Postgraduate Medical Journal                                          | 69     | 502-502    | [10.1136/PGMJ.69.812.502-A](https://doi.org/10.1136/PGMJ.69.812.502-A)   |
# | 84   | S. W. Kenneth, et al.                                     | 1996 | Hierarchical elaboration in the conceptual structures of Vietnam combat veterans                                           | Journal of Constructivist Psychology                                  | 9      | 79-96      | [10.1080/10720539608404656](https://doi.org/10.1080/10720539608404656)   |
# | 85   | G. Chiari, M. Nuzzo                                       | 1996 | Psychological constructivisms: A metatheoretical differentiation                                                           | Journal of Constructivist Psychology                                  | 9      | 163-184    | [10.1080/10720539608404663](https://doi.org/10.1080/10720539608404663)   |
# | 89   | B. Held                                                  | 1995 | CONSTRUCTIVISM IN PSYCHOTHERAPY                                                                                            | Annals of the New York Academy of Sciences                            | 775    | null       | [10.1111/j.1749-6632.1996.tb23139.x](https://doi.org/10.1111/j.1749-6632.1996.tb23139.x)             |
# | 90   | E. Gillett                                                | 1998 | Relativism and the Social-constructivist Paradigm                                                                          | Philosophy, Psychiatry, & Psychology                                  | 5      | 37-48      | -                                                                                                   |
# | 92   | Bill Warren                                               | 1998 | Philosophical Dimensions of Personal Construct Psychology                                                                  | -                                                                     | -      | -          | [10.4324/9780203004692](https://doi.org/10.4324/9780203004692)           |
# | 93   | C. Stevens                                                | 1998 | Realism and Kelly'S pragmatic constructivism                                                                               | Journal of Constructivist Psychology                                  | 11     | 283-308    | [10.1080/10720539808405226](https://doi.org/10.1080/10720539808405226)   |
# | 80   | J. Grice                                                  | 2002 | Idiogrid: Software for the management and analysis of repertory grids                                                      | Behavior Research Methods, Instruments, & Computers                  | 34     | 338-341    | [10.3758/BF03195461](https://doi.org/10.3758/BF03195461)                 |
# | 96   | G. Feixas, et al.                                         | 2002 | CONTENT ANALYSIS OF PERSONAL CONSTRUCTS                                                                                    | Journal of Constructivist Psychology                                  | 15     | 1-19       | [10.1080/107205302753305692](https://doi.org/10.1080/107205302753305692) |
# | 91   | D. Jankowicz                                               | 2003 | The Easy Guide to Repertory Grids                                                                                          | -                                                                     | -      | -          | -                                                                                                 |
# | 76   | F. Fransella                                              | 2003 | International handbook of personal construct psychology                                                                    | -                                                                     | -      | -          | -                                                                                                   |
# | 95   | D. Winter                                                 | 2003 | REPERTORY GRID TECHNIQUE AS A PSYCHOTHERAPY RESEARCH MEASURE                                                               | Psychotherapy Research                                                | 13     | 25-42      | [10.1093/ptr/kpg005](https://doi.org/10.1093/ptr/kpg005)                 |
# | 109  | G. Feixas, L. A. Saúl                                     | 2004 | The Multi-Center Dilemma Project: An Investigation on the Role of Cognitive Conflicts in Health                              | The Spanish Journal of Psychology                                     | 7      | 69-78      | [10.1017/S1138741600004765](https://doi.org/10.1017/S1138741600004765)   |
# | 78   | F. Fransella                                              | 2005 | International Handbook of Personal Construct Psychology: Fransella/Personal Construct Psychology                            | -                                                                     | -      | -          | [10.1002/0470013370](https://doi.org/10.1002/0470013370)                 |
# | 73   | D. Winter, L. Viney                                       | 2005 | Personal Construct Psychotherapy: Advances in Theory, Practice and Research                                                 | -                                                                     | -      | -          | -                                                                                                   |
# | 103  | D. Winter, L. Viney                                       | 2005 | Personal Construct Psychotherapy                                                                                           | -                                                                     | -      | -          | [10.1002/9780470713686](https://doi.org/10.1002/9780470713686)           |
# | 81   | G. Feixas, L. A. Saúl                                     | 2005 | Resolution of Dilemmas by Personal Construct Psychotherapy                                                                 | -                                                                     | -      | -          | [10.1002/9780470713686.CH11](https://doi.org/10.1002/9780470713686.CH11) |
# | 87   | G. Kelly                                                  | 2005 | A Brief Introduction to Personal Construct Theory                                                                          | -                                                                     | -      | -          | [10.1002/0470013370.CH1](https://doi.org/10.1002/0470013370.CH1)         |
# | 107  | D. Winter, et al.                                         | 2007 | A controlled trial of personal construct psychotherapy for deliberate self-harm.                                            | Psychology and psychotherapy                                          | 80 Pt 1 | 23-37      | [10.1348/147608306X102778](https://doi.org/10.1348/147608306X102778)     |
# | 101  | B. Walker, D. Winter                                      | 2007 | The elaboration of personal construct psychology.                                                                          | Annual review of psychology                                           | 58     | 453-77     | [10.1146/ANNUREV.PSYCH.58.110405.085535](https://doi.org/10.1146/ANNUREV.PSYCH.58.110405.085535)     |
# | 82   | G. Feixas, et al.                                         | 2008 | Construction of Self and Others in Unipolar Depressive Disorders: A Study Using Repertory Grid Technique                    | Cognitive Therapy and Research                                        | 32     | 386-400    | [10.1007/s10608-007-9149-7](https://doi.org/10.1007/s10608-007-9149-7)   |
# | 110  | D. Winter, et al.                                         | 2000 | The person in society: challenges to a constructivist theory                                                                | -                                                                     | -      | -          | -                                                                                                   |
# | 111  | G. Feixas, et al.                                         | 2009 | Viewing Cognitive Conflicts as Dilemmas: Implications for Mental Health                                                    | Journal of Constructivist Psychology                                  | 22     | 141-169    | [10.1080/10720530802675755](https://doi.org/10.1080/10720530802675755)   |
# | 74   | G. Chiari, M. Nuzzo                                       | 2009 | Constructivist Psychotherapy: A Narrative Hermeneutic Approach                                                              | Clinical Psychology Forum                                             | -      | -          | [10.4324/9780203866733](https://doi.org/10.4324/9780203866733)           |
# | 108  | G. Kelly                                                  | 2011 | The Psychology Of Personal Constructs Volume One A Theory Of Personality                                                    | -                                                                     | -      | -          | [10.4324/9780203405970](https://doi.org/10.4324/9780203405970)           |
# | 104  | G. Feixas, et al.                                         | 2014 | Implicative Dilemmas and Symptom Severity in Depression: A Preliminary and Content Analysis Study                            | Journal of Constructivist Psychology                                  | 27     | 31-40      | [10.1080/10720537.2014.850369](https://doi.org/10.1080/10720537.2014.850369) |
#
# ### Taxonomy
# ```
# - (Construct)Factor
#    |__ Adjective
#          |__ Synonym
#          |__ Verb
#          |__ Noun
# ```

# %% [markdown]
# ##  Steps for PCT Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (PCT).
#     * **Actions:**
#         * Define the PCT dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the PCT dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the PCT dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our PCT Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up PCT experiment
experiment_name = "PCT"
mlflow.set_experiment(experiment_name)

# PCT dataset without 'Construct' labels and includes verbs and nouns
pct_dataset = {
    'Cognitive Flexibility': {
        'Understanding': {
            'Synonyms': ['Comprehending', 'Grasping', 'Perceiving', 'Apprehending', 'Recognizing'],
            'Verbs': ['Comprehend', 'Grasp', 'Perceive', 'Apprehend', 'Recognize'],
            'Nouns': ['Comprehension', 'Grasp', 'Perception', 'Apprehension', 'Recognition']
        },
        'Adaptable': {
            'Synonyms': ['Flexible', 'Versatile', 'Pliant', 'Adjustable', 'Malleable'],
            'Verbs': ['Adapt', 'Flex', 'Versatilize', 'Adjust', 'Mold'],
            'Nouns': ['Adaptability', 'Flexibility', 'Versatility', 'Adjustability', 'Malleability']
        },
        'Insightful': {
            'Synonyms': ['Perceptive', 'Discerning', 'Intuitive', 'Keen', 'Observant'],
            'Verbs': ['Perceive', 'Discern', 'Intuit', 'Keen', 'Observe'],
            'Nouns': ['Perception', 'Discernment', 'Intuition', 'Keenness', 'Observation']
        },
        'Resourceful': {
            'Synonyms': ['Inventive', 'Clever', 'Quick-witted', 'Resourceful', 'Adroit'],
            'Verbs': ['Invent', 'Solve', 'Concoct', 'Utilize', 'Master'],
            'Nouns': ['Inventiveness', 'Cleverness', 'Wittiness', 'Resourcefulness', 'Adroitness']
        },
        'Adaptive': {
            'Synonyms': ['Flexible', 'Adjustable', 'Variable', 'Versatile', 'Malleable'],
            'Verbs': ['Adapt', 'Adjust', 'Change', 'Versatilize', 'Modify'],
            'Nouns': ['Adaptation', 'Adjustability', 'Variability', 'Versatility', 'Malleability']
        }
    },
    'Analytical Reasoning': {
        'Rational': {
            'Synonyms': ['Logical', 'Reasonable', 'Analytical', 'Sensible', 'Cogent'],
            'Verbs': ['Rationalize', 'Reason', 'Analyze', 'Sense', 'Clarify'],
            'Nouns': ['Rationality', 'Reasoning', 'Analysis', 'Sensibility', 'Cogency']
        },
        'Predictable': {
            'Synonyms': ['Consistent', 'Stable', 'Dependable', 'Reliable', 'Unchanging'],
            'Verbs': ['Predict', 'Stabilize', 'Ensure', 'Secure', 'Maintain'],
            'Nouns': ['Predictability', 'Consistency', 'Stability', 'Dependability', 'Reliability']
        },
        'Logical': {
            'Synonyms': ['Reasonable', 'Analytical', 'Rational', 'Valid', 'Well-founded'],
            'Verbs': ['Logize', 'Reason', 'Analyze', 'Validate', 'Found'],
            'Nouns': ['Logic', 'Reasoning', 'Analysis', 'Validity', 'Foundation']
        },
        'Sound': {
            'Synonyms': ['Valid', 'Sensible', 'Justifiable', 'Warranted', 'Rational'],
            'Verbs': ['Validate', 'Justify', 'Rationalize', 'Warrant', 'Confirm'],
            'Nouns': ['Soundness', 'Sensibility', 'Justifiability', 'Warranty', 'Rationality']
        },
        'Systematic': {
            'Synonyms': ['Methodical', 'Organized', 'Orderly', 'Structured', 'Systematized'],
            'Verbs': ['Systematize', 'Organize', 'Order', 'Structure', 'Coordinate'],
            'Nouns': ['Systematization', 'Organization', 'Orderliness', 'Structure', 'Coordination']
        }
    },
    'Innovativeness': {
        'Innovative': {
            'Synonyms': ['Creative', 'Inventive', 'Original', 'Imaginative', 'Resourceful'],
            'Verbs': ['Create', 'Invent', 'Originate', 'Imagine', 'Utilize'],
            'Nouns': ['Creativity', 'Invention', 'Originality', 'Imagination', 'Resourcefulness']
        },
        'Divergent': {
            'Synonyms': ['Different', 'Unconventional', 'Nonconformist', 'Eccentric', 'Quirky'],
            'Verbs': ['Diverge', 'Deviate', 'Rebel', 'Vary', 'Alter'],
            'Nouns': ['Difference', 'Unconventionality', 'Nonconformity', 'Eccentricity', 'Quirkiness']
        },
        'Unique': {
            'Synonyms': ['Distinctive', 'Individual', 'Special', 'Exceptional', 'Uncommon'],
            'Verbs': ['Differentiate', 'Individualize', 'Specialize', 'Excel', 'Stand out'],
            'Nouns': ['Distinctiveness', 'Individuality', 'Specialty', 'Exceptionality', 'Uncommonness']
        },
        'Pioneering': {
            'Synonyms': ['Trailblazing', 'Groundbreaking', 'Cutting-edge', 'Revolutionary', 'Inceptive'],
            'Verbs': ['Pioneer', 'Lead', 'Innovate', 'Revolutionize', 'Initiate'],
            'Nouns': ['Pioneering', 'Leadership', 'Innovation', 'Revolution', 'Inception']
        },
        'Novel': {
            'Synonyms': ['Fresh', 'Innovatory', 'Newfangled', 'Experimental', 'Advanced'],
            'Verbs': ['Innovate', 'Develop', 'Experiment', 'Advance', 'Renew'],
            'Nouns': ['Novelty', 'Innovation', 'Experimentation', 'Advancement', 'Renewal']
        }
    },
    'Emotional Sensitivity': {
        'Empathetic': {
            'Synonyms': ['Compassionate', 'Sympathetic', 'Understanding', 'Considerate', 'Kind-hearted'],
            'Verbs': ['Empathize', 'Sympathize', 'Understand', 'Consider', 'Support'],
            'Nouns': ['Empathy', 'Compassion', 'Understanding', 'Consideration', 'Kind-heartedness']
        },
        'Emotionally Intelligent': {
            'Synonyms': ['Emotionally aware', 'Emotionally in tune', 'Emotionally savvy', 'Sensitive to emotions', 'Emotionally perceptive'],
            'Verbs': ['Perceive', 'Tune in', 'Manage', 'Navigate', 'Read'],
            'Nouns': ['Emotional intelligence', 'Emotional awareness', 'Sensitivity', 'Perceptiveness', 'Acuity']
        },
        'Sensitive': {
            'Synonyms': ['Tuned in', 'Caring', 'Considerate', 'Responsive', 'Attentive'],
            'Verbs': ['Sense', 'Care for', 'Attend to', 'Respond to', 'Heed'],
            'Nouns': ['Sensitivity', 'Care', 'Consideration', 'Responsiveness', 'Attentiveness']
        },
        'Compassive': {
            'Synonyms': ['Cordial', 'Tender-hearted', 'Supportive', 'Solicitous', 'Feeling'],
            'Verbs': ['Comfort', 'Nurture', 'Aid', 'Encourage', 'Care'],
            'Nouns': ['Compassion', 'Tenderness', 'Support', 'Solicitude', 'Feeling']
        },
        'Heartfelt': {
            'Synonyms': ['Sincere', 'Genuine', 'Wholehearted', 'Deeply felt', 'Earnest'],
            'Verbs': ['Express', 'Convey', 'Manifest', 'Project', 'Reveal'],
            'Nouns': ['Sincerity', 'Genuineness', 'Heartfelt emotion', 'Earnestness', 'Depth']
        }
    },
    'Assertiveness': {
        'Assertive': {
            'Synonyms': ['Confident', 'Decisive', 'Determined', 'Bold', 'Resolute'],
            'Verbs': ['Assert', 'Decide', 'Determine', 'Boldly act', 'Resolve'],
            'Nouns': ['Assertiveness', 'Confidence', 'Decisiveness', 'Boldness', 'Resolution']
        },
        'Dominant': {
            'Synonyms': ['Commanding', 'Controlling', 'Overbearing', 'Authoritative', 'Imperious'],
            'Verbs': ['Dominate', 'Control', 'Command', 'Overbear', 'Rule'],
            'Nouns': ['Dominance', 'Control', 'Command', 'Authority', 'Imperiousness']
        },
        'Self-assured': {
            'Synonyms': ['Confident', 'Positive', 'Secure', 'Self-confident', 'Assured'],
            'Verbs': ['Reassure', 'Self-validate', 'Secure', 'Affirm', 'Fortify'],
            'Nouns': ['Self-assurance', 'Confidence', 'Security', 'Self-belief', 'Assuredness']
        },
        'Unyielding': {
            'Synonyms': ['Persistent', 'Unwavering', 'Tenacious', 'Steadfast', 'Inflexible'],
            'Verbs': ['Persist', 'Hold firm', 'Stand strong', 'Resist', 'Endure'],
            'Nouns': ['Persistence', 'Unwavering stance', 'Tenacity', 'Steadfastness', 'Inflexibility']
        },
        'Courageous': {
            'Synonyms': ['Brave', 'Fearless', 'Valiant', 'Heroic', 'Daring'],
            'Verbs': ['Brave', 'Face', 'Challenge', 'Confront', 'Dare'],
            'Nouns': ['Courage', 'Bravery', 'Valiance', 'Heroism', 'Daringness']
        }
    },
    'Intuition': {
        'Intuitive': {
            'Synonyms': ['Instinctive', 'Natural', 'Inherent', 'Spontaneous', 'Automatic'],
            'Verbs': ['Sense', 'Intuit', 'Perceive', 'Feel', 'Grasp'],
            'Nouns': ['Instinct', 'Intuition', 'Perception', 'Feeling', 'Grasping']
        },
        'Impulsivity': {
            'Synonyms': ['Unthinking', 'Rash', 'Hasty', 'Impetuous', 'Cavalier'],
            'Verbs': ['Act impulsively', 'React', 'Leap', 'Rush', 'Hasten'],
            'Nouns': ['Impulsiveness', 'Haste', 'Rashness', 'Impetuosity', 'Cavalier behavior']
        },
        'Instinctual': {
            'Synonyms': ['Innate', 'Inborn', 'Primitive', 'Hardwired', 'Inherent'],
            'Verbs': ['Follow instinct', 'React primitively', 'Operate naturally', 'Behave instinctively', 'Act inherently'],
            'Nouns': ['Instinct', 'Inborn trait', 'Primitiveness', 'Hardwiring', 'Inherent nature']
        },
        'Perceptive': {
            'Synonyms': ['Observant', 'Aware', 'Insightful', 'Discerning', 'Keen'],
            'Verbs': ['Observe', 'Perceive', 'Discern', 'Detect', 'Recognize'],
            'Nouns': ['Perceptiveness', 'Awareness', 'Insight', 'Discernment', 'Keenness']
        },
        'Responsive': {
            'Synonyms': ['Attuned', 'Sensitive', 'Receptive', 'Quick to react', 'Answering'],
            'Verbs': ['Respond', 'React', 'Reply', 'Heed', 'Acknowledge'],
            'Nouns': ['Responsiveness', 'Receptivity', 'Sensitivity', 'Readiness', 'Alertness']
        }
    },
    'Perseverance': {
        'Patient': {
            'Synonyms': ['Tolerant', 'Forbearing', 'Enduring', 'Steadfast', 'Calm'],
            'Verbs': ['Wait patiently', 'Tolerate', 'Endure', 'Persevere', 'Maintain composure'],
            'Nouns': ['Patience', 'Tolerance', 'Endurance', 'Steadfastness', 'Calmness']
        },
        'Persevering': {
            'Synonyms': ['Persistent', 'Determined', 'Dogged', 'Tenacious', 'Relentless'],
            'Verbs': ['Persist', 'Continue', 'Insist', 'Persevere', 'Push'],
            'Nouns': ['Persistence', 'Determination', 'Tenacity', 'Doggedness', 'Relentlessness']
        },
        'Enduring': {
            'Synonyms': ['Lasting', 'Durable', 'Persistent', 'Constant', 'Unyielding'],
            'Verbs': ['Last', 'Survive', 'Persist', 'Withstand', 'Endure'],
            'Nouns': ['Endurance', 'Durability', 'Persistence', 'Constancy', 'Resilience']
        },
        'Resilient': {
            'Synonyms': ['Tough', 'Flexible', 'Recoverable', 'Strong', 'Adaptable'],
            'Verbs': ['Recover', 'Rebound', 'Adapt', 'Bounce back', 'Resist'],
            'Nouns': ['Resilience', 'Toughness', 'Recovery', 'Adaptability', 'Flexibility']
        },
        'Unyielding': {
            'Synonyms': ['Inflexible', 'Stubborn', 'Obdurate', 'Adamant', 'Intransigent'],
            'Verbs': ['Stand firm', 'Resist', 'Insist', 'Persist', 'Hold fast'],
            'Nouns': ['Inflexibility', 'Stubbornness', 'Obduracy', 'Adamance', 'Firmness']
        }
    },
    'Harmony': {
        'Harmonious': {
            'Synonyms': ['Balanced', 'Symmetrical', 'Congruent', 'Proportionate', 'Coordinated'],
            'Verbs': ['Balance', 'Coordinate', 'Align', 'Match', 'Sync'],
            'Nouns': ['Harmony', 'Balance', 'Symmetry', 'Congruence', 'Coordination']
        },
        'Integrated': {
            'Synonyms': ['Unified', 'Incorporated', 'Combined', 'Merged', 'Consolidated'],
            'Verbs': ['Integrate', 'Unify', 'Merge', 'Combine', 'Consolidate'],
            'Nouns': ['Integration', 'Unity', 'Combination', 'Merger', 'Consolidation']
        },
        'Coherent': {
            'Synonyms': ['Consistent', 'Logical', 'Clear', 'Lucid', 'Understandable'],
            'Verbs': ['Clarify', 'Explain', 'Elucidate', 'Rationalize', 'Simplify'],
            'Nouns': ['Coherence', 'Consistency', 'Clarity', 'Lucidity', 'Rationality']
        },
        'Unified': {
            'Synonyms': ['Integrated', 'Merged', 'Coordinated', 'Converged', 'Amalgamated'],
            'Verbs': ['Unite', 'Merge', 'Coordinate', 'Harmonize', 'Consolidate'],
            'Nouns': ['Unity', 'Integration', 'Coordination', 'Convergence', 'Amalgamation']
        },
        'Tranquil': {
            'Synonyms': ['Peaceful', 'Calm', 'Serene', 'Relaxing', 'Soothing'],
            'Verbs': ['Calm', 'Soothe', 'Quiet', 'Pacify', 'Tranquilize'],
            'Nouns': ['Tranquility', 'Calmness', 'Serenity', 'Relaxation', 'Peacefulness']
        }
    },
    'Self-concept': {
        'Self-esteem': {
            'Synonyms': ['Confident', 'Self-assured', 'Self-respecting', 'Proud', 'Valued'],
            'Verbs': ['Uphold', 'Boost', 'Maintain', 'Affirm', 'Value'],
            'Nouns': ['Confidence', 'Self-worth', 'Pride', 'Esteem', 'Value']
        },
        'Self-identity': {
            'Synonyms': ['Individualistic', 'Personal', 'Unique', 'Distinctive', 'Original'],
            'Verbs': ['Define', 'Differentiate', 'Personalize', 'Identify', 'Characterize'],
            'Nouns': ['Identity', 'Individuality', 'Uniqueness', 'Personality', 'Selfhood']
        },
        'Self-efficacy': {
            'Synonyms': ['Capable', 'Competent', 'Effective', 'Potent', 'Skilled'],
            'Verbs': ['Achieve', 'Manage', 'Perform', 'Accomplish', 'Succeed'],
            'Nouns': ['Capability', 'Competence', 'Effectiveness', 'Potency', 'Skill']
        },
        'Self-assured': {
            'Synonyms': ['Confident', 'Secure', 'Certain', 'Unwavering', 'Self-confident'],
            'Verbs': ['Reassure', 'Secure', 'Empower', 'Strengthen', 'Assert'],
            'Nouns': ['Assurance', 'Security', 'Certainty', 'Confidence', 'Self-belief']
        }
    },
    'Interpersonal Relationships': {
        'Trust': {
            'Synonyms': ['Reliable', 'Trustworthy', 'Dependable', 'Loyal', 'Steadfast'],
            'Verbs': ['Rely on', 'Depend', 'Trust', 'Count on', 'Confide'],
            'Nouns': ['Reliability', 'Trustworthiness', 'Dependability', 'Loyalty', 'Commitment']
        },
        'Empathy': {
            'Synonyms': ['Understanding', 'Compassionate', 'Caring', 'Sensitive', 'Receptive'],
            'Verbs': ['Understand', 'Sympathize', 'Relate', 'Perceive', 'Commiserate'],
            'Nouns': ['Understanding', 'Compassion', 'Caring', 'Sensitivity', 'Receptiveness']
        },
        'Intimacy': {
            'Synonyms': ['Close', 'Connected', 'Bonded', 'Personal', 'Confidential'],
            'Verbs': ['Bond', 'Connect', 'Share', 'Unite', 'Confide'],
            'Nouns': ['Closeness', 'Connection', 'Bonding', 'Intimacy', 'Confidence']
        },
        'Connection': {
            'Synonyms': ['Linked', 'Connected', 'Unified', 'Joined', 'Associated'],
            'Verbs': ['Link', 'Connect', 'Join', 'Associate', 'Unite'],
            'Nouns': ['Linkage', 'Connection', 'Unity', 'Association', 'Partnership']
        },
        'Companionship': {
            'Synonyms': ['Friendly', 'Companionable', 'Sociable', 'Supportive', 'Affable'],
            'Verbs': ['Accompany', 'Associate', 'Socialize', 'Support', 'Befriend'],
            'Nouns': ['Friendship', 'Companionship', 'Sociability', 'Support', 'Affability']
        }
    },
    'Emotional': {
        'Happiness': {
            'Synonyms': ['Joyful', 'Cheerful', 'Content', 'Pleased', 'Satisfied'],
            'Verbs': ['Enjoy', 'Cherish', 'Savor', 'Delight in', 'Appreciate'],
            'Nouns': ['Joy', 'Cheerfulness', 'Contentment', 'Pleasure', 'Satisfaction']
        },
        'Sadness': {
            'Synonyms': ['Unhappy', 'Sorrowful', 'Melancholic', 'Mournful', 'Despondent'],
            'Verbs': ['Mourn', 'Grieve', 'Lament', 'Sulk', 'Brood'],
            'Nouns': ['Unhappiness', 'Sorrow', 'Melancholy', 'Mourning', 'Despondency']
        },
        'Anger': {
            'Synonyms': ['Irritated', 'Enraged', 'Furious', 'Incensed', 'Annoyed'],
            'Verbs': ['Rage', 'Fume', 'Seethe', 'Explode', 'React'],
            'Nouns': ['Irritation', 'Fury', 'Rage', 'Wrath', 'Annoyance']
        },
        'Calmness': {
            'Synonyms': ['Peaceful', 'Tranquil', 'Serene', 'Steady', 'Placid'],
            'Verbs': ['Soothe', 'Calm', 'Quiet', 'Pacify', 'Stabilize'],
            'Nouns': ['Peace', 'Tranquility', 'Serenity', 'Steadiness', 'Calm']
        },
        'Surprise': {
            'Synonyms': ['Astounded', 'Amazed', 'Startled', 'Shocked', 'Stunned'],
            'Verbs': ['Surprise', 'Astonish', 'Amaze', 'Startle', 'Shock'],
            'Nouns': ['Surprise', 'Astonishment', 'Amazement', 'Startlement', 'Shock']
        }
    },
    'Cognitive': {
        'Intelligence': {
            'Synonyms': ['Smart', 'Insightful', 'Clever', 'Astute', 'Knowledgeable'],
            'Verbs': ['Analyze', 'Comprehend', 'Think', 'Reason', 'Understand'],
            'Nouns': ['Intelligence', 'Insight', 'Cleverness', 'Astuteness', 'Knowledge']
        },
        'Creativity': {
            'Synonyms': ['Innovative', 'Artistic', 'Original', 'Imaginative', 'Inventive'],
            'Verbs': ['Create', 'Design', 'Innovate', 'Imagine', 'Invent'],
            'Nouns': ['Creativity', 'Artistry', 'Originality', 'Imagination', 'Invention']
        },
        'Memory': {
            'Synonyms': ['Recall', 'Retentive', 'Memorable', 'Persistent', 'Lasting'],
            'Verbs': ['Remember', 'Recall', 'Retain', 'Memorize', 'Record'],
            'Nouns': ['Memory', 'Recollection', 'Retention', 'Remembrance', 'Recall']
        },
        'Analytical': {
            'Synonyms': ['Logical', 'Reasoning', 'Systematic', 'Methodical', 'Rational'],
            'Verbs': ['Analyze', 'Evaluate', 'Deduce', 'Reason', 'Assess'],
            'Nouns': ['Analysis', 'Evaluation', 'Deduction', 'Reasoning', 'Assessment']
        },
        'Problem-solving': {
            'Synonyms': ['Solution-oriented', 'Resolutive', 'Analytical', 'Resourceful', 'Practical'],
            'Verbs': ['Solve', 'Resolve', 'Address', 'Tackle', 'Manage'],
            'Nouns': ['Problem-solving', 'Resolution', 'Solution', 'Resourcefulness', 'Practicality']
        }
    },
    'Motivational': {
        'Motivation': {
            'Synonyms': ['Driven', 'Energetic', 'Dynamic', 'Persistent', 'Proactive'],
            'Verbs': ['Motivate', 'Drive', 'Inspire', 'Energize', 'Activate'],
            'Nouns': ['Motivation', 'Drive', 'Inspiration', 'Energy', 'Activation']
        },
        'Ambition': {
            'Synonyms': ['Aspirational', 'Goal-driven', 'Determined', 'Eager', 'Zealous'],
            'Verbs': ['Aspire', 'Strive', 'Seek', 'Pursue', 'Chase'],
            'Nouns': ['Ambition', 'Aspiration', 'Determination', 'Eagerness', 'Zeal']
        },
        'Drive': {
            'Synonyms': ['Compelling', 'Forceful', 'Dynamic', 'Vigorous', 'Strong'],
            'Verbs': ['Push', 'Compel', 'Drive', 'Propel', 'Stimulate'],
            'Nouns': ['Drive', 'Compulsion', 'Forcefulness', 'Vigor', 'Strength']
        },
        'Dedication': {
            'Synonyms': ['Committed', 'Devoted', 'Loyal', 'Faithful', 'Steadfast'],
            'Verbs': ['Dedicate', 'Commit', 'Devote', 'Pledge', 'Adhere'],
            'Nouns': ['Dedication', 'Commitment', 'Devotion', 'Faithfulness', 'Steadfastness']
        },
        'Enthusiasm': {
            'Synonyms': ['Excited', 'Passionate', 'Vibrant', 'Energetic', 'Zealous'],
            'Verbs': ['Enthuse', 'Excite', 'Energize', 'Animate', 'Inspire'],
            'Nouns': ['Enthusiasm', 'Excitement', 'Passion', 'Energy', 'Zest']
        }
    },
    'Moral': {
        'Ethics': {
            'Synonyms': ['Principled', 'Righteous', 'Moralistic', 'Upright', 'Honorable'],
            'Verbs': ['Adhere', 'Conform', 'Uphold', 'Practice', 'Maintain'],
            'Nouns': ['Ethics', 'Principles', 'Morality', 'Uprightness', 'Honor']
        },
        'Morality': {
            'Synonyms': ['Virtuous', 'Good', 'Decent', 'Proper', 'Ethical'],
            'Verbs': ['Behave', 'Act', 'Operate', 'Function', 'React'],
            'Nouns': ['Morality', 'Virtue', 'Decency', 'Ethics', 'Conduct']
        },
        'Right vs. Wrong': {
            'Synonyms': ['Just', 'Fair', 'Correct', 'Proper', 'Righteous'],
            'Verbs': ['Judge', 'Decide', 'Determine', 'Assess', 'Evaluate'],
            'Nouns': ['Judgment', 'Decision', 'Determination', 'Assessment', 'Evaluation']
        },
        'Conscientious': {
            'Synonyms': ['Diligent', 'Careful', 'Meticulous', 'Thorough', 'Precise'],
            'Verbs': ['Manage', 'Handle', 'Administrate', 'Organize', 'Coordinate'],
            'Nouns': ['Conscientiousness', 'Diligence', 'Carefulness', 'Meticulousness', 'Precision']
        },
        'Upright': {
            'Synonyms': ['Honorable', 'Respectable', 'Noble', 'Dignified', 'Decorous'],
            'Verbs': ['Maintain', 'Preserve', 'Uphold', 'Protect', 'Defend'],
            'Nouns': ['Uprightness', 'Honor', 'Respectability', 'Nobility', 'Dignity']
        }
    },
    'Work-related': {
        'Job Satisfaction': {
            'Synonyms': ['Contented', 'Pleased', 'Satisfied', 'Fulfilled', 'Gratified'],
            'Verbs': ['Enjoy', 'Appreciate', 'Value', 'Cherish', 'Savor'],
            'Nouns': ['Satisfaction', 'Pleasure', 'Contentment', 'Fulfillment', 'Gratification']
        },
        'Work-life Balance': {
            'Synonyms': ['Harmonious', 'Integrated', 'Balanced', 'Aligned', 'Coordinated'],
            'Verbs': ['Balance', 'Harmonize', 'Sync', 'Align', 'Arrange'],
            'Nouns': ['Equilibrium', 'Harmony', 'Alignment', 'Coordination', 'Synthesis']
        },
        'Career Success': {
            'Synonyms': ['Achievement', 'Prosperity', 'Advancement', 'Progress', 'Triumph'],
            'Verbs': ['Succeed', 'Advance', 'Progress', 'Achieve', 'Triumph'],
            'Nouns': ['Success', 'Advancement', 'Achievement', 'Progression', 'Triumph']
        },
        'Satisfying': {
            'Synonyms': ['Gratifying', 'Pleasing', 'Rewarding', 'Enjoyable', 'Delightful'],
            'Verbs': ['Please', 'Gratify', 'Satisfy', 'Delight', 'Entertain'],
            'Nouns': ['Satisfaction', 'Pleasure', 'Gratification', 'Enjoyment', 'Delight']
        },
        'Harmonious': {
            'Synonyms': ['Congruent', 'Compatible', 'Consistent', 'Accordant', 'Coherent'],
            'Verbs': ['Agree', 'Correlate', 'Match', 'Fit', 'Accord'],
            'Nouns': ['Harmony', 'Congruence', 'Compatibility', 'Consistency', 'Accordance']
        }
    },
    'Health-related': {
        'Well-being': {
            'Synonyms': ['Healthy', 'Wholesome', 'Sound', 'Fit', 'Robust'],
            'Verbs': ['Maintain', 'Foster', 'Promote', 'Support', 'Nurture'],
            'Nouns': ['Health', 'Fitness', 'Vitality', 'Wellness', 'Robustness']
        },
        'Stress': {
            'Synonyms': ['Tense', 'Strained', 'Pressured', 'Stressed', 'Overwhelmed'],
            'Verbs': ['Manage', 'Alleviate', 'Reduce', 'Control', 'Mitigate'],
            'Nouns': ['Tension', 'Pressure', 'Stress', 'Overload', 'Strain']
        },
        'Resilience': {
            'Synonyms': ['Strong', 'Sturdy', 'Tough', 'Hardy', 'Unyielding'],
            'Verbs': ['Recover', 'Rebound', 'Resist', 'Withstand', 'Survive'],
            'Nouns': ['Resilience', 'Sturdiness', 'Toughness', 'Hardiness', 'Endurance']
        },
        'Vitality': {
            'Synonyms': ['Lively', 'Energetic', 'Vigorous', 'Dynamic', 'Active'],
            'Verbs': ['Invigorate', 'Energize', 'Animate', 'Revitalize', 'Stimulate'],
            'Nouns': ['Vitality', 'Energy', 'Vigor', 'Dynamism', 'Activity']
        },
        'Calmness': {
            'Synonyms': ['Peaceful', 'Tranquil', 'Serene', 'Placid', 'Composed'],
            'Verbs': ['Calm', 'Soothe', 'Quiet', 'Settle', 'Pacify'],
            'Nouns': ['Calmness', 'Tranquility', 'Serenity', 'Peace', 'Composure']
        }
    },
    'Time Management': {
        'Efficiency': {
            'Synonyms': ['Productive', 'Capable', 'Effective', 'Competent'],
            'Verbs': ['Maximize', 'Optimize', 'Streamline', 'Expedite'],
            'Nouns': ['Efficiency', 'Productivity', 'Capability', 'Effectiveness']
        },
        'Organization': {
            'Synonyms': ['Structured', 'Ordered', 'Systematic', 'Arranged'],
            'Verbs': ['Organize', 'Arrange', 'Systematize', 'Coordinate'],
            'Nouns': ['Organization', 'Structure', 'Systematization', 'Coordination']
        },
        'Prioritization': {
            'Synonyms': ['Focal', 'Preferential', 'Primary', 'Foremost'],
            'Verbs': ['Prioritize', 'Rank', 'Classify', 'Order'],
            'Nouns': ['Priority', 'Preference', 'Primacy', 'Precedence']
        },
        'Deadline Adherence': {
            'Synonyms': ['Timely', 'Punctual', 'On-schedule', 'Deadline-oriented'],
            'Verbs': ['Meet', 'Observe', 'Respect', 'Comply'],
            'Nouns': ['Timeliness', 'Punctuality', 'Adherence', 'Compliance']
        },
        'Procrastination Management': {
            'Synonyms': ['Prompt', 'Decisive', 'Immediate', 'Active'],
            'Verbs': ['Act', 'Decide', 'Initiate', 'Proceed'],
            'Nouns': ['Action', 'Decision', 'Initiation', 'Activity']
        }
    },
    'Environmental Conservation': {
        'Conservation': {
            'Synonyms': ['Preserving', 'Protecting', 'Safeguarding', 'Conserving'],
            'Verbs': ['Conserve', 'Preserve', 'Protect', 'Maintain'],
            'Nouns': ['Conservation', 'Preservation', 'Protection', 'Maintenance']
        },
        'Recycling': {
            'Synonyms': ['Reusing', 'Reprocessing', 'Recovering', 'Salvaging'],
            'Verbs': ['Recycle', 'Reuse', 'Reprocess', 'Recover'],
            'Nouns': ['Recycling', 'Reusability', 'Reprocessing', 'Recovery']
        },
        'Sustainable Living': {
            'Synonyms': ['Eco-friendly', 'Green', 'Resource-efficient', 'Low-impact'],
            'Verbs': ['Sustain', 'Live sustainably', 'Utilize efficiently', 'Reduce impact'],
            'Nouns': ['Sustainability', 'Green living', 'Efficiency', 'Impact reduction']
        },
        'Pollution Reduction': {
            'Synonyms': ['Emission-cutting', 'Waste-reducing', 'Contaminant-lowering', 'Clean-up'],
            'Verbs': ['Reduce', 'Minimize', 'Lower', 'Clean'],
            'Nouns': ['Reduction', 'Minimization', 'Lowering', 'Cleanup']
        },
        'Climate Change Mitigation': {
            'Synonyms': ['Emission control', 'Carbon footprint reduction', 'Greenhouse effect limiting', 'Global warming prevention'],
            'Verbs': ['Mitigate', 'Control', 'Reduce', 'Prevent'],
            'Nouns': ['Mitigation', 'Control', 'Reduction', 'Prevention']
        }
    },
    'Social Skills': {
        'Interpersonal Communication': {
            'Synonyms': ['Conversational', 'Interactive', 'Engaging', 'Communicative'],
            'Verbs': ['Communicate', 'Interact', 'Engage', 'Connect'],
            'Nouns': ['Communication', 'Interaction', 'Engagement', 'Connection']
        },
        'Empathy': {
            'Synonyms': ['Understanding', 'Compassionate', 'Sympathetic', 'Kind'],
            'Verbs': ['Empathize', 'Understand', 'Sympathize', 'Support'],
            'Nouns': ['Empathy', 'Understanding', 'Compassion', 'Kindness']
        },
        'Conflict Resolution': {
            'Synonyms': ['Peacemaking', 'Mediating', 'Reconciling', 'Settling'],
            'Verbs': ['Resolve', 'Mediate', 'Reconcile', 'Settle'],
            'Nouns': ['Resolution', 'Mediation', 'Reconciliation', 'Settlement']
        },
        'Team Collaboration': {
            'Synonyms': ['Cooperative', 'Team-oriented', 'Collaborative', 'Synergistic'],
            'Verbs': ['Collaborate', 'Cooperate', 'Participate', 'Synergize'],
            'Nouns': ['Collaboration', 'Cooperation', 'Participation', 'Synergy']
        },
        'Leadership': {
            'Synonyms': ['Guiding', 'Directing', 'Influencing', 'Commanding'],
            'Verbs': ['Lead', 'Guide', 'Influence', 'Command'],
            'Nouns': ['Leadership', 'Guidance', 'Influence', 'Command']
        }
    },
    'Personal Growth': {
        'Self-Improvement': {
            'Synonyms': ['Enhancement', 'Development', 'Advancement', 'Progress'],
            'Verbs': ['Improve', 'Enhance', 'Develop', 'Advance'],
            'Nouns': ['Improvement', 'Enhancement', 'Development', 'Advancement']
        },
        'Goal Setting': {
            'Synonyms': ['Targeting', 'Planning', 'Aiming', 'Objectiving'],
            'Verbs': ['Set', 'Plan', 'Target', 'Aim'],
            'Nouns': ['Goal', 'Plan', 'Target', 'Objective']
        },
        'Adaptability': {
            'Synonyms': ['Flexibility', 'Versatility', 'Resilience', 'Adjustability'],
            'Verbs': ['Adapt', 'Flex', 'Adjust', 'Accommodate'],
            'Nouns': ['Adaptability', 'Flexibility', 'Versatility', 'Resilience']
        },
        'Mindfulness': {
            'Synonyms': ['Awareness', 'Presence', 'Consciousness', 'Attentiveness'],
            'Verbs': ['Mind', 'Attend', 'Focus', 'Observe'],
            'Nouns': ['Mindfulness', 'Awareness', 'Consciousness', 'Presence']
        },
        'Resilience': {
            'Synonyms': ['Toughness', 'Hardiness', 'Strength', 'Endurance'],
            'Verbs': ['Bounce back', 'Recover', 'Persist', 'Endure'],
            'Nouns': ['Resilience', 'Recovery', 'Persistence', 'Endurance']
        }
    },
    'Mental Health': {
        'Stress Management': {
            'Synonyms': ['Coping', 'Handling', 'Controlling', 'Mitigating'],
            'Verbs': ['Manage', 'Control', 'Alleviate', 'Reduce'],
            'Nouns': ['Management', 'Control', 'Alleviation', 'Reduction']
        },
        'Anxiety Reduction': {
            'Synonyms': ['Calming', 'Soothing', 'Relieving', 'Easing'],
            'Verbs': ['Calm', 'Soothe', 'Relieve', 'Ease'],
            'Nouns': ['Calmness', 'Soothing', 'Relief', 'Ease']
        },
        'Depression Awareness': {
            'Synonyms': ['Recognition', 'Understanding', 'Insight', 'Acknowledgment'],
            'Verbs': ['Recognize', 'Understand', 'Identify', 'Acknowledge'],
            'Nouns': ['Recognition', 'Understanding', 'Insight', 'Awareness']
        },
        'Emotional Regulation': {
            'Synonyms': ['Balancing', 'Controlling', 'Managing', 'Stabilizing'],
            'Verbs': ['Regulate', 'Control', 'Manage', 'Balance'],
            'Nouns': ['Regulation', 'Control', 'Management', 'Balance']
        },
        'Happiness Cultivation': {
            'Synonyms': ['Fostering', 'Encouraging', 'Promoting', 'Enhancing'],
            'Verbs': ['Cultivate', 'Foster', 'Promote', 'Enhance'],
            'Nouns': ['Cultivation', 'Fostering', 'Promotion', 'Enhancement']
        }
    },
    'Career Development': {
        'Professional Growth': {
            'Synonyms': ['Advancement', 'Progression', 'Elevation', 'Development'],
            'Verbs': ['Advance', 'Progress', 'Develop', 'Elevate'],
            'Nouns': ['Advancement', 'Progression', 'Development', 'Elevation']
        },
        'Skill Acquisition': {
            'Synonyms': ['Learning', 'Mastering', 'Gaining', 'Obtaining'],
            'Verbs': ['Acquire', 'Learn', 'Master', 'Gain'],
            'Nouns': ['Acquisition', 'Learning', 'Mastery', 'Gain']
        },
        'Leadership Training': {
            'Synonyms': ['Coaching', 'Mentoring', 'Guiding', 'Educating'],
            'Verbs': ['Train', 'Coach', 'Mentor', 'Guide'],
            'Nouns': ['Training', 'Coaching', 'Mentoring', 'Guidance']
        },
        'Networking Enhancement': {
            'Synonyms': ['Building', 'Expanding', 'Strengthening', 'Broadening'],
            'Verbs': ['Enhance', 'Build', 'Expand', 'Strengthen'],
            'Nouns': ['Enhancement', 'Building', 'Expansion', 'Strengthening']
        },
        'Job Satisfaction': {
            'Synonyms': ['Fulfillment', 'Contentment', 'Pleasure', 'Gratification'],
            'Verbs': ['Satisfy', 'Fulfill', 'Content', 'Gratify'],
            'Nouns': ['Satisfaction', 'Fulfillment', 'Contentment', 'Gratification']
        }
    },
    'Cultural Awareness': {
        'Cultural Sensitivity': {
            'Synonyms': ['Cultural understanding', 'Ethnocultural empathy', 'Cross-cultural awareness', 'Multicultural sensitivity'],
            'Verbs': ['Understand', 'Empathize', 'Recognize', 'Appreciate'],
            'Nouns': ['Understanding', 'Empathy', 'Recognition', 'Appreciation']
        },
        'Cultural Competence': {
            'Synonyms': ['Cultural proficiency', 'Cross-cultural skills', 'Multicultural competence', 'Intercultural ability'],
            'Verbs': ['Navigate', 'Communicate', 'Interact', 'Engage'],
            'Nouns': ['Proficiency', 'Skills', 'Competence', 'Ability']
        },
        'Global Mindset': {
            'Synonyms': ['Global awareness', 'Worldly understanding', 'International outlook', 'Transnational perspective'],
            'Verbs': ['Adapt', 'Open', 'Integrate', 'Embrace'],
            'Nouns': ['Mindset', 'Awareness', 'Outlook', 'Perspective']
        },
        'Cultural Adaptation': {
            'Synonyms': ['Cultural integration', 'Cultural adjustment', 'Cross-cultural adaptation', 'Multicultural adaptation'],
            'Verbs': ['Adapt', 'Adjust', 'Assimilate', 'Acclimatize'],
            'Nouns': ['Integration', 'Adjustment', 'Adaptation', 'Acclimatization']
        },
        'Cultural Advocacy': {
            'Synonyms': ['Cultural representation', 'Cultural defense', 'Multicultural advocacy', 'Cultural support'],
            'Verbs': ['Advocate', 'Promote', 'Support', 'Defend'],
            'Nouns': ['Advocacy', 'Promotion', 'Support', 'Defense']
        }
    },
    'Environmental Advocacy': {
        'Eco-Friendly Practices': {
            'Synonyms': ['Green practices', 'Sustainable methods', 'Environmental friendliness', 'Eco-conscious behaviors'],
            'Verbs': ['Practice', 'Implement', 'Maintain', 'Adopt'],
            'Nouns': ['Practices', 'Methods', 'Behaviors', 'Actions']
        },
        'Conservation Initiatives': {
            'Synonyms': ['Resource preservation', 'Wildlife conservation', 'Environmental protection', 'Nature conservation'],
            'Verbs': ['Conserve', 'Preserve', 'Protect', 'Maintain'],
            'Nouns': ['Conservation', 'Preservation', 'Protection', 'Maintenance']
        },
        'Sustainability Projects': {
            'Synonyms': ['Sustainable development', 'Green projects', 'Eco-development', 'Sustainability efforts'],
            'Verbs': ['Develop', 'Build', 'Design', 'Implement'],
            'Nouns': ['Projects', 'Development', 'Efforts', 'Initiatives']
        },
        'Renewable Energy Adoption': {
            'Synonyms': ['Solar energy use', 'Wind energy implementation', 'Geothermal energy adoption', 'Hydro energy exploitation'],
            'Verbs': ['Adopt', 'Utilize', 'Implement', 'Exploit'],
            'Nouns': ['Adoption', 'Utilization', 'Implementation', 'Exploitation']
        },
        'Pollution Reduction': {
            'Synonyms': ['Emission control', 'Waste reduction', 'Toxin decrease', 'Contaminant reduction'],
            'Verbs': ['Reduce', 'Control', 'Decrease', 'Minimize'],
            'Nouns': ['Reduction', 'Control', 'Decrease', 'Minimization']
        }
    },
    'Digital Transformation': {
        'Technology Integration': {
            'Synonyms': ['Tech incorporation', 'System digitization', 'Software implementation', 'Platform integration'],
            'Verbs': ['Integrate', 'Incorporate', 'Digitize', 'Implement'],
            'Nouns': ['Integration', 'Incorporation', 'Digitization', 'Implementation']
        },
        'Digital Literacy': {
            'Synonyms': ['Tech fluency', 'Digital skills', 'Cyber literacy', 'Online proficiency'],
            'Verbs': ['Master', 'Develop', 'Enhance', 'Learn'],
            'Nouns': ['Literacy', 'Skills', 'Proficiency', 'Fluency']
        },
        'Cybersecurity Measures': {
            'Synonyms': ['Data protection', 'Information security', 'Network defense', 'Cyber safeguards'],
            'Verbs': ['Secure', 'Protect', 'Defend', 'Safeguard'],
            'Nouns': ['Security', 'Protection', 'Defense', 'Safeguards']
        },
        'AI Implementation': {
            'Synonyms': ['Artificial intelligence deployment', 'AI development', 'Robotics integration', 'Machine learning application'],
            'Verbs': ['Implement', 'Deploy', 'Develop', 'Apply'],
            'Nouns': ['Implementation', 'Deployment', 'Development', 'Application']
        },
        'Cloud Computing': {
            'Synonyms': ['Cloud services', 'Cloud-based technology', 'Online storage solutions', 'Virtual server environments'],
            'Verbs': ['Migrate', 'Store', 'Access', 'Manage'],
            'Nouns': ['Computing', 'Services', 'Solutions', 'Environments']
        }
    },
    'Personal Development': {
        'Self-Improvement': {
            'Synonyms': ['Self-enhancement', 'Personal growth', 'Self-development', 'Capacity building'],
            'Verbs': ['Improve', 'Enhance', 'Grow', 'Develop'],
            'Nouns': ['Improvement', 'Enhancement', 'Growth', 'Development']
        },
        'Goal Setting': {
            'Synonyms': ['Objective planning', 'Target establishment', 'Aim configuration', 'Goal formulation'],
            'Verbs': ['Set', 'Plan', 'Establish', 'Formulate'],
            'Nouns': ['Setting', 'Planning', 'Establishment', 'Formulation']
        },
        'Resilience': {
            'Synonyms': ['Toughness', 'Robustness', 'Sturdiness', 'Endurance'],
            'Verbs': ['Persist', 'Overcome', 'Withstand', 'Endure'],
            'Nouns': ['Resilience', 'Persistence', 'Durability', 'Endurance']
        },
        'Time Management': {
            'Synonyms': ['Scheduling efficiency', 'Time allocation', 'Time optimization', 'Deadline management'],
            'Verbs': ['Manage', 'Allocate', 'Optimize', 'Schedule'],
            'Nouns': ['Management', 'Allocation', 'Optimization', 'Scheduling']
        },
        'Mindfulness': {
            'Synonyms': ['Awareness', 'Presence', 'Consciousness', 'Attentiveness'],
            'Verbs': ['Observe', 'Focus', 'Perceive', 'Attend'],
            'Nouns': ['Mindfulness', 'Awareness', 'Consciousness', 'Perception']
        }
    },
    'Social Dynamics': {
        'Communication Skills': {
            'Synonyms': ['Articulation', 'Expression', 'Dialogue proficiency', 'Verbal skills'],
            'Verbs': ['Communicate', 'Express', 'Converse', 'Articulate'],
            'Nouns': ['Communication', 'Expression', 'Dialogue', 'Articulation']
        },
        'Team Collaboration': {
            'Synonyms': ['Teamwork', 'Group cooperation', 'Collaborative efforts', 'Partnership synergy'],
            'Verbs': ['Collaborate', 'Cooperate', 'Partner', 'Synergize'],
            'Nouns': ['Collaboration', 'Cooperation', 'Partnership', 'Synergy']
        },
        'Conflict Resolution': {
            'Synonyms': ['Dispute settlement', 'Conflict mediation', 'Peacemaking', 'Reconciliation'],
            'Verbs': ['Resolve', 'Mediate', 'Reconcile', 'Negotiate'],
            'Nouns': ['Resolution', 'Mediation', 'Reconciliation', 'Negotiation']
        },
        'Interpersonal Influence': {
            'Synonyms': ['Persuasion', 'Charisma', 'Social leverage', 'Influence tactics'],
            'Verbs': ['Influence', 'Persuade', 'Attract', 'Motivate'],
            'Nouns': ['Influence', 'Persuasion', 'Charisma', 'Attraction']
        },
        'Social Networking': {
            'Synonyms': ['Networking skills', 'Community building', 'Social connections', 'Networking abilities'],
            'Verbs': ['Network', 'Connect', 'Engage', 'Build'],
            'Nouns': ['Networking', 'Connection', 'Engagement', 'Community']
        }
    },
    'Innovation and Technology': {
        'Tech Savviness': {
            'Synonyms': ['Technological adeptness', 'Digital fluency', 'Tech proficiency', 'IT competence'],
            'Verbs': ['Navigate', 'Utilize', 'Master', 'Operate'],
            'Nouns': ['Savviness', 'Fluency', 'Proficiency', 'Competence']
        },
        'Innovative Thinking': {
            'Synonyms': ['Creative ideation', 'Inventive mindset', 'Innovative outlook', 'Novel thinking'],
            'Verbs': ['Innovate', 'Invent', 'Imagine', 'Create'],
            'Nouns': ['Innovation', 'Ideation', 'Invention', 'Creativity']
        },
        'Adaptation to Change': {
            'Synonyms': ['Flexibility', 'Change readiness', 'Adaptability', 'Dynamic response'],
            'Verbs': ['Adapt', 'Adjust', 'Acclimate', 'Respond'],
            'Nouns': ['Adaptation', 'Readiness', 'Flexibility', 'Response']
        },
        'Future Forecasting': {
            'Synonyms': ['Predictive analysis', 'Trend projection', 'Futuristic planning', 'Forecasting acumen'],
            'Verbs': ['Forecast', 'Predict', 'Project', 'Plan'],
            'Nouns': ['Forecasting', 'Prediction', 'Projection', 'Planning']
        },
        'AI Implementation': {
            'Synonyms': ['Artificial intelligence deployment', 'AI development', 'Robotics integration', 'Machine learning application'],
            'Verbs': ['Implement', 'Deploy', 'Develop', 'Apply'],
            'Nouns': ['Implementation', 'Deployment', 'Development', 'Application']
        },
        'Cloud Computing': {
            'Synonyms': ['Cloud services', 'Cloud-based technology', 'Online storage solutions', 'Virtual server environments'],
            'Verbs': ['Migrate', 'Store', 'Access', 'Manage'],
            'Nouns': ['Computing', 'Services', 'Solutions', 'Environments']
        }
    },
    'Emotional Intelligence': {
        'Self-awareness': {
            'Synonyms': ['Introspective', 'Self-conscious', 'Aware', 'Reflective'],
            'Verbs': ['Reflect', 'Contemplate', 'Assess', 'Introspect'],
            'Nouns': ['Awareness', 'Consciousness', 'Insight', 'Reflection']
        },
        'Self-regulation': {
            'Synonyms': ['Control', 'Management', 'Discipline', 'Moderation'],
            'Verbs': ['Regulate', 'Control', 'Manage', 'Discipline'],
            'Nouns': ['Regulation', 'Control', 'Management', 'Discipline']
        },
        'Motivation': {
            'Synonyms': ['Drive', 'Determination', 'Passion', 'Aspiration'],
            'Verbs': ['Motivate', 'Inspire', 'Aspire', 'Strive'],
            'Nouns': ['Motivation', 'Inspiration', 'Aspiration', 'Determination']
        },
        'Empathy': {
            'Synonyms': ['Compassionate', 'Sympathetic', 'Understanding', 'Perceptive'],
            'Verbs': ['Empathize', 'Understand', 'Perceive', 'Relate'],
            'Nouns': ['Empathy', 'Compassion', 'Understanding', 'Perception']
        },
        'Social Skills': {
            'Synonyms': ['Communicative', 'Cooperative', 'Adaptable', 'Persuasive'],
            'Verbs': ['Communicate', 'Cooperate', 'Adapt', 'Persuade'],
            'Nouns': ['Communication', 'Cooperation', 'Adaptability', 'Persuasion']
        }
    },
    'Physical Wellness': {
        'Exercise': {
            'Synonyms': ['Workout', 'Training', 'Physical activity', 'Gym'],
            'Verbs': ['Exercise', 'Train', 'Work out', 'Engage'],
            'Nouns': ['Exercise', 'Training', 'Activity', 'Workout']
        },
        'Nutrition': {
            'Synonyms': ['Healthy eating', 'Dietary habits', 'Nutritious', 'Balanced diet'],
            'Verbs': ['Eat', 'Feed', 'Nourish', 'Balance'],
            'Nouns': ['Nutrition', 'Diet', 'Eating', 'Feeding']
        },
        'Rest and Recovery': {
            'Synonyms': ['Relaxation', 'Rejuvenation', 'Restoration', 'Sleep'],
            'Verbs': ['Rest', 'Recover', 'Rejuvenate', 'Relax'],
            'Nouns': ['Rest', 'Recovery', 'Rejuvenation', 'Relaxation']
        },
        'Mental Health': {
            'Synonyms': ['Psychological well-being', 'Mental stability', 'Emotional health', 'Cognitive health'],
            'Verbs': ['Maintain', 'Balance', 'Support', 'Stabilize'],
            'Nouns': ['Mental health', 'Well-being', 'Stability', 'Support']
        },
        'Preventative Care': {
            'Synonyms': ['Health screening', 'Vaccination', 'Regular check-ups', 'Prophylaxis'],
            'Verbs': ['Prevent', 'Screen', 'Vaccinate', 'Check'],
            'Nouns': ['Prevention', 'Screening', 'Vaccination', 'Check-up']
        }
    },
    'Career and Professional Development': {
        'Career Growth': {
            'Synonyms': ['Career advancement', 'Professional development', 'Career progression', 'Professional growth'],
            'Verbs': ['Advance', 'Develop', 'Progress', 'Grow'],
            'Nouns': ['Advancement', 'Development', 'Progression', 'Growth']
        },
        'Skill Enhancement': {
            'Synonyms': ['Skill development', 'Skill training', 'Skill improvement', 'Skill acquisition'],
            'Verbs': ['Enhance', 'Develop', 'Train', 'Acquire'],
            'Nouns': ['Enhancement', 'Development', 'Training', 'Acquisition']
        },
        'Leadership Development': {
            'Synonyms': ['Leadership training', 'Leadership skills', 'Management development', 'Leadership enhancement'],
            'Verbs': ['Develop', 'Train', 'Enhance', 'Lead'],
            'Nouns': ['Development', 'Training', 'Enhancement', 'Leadership']
        },
        'Networking and Connections': {
            'Synonyms': ['Building connections', 'Networking', 'Creating partnerships', 'Expanding network'],
            'Verbs': ['Network', 'Connect', 'Partner', 'Expand'],
            'Nouns': ['Networking', 'Connection', 'Partnership', 'Expansion']
        },
        'Job Satisfaction': {
            'Synonyms': ['Work happiness', 'Job fulfillment', 'Career contentment', 'Professional satisfaction'],
            'Verbs': ['Satisfy', 'Fulfill', 'Content', 'Please'],
            'Nouns': ['Satisfaction', 'Fulfillment', 'Contentment', 'Happiness']
        }
    },
    'Community and Social Engagement': {
        'Volunteering': {
            'Synonyms': ['Community service', 'Charitable work', 'Volunteer work', 'Helping others'],
            'Verbs': ['Volunteer', 'Serve', 'Assist', 'Help'],
            'Nouns': ['Volunteering', 'Service', 'Assistance', 'Help']
        },
        'Civic Participation': {
            'Synonyms': ['Civic engagement', 'Public service', 'Community involvement', 'Civic duty'],
            'Verbs': ['Participate', 'Engage', 'Involve', 'Serve'],
            'Nouns': ['Participation', 'Engagement', 'Involvement', 'Service']
        },
        'Community Building': {
            'Synonyms': ['Community development', 'Neighborhood enhancement', 'Community organization', 'Social cohesion'],
            'Verbs': ['Build', 'Develop', 'Organize', 'Enhance'],
            'Nouns': ['Building', 'Development', 'Organization', 'Enhancement']
        },
        'Social Advocacy': {
            'Synonyms': ['Activism', 'Advocacy', 'Campaigning', 'Promoting change'],
            'Verbs': ['Advocate', 'Campaign', 'Promote', 'Support'],
            'Nouns': ['Advocacy', 'Campaign', 'Promotion', 'Support']
        },
        'Cultural Engagement': {
            'Synonyms': ['Cultural participation', 'Cultural involvement', 'Cultural activities', 'Cultural events'],
            'Verbs': ['Engage', 'Participate', 'Involve', 'Attend'],
            'Nouns': ['Engagement', 'Participation', 'Involvement', 'Attendance']
        }
    },
    'Global Awareness': {
        'Cultural Sensitivity': {
            'Synonyms': ['Culturally aware', 'Culturally sensitive', 'Ethnoculturally empathetic', 'Intercultural understanding'],
            'Verbs': ['Understand', 'Respect', 'Appreciate', 'Acknowledge'],
            'Nouns': ['Awareness', 'Sensitivity', 'Empathy', 'Understanding']
        },
        'Global Citizenship': {
            'Synonyms': ['World-minded', 'Globally aware', 'Internationalist', 'Cross-cultural participant'],
            'Verbs': ['Participate', 'Engage', 'Act', 'Involve'],
            'Nouns': ['Citizenship', 'Participation', 'Engagement', 'Activity']
        },
        'Environmental Stewardship': {
            'Synonyms': ['Eco-friendly', 'Conservationist', 'Green advocate', 'Environmental caretaker'],
            'Verbs': ['Protect', 'Preserve', 'Conserve', 'Maintain'],
            'Nouns': ['Stewardship', 'Protection', 'Conservation', 'Maintenance']
        },
        'Global Economics': {
            'Synonyms': ['Economic awareness', 'Global trade understanding', 'International market insights', 'Economic globalism'],
            'Verbs': ['Understand', 'Analyze', 'Navigate', 'Forecast'],
            'Nouns': ['Awareness', 'Insight', 'Navigation', 'Forecasting']
        },
        'Political Awareness': {
            'Synonyms': ['Politically informed', 'Civic-minded', 'Governmental understanding', 'Policy awareness'],
            'Verbs': ['Understand', 'Discuss', 'Evaluate', 'Influence'],
            'Nouns': ['Awareness', 'Understanding', 'Evaluation', 'Influence']
        }
    },
    'Personal Development': {
        'Self-improvement': {
            'Synonyms': ['Personal growth', 'Self-enhancement', 'Self-betterment', 'Personal advancement'],
            'Verbs': ['Improve', 'Enhance', 'Advance', 'Develop'],
            'Nouns': ['Improvement', 'Enhancement', 'Advancement', 'Development']
        },
        'Mindfulness': {
            'Synonyms': ['Awareness', 'Presence', 'Consciousness', 'Attentiveness'],
            'Verbs': ['Focus', 'Attend', 'Observe', 'Notice'],
            'Nouns': ['Mindfulness', 'Awareness', 'Presence', 'Consciousness']
        },
        'Life Skills': {
            'Synonyms': ['Practical abilities', 'Daily living skills', 'Survival skills', 'Basic competencies'],
            'Verbs': ['Manage', 'Handle', 'Navigate', 'Operate'],
            'Nouns': ['Skills', 'Abilities', 'Competencies', 'Capabilities']
        },
        'Resilience': {
            'Synonyms': ['Toughness', 'Endurance', 'Recoverability', 'Adaptability'],
            'Verbs': ['Recover', 'Withstand', 'Adapt', 'Bounce back'],
            'Nouns': ['Resilience', 'Endurance', 'Adaptability', 'Recovery']
        },
        'Aspiration': {
            'Synonyms': ['Ambition', 'Goal-setting', 'Dreams', 'Hopes'],
            'Verbs': ['Aspire', 'Dream', 'Hope', 'Strive'],
            'Nouns': ['Aspiration', 'Ambition', 'Dream', 'Hope']
        }
    },
    'Health and Wellbeing': { #35
        'Mental Health': {
            'Synonyms': ['Psychological well-being', 'Mental fitness', 'Emotional health', 'Cognitive health'],
            'Verbs': ['Maintain', 'Balance', 'Support', 'Strengthen'],
            'Nouns': ['Health', 'Well-being', 'Stability', 'Support']
        },
        'Physical Health': {
            'Synonyms': ['Physical fitness', 'Bodily health', 'Physical condition', 'Body wellness'],
            'Verbs': ['Exercise', 'Nourish', 'Care for', 'Maintain'],
            'Nouns': ['Fitness', 'Health', 'Condition', 'Wellness']
        },
        'Diet and Nutrition': {
            'Synonyms': ['Healthy eating', 'Nutritional habits', 'Balanced diet', 'Eating well'],
            'Verbs': ['Eat', 'Nourish', 'Balance', 'Plan'],
            'Nouns': ['Diet', 'Nutrition', 'Eating', 'Meal planning']
        },
        'Sleep Habits': {
            'Synonyms': ['Sleep patterns', 'Restful sleep', 'Sleep quality', 'Sleep hygiene'],
            'Verbs': ['Sleep', 'Rest', 'Rejuvenate', 'Regulate'],
            'Nouns': ['Sleep', 'Rest', 'Rejuvenation', 'Regulation']
        },
        'Stress Management': {
            'Synonyms': ['Stress reduction', 'Stress control', 'Coping mechanisms', 'Stress relief'],
            'Verbs': ['Manage', 'Reduce', 'Control', 'Alleviate'],
            'Nouns': ['Management', 'Reduction', 'Control', 'Relief']
        }
    },
    'Professional Growth': {
        'Career Development': {
            'Synonyms': ['Career advancement', 'Professional progress', 'Job growth', 'Workplace development'],
            'Verbs': ['Advance', 'Develop', 'Grow', 'Climb'],
            'Nouns': ['Advancement', 'Development', 'Growth', 'Progression']
        },
        'Leadership Skills': {
            'Synonyms': ['Managerial ability', 'Leadership prowess', 'Guidance skills', 'Command capabilities'],
            'Verbs': ['Lead', 'Manage', 'Guide', 'Command'],
            'Nouns': ['Leadership', 'Management', 'Guidance', 'Command']
        },
        'Professional Networking': {
            'Synonyms': ['Networking', 'Professional connections', 'Business networking', 'Career networking'],
            'Verbs': ['Connect', 'Network', 'Engage', 'Interact'],
            'Nouns': ['Connections', 'Networking', 'Engagement', 'Interaction']
        },
        'Skill Acquisition': {
            'Synonyms': ['Learning new skills', 'Skill development', 'Competence building', 'Capability enhancement'],
            'Verbs': ['Learn', 'Develop', 'Build', 'Enhance'],
            'Nouns': ['Skill', 'Development', 'Competence', 'Capability']
        },
        'Workplace Adaptability': {
            'Synonyms': ['Adaptability at work', 'Flexibility in job roles', 'Adjustability in workplace', 'Work adaptiveness'],
            'Verbs': ['Adapt', 'Flex', 'Adjust', 'Modify'],
            'Nouns': ['Adaptability', 'Flexibility', 'Adjustability', 'Modifiability']
        }
    },
    'Social Dynamics': {
        'Interpersonal Communication': {
            'Synonyms': ['Verbal communication', 'Dialogue skills', 'Conversational abilities', 'Social interaction'],
            'Verbs': ['Communicate', 'Dialogue', 'Converse', 'Interact'],
            'Nouns': ['Communication', 'Dialogue', 'Conversation', 'Interaction']
        },
        'Conflict Resolution': {
            'Synonyms': ['Dispute settlement', 'Conflict management', 'Issue resolution', 'Problem solving'],
            'Verbs': ['Resolve', 'Settle', 'Manage', 'Solve'],
            'Nouns': ['Resolution', 'Settlement', 'Management', 'Solving']
        },
        'Group Dynamics': {
            'Synonyms': ['Team interactions', 'Group behavior', 'Teamwork efficiency', 'Collective performance'],
            'Verbs': ['Collaborate', 'Interact', 'Cooperate', 'Perform'],
            'Nouns': ['Dynamics', 'Interaction', 'Cooperation', 'Performance']
        },
        'Empathy and Compassion': {
            'Synonyms': ['Understanding others', 'Compassionate interactions', 'Empathetic engagement', 'Sympathetic responses'],
            'Verbs': ['Empathize', 'Compassionate', 'Engage', 'Respond'],
            'Nouns': ['Empathy', 'Compassion', 'Engagement', 'Response']
        },
        'Social Influence': {
            'Synonyms': ['Influential capacity', 'Persuasive power', 'Leadership impact', 'Social sway'],
            'Verbs': ['Influence', 'Persuade', 'Lead', 'Sway'],
            'Nouns': ['Influence', 'Persuasion', 'Leadership', 'Sway']
        }
    },
    'Cultural Engagement': { #38
        'Cultural Appreciation': {
            'Synonyms': ['Cultural respect', 'Cultural admiration', 'Cultural value', 'Cultural reverence'],
            'Verbs': ['Appreciate', 'Respect', 'Admire', 'Value'],
            'Nouns': ['Appreciation', 'Respect', 'Admiration', 'Value']
        },
        'Multicultural Interaction': {
            'Synonyms': ['Cross-cultural communication', 'Multicultural exchanges', 'Diverse interactions', 'Intercultural engagement'],
            'Verbs': ['Interact', 'Communicate', 'Exchange', 'Engage'],
            'Nouns': ['Interaction', 'Communication', 'Exchange', 'Engagement']
        },
        'Cultural Adaptation': {
            'Synonyms': ['Cultural adjustment', 'Cultural acclimatization', 'Cultural assimilation', 'Cultural integration'],
            'Verbs': ['Adapt', 'Adjust', 'Acclimatize', 'Assimilate'],
            'Nouns': ['Adaptation', 'Adjustment', 'Acclimatization', 'Assimilation']
        },
        'Cultural Preservation': {
            'Synonyms': ['Cultural conservation', 'Cultural maintenance', 'Heritage preservation', 'Cultural sustainability'],
            'Verbs': ['Preserve', 'Conserve', 'Maintain', 'Sustain'],
            'Nouns': ['Preservation', 'Conservation', 'Maintenance', 'Sustainability']
        },
        'Global Awareness': {
            'Synonyms': ['Worldwide understanding', 'Global consciousness', 'International awareness', 'Worldly knowledge'],
            'Verbs': ['Understand', 'Conscious', 'Aware', 'Know'],
            'Nouns': ['Understanding', 'Consciousness', 'Awareness', 'Knowledge']
        }
    },
    'Environmental Awareness': {
        'Sustainability Practices': {
            'Synonyms': ['Eco-friendly habits', 'Green living', 'Sustainable behaviors', 'Environmental stewardship'],
            'Verbs': ['Sustain', 'Conserve', 'Preserve', 'Protect'],
            'Nouns': ['Sustainability', 'Conservation', 'Preservation', 'Protection']
        },
        'Recycling Initiatives': {
            'Synonyms': ['Waste management', 'Recyclable processing', 'Resource recovery', 'Material reclamation'],
            'Verbs': ['Recycle', 'Reuse', 'Reduce', 'Recover'],
            'Nouns': ['Recycling', 'Reusability', 'Reduction', 'Recovery']
        },
        'Renewable Energy Use': {
            'Synonyms': ['Solar power', 'Wind energy', 'Hydropower', 'Geothermal energy'],
            'Verbs': ['Generate', 'Harness', 'Utilize', 'Implement'],
            'Nouns': ['Generation', 'Harnessing', 'Utilization', 'Implementation']
        },
        'Conservation Efforts': {
            'Synonyms': ['Wildlife protection', 'Habitat preservation', 'Biodiversity conservation', 'Ecosystem management'],
            'Verbs': ['Conserve', 'Preserve', 'Protect', 'Manage'],
            'Nouns': ['Conservation', 'Preservation', 'Protection', 'Management']
        },
        'Environmental Education': {
            'Synonyms': ['Ecological literacy', 'Sustainability training', 'Conservation education', 'Green learning'],
            'Verbs': ['Educate', 'Teach', 'Inform', 'Train'],
            'Nouns': ['Education', 'Teaching', 'Information', 'Training']
        }
    },
    'Health and Wellness': {
        'Physical Fitness': {
            'Synonyms': ['Exercise routine', 'Gym training', 'Aerobic activity', 'Strength conditioning'],
            'Verbs': ['Exercise', 'Train', 'Condition', 'Strengthen'],
            'Nouns': ['Fitness', 'Training', 'Conditioning', 'Strength']
        },
        'Mental Health': {
            'Synonyms': ['Psychological well-being', 'Emotional balance', 'Mental stability', 'Cognitive health'],
            'Verbs': ['Stabilize', 'Balance', 'Support', 'Fortify'],
            'Nouns': ['Stability', 'Balance', 'Support', 'Fortification']
        },
        'Nutritional Awareness': {
            'Synonyms': ['Healthy eating', 'Dietary choices', 'Balanced diet', 'Nutrient intake'],
            'Verbs': ['Eat', 'Choose', 'Balance', 'Intake'],
            'Nouns': ['Eating', 'Choices', 'Diet', 'Intake']
        },
        'Stress Management': {
            'Synonyms': ['Relaxation techniques', 'Stress relief', 'Coping strategies', 'Tension reduction'],
            'Verbs': ['Relax', 'Relieve', 'Cope', 'Reduce'],
            'Nouns': ['Relaxation', 'Relief', 'Coping', 'Reduction']
        },
        'Sleep Hygiene': {
            'Synonyms': ['Sleep quality', 'Rest patterns', 'Bedtime routine', 'Nighttime relaxation'],
            'Verbs': ['Sleep', 'Rest', 'Routinize', 'Relax'],
            'Nouns': ['Sleep', 'Rest', 'Routine', 'Relaxation']
        }
    },
    'Lifelong Learning': {
        'Continuous Education': {
            'Synonyms': ['Ongoing training', 'Permanent education', 'Continuous study', 'Lifelong instruction'],
            'Verbs': ['Learn', 'Train', 'Study', 'Instruct'],
            'Nouns': ['Learning', 'Training', 'Study', 'Instruction']
        },
        'Skill Development': {
            'Synonyms': ['Capability enhancement', 'Skill training', 'Competency growth', 'Expertise building'],
            'Verbs': ['Develop', 'Train', 'Grow', 'Build'],
            'Nouns': ['Development', 'Training', 'Growth', 'Building']
        },
        'Professional Upgrading': {
            'Synonyms': ['Career enhancement', 'Job upskilling', 'Professional development', 'Skill updating'],
            'Verbs': ['Enhance', 'Upskill', 'Develop', 'Update'],
            'Nouns': ['Enhancement', 'Upskilling', 'Development', 'Updating']
        },
        'Knowledge Expansion': {
            'Synonyms': ['Information acquisition', 'Learning broadening', 'Education expansion', 'Intellectual growth'],
            'Verbs': ['Acquire', 'Broaden', 'Expand', 'Grow'],
            'Nouns': ['Acquisition', 'Broadening', 'Expansion', 'Growth']
        },
        'Cultural Education': {
            'Synonyms': ['Cultural literacy', 'Cultural awareness', 'Cross-cultural learning', 'Intercultural education'],
            'Verbs': ['Learn', 'Understand', 'Absorb', 'Educate'],
            'Nouns': ['Learning', 'Understanding', 'Absorption', 'Education']
        }
    },
    'Career Development': {
        'Professional Growth': {
            'Synonyms': ['Career advancement', 'Professional progress', 'Skill enhancement', 'Position elevation'],
            'Verbs': ['Advance', 'Progress', 'Enhance', 'Elevate'],
            'Nouns': ['Advancement', 'Progress', 'Enhancement', 'Elevation']
        },
        'Leadership Training': {
            'Synonyms': ['Management skills', 'Leadership skills', 'Supervisory training', 'Executive development'],
            'Verbs': ['Train', 'Develop', 'Cultivate', 'Enhance'],
            'Nouns': ['Training', 'Development', 'Cultivation', 'Enhancement']
        },
        'Networking': {
            'Synonyms': ['Professional connections', 'Networking opportunities', 'Business networking', 'Career networking'],
            'Verbs': ['Connect', 'Network', 'Interact', 'Engage'],
            'Nouns': ['Connection', 'Networking', 'Interaction', 'Engagement']
        },
        'Mentorship': {
            'Synonyms': ['Guidance', 'Advising', 'Coaching', 'Mentoring'],
            'Verbs': ['Guide', 'Advise', 'Coach', 'Mentor'],
            'Nouns': ['Guidance', 'Advice', 'Coaching', 'Mentorship']
        },
        'Career Satisfaction': {
            'Synonyms': ['Job fulfillment', 'Work contentment', 'Professional happiness', 'Career enjoyment'],
            'Verbs': ['Fulfill', 'Content', 'Satisfy', 'Enjoy'],
            'Nouns': ['Fulfillment', 'Contentment', 'Satisfaction', 'Enjoyment']
        }
    },
    'Personal Relationships': {
        'Social Support': {
            'Synonyms': ['Support network', 'Community support', 'Social aid', 'Help from friends'],
            'Verbs': ['Support', 'Aid', 'Assist', 'Help'],
            'Nouns': ['Support', 'Aid', 'Assistance', 'Help']
        },
        'Friendship Development': {
            'Synonyms': ['Building friendships', 'Fostering connections', 'Developing bonds', 'Strengthening relationships'],
            'Verbs': ['Build', 'Foster', 'Develop', 'Strengthen'],
            'Nouns': ['Building', 'Fostering', 'Development', 'Strengthening']
        },
        'Communication Skills': {
            'Synonyms': ['Verbal communication', 'Effective speaking', 'Listening skills', 'Expressive communication'],
            'Verbs': ['Communicate', 'Speak', 'Listen', 'Express'],
            'Nouns': ['Communication', 'Speaking', 'Listening', 'Expression']
        },
        'Conflict Resolution': {
            'Synonyms': ['Resolving disputes', 'Mediating conflicts', 'Settling disagreements', 'Negotiating solutions'],
            'Verbs': ['Resolve', 'Mediate', 'Settle', 'Negotiate'],
            'Nouns': ['Resolution', 'Mediation', 'Settlement', 'Negotiation']
        },
        'Emotional Intimacy': {
            'Synonyms': ['Close bonds', 'Deep connections', 'Emotional closeness', 'Personal intimacy'],
            'Verbs': ['Bond', 'Connect', 'Close', 'Intimate'],
            'Nouns': ['Bonding', 'Connection', 'Closeness', 'Intimacy']
        }
    },
    'Civic Engagement': {
        'Community Service': {
            'Synonyms': ['Volunteering', 'Community work', 'Social service', 'Civic duty'],
            'Verbs': ['Volunteer', 'Serve', 'Assist', 'Participate'],
            'Nouns': ['Volunteering', 'Service', 'Assistance', 'Participation']
        },
        'Political Participation': {
            'Synonyms': ['Voting', 'Political activism', 'Civic participation', 'Electoral engagement'],
            'Verbs': ['Vote', 'Advocate', 'Participate', 'Engage'],
            'Nouns': ['Voting', 'Advocacy', 'Participation', 'Engagement']
        },
        'Environmental Advocacy': {
            'Synonyms': ['Conservation efforts', 'Eco-activism', 'Green advocacy', 'Environmental campaigning'],
            'Verbs': ['Advocate', 'Campaign', 'Protect', 'Preserve'],
            'Nouns': ['Advocacy', 'Campaigning', 'Protection', 'Preservation']
        },
        'Community Organizing': {
            'Synonyms': ['Building coalitions', 'Grassroots organizing', 'Local leadership', 'Community coordination'],
            'Verbs': ['Organize', 'Lead', 'Coordinate', 'Mobilize'],
            'Nouns': ['Organizing', 'Leadership', 'Coordination', 'Mobilization']
        },
        'Social Justice': {
            'Synonyms': ['Equality advocacy', 'Rights activism', 'Social reform', 'Justice initiatives'],
            'Verbs': ['Advocate', 'Reform', 'Campaign', 'Act'],
            'Nouns': ['Advocacy', 'Reform', 'Campaigning', 'Action']
        }
    }
}

#Create a list to store the dataset
data = []
for factor, attributes in pct_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
pct_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/pct.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="PCT Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "PCT")
    mlflow.log_param("Total Rows", len(pct_df))
    mlflow.log_param("Total Factors", len(pct_dataset))
    mlflow.log_param("Data Schema", str(pct_df.columns.tolist()))
    
    # Save dataset to CSV
    pct_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ PCT dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(pct_df.head())
    print("\nDataset shape:", pct_df.shape)
    print("\nNumber of unique Factors:", pct_df['Factor'].nunique())
    print("Unique Factors:", pct_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# 2025/03/17 18:16:22 INFO mlflow.tracking.fluent: Experiment with name 'PCT' does not exist. Creating a new experiment.
# ✅ PCT dataset created and saved to ../Datasets/pct.csv
# First 5 rows of the dataset:
#                   Factor      Adjective        Synonym        Verb  \
# 0  Cognitive Flexibility  Understanding  Comprehending  Comprehend
# 1  Cognitive Flexibility  Understanding       Grasping       Grasp
# 2  Cognitive Flexibility  Understanding     Perceiving    Perceive
# 3  Cognitive Flexibility  Understanding   Apprehending   Apprehend
# 4  Cognitive Flexibility  Understanding    Recognizing   Recognize
#
#             Noun
# 0  Comprehension
# 1          Grasp
# 2     Perception
# 3   Apprehension
# 4    Recognition
#
# Dataset shape: (899, 5)
#
# Number of unique Factors: 41
# Unique Factors: ['Cognitive Flexibility' 'Analytical Reasoning' 'Innovativeness'
#  'Emotional Sensitivity' 'Assertiveness' 'Intuition' 'Perseverance'
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="pct_page_2"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/25/runs/da4285106da1485fbd336bbebb43de3c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/25

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="pct_page_2"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018421143293380737, -0.007218753919005394, 0.003606205340474844, -0.05419774353504181, -0.022721948102116585, 0.036969155073165894, 0.02902725711464882, 0.023901814594864845, 0.011240449734032154, -0.020641323179006577]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/25/runs/7439069ed7ce4430a341ea413fe7695a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/25

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create PCT Embeddings** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved pct dataset from a CSV file
dataset_path = '../Datasets/pct.csv'
try:
    pct_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'pct_df' is empty before processing
        if pct_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", pct_df.shape[0])
            print(f"📊 Processing {pct_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        pct_df['Embedding'] = pct_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/pct_embeddings.csv'
        pct_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = pct_df.shape[0]
        num_columns = pct_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in pct_df.columns and not pct_df['Embedding'].empty:
            embedding_length = len(pct_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(pct_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/pct.csv
# ⏳ Embedding generation started at: 2025-03-17 18:16:23.837323
# 📊 Processing 899 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-17 18:22:43.546688 (Duration: 0:06:19.709365)
# 💾 Embeddings saved to: ../Embeddings/pct_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#                   Factor      Adjective        Synonym        Verb  \
# 0  Cognitive Flexibility  Understanding  Comprehending  Comprehend
# 1  Cognitive Flexibility  Understanding       Grasping       Grasp
# 2  Cognitive Flexibility  Understanding     Perceiving    Perceive
# 3  Cognitive Flexibility  Understanding   Apprehending   Apprehend
# 4  Cognitive Flexibility  Understanding    Recognizing   Recognize
#
#             Noun                                          Embedding
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/pct_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/pct_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "pct_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/pct_embeddings.csv
# 💾 Label encoder saved to: ../Models/pct_label_encoder.pkl
#
# First 5 rows with encoded labels:
#                   Factor  Factor_Encoded
# 0  Cognitive Flexibility               6
# 1  Cognitive Flexibility               6
# 2  Cognitive Flexibility               6
# 3  Cognitive Flexibility               6
# 4  Cognitive Flexibility               6
#
# Mapping of original labels to encoded labels:
# Analytical Reasoning: 0
# Assertiveness: 1
# Career Development: 2
# Career and Professional Development: 3
# Civic Engagement: 4
# Cognitive: 5
# Cognitive Flexibility: 6
# Community and Social Engagement: 7
# Cultural Awareness: 8
# Cultural Engagement: 9
# Digital Transformation: 10
# Emotional: 11
# Emotional Intelligence: 12
# Emotional Sensitivity: 13
# Environmental Advocacy: 14
# Environmental Awareness: 15
# Environmental Conservation: 16
# Global Awareness: 17
# Harmony: 18
# Health and Wellbeing: 19
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/pct_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/pct_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="pct Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "pct_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "pct_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "pct_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/pct_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/pct_embeddings.csv
# ✅ Label encoder loaded from: ../Models/pct_label_encoder.pkl
# ⏳ Model training started at: 2025-03-17 18:22:50.008426
# ✅ Model training finished at: 2025-03-17 18:22:53.805973 (Duration: 0:00:03.797547)
# 📊 Classification report saved to: pct_classification_report.csv
# 📊 Confusion matrix saved to: pct_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: pct_confusion_matrix.png
# 💾 Trained model saved to: ../Models/pct_rf_model.pkl
# ✅ Model training complete. Accuracy: 0.9555555555555556
#
# Classification Report:
#                                       precision    recall  f1-score   support
#
#                Analytical Reasoning       0.83      1.00      0.91         5
#                       Assertiveness       1.00      1.00      1.00         5
#                  Career Development       0.60      0.75      0.67         4
# Career and Professional Development       0.75      0.75      0.75         4
# ...

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/pct_embeddings.csv'
label_encoder_path = "../Models/pct_label_encoder.pkl"
model_path = "../Models/pct_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate PCT Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate PCT Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "pct_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "pct_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "pct_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ PCT Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/pct_embeddings.csv
# ✅ Label encoder loaded from: ../Models/pct_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/pct_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 0.9556
# 📊 Classification report saved to: pct_evaluation_classification_report.csv
#
# Classification Report:
#                                       precision    recall  f1-score   support
#
#                Analytical Reasoning       0.83      1.00      0.91         5
#                       Assertiveness       1.00      1.00      1.00         5
#                  Career Development       0.60      0.75      0.67         4
# Career and Professional Development       0.75      0.75      0.75         4
#                    Civic Engagement       1.00      1.00      1.00         4
#                           Cognitive       1.00      0.80      0.89         5
#               Cognitive Flexibility       1.00      1.00      1.00         5
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/pct_label_encoder.pkl"
model_path = "../Models/pct_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/pct_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/pct_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Social Dynamics
# Predicted Factor for 'I prefer staying home with a good book....': Personal Relationships
# Predicted Factor for 'I often feel anxious and worried....': Motivational
# Predicted Factor for 'I am generally calm and relaxed....': Health and Wellbeing
# Predicted Factor for 'I enjoy taking risks and trying new things....': Innovativeness
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/25/runs/1cf001b7c2024cc3a992b417aa25c6a1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/25
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/pct_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="PCT Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/pct_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "pct_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/pct_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of PCT Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/pct_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of PCT Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/17 18:23:11 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Intuition
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Emotional
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Moral
# Predicted Factor for 'Organized Meticulous Plan Planner': Time Management
# Predicted Factor for 'Moody Anxious Worry Worrier': Innovativeness
# 🏃 View run PCT Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/25/runs/978f8acb2bee487a9f0a7c0c3618f354
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/25

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/pct_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/pct_label_encoder.pkl"
        model_path = "../Models/pct_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of PCT Embeddings")

            # Save and log the plot
            pca_plot_path = "pct_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "pct_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/pct_embeddings.csv
#
# DataFrame with Embeddings:
#                   Factor      Adjective        Synonym        Verb  \
# 0  Cognitive Flexibility  Understanding  Comprehending  Comprehend
# 1  Cognitive Flexibility  Understanding       Grasping       Grasp
# 2  Cognitive Flexibility  Understanding     Perceiving    Perceive
# 3  Cognitive Flexibility  Understanding   Apprehending   Apprehend
# 4  Cognitive Flexibility  Understanding    Recognizing   Recognize
#
#             Noun                                          Embedding
# 0  Comprehension  [0.03454020246863365, 0.014335734769701958, -0...
# 1          Grasp  [0.020802436396479607, 0.026854055002331734, -...
# 2     Perception  [0.022630946710705757, -0.014921082183718681, ...
# 3   Apprehension  [0.012853707186877728, 0.0021720549557358027, ...
# 4    Recognition  [0.022853197529911995, -0.0030588177032768726,...
#
# Shape of DataFrame:
# (899, 6)
#
# ...

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [0.83333333 0.78333333 0.73888889 0.72777778 0.73743017]
# Mean cross-validation score: 0.7641527001862197

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="pct_page_3"></a>
#
# [Back to Top](#pct_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/pct_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_pct.pkl')
clf = joblib.load('../Models/pct_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Moral
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Health-related
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Cognitive
# Predicted Factor for 'Organized Meticulous Plan Planner': Time Management
# Predicted Factor for 'Moody Anxious Worry Worrier': Innovativeness
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Emotional

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Cognitive

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Mental Health

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Motivational

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Emotional

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Emotional

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="PCT_page_4"></a>
#
#
# [Back to Top](#PCT_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("PCT")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/25/runs/619566ca94bf4630a7d9bf45bc1b59c6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/25

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create PCT Schema in Neo4j** <a class="anchor" id="PCT_page_4"></a>
#
#
# [Back to Top](#PCT_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("PCT")

# Load the dataset
dataset_path = "../Embeddings/pct_embeddings.csv"
pct_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in pct_df.columns:
    pct_df['Embedding'] = pct_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the PCT schema in Neo4j
def create_pct_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with PCT labels
        graph.run("MERGE (f:PCT_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:PCT_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:PCT_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:PCT_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:PCT_Noun {name: $noun})", noun=noun)
        
        # Create relationships with PCT namespacing
        graph.run("""
            MATCH (f:PCT_Factor {name: $factor}), (a:PCT_Adjective {name: $adjective})
            MERGE (f)-[:PCT_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:PCT_Adjective {name: $adjective}), (s:PCT_Synonym {name: $synonym})
            MERGE (a)-[:PCT_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:PCT_Adjective {name: $adjective}), (v:PCT_Verb {name: $verb})
            MERGE (a)-[:PCT_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:PCT_Adjective {name: $adjective}), (n:PCT_Noun {name: $noun})
            MERGE (a)-[:PCT_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:PCT_Factor {name: $factor}), (a:PCT_Adjective {name: $adjective})
                MERGE (e:PCT_Embedding {value: $embedding})
                MERGE (f)-[:PCT_HAS_EMBEDDING]->(e)
                MERGE (a)-[:PCT_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create PCT Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create PCT Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the PCT schema
        create_pct_schema(graph, pct_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", pct_df.shape[0])
        mlflow.log_param("Number of Columns", pct_df.shape[1])
        
        # Print the DataFrame
        print(pct_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#                   Factor      Adjective        Synonym        Verb  \
# 0  Cognitive Flexibility  Understanding  Comprehending  Comprehend
# 1  Cognitive Flexibility  Understanding       Grasping       Grasp
# 2  Cognitive Flexibility  Understanding     Perceiving    Perceive
# 3  Cognitive Flexibility  Understanding   Apprehending   Apprehend
# 4  Cognitive Flexibility  Understanding    Recognizing   Recognize
#
#             Noun                                          Embedding
# 0  Comprehension  [0.03454020246863365, 0.014335734769701958, -0...
# 1          Grasp  [0.020802436396479607, 0.026854055002331734, -...
# 2     Perception  [0.022630946710705757, -0.014921082183718681, ...
# 3   Apprehension  [0.012853707186877728, 0.0021720549557358027, ...
# 4    Recognition  [0.022853197529911995, -0.0030588177032768726,...
# 🏃 View run Create PCT Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/25/runs/3e55e0d88893447093e960500b192360
# ...

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:PCT_Factor OR n:PCT_Adjective OR n:PCT_Synonym OR n:PCT_Verb OR n:PCT_Noun)
# AND NOT m:PCT_Embedding
# RETURN n, r, m
# ```
