# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Cognitive-Experiential Self-Theory Model (FSLS)<a class="anchor" id="PTMD_page_17"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# The **Cognitive-Experiential Model (CEM)**, developed by renowned psychologist Seymour Epstein, offers a fascinating perspective on human cognition, personality, and decision-making. This model, presented in Epstein's influential book "Cognitive-Experiential Theory: An Integrative Theory of Personality," published in 1994, delves into the intricate interplay between two distinct systems of information processing within the human mind: the rational system and the experiential system.
#
# **The Rational System:**
# The rational system, as described in the CEM, represents a mode of thinking characterized by logical, analytical, and deliberate thought processes. It involves careful consideration, systematic analysis, and the use of explicit rules and reasoning. This system is associated with conscious awareness and cognitive control. When we engage the rational system, we think critically, evaluate evidence, and make decisions based on well-reasoned judgments.
#
# **The Experiential System:**
# In contrast, the experiential system taps into intuitive, emotional, and automatic thought processes. This system operates rapidly, often subconsciously, drawing on emotional responses, gut feelings, and immediate, unfiltered reactions to situations. It is associated with vivid experiences and has a significant impact on our emotional responses and behavior. The experiential system can be impulsive and driven by our innate instincts and emotional reactions.
#
# **Integration of Systems:**
# What makes CEM particularly insightful is its recognition that these two systems do not operate independently but interact dynamically. Depending on the context and individual differences, one system may dominate over the other. Sometimes, we rely on our rational system to carefully analyze complex problems, while at other times, our experiential system might guide us through quick, emotionally charged decisions. The balance between these systems can influence how we perceive the world, make choices, and even shape our personality.
#
# **Applications and Impact:**
# CEM has had a substantial impact on various fields, including psychology, decision-making, and personality research. It has provided a framework for understanding why people sometimes make seemingly irrational decisions, driven by emotions or instincts, even when a rational analysis might suggest otherwise. This model has also contributed to our understanding of individual differences in cognitive styles and the role of intuition in decision-making.
#
# Researchers and practitioners have found CEM valuable for exploring topics like consumer behavior, moral decision-making, and emotional regulation. By recognizing the interplay between the rational and experiential systems, professionals in fields ranging from psychology to marketing have gained insights into human behavior and decision processes.
#
# Seymour Epstein's Cognitive-Experiential Model sheds light on the intricate dance between rational and experiential thinking within the human mind. Its exploration of how these systems interact and influence our thoughts, emotions, and actions has enriched our understanding of human behavior and decision-making, making it a significant and enduring contribution to the field of psychology and beyond.
#
# Timeline and reference table for the Cognitive-Experiential Self-Theory (FSLS), sometimes referred to as the Cognitive-Experiential Model (CEM), involves outlining the key developments of this psychological theory. Developed by Seymour Epstein, FSLS proposes that individuals operate based on two systems: a rational system, which is analytical and logic-based, and an experiential system, which is intuitive and emotion-based. Here's a hypothetical timeline and reference table:
#
# Here's the conversion of your HTML table into markdown format for the "Cognitive-Experiential Self-Theory (FSLS) Timeline and Reference Table":
#
# ### Cognitive-Experiential Self-Theory (FSLS) Timeline and Reference Table
#
# | Year         | Milestone                                       | Contributor(s)      | Original Work Reference                                                                                     | Key Contributions                                               | Additional Information                                              |
# |--------------|-------------------------------------------------|---------------------|-------------------------------------------------------------------------------------------------------------|-----------------------------------------------------------------|----------------------------------------------------------------------|
# | 1970s-1980s  | Early Development of FSLS Concepts.             | Seymour Epstein     | Various academic papers and publications.                                                                   | Initial exploration of dual-process theories, laying the groundwork for FSLS. | Focus on understanding how people process information using both rational and experiential systems. |
# | 1990         | Formal Introduction of FSLS.                    | Seymour Epstein     | Epstein, S. (1990). "Cognitive-Experiential Self-Theory of Personality". In T. Pervin (Ed.), Handbook of personality: Theory and research. | Introduction of FSLS as a comprehensive theory combining cognitive and experiential aspects of processing. | Provided a framework for understanding the balance between emotion and logic in human psychology. |
# | 1994         | Further Elaboration on FSLS.                    | Seymour Epstein     | Epstein, S. (1994). "Integration of the cognitive and the psychodynamic unconscious". American Psychologist. | Discussed the integration of cognitive processes and unconscious psychodynamic processes. | Emphasized the interaction between the rational and the experiential systems in personal and social behavior. |
# | 2003         | Development of the Constructive Thinking Inventory (CTI). | Seymour Epstein     | Epstein, S. (2003). "Constructive Thinking: The Key to Emotional Intelligence". Praeger Publishers.          | Introduction of the CTI to assess individual differences in constructive thinking, a concept central to FSLS. | Highlighted the practical applications of FSLS in assessing and developing emotional intelligence. |
# | 2010s        | Application of FSLS in Various Fields.          | Various Researchers | Multiple studies and publications in psychological journals.                                                 | Application of FSLS principles in clinical psychology, decision-making, and personality research. | Expanded the influence of FSLS in understanding complex psychological phenomena and behavioral patterns. |
# | Present      | Ongoing Research and Developments in FSLS.      | Contemporary Scholars| Recent academic publications and studies.                                                                   | Further exploration of the dual-systems approach in cognitive and emotional processing. | Reflects the continuous evolution of FSLS and its relevance in modern psychological research and practice. |
#
# This table provides a comprehensive overview of the key developments in the Cognitive-Experiential Self-Theory (FSLS), highlighting the pivotal contributions of Seymour Epstein and subsequent researchers. Each row represents a significant milestone in the evolution of FSLS, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# FSLS has been influential in advancing the understanding of how rational and experiential systems interact to shape human cognition, emotion, and behavior. Its impact is evident across various psychological disciplines, providing a nuanced perspective on the complexity of human thought and behavior.
#
# | #   | Author                                                                         | Year | Title                                                                                                                    | Journal                                        | Volume  | Pages        | DOI                                                        |
# |-----|---------------------------------------------------------------------------------|------|--------------------------------------------------------------------------------------------------------------------------|------------------------------------------------|---------|--------------|------------------------------------------------------------|
# | 1   | S. Epstein                                                                      | 2003 | Cognitive-Experiential Self-Theory of Personality                                                                        | -                                              | -       | -            | [10.1002/0471264385.WEI0507](https://doi.org/10.1002/0471264385.WEI0507) |
# | 2   | P. Norris, S. Epstein                                                           | 2011 | An experiential thinking style: its facets and relations with objective and subjective criterion measures.                | Journal of personality                        | 79 5    | 1043-79      | [10.1111/j.1467-6494.2011.00718.x](https://doi.org/10.1111/j.1467-6494.2011.00718.x) |
# | 3   | T. Novak, D. Hoffman                                                            | 2007 | The Fit of Thinking Style and Situation: New Measures of Situation-Specific Experiential and Rational Cognition          | Behavioral & Experimental Economics           | null    | null         | [10.2139/ssrn.770365](https://doi.org/10.2139/ssrn.770365) |
# | 4   | S. Epstein, Rosemary Pacini                                                     | 2001 | The Influence of Visualization on Intuitive and Analytical Information Processing                                         | Imagination, Cognition and Personality        | 20      | 195 - 216    | [10.2190/G4VG-AKQP-2Q91-JQHP](https://doi.org/10.2190/G4VG-AKQP-2Q91-JQHP) |
# | 5   | S. Epstein, Rosemary Pacini, Veronika Denes-Raj, Harriet Heier                  | 1996 | Individual Differences in Intuitive-Experiential and Analytical-Rational Thinking Styles                                  | -                                              | -       | -            | [10.1037/0022-3514.71.2.390](https://doi.org/10.1037/0022-3514.71.2.390) |
# | 6   | L. King, Chad M. Burton, Joshua A. Hicks, S. Drigotas                            | 2007 | Shifting the Balance to the Experiential System : The Potential Role of Positive Affect                                  | -                                              | -       | -            | -                                                          |
# | 7   | S. Epstein                                                                      | 1994 | Integration of the cognitive and the psychodynamic unconscious.                                                         | The American psychologist                     | 49 8    | 709-24       | [10.1037/0003-066X.49.8.709](https://doi.org/10.1037/0003-066X.49.8.709) |
# | 8   | Rosemary Pacini, S. Epstein                                                      | 1999 | The interaction of three facets of concrete thinking in a game of chance                                                | Thinking & Reasoning                          | 5       | 303-325      | [10.1080/135467899393959](https://doi.org/10.1080/135467899393959) |
# | 9   | S. Epstein, Rosemary Pacini, Veronika Denes-Raj, Harriet Heier                  | 1996 | Individual differences in intuitive-experiential and analytical-rational thinking styles.                               | Journal of personality and social psychology  | 71 2    | 390-405      | [10.1037//0022-3514.71.2.390](https://doi.org/10.1037//0022-3514.71.2.390) |
# | 10  | C. Witteman, J. H. Bercken, L. Claes, A. Godoy                                   | 2009 | Assessing Rational and Intuitive Thinking Styles                                                                         | European Journal of Psychological Assessment   | 25      | 39-47        | [10.1027/1015-5759.25.1.39](https://doi.org/10.1027/1015-5759.25.1.39) |
# | 11  | S. Shiloh, Efrat Salton, Dana Sharabi                                            | 2002 | Individual differences in rational and intuitive thinking styles as predictors of heuristic responses and framing effects | Personality and Individual Differences        | 32      | 415-429      | [10.1016/S0191-8869(01)00034-4](https://doi.org/10.1016/S0191-8869(01)00034-4) |
# | 12  | S. Epstein                                                                      | 1998 | Personal Control from the Perspective of Cognitive-Experiential Self-Theory                                             | -                                              | -       | -            | [10.1007/978-1-4757-2901-6_1](https://doi.org/10.1007/978-1-4757-2901-6_1) |
# | 13  | S. Sloman                                                                       | 1996 | The empirical case for two systems of reasoning.                                                                        | Psychological Bulletin                        | 119     | 3-22         | [10.1037/0033-2909.119.1.3](https://doi.org/10.1037/0033-2909.119.1.3) |
# | 14  | S. Epstein                                                                      | 1998 | Cognitive-experiential self-theory.                                                                                    | -                                              | -       | -            | [10.1007/978-1-4419-8580-4_9](https://doi.org/10.1007/978-1-4419-8580-4_9) |
# | 15  | R. Hogarth                                                                      | 2002 | Deciding Analytically or Trusting your Intuition? The Advantages and Disadvantages of Analytic and Intuitive Thought    | -                                              | -       | -            | [10.2139/SSRN.394920](https://doi.org/10.2139/SSRN.394920) |
# | 16  | Joel D. Lieberman                                                               | 2002 | Head Over the Heart or Heart Over the Head? Cognitive Experiential Self‐Theory and Extralegal Heuristics in Juror Decision Making1 | Journal of Applied Social Psychology          | 32      | 2526-2553    | [10.1111/J.1559-1816.2002.TB02755.X](https://doi.org/10.1111/J.1559-1816.2002.TB02755.X) |
# | 17  | Veronika Denes-Raj, Seymour Epstein                                             | 1994 | Conflict between intuitive and rational processing: when people behave against their better judgment.                    | Journal of personality and social psychology  | 66 5    | 819-29       | [10.1037//0022-3514.66.5.819](https://doi.org/10.1037//0022-3514.66.5.819) |
# | 18  | Leila Setork                                                                    | 2015 | Cognitive and Physiological Processes Underlying                                                                         | -                                              | -       | -            | -                                                          |
# | 19  | A. Demirtaş, M. Güven                                                           | 2017 | The effect of cognitive-experiential theory based psycho-educational program on constructive thinking                    | Cogent Psychology                             | 4       | null         | [10.1080/23311908.2017.1416883](https://doi.org/10.1080/23311908.2017.1416883) |
# | 20  | Rosemary Pacini, Francisco Muir, S. Epstein                                      | 1998 | Depressive realism from the perspective of cognitive-experiential self-theory.                                           | Journal of personality and social psychology  | 74 4    | 1056-68      | [10.1037/0022-3514.74.4.1056](https://doi.org/10.1037/0022-3514.74.4.1056) |
# | 21  | K. Stanovich, R. F. West                                                        | 2002 | Heuristics and Biases: Individual Differences in Reasoning: Implications for the Rationality Debate?                      | -                                              | -       | -            | [10.1017/CBO9780511808098.026](https://doi.org/10.1017/CBO9780511808098.026) |
# | 22  | D. Kahneman, S. Frederick                                                       | 2002 | Representativeness revisited: Attribute substitution in intuitive judgment.                                              | Columbia Business School Research Paper Series | null    | null         | [10.2139/ssrn.1304758](https://doi.org/10.2139/ssrn.1304758) |
# | 23  | R. Hogarth                                                                      | 2010 | Intuition: A Challenge for Psychological Research on Decision Making                                                     | Psychological Inquiry                          | 21      | 338 - 353    | [10.1080/1047840X.2010.520260](https://doi.org/10.1080/1047840X.2010.520260) |
# | 24  | E. Scheuer, S. Epstein                                                          | 1997 | Constructive thinking, reactions to a laboratory stressor, and symptoms in everyday life                                  | Anxiety Stress and Coping                      | 10      | 269-303      | [10.1080/10615809708249305](https://doi.org/10.1080/10615809708249305) |
# | 25  | Erik Dane, M. Pratt                                                             | 2007 | Exploring Intuition and its Role in Managerial Decision Making                                                           | Academy of Management Review                  | 32      | 33-54        | [10.5465/AMR.2007.23463682](https://doi.org/10.5465/AMR.2007.23463682) |
# | 26  | S. Epstein, Sean Donovan, Veronika Denes-Raj                                     | 1999 | The Missing Link in the Paradox of the Linda Conjunction Problem: Beyond Knowing and Thinking of the Conjunction Rule, the Intrinsic Appeal of Heuristic Processing | Personality and Social Psychology Bulletin     | 25      | 204 - 214    | [10.1177/0146167299025002006](https://doi.org/10.1177/0146167299025002006) |
# | 27  | J. Rudski, Jennifer Volksdorf                                                   | 2002 | Pictorial versus Textual Information and the Ratio-Bias Effect                                                            | Perceptual and Motor Skills                    | 95      | 547 - 554    | [10.2466/pms.2002.95.2.547](https://doi.org/10.2466/pms.2002.95.2.547) |
# | 28  | Yong Lu                                                                         | 2015 | Is experiential-intuitive cognitive style more inclined to err on conjunction fallacy than analytical-rational cognitive style? | Frontiers in Psychology                        | 6       | null         | [10.3389/fpsyg.2015.00085](https://doi.org/10.3389/fpsyg.2015.00085) |
# | 29  | R. Sladek, M. Bond, P. Phillips                                                 | 2010 | Age and gender differences in preferences for rational and experiential thinking                                          | Personality and Individual Differences         | 49      | 907-911      | [10.1016/J.PAID.2010.07.028](https://doi.org/10.1016/J.PAID.2010.07.028) |
# | 30  | L. Kirkpatrick, S. Epstein                                                      | 1992 | Cognitive-experiential self-theory and subjective probability: further evidence for two conceptual systems.               | Journal of personality and social psychology   | 63 4    | 534-44       | [10.1037//0022-3514.63.4.534](https://doi.org/10.1037//0022-3514.63.4.534) |
# | 31  | Jonathan Evans                                                                  | 2003 | In two minds: dual-process accounts of reasoning                                                                         | Trends in Cognitive Sciences                   | 7       | 454-459      | [10.1016/j.tics.2003.08.012](https://doi.org/10.1016/j.tics.2003.08.012) |
# | 32  | Jonathan Evans                                                                  | 2008 | Dual-processing accounts of reasoning, judgment, and social cognition.                                                   | Annual review of psychology                    | 59      | 255-78       | [10.1146/ANNUREV.PSYCH.59.103006.093629](https://doi.org/10.1146/ANNUREV.PSYCH.59.103006.093629) |
# | 33  | J. Worrall                                                                      | 2013 | The Police Sixth Sense: An Observation in Search of a Theory                                                              | American Journal of Criminal Justice           | 38      | 306-322      | [10.1007/S12103-012-9176-0](https://doi.org/10.1007/S12103-012-9176-0) |
# | 34  | L. King, Chad M. Burton, Joshua A. Hicks, S. Drigotas                            | 2007 | Ghosts, UFOs, and magic: positive affect and the experiential system.                                                     | Journal of personality and social psychology   | 92 5    | 905-19       | [10.1037/0022-3514.92.5.905](https://doi.org/10.1037/0022-3514.92.5.905) |
# | 35  | F. Björklund, M. Bäckström                                                      | 2008 | Individual differences in processing styles: validity of the Rational-Experiential Inventory.                              | Scandinavian journal of psychology              | 49 5    | 439-46       | [10.1111/j.1467-9450.2008.00652.x](https://doi.org/10.1111/j.1467-9450.2008.00652.x) |
# | 36  | Thomas Gilovich, D. Griffin, D. Kahneman                                        | 2002 | Heuristics and Biases: The Psychology of Intuitive Judgment                                                              | -                                              | -       | -            | -                                                          |
# | 37  | S. Epstein                                                                      | 2010 | Demystifying Intuition: What It Is, What It Does, and How It Does It                                                     | Psychological Inquiry                          | 21      | 295 - 312    | [10.1080/1047840X.2010.523875](https://doi.org/10.1080/1047840X.2010.523875) |
# | 38  | Paul D. Windschitl, E. Weber                                                    | 1999 | The Interpretation of 'Likely' Depends on the Context, But 70% is 70% - Right? The Influence of Associative Processes on Perceived Certainty | Columbia Business School Research Paper Series | null    | null         | [10.2139/ssrn.1304758](https://doi.org/10.2139/ssrn.1304758) |
#
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %% [markdown]
# ##  Steps for FSLS Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (FSLS).
#     * **Actions:**
#         * Define the FSLS dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the FSLS dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the FSLS dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our FSLS Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up FSLS experiment
experiment_name = "FSLS"
mlflow.set_experiment(experiment_name)

# FSLS dataset 
fsls_dataset = {
    'Active': {
        'Engaged': {
            'Synonyms': ['Involved', 'Participating', 'Active', 'Busy', 'Committed', 'Dedicated'],
            'Verbs': ['Engage', 'Participate', 'Act', 'Busy oneself', 'Commit', 'Dedicate'],
            'Nouns': ['Engagement', 'Participation', 'Activity', 'Busyness', 'Commitment', 'Dedication']
        },
        'Experimental': {
            'Synonyms': ['Testing', 'Investigative', 'Trial', 'Exploratory', 'Pioneering', 'Innovative'],
            'Verbs': ['Experiment', 'Investigate', 'Try', 'Explore', 'Pioneer', 'Innovate'],
            'Nouns': ['Experimentation', 'Investigation', 'Trial', 'Exploration', 'Pioneering', 'Innovation']
        },
        'Practical': {
            'Synonyms': ['Functional', 'Useful', 'Applicable', 'Pragmatic', 'Realistic', 'Efficient'],
            'Verbs': ['Practice', 'Utilize', 'Apply', 'Execute', 'Adapt', 'Operate'],
            'Nouns': ['Practicality', 'Utility', 'Application', 'Pragmatism', 'Realism', 'Efficiency']
        },
        'Collaborative': {
            'Synonyms': ['Cooperative', 'Team-oriented', 'Joined', 'Shared', 'Unified', 'Collective'],
            'Verbs': ['Collaborate', 'Cooperate', 'Join forces', 'Share', 'Unite', 'Support'],
            'Nouns': ['Collaboration', 'Cooperation', 'Unity', 'Sharing', 'Alliance', 'Teamwork']
        },
        'Energetic': {
            'Synonyms': ['Dynamic', 'Lively', 'Exuberant', 'Vigorous', 'Active', 'Enthusiastic'],
            'Verbs': ['Energize', 'Invigorate', 'Stimulate', 'Activate', 'Motivate', 'Drive'],
            'Nouns': ['Energy', 'Vigor', 'Exuberance', 'Liveliness', 'Motivation', 'Drive']
        },
        'Proactive': {
            'Synonyms': ['Initiative-taking', 'Forward-thinking', 'Prepared', 'Preventive', 'Enterprising', 'Anticipatory'],
            'Verbs': ['Initiate', 'Anticipate', 'Plan ahead', 'Act early', 'Prepare', 'Foresee'],
            'Nouns': ['Initiative', 'Foresight', 'Preparation', 'Readiness', 'Proactivity', 'Prevention']
        }
    },
    'Reflective': {
        'Thoughtful': {
            'Synonyms': ['Considerate', 'Contemplative', 'Deliberate', 'Introspective', 'Mindful', 'Reflective'],
            'Verbs': ['Think', 'Contemplate', 'Deliberate', 'Reflect', 'Meditate', 'Ponder'],
            'Nouns': ['Thoughtfulness', 'Consideration', 'Deliberation', 'Reflection', 'Mindfulness', 'Pondering']
        },
        'Analytical': {
            'Synonyms': ['Logical', 'Examining', 'Investigative', 'Systematic', 'Critical', 'Evaluative'],
            'Verbs': ['Analyze', 'Examine', 'Investigate', 'Systematize', 'Critique', 'Assess'],
            'Nouns': ['Analysis', 'Examination', 'Investigation', 'Systematization', 'Criticism', 'Evaluation']
        },
        'Patient': {
            'Synonyms': ['Tolerant', 'Enduring', 'Persevering', 'Steadfast', 'Resilient', 'Composed'],
            'Verbs': ['Wait', 'Endure', 'Persevere', 'Maintain', 'Sustain', 'Persist'],
            'Nouns': ['Patience', 'Tolerance', 'Endurance', 'Perseverance', 'Resilience', 'Composure']
        },
        'Independent': {
            'Synonyms': ['Self-reliant', 'Autonomous', 'Self-sufficient', 'Self-governing', 'Individualistic', 'Unconstrained'],
            'Verbs': ['Operate independently', 'Function autonomously', 'Govern oneself', 'Stand alone', 'Self-direct', 'Sustain oneself'],
            'Nouns': ['Independence', 'Autonomy', 'Self-governance', 'Individuality', 'Self-sufficiency', 'Freedom']
        },
        'Self-Aware': {
            'Synonyms': ['Insightful', 'Conscious', 'Perceptive', 'Aware', 'Observant', 'Introspective'],
            'Verbs': ['Recognize', 'Understand', 'Acknowledge', 'Examine', 'Comprehend', 'Interpret'],
            'Nouns': ['Self-awareness', 'Consciousness', 'Perception', 'Observation', 'Insight', 'Recognition']
        },
        'Metacognitive': {
            'Synonyms': ['Self-regulating', 'Strategic', 'Mindful', 'Knowledgeable', 'Deliberate', 'Thoughtful'],
            'Verbs': ['Monitor', 'Adjust', 'Plan', 'Evaluate', 'Control', 'Regulate'],
            'Nouns': ['Metacognition', 'Strategy', 'Self-regulation', 'Control', 'Planning', 'Awareness']
        }
    },
    'Sensing': {
        'Practical': {
            'Synonyms': ['Functional', 'Useful', 'Applicable', 'Pragmatic', 'Efficient', 'Hands-on'],
            'Verbs': ['Utilize', 'Employ', 'Apply', 'Practice', 'Adapt', 'Implement'],
            'Nouns': ['Utility', 'Functionality', 'Applicability', 'Pragmatism', 'Efficiency', 'Implementation']
        },
        'Concrete': {
            'Synonyms': ['Real', 'Tangible', 'Actual', 'Solid', 'Definite', 'Observable'],
            'Verbs': ['Realize', 'Materialize', 'Actualize', 'Solidify', 'Define', 'Confirm'],
            'Nouns': ['Reality', 'Tangibility', 'Actuality', 'Solidity', 'Definition', 'Observation']
        },
        'Detailed': {
            'Synonyms': ['Specific', 'Particular', 'Elaborate', 'Thorough', 'Meticulous', 'Precise'],
            'Verbs': ['Detail', 'Specify', 'Elaborate', 'Examine', 'Describe', 'Clarify'],
            'Nouns': ['Detail', 'Specificity', 'Elaboration', 'Thoroughness', 'Precision', 'Clarification']
        },
        'Observant': {
            'Synonyms': ['Watchful', 'Alert', 'Attentive', 'Vigilant', 'Aware', 'Perceptive'],
            'Verbs': ['Observe', 'Watch', 'Monitor', 'Notice', 'Detect', 'Scrutinize'],
            'Nouns': ['Observance', 'Alertness', 'Attention', 'Vigilance', 'Awareness', 'Perception']
        },
        'Realistic': {
            'Synonyms': ['Practical', 'Sensible', 'Down-to-earth', 'Grounded', 'Rational', 'Logical'],
            'Verbs': ['Assess', 'Evaluate', 'Examine', 'Measure', 'Judge', 'Analyze'],
            'Nouns': ['Realism', 'Practicality', 'Sensibility', 'Groundedness', 'Rationality', 'Logic']
        },
        'Structured': {
            'Synonyms': ['Organized', 'Systematic', 'Methodical', 'Orderly', 'Disciplined', 'Well-planned'],
            'Verbs': ['Structure', 'Organize', 'Arrange', 'Plan', 'Regulate', 'Standardize'],
            'Nouns': ['Structure', 'Organization', 'Arrangement', 'Planning', 'Regulation', 'Standardization']
        }
    },
    'Intuitive': {
        'Inventive': {
            'Synonyms': ['Innovative', 'Creative', 'Original', 'Resourceful', 'Visionary', 'Imaginative'],
            'Verbs': ['Invent', 'Create', 'Originate', 'Innovate', 'Envision', 'Redesign'],
            'Nouns': ['Invention', 'Creativity', 'Originality', 'Innovation', 'Vision', 'Ingenuity']
        },
        'Abstract': {
            'Synonyms': ['Theoretical', 'Conceptual', 'Hypothetical', 'Nonliteral', 'Speculative', 'Ideational'],
            'Verbs': ['Theorize', 'Conceptualize', 'Speculate', 'Abstract', 'Imagine', 'Interpret'],
            'Nouns': ['Theory', 'Concept', 'Hypothesis', 'Abstraction', 'Speculation', 'Interpretation']
        },
        'Inquisitive': {
            'Synonyms': ['Curious', 'Questioning', 'Probing', 'Investigative', 'Exploratory', 'Perceptive'],
            'Verbs': ['Inquire', 'Question', 'Probe', 'Investigate', 'Explore', 'Examine'],
            'Nouns': ['Inquisitiveness', 'Curiosity', 'Questioning', 'Investigation', 'Exploration', 'Examination']
        },
        'Conceptual': {
            'Synonyms': ['Theoretical', 'Abstract', 'Ideational', 'Notional', 'Intellectual', 'Philosophical'],
            'Verbs': ['Conceptualize', 'Envision', 'Ideate', 'Theorize', 'Speculate', 'Develop'],
            'Nouns': ['Conceptualization', 'Theory', 'Ideation', 'Notion', 'Philosophy', 'Interpretation']
        },
        'Spontaneous': {
            'Synonyms': ['Unplanned', 'Instinctive', 'Unscripted', 'Impulsive', 'Natural', 'Immediate'],
            'Verbs': ['React', 'Respond', 'Express', 'Improvise', 'Decide', 'Act'],
            'Nouns': ['Spontaneity', 'Instinct', 'Impulse', 'Reaction', 'Improvisation', 'Decision']
        },
        'Creative': {
            'Synonyms': ['Artistic', 'Expressive', 'Inventive', 'Imaginative', 'Unconventional', 'Inspiring'],
            'Verbs': ['Create', 'Design', 'Compose', 'Express', 'Develop', 'Reinvent'],
            'Nouns': ['Creativity', 'Expression', 'Design', 'Innovation', 'Vision', 'Artistry']
        }
    },
    'Visual': {
        'Observant': {
            'Synonyms': ['Watchful', 'Alert', 'Attentive', 'Vigilant', 'Aware', 'Keen-eyed'],
            'Verbs': ['Observe', 'Watch', 'Monitor', 'Scrutinize', 'Inspect', 'Survey'],
            'Nouns': ['Observation', 'Alertness', 'Attention', 'Vigilance', 'Awareness', 'Inspection']
        },
        'Perceptive': {
            'Synonyms': ['Discerning', 'Sensitive', 'Intuitive', 'Insightful', 'Astute', 'Sharp-eyed'],
            'Verbs': ['Perceive', 'Discern', 'Sense', 'Detect', 'Notice', 'Identify'],
            'Nouns': ['Perception', 'Discernment', 'Sensitivity', 'Insight', 'Awareness', 'Recognition']
        },
        'Imaginative': {
            'Synonyms': ['Creative', 'Inventive', 'Innovative', 'Visionary', 'Expressive', 'Artistic'],
            'Verbs': ['Imagine', 'Create', 'Innovate', 'Envision', 'Visualize', 'Design'],
            'Nouns': ['Imagination', 'Creativity', 'Innovation', 'Vision', 'Expression', 'Artistry']
        },
        'Spatial': {
            'Synonyms': ['Geometric', 'Dimensional', 'Formative', 'Structural', 'Architectural', 'Configurable'],
            'Verbs': ['Configure', 'Shape', 'Form', 'Construct', 'Arrange', 'Align'],
            'Nouns': ['Configuration', 'Dimension', 'Formation', 'Structure', 'Arrangement', 'Alignment']
        },
        'Visualizing': {
            'Synonyms': ['Seeing', 'Depicting', 'Imagining', 'Projecting', 'Illustrative', 'Representational'],
            'Verbs': ['Visualize', 'Depict', 'Portray', 'Illustrate', 'Render', 'Project'],
            'Nouns': ['Visualization', 'Depiction', 'Portrayal', 'Illustration', 'Rendering', 'Projection']
        },
        'Graphical': {
            'Synonyms': ['Illustrative', 'Pictorial', 'Representational', 'Expressive', 'Diagrammatic', 'Symbolic'],
            'Verbs': ['Illustrate', 'Graph', 'Diagram', 'Express visually', 'Sketch', 'Map'],
            'Nouns': ['Illustration', 'Graph', 'Diagram', 'Expression', 'Sketch', 'Mapping']
        }
    },
    'Verbal': {
        'Linguistic': {
            'Synonyms': ['Language-based', 'Semantic', 'Phonetic', 'Lexical', 'Grammatical', 'Verbiage'],
            'Verbs': ['Articulate', 'Express', 'Verbalize', 'Communicate', 'Pronounce', 'Enunciate'],
            'Nouns': ['Articulation', 'Expression', 'Verbalization', 'Communication', 'Pronunciation', 'Language']
        },
        'Expressive': {
            'Synonyms': ['Articulate', 'Eloquent', 'Fluent', 'Vocal', 'Dramatic', 'Gestural'],
            'Verbs': ['Express', 'Articulate', 'Eloquate', 'Vocalize', 'Declare', 'Convey'],
            'Nouns': ['Expression', 'Articulation', 'Eloquence', 'Vocality', 'Declaration', 'Conveyance']
        },
        'Logical': {
            'Synonyms': ['Reasoning', 'Rational', 'Analytical', 'Systematic', 'Coherent', 'Structured'],
            'Verbs': ['Reason', 'Analyze', 'Rationalize', 'Systematize', 'Deduce', 'Infer'],
            'Nouns': ['Reasoning', 'Analysis', 'Rationality', 'Systematization', 'Deduction', 'Inference']
        },
        'Auditory': {
            'Synonyms': ['Aural', 'Phonic', 'Resonant', 'Harmonic', 'Melodic', 'Tonal'],
            'Verbs': ['Listen', 'Hear', 'Sound', 'Resonate', 'Tune in', 'Echo'],
            'Nouns': ['Listening', 'Hearing', 'Sound', 'Resonance', 'Melody', 'Echo']
        },
        'Conversational': {
            'Synonyms': ['Talkative', 'Chatty', 'Social', 'Interpersonal', 'Communicative', 'Engaging'],
            'Verbs': ['Converse', 'Discuss', 'Dialogue', 'Engage', 'Chat', 'Talk'],
            'Nouns': ['Conversation', 'Discussion', 'Dialogue', 'Engagement', 'Chat', 'Talk']
        },
        'Narrative': {
            'Synonyms': ['Storytelling', 'Descriptive', 'Dramatic', 'Illustrative', 'Explanatory', 'Detailed'],
            'Verbs': ['Narrate', 'Describe', 'Tell', 'Illustrate', 'Depict', 'Recount'],
            'Nouns': ['Narration', 'Description', 'Storytelling', 'Illustration', 'Depiction', 'Recounting']
        }
    },
    'Sequential': {
        'Orderly': {
            'Synonyms': ['Organized', 'Structured', 'Arranged', 'Systematic', 'Methodical', 'Well-planned'],
            'Verbs': ['Organize', 'Structure', 'Arrange', 'Systematize', 'Coordinate', 'Plan'],
            'Nouns': ['Organization', 'Structure', 'Arrangement', 'Systematization', 'Coordination', 'Planning']
        },
        'Linear': {
            'Synonyms': ['Direct', 'Unbroken', 'Continual', 'Progressive', 'Straightforward', 'Sequential'],
            'Verbs': ['Align', 'Progress', 'Continue', 'Direct', 'Advance', 'Follow'],
            'Nouns': ['Alignment', 'Progression', 'Continuity', 'Direction', 'Advancement', 'Sequence']
        },
        'Analytical': {
            'Synonyms': ['Logical', 'Systematic', 'Rational', 'Objective', 'Critical', 'Evaluative'],
            'Verbs': ['Analyze', 'Systematize', 'Rationalize', 'Objectify', 'Critique', 'Assess'],
            'Nouns': ['Analysis', 'Systematization', 'Rationality', 'Objectivity', 'Criticism', 'Evaluation']
        },
        'Consistent': {
            'Synonyms': ['Steady', 'Regular', 'Stable', 'Unvarying', 'Predictable', 'Reliable'],
            'Verbs': ['Maintain', 'Regulate', 'Standardize', 'Stabilize', 'Ensure', 'Sustain'],
            'Nouns': ['Consistency', 'Regularity', 'Stability', 'Standardization', 'Predictability', 'Reliability']
        },
        'Structured': {
            'Synonyms': ['Well-ordered', 'Methodical', 'Planned', 'Coherent', 'Formatted', 'Organized'],
            'Verbs': ['Format', 'Plan', 'Arrange', 'Construct', 'Compile', 'Develop'],
            'Nouns': ['Structure', 'Format', 'Plan', 'Arrangement', 'Construction', 'Development']
        },
        'Stepwise': {
            'Synonyms': ['Gradual', 'Incremental', 'Step-by-step', 'Progressive', 'Layered', 'Sequential'],
            'Verbs': ['Proceed', 'Advance', 'Develop', 'Expand', 'Refine', 'Build'],
            'Nouns': ['Progression', 'Step', 'Development', 'Expansion', 'Refinement', 'Hierarchy']
        }
    },
    'Global': {
        'Holistic': {
            'Synonyms': ['Complete', 'Comprehensive', 'All-encompassing', 'Integrated', 'Interconnected', 'Expansive'],
            'Verbs': ['Integrate', 'Unify', 'Synthesize', 'Encompass', 'Connect', 'Merge'],
            'Nouns': ['Holism', 'Comprehensiveness', 'Integration', 'Synthesis', 'Connection', 'Unification']
        },
        'Overview': {
            'Synonyms': ['Summary', 'Survey', 'Synopsis', 'Outline', 'Broad', 'Generalized'],
            'Verbs': ['Summarize', 'Survey', 'Synopsize', 'Outline', 'Generalize', 'Review'],
            'Nouns': ['Summary', 'Survey', 'Synopsis', 'Outline', 'Generalization', 'Review']
        },
        'Random': {
            'Synonyms': ['Irregular', 'Non-sequential', 'Haphazard', 'Arbitrary', 'Unsystematic', 'Unpredictable'],
            'Verbs': ['Scatter', 'Disperse', 'Randomize', 'Vary', 'Shuffle', 'Disorganize'],
            'Nouns': ['Randomness', 'Irregularity', 'Haphazardness', 'Arbitrariness', 'Variation', 'Unpredictability']
        },
        'Synthesis': {
            'Synonyms': ['Integration', 'Combination', 'Amalgamation', 'Unification', 'Fusion', 'Blending'],
            'Verbs': ['Synthesize', 'Combine', 'Amalgamate', 'Unify', 'Merge', 'Blend'],
            'Nouns': ['Synthesis', 'Combination', 'Amalgamation', 'Unification', 'Fusion', 'Blending']
        },
        'Big-Picture': {
            'Synonyms': ['Expansive', 'Overarching', 'Macro-level', 'Strategic', 'Panoramic', 'Comprehensive'],
            'Verbs': ['Envision', 'Strategize', 'Plan broadly', 'Think holistically', 'Survey', 'Analyze'],
            'Nouns': ['Perspective', 'Vision', 'Strategy', 'Approach', 'Viewpoint', 'Panorama']
        },
        'Inclusive': {
            'Synonyms': ['All-encompassing', 'Broad-minded', 'Accepting', 'Universal', 'Open', 'Diverse'],
            'Verbs': ['Include', 'Incorporate', 'Embrace', 'Adopt', 'Accommodate', 'Unite'],
            'Nouns': ['Inclusivity', 'Diversity', 'Acceptance', 'Universality', 'Openness', 'Unity']
        }
    },
    'Inductive': {
        'Inferential': {
            'Synonyms': ['Deductive', 'Reasoning', 'Conjecturing', 'Extrapolating', 'Deriving', 'Interpreting'],
            'Verbs': ['Infer', 'Deduce', 'Conjecture', 'Extrapolate', 'Derive', 'Interpret'],
            'Nouns': ['Inference', 'Deduction', 'Conjecture', 'Extrapolation', 'Derivation', 'Interpretation']
        },
        'Observational': {
            'Synonyms': ['Perceptive', 'Watchful', 'Noticing', 'Mindful', 'Attentive', 'Aware'],
            'Verbs': ['Observe', 'Watch', 'Notice', 'Mind', 'Examine', 'Survey'],
            'Nouns': ['Observation', 'Watchfulness', 'Notice', 'Mindfulness', 'Examination', 'Surveillance']
        },
        'Investigative': {
            'Synonyms': ['Researching', 'Examining', 'Probing', 'Studying', 'Exploring', 'Inquiring'],
            'Verbs': ['Investigate', 'Examine', 'Probe', 'Study', 'Explore', 'Inquire'],
            'Nouns': ['Investigation', 'Examination', 'Probing', 'Study', 'Exploration', 'Inquiry']
        },
        'Experimental': {
            'Synonyms': ['Testing', 'Trial', 'Exploratory', 'Empirical', 'Innovative', 'Hypothetical'],
            'Verbs': ['Experiment', 'Test', 'Explore', 'Empiricize', 'Innovate', 'Hypothesize'],
            'Nouns': ['Experimentation', 'Testing', 'Exploration', 'Empiricism', 'Innovation', 'Hypothesis']
        },
        'Adaptive': {
            'Synonyms': ['Flexible', 'Adjustable', 'Modifiable', 'Versatile', 'Responsive', 'Resilient'],
            'Verbs': ['Adapt', 'Modify', 'Adjust', 'Respond', 'Refine', 'Optimize'],
            'Nouns': ['Adaptation', 'Modification', 'Adjustment', 'Versatility', 'Responsiveness', 'Resilience']
        },
        'Comparative': {
            'Synonyms': ['Relative', 'Contrasting', 'Evaluative', 'Differential', 'Analogous', 'Correlational'],
            'Verbs': ['Compare', 'Contrast', 'Evaluate', 'Differentiate', 'Correlate', 'Assess'],
            'Nouns': ['Comparison', 'Contrast', 'Evaluation', 'Differentiation', 'Correlation', 'Assessment']
        }
    },
    'Deductive': {
        'Logical': {
            'Synonyms': ['Reasoning', 'Rational', 'Analytical', 'Systematic', 'Methodical', 'Objective'],
            'Verbs': ['Reason', 'Rationalize', 'Analyze', 'Systematize', 'Deduce', 'Compute'],
            'Nouns': ['Reasoning', 'Rationality', 'Analysis', 'Systematization', 'Deduction', 'Calculation']
        },
        'Conclusive': {
            'Synonyms': ['Decisive', 'Determinative', 'Resolving', 'Final', 'Definitive', 'Absolute'],
            'Verbs': ['Conclude', 'Decide', 'Resolve', 'Finalize', 'Confirm', 'Establish'],
            'Nouns': ['Conclusion', 'Decision', 'Resolution', 'Finality', 'Confirmation', 'Establishment']
        },
        'Predictive': {
            'Synonyms': ['Forecasting', 'Prophesying', 'Projecting', 'Foretelling', 'Anticipating', 'Estimating'],
            'Verbs': ['Predict', 'Forecast', 'Project', 'Foretell', 'Anticipate', 'Estimate'],
            'Nouns': ['Prediction', 'Forecast', 'Projection', 'Foretelling', 'Anticipation', 'Estimation']
        },
        'Prescriptive': {
            'Synonyms': ['Guiding', 'Directing', 'Advising', 'Recommending', 'Mandating', 'Instructive'],
            'Verbs': ['Prescribe', 'Guide', 'Advise', 'Recommend', 'Mandate', 'Instruct'],
            'Nouns': ['Prescription', 'Guidance', 'Advice', 'Recommendation', 'Mandate', 'Instruction']
        },
        'Categorical': {
            'Synonyms': ['Absolute', 'Definite', 'Classified', 'Distinguished', 'Explicit', 'Unambiguous'],
            'Verbs': ['Classify', 'Distinguish', 'Define', 'Organize', 'Label', 'Specify'],
            'Nouns': ['Category', 'Definition', 'Classification', 'Distinction', 'Label', 'Specification']
        },
        'Normative': {
            'Synonyms': ['Standardized', 'Regulatory', 'Conforming', 'Authoritative', 'Prescriptive', 'Conventional'],
            'Verbs': ['Standardize', 'Regulate', 'Conform', 'Authorize', 'Prescribe', 'Mandate'],
            'Nouns': ['Norm', 'Standard', 'Regulation', 'Conformity', 'Authority', 'Mandate']
        }
    }
}

#Create a list to store the dataset
data = []
for factor, attributes in fsls_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
fsls_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/fsls.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="FSLS Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "FSLS")
    mlflow.log_param("Total Rows", len(fsls_df))
    mlflow.log_param("Total Factors", len(fsls_dataset))
    mlflow.log_param("Data Schema", str(fsls_df.columns.tolist()))
    
    # Save dataset to CSV
    fsls_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ FSLS dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(fsls_df.head())
    print("\nDataset shape:", fsls_df.shape)
    print("\nNumber of unique Factors:", fsls_df['Factor'].nunique())
    print("Unique Factors:", fsls_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# 2025/03/18 10:11:28 INFO mlflow.tracking.fluent: Experiment with name 'FSLS' does not exist. Creating a new experiment.
# ✅ FSLS dataset created and saved to ../Datasets/fsls.csv
# First 5 rows of the dataset:
#    Factor Adjective        Synonym          Verb           Noun
# 0  Active   Engaged       Involved        Engage     Engagement
# 1  Active   Engaged  Participating   Participate  Participation
# 2  Active   Engaged         Active           Act       Activity
# 3  Active   Engaged           Busy  Busy oneself       Busyness
# 4  Active   Engaged      Committed        Commit     Commitment
#
# Dataset shape: (360, 5)
#
# Number of unique Factors: 10
# Unique Factors: ['Active' 'Reflective' 'Sensing' 'Intuitive' 'Visual' 'Verbal'
#  'Sequential' 'Global' 'Inductive' 'Deductive']
# 📌 MLflow tracking active under experiment 'FSLS' (ID: 28)
# 🏃 View run FSLS Dataset Creation at: http://127.0.0.1:5000/#/experiments/28/runs/5e63975221a1457ab3ab66702ff33e05
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="fsls_page_2"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/28/runs/75d973bb07724168be407d7ef9783bee
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="fsls_page_2"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018421143293380737, -0.007218753919005394, 0.003606205340474844, -0.05419774353504181, -0.022721948102116585, 0.036969155073165894, 0.02902725711464882, 0.023901814594864845, 0.011240449734032154, -0.020641323179006577]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/28/runs/92c7713b3c2a457a83176b6ba1d4dc98
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create fsls Embeddings** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved fsls dataset from a CSV file
dataset_path = '../Datasets/fsls.csv'
try:
    fsls_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'fsls_df' is empty before processing
        if fsls_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", fsls_df.shape[0])
            print(f"📊 Processing {fsls_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        fsls_df['Embedding'] = fsls_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/fsls_embeddings.csv'
        fsls_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = fsls_df.shape[0]
        num_columns = fsls_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in fsls_df.columns and not fsls_df['Embedding'].empty:
            embedding_length = len(fsls_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(fsls_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/fsls.csv
# ⏳ Embedding generation started at: 2025-03-18 10:11:31.463183
# 📊 Processing 360 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-18 10:13:49.927729 (Duration: 0:02:18.464546)
# 💾 Embeddings saved to: ../Embeddings/fsls_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#    Factor Adjective        Synonym          Verb           Noun  \
# 0  Active   Engaged       Involved        Engage     Engagement
# 1  Active   Engaged  Participating   Participate  Participation
# 2  Active   Engaged         Active           Act       Activity
# 3  Active   Engaged           Busy  Busy oneself       Busyness
# 4  Active   Engaged      Committed        Commit     Commitment
#
#                                            Embedding
# 0  [0.007877440191805363, 0.02038240060210228, -0...
# 1  [0.008844827301800251, 0.020212432369589806, 0...
# 2  [0.008775983937084675, 0.0443153940141201, -0....
# 3  [0.004633444361388683, 0.03577949106693268, 0....
# 4  [0.02489524520933628, 0.03291806951165199, 0.0...
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5000/#/experiments/28/runs/b8ecfb88a57c426cbc367c5cd94fd8b4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/fsls_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/fsls_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "fsls_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/fsls_embeddings.csv
# 💾 Label encoder saved to: ../Models/fsls_label_encoder.pkl
#
# First 5 rows with encoded labels:
#    Factor  Factor_Encoded
# 0  Active               0
# 1  Active               0
# 2  Active               0
# 3  Active               0
# 4  Active               0
#
# Mapping of original labels to encoded labels:
# Active: 0
# Deductive: 1
# Global: 2
# Inductive: 3
# Intuitive: 4
# Reflective: 5
# Sensing: 6
# Sequential: 7
# Verbal: 8
# Visual: 9
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/fsls_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: fsls_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/28/runs/70b845071aad451c9635db3ee3bbe64d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/fsls_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/fsls_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="fsls Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "fsls_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "fsls_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "fsls_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/fsls_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/fsls_embeddings.csv
# ✅ Label encoder loaded from: ../Models/fsls_label_encoder.pkl
# ⏳ Model training started at: 2025-03-18 10:13:53.623715
# ✅ Model training finished at: 2025-03-18 10:13:54.228209 (Duration: 0:00:00.604494)
# 📊 Classification report saved to: fsls_classification_report.csv
# 📊 Confusion matrix saved to: fsls_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: fsls_confusion_matrix.png
# 💾 Trained model saved to: ../Models/fsls_rf_model.pkl
# ✅ Model training complete. Accuracy: 0.9861111111111112
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Active       1.00      0.86      0.92         7
#    Deductive       1.00      1.00      1.00         7
#       Global       0.88      1.00      0.93         7
#    Inductive       1.00      1.00      1.00         8
#    Intuitive       1.00      1.00      1.00         7
#   Reflective       1.00      1.00      1.00         7
#      Sensing       1.00      1.00      1.00         8
#   Sequential       1.00      1.00      1.00         7
#       Verbal       1.00      1.00      1.00         7
#       Visual       1.00      1.00      1.00         7
#
#     accuracy                           0.99        72
#    macro avg       0.99      0.99      0.99        72
# weighted avg       0.99      0.99      0.99        72
#
#
# Confusion Matrix:
#              Active  Deductive  Global  Inductive  Intuitive  Reflective  \
# Active           6          0       1          0          0           0
# Deductive        0          7       0          0          0           0
# Global           0          0       7          0          0           0
# Inductive        0          0       0          8          0           0
# Intuitive        0          0       0          0          7           0
# Reflective       0          0       0          0          0           7
# Sensing          0          0       0          0          0           0
# Sequential       0          0       0          0          0           0
# Verbal           0          0       0          0          0           0
# Visual           0          0       0          0          0           0
#
#             Sensing  Sequential  Verbal  Visual
# Active            0           0       0       0
# Deductive         0           0       0       0
# Global            0           0       0       0
# Inductive         0           0       0       0
# Intuitive         0           0       0       0
# Reflective        0           0       0       0
# Sensing           8           0       0       0
# Sequential        0           7       0       0
# Verbal            0           0       7       0
# Visual            0           0       0       7
# 🏃 View run fsls Model Training and Evaluation Workflow at: http://127.0.0.1:5000/#/experiments/28/runs/9cc3989db41d447c96b1630c2f71f73a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/fsls_embeddings.csv'
label_encoder_path = "../Models/fsls_label_encoder.pkl"
model_path = "../Models/fsls_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate fsls Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate fsls Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "fsls_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "fsls_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "fsls_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ fsls Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/fsls_embeddings.csv
# ✅ Label encoder loaded from: ../Models/fsls_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/fsls_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 0.9861
# 📊 Classification report saved to: fsls_evaluation_classification_report.csv
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Active       1.00      0.86      0.92         7
#    Deductive       1.00      1.00      1.00         7
#       Global       0.88      1.00      0.93         7
#    Inductive       1.00      1.00      1.00         8
#    Intuitive       1.00      1.00      1.00         7
#   Reflective       1.00      1.00      1.00         7
#      Sensing       1.00      1.00      1.00         8
#   Sequential       1.00      1.00      1.00         7
#       Verbal       1.00      1.00      1.00         7
#       Visual       1.00      1.00      1.00         7
#
#     accuracy                           0.99        72
#    macro avg       0.99      0.99      0.99        72
# weighted avg       0.99      0.99      0.99        72
#
# 📊 Confusion matrix saved to: fsls_evaluation_confusion_matrix.csv
#
# Confusion Matrix:
#              Active  Deductive  Global  Inductive  Intuitive  Reflective  \
# Active           6          0       1          0          0           0
# Deductive        0          7       0          0          0           0
# Global           0          0       7          0          0           0
# Inductive        0          0       0          8          0           0
# Intuitive        0          0       0          0          7           0
# Reflective       0          0       0          0          0           7
# Sensing          0          0       0          0          0           0
# Sequential       0          0       0          0          0           0
# Verbal           0          0       0          0          0           0
# Visual           0          0       0          0          0           0
#
#             Sensing  Sequential  Verbal  Visual
# Active            0           0       0       0
# Deductive         0           0       0       0
# Global            0           0       0       0
# Inductive         0           0       0       0
# Intuitive         0           0       0       0
# Reflective        0           0       0       0
# Sensing           8           0       0       0
# Sequential        0           7       0       0
# Verbal            0           0       7       0
# Visual            0           0       0       7
# 🖼️ Confusion matrix plot saved to: fsls_evaluation_confusion_matrix.png
# 🏃 View run Evaluate fsls Model at: http://127.0.0.1:5000/#/experiments/28/runs/f06bcb17d77e42bfb3a8eba914af0abd
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28
#
# ✅ fsls Model evaluation on the test set complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/fsls_label_encoder.pkl"
model_path = "../Models/fsls_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/fsls_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/fsls_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Active
# Predicted Factor for 'I prefer staying home with a good book....': Active
# Predicted Factor for 'I often feel anxious and worried....': Intuitive
# Predicted Factor for 'I am generally calm and relaxed....': Verbal
# Predicted Factor for 'I enjoy taking risks and trying new things....': Active
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/28/runs/746ae03254e14a0eb20d8b02c66deab0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/fsls_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="fsls Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/fsls_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "fsls_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/fsls_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of fsls Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/fsls_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of fsls Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/18 10:14:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Active
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Reflective
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Intuitive
# Predicted Factor for 'Organized Meticulous Plan Planner': Sequential
# Predicted Factor for 'Moody Anxious Worry Worrier': Reflective
# 🏃 View run fsls Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/28/runs/0ca208ab7aef4d36aaa4569d6d7b1736
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/fsls_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/fsls_label_encoder.pkl"
        model_path = "../Models/fsls_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of fsls Embeddings")

            # Save and log the plot
            pca_plot_path = "fsls_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "fsls_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/fsls_embeddings.csv
#
# DataFrame with Embeddings:
#    Factor Adjective        Synonym          Verb           Noun  \
# 0  Active   Engaged       Involved        Engage     Engagement
# 1  Active   Engaged  Participating   Participate  Participation
# 2  Active   Engaged         Active           Act       Activity
# 3  Active   Engaged           Busy  Busy oneself       Busyness
# 4  Active   Engaged      Committed        Commit     Commitment
#
#                                            Embedding
# 0  [0.007877440191805363, 0.02038240060210228, -0...
# 1  [0.008844827301800251, 0.020212432369589806, 0...
# 2  [0.008775983937084675, 0.0443153940141201, -0....
# 3  [0.004633444361388683, 0.03577949106693268, 0....
# 4  [0.02489524520933628, 0.03291806951165199, 0.0...
#
# Shape of DataFrame:
# (360, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.00787744  0.0203824  -0.0042698  ... -0.0252687   0.01056414
#   0.0241727 ]
# ✅ Label encoder loaded from: ../Models/fsls_label_encoder.pkl
#
# Shape of X:
# (360, 1536)
# ✅ PCA visualization saved to: fsls_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: fsls_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Active
# 🏃 View run Step 9: Model Application, Visualization, and Analysis at: http://127.0.0.1:5000/#/experiments/28/runs/8f209a8083954cc4a50b6e055e2bd0d6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28
#
# ✅ Step 10: Save Model Visualization and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [0.93055556 0.97222222 0.97222222 0.98611111 0.95833333]
# Mean cross-validation score: 0.9638888888888889

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="fsls_page_3"></a>
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/fsls_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_fsls.pkl')
clf = joblib.load('../Models/fsls_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Active
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Verbal
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Intuitive
# Predicted Factor for 'Organized Meticulous Plan Planner': Sequential
# Predicted Factor for 'Moody Anxious Worry Worrier': Intuitive
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Active

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Intuitive

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Intuitive

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Reflective

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Verbal

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Verbal

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="fsls_page_4"></a>
#
#
# [Back to Top](#fsls_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("FSLS")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/28/runs/82b7bb8a5bff4f1db2887959a7d114ee
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create fsls Schema in Neo4j** <a class="anchor" id="FSLS_page_4"></a>
#
#
# [Back to Top](#FSLS_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("FSLS")

# Load the dataset
dataset_path = "../Embeddings/fsls_embeddings.csv"
fsls_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in fsls_df.columns:
    fsls_df['Embedding'] = fsls_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the FSL schema in Neo4j
def create_fsls_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with FSLS labels
        graph.run("MERGE (f:FSLS_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:FSLS_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:FSLS_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:FSLS_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:FSLS_Noun {name: $noun})", noun=noun)
        
        # Create relationships with FSLS namespacing
        graph.run("""
            MATCH (f:FSLS_Factor {name: $factor}), (a:FSLS_Adjective {name: $adjective})
            MERGE (f)-[:FSLS_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:FSLS_Adjective {name: $adjective}), (s:FSLS_Synonym {name: $synonym})
            MERGE (a)-[:FSLS_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:FSLS_Adjective {name: $adjective}), (v:FSLS_Verb {name: $verb})
            MERGE (a)-[:FSLS_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:FSLS_Adjective {name: $adjective}), (n:FSLS_Noun {name: $noun})
            MERGE (a)-[:FSLS_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:FSLS_Factor {name: $factor}), (a:FSLS_Adjective {name: $adjective})
                MERGE (e:FSLS_Embedding {value: $embedding})
                MERGE (f)-[:FSLS_HAS_EMBEDDING]->(e)
                MERGE (a)-[:FSLS_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create FSLS Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create FSLS Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the FSLS schema
        create_fsls_schema(graph, fsls_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", fsls_df.shape[0])
        mlflow.log_param("Number of Columns", fsls_df.shape[1])
        
        # Print the DataFrame
        print(fsls_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#    Factor Adjective        Synonym          Verb           Noun  \
# 0  Active   Engaged       Involved        Engage     Engagement
# 1  Active   Engaged  Participating   Participate  Participation
# 2  Active   Engaged         Active           Act       Activity
# 3  Active   Engaged           Busy  Busy oneself       Busyness
# 4  Active   Engaged      Committed        Commit     Commitment
#
#                                            Embedding
# 0  [0.007877440191805363, 0.02038240060210228, -0...
# 1  [0.008844827301800251, 0.020212432369589806, 0...
# 2  [0.008775983937084675, 0.0443153940141201, -0....
# 3  [0.004633444361388683, 0.03577949106693268, 0....
# 4  [0.02489524520933628, 0.03291806951165199, 0.0...
# 🏃 View run Create FSLS Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/28/runs/9a8091d8bf424588b1a9c18480cc5a36
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/28

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:FSLS_Factor OR n:FSLS_Adjective OR n:FSLS_Synonym OR n:FSLS_Verb OR n:FSLS_Noun)
# AND NOT m:FSLS_Embedding
# RETURN n, r, m
# ```
