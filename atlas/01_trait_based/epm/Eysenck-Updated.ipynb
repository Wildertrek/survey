# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Eysenck Personality Model (EPM)<a class="anchor" id="PTMD_page_4"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# ## **Exploring the Eysenck Personality Model (EPM)**
#
# In the realm of personality psychology, the Eysenck Personality Model (EPM) stands as a testament to the simplicity and effectiveness of understanding human nature. This model, developed by the pioneering psychologist Hans Eysenck, distills the complexities of personality into five fundamental dimensions. Let's embark on a journey to discover these dimensions and the EPM dataset that helps us explore them.
#
# 1. **Extraversion**: Imagine a world where sociability and assertiveness reign supreme. Here, individuals are sociable, assertive, active, talkative, adventurous, and fun-loving. They thrive in social gatherings, exude confidence, and are often the life of the party. This dimension celebrates the extroverted, dynamic, and adventurous spirit.
#
# 2. **Introversion**: Step into a realm of quiet contemplation and independence. Introverted individuals are reserved, reflective, peaceful, independent, quiet, and deliberate. They find solace in introspection and self-reliance. This dimension values thoughtfulness, tranquility, and autonomy.
#
# 3. **Neuroticism**: In this emotional landscape, anxiety and mood swings take center stage. People here are anxious, irritable, moody, tense, frustrated, and over-sensitive. Emotions ebb and flow like waves, and individuals are often on a rollercoaster of feelings. This dimension delves into the intricacies of emotional volatility.
#
# 4. **Stability**: Picture a serene haven of calmness and reliability. In this dimension, individuals are calm, even-tempered, contented, patient, reliable, and peaceful. They offer a steady presence in the lives of others and find contentment in the simple joys of life. Stability celebrates composure, dependability, and inner peace.
#
# 5. **Psychoticism**: Venture into a world where unconventional traits define the norm. Psychoticism is a complex dimension where individuals can be aggressive, impersonal, antisocial, unemotional, creative, and rebellious. It explores the boundaries of conformity and societal norms, celebrating inventiveness and resistance to authority.
#
# The `epm_dataset` serves as a compass through this captivating terrain. Within each dimension, you'll find a collection of adjectives and their synonyms, providing a nuanced understanding of the facets that make up each dimension. For instance, "Sociable" is akin to being "gregarious," "outgoing," and "friendly" within the realm of Extraversion.
#
# Just as a seasoned explorer relies on a well-annotated map to navigate new territories, psychologists, researchers, and personality enthusiasts turn to the EPM dataset to delve into the intricacies of human personality. This dataset is a treasure trove of insights, offering a deep understanding of how individuals express their EPM dimensions.
#
# As you embark on your journey through the Eysenck Personality Model, this dataset will serve as your guide, illuminating the unique traits and characteristics that define each dimension. It's a reminder that human personality, in all its diversity, can be understood through the elegant simplicity of EPM's four fundamental dimensions.
#
# Creating a timeline and reference table for the Eysenck Personality Model (EPM) involves identifying key milestones in its development and the significant contributions made by researchers in this field. Eysenck's model primarily focuses on three major dimensions of personality: Extraversion-Introversion, Neuroticism-Stability, and Psychoticism-Superego function. Here is a timeline and reference table for the Eysenck Personality Model:
#
# ### **Timeline of the Eysenck Personality Model (EPM)**
#
# | Year | Milestone |
# |------|-----------|
# | 1947 | Hans Eysenck's publication "Dimensions of Personality" introduces the initial framework of the Eysenck Personality Model focusing on Extraversion and Neuroticism. |
# | 1952 | Eysenck develops the Eysenck Personality Inventory (EPI) to measure Extraversion and Neuroticism traits. |
# | 1967 | Introduction of the concept of Psychoticism as a distinct personality dimension, expanding the Eysenck Personality Model. |
# | 1970 | Eysenck's "The Structure of Human Personality" further refines the model and its underlying theoretical basis. |
# | 1975 | Development of the revised Eysenck Personality Questionnaire (EPQ), which includes scales for Psychoticism, Extraversion, Neuroticism, and a Lie scale. |
# | 1985 | Research by Eysenck and Eysenck focuses on the biological and genetic underpinnings of personality traits. |
# | 1991 | Hans Eysenck's "Personality, Genetics, and Behavior" discusses the heritability and biological correlates of personality traits. |
# | 1992 | Further empirical studies and cross-cultural validations of the EPM, solidifying its global applicability. |
# | 2000s | Ongoing research continues to explore the biological basis of personality traits and their relation to the Eysenck Personality Model. |
# | Present | The Eysenck Personality Model remains influential in personality psychology, with ongoing research and applications. |
#
#
# This table and timeline present a concise overview of the development and evolution of the Eysenck Personality Model (EPM). Each entry highlights the significant contributions and advancements in understanding and measuring personality traits according to Eysenck's model. The DOI information may not be available for older publications, but recent studies and reviews can be sourced for more detailed information and contemporary perspectives on EPM.
#
# ### **Eysenck Personality Model (EPM) Reference Table**
#
# | Ref | Author(s) | Year | Title | Journal | Volume and Pages | DOI |
# |-----|-----------|------|-------|---------|-----------------|-----|
# | 89  | G. Āllport | 1938 | Personality: A Psychological Interpretation | - | - | [10.2307/2785590](https://doi.org/10.2307/2785590) |
# | 90  | H. Eysenck | 1947 | Dimensions of Personality | - | - | [10.4324/9780203793268](https://doi.org/10.4324/9780203793268) |
# | 91  | W. D. Furneaux | 1950 | Criterion analysis; an application of the hypothetico-deductive method to factor analysis | Psychological Review | 57(1), 38-53 | [10.1037/H0057657](https://doi.org/10.1037/H0057657) |
# | 92  | W. D. Furneaux | 1952 | Primary Suggestibility and Hypnotic Susceptibility in a Group Situation | Journal of General Psychology | 46, 87-91 | [10.1080/00221309.1952.9710640](https://doi.org/10.1080/00221309.1952.9710640) |
# | 93  | A. Benton, A. Bandura | 1953 | Primary and secondary suggestibility | Journal of Abnormal Psychology | 48(3), 336-40 | [10.1037/H0055272](https://doi.org/10.1037/H0055272) |
# | 94  | H. Eysenck | 1953 | The structure of human personality | - | - | [10.1037/h0052161](https://doi.org/10.1037/h0052161) |
# | 95  | W. McBain | 1954 | Imagery and suggestibility: a test of the Arnold hypothesis | Journal of Abnormal Psychology | 49(1), 36-44 | [10.1037/H0062841](https://doi.org/10.1037/H0062841) |
# | 96  | H. Eysenck | 1957 | Dynamics of Anxiety and Hysteria | - | - | - |
# | 97  | A. Weitzenhoffer, Geneva B. Weitzenhoffer | 1958 | Personality and Hypnotic Susceptibility | American Journal of Clinical Hypnosis | 1, 79-82 | [10.1080/00029157.1958.10734338](https://doi.org/10.1080/00029157.1958.10734338) |
# | 98  | D. Pond | 1958 | The Dynamics of Anxiety and Hysteria | Mental Health | 17, 74-75 | - |
# | 99  | R. Cattell | 1958 | Personality and motivation structure and measurement | American Journal of Psychology | 71, 620 | [10.2307/1420273](https://doi.org/10.2307/1420273) |
# | 100 | M. Zuckerman, H. Grosz | 1958 | Suggestibility and dependency | Journal of Consulting Psychology | 22(5), 328 | [10.1037/H0046309](https://doi.org/10.1037/H0046309) |
# | 101 | F. Heilizer | 1961 | Relationships between anxiety and hypnotizability | The American Journal of Clinical Hypnosis | 4, 30-35 | [10.1080/00029157.1961.10401864](https://doi.org/10.1080/00029157.1961.10401864) |
# | 102 | W. D. Furneaux, H. B. Gibson | 1961 | The Maudsley Personality Inventory as a predictor of susceptibility to hypnosis | International Journal of Clinical and Experimental Hypnosis | 9, 167-177 | [10.1080/00207146108409672](https://doi.org/10.1080/00207146108409672) |
# | 103 | I. I. Secter | 1961 | Personality Factors of the MMPI and Hypnotizability | American Journal of Clinical Hypnosis | 3, 185-188 | [10.1080/00029157.1961.10701713](https://doi.org/10.1080/00029157.1961.10701713) |
# | 104 | W. D. Furneaux | 1961 | Neuroticism, extraversion, drive, and suggestibility | The International Journal of Clinical and Experimental Hypnosis | 9, 195-214 | [10.1080/00207146108409674](https://doi.org/10.1080/00207146108409674) |
# | 105 | A. Welford | 1962 | Arousal, Channel-Capacity and Decision | Nature | 194, 365-366 | [10.1038/194365A0](https://doi.org/10.1038/194365A0) |
# | 106 | E. Hilgard, L. Lauer | 1962 | Lack of correlation between the California Psychological Inventory and hypnotic susceptibility | Journal of Consulting Psychology | 26, 331-335 | [10.1037/H0046247](https://doi.org/10.1037/H0046247) |
# | 107 | H. Eysenck | 1963 | Biological Basis of Personality | Nature | 199, 1031-1034 | [10.1038/1991031A0](https://doi.org/10.1038/1991031A0) |
# | 108 | W. T. Norman | 1963 | Toward an adequate taxonomy of personality attributes: replicated factors structure in peer nomination personality ratings | Journal of Abnormal and Social Psychology | 66, 574-83 | [10.1037/H0040291](https://doi.org/10.1037/H0040291) |
# | 109 | W. D. Furneaux | 1964 | The heat-illusion test and the structure of suggestibility | The International Journal of Clinical and Experimental Hypnosis | 12, 169-180 | [10.1080/00207146408409103](https://doi.org/10.1080/00207146408409103) |
# | 110 | T. Mordey, J. Bryan | 1965 | Suggestibility and its distribution | The American Journal of Clinical Hypnosis | 8, 226-228 | [10.1080/00029157.1965.10402422](https://doi.org/10.1080/00029157.1965.10402422) |
# | 111 | H. Brierley | 1967 | The treatment of hysterical spasmodic torticollis by behaviour therapy | Behaviour Research and Therapy | 5(2), 139-142 | [10.1016/0005-7967(67)90011-3](https://doi.org/10.1016/0005-7967(67)90011-3) |
# | 112 | J. Gray | 1970 | The psychophysiological basis of introversion-extraversion | Behaviour Research and Therapy | 8(3), 249-266 | [10.1016/0005-7967(70)90069-0](https://doi.org/10.1016/0005-7967(70)90069-0) |
# | 113 | A. Hedberg | 1974 | The effect of certain examiner and subject characteristics on responsiveness to suggestion | The International Journal of Clinical and Experimental Hypnosis | 22(4), 354-364 | [10.1080/00207147408413015](https://doi.org/10.1080/00207147408413015) |
# | 114 | H. Eysenck, S. Eysenck | 1976 | Psychoticism as a dimension of personality | - | - | - |
# | 115 | M. Zuckerman | 1991 | Psychobiology of personality | - | - | [10.1097/00004850-199100640-00009](https://doi.org/10.1097/00004850-199100640-00009) |
# | 116 | H. Eysenck | 1981 | A Model for Personality | - | - | [10.1007/978-3-642-67783-0](https://doi.org/10.1007/978-3-642-67783-0) |
# | 117 | J. Gray | 1981 | A Critique of Eysenck’s Theory of Personality | - | - | [10.1007/978-3-642-67783-0_8](https://doi.org/10.1007/978-3-642-67783-0_8) |
# | 118 | M. Friedman, D. Shmukler | 1982 | An Integration of Major Theoretical Aspects of Anxiety, Creative Behavior, or Rackets | Transactional Analysis Journal | 12, 147-152 | [10.1177/036215378201200210](https://doi.org/10.1177/036215378201200210) |
# | 119 | J. Gray | 1982 | Précis of The neuropsychology of anxiety: An enquiry into the functions of the septo-hippocampal system | Behavioral and Brain Sciences | 5, 469-484 | [10.1017/S0140525X00013066](https://doi.org/10.1017/S0140525X00013066) |
# | 120 | S. Eysenck, H. Eysenck, P. Barrett | 1985 | A revised version of the Psychoticism scale | Personality and Individual Differences | 6, 21-29 | [10.1016/0191-8869(85)90026-1](https://doi.org/10.1016/0191-8869(85)90026-1) |
# | 121 | L. R. Goldberg, et al. | 1990 | PERSONALITY PROCESSES AND INDIVIDUAL DIFFERENCES An Alternative "Description of Personality": The Big-Five Factor Structure | Journal of Personality and Social Psychology | 59(6), 1216-1229 | [10.1037/0022-3514.59.6.1216](https://doi.org/10.1037/0022-3514.59.6.1216) |
# | 122 | H. Eysenck | 1991 | Dimensions of personality: 16, 5 or 3? — Criteria for a taxonomic paradigm | Personality and Individual Differences | 12, 773-790 | [10.1016/0191-8869(91)90144-Z](https://doi.org/10.1016/0191-8869(91)90144-Z) |
# | 123 | P. Costa, R. McCrae | 1992 | Four ways five factors are basic | Personality and Individual Differences | 13, 653-665 | [10.1016/0191-8869(92)90236-I](https://doi.org/10.1016/0191-8869(92)90236-I) |
# | 124 | H. Eysenck | 1992 | Four ways five factors are not basic | Personality and Individual Differences | 13, 667-673 | [10.1016/0191-8869(92)90237-J](https://doi.org/10.1016/0191-8869(92)90237-J) |
# | 125 | E. C. Tupes, R. E. Christal | 1992 | Recurrent personality factors based on trait ratings | Journal of Personality | 60(2), 225-251 | [10.1111/J.1467-6494.1992.Tb00973.X](https://doi.org/10.1111/J.1467-6494.1992.Tb00973.X) |
# | 126 | Haiwei Jin | 2009 | A hybrid instructional design model for the combination of motivation theory and constructivism | 2009 4th International Conference on Computer Science & Education | - | [10.1109/ICCSE.2009.5228285](https://doi.org/10.1109/ICCSE.2009.5228285) |
# | 127 | S. Kuwahara | 2010 | Economic Analysis on Business Cycles and Suicide Rate - An Approach from Corporate Behavior - | - | - | - |
# | 128 | H. Igarashi, M. Fukushi | 2010 | Survey of human errors by radiological technologists in Gunma and evaluation of preventive measures : focusing on CT and MRI examinations | - | - | [10.24531/JHSAIIH.13.2_77](https://doi.org/10.24531/JHSAIIH.13.2_77) |
# | 129 | Prof A. Seshachalam | 2016 | Healthy Way to Handle Work Place Stress through Yoga, Meditation and Soothing Humor | IOSR Journal of Business and Management | 18, 18-25 | [10.9790/487X-1810031825](https://doi.org/10.9790/487X-1810031825) |
#
#
#
# ## Eysenck Personality Model (EPM) Timeline Reference Table
#
# | Year          | Milestone                                                | Contributor(s)            | Original Work Reference                                                                                                          | Contribution Reference                                              | Additional Information                                |
# |---------------|----------------------------------------------------------|---------------------------|----------------------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------|------------------------------------------------------|
# | 1947          | Introduction of the EPM focusing on Extraversion and Neuroticism. | Hans Eysenck              | Eysenck, H. J. (1947). Dimensions of Personality.                                                                                | Foundational work in EPM.                                           | Initiates the Eysenck Personality Model.             |
# | 1952          | Development of the Eysenck Personality Inventory (EPI).          | Hans Eysenck              | Eysenck, H. J. (1952). The Scientific Study of Personality.                                                                      | Instrumental in measuring key personality traits.                   | Creates a tool to measure Extraversion and Neuroticism. |
# | 1967, 1970    | Introduction of Psychoticism; refinement of the EPM.             | Hans Eysenck              | Eysenck, H. J. (1967). The Biological Basis of Personality.<br>Eysenck, H. J. (1970). The Structure of Human Personality.       | Expands the EPM to include Psychoticism.                            | Adds a third dimension to the EPM.                     |
# | 1975          | Revision of the Eysenck Personality Questionnaire (EPQ).         | Hans Eysenck              | Eysenck, H. J. (1975). Manual of the Eysenck Personality Questionnaire.                                                         | Includes scales for Psychoticism, Extraversion, Neuroticism, and a Lie scale. | Further refines the measurement of EPM traits.        |
# | 1985          | Focus on biological and genetic basis of personality traits.     | Hans Eysenck and Sybil Eysenck | Eysenck, H. J., & Eysenck, S. B. G. (1985). Personality and Individual Differences: A Natural Science Approach.              | Emphasized the role of biology in personality.                       | Highlights biological underpinnings of EPM.           |
# | 1991          | Discussion on heritability and biological correlates of personality traits. | Hans Eysenck              | Eysenck, H. J. (1991). Personality, Genetics, and Behavior.                                                                      | Significant contribution to understanding the genetic aspects of personality. | Explores the genetic basis of EPM traits.             |
# | 1992 - Present| Ongoing research on EPM.                                        | Various Researchers       | Multiple publications.                                                                                                          | Continued exploration of the model's applicability and relevance.    | Includes modern research and findings.                |
#
#
#
# development with detailed references for each milestone. Each row represents a significant event in the evolution of the EPM, listing the year, a brief description of the milestone, the main contributors, the original works and contributions, additional notes for context, and the DOI (if available). This format provides a comprehensive view of the model's progression, offering an informative and structured overview of its historical and academic journey.
#
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %% [markdown]
# ##  Steps for EPM Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (EPM).
#     * **Actions:**
#         * Define the EPM dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the EPM dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the EPM dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our EPM Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up EPM experiment
experiment_name = "EPM"
mlflow.set_experiment(experiment_name)

# Eysenck Personality Model Dataset with Nouns
epm_dataset = {
    'Extraversion': {
        'Sociable': {
            'Synonyms': ['Gregarious', 'Outgoing', 'Friendly'],
            'Verbs': ['Engage socially', 'Interact joyfully', 'Participate in social activities'],
            'Nouns': ['Parties', 'Social gatherings', 'Meetups']
        },
        'Assertive': {
            'Synonyms': ['Confident', 'Dominant', 'Bold'],
            'Verbs': ['State clearly', 'Command respectfully', 'Assert confidently'],
            'Nouns': ['Debates', 'Leadership roles', 'Public speaking events']
        },
        'Active': {
            'Synonyms': ['Energetic', 'Vivacious', 'Dynamic'],
            'Verbs': ['Move energetically', 'Act dynamically', 'Perform actively'],
            'Nouns': ['Sports', 'Dance events', 'Gym sessions']
        },
        'Talkative': {
            'Synonyms': ['Loquacious', 'Chatty', 'Communicative'],
            'Verbs': ['Speak freely', 'Converse openly', 'Communicate effectively'],
            'Nouns': ['Conversations', 'Dialogues', 'Discussions']
        },
        'Adventurous': {
            'Synonyms': ['Daring', 'Bold', 'Fearless'],
            'Verbs': ['Explore bravely', 'Try new things', 'Venture out'],
            'Nouns': ['Adventures', 'Expeditions', 'Challenges']
        },
        'Fun-loving': {
            'Synonyms': ['Playful', 'Cheerful', 'Joyful'],
            'Verbs': ['Enjoy life', 'Play gleefully', 'Celebrate often'],
            'Nouns': ['Parties', 'Games', 'Festivals']
        }
    },
    'Introversion': {
        'Reserved': {
            'Synonyms': ['Restrained', 'Quiet', 'Withdrawn'],
            'Verbs': ['Keep to oneself', 'Stay reserved', 'Limit social interactions'],
            'Nouns': ['Quiet places', 'Private settings', 'Solitary activities']
        },
        'Reflective': {
            'Synonyms': ['Thoughtful', 'Contemplative', 'Introspective'],
            'Verbs': ['Think deeply', 'Reflect regularly', 'Consider thoughtfully'],
            'Nouns': ['Journals', 'Quiet times', 'Reflection sessions']
        },
        'Peaceful': {
            'Synonyms': ['Calm', 'Tranquil', 'Serene'],
            'Verbs': ['Maintain calm', 'Seek peace', 'Embrace tranquility'],
            'Nouns': ['Nature walks', 'Quiet mornings', 'Peaceful evenings']
        },
        'Independent': {
            'Synonyms': ['Self-reliant', 'Self-sufficient', 'Autonomous'],
            'Verbs': ['Operate independently', 'Rely on oneself', 'Manage alone'],
            'Nouns': ['Solo projects', 'Independent tasks', 'Self-employment']
        },
        'Quiet': {
            'Synonyms': ['Hushed', 'Silent', 'Low-key'],
            'Verbs': ['Speak softly', 'Reduce noise', 'Maintain silence'],
            'Nouns': ['Libraries', 'Study rooms', 'Quiet zones']
        },
        'Deliberate': {
            'Synonyms': ['Thoughtful', 'Intentional', 'Careful'],
            'Verbs': ['Plan carefully', 'Act intentionally', 'Consider consequences'],
            'Nouns': ['Strategic plans', 'Careful decisions', 'Thoughtful gestures']
        }
    },
    'Neuroticism': {
        'Anxious': {
            'Synonyms': ['Worried', 'Uneasy', 'Apprehensive'],
            'Verbs': ['Worry often', 'Feel uneasy', 'Express anxiety'],
            'Nouns': ['Anxiety triggers', 'Stressful situations', 'Worrisome thoughts']
        },
        'Irritable': {
            'Synonyms': ['Grumpy', 'Impatient', 'Crabby'],
            'Verbs': ['Get irritated easily', 'Show impatience', 'React quickly'],
            'Nouns': ['Traffic jams', 'Long lines', 'Waiting times']
        },
        'Moody': {
            'Synonyms': ['Temperamental', 'Changeable', 'Mercurial'],
            'Verbs': ['Change moods often', 'Display emotions', 'React spontaneously'],
            'Nouns': ['Emotional swings', 'Unpredictable days', 'Moody episodes']
        },
        'Tense': {
            'Synonyms': ['Tight', 'Rigid', 'Stressed'],
            'Verbs': ['Feel tensed', 'Hold stress', 'React sharply'],
            'Nouns': ['High-pressure situations', 'Stressful meetings', 'Tight deadlines']
        },
        'Frustrated': {
            'Synonyms': ['Disappointed', 'Dissatisfied', 'Unfulfilled'],
            'Verbs': ['Express frustration', 'Feel dissatisfaction', 'React to setbacks'],
            'Nouns': ['Failed attempts', 'Unmet goals', 'Thwarted plans']
        },
        'Over-sensitive': {
            'Synonyms': ['Touchy', 'Thin-skinned', 'Delicate'],
            'Verbs': ['Take offense easily', 'React sensitively', 'Feel deeply'],
            'Nouns': ['Critical comments', 'Harsh feedback', 'Sensitive topics']
        }
    },
    'Stability': {
        'Calm': {
            'Synonyms': ['Relaxed', 'Composed', 'Unruffled'],
            'Verbs': ['Stay calm', 'Maintain composure', 'Handle stress well'],
            'Nouns': ['Relaxing environments', 'Calm situations', 'Stress-free zones']
        },
        'Even-tempered': {
            'Synonyms': ['Balanced', 'Steady', 'Placid'],
            'Verbs': ['Keep an even keel', 'Balance emotions', 'React calmly'],
            'Nouns': ['Balanced discussions', 'Steady relationships', 'Even interactions']
        },
        'Contented': {
            'Synonyms': ['Satisfied', 'Gratified', 'Pleased'],
            'Verbs': ['Feel content', 'Show satisfaction', 'Live gratifyingly'],
            'Nouns': ['Contented living', 'Satisfactory outcomes', 'Gratifying experiences']
        },
        'Patient': {
            'Synonyms': ['Tolerant', 'Forbearing', 'Understanding'],
            'Verbs': ['Practice patience', 'Exhibit tolerance', 'Show forbearance'],
            'Nouns': ['Waiting periods', 'Patient practices', 'Tolerance tests']
        },
        'Reliable': {
            'Synonyms': ['Dependable', 'Trustworthy', 'Consistent'],
            'Verbs': ['Prove reliability', 'Act dependably', 'Maintain consistency'],
            'Nouns': ['Reliable services', 'Dependable systems', 'Consistent performance']
        },
        'Peaceful': {
            'Synonyms': ['Tranquil', 'Calm', 'Serene'],
            'Verbs': ['Live peacefully', 'Promote tranquility', 'Foster serenity'],
            'Nouns': ['Peaceful retreats', 'Tranquil spaces', 'Serene atmospheres']
        }
    },
    'Psychoticism': {
        'Aggressive': {
            'Synonyms': ['Hostile', 'Forceful', 'Belligerent'],
            'Verbs': ['Confront', 'Dominate', 'Assert power'],
            'Nouns': ['Fights', 'Arguments', 'Conflicts']
        },
        'Impersonal': {
            'Synonyms': ['Detached', 'Unemotional', 'Aloof'],
            'Verbs': ['Disengage', 'Remain indifferent', 'Avoid emotional involvement'],
            'Nouns': ['Distant relationships', 'Objective discussions', 'Non-personal interactions']
        },
        'Antisocial': {
            'Synonyms': ['Unfriendly', 'Withdrawn', 'Apathetic'],
            'Verbs': ['Avoid social norms', 'Reject rules', 'Ignore social cues'],
            'Nouns': ['Isolated lifestyles', 'Nonconformist behaviors', 'Solitary habits']
        },
        'Unemotional': {
            'Synonyms': ['Cold', 'Indifferent', 'Unfeeling'],
            'Verbs': ['Suppress emotions', 'Remain stoic', 'Detach emotionally'],
            'Nouns': ['Lack of empathy', 'Emotionless responses', 'Indifferent attitudes']
        },
        'Creative': {
            'Synonyms': ['Inventive', 'Imaginative', 'Original'],
            'Verbs': ['Innovate', 'Experiment', 'Think outside the box'],
            'Nouns': ['Artistic endeavors', 'Unique solutions', 'Groundbreaking ideas']
        },
        'Rebellious': {
            'Synonyms': ['Defiant', 'Resistant', 'Nonconformist'],
            'Verbs': ['Challenge authority', 'Reject traditions', 'Defy expectations'],
            'Nouns': ['Protests', 'Revolutions', 'Countercultural movements']
        }
    }
}

# Create a list to store the dataset
data = []
for factor, attributes in epm_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
epm_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/epm.csv"

# Start an MLflow run
with mlflow.start_run(run_name="EPM Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "EPM")
    mlflow.log_param("Total Rows", len(epm_df))
    mlflow.log_param("Total Factors", len(epm_dataset))
    mlflow.log_param("Data Schema", str(epm_df.columns.tolist()))

    # Save dataset to CSV
    epm_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data") # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ EPM dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(epm_df.head())
    print("\nDataset shape:", epm_df.shape)
    print("\nNumber of unique Factors:", epm_df['Factor'].nunique())
    print("Unique Factors:", epm_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# ✅ EPM dataset created and saved to ../Datasets/epm.csv
# First 5 rows of the dataset:
#          Factor  Adjective     Synonym                              Verb  \
# 0  Extraversion   Sociable  Gregarious                   Engage socially
# 1  Extraversion   Sociable    Outgoing                 Interact joyfully
# 2  Extraversion   Sociable    Friendly  Participate in social activities
# 3  Extraversion  Assertive   Confident                     State clearly
# 4  Extraversion  Assertive    Dominant              Command respectfully
#
#                 Noun
# 0            Parties
# 1  Social gatherings
# 2            Meetups
# 3            Debates
# 4   Leadership roles
#
# Dataset shape: (90, 5)
#
# Number of unique Factors: 5
# Unique Factors: ['Extraversion' 'Introversion' 'Neuroticism' 'Stability' 'Psychoticism']
# 📌 MLflow tracking active under experiment 'EPM' (ID: 5)
# 🏃 View run EPM Dataset Creation at: http://127.0.0.1:5000/#/experiments/5/runs/3845a6ca29d84a409e6943d75bb70e47
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="epm_page_2"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/5/runs/031e6eaae87f4ff5b4fdced8490f1814
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="epm_page_2"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018396804109215736, -0.007225503213703632, 0.003625439014285803, -0.05420079082250595, -0.022697849199175835, 0.03697123005986214, 0.029028886929154396, 0.02390315756201744, 0.011228393763303757, -0.020642481744289398]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/5/runs/ba208798c838438d87c397150675e8ba
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create EPM Embeddings** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved epm dataset from a CSV file
dataset_path = '../Datasets/epm.csv'
try:
    epm_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'epm_df' is empty before processing
        if epm_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", epm_df.shape[0])
            print(f"📊 Processing {epm_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        epm_df['Embedding'] = epm_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/epm_embeddings.csv'
        epm_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = epm_df.shape[0]
        num_columns = epm_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in epm_df.columns and not epm_df['Embedding'].empty:
            embedding_length = len(epm_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(epm_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/epm.csv
# ⏳ Embedding generation started at: 2025-03-16 10:27:40.805102
# 📊 Processing 90 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-16 10:28:07.760318 (Duration: 0:00:26.955216)
# 💾 Embeddings saved to: ../Embeddings/epm_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#          Factor  Adjective     Synonym                              Verb  \
# 0  Extraversion   Sociable  Gregarious                   Engage socially
# 1  Extraversion   Sociable    Outgoing                 Interact joyfully
# 2  Extraversion   Sociable    Friendly  Participate in social activities
# 3  Extraversion  Assertive   Confident                     State clearly
# 4  Extraversion  Assertive    Dominant              Command respectfully
#
#                 Noun                                          Embedding
# 0            Parties  [-0.004787823185324669, -0.043590739369392395,...
# 1  Social gatherings  [0.004578143823891878, -0.03912104666233063, 0...
# 2            Meetups  [-0.02574155665934086, -0.04326540604233742, 0...
# 3            Debates  [0.028135675936937332, -0.0337313748896122, 0....
# 4   Leadership roles  [0.01175365224480629, -0.02560514397919178, 0....
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5000/#/experiments/5/runs/c76316f398384e94964cb8400e429871
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/epm_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/epm_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "epm_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/epm_embeddings.csv
# 💾 Label encoder saved to: ../Models/epm_label_encoder.pkl
#
# First 5 rows with encoded labels:
#          Factor  Factor_Encoded
# 0  Extraversion               0
# 1  Extraversion               0
# 2  Extraversion               0
# 3  Extraversion               0
# 4  Extraversion               0
#
# Mapping of original labels to encoded labels:
# Extraversion: 0
# Introversion: 1
# Neuroticism: 2
# Psychoticism: 3
# Stability: 4
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/epm_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: epm_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/5/runs/fdb7fe44026f4f52861f0b1a9a7e2ae4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/epm_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/epm_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="epm Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "epm_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "epm_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "epm_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/epm_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/epm_embeddings.csv
# ✅ Label encoder loaded from: ../Models/epm_label_encoder.pkl
# ⏳ Model training started at: 2025-03-16 11:01:29.545894
# ✅ Model training finished at: 2025-03-16 11:01:29.726980 (Duration: 0:00:00.181086)
# 📊 Classification report saved to: epm_classification_report.csv
# 📊 Confusion matrix saved to: epm_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: epm_confusion_matrix.png
# 💾 Trained model saved to: ../Models/epm_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Extraversion       1.00      1.00      1.00         4
# Introversion       1.00      1.00      1.00         3
#  Neuroticism       1.00      1.00      1.00         4
# Psychoticism       1.00      1.00      1.00         4
#    Stability       1.00      1.00      1.00         3
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
#
# Confusion Matrix:
#                Extraversion  Introversion  Neuroticism  Psychoticism  Stability
# Extraversion             4             0            0             0          0
# Introversion             0             3            0             0          0
# Neuroticism              0             0            4             0          0
# Psychoticism             0             0            0             4          0
# Stability                0             0            0             0          3
# 🏃 View run epm Model Training and Evaluation Workflow at: http://127.0.0.1:5000/#/experiments/5/runs/d59716405514466b8eeaae6086993dc2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/epm_embeddings.csv'
label_encoder_path = "../Models/epm_label_encoder.pkl"
model_path = "../Models/epm_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate EPM Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate EPM Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "epm_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "epm_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "epm_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ EPM Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/epm_embeddings.csv
# ✅ Label encoder loaded from: ../Models/epm_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/epm_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: evaluation_classification_report.csv
#
# Classification Report:
#                precision    recall  f1-score   support
#
# Extraversion       1.00      1.00      1.00         4
# Introversion       1.00      1.00      1.00         3
#  Neuroticism       1.00      1.00      1.00         4
# Psychoticism       1.00      1.00      1.00         4
#    Stability       1.00      1.00      1.00         3
#
#     accuracy                           1.00        18
#    macro avg       1.00      1.00      1.00        18
# weighted avg       1.00      1.00      1.00        18
#
# 📊 Confusion matrix saved to: evaluation_confusion_matrix.csv
#
# Confusion Matrix:
#                Extraversion  Introversion  Neuroticism  Psychoticism  Stability
# Extraversion             4             0            0             0          0
# Introversion             0             3            0             0          0
# Neuroticism              0             0            4             0          0
# Psychoticism             0             0            0             4          0
# Stability                0             0            0             0          3
# 🖼️ Confusion matrix plot saved to: epm_evaluation_confusion_matrix.png
# 🏃 View run Evaluate EPM Model at: http://127.0.0.1:5000/#/experiments/5/runs/e44232757f244b338b7f8405de004eb9
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
#
# ✅ Model evaluation on the test set complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/epm_label_encoder.pkl"
model_path = "../Models/epm_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/epm_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/epm_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Extraversion
# Predicted Factor for 'I prefer staying home with a good book....': Introversion
# Predicted Factor for 'I often feel anxious and worried....': Neuroticism
# Predicted Factor for 'I am generally calm and relaxed....': Stability
# Predicted Factor for 'I enjoy taking risks and trying new things....': Extraversion
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/5/runs/ef8d773ca8e24bcc8918c8ae68989408
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/epm_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="EPM Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/epm_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "epm_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/epm_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of EPM Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/epm_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of EPM Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/16 11:40:17 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Extraversion
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Stability
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Extraversion
# Predicted Factor for 'Organized Meticulous Plan Planner': Stability
# Predicted Factor for 'Moody Anxious Worry Worrier': Neuroticism
# 🏃 View run EPM Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/5/runs/15eab52557364d87a6549ef55b7d0f8a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/epm_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/epm_label_encoder.pkl"
        model_path = "../Models/epm_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of EPM Embeddings")

            # Save and log the plot
            pca_plot_path = "epm_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "epm_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/epm_embeddings.csv
#
# DataFrame with Embeddings:
#          Factor  Adjective     Synonym                              Verb  \
# 0  Extraversion   Sociable  Gregarious                   Engage socially
# 1  Extraversion   Sociable    Outgoing                 Interact joyfully
# 2  Extraversion   Sociable    Friendly  Participate in social activities
# 3  Extraversion  Assertive   Confident                     State clearly
# 4  Extraversion  Assertive    Dominant              Command respectfully
#
#                 Noun                                          Embedding
# 0            Parties  [-0.004787823185324669, -0.043590739369392395,...
# 1  Social gatherings  [0.004578143823891878, -0.03912104666233063, 0...
# 2            Meetups  [-0.02574155665934086, -0.04326540604233742, 0...
# 3            Debates  [0.028135675936937332, -0.0337313748896122, 0....
# 4   Leadership roles  [0.01175365224480629, -0.02560514397919178, 0....
#
# Shape of DataFrame:
# (90, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [-0.00478782 -0.04359074  0.00065463 ... -0.00975825  0.01843549
#   0.01693085]
# ✅ Label encoder loaded from: ../Models/epm_label_encoder.pkl
#
# Shape of X:
# (90, 1536)
# ✅ PCA visualization saved to: epm_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: epm_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Extraversion
# 🏃 View run Step 8: Model Application, Visualization, and Analysis at: http://127.0.0.1:5000/#/experiments/5/runs/c572b0aca0344aafa614707d6c63fefc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
#
# ✅ Step 8: Model Application, Visualization, and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean cross-validation score: 1.0

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="epm_page_3"></a>
#
# [Back to Top](#epm_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/epm_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_epm.pkl')
clf = joblib.load('../Models/epm_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Extraversion
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Stability
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Extraversion
# Predicted Factor for 'Organized Meticulous Plan Planner': Neuroticism
# Predicted Factor for 'Moody Anxious Worry Worrier': Neuroticism
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Psychoticism

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Extraversion

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Neuroticism

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Neuroticism

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Stability

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Psychoticism

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="EPM_page_4"></a>
#
#
# [Back to Top](#EPM_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("EPM")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/5/runs/4183ac2e4aab4b0ab06c9b63c8ba354b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create EPM Schema in Neo4j** <a class="anchor" id="EPM_page_4"></a>
#
#
# [Back to Top](#EPM_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("EPM")

# Load the dataset
dataset_path = "../Embeddings/epm_embeddings.csv"
epm_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in epm_df.columns:
    epm_df['Embedding'] = epm_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the EPM schema in Neo4j
def create_epm_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with EPM labels
        graph.run("MERGE (f:EPM_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:EPM_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:EPM_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:EPM_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:EPM_Noun {name: $noun})", noun=noun)
        
        # Create relationships with EPM namespacing
        graph.run("""
            MATCH (f:EPM_Factor {name: $factor}), (a:EPM_Adjective {name: $adjective})
            MERGE (f)-[:EPM_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:EPM_Adjective {name: $adjective}), (s:EPM_Synonym {name: $synonym})
            MERGE (a)-[:EPM_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:EPM_Adjective {name: $adjective}), (v:EPM_Verb {name: $verb})
            MERGE (a)-[:EPM_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:EPM_Adjective {name: $adjective}), (n:EPM_Noun {name: $noun})
            MERGE (a)-[:EPM_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:EPM_Factor {name: $factor}), (a:EPM_Adjective {name: $adjective})
                MERGE (e:EPM_Embedding {value: $embedding})
                MERGE (f)-[:EPM_HAS_EMBEDDING]->(e)
                MERGE (a)-[:EPM_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create EPM Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create EPM Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the EPM schema
        create_epm_schema(graph, epm_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", epm_df.shape[0])
        mlflow.log_param("Number of Columns", epm_df.shape[1])
        
        # Print the DataFrame
        print(epm_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#          Factor  Adjective     Synonym                              Verb  \
# 0  Extraversion   Sociable  Gregarious                   Engage socially
# 1  Extraversion   Sociable    Outgoing                 Interact joyfully
# 2  Extraversion   Sociable    Friendly  Participate in social activities
# 3  Extraversion  Assertive   Confident                     State clearly
# 4  Extraversion  Assertive    Dominant              Command respectfully
#
#                 Noun                                          Embedding
# 0            Parties  [-0.004787823185324669, -0.043590739369392395,...
# 1  Social gatherings  [0.004602143075317144, -0.03911646082997322, 0...
# 2            Meetups  [-0.02574155665934086, -0.04326540604233742, 0...
# 3            Debates  [0.028135675936937332, -0.0337313748896122, 0....
# 4   Leadership roles  [0.01175365224480629, -0.02560514397919178, 0....
# 🏃 View run Create EPM Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/5/runs/e35ad8062eb64ad7b990466f0e54efad
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/5
