# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## 16 Personality Factors (16PF)<a class="anchor" id="PTMD_page_6"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# ## **Journey through the 16 Personality Factors (16PF)**
#
# In the vast landscape of personality psychology, the 16 Personality Factors (16PF) model stands as a rich and comprehensive map, guiding us through the intricate terrain of human temperament. Developed by the eminent psychologist Raymond B. Cattell and his colleagues, this model is a testament to the depth and breadth of our understanding of human personality.
#
# **Meet the Architects:**
# Raymond B. Cattell, along with his colleagues, paved the way for a deeper exploration of human personality. Born in 1905 in England, Cattell's lifelong fascination with understanding what makes us who we are led to the creation of the 16PF model. His pioneering work in the field of psychology continues to shape our understanding of personality to this day.
#
# The 16PF model is a comprehensive system that captures the multifaceted nature of human character. Rather than reducing personality to a few broad traits, it delves into 16 primary factors, each representing a unique facet of our individuality. These factors include:
#
# 1. **Warmth**: This dimension explores one's level of warmth and affection towards others.
#
# 2. **Reasoning**: It reflects the extent to which a person relies on rational thinking.
#
# 3. **Emotional Stability**: This factor delves into emotional resilience and stability in the face of challenges.
#
# 4. **Dominance**: It measures one's inclination to assert control and influence over their surroundings.
#
# 5. **Liveliness**: This factor examines one's energy level and enthusiasm for life.
#
# 6. **Rule-Consciousness**: It assesses the degree to which an individual values and adheres to rules and structure.
#
# 7. **Social Boldness**: This dimension explores a person's level of comfort in social situations and their inclination to take risks.
#
# 8. **Sensitivity**: It measures how keenly an individual perceives and reacts to emotional cues from others.
#
# 9. **Vigilance**: This factor reflects one's attentiveness to potential threats and dangers in their environment.
#
# 10. **Abstractedness**: It assesses a person's tendency to think in abstract or concrete terms.
#
# 11. **Privateness**: This dimension explores the extent to which an individual is open about their inner thoughts and feelings.
#
# 12. **Apprehension**: It delves into one's level of anxiety and apprehension in challenging situations.
#
# 13. **Openness to Change**: This factor measures a person's adaptability and willingness to embrace change.
#
# 14. **Self-Reliance**: It examines the degree to which an individual relies on themselves rather than seeking external validation.
#
# 15. **Perfectionism**: This dimension explores the pursuit of excellence and precision in one's endeavors.
#
# 16. **Tension**: It reflects the level of inner turmoil and stress experienced by an individual.
#
# Each of these factors adds a layer to the intricate tapestry of an individual's personality, painting a more nuanced and complete picture. The 16PF model reminds us that human personality is not a monolithic structure but a symphony of various elements, each contributing to the unique melody that is you.
#
# As you explore the 16PF model, remember the pioneering spirit of Raymond B. Cattell and his colleagues. Their dedication to unraveling the complexities of human personality has illuminated our understanding and continues to guide our journey through the fascinating world of psychology.
#
# To provide a complete and accurate 16 Personality Factors (16PF) Timeline Reference Table, I'll list significant references and milestones in the development of the 16PF model. However, please note that the information might be slightly dated as my last training data includes information only up to April 2023.
#
# ### Significant References for the 16 Personality Factors (16PF)
#
# 1. **1949**: Raymond Cattell's early research leading to the development of the 16PF.
# 2. **1956**: First publication of the 16PF Questionnaire by Raymond Cattell.
# 3. **1963**: "Handbook for the Sixteen Personality Factor Questionnaire (16PF)" by Raymond Cattell, providing comprehensive guidance on the use of the 16PF.
# 4. **1970**: Subsequent revisions and validations of the 16PF Questionnaire to improve reliability and validity.
# 5. **1993**: "The 16PF Fifth Edition Technical Manual" by R.B. Cattell, A.K.S. Cattell, and H.E.P. Cattell, offering an updated version of the questionnaire with technical advancements.
# 6. **2002 and beyond**: Further research and applications of the 16PF in various fields such as occupational, educational, and clinical psychology.
#
# Here's the HTML table converted into a markdown format:
#
# ### 16PF Timeline Reference Table
#
# | Year        | Milestone                                                | Contributor(s)                          | Original Work Reference                                                                  | Contribution Reference                                         | Additional Information                                             |
# |-------------|----------------------------------------------------------|-----------------------------------------|-----------------------------------------------------------------------------------------|---------------------------------------------------------------|-------------------------------------------------------------------|
# | 1949        | Initial development of the 16PF Questionnaire.           | Raymond Cattell                         | Cattell, R. B. (1949). The Dimensions of Culture Patterns by Factor Analysis of Their Aspects. | Introduction of the 16 personality factors.                    | Laid the groundwork for the 16PF Questionnaire.                    |
# | 1956        | First publication of the 16PF Questionnaire.             | Raymond Cattell                         | Cattell, R. B. (1956). The 16 Personality Factor Questionnaire.                          | Formal introduction of the questionnaire for practical use.    | Marked the first use of the 16PF in psychological assessment.      |
# | 1963        | Publication of the 16PF Handbook.                        | Raymond Cattell                         | Cattell, R. B. (1963). Handbook for the Sixteen Personality Factor Questionnaire (16PF). | Provided comprehensive guidance on the 16PF.                   | Significantly contributed to the understanding and application of the 16PF. |
# | 1970s       | Revisions and validations of the 16PF.                   | Raymond Cattell and colleagues          | Various publications.                                                                    | Enhanced the reliability and validity of the 16PF.             | Important for the ongoing development of the model.               |
# | 1993        | Release of the 16PF Fifth Edition Technical Manual.      | R.B. Cattell, A.K.S. Cattell, H.E.P. Cattell | Cattell, R.B., Cattell, A.K.S., & Cattell, H.E.P. (1993). The 16PF Fifth Edition Technical Manual. | Update and revision of the 16PF questionnaire and its manual. | Introduced technical advancements and modernizations in the questionnaire. |
# | 2002 - Present | Ongoing research and applications in various fields.   | Various Researchers                      | Multiple publications.                                                                    | Continued exploration and application in diverse areas.        | Includes modern research, adaptations, and findings in various contexts. |
#
# This table uses markdown syntax to format the data from the HTML table into a more text-based representation suitable for markdown environments like GitHub or other platforms that support markdown rendering.
#
#
# ## **Sixteen Personality Factor (16PF) References**
#
# | Ref | Author(s) | Year | Title | Journal | Volume and Pages | DOI |
# |-----|----------------------|------|-------|------------------|-----------------|-----|
# | 141 | Bryan Mershon, R. Gorsuch                            | 1988 | Number of Factors in the Personality Sphere: Does Increase in Factors Increase Predictability of Real-Life Criteria? | Journal of Personality and Social Psychology | 55, 675-680 | [10.1037/0022-3514.55.4.675](https://doi.org/10.1037/0022-3514.55.4.675) |
# | 142 | D. Gerbing, M. Tuley                                  | 1991 | The 16PF Related to the Five-Factor Model of Personality: Multiple-Indicator Measurement versus the A Priori Scales. | Multivariate behavioral research | 26, 271-89 | [10.1207/s15327906mbr2602_5](https://doi.org/10.1207/s15327906mbr2602_5) |
# | 143 | G. Saucier                                           | 1992 | Openness versus intellect: Much ado about nothing? | European Journal of Personality | 6, 381 - 386 | [10.1002/per.2410060506](https://doi.org/10.1002/per.2410060506) |
# | 144 | R. McCrae, O. John                                    | 1992 | An introduction to the five-factor model and its applications. | Journal of personality | 60 2, 175-215 | [10.1111/J.1467-6494.1992.TB00970.X](https://doi.org/10.1111/J.1467-6494.1992.TB00970.X) |
# | 145 | L. R. Goldberg | 1993 | The structure of personality traits: Vertical and horizontal aspects. | - | - | [10.1037/10127-024](https://doi.org/10.1037/10127-024) |
# | 146   | G. Saucier, L. R. Goldberg                          | 1996 | Evidence for the Big Five in analyses of familiar English personality adjectives | European Journal of Personality | 10, 61 - 77 | [10.1002/(SICI)1099-0984(199603)10:1<61::AID-PER246>3.0.CO;2-D](https://doi.org/10.1002/(SICI)1099-0984(199603)10:1<61::AID-PER246>3.0.CO;2-D) |
# | 147 | J. Wiggins, P. Trapnell                               | 1997 | Personality Structure: The Return of the Big Five | - | - | [10.1016/B978-012134645-4/50029-9](https://doi.org/10.1016/B978-012134645-4/50029-9) |
# | 148 | James McKenzie, G. Tindell, J. French                 | 1997 | The great triumvirate: Agreement between lexically and psycho-physiologically based models of personality | Personality and Individual Differences | 22, 269-277 | [10.1016/S0191-8869(96)00184-5](https://doi.org/10.1016/S0191-8869(96)00184-5) |
# | 149 | S. Hofer, J. Horn, H. Eber | 1997 | A robust five-factor structure of the 16PF : Strong evidence from independent rotation and confirmatory factorial invariance procedures | Personality and Individual Differences | 23, 247-269 | [10.1016/S0191-8869(97)00025-1](https://doi.org/10.1016/S0191-8869(97)00025-1) |
# | 150 | G. Saucier | 1997 | Effects of variable selection on the factor structure of person descriptors. | Journal of personality and social psychology | 73 6, 1296-312 | [10.1037/0022-3514.73.6.1296](https://doi.org/10.1037/0022-3514.73.6.1296) |
# | 151 | G. Saucier, L. R. Goldberg                            | 1998 | What is beyond the big five? | Journal of personality | 66 4, 495-524 | [10.1111/1467-6494.00022](https://doi.org/10.1111/1467-6494.00022) |
# | 152 | B. D. Raad, M. Perugini, M. Hřebíčková, P. Szarota    | 1998 | Lingua Franca of Personality | Journal of Cross-Cultural Psychology | 29, 212 - 232 | [10.1177/0022022198291011](https://doi.org/10.1177/0022022198291011) |
# | 153 | James McKenzie | 1998 | Fundamental flaws in the five factor model: A re-analysis of the seminal correlation matrix from which the “openness-to-experience” factor was extracted | Personality and Individual Differences | 24, 475-480 | [10.1016/S0191-8869(97)00223-7](https://doi.org/10.1016/S0191-8869(97)00223-7) |
# | 154 | O. Somer, L. R. Goldberg | 1999 | The structure of Turkish trait-descriptive adjectives. | Journal of personality and social psychology | 76 3, 431-50 | [10.1037//0022-3514.76.3.431](https://doi.org/10.1037//0022-3514.76.3.431) |
# | 155 | L. Blas, M. Forzi                                    | 1999 | Refining a descriptive structure of personality attributes in the Italian language: The abridged Big Three circumplex structure. | Journal of Personality and Social Psychology | 76, 451-481 | [10.1037/0022-3514.76.3.451](https://doi.org/10.1037/0022-3514.76.3.451) |
# | 156 | G. Saucier, F. Ostendorf                             | 1999 | Hierarchical subcomponents of the Big Five personality factors: a cross-language replication. | Journal of personality and social psychology | 76 4, 613-27 | [10.1037/0022-3514.76.4.613](https://doi.org/10.1037/0022-3514.76.4.613) |
# | 157 | G. Saucier, L. R. Goldberg, O. R. Institute          | 2001 | Lexical studies of indigenous personality factors: premises, products, and prospects. | Journal of personality | 69 6, 847-79 | [10.1111/1467-6494.696167](https://doi.org/10.1111/1467-6494.696167) |
# | 158 | J. Rolland                                            | 2002 | The Cross-Cultural Generalizability of the Five-Factor Model of Personality | - | - | [10.1007/978-1-4615-0763-5_2](https://doi.org/10.1007/978-1-4615-0763-5_2) |
# | 159 | G. Saucier | 2002 | The substantive nature of psycholexical personality factors: a comparison across languages. | Journal of personality and social psychology | 83 4, 983-97 | [10.1037/0022-3514.83.4.983](https://doi.org/10.1037/0022-3514.83.4.983) |
# | 160 | Eileen Algeo et al. | 2003 | College Students' Social and Academic Behaviors and Scores on the Five Factors: Are Personality Measures Predictive of Campus Functioning?. | - | - | - |
# | 161 | M. Hersen                                             | 2004 | Comprehensive handbook of psychological assessment | - | - | [10.5860/choice.42-1239](https://doi.org/10.5860/choice.42-1239) |
# | 162 | J. Rossier et al.                                    | 2004 | The Hierarchical Structures of the NEO PI-R and the 16PF5. | European Journal of Psychological Assessment | 20, 27-38 | [10.1027/1015-5759.20.1.27](https://doi.org/10.1027/1015-5759.20.1.27) |
# | 163 | B. Roberts et al.                                    | 2004 | A lexical investigation of the lower-order structure of conscientiousness. | Journal of Research in Personality | 38, 164-178 | [10.1016/S0092-6566(03)00065-5](https://doi.org/10.1016/S0092-6566(03)00065-5) |
# | 164 | Boris Mlacic, F. Ostendorf | 2005 | Taxonomy and structure of Croatian personality‐descriptive adjectives | European Journal of Personality | 19, 117 - 152 | [10.1002/per.539](https://doi.org/10.1002/per.539) |
# | 165 | G. Saucier et al. | 2005 | The factor structure of Greek personality adjectives. | Journal of personality and social psychology | 88 5, 856-75 | [10.1037/0022-3514.88.5.856](https://doi.org/10.1037/0022-3514.88.5.856) |
# | 166 | J. Rossier et al. | 2005 | Structural and Mean-Level Analyses of the Five-Factor Model and Locus of Control | Journal of Cross-Cultural Psychology | 36, 227 - 246 | [10.1177/0022022104272903](https://doi.org/10.1177/0022022104272903) |
# | 167 | Boele de Raad, D. Peabody | 2005 | Cross‐culturally recurrent personality factors: analyses of three factors | European Journal of Personality | 19, 451 - 474 | [10.1002/per.550](https://doi.org/10.1002/per.550) |
# | 168 | A. Aluja et al.                                      | 2005 | The 16PF5 and the NEO-PI-R in Spanish and Swiss Samples: A Cross-Cultural Comparison | Journal of Individual Differences | 26, 53-62 | [10.1027/1614-0001.26.2.53](https://doi.org/10.1027/1614-0001.26.2.53) |
# | 169   | A. Aluja, J. Rossier, L. F. García, Sabrina Verardi | 2005 | The 16 PF 5 and the NEO-PIR in Spanish and Swiss Samples: A Cross-Cultural Comparison | - | - | - |
# | 170   | H. Cattell, A. Mead                                 | 2008 | The Sixteen Personality Factor Questionnaire (16PF) | - | - | [10.4135/9781849200479.N7](https://doi.org/10.4135/9781849200479.N7) |
# | 171 | Laura Wright                                         | 2008 | A Comparison of Big Five and Narrow Personality Traits In Relation to Academic Performance | - | - | - |
# | 172 | G. Boyle                                             | 2008 | Critique of the five-factor model of personality | - | - | [10.4135/9781849200462.N14](https://doi.org/10.4135/9781849200462.N14) |
# | 173 | Boele de Raad, D. Barelds                            | 2008 | A new taxonomy of Dutch personality traits based on a comprehensive and unrestricted list of descriptors. | Journal of personality and social psychology | 94 2, 347-64 | [10.1037/0022-3514.94.2.347](https://doi.org/10.1037/0022-3514.94.2.347) |
# | 174 | G. Saucier                                           | 2009 | What Are the Most Important Dimensions of Personality?Evidence from Studies of Descriptors in Diverse Languages | Social and Personality Psychology Compass | 3, 620-637 | [10.1111/J.1751-9004.2009.00188.X](https://doi.org/10.1111/J.1751-9004.2009.00188.X) |
# | 175 | G. Saucier | 2009 | Recurrent personality dimensions in inclusive lexical studies: indications for a big six structure. | Journal of personality | 77 5, 1577-614 | [10.1111/j.1467-6494.2009.00593.x](https://doi.org/10.1111/j.1467-6494.2009.00593.x) |
# | 176 | Boele de Raad et al.                                 | 2010 | Only three factors of personality description are fully replicable across languages: a comparison of 14 trait taxonomies. | Journal of personality and social psychology | 98 1, 160-73 | [10.1037/a0017184](https://doi.org/10.1037/a0017184) |
# | 177 | C. Watkins, V. L. Campbell                            | 2012 | The Sixteen Personality Factor Questionnaire (16PF) | - | - | [10.4324/9781410604323-10](https://doi.org/10.4324/9781410604323-10) |
# | 178 | M. Cornwell, Dion Greenidge                          | 2017 | The Sixteen-Factor Model of Personality | - | - | [10.1007/978-3-319-28099-8_1266-1](https://doi.org/10.1007/978-3-319-28099-8_1266-1) |
# | 179 | Stephanie N. Means | 2017 | Investigating Personality Traits of Registered Nurses: Implications for Personnel Evaluation | - | - | - |
# | 180 | M. Cornwell, Dion Greenidge                          | 2020 | Sixteen-Factor Model of Personality, The | Encyclopedia of Personality and Individual Differences | - | [10.1007/978-3-319-24612-3_1266](https://doi.org/10.1007/978-3-319-24612-3_1266) |
#
#
# This table aims to provide a comprehensive overview of the development and evolution of the 16PF model, highlighting key milestones, contributors, and their significant works. Each entry includes the year, a brief description of the milestone, the main contributors, the original works and contributions, additional notes for context, and the DOI when available. This format offers an informative and structured overview of the historical and academic journey of the 16PF model.
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %%
import pandas as pd

sixteen_pf_dataset = {
    'Warmth': {
        'Affectionate': {
            'Synonyms': ['Loving', 'Tender', 'Fond'],
            'Verbs': ['Cherish', 'Adore', 'Embrace'],
            'Nouns': ['Affection', 'Tenderness', 'Fondness']
        },
        'Appreciative': {
            'Synonyms': ['Grateful', 'Thankful', 'Pleased'],
            'Verbs': ['Value', 'Praise', 'Appreciate'],
            'Nouns': ['Appreciation', 'Gratitude', 'Thankfulness']
        },
        'Generous': {
            'Synonyms': ['Bountiful', 'Benevolent', 'Liberal'],
            'Verbs': ['Give', 'Donate', 'Contribute'],
            'Nouns': ['Generosity', 'Benevolence', 'Liberalness']
        },
        'Attentive': {
            'Synonyms': ['Observant', 'Aware', 'Heedful'],
            'Verbs': ['Attend', 'Monitor', 'Notice'],
            'Nouns': ['Attention', 'Awareness', 'Mindfulness']
        }
    },
    'Reasoning': {
        'Logical': {
            'Synonyms': ['Rational', 'Analytical', 'Cogent'],
            'Verbs': ['Reason', 'Analyze', 'Infer'],
            'Nouns': ['Logic', 'Rationality', 'Analysis']
        },
        'Intelligent': {
            'Synonyms': ['Smart', 'Bright', 'Wise'],
            'Verbs': ['Understand', 'Comprehend', 'Perceive'],
            'Nouns': ['Intelligence', 'Brightness', 'Wisdom']
        },
        'Thoughtful': {
            'Synonyms': ['Considerate', 'Pensive', 'Reflective'],
            'Verbs': ['Contemplate', 'Consider', 'Reflect'],
            'Nouns': ['Thoughtfulness', 'Consideration', 'Reflection']
        },
        'Inquisitive': {
            'Synonyms': ['Curious', 'Interested', 'Prying'],
            'Verbs': ['Inquire', 'Explore', 'Investigate'],
            'Nouns': ['Inquisitiveness', 'Curiosity', 'Investigation']
        }
    },
    'Emotional Stability': {
        'Calm': {
            'Synonyms': ['Composed', 'Cool', 'Serene'],
            'Verbs': ['Soothe', 'Stabilize', 'Calm'],
            'Nouns': ['Calmness', 'Composure', 'Serenity']
        },
        'Relaxed': {
            'Synonyms': ['At ease', 'Untroubled', 'Laid-back'],
            'Verbs': ['Relax', 'Unwind', 'Lounge'],
            'Nouns': ['Relaxation', 'Ease', 'Tranquility']
        },
        'Secure': {
            'Synonyms': ['Safe', 'Protected', 'Shielded'],
            'Verbs': ['Secure', 'Protect', 'Defend'],
            'Nouns': ['Security', 'Safety', 'Protection']
        },
        'Unworried': {
            'Synonyms': ['Carefree', 'Unconcerned', 'Nonchalant'],
            'Verbs': ['Disregard', 'Overlook', 'Dismiss'],
            'Nouns': ['Carefreeness', 'Unconcern', 'Nonchalance']
        }
    },
    'Dominance': {
        'Assertive': {
            'Synonyms': ['Confident', 'Bold', 'Decisive'],
            'Verbs': ['Assert', 'Command', 'Demand'],
            'Nouns': ['Assertiveness', 'Confidence', 'Decisiveness']
        },
        'Controlling': {
            'Synonyms': ['Commanding', 'Dominating', 'Regulating'],
            'Verbs': ['Control', 'Command', 'Dominate'],
            'Nouns': ['Control', 'Command', 'Domination']
        },
        'Forceful': {
            'Synonyms': ['Strong', 'Powerful', 'Compelling'],
            'Verbs': ['Push', 'Compel', 'Drive'],
            'Nouns': ['Force', 'Power', 'Compulsion']
        },
        'Aggressive': {
            'Synonyms': ['Confrontational', 'Combative', 'Belligerent'],
            'Verbs': ['Attack', 'Confront', 'Challenge'],
            'Nouns': ['Aggression', 'Confrontation', 'Belligerence']
        }
    },
    'Liveliness': {
        'Active': {
            'Synonyms': ['Energetic', 'Vigorous', 'Dynamic'],
            'Verbs': ['Energize', 'Activate', 'Mobilize'],
            'Nouns': ['Activity', 'Vigor', 'Dynamism']
        },
        'Spontaneous': {
            'Synonyms': ['Impromptu', 'Unplanned', 'Unpredictable'],
            'Verbs': ['Improvise', 'React', 'Spontaneate'],
            'Nouns': ['Spontaneity', 'Impromptuness', 'Unpredictability']
        },
        'Animated': {
            'Synonyms': ['Lively', 'Vivacious', 'Spirited'],
            'Verbs': ['Animate', 'Enliven', 'Vitalize'],
            'Nouns': ['Animation', 'Vivacity', 'Spirit']
        },
        'Expressive': {
            'Synonyms': ['Emotive', 'Demonstrative', 'Passionate'],
            'Verbs': ['Express', 'Demonstrate', 'Display'],
            'Nouns': ['Expression', 'Demonstration', 'Passion']
        }
    },
    'Rule-Consciousness': {
        'Dutiful': {
            'Synonyms': ['Obedient', 'Compliant', 'Conforming'],
            'Verbs': ['Obey', 'Follow', 'Comply'],
            'Nouns': ['Duty', 'Compliance', 'Conformity']
        },
        'Responsible': {
            'Synonyms': ['Reliable', 'Accountable', 'Dependable'],
            'Verbs': ['Respond', 'Account', 'Uphold'],
            'Nouns': ['Responsibility', 'Reliability', 'Accountability']
        },
        'Conforming': {
            'Synonyms': ['Compliant', 'Obedient', 'Accordant'],
            'Verbs': ['Conform', 'Accommodate', 'Adjust'],
            'Nouns': ['Conformity', 'Compliance', 'Accordance']
        },
        'Moralistic': {
            'Synonyms': ['Righteous', 'Principled', 'Ethical'],
            'Verbs': ['Uphold', 'Adhere', 'Observe'],
            'Nouns': ['Morality', 'Principle', 'Ethics']
        }
    },
    'Social Boldness': {
        'Uninhibited': {
            'Synonyms': ['Open', 'Unrestrained', 'Free'],
            'Verbs': ['Act freely', 'Express openly', 'Behave uninhibitedly'],
            'Nouns': ['Openness', 'Freedom', 'Uninhibitedness']
        },
        'Courageous': {
            'Synonyms': ['Brave', 'Fearless', 'Valiant'],
            'Verbs': ['Face fear', 'Stand up', 'Challenge'],
            'Nouns': ['Courage', 'Bravery', 'Valor']
        },
        'Self-assured': {
            'Synonyms': ['Confident', 'Certain', 'Bold'],
            'Verbs': ['Assert', 'Display confidence', 'Project assurance'],
            'Nouns': ['Self-assurance', 'Confidence', 'Certainty']
        },
        'Adventurous': {
            'Synonyms': ['Daring', 'Venturesome', 'Audacious'],
            'Verbs': ['Explore', 'Take risks', 'Venture'],
            'Nouns': ['Adventure', 'Daringness', 'Audacity']
        }
    },
    'Sensitivity': {
        'Aesthetic': {
            'Synonyms': ['Artistic', 'Tasteful', 'Refined'],
            'Verbs': ['Appreciate art', 'Cultivate taste', 'Refine senses'],
            'Nouns': ['Aesthetic sense', 'Art appreciation', 'Refinement']
        },
        'Tender-minded': {
            'Synonyms': ['Compassionate', 'Sympathetic', 'Warm'],
            'Verbs': ['Empathize', 'Comfort', 'Sympathize'],
            'Nouns': ['Compassion', 'Sympathy', 'Warmth']
        },
        'Intuitive': {
            'Synonyms': ['Insightful', 'Perceptive', 'Astute'],
            'Verbs': ['Intuit', 'Perceive deeply', 'Understand intuitively'],
            'Nouns': ['Intuition', 'Perceptiveness', 'Insight']
        },
        'Cultured': {
            'Synonyms': ['Civilized', 'Polished', 'Sophisticated'],
            'Verbs': ['Cultivate culture', 'Educate oneself', 'Polish manners'],
            'Nouns': ['Culture', 'Polish', 'Sophistication']
        }
    },
    'Vigilance': {
        'Suspicious': {
            'Synonyms': ['Distrustful', 'Doubtful', 'Wary'],
            'Verbs': ['Suspect', 'Scrutinize', 'Watch carefully'],
            'Nouns': ['Suspicion', 'Distrust', 'Wariness']
        },
        'Wary': {
            'Synonyms': ['Cautious', 'Vigilant', 'Guarded'],
            'Verbs': ['Be cautious', 'Guard', 'Keep watch'],
            'Nouns': ['Wariness', 'Vigilance', 'Guardedness']
        },
        'Prudent': {
            'Synonyms': ['Cautious', 'Wise', 'Discreet'],
            'Verbs': ['Act prudently', 'Manage wisely', 'Decide carefully'],
            'Nouns': ['Prudence', 'Wisdom', 'Discretion']
        },
        'Skeptical': {
            'Synonyms': ['Doubtful', 'Disbelieving', 'Unconvinced'],
            'Verbs': ['Question', 'Doubt', 'Disbelieve'],
            'Nouns': ['Skepticism', 'Doubt', 'Disbelief']
        }
    },
    'Abstractedness': {
        'Imaginative': {
            'Synonyms': ['Creative', 'Inventive', 'Innovative'],
            'Verbs': ['Imagine', 'Create', 'Invent'],
            'Nouns': ['Imagination', 'Creativity', 'Inventiveness']
        },
        'Idea-oriented': {
            'Synonyms': ['Conceptual', 'Theoretical', 'Intellectual'],
            'Verbs': ['Theorize', 'Speculate', 'Conceptualize'],
            'Nouns': ['Conceptualization', 'Theorizing', 'Intellect']
        },
        'Artistic': {
            'Synonyms': ['Creative', 'Expressive', 'Inventive'],
            'Verbs': ['Create art', 'Express visually', 'Design'],
            'Nouns': ['Artistry', 'Expression', 'Creativity']
        },


        'Innovative': {
            'Synonyms': ['Creative', 'Original', 'Pioneering'],
            'Verbs': ['Innovate', 'Pioneer', 'Initiate'],
            'Nouns': ['Innovation', 'Originality', 'Pioneering']
        }
    },
    'Privateness': {
        'Discreet': {
            'Synonyms': ['Cautious', 'Careful', 'Prudent'],
            'Verbs': ['Act discreetly', 'Maintain secrecy', 'Handle sensitively'],
            'Nouns': ['Discretion', 'Carefulness', 'Prudence']
        },
        'Confidential': {
            'Synonyms': ['Private', 'Secret', 'Classified'],
            'Verbs': ['Keep confidential', 'Protect information', 'Secure secrets'],
            'Nouns': ['Confidentiality', 'Privacy', 'Secrecy']
        },
        'Unrevealing': {
            'Synonyms': ['Uninformative', 'Undisclosed', 'Concealed'],
            'Verbs': ['Withhold information', 'Hide details', 'Obscure facts'],
            'Nouns': ['Secretiveness', 'Non-disclosure', 'Concealment']
        },
        'Secretive': {
            'Synonyms': ['Covert', 'Hidden', 'Concealed'],
            'Verbs': ['Keep secrets', 'Cover up', 'Disguise'],
            'Nouns': ['Secrecy', 'Covert actions', 'Concealment']
        }
    },
    'Apprehension': {
        'Worrying': {
            'Synonyms': ['Anxious', 'Nervous', 'Uneasy'],
            'Verbs': ['Worry', 'Fret', 'Stress'],
            'Nouns': ['Anxiety', 'Nervousness', 'Unease']
        },
        'Self-doubting': {
            'Synonyms': ['Insecure', 'Uncertain', 'Doubtful'],
            'Verbs': ['Question oneself', 'Hesitate', 'Doubt'],
            'Nouns': ['Self-doubt', 'Insecurity', 'Uncertainty']
        },
        'Fearful': {
            'Synonyms': ['Afraid', 'Frightened', 'Terrified'],
            'Verbs': ['Fear', 'Cower', 'Shrink'],
            'Nouns': ['Fear', 'Fright', 'Terror']
        },
        'Insecure': {
            'Synonyms': ['Uncertain', 'Unsure', 'Unconfident'],
            'Verbs': ['Feel insecure', 'Waver', 'Lack confidence'],
            'Nouns': ['Insecurity', 'Uncertainty', 'Lack of confidence']
        }
    },
    'Openness to Change': {
        'Flexible': {
            'Synonyms': ['Adaptable', 'Versatile', 'Accommodating'],
            'Verbs': ['Adapt', 'Flex', 'Adjust'],
            'Nouns': ['Flexibility', 'Adaptability', 'Versatility']
        },
        'Liberal': {
            'Synonyms': ['Progressive', 'Broad-minded', 'Unbiased'],
            'Verbs': ['Advocate', 'Support', 'Promote'],
            'Nouns': ['Liberalism', 'Progressiveness', 'Open-mindedness']
        },
        'Receptive': {
            'Synonyms': ['Open', 'Welcoming', 'Accepting'],
            'Verbs': ['Receive', 'Welcome', 'Embrace'],
            'Nouns': ['Receptiveness', 'Openness', 'Acceptance']
        },
        'Willing to Experiment': {
            'Synonyms': ['Innovative', 'Adventurous', 'Daring'],
            'Verbs': ['Experiment', 'Try new things', 'Explore'],
            'Nouns': ['Willingness to experiment', 'Adventurousness', 'Innovation']
        }
    },
    'Self-Reliance': {
        'Individualistic': {
            'Synonyms': ['Independent', 'Autonomous', 'Self-sufficient'],
            'Verbs': ['Act independently', 'Function alone', 'Rely on oneself'],
            'Nouns': ['Individualism', 'Independence', 'Autonomy']
        },
        'Self-sufficient': {
            'Synonyms': ['Independent', 'Self-contained', 'Self-reliant'],
            'Verbs': ['Maintain self-sufficiency', 'Manage alone', 'Sustain oneself'],
            'Nouns': ['Self-sufficiency', 'Self-reliance', 'Independence']
        },
        'Solitary': {
            'Synonyms': ['Alone', 'Solo', 'Single'],
            'Verbs': ['Isolate', 'Separate', 'Solitude'],
            'Nouns': ['Solitariness', 'Isolation', 'Loneliness']
        },
        'Self-serving': {
            'Synonyms': ['Selfish', 'Self-interested', 'Egocentric'],
            'Verbs': ['Serve oneself', 'Prioritize oneself', 'Focus on oneself'],
            'Nouns': ['Selfishness', 'Self-interest', 'Egocentrism']
        }
    },
    'Perfectionism': {
        'Organized': {
            'Synonyms': ['Orderly', 'Methodical', 'Structured'],
            'Verbs': ['Organize', 'Arrange', 'Systematize'],
            'Nouns': ['Organization', 'Orderliness', 'Methodicalness']
        },
        'Precise': {
            'Synonyms': ['Exact', 'Accurate', 'Meticulous'],
            'Verbs': ['Measure precisely', 'Calibrate', 'Detail'],
            'Nouns': ['Precision', 'Accuracy', 'Meticulousness']
        },
        'High Standards': {
            'Synonyms': ['Exacting', 'Demanding', 'Rigorous'],
            'Verbs': ['Uphold standards', 'Demand perfection', 'Enforce rigor'],
            'Nouns': ['High standards', 'Exactingness', 'Rigor']
        },
        'Detail Oriented': {
            'Synonyms': ['Meticulous', 'Thorough', 'Exact'],
            'Verbs': ['Focus on details', 'Fine-tune', 'Perfect'],
            'Nouns': ['Attention to detail', 'Thoroughness', 'Precision']
        }
    },
    'Tension': {
        'Frustrated': {
            'Synonyms': ['Disappointed', 'Unsatisfied', 'Discontented'],
            'Verbs': ['Feel frustrated', 'Express dissatisfaction', 'Struggle'],
            'Nouns': ['Frustration', 'Disappointment', 'Dissatisfaction']
        },
        'Impatient': {
            'Synonyms': ['Restless', 'Eager', 'Hasty'],
            'Verbs': ['Rush', 'Hurry', 'Demand quickly'],
            'Nouns': ['Impatience', 'Restlessness', 'Haste']
        },
        'Driven': {
            'Synonyms': ['Motivated', 'Ambitious', 'Determined'],
            'Verbs': ['Push oneself', 'Strive', 'Pursue goals'],
            'Nouns': ['Drive', 'Ambition', 'Determination']
        },
        'Stressed': {
            'Synonyms': ['Pressured', 'Overworked', 'Worried'],
            'Verbs': ['Feel stressed', 'Overwork', 'Worry'],
            'Nouns': ['Stress', 'Pressure', 'Overwork']
        }
    }
}

# Create a list to store the data
data = []

# Iterate over each factor
for factor, attributes in sixteen_pf_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate over each synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            # Append the factor, adjective, synonym, verb, and noun to the data list
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
sixteen_pf_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Save dataset to csv file for further analysis
sixteen_pf_df.to_csv('../Datasets/16pf.csv', index=False)

# Print the DataFrame
print(sixteen_pf_df.head())
# Out:
#    Factor     Adjective   Synonym     Verb          Noun
# 0  Warmth  Affectionate    Loving  Cherish     Affection
# 1  Warmth  Affectionate    Tender    Adore    Tenderness
# 2  Warmth  Affectionate      Fond  Embrace      Fondness
# 3  Warmth  Appreciative  Grateful    Value  Appreciation
# 4  Warmth  Appreciative  Thankful   Praise     Gratitude

# %% [markdown]
# ##  Steps for 16PF Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (16PF).
#     * **Actions:**
#         * Define the 16PF dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the 16PF dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the 16PF dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our 16PF Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up 16PF experiment
experiment_name = "16PF"
mlflow.set_experiment(experiment_name)

sixteen_pf_dataset = {
    'Warmth': {
        'Affectionate': {
            'Synonyms': ['Loving', 'Tender', 'Fond'],
            'Verbs': ['Cherish', 'Adore', 'Embrace'],
            'Nouns': ['Affection', 'Tenderness', 'Fondness']
        },
        'Appreciative': {
            'Synonyms': ['Grateful', 'Thankful', 'Pleased'],
            'Verbs': ['Value', 'Praise', 'Appreciate'],
            'Nouns': ['Appreciation', 'Gratitude', 'Thankfulness']
        },
        'Generous': {
            'Synonyms': ['Bountiful', 'Benevolent', 'Liberal'],
            'Verbs': ['Give', 'Donate', 'Contribute'],
            'Nouns': ['Generosity', 'Benevolence', 'Liberalness']
        },
        'Attentive': {
            'Synonyms': ['Observant', 'Aware', 'Heedful'],
            'Verbs': ['Attend', 'Monitor', 'Notice'],
            'Nouns': ['Attention', 'Awareness', 'Mindfulness']
        }
    },
    'Reasoning': {
        'Logical': {
            'Synonyms': ['Rational', 'Analytical', 'Cogent'],
            'Verbs': ['Reason', 'Analyze', 'Infer'],
            'Nouns': ['Logic', 'Rationality', 'Analysis']
        },
        'Intelligent': {
            'Synonyms': ['Smart', 'Bright', 'Wise'],
            'Verbs': ['Understand', 'Comprehend', 'Perceive'],
            'Nouns': ['Intelligence', 'Brightness', 'Wisdom']
        },
        'Thoughtful': {
            'Synonyms': ['Considerate', 'Pensive', 'Reflective'],
            'Verbs': ['Contemplate', 'Consider', 'Reflect'],
            'Nouns': ['Thoughtfulness', 'Consideration', 'Reflection']
        },
        'Inquisitive': {
            'Synonyms': ['Curious', 'Interested', 'Prying'],
            'Verbs': ['Inquire', 'Explore', 'Investigate'],
            'Nouns': ['Inquisitiveness', 'Curiosity', 'Investigation']
        }
    },
    'Emotional Stability': {
        'Calm': {
            'Synonyms': ['Composed', 'Cool', 'Serene'],
            'Verbs': ['Soothe', 'Stabilize', 'Calm'],
            'Nouns': ['Calmness', 'Composure', 'Serenity']
        },
        'Relaxed': {
            'Synonyms': ['At ease', 'Untroubled', 'Laid-back'],
            'Verbs': ['Relax', 'Unwind', 'Lounge'],
            'Nouns': ['Relaxation', 'Ease', 'Tranquility']
        },
        'Secure': {
            'Synonyms': ['Safe', 'Protected', 'Shielded'],
            'Verbs': ['Secure', 'Protect', 'Defend'],
            'Nouns': ['Security', 'Safety', 'Protection']
        },
        'Unworried': {
            'Synonyms': ['Carefree', 'Unconcerned', 'Nonchalant'],
            'Verbs': ['Disregard', 'Overlook', 'Dismiss'],
            'Nouns': ['Carefreeness', 'Unconcern', 'Nonchalance']
        }
    },
    'Dominance': {
        'Assertive': {
            'Synonyms': ['Confident', 'Bold', 'Decisive'],
            'Verbs': ['Assert', 'Command', 'Demand'],
            'Nouns': ['Assertiveness', 'Confidence', 'Decisiveness']
        },
        'Controlling': {
            'Synonyms': ['Commanding', 'Dominating', 'Regulating'],
            'Verbs': ['Control', 'Command', 'Dominate'],
            'Nouns': ['Control', 'Command', 'Domination']
        },
        'Forceful': {
            'Synonyms': ['Strong', 'Powerful', 'Compelling'],
            'Verbs': ['Push', 'Compel', 'Drive'],
            'Nouns': ['Force', 'Power', 'Compulsion']
        },
        'Aggressive': {
            'Synonyms': ['Confrontational', 'Combative', 'Belligerent'],
            'Verbs': ['Attack', 'Confront', 'Challenge'],
            'Nouns': ['Aggression', 'Confrontation', 'Belligerence']
        }
    },
    'Liveliness': {
        'Active': {
            'Synonyms': ['Energetic', 'Vigorous', 'Dynamic'],
            'Verbs': ['Energize', 'Activate', 'Mobilize'],
            'Nouns': ['Activity', 'Vigor', 'Dynamism']
        },
        'Spontaneous': {
            'Synonyms': ['Impromptu', 'Unplanned', 'Unpredictable'],
            'Verbs': ['Improvise', 'React', 'Spontaneate'],
            'Nouns': ['Spontaneity', 'Impromptuness', 'Unpredictability']
        },
        'Animated': {
            'Synonyms': ['Lively', 'Vivacious', 'Spirited'],
            'Verbs': ['Animate', 'Enliven', 'Vitalize'],
            'Nouns': ['Animation', 'Vivacity', 'Spirit']
        },
        'Expressive': {
            'Synonyms': ['Emotive', 'Demonstrative', 'Passionate'],
            'Verbs': ['Express', 'Demonstrate', 'Display'],
            'Nouns': ['Expression', 'Demonstration', 'Passion']
        }
    },
    'Rule-Consciousness': {
        'Dutiful': {
            'Synonyms': ['Obedient', 'Compliant', 'Conforming'],
            'Verbs': ['Obey', 'Follow', 'Comply'],
            'Nouns': ['Duty', 'Compliance', 'Conformity']
        },
        'Responsible': {
            'Synonyms': ['Reliable', 'Accountable', 'Dependable'],
            'Verbs': ['Respond', 'Account', 'Uphold'],
            'Nouns': ['Responsibility', 'Reliability', 'Accountability']
        },
        'Conforming': {
            'Synonyms': ['Compliant', 'Obedient', 'Accordant'],
            'Verbs': ['Conform', 'Accommodate', 'Adjust'],
            'Nouns': ['Conformity', 'Compliance', 'Accordance']
        },
        'Moralistic': {
            'Synonyms': ['Righteous', 'Principled', 'Ethical'],
            'Verbs': ['Uphold', 'Adhere', 'Observe'],
            'Nouns': ['Morality', 'Principle', 'Ethics']
        }
    },
    'Social Boldness': {
        'Uninhibited': {
            'Synonyms': ['Open', 'Unrestrained', 'Free'],
            'Verbs': ['Act freely', 'Express openly', 'Behave uninhibitedly'],
            'Nouns': ['Openness', 'Freedom', 'Uninhibitedness']
        },
        'Courageous': {
            'Synonyms': ['Brave', 'Fearless', 'Valiant'],
            'Verbs': ['Face fear', 'Stand up', 'Challenge'],
            'Nouns': ['Courage', 'Bravery', 'Valor']
        },
        'Self-assured': {
            'Synonyms': ['Confident', 'Certain', 'Bold'],
            'Verbs': ['Assert', 'Display confidence', 'Project assurance'],
            'Nouns': ['Self-assurance', 'Confidence', 'Certainty']
        },
        'Adventurous': {
            'Synonyms': ['Daring', 'Venturesome', 'Audacious'],
            'Verbs': ['Explore', 'Take risks', 'Venture'],
            'Nouns': ['Adventure', 'Daringness', 'Audacity']
        }
    },
    'Sensitivity': {
        'Aesthetic': {
            'Synonyms': ['Artistic', 'Tasteful', 'Refined'],
            'Verbs': ['Appreciate art', 'Cultivate taste', 'Refine senses'],
            'Nouns': ['Aesthetic sense', 'Art appreciation', 'Refinement']
        },
        'Tender-minded': {
            'Synonyms': ['Compassionate', 'Sympathetic', 'Warm'],
            'Verbs': ['Empathize', 'Comfort', 'Sympathize'],
            'Nouns': ['Compassion', 'Sympathy', 'Warmth']
        },
        'Intuitive': {
            'Synonyms': ['Insightful', 'Perceptive', 'Astute'],
            'Verbs': ['Intuit', 'Perceive deeply', 'Understand intuitively'],
            'Nouns': ['Intuition', 'Perceptiveness', 'Insight']
        },
        'Cultured': {
            'Synonyms': ['Civilized', 'Polished', 'Sophisticated'],
            'Verbs': ['Cultivate culture', 'Educate oneself', 'Polish manners'],
            'Nouns': ['Culture', 'Polish', 'Sophistication']
        }
    },
    'Vigilance': {
        'Suspicious': {
            'Synonyms': ['Distrustful', 'Doubtful', 'Wary'],
            'Verbs': ['Suspect', 'Scrutinize', 'Watch carefully'],
            'Nouns': ['Suspicion', 'Distrust', 'Wariness']
        },
        'Wary': {
            'Synonyms': ['Cautious', 'Vigilant', 'Guarded'],
            'Verbs': ['Be cautious', 'Guard', 'Keep watch'],
            'Nouns': ['Wariness', 'Vigilance', 'Guardedness']
        },
        'Prudent': {
            'Synonyms': ['Cautious', 'Wise', 'Discreet'],
            'Verbs': ['Act prudently', 'Manage wisely', 'Decide carefully'],
            'Nouns': ['Prudence', 'Wisdom', 'Discretion']
        },
        'Skeptical': {
            'Synonyms': ['Doubtful', 'Disbelieving', 'Unconvinced'],
            'Verbs': ['Question', 'Doubt', 'Disbelieve'],
            'Nouns': ['Skepticism', 'Doubt', 'Disbelief']
        }
    },
    'Abstractedness': {
        'Imaginative': {
            'Synonyms': ['Creative', 'Inventive', 'Innovative'],
            'Verbs': ['Imagine', 'Create', 'Invent'],
            'Nouns': ['Imagination', 'Creativity', 'Inventiveness']
        },
        'Idea-oriented': {
            'Synonyms': ['Conceptual', 'Theoretical', 'Intellectual'],
            'Verbs': ['Theorize', 'Speculate', 'Conceptualize'],
            'Nouns': ['Conceptualization', 'Theorizing', 'Intellect']
        },
        'Artistic': {
            'Synonyms': ['Creative', 'Expressive', 'Inventive'],
            'Verbs': ['Create art', 'Express visually', 'Design'],
            'Nouns': ['Artistry', 'Expression', 'Creativity']
        },


        'Innovative': {
            'Synonyms': ['Creative', 'Original', 'Pioneering'],
            'Verbs': ['Innovate', 'Pioneer', 'Initiate'],
            'Nouns': ['Innovation', 'Originality', 'Pioneering']
        }
    },
    'Privateness': {
        'Discreet': {
            'Synonyms': ['Cautious', 'Careful', 'Prudent'],
            'Verbs': ['Act discreetly', 'Maintain secrecy', 'Handle sensitively'],
            'Nouns': ['Discretion', 'Carefulness', 'Prudence']
        },
        'Confidential': {
            'Synonyms': ['Private', 'Secret', 'Classified'],
            'Verbs': ['Keep confidential', 'Protect information', 'Secure secrets'],
            'Nouns': ['Confidentiality', 'Privacy', 'Secrecy']
        },
        'Unrevealing': {
            'Synonyms': ['Uninformative', 'Undisclosed', 'Concealed'],
            'Verbs': ['Withhold information', 'Hide details', 'Obscure facts'],
            'Nouns': ['Secretiveness', 'Non-disclosure', 'Concealment']
        },
        'Secretive': {
            'Synonyms': ['Covert', 'Hidden', 'Concealed'],
            'Verbs': ['Keep secrets', 'Cover up', 'Disguise'],
            'Nouns': ['Secrecy', 'Covert actions', 'Concealment']
        }
    },
    'Apprehension': {
        'Worrying': {
            'Synonyms': ['Anxious', 'Nervous', 'Uneasy'],
            'Verbs': ['Worry', 'Fret', 'Stress'],
            'Nouns': ['Anxiety', 'Nervousness', 'Unease']
        },
        'Self-doubting': {
            'Synonyms': ['Insecure', 'Uncertain', 'Doubtful'],
            'Verbs': ['Question oneself', 'Hesitate', 'Doubt'],
            'Nouns': ['Self-doubt', 'Insecurity', 'Uncertainty']
        },
        'Fearful': {
            'Synonyms': ['Afraid', 'Frightened', 'Terrified'],
            'Verbs': ['Fear', 'Cower', 'Shrink'],
            'Nouns': ['Fear', 'Fright', 'Terror']
        },
        'Insecure': {
            'Synonyms': ['Uncertain', 'Unsure', 'Unconfident'],
            'Verbs': ['Feel insecure', 'Waver', 'Lack confidence'],
            'Nouns': ['Insecurity', 'Uncertainty', 'Lack of confidence']
        }
    },
    'Openness to Change': {
        'Flexible': {
            'Synonyms': ['Adaptable', 'Versatile', 'Accommodating'],
            'Verbs': ['Adapt', 'Flex', 'Adjust'],
            'Nouns': ['Flexibility', 'Adaptability', 'Versatility']
        },
        'Liberal': {
            'Synonyms': ['Progressive', 'Broad-minded', 'Unbiased'],
            'Verbs': ['Advocate', 'Support', 'Promote'],
            'Nouns': ['Liberalism', 'Progressiveness', 'Open-mindedness']
        },
        'Receptive': {
            'Synonyms': ['Open', 'Welcoming', 'Accepting'],
            'Verbs': ['Receive', 'Welcome', 'Embrace'],
            'Nouns': ['Receptiveness', 'Openness', 'Acceptance']
        },
        'Willing to Experiment': {
            'Synonyms': ['Innovative', 'Adventurous', 'Daring'],
            'Verbs': ['Experiment', 'Try new things', 'Explore'],
            'Nouns': ['Willingness to experiment', 'Adventurousness', 'Innovation']
        }
    },
    'Self-Reliance': {
        'Individualistic': {
            'Synonyms': ['Independent', 'Autonomous', 'Self-sufficient'],
            'Verbs': ['Act independently', 'Function alone', 'Rely on oneself'],
            'Nouns': ['Individualism', 'Independence', 'Autonomy']
        },
        'Self-sufficient': {
            'Synonyms': ['Independent', 'Self-contained', 'Self-reliant'],
            'Verbs': ['Maintain self-sufficiency', 'Manage alone', 'Sustain oneself'],
            'Nouns': ['Self-sufficiency', 'Self-reliance', 'Independence']
        },
        'Solitary': {
            'Synonyms': ['Alone', 'Solo', 'Single'],
            'Verbs': ['Isolate', 'Separate', 'Solitude'],
            'Nouns': ['Solitariness', 'Isolation', 'Loneliness']
        },
        'Self-serving': {
            'Synonyms': ['Selfish', 'Self-interested', 'Egocentric'],
            'Verbs': ['Serve oneself', 'Prioritize oneself', 'Focus on oneself'],
            'Nouns': ['Selfishness', 'Self-interest', 'Egocentrism']
        }
    },
    'Perfectionism': {
        'Organized': {
            'Synonyms': ['Orderly', 'Methodical', 'Structured'],
            'Verbs': ['Organize', 'Arrange', 'Systematize'],
            'Nouns': ['Organization', 'Orderliness', 'Methodicalness']
        },
        'Precise': {
            'Synonyms': ['Exact', 'Accurate', 'Meticulous'],
            'Verbs': ['Measure precisely', 'Calibrate', 'Detail'],
            'Nouns': ['Precision', 'Accuracy', 'Meticulousness']
        },
        'High Standards': {
            'Synonyms': ['Exacting', 'Demanding', 'Rigorous'],
            'Verbs': ['Uphold standards', 'Demand perfection', 'Enforce rigor'],
            'Nouns': ['High standards', 'Exactingness', 'Rigor']
        },
        'Detail Oriented': {
            'Synonyms': ['Meticulous', 'Thorough', 'Exact'],
            'Verbs': ['Focus on details', 'Fine-tune', 'Perfect'],
            'Nouns': ['Attention to detail', 'Thoroughness', 'Precision']
        }
    },
    'Tension': {
        'Frustrated': {
            'Synonyms': ['Disappointed', 'Unsatisfied', 'Discontented'],
            'Verbs': ['Feel frustrated', 'Express dissatisfaction', 'Struggle'],
            'Nouns': ['Frustration', 'Disappointment', 'Dissatisfaction']
        },
        'Impatient': {
            'Synonyms': ['Restless', 'Eager', 'Hasty'],
            'Verbs': ['Rush', 'Hurry', 'Demand quickly'],
            'Nouns': ['Impatience', 'Restlessness', 'Haste']
        },
        'Driven': {
            'Synonyms': ['Motivated', 'Ambitious', 'Determined'],
            'Verbs': ['Push oneself', 'Strive', 'Pursue goals'],
            'Nouns': ['Drive', 'Ambition', 'Determination']
        },
        'Stressed': {
            'Synonyms': ['Pressured', 'Overworked', 'Worried'],
            'Verbs': ['Feel stressed', 'Overwork', 'Worry'],
            'Nouns': ['Stress', 'Pressure', 'Overwork']
        }
    }
}

# Create a list to store the dataset
data = []
for factor, attributes in sixteen_pf_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
sixteenpf_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/sixteenpf.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="16PF Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "16PF")
    mlflow.log_param("Total Rows", len(sixteenpf_df))
    mlflow.log_param("Total Factors", len(sixteen_pf_dataset))
    mlflow.log_param("Data Schema", str(sixteenpf_df.columns.tolist()))
    
    # Save dataset to CSV
    sixteenpf_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ 16PF dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(sixteenpf_df.head())
    print("\nDataset shape:", sixteenpf_df.shape)
    print("\nNumber of unique Factors:", sixteenpf_df['Factor'].nunique())
    print("Unique Factors:", sixteenpf_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# ✅ 16PF dataset created and saved to ../Datasets/sixteenpf.csv
# First 5 rows of the dataset:
#    Factor     Adjective   Synonym     Verb          Noun
# 0  Warmth  Affectionate    Loving  Cherish     Affection
# 1  Warmth  Affectionate    Tender    Adore    Tenderness
# 2  Warmth  Affectionate      Fond  Embrace      Fondness
# 3  Warmth  Appreciative  Grateful    Value  Appreciation
# 4  Warmth  Appreciative  Thankful   Praise     Gratitude
#
# Dataset shape: (192, 5)
#
# Number of unique Factors: 16
# Unique Factors: ['Warmth' 'Reasoning' 'Emotional Stability' 'Dominance' 'Liveliness'
#  'Rule-Consciousness' 'Social Boldness' 'Sensitivity' 'Vigilance'
#  'Abstractedness' 'Privateness' 'Apprehension' 'Openness to Change'
#  'Self-Reliance' 'Perfectionism' 'Tension']
# 📌 MLflow tracking active under experiment '16PF' (ID: 7)
# 🏃 View run 16PF Dataset Creation at: http://127.0.0.1:5000/#/experiments/7/runs/c2bd455f3a924da4973cbca9df8e6c7a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="sixteenpf_page_2"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/7/runs/a28b69d03ce04be8a5e6d3d91f745fa8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="sixteenpf_page_2"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018421143293380737, -0.007218753919005394, 0.003606205340474844, -0.05419774353504181, -0.022721948102116585, 0.036969155073165894, 0.02902725711464882, 0.023901814594864845, 0.011240449734032154, -0.020641323179006577]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/7/runs/b1bede3dfcc04127847b535d803aaa0d
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create 16PF Embeddings** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved sixteenpf dataset from a CSV file
dataset_path = '../Datasets/sixteenpf.csv'
try:
    sixteenpf_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'sixteenpf_df' is empty before processing
        if sixteenpf_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", sixteenpf_df.shape[0])
            print(f"📊 Processing {sixteenpf_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        sixteenpf_df['Embedding'] = sixteenpf_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/sixteenpf_embeddings.csv'
        sixteenpf_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = sixteenpf_df.shape[0]
        num_columns = sixteenpf_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in sixteenpf_df.columns and not sixteenpf_df['Embedding'].empty:
            embedding_length = len(sixteenpf_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(sixteenpf_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/sixteenpf.csv
# ⏳ Embedding generation started at: 2025-03-16 12:22:13.257104
# 📊 Processing 192 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-16 12:23:07.441105 (Duration: 0:00:54.184001)
# 💾 Embeddings saved to: ../Embeddings/sixteenpf_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#    Factor     Adjective   Synonym     Verb          Noun  \
# 0  Warmth  Affectionate    Loving  Cherish     Affection
# 1  Warmth  Affectionate    Tender    Adore    Tenderness
# 2  Warmth  Affectionate      Fond  Embrace      Fondness
# 3  Warmth  Appreciative  Grateful    Value  Appreciation
# 4  Warmth  Appreciative  Thankful   Praise     Gratitude
#
#                                            Embedding
# 0  [0.046978358179330826, -0.04488566145300865, 0...
# 1  [0.018803000450134277, -0.04531193524599075, -...
# 2  [0.027186881750822067, -0.05825569108128548, 0...
# 3  [0.001136164297349751, -0.017528383061289787, ...
# 4  [-0.006799143273383379, -0.03882908448576927, ...
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5000/#/experiments/7/runs/f1727dce6e24481daa933208b780dd10
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/sixteenpf_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/sixteenpf_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "sixteenpf_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/sixteenpf_embeddings.csv
# 💾 Label encoder saved to: ../Models/sixteenpf_label_encoder.pkl
#
# First 5 rows with encoded labels:
#    Factor  Factor_Encoded
# 0  Warmth              15
# 1  Warmth              15
# 2  Warmth              15
# 3  Warmth              15
# 4  Warmth              15
#
# Mapping of original labels to encoded labels:
# Abstractedness: 0
# Apprehension: 1
# Dominance: 2
# Emotional Stability: 3
# Liveliness: 4
# Openness to Change: 5
# Perfectionism: 6
# Privateness: 7
# Reasoning: 8
# Rule-Consciousness: 9
# Self-Reliance: 10
# Sensitivity: 11
# Social Boldness: 12
# Tension: 13
# Vigilance: 14
# Warmth: 15
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/sixteenpf_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: sixteenpf_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/7/runs/1a4e1fcfd07b48fb95ac540c64c45b84
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/sixteenpf_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/sixteenpf_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="sixteenpf Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "sixteenpf_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "sixteenpf_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "sixteenpf_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/sixteenpf_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/sixteenpf_embeddings.csv
# ✅ Label encoder loaded from: ../Models/sixteenpf_label_encoder.pkl
# ⏳ Model training started at: 2025-03-16 12:23:58.934803
# ✅ Model training finished at: 2025-03-16 12:23:59.365313 (Duration: 0:00:00.430510)
# 📊 Classification report saved to: sixteenpf_classification_report.csv
# 📊 Confusion matrix saved to: sixteenpf_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: sixteenpf_confusion_matrix.png
# 💾 Trained model saved to: ../Models/sixteenpf_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#      Abstractedness       1.00      1.00      1.00         2
#        Apprehension       1.00      1.00      1.00         2
#           Dominance       1.00      1.00      1.00         2
# Emotional Stability       1.00      1.00      1.00         3
#          Liveliness       1.00      1.00      1.00         3
#  Openness to Change       1.00      1.00      1.00         2
#       Perfectionism       1.00      1.00      1.00         3
#         Privateness       1.00      1.00      1.00         3
#           Reasoning       1.00      1.00      1.00         2
#  Rule-Consciousness       1.00      1.00      1.00         2
#       Self-Reliance       1.00      1.00      1.00         3
#         Sensitivity       1.00      1.00      1.00         2
#     Social Boldness       1.00      1.00      1.00         3
#             Tension       1.00      1.00      1.00         2
#           Vigilance       1.00      1.00      1.00         2
#              Warmth       1.00      1.00      1.00         3
#
#            accuracy                           1.00        39
#           macro avg       1.00      1.00      1.00        39
#        weighted avg       1.00      1.00      1.00        39
#
#
# Confusion Matrix:
#                       Abstractedness  Apprehension  Dominance  \
# Abstractedness                    2             0          0
# Apprehension                      0             2          0
# Dominance                         0             0          2
# Emotional Stability               0             0          0
# Liveliness                        0             0          0
# Openness to Change                0             0          0
# Perfectionism                     0             0          0
# Privateness                       0             0          0
# Reasoning                         0             0          0
# Rule-Consciousness                0             0          0
# Self-Reliance                     0             0          0
# Sensitivity                       0             0          0
# Social Boldness                   0             0          0
# Tension                           0             0          0
# Vigilance                         0             0          0
# Warmth                            0             0          0
#
#                      Emotional Stability  Liveliness  Openness to Change  \
# Abstractedness                         0           0                   0
# Apprehension                           0           0                   0
# Dominance                              0           0                   0
# Emotional Stability                    3           0                   0
# Liveliness                             0           3                   0
# Openness to Change                     0           0                   2
# Perfectionism                          0           0                   0
# Privateness                            0           0                   0
# Reasoning                              0           0                   0
# Rule-Consciousness                     0           0                   0
# Self-Reliance                          0           0                   0
# Sensitivity                            0           0                   0
# Social Boldness                        0           0                   0
# Tension                                0           0                   0
# Vigilance                              0           0                   0
# Warmth                                 0           0                   0
#
#                      Perfectionism  Privateness  Reasoning  \
# Abstractedness                   0            0          0
# Apprehension                     0            0          0
# Dominance                        0            0          0
# Emotional Stability              0            0          0
# Liveliness                       0            0          0
# Openness to Change               0            0          0
# Perfectionism                    3            0          0
# Privateness                      0            3          0
# Reasoning                        0            0          2
# Rule-Consciousness               0            0          0
# Self-Reliance                    0            0          0
# Sensitivity                      0            0          0
# Social Boldness                  0            0          0
# Tension                          0            0          0
# Vigilance                        0            0          0
# Warmth                           0            0          0
#
#                      Rule-Consciousness  Self-Reliance  Sensitivity  \
# Abstractedness                        0              0            0
# Apprehension                          0              0            0
# Dominance                             0              0            0
# Emotional Stability                   0              0            0
# Liveliness                            0              0            0
# Openness to Change                    0              0            0
# Perfectionism                         0              0            0
# Privateness                           0              0            0
# Reasoning                             0              0            0
# Rule-Consciousness                    2              0            0
# Self-Reliance                         0              3            0
# Sensitivity                           0              0            2
# Social Boldness                       0              0            0
# Tension                               0              0            0
# Vigilance                             0              0            0
# Warmth                                0              0            0
#
#                      Social Boldness  Tension  Vigilance  Warmth
# Abstractedness                     0        0          0       0
# Apprehension                       0        0          0       0
# Dominance                          0        0          0       0
# Emotional Stability                0        0          0       0
# Liveliness                         0        0          0       0
# Openness to Change                 0        0          0       0
# Perfectionism                      0        0          0       0
# Privateness                        0        0          0       0
# Reasoning                          0        0          0       0
# Rule-Consciousness                 0        0          0       0
# Self-Reliance                      0        0          0       0
# Sensitivity                        0        0          0       0
# Social Boldness                    3        0          0       0
# Tension                            0        2          0       0
# Vigilance                          0        0          2       0
# Warmth                             0        0          0       3
# 🏃 View run sixteenpf Model Training and Evaluation Workflow at: http://127.0.0.1:5000/#/experiments/7/runs/d77f2003917643878725fcfe8ff585b0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/sixteenpf_embeddings.csv'
label_encoder_path = "../Models/sixteenpf_label_encoder.pkl"
model_path = "../Models/sixteenpf_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate 16PF Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate 16PF Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "sixteenpf_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "sixteenpf_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "sixteenpf_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ 16PF Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/sixteenpf_embeddings.csv
# ✅ Label encoder loaded from: ../Models/sixteenpf_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/sixteenpf_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: sixteenpf_evaluation_classification_report.csv
#
# Classification Report:
#                       precision    recall  f1-score   support
#
#      Abstractedness       1.00      1.00      1.00         2
#        Apprehension       1.00      1.00      1.00         2
#           Dominance       1.00      1.00      1.00         2
# Emotional Stability       1.00      1.00      1.00         3
#          Liveliness       1.00      1.00      1.00         3
#  Openness to Change       1.00      1.00      1.00         2
#       Perfectionism       1.00      1.00      1.00         3
#         Privateness       1.00      1.00      1.00         3
#           Reasoning       1.00      1.00      1.00         2
#  Rule-Consciousness       1.00      1.00      1.00         2
#       Self-Reliance       1.00      1.00      1.00         3
#         Sensitivity       1.00      1.00      1.00         2
#     Social Boldness       1.00      1.00      1.00         3
#             Tension       1.00      1.00      1.00         2
#           Vigilance       1.00      1.00      1.00         2
#              Warmth       1.00      1.00      1.00         3
#
#            accuracy                           1.00        39
#           macro avg       1.00      1.00      1.00        39
#        weighted avg       1.00      1.00      1.00        39
#
# 📊 Confusion matrix saved to: sixteenpf_evaluation_confusion_matrix.csv
#
# Confusion Matrix:
#                       Abstractedness  Apprehension  Dominance  \
# Abstractedness                    2             0          0
# Apprehension                      0             2          0
# Dominance                         0             0          2
# Emotional Stability               0             0          0
# Liveliness                        0             0          0
# Openness to Change                0             0          0
# Perfectionism                     0             0          0
# Privateness                       0             0          0
# Reasoning                         0             0          0
# Rule-Consciousness                0             0          0
# Self-Reliance                     0             0          0
# Sensitivity                       0             0          0
# Social Boldness                   0             0          0
# Tension                           0             0          0
# Vigilance                         0             0          0
# Warmth                            0             0          0
#
#                      Emotional Stability  Liveliness  Openness to Change  \
# Abstractedness                         0           0                   0
# Apprehension                           0           0                   0
# Dominance                              0           0                   0
# Emotional Stability                    3           0                   0
# Liveliness                             0           3                   0
# Openness to Change                     0           0                   2
# Perfectionism                          0           0                   0
# Privateness                            0           0                   0
# Reasoning                              0           0                   0
# Rule-Consciousness                     0           0                   0
# Self-Reliance                          0           0                   0
# Sensitivity                            0           0                   0
# Social Boldness                        0           0                   0
# Tension                                0           0                   0
# Vigilance                              0           0                   0
# Warmth                                 0           0                   0
#
#                      Perfectionism  Privateness  Reasoning  \
# Abstractedness                   0            0          0
# Apprehension                     0            0          0
# Dominance                        0            0          0
# Emotional Stability              0            0          0
# Liveliness                       0            0          0
# Openness to Change               0            0          0
# Perfectionism                    3            0          0
# Privateness                      0            3          0
# Reasoning                        0            0          2
# Rule-Consciousness               0            0          0
# Self-Reliance                    0            0          0
# Sensitivity                      0            0          0
# Social Boldness                  0            0          0
# Tension                          0            0          0
# Vigilance                        0            0          0
# Warmth                           0            0          0
#
#                      Rule-Consciousness  Self-Reliance  Sensitivity  \
# Abstractedness                        0              0            0
# Apprehension                          0              0            0
# Dominance                             0              0            0
# Emotional Stability                   0              0            0
# Liveliness                            0              0            0
# Openness to Change                    0              0            0
# Perfectionism                         0              0            0
# Privateness                           0              0            0
# Reasoning                             0              0            0
# Rule-Consciousness                    2              0            0
# Self-Reliance                         0              3            0
# Sensitivity                           0              0            2
# Social Boldness                       0              0            0
# Tension                               0              0            0
# Vigilance                             0              0            0
# Warmth                                0              0            0
#
#                      Social Boldness  Tension  Vigilance  Warmth
# Abstractedness                     0        0          0       0
# Apprehension                       0        0          0       0
# Dominance                          0        0          0       0
# Emotional Stability                0        0          0       0
# Liveliness                         0        0          0       0
# Openness to Change                 0        0          0       0
# Perfectionism                      0        0          0       0
# Privateness                        0        0          0       0
# Reasoning                          0        0          0       0
# Rule-Consciousness                 0        0          0       0
# Self-Reliance                      0        0          0       0
# Sensitivity                        0        0          0       0
# Social Boldness                    3        0          0       0
# Tension                            0        2          0       0
# Vigilance                          0        0          2       0
# Warmth                             0        0          0       3
# 🖼️ Confusion matrix plot saved to: sixteenpf_evaluation_confusion_matrix.png
# 🏃 View run Evaluate 16PF Model at: http://127.0.0.1:5000/#/experiments/7/runs/fec5587ba84d4a7fa8a285a85362f704
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7
#
# ✅ 16PF Model evaluation on the test set complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/sixteenpf_label_encoder.pkl"
model_path = "../Models/sixteenpf_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/sixteenpf_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/sixteenpf_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Dominance
# Predicted Factor for 'I prefer staying home with a good book....': Self-Reliance
# Predicted Factor for 'I often feel anxious and worried....': Apprehension
# Predicted Factor for 'I am generally calm and relaxed....': Tension
# Predicted Factor for 'I enjoy taking risks and trying new things....': Openness to Change
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/7/runs/57cf74ec708d4257b3d6bbb3642a621c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/sixteenpf_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="16PF Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/sixteenpf_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "sixteenpf_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/sixteenpf_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of 16PF Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/sixteenpf_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of 16PF Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/16 12:24:33 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Liveliness
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Emotional Stability
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Reasoning
# Predicted Factor for 'Organized Meticulous Plan Planner': Perfectionism
# Predicted Factor for 'Moody Anxious Worry Worrier': Apprehension
# 🏃 View run 16PF Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/7/runs/31352f360498433b86fc289dfa48e9b2
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/sixteenpf_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/sixteenpf_label_encoder.pkl"
        model_path = "../Models/sixteenpf_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of 16PF Embeddings")

            # Save and log the plot
            pca_plot_path = "sixteenpf_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "sixteenpf_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/sixteenpf_embeddings.csv
#
# DataFrame with Embeddings:
#    Factor     Adjective   Synonym     Verb          Noun  \
# 0  Warmth  Affectionate    Loving  Cherish     Affection
# 1  Warmth  Affectionate    Tender    Adore    Tenderness
# 2  Warmth  Affectionate      Fond  Embrace      Fondness
# 3  Warmth  Appreciative  Grateful    Value  Appreciation
# 4  Warmth  Appreciative  Thankful   Praise     Gratitude
#
#                                            Embedding
# 0  [0.046978358179330826, -0.04488566145300865, 0...
# 1  [0.018803000450134277, -0.04531193524599075, -...
# 2  [0.027186881750822067, -0.05825569108128548, 0...
# 3  [0.001136164297349751, -0.017528383061289787, ...
# 4  [-0.006799143273383379, -0.03882908448576927, ...
#
# Shape of DataFrame:
# (192, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.04697836 -0.04488566  0.00154353 ... -0.01950501  0.021316
#  -0.01254277]
# ✅ Label encoder loaded from: ../Models/sixteenpf_label_encoder.pkl
#
# Shape of X:
# (192, 1536)
# ✅ PCA visualization saved to: sixteenpf_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: sixteenpf_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Dominance
# 🏃 View run Step 9: Model Application, Visualization, and Analysis at: http://127.0.0.1:5000/#/experiments/7/runs/fa432557f328453cb76b9f2666380655
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7
#
# ✅ Step 10: Save Model Visualization and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean cross-validation score: 1.0

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="sixteenpf_page_3"></a>
#
# [Back to Top](#sixteenpf_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/sixteenpf_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_sixteenpf.pkl')
clf = joblib.load('../Models/sixteenpf_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Liveliness
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Emotional Stability
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Reasoning
# Predicted Factor for 'Organized Meticulous Plan Planner': Perfectionism
# Predicted Factor for 'Moody Anxious Worry Worrier': Apprehension
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Self-Reliance

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Reasoning

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Apprehension

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Apprehension

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Sensitivity

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Emotional Stability

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="SixteenPF_page_4"></a>
#
#
# [Back to Top](#SixteenPF_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("16PF")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/7/runs/28da4221de36449a8ed1ed0f1736f7dc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create 16PF Schema in Neo4j** <a class="anchor" id="SixteenPF_page_4"></a>
#
#
# [Back to Top](#SixteenPF_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("16PF")

# Load the dataset
dataset_path = "../Embeddings/sixteenpf_embeddings.csv"
sixteenpf_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in sixteenpf_df.columns:
    sixteenpf_df['Embedding'] = sixteenpf_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the 16PF schema in Neo4j
def create_sixteenpf_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with 16PF labels
        graph.run("MERGE (f:SixteenPF_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:SixteenPF_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:SixteenPF_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:SixteenPF_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:SixteenPF_Noun {name: $noun})", noun=noun)
        
        # Create relationships with 16PF namespacing
        graph.run("""
            MATCH (f:SixteenPF_Factor {name: $factor}), (a:SixteenPF_Adjective {name: $adjective})
            MERGE (f)-[:SixteenPF_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:SixteenPF_Adjective {name: $adjective}), (s:SixteenPF_Synonym {name: $synonym})
            MERGE (a)-[:SixteenPF_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:SixteenPF_Adjective {name: $adjective}), (v:SixteenPF_Verb {name: $verb})
            MERGE (a)-[:SixteenPF_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:SixteenPF_Adjective {name: $adjective}), (n:SixteenPF_Noun {name: $noun})
            MERGE (a)-[:SixteenPF_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:SixteenPF_Factor {name: $factor}), (a:SixteenPF_Adjective {name: $adjective})
                MERGE (e:SixteenPF_Embedding {value: $embedding})
                MERGE (f)-[:SixteenPF_HAS_EMBEDDING]->(e)
                MERGE (a)-[:SixteenPF_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create 16PF Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create 16PF Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the 16PF schema
        create_sixteenpf_schema(graph, sixteenpf_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", sixteenpf_df.shape[0])
        mlflow.log_param("Number of Columns", sixteenpf_df.shape[1])
        
        # Print the DataFrame
        print(sixteenpf_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#    Factor     Adjective   Synonym     Verb          Noun  \
# 0  Warmth  Affectionate    Loving  Cherish     Affection
# 1  Warmth  Affectionate    Tender    Adore    Tenderness
# 2  Warmth  Affectionate      Fond  Embrace      Fondness
# 3  Warmth  Appreciative  Grateful    Value  Appreciation
# 4  Warmth  Appreciative  Thankful   Praise     Gratitude
#
#                                            Embedding
# 0  [0.046978358179330826, -0.04488566145300865, 0...
# 1  [0.018803000450134277, -0.04531193524599075, -...
# 2  [0.027186881750822067, -0.05825569108128548, 0...
# 3  [0.001136164297349751, -0.017528383061289787, ...
# 4  [-0.006799143273383379, -0.03882908448576927, ...
# 🏃 View run Create 16PF Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/7/runs/cb9985cc29604de394c1dc7a265c3d1c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/7

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:SixteenPF_Factor OR n:SixteenPF_Adjective OR n:SixteenPF_Synonym OR n:SixteenPF_Verb OR n:SixteenPF_Noun)
# AND NOT m:SixteenPF_Embedding
# RETURN n, r, m
# ```
