# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Rorschach Inkblot Test (RIT)<a class="anchor" id="PTMD_page_20.6"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# **Rorschach Inkblot Test Dataset**
#
# The Rorschach Inkblot Test analyzes responses to ambiguous inkblot stimuli to assess personality traits and emotional functioning. Here are the main factors and scoring information:
#
# **Factors:**
#
# 1. **Location:** Where the individual focuses on the inkblot image.
#    - **Whole:** Respondent perceives the entire inkblot as a single entity.
#    - **Details:** The response pertains to distinct and identifiable portions of the inkblot.
#    - **Unusual Details:** Focus on small or less obvious parts of the inkblot that most people may not notice.
#    - **White Space:** Interpretation involving the white space or negative areas around and within the inkblot.
#
# 2. **Determinants:** Characteristics influencing how the respondent perceives and interprets the inkblot.
#    - **Form:** How the shape and outline affect the interpretation.
#    - **Movement:** The perception of movement or activity in the image (e.g., human, animal).
#    - **Color:** How the presence of color impacts perception and response.
#    - **Shading:** Use of varying intensities and gradations of ink shading.
#    - **Texture:** Perceived surface quality, inferred by shading or patterns.
#    - **Pairs:** Responses involving pairs or symmetrical patterns within the inkblot.
#
# 3. **Content:** What the interpretation includes or represents.
#    - **Human:** Responses involving human figures, features, or activities.
#    - **Animal:** Perception of animal shapes or behaviors in the inkblot.
#    - **Nature:** Natural objects like landscapes, plants, or weather phenomena.
#    - **Objects:** Non-living objects, such as tools, buildings, or household items.
#    - **Abstract:** Geometric shapes or patterns, often with non-specific or imaginative descriptions.
#
# **Scoring Information:**
# The interpretation of responses involves comprehensive scoring guidelines and criteria:
# - **Quantitative Scores:** Assigning numerical values to the prevalence and frequency of various responses and factors.
# - **Qualitative Analysis:** Analyzing patterns and themes in responses to discern underlying personality traits.
# - **Normative Comparisons:** Comparing individual scores to standardized norms to identify patterns of psychopathology or cognitive functioning.
# - **Diagnostic Indicators:** Specific responses indicating potential psychological conditions or coping mechanisms.
#
#
#
# | Year | Milestone | Contributor(s) | Original Work Reference | Key Contributions |
# |------|-----------|----------------|-------------------------|-------------------|
# | 1921 | Initial publication of the Rorschach Inkblot Test. | Hermann Rorschach | Rorschach, H. (1921). *Psychodiagnostik.* | Introduced the use of inkblots to assess personality and identify psychopathology. |
# | 1922 | Early recognition following Rorschach's death. | Hermann Rorschach | Early clinical studies. | Gained recognition for its innovative approach in understanding personality. |
# | 1939 | English translation published in the U.S., growing popularity. | Various | Beck, S. J. (1939). *Rorschach's Test: Vol. 1.* | Translated into English, introducing the test to American psychologists. |
# | 1942 | First comprehensive scoring system published. | Samuel Beck | Beck, S. J. (1942). *Rorschach's Test: Vol. 1.* | Provided a comprehensive system for scoring and interpreting results. |
# | 1945 | Expanded use in diagnosing WWII veterans. | Various clinicians and researchers | Various clinical publications. | Widespread adoption for clinical diagnosis, especially for returning soldiers. |
# | 1954 | Bruno Klopfer's new scoring and interpretation system. | Bruno Klopfer | Klopfer, B. (1954). *Developments in the Rorschach Technique.* | Introduced a new scoring system, contributing diverse interpretive approaches. |
# | 1968 | Exner's Comprehensive System standardizes scoring. | John E. Exner Jr. | Exner, J. E. (1969). *The Rorschach Systems Manual.* | Standardized scoring to improve the test's reliability and validity. |
# | 1993 | "Rorschach Inkblot Test: An International Reference" published. | Various | Weiner, I. B. (1993). *Rorschach Inkblot Test: An International Reference.* | Demonstrated the test's cross-cultural applicability. |
# | 2011 | Introduction of the R-PAS system. | Various | Meyer, G. J., et al. (2011). *Rorschach Performance Assessment System (R-PAS).* | Standardized scoring with a new system to enhance accuracy. |
# | Present | Continued use across clinical, forensic, and research settings. | Various clinicians and researchers | Multiple research studies and academic publications. | Ongoing assessment alongside other tools in diverse contexts. |
#
# | #   | Author(s)                                   | Year | Title                                                           | Journal/Source                    | Volume | Pages  | DOI                                                       |
# |-----|---------------------------------------------|------|-----------------------------------------------------------------|------------------------------------|--------|--------|----------------------------------------------------------|
# | 1   | H. Rorschach, P. Lemkau, B. Kronenberg, and W. Morgenthaler | 1942 | Psychodiagnostics: A diagnostic test based on perception (3rd ed. rev. and enlarged), including the application of the form interpretation test. | - | - | - | [10.1037/11537-000](https://doi.org/10.1037/11537-000) |
# | 2   | James M. Wood, S. Lilienfeld, H. Garb, and M. Nezworski | 2000 | The Rorschach test in clinical diagnosis: a critical review, with a backward look at Garfield (1947). | Journal of Clinical Psychology | 56 | 395-430 | [10.1002/(SICI)1097-4679(200003)56:3<395::AID-JCLP15>3.0.CO;2-O](https://doi.org/10.1002/(SICI)1097-4679(200003)56:3<395::AID-JCLP15>3.0.CO;2-O) |
# | 3   | J. Hunsley and J. Michael Bailey            | 1999 | The clinical utility of the Rorschach: Unfulfilled promises and an uncertain future | Psychological Assessment | 11 | 266-277 | [10.1037/1040-3590.11.3.266](https://doi.org/10.1037/1040-3590.11.3.266) |
# | 4   | G. Meyer, Wei-Cheng Hsiao, D. Viglione, J. L. Mihura, and L. M. Abraham | 2013 | Rorschach Scores in Applied Clinical Practice: A Survey of Perceived Validity by Experienced Clinicians | Journal of Personality Assessment | 95 | 351-365 | [10.1080/00223891.2013.770399](https://doi.org/10.1080/00223891.2013.770399) |
# | 5   | H. Rorschach, P. Lemkau, and B. Kronenberg  | 1951 | Psychodiagnostics: a diagnostic test based on perception: including Rorschach's paper The application of the form interpretation test | - | - | - | - |
# | 6   | Thomas W. Shaffer, P. Erdberg, and G. Meyer | 2007 | Introduction to the JPA Special Supplement on International Reference Samples for the Rorschach Comprehensive System | Journal of Personality Assessment | 89 | S2-S6 | [10.1080/00223890701629268](https://doi.org/10.1080/00223890701629268) |
# | 7   | Kristin L. Dean, D. Viglione, W. Perry, and G. Meyer | 2007 | A Method to Optimize the Response Range While Maintaining Rorschach Comprehensive System Validity | Journal of Personality Assessment | 89 | 149-161 | [10.1080/00223890701468543](https://doi.org/10.1080/00223890701468543) |
# | 8   | Danilo R. Silva                             | 2015 | O Sistema de Avaliação do Desempenho no Rorschach (SADR) Aplicação, Codificação e Interpretação, Manual Técnico | - | - | - | - |
# | 9   | D. Viglione                                 | 1999 | A review of recent research addressing the utility of the Rorschach. | Psychological Assessment | 11 | 251-265 | [10.1037/1040-3590.11.3.251](https://doi.org/10.1037/1040-3590.11.3.251) |
# | 10  | D. Viglione and M. Hilsenroth               | 2001 | The Rorschach: facts, fictions, and future.                     | Psychological Assessment | 13 | 452-471 | [10.1037/1040-3590.13.4.452](https://doi.org/10.1037/1040-3590.13.4.452) |
# | 11  | James M. Wood, M. Nezworski, and W. Stejskal | 1996 | The Comprehensive System for the Rorschach: A Critical Examination | Psychological Science | 7 | 10-13 | [10.1111/J.1467-9280.1996.TB00658.X](https://doi.org/10.1111/J.1467-9280.1996.TB00658.X) |
# | 12  | Gregory J. Meyer and Robert P. Archer      | 2001 | The hard science of Rorschach research: what do we know and where do we go? | Psychological Assessment | 13 | 486-502 | [10.1037/1040-3590.13.4.486](https://doi.org/10.1037/1040-3590.13.4.486) |
# | 13  | Gregory J. Meyer et al.                     | 2002 | An Examination of Interrater Reliability for Scoring the Rorschach Comprehensive System in Eight Data Sets | Journal of Personality Assessment | 78 | 219-274 | [10.1207/S15327752JPA7802_03](https://doi.org/10.1207/S15327752JPA7802_03) |
# | 14  | James M. Wood, H. Garb, M. Nezworski, S. Lilienfeld, and M. Duke | 2015 | A second look at the validity of widely used Rorschach indices: comment on Mihura, Meyer, Dumitrascu, and Bombel (2013) | Psychological Bulletin | 141 | 236-249 | [10.1037/a0036005](https://doi.org/10.1037/a0036005) |
# | 15  | D. Viglione and G. Meyer                   | 2008 | An overview of Rorschach psychometrics for forensic practice | The handbook of forensic Rorschach assessment | - | 21-53 | [10.4324/9780203810071](https://doi.org/10.4324/9780203810071) |
# | 16  | I. Weiner                                  | 2001 | Advancing the science of psychological assessment: the Rorschach Inkblot Method as exemplar | Psychological Assessment | 13 | 423-432 | [10.1037/1040-3590.13.4.423](https://doi.org/10.1037/1040-3590.13.4.423) |
# | 17  | R. Flanagan                                | 2006 | The Rorschach: A comprehensive system                           | -                                | -      | -      | [10.1007/978-0-387-79948-3_5319](https://doi.org/10.1007/978-0-387-79948-3_5319) |
# | 18  | A. Klug                                    | 2016 | Principles of Rorschach Interpretation                          | -                                | -      | -      | [10.4324/9781410607799](https://doi.org/10.4324/9781410607799) |
# | 19  | R. Bornstein                               | 2012 | Rorschach Score Validation as a Model for 21st-Century Personality Assessment | Journal of Personality Assessment | 94 | 26-38 | [10.1080/00223891.2011.627961](https://doi.org/10.1080/00223891.2011.627961) |
# | 20  | J. Exner and P. Erdberg                    | 2003 | The Rorschach: A comprehensive system, 3rd ed.                   | -                                | -      | -      | - |
# | 21  | R. Flanagan                                | 2006 | The Rorschach: A Comprehensive System (4th ed.)                 | Journal of Psychoeducational Assessment | 24 | 166-171 | [10.1177/0734282905285790](https://doi.org/10.1177/0734282905285790) |
# | 22  | J. Exner                                   | 2007 | A New U.S. Adult Nonpatient Sample                              | Journal of Personality Assessment | 89 | S154-S158 | [10.1080/00223890701583523](https://doi.org/10.1080/00223890701583523) |
# | 23  | Marc J. Diener, M. Hilsenroth, Seth A. Shaffer, and James Sexton | 2011 | A Meta-Analysis of the relationship between the Rorschach Ego Impairment Index (EII) and psychiatric severity | Clinical Psychology & Psychotherapy | 18 | 464-485 | [10.1002/cpp.725](https://doi.org/10.1002/cpp.725) |
# | 24  | J. L. Mihura et al.                        | 2015 | Standards, accuracy, and questions of bias in Rorschach meta-analyses: reply to Wood, Garb, Nezworski, Lilienfeld, and Duke (2015) | Psychological Bulletin | 141 | 250-260 | [10.1037/a0038445](https://doi.org/10.1037/a0038445) |
# | 25  | D. Viglione, W. Perry, and G. Meyer        | 2003 | Refinements in the Rorschach Ego Impairment Index Incorporating the Human Representational Variable | Journal of Personality Assessment | 81 | 149-156 | [10.1207/S15327752JPA8102_06](https://doi.org/10.1207/S15327752JPA8102_06) |
# | 26  | Robert A. Graceffo, J. L. Mihura, and G. Meyer | 2014 | A Meta-Analysis of an Implicit Measure of Personality Functioning: The Mutuality of Autonomy Scale | Journal of Personality Assessment | 96 | 581-595 | [10.1080/00223891.2014.919299](https://doi.org/10.1080/00223891.2014.919299) |
# | 27  | D. Viglione et al.                         | 2011 | Revising the Rorschach Ego Impairment Index to Accommodate Recent Recommendations About Improving Rorschach Validity | International Journal of Testing | 11 | 349-364 | [10.1080/15305058.2011.589019](https://doi.org/10.1080/15305058.2011.589019) |
# | 28  | D. Viglione et al.                         | 2015 | Developing an Alternative Rorschach Administration Method to Optimize the Number of Responses and Enhance Clinical Inferences | Clinical Psychology & Psychotherapy | 22 | 546-558 | [10.1002/cpp.1913](https://doi.org/10.1002/cpp.1913) |
# | 29  | G. Meyer et al.                            | 2015 | Addressing Issues in the Development and Use of the Composite International Reference Values as Rorschach Norms for Adults | Journal of Personality Assessment | 97 | 330-347 | [10.1080/00223891.2014.961603](https://doi.org/10.1080/00223891.2014.961603) |
# | 30  | G. Meyer et al.                            | 2015 | The Association of Gender, Ethnicity, Age, and Education With Rorschach Scores | Assessment | 22 | 46-64 | [10.1177/1073191114544358](https://doi.org/10.1177/1073191114544358) |
# | 31  | Jennifer Reese, D. Viglione, and L. Giromini | 2014 | A Comparison Between Comprehensive System and an Early Version of the Rorschach Performance Assessment System Administration With Outpatient Children and Adolescents | Journal of Personality Assessment | 96 | 515-522 | [10.1080/00223891.2014.889700](https://doi.org/10.1080/00223891.2014.889700) |
# | 32  | D. Viglione, L. Giromini, M. L. Gustafson, and G. Meyer | 2014 | Developing Continuous Variable Composites for Rorschach Measures of Thought Problems, Vigilance, and Suicide Risk | Assessment | 21 | 42-49 | [10.1177/1073191112446963](https://doi.org/10.1177/1073191112446963) |
# | 33  | G. Meyer                                  | 2017 | What Rorschach performance can add to assessing and understanding personality | - | - | - | - |

# %% [markdown]
# ##  Steps for RIT Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (RIT).
#     * **Actions:**
#         * Define the RIT dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the RIT dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the RIT dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our RIT Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
# Category
#    |__ Factor
#    |__ Adjective (Description)
#           |__ Synonyms
#           |__ Verbs
#           |__ Nouns


# Import pandas for creating the DataFrame
import pandas as pd

# Initialize an empty list to store the data
data = []

# Rorschach Inkblot Test dataset structure
rorschach_dataset = {
    'Location': {# Category
        'Whole': { # factor
            'Description': 'Interpretation of the entire inkblot as a single entity.', # adjective
            'Synonyms': ['Overall', 'Entire', 'Global'],
            'Verbs': ['Perceive', 'Identify', 'View'],
            'Nouns': ['Whole', 'Entity', 'Complete form']
        },
        'Details': {
            'Description': 'Interpretation of distinct and recognizable parts of the inkblot.',
            'Synonyms': ['Particulars', 'Specifics', 'Fragments'],
            'Verbs': ['Focus', 'Identify', 'Detail'],
            'Nouns': ['Details', 'Fragments', 'Portions']
        },
        'Unusual Details': {
            'Description': 'Focus on small or less obvious areas of the inkblot.',
            'Synonyms': ['Obscure', 'Hidden', 'Uncommon'],
            'Verbs': ['Notice', 'Identify', 'Detect'],
            'Nouns': ['Obscure details', 'Hidden portions', 'Uncommon areas']
        },
        'White Space': {
            'Description': 'Interpretation involving the white space or negative areas around and within the inkblot.',
            'Synonyms': ['Negative space', 'Background', 'Unfilled areas'],
            'Verbs': ['Notice', 'Incorporate', 'Interpret'],
            'Nouns': ['White space', 'Negative areas', 'Empty zones']
        }
    },
    'Determinants': {
        'Form': {
            'Description': 'The shape and outline influence the perception.',
            'Synonyms': ['Shape', 'Contour', 'Outline'],
            'Verbs': ['Identify', 'Outline', 'Form'],
            'Nouns': ['Form', 'Shape', 'Contour']
        },
        'Movement': {
            'Description': 'The perception of motion or activity in the inkblot (human, animal).',
            'Synonyms': ['Motion', 'Action', 'Activity'],
            'Verbs': ['Move', 'Act', 'Engage'],
            'Nouns': ['Movement', 'Activity', 'Motion']
        },
        'Color': {
            'Description': 'Interpretation influenced by the presence of color in the inkblot.',
            'Synonyms': ['Hue', 'Tint', 'Shade'],
            'Verbs': ['Color', 'Tint', 'Hue'],
            'Nouns': ['Color', 'Hue', 'Shade']
        },
        'Shading': {
            'Description': 'Use of varying intensities and gradations of ink shading.',
            'Synonyms': ['Gradation', 'Shadow', 'Contrast'],
            'Verbs': ['Shade', 'Contrast', 'Shadow'],
            'Nouns': ['Shading', 'Gradation', 'Contrast']
        },
        'Texture': {
            'Description': 'Perceived surface quality inferred by shading or patterns.',
            'Synonyms': ['Feel', 'Surface', 'Pattern'],
            'Verbs': ['Texture', 'Pattern', 'Surface'],
            'Nouns': ['Texture', 'Pattern', 'Feel']
        },
        'Pairs': {
            'Description': 'Responses involving pairs or symmetrical patterns within the inkblot.',
            'Synonyms': ['Couple', 'Duo', 'Double'],
            'Verbs': ['Pair', 'Match', 'Double'],
            'Nouns': ['Pair', 'Couple', 'Symmetry']
        }
    },
    'Content': {
        'Human': {
            'Description': 'Responses involving human figures, features, or activities.',
            'Synonyms': ['Person', 'Individual', 'Man/Woman'],
            'Verbs': ['Humanize', 'Relate', 'Include'],
            'Nouns': ['Human', 'Person', 'Individual']
        },
        'Animal': {
            'Description': 'Perception of animal shapes or behaviors in the inkblot.',
            'Synonyms': ['Creature', 'Mammal', 'Reptile'],
            'Verbs': ['Perceive', 'Identify', 'Relate'],
            'Nouns': ['Animal', 'Creature', 'Mammal']
        },
        'Nature': {
            'Description': 'Natural objects like landscapes, plants, or weather phenomena.',
            'Synonyms': ['Landscape', 'Vegetation', 'Weather'],
            'Verbs': ['Perceive', 'Identify', 'Interpret'],
            'Nouns': ['Nature', 'Landscape', 'Vegetation']
        },
        'Objects': {
            'Description': 'Non-living objects, such as tools, buildings, or household items.',
            'Synonyms': ['Tool', 'Building', 'Item'],
            'Verbs': ['Perceive', 'Identify', 'Interpret'],
            'Nouns': ['Object', 'Tool', 'Building']
        },
        'Abstract': {
            'Description': 'Geometric shapes or patterns, often with imaginative descriptions.',
            'Synonyms': ['Shape', 'Pattern', 'Concept'],
            'Verbs': ['Perceive', 'Interpret', 'Imagine'],
            'Nouns': ['Abstract', 'Shape', 'Pattern']
        }
    }
}

# Process the Rorschach dataset to extract each scale's details
for factor, subcategories in rorschach_dataset.items():
    for subcategory, traits in subcategories.items():
        synonyms = traits.get('Synonyms', [])
        verbs = traits.get('Verbs', [])
        nouns = traits.get('Nouns', [])
        description = traits.get('Description', '')
        
        # Normalize lists to match each other in length
        max_len = max(len(synonyms), len(verbs), len(nouns))
        synonyms += [''] * (max_len - len(synonyms))
        verbs += [''] * (max_len - len(verbs))
        nouns += [''] * (max_len - len(nouns))
        
        # Add data for each synonym-verb-noun combination
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, subcategory, description, synonym, verb, noun))

# Create a DataFrame with the structured data
rorschach_df = pd.DataFrame(data, columns=['Factor', 'Subcategory', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Save to CSV
rorschach_df.to_csv('../Datasets/rit.csv', index=False)

# Display the first few rows
print(rorschach_df.head())
# Out:
#      Factor Subcategory                                          Adjective  \
# 0  Location       Whole  Interpretation of the entire inkblot as a sing...
# 1  Location       Whole  Interpretation of the entire inkblot as a sing...
# 2  Location       Whole  Interpretation of the entire inkblot as a sing...
# 3  Location     Details  Interpretation of distinct and recognizable pa...
# 4  Location     Details  Interpretation of distinct and recognizable pa...
#
#        Synonym      Verb           Noun
# 0      Overall  Perceive          Whole
# 1       Entire  Identify         Entity
# 2       Global      View  Complete form
# 3  Particulars     Focus        Details
# 4    Specifics  Identify      Fragments

# %%
import pandas as pd

# Initialize list to collect rows
rows = []

# Rorschach Inkblot Test dataset structured by your taxonomy
rorschach_dataset = {
    'Location': {
        'Whole': {
            'Description': 'Interpretation of the entire inkblot as a single entity.',
            'Synonyms': ['Overall', 'Entire', 'Global'],
            'Verbs':    ['Perceive', 'Identify', 'View'],
            'Nouns':    ['Whole', 'Entity', 'Complete form']
        },
        'Details': {
            'Description': 'Interpretation of distinct and recognizable parts of the inkblot.',
            'Synonyms': ['Particulars', 'Specifics', 'Fragments'],
            'Verbs':    ['Focus', 'Identify', 'Detail'],
            'Nouns':    ['Details', 'Fragments', 'Portions']
        },
        'Unusual Details': {
            'Description': 'Focus on small or less obvious areas of the inkblot.',
            'Synonyms': ['Obscure', 'Hidden', 'Uncommon'],
            'Verbs':    ['Notice', 'Identify', 'Detect'],
            'Nouns':    ['Obscure details', 'Hidden portions', 'Uncommon areas']
        },
        'White Space': {
            'Description': 'Interpretation involving the white space or negative areas around and within the inkblot.',
            'Synonyms': ['Negative space', 'Background', 'Unfilled areas'],
            'Verbs':    ['Notice', 'Incorporate', 'Interpret'],
            'Nouns':    ['White space', 'Negative areas', 'Empty zones']
        }
    },
    'Determinants': {
        'Form':    {'Description': 'The shape and outline influence the perception.',
                    'Synonyms': ['Shape', 'Contour', 'Outline'],
                    'Verbs':    ['Identify', 'Outline', 'Form'],
                    'Nouns':    ['Form', 'Shape', 'Contour']},
        'Movement':{'Description': 'The perception of motion or activity in the inkblot (human, animal).',
                    'Synonyms': ['Motion', 'Action', 'Activity'],
                    'Verbs':    ['Move', 'Act', 'Engage'],
                    'Nouns':    ['Movement', 'Activity', 'Motion']},
        'Color':   {'Description': 'Interpretation influenced by the presence of color in the inkblot.',
                    'Synonyms': ['Hue', 'Tint', 'Shade'],
                    'Verbs':    ['Color', 'Tint', 'Hue'],
                    'Nouns':    ['Color', 'Hue', 'Shade']},
        'Shading': {'Description': 'Use of varying intensities and gradations of ink shading.',
                    'Synonyms': ['Gradation', 'Shadow', 'Contrast'],
                    'Verbs':    ['Shade', 'Contrast', 'Shadow'],
                    'Nouns':    ['Shading', 'Gradation', 'Contrast']},
        'Texture': {'Description': 'Perceived surface quality inferred by shading or patterns.',
                    'Synonyms': ['Feel', 'Surface', 'Pattern'],
                    'Verbs':    ['Texture', 'Pattern', 'Surface'],
                    'Nouns':    ['Texture', 'Pattern', 'Feel']},
        'Pairs':   {'Description': 'Responses involving pairs or symmetrical patterns within the inkblot.',
                    'Synonyms': ['Couple', 'Duo', 'Double'],
                    'Verbs':    ['Pair', 'Match', 'Double'],
                    'Nouns':    ['Pair', 'Couple', 'Symmetry']}
    },
    'Content': {
        'Human':   {'Description': 'Responses involving human figures, features, or activities.',
                    'Synonyms': ['Person', 'Individual', 'Man/Woman'],
                    'Verbs':    ['Humanize', 'Relate', 'Include'],
                    'Nouns':    ['Human', 'Person', 'Individual']},
        'Animal':  {'Description': 'Perception of animal shapes or behaviors in the inkblot.',
                    'Synonyms': ['Creature', 'Mammal', 'Reptile'],
                    'Verbs':    ['Perceive', 'Identify', 'Relate'],
                    'Nouns':    ['Animal', 'Creature', 'Mammal']},
        'Nature':  {'Description': 'Natural objects like landscapes, plants, or weather phenomena.',
                    'Synonyms': ['Landscape', 'Vegetation', 'Weather'],
                    'Verbs':    ['Perceive', 'Identify', 'Interpret'],
                    'Nouns':    ['Nature', 'Landscape', 'Vegetation']},
        'Objects': {'Description': 'Non-living objects, such as tools, buildings, or household items.',
                    'Synonyms': ['Tool', 'Building', 'Item'],
                    'Verbs':    ['Perceive', 'Identify', 'Interpret'],
                    'Nouns':    ['Object', 'Tool', 'Building']},
        'Abstract':{'Description': 'Geometric shapes or patterns, often with imaginative descriptions.',
                    'Synonyms': ['Shape', 'Pattern', 'Concept'],
                    'Verbs':    ['Perceive', 'Interpret', 'Imagine'],
                    'Nouns':    ['Abstract', 'Shape', 'Pattern']}
    }
}

# Build rows
for category, factors in rorschach_dataset.items():
    for factor, attrs in factors.items():
        desc = attrs.get('Description', '')
        syns = attrs.get('Synonyms', [])
        verbs = attrs.get('Verbs', [])
        nouns = attrs.get('Nouns', [])
        # pad shorter lists so they all match
        max_len = max(len(syns), len(verbs), len(nouns))
        syns += [''] * (max_len - len(syns))
        verbs += [''] * (max_len - len(verbs))
        nouns += [''] * (max_len - len(nouns))
        
        for syn, verb, noun in zip(syns, verbs, nouns):
            rows.append({
                'Category':   category,
                'Factor':     factor,
                'Adjective':  desc,
                'Synonym':    syn,
                'Verb':       verb,
                'Noun':       noun
            })

# Create DataFrame and save
df = pd.DataFrame(rows, columns=['Category','Factor','Adjective','Synonym','Verb','Noun'])
df.to_csv('../Datasets/rit.csv', index=False)

# Quick preview
print(df.head())
# Out:
#    Category   Factor                                          Adjective  \
# 0  Location    Whole  Interpretation of the entire inkblot as a sing...
# 1  Location    Whole  Interpretation of the entire inkblot as a sing...
# 2  Location    Whole  Interpretation of the entire inkblot as a sing...
# 3  Location  Details  Interpretation of distinct and recognizable pa...
# 4  Location  Details  Interpretation of distinct and recognizable pa...
#
#        Synonym      Verb           Noun
# 0      Overall  Perceive          Whole
# 1       Entire  Identify         Entity
# 2       Global      View  Complete form
# 3  Particulars     Focus        Details
# 4    Specifics  Identify      Fragments

# %%
import pandas as pd

# Rorschach Inkblot Test dataset structure
rorschach_dataset = {
    'Location': {
        'Whole': {
            'Description': 'Interpretation of the entire inkblot as a single entity.',
            'Synonyms': ['Overall', 'Entire', 'Global'],
            'Verbs':    ['Perceive', 'Identify', 'View'],
            'Nouns':    ['Whole', 'Entity', 'Complete form']
        },
        'Details': {
            'Description': 'Interpretation of distinct and recognizable parts of the inkblot.',
            'Synonyms': ['Particulars', 'Specifics', 'Fragments'],
            'Verbs':    ['Focus', 'Identify', 'Detail'],
            'Nouns':    ['Details', 'Fragments', 'Portions']
        },
        'Unusual Details': {
            'Description': 'Focus on small or less obvious areas of the inkblot.',
            'Synonyms': ['Obscure', 'Hidden', 'Uncommon'],
            'Verbs':    ['Notice', 'Identify', 'Detect'],
            'Nouns':    ['Obscure details', 'Hidden portions', 'Uncommon areas']
        },
        'White Space': {
            'Description': 'Interpretation involving the white space or negative areas around and within the inkblot.',
            'Synonyms': ['Negative space', 'Background', 'Unfilled areas'],
            'Verbs':    ['Notice', 'Incorporate', 'Interpret'],
            'Nouns':    ['White space', 'Negative areas', 'Empty zones']
        }
    },
    'Determinants': {
        'Form': {
            'Description': 'The shape and outline influence the perception.',
            'Synonyms': ['Shape', 'Contour', 'Outline'],
            'Verbs':    ['Identify', 'Outline', 'Form'],
            'Nouns':    ['Form', 'Shape', 'Contour']
        },
        'Movement': {
            'Description': 'The perception of motion or activity in the inkblot (human, animal).',
            'Synonyms': ['Motion', 'Action', 'Activity'],
            'Verbs':    ['Move', 'Act', 'Engage'],
            'Nouns':    ['Movement', 'Activity', 'Motion']
        },
        'Color': {
            'Description': 'Interpretation influenced by the presence of color in the inkblot.',
            'Synonyms': ['Hue', 'Tint', 'Shade'],
            'Verbs':    ['Color', 'Tint', 'Hue'],
            'Nouns':    ['Color', 'Hue', 'Shade']
        },
        'Shading': {
            'Description': 'Use of varying intensities and gradations of ink shading.',
            'Synonyms': ['Gradation', 'Shadow', 'Contrast'],
            'Verbs':    ['Shade', 'Contrast', 'Shadow'],
            'Nouns':    ['Shading', 'Gradation', 'Contrast']
        },
        'Texture': {
            'Description': 'Perceived surface quality inferred by shading or patterns.',
            'Synonyms': ['Feel', 'Surface', 'Pattern'],
            'Verbs':    ['Texture', 'Pattern', 'Surface'],
            'Nouns':    ['Texture', 'Pattern', 'Feel']
        },
        'Pairs': {
            'Description': 'Responses involving pairs or symmetrical patterns within the inkblot.',
            'Synonyms': ['Couple', 'Duo', 'Double'],
            'Verbs':    ['Pair', 'Match', 'Double'],
            'Nouns':    ['Pair', 'Couple', 'Symmetry']
        }
    },
    'Content': {
        'Human': {
            'Description': 'Responses involving human figures, features, or activities.',
            'Synonyms': ['Person', 'Individual', 'Man/Woman'],
            'Verbs':    ['Humanize', 'Relate', 'Include'],
            'Nouns':    ['Human', 'Person', 'Individual']
        },
        'Animal': {
            'Description': 'Perception of animal shapes or behaviors in the inkblot.',
            'Synonyms': ['Creature', 'Mammal', 'Reptile'],
            'Verbs':    ['Perceive', 'Identify', 'Relate'],
            'Nouns':    ['Animal', 'Creature', 'Mammal']
        },
        'Nature': {
            'Description': 'Natural objects like landscapes, plants, or weather phenomena.',
            'Synonyms': ['Landscape', 'Vegetation', 'Weather'],
            'Verbs':    ['Perceive', 'Identify', 'Interpret'],
            'Nouns':    ['Nature', 'Landscape', 'Vegetation']
        },
        'Objects': {
            'Description': 'Non-living objects, such as tools, buildings, or household items.',
            'Synonyms': ['Tool', 'Building', 'Item'],
            'Verbs':    ['Perceive', 'Identify', 'Interpret'],
            'Nouns':    ['Object', 'Tool', 'Building']
        },
        'Abstract': {
            'Description': 'Geometric shapes or patterns, often with imaginative descriptions.',
            'Synonyms': ['Shape', 'Pattern', 'Concept'],
            'Verbs':    ['Perceive', 'Interpret', 'Imagine'],
            'Nouns':    ['Abstract', 'Shape', 'Pattern']
        }
    }
}

# Flatten into the same format as your FFM dataset:
# Factor → Adjective → Synonym → Verb → Noun
rows = []
for factor, adjectives in rorschach_dataset.items():
    for adjective, attrs in adjectives.items():
        syns = attrs['Synonyms']
        verbs = attrs['Verbs']
        nouns = attrs['Nouns']
        # pad lists to equal length
        max_len = max(len(syns), len(verbs), len(nouns))
        syns += [''] * (max_len - len(syns))
        verbs += [''] * (max_len - len(verbs))
        nouns += [''] * (max_len - len(nouns))
        # build one row per synonym-verb-noun tuple
        for syn, vb, nn in zip(syns, verbs, nouns):
            rows.append((factor, adjective, syn, vb, nn))

rit_df = pd.DataFrame(rows, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Save or inspect
rit_df.to_csv('../Datasets/rit.csv', index=False)
print(rit_df.head())
# Out:
#      Factor Adjective      Synonym      Verb           Noun
# 0  Location     Whole      Overall  Perceive          Whole
# 1  Location     Whole       Entire  Identify         Entity
# 2  Location     Whole       Global      View  Complete form
# 3  Location   Details  Particulars     Focus        Details
# 4  Location   Details    Specifics  Identify      Fragments

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="rit_page_2"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5001/#/experiments/3/runs/d7c91dd7d92b47989f7ed6ea1c411622
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="rit_page_2"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.01842353865504265, -0.00725775770843029, 0.0036669441033154726, -0.0542047917842865, -0.022724902257323265, 0.03694858402013779, 0.02903103083372116, 0.023866858333349228, 0.011229223571717739, -0.020618630573153496]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5001/#/experiments/3/runs/a31215cf4ce04ad5a435dd7c020af3a4
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create RIT Embeddings** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved rit dataset from a CSV file
dataset_path = '../Datasets/rit.csv'
try:
    rit_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'rit_df' is empty before processing
        if rit_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", rit_df.shape[0])
            print(f"📊 Processing {rit_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        rit_df['Embedding'] = rit_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/rit_embeddings.csv'
        rit_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = rit_df.shape[0]
        num_columns = rit_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in rit_df.columns and not rit_df['Embedding'].empty:
            embedding_length = len(rit_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(rit_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/rit.csv
# ⏳ Embedding generation started at: 2025-05-13 19:37:25.832539
# 📊 Processing 45 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-05-13 19:37:44.791700 (Duration: 0:00:18.959161)
# 💾 Embeddings saved to: ../Embeddings/rit_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#      Factor Adjective      Synonym      Verb           Noun  \
# 0  Location     Whole      Overall  Perceive          Whole
# 1  Location     Whole       Entire  Identify         Entity
# 2  Location     Whole       Global      View  Complete form
# 3  Location   Details  Particulars     Focus        Details
# 4  Location   Details    Specifics  Identify      Fragments
#
#                                            Embedding
# 0  [0.024969829246401787, -0.02679545432329178, 0...
# 1  [-0.010919989086687565, -0.021649299189448357,...
# 2  [0.014100281521677971, 0.04727916792035103, 0....
# 3  [-0.06766358762979507, -0.0018393141217529774,...
# 4  [-0.0405363105237484, 0.04887589067220688, 0.0...
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5001/#/experiments/3/runs/5058f6efdb724d44b86eb935ff91da6d
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/rit_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/rit_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "rit_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/rit_embeddings.csv
# 💾 Label encoder saved to: ../Models/rit_label_encoder.pkl
#
# First 5 rows with encoded labels:
#      Factor  Factor_Encoded
# 0  Location               2
# 1  Location               2
# 2  Location               2
# 3  Location               2
# 4  Location               2
#
# Mapping of original labels to encoded labels:
# Content: 0
# Determinants: 1
# Location: 2
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/rit_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: rit_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5001/#/experiments/3/runs/0ec2c8773c68489fa4782e14a4595850
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/rit_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/rit_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="rit Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "rit_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "rit_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "rit_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/rit_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/rit_embeddings.csv
# ✅ Label encoder loaded from: ../Models/rit_label_encoder.pkl
# ⏳ Model training started at: 2025-05-13 19:37:53.406828
# ✅ Model training finished at: 2025-05-13 19:37:53.548393 (Duration: 0:00:00.141565)
# 📊 Classification report saved to: rit_classification_report.csv
# 📊 Confusion matrix saved to: rit_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: rit_confusion_matrix.png
# 💾 Trained model saved to: ../Models/rit_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Content       1.00      1.00      1.00         3
# Determinants       1.00      1.00      1.00         4
#     Location       1.00      1.00      1.00         2
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Confusion Matrix:
#                Content  Determinants  Location
# Content             3             0         0
# Determinants        0             4         0
# Location            0             0         2
# 🏃 View run rit Model Training and Evaluation Workflow at: http://127.0.0.1:5001/#/experiments/3/runs/6813104de9234dd299dce1e4e90b6bb3
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/rit_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}.")
    exit()

# Function to convert embedding strings back to arrays
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/rit_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}.")
    exit()

# Prepare features and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values
y_encoded = label_encoder.transform(y)

# Determine a test fraction that ensures ≥1 sample per class
n_samples = len(y_encoded)
n_classes = len(np.unique(y_encoded))
min_test_samples = n_classes
frac_test_samples = int(np.ceil(0.2 * n_samples))
test_count = max(min_test_samples, frac_test_samples)
test_fraction = test_count / n_samples

print(f"ℹ️ Splitting off {test_count} samples ({test_fraction:.2%}) to test, "
      f"to cover all {n_classes} classes at least once.")

# Stratified split with dynamic test_fraction
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=test_fraction,
    random_state=42,
    stratify=y_encoded
)

# Start MLflow run
with mlflow.start_run(run_name="rit Model Training and Evaluation Workflow") as run:
    mlflow.log_params({
        "Model Type": "RandomForestClassifier",
        "Dataset": embeddings_csv_path,
        "Test Fraction": test_fraction,
        "Random State": 42,
        "Stratify": True
    })
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    start_time = datetime.now()
    print(f"⏳ Training started: {start_time}")

    clf = RandomForestClassifier(n_estimators=100, random_state=42)
    clf.fit(X_train, y_train)

    end_time = datetime.now()
    print(f"✅ Training finished: {end_time} (Duration: {end_time - start_time})")

    # Predictions & metrics
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    mlflow.log_metric("Accuracy", accuracy)

    # Classification report
    class_report = classification_report(
        y_test, y_pred, 
        target_names=label_encoder.classes_, 
        output_dict=True
    )
    cr_df = pd.DataFrame(class_report).transpose()
    cr_path = "rit_classification_report.csv"
    cr_df.to_csv(cr_path)
    mlflow.log_artifact(cr_path, artifact_path="metrics")

    # Confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    cm_df = pd.DataFrame(cm, index=label_encoder.classes_, columns=label_encoder.classes_)
    cm_path = "rit_confusion_matrix.csv"
    cm_df.to_csv(cm_path)
    mlflow.log_artifact(cm_path, artifact_path="metrics")

    # Plot & log confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predicted'); plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    cm_img = "rit_confusion_matrix.png"
    plt.savefig(cm_img)
    plt.close()
    mlflow.log_artifact(cm_img, artifact_path="metrics")

    # Save model
    model_path = "../Models/rit_rf_model.pkl"
    joblib.dump(clf, model_path)
    mlflow.log_artifact(model_path, artifact_path="models")

    # Log additional info
    mlflow.log_params({
        "Train Samples": X_train.shape[0],
        "Test Samples":  X_test.shape[0],
        "Feature Count": X_train.shape[1]
    })

    print(f"📈 Accuracy: {accuracy:.4f}")
    print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
    print("\nConfusion Matrix:\n", cm_df)
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/rit_embeddings.csv
# ✅ Label encoder loaded from: ../Models/rit_label_encoder.pkl
# ℹ️ Splitting off 9 samples (20.00%) to test, to cover all 3 classes at least once.
# ⏳ Training started: 2025-05-13 19:37:57.464217
# ✅ Training finished: 2025-05-13 19:37:57.598648 (Duration: 0:00:00.134431)
# 📈 Accuracy: 1.0000
#
# Classification Report:
#                precision    recall  f1-score   support
#
#      Content       1.00      1.00      1.00         3
# Determinants       1.00      1.00      1.00         4
#     Location       1.00      1.00      1.00         2
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
#
#
# Confusion Matrix:
#                Content  Determinants  Location
# Content             3             0         0
# Determinants        0             4         0
# Location            0             0         2
# 🏃 View run rit Model Training and Evaluation Workflow at: http://127.0.0.1:5001/#/experiments/3/runs/b52f9442dcf3472f99999b88741936fa
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# Define paths
embeddings_csv_path = '../Embeddings/rit_embeddings.csv'
label_encoder_path    = "../Models/rit_label_encoder.pkl"
model_path            = "../Models/rit_rf_model.pkl"

# --- Load embeddings dataset ---
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Loaded embeddings from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Embeddings not found at: {embeddings_csv_path}")
    exit()

# Parse embedding strings
def parse_embedding(s):
    return np.array(eval(s))

df['Embedding'] = df['Embedding'].apply(parse_embedding)

# --- Load label encoder & model ---
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Loaded label encoder from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Label encoder not found at: {label_encoder_path}")
    exit()

try:
    clf = joblib.load(model_path)
    print(f"✅ Loaded model from: {model_path}")
except FileNotFoundError:
    print(f"❌ Model not found at: {model_path}")
    exit()

# --- Prepare X, y ---
X = np.stack(df['Embedding'].values)
y = df['Factor'].values
y_encoded = label_encoder.transform(y)

# --- Compute dynamic test fraction to ensure ≥1 sample/class ---
n_samples       = len(y_encoded)
n_classes       = len(np.unique(y_encoded))
min_test_samples = n_classes
frac_test_samples = int(np.ceil(0.2 * n_samples))
test_count      = max(min_test_samples, frac_test_samples)
test_fraction   = test_count / n_samples

print(f"ℹ️  Evaluating on {test_count} samples ({test_fraction:.2%}) "
      f"to cover all {n_classes} classes at least once.")

# --- Split ---
X_train, X_test, y_train, y_test = train_test_split(
    X, y_encoded,
    test_size=test_fraction,
    random_state=42,
    stratify=y_encoded
)

# --- MLflow run for evaluation ---
with mlflow.start_run(run_name="Evaluate RIT Model") as run:
    # log artifacts & params
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
    mlflow.log_artifact(model_path, artifact_path="model")
    mlflow.log_params({
        "Test Fraction": test_fraction,
        "Test Samples":  X_test.shape[0],
        "Random State":  42,
        "Stratify":      True
    })

    print("\n--- Model evaluation on test set ---")
    y_pred = clf.predict(X_test)

    # accuracy
    acc = accuracy_score(y_test, y_pred)
    mlflow.log_metric("Accuracy", acc)
    print(f"✅ Test Accuracy: {acc:.4f}")

    # classification report
    cr_dict = classification_report(
        y_test, y_pred,
        target_names=label_encoder.classes_,
        output_dict=True
    )
    cr_df = pd.DataFrame(cr_dict).transpose()
    cr_path = "rit_evaluation_classification_report.csv"
    cr_df.to_csv(cr_path, index=True)
    mlflow.log_artifact(cr_path, artifact_path="evaluation")
    print(f"📊 Saved classification report: {cr_path}")

    # confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    cm_df = pd.DataFrame(cm,
                         index=label_encoder.classes_,
                         columns=label_encoder.classes_)
    cm_path = "rit_evaluation_confusion_matrix.csv"
    cm_df.to_csv(cm_path, index=True)
    mlflow.log_artifact(cm_path, artifact_path="evaluation")
    print(f"📊 Saved confusion matrix CSV: {cm_path}")

    # plot confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm_df, annot=True, fmt='d', cmap='Blues',
                xticklabels=label_encoder.classes_,
                yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix (Test Set)')
    img_path = "rit_evaluation_confusion_matrix.png"
    plt.savefig(img_path)
    plt.close()
    mlflow.log_artifact(img_path, artifact_path="evaluation")
    print(f"🖼️ Saved confusion matrix plot: {img_path}")

print("\n✅ RIT Model evaluation complete.")
# Out:
# ✅ Loaded embeddings from: ../Embeddings/rit_embeddings.csv
# ✅ Loaded label encoder from: ../Models/rit_label_encoder.pkl
# ✅ Loaded model from: ../Models/rit_rf_model.pkl
# ℹ️  Evaluating on 9 samples (20.00%) to cover all 3 classes at least once.
#
# --- Model evaluation on test set ---
# ✅ Test Accuracy: 1.0000
# 📊 Saved classification report: rit_evaluation_classification_report.csv
# 📊 Saved confusion matrix CSV: rit_evaluation_confusion_matrix.csv
# 🖼️ Saved confusion matrix plot: rit_evaluation_confusion_matrix.png
# 🏃 View run Evaluate RIT Model at: http://127.0.0.1:5001/#/experiments/3/runs/cd7604d9b53e4d57b44da7a22062aa76
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3
#
# ✅ RIT Model evaluation complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/rit_label_encoder.pkl"
model_path = "../Models/rit_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/rit_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/rit_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Content
# Predicted Factor for 'I prefer staying home with a good book....': Location
# Predicted Factor for 'I often feel anxious and worried....': Location
# Predicted Factor for 'I am generally calm and relaxed....': Content
# Predicted Factor for 'I enjoy taking risks and trying new things....': Determinants
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5001/#/experiments/3/runs/ff8e0ee013534c9ea39ea8d5bcf0fb0d
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/rit_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="RIT Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/rit_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "rit_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/rit_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of RIT Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/rit_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of RIT Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/05/13 19:38:23 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Determinants
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Determinants
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Determinants
# Predicted Factor for 'Organized Meticulous Plan Planner': Content
# Predicted Factor for 'Moody Anxious Worry Worrier': Determinants
# 🏃 View run RIT Model Visualization and Evaluation at: http://127.0.0.1:5001/#/experiments/3/runs/9bdcb94bc9a1403f995ca618ab6e5d92
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/rit_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/rit_label_encoder.pkl"
        model_path = "../Models/rit_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of RIT Embeddings")

            # Save and log the plot
            pca_plot_path = "rit_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "rit_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/rit_embeddings.csv
#
# DataFrame with Embeddings:
#      Factor Adjective      Synonym      Verb           Noun  \
# 0  Location     Whole      Overall  Perceive          Whole
# 1  Location     Whole       Entire  Identify         Entity
# 2  Location     Whole       Global      View  Complete form
# 3  Location   Details  Particulars     Focus        Details
# 4  Location   Details    Specifics  Identify      Fragments
#
#                                            Embedding
# 0  [0.024969829246401787, -0.02679545432329178, 0...
# 1  [-0.010919989086687565, -0.021649299189448357,...
# 2  [0.014100281521677971, 0.04727916792035103, 0....
# 3  [-0.06766358762979507, -0.0018393141217529774,...
# 4  [-0.0405363105237484, 0.04887589067220688, 0.0...
#
# Shape of DataFrame:
# (45, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.02496983 -0.02679545  0.00279181 ...  0.00414446  0.0135744
#   0.01475222]
# ✅ Label encoder loaded from: ../Models/rit_label_encoder.pkl
#
# Shape of X:
# (45, 1536)
# ✅ PCA visualization saved to: rit_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: rit_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Content
# 🏃 View run Step 9: Model Application, Visualization, and Analysis at: http://127.0.0.1:5001/#/experiments/3/runs/7b1adb0ccd71494589a81c8b8da76375
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3
#
# ✅ Step 10: Save Model Visualization and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="rit_page_3"></a>
#
# [Back to Top](#rit_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/rit_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_rit.pkl')
clf = joblib.load('../Models/rit_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Content
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Content
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Content
# Predicted Factor for 'Organized Meticulous Plan Planner': Location
# Predicted Factor for 'Moody Anxious Worry Worrier': Content
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Content

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Location

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Content

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Content

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Determinants

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Content

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="RIT_page_4"></a>
#
#
# [Back to Top](#RIT_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("RIT")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# 2025/05/13 06:53:06 INFO mlflow.tracking.fluent: Experiment with name 'RIT' does not exist. Creating a new experiment.
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5001/#/experiments/3/runs/47ca4e3aa21543b69146a4b05b767c32
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# Neo4j connection settings
NEO4J_URI      = os.getenv("NEO4J_URI")
NEO4J_USER     = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")

# MLflow tracking
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
mlflow.set_experiment("MCMI")

def test_neo4j_connection(uri, user, password):
    graph = Graph(uri, auth=(user, password))
    return graph.run("RETURN 'Connection successful!' AS greeting").evaluate()

# Start MLflow run
with mlflow.start_run(run_name="Test & Clear Neo4j"):

    # 1) Test connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    mlflow.log_param("Connection Test", result)
    print(f"🔗 Connection test result: {result}")

    # 2) Clear the entire database (nodes + relationships)
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    graph.delete_all()
    mlflow.log_param("Database Cleared", True)
    print("🗑️  All nodes and relationships have been deleted.")

    # 3) (Optional) Confirm it's empty
    remaining = graph.run("MATCH (n) RETURN count(n) AS nodes").evaluate()
    mlflow.log_param("Remaining Nodes", remaining)
    print(f"📊 Remaining node count after clear: {remaining}")
# Out:
# 🔗 Connection test result: Connection successful!
# 🗑️  All nodes and relationships have been deleted.
# 📊 Remaining node count after clear: 0
# 🏃 View run Test & Clear Neo4j at: http://127.0.0.1:5001/#/experiments/2/runs/2fac8d01e2f64806a9ca70e2735ba127
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/2

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create RIT Schema in Neo4j** <a class="anchor" id="RIT_page_4"></a>
#
#
# [Back to Top](#RIT_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("RIT")

# Load the dataset
dataset_path = "../Embeddings/rit_embeddings.csv"
rit_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in rit_df.columns:
    rit_df['Embedding'] = rit_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the RIT schema in Neo4j
def create_rit_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with RIT labels
        graph.run("MERGE (f:RIT_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:RIT_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:RIT_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:RIT_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:RIT_Noun {name: $noun})", noun=noun)
        
        # Create relationships with RIT namespacing
        graph.run("""
            MATCH (f:RIT_Factor {name: $factor}), (a:RIT_Adjective {name: $adjective})
            MERGE (f)-[:RIT_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:RIT_Adjective {name: $adjective}), (s:RIT_Synonym {name: $synonym})
            MERGE (a)-[:RIT_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:RIT_Adjective {name: $adjective}), (v:RIT_Verb {name: $verb})
            MERGE (a)-[:RIT_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:RIT_Adjective {name: $adjective}), (n:RIT_Noun {name: $noun})
            MERGE (a)-[:RIT_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:RIT_Factor {name: $factor}), (a:RIT_Adjective {name: $adjective})
                MERGE (e:RIT_Embedding {value: $embedding})
                MERGE (f)-[:RIT_HAS_EMBEDDING]->(e)
                MERGE (a)-[:RIT_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create RIT Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create RIT Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the RIT schema
        create_rit_schema(graph, rit_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", rit_df.shape[0])
        mlflow.log_param("Number of Columns", rit_df.shape[1])
        
        # Print the DataFrame
        print(rit_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#      Factor Adjective      Synonym      Verb           Noun  \
# 0  Location     Whole      Overall  Perceive          Whole
# 1  Location     Whole       Entire  Identify         Entity
# 2  Location     Whole       Global      View  Complete form
# 3  Location   Details  Particulars     Focus        Details
# 4  Location   Details    Specifics  Identify      Fragments
#
#                                            Embedding
# 0  [0.024969829246401787, -0.02679545432329178, 0...
# 1  [-0.010919989086687565, -0.021649299189448357,...
# 2  [0.014100281521677971, 0.04727916792035103, 0....
# 3  [-0.06766358762979507, -0.0018393141217529774,...
# 4  [-0.0405363105237484, 0.04887589067220688, 0.0...
# 🏃 View run Create RIT Schema in Neo4j at: http://127.0.0.1:5001/#/experiments/3/runs/894e1a5755a144a4bb5957c59c4f2640
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/3

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:RIT_Factor OR n:RIT_Adjective OR n:RIT_Synonym OR n:RIT_Verb OR n:RIT_Noun)
# AND NOT m:RIT_Embedding
# RETURN n, r, m
# ```
