# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Minnesota Multiphasic Personality Inventory (MMPI)<a class="anchor" id="PTMD_page_19"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# The **Minnesota Multiphasic Personality Inventory (MMPI)** is a well-established psychological assessment tool commonly used in clinical settings to evaluate and understand various aspects of an individual's mental and emotional well-being. Developed by Drs. Starke R. Hathaway and J.C. McKinley in the late 1930s, the MMPI has since undergone several revisions, with the MMPI-2 and MMPI-2-RF (Restructured Form) being widely used today.
#
# **Key Features and Purpose:**
#
# 1. **Comprehensive Assessment:** The MMPI is designed to assess a broad range of psychological and emotional issues, making it a valuable tool for diagnosing mental health disorders, personality traits, and psychopathology.
#
# 2. **Objective Measurement:** Unlike some other assessment methods, the MMPI relies on a structured format with standardized questions. This objectivity helps reduce potential biases in the assessment process.
#
# 3. **Validity Scales:** The MMPI includes validity scales that help identify if a person is exaggerating or minimizing symptoms, providing valuable insights into the reliability of the responses.
#
# 4. **Clinical Scales:** The assessment consists of numerous clinical scales that evaluate various aspects of a person's psychological functioning. These scales cover areas such as depression, anxiety, paranoia, schizophrenia, and more.
#
# 5. **Profile Analysis:** Clinicians interpret a person's responses to the MMPI items to create a profile that can aid in diagnosing mental health conditions and understanding an individual's unique psychological makeup.
#
# 6. **Treatment Planning:** MMPI results can inform treatment planning by highlighting specific areas of concern and providing insights into a patient's emotional and cognitive functioning.
#
# **The MMPI Factors:**
#
# The MMPI assessment is divided into multiple factors, each of which addresses specific aspects of an individual's psychological state. These factors include:
#
# - **Hypochondriasis**: Evaluates concerns about physical health.
#
# - **Depression**: Assesses symptoms related to depression.
#
# - **Hysteria**: Measures emotional responses to stress.
#
# - **Psychopathic Deviate**: Examines deviant behaviors and social maladjustment.
#
# - **Masculinity/Femininity**: Assesses gender-related concerns.
#
# - **Paranoia**: Evaluates paranoid tendencies and suspiciousness.
#
# - **Psychasthenia**: Focuses on anxiety and obsessive-compulsive traits.
#
# - **Schizophrenia**: Assesses thought disorders and psychosis.
#
# - **Hypomania**: Examines manic or hypomanic tendencies.
#
# - **Social Introversion**: Measures introverted tendencies and social withdrawal.
#
# **Clinical Use:**
#
# The MMPI is widely employed by mental health professionals, including clinical psychologists, psychiatrists, and counselors, to aid in the diagnosis and treatment planning for various psychological conditions. It is valuable in clinical settings, forensic evaluations, and research studies.
#
# In conclusion, the Minnesota Multiphasic Personality Inventory (MMPI) is a comprehensive psychological assessment tool that has played a crucial role in understanding and diagnosing mental health conditions for many decades. Its structured format, extensive clinical scales, and validity measures make it a valuable resource for clinicians seeking insights into an individual's psychological well-being, ultimately aiding in the provision of effective mental health care.
#
# Timeline and reference table for the Minnesota Multiphasic Personality Inventory (MMPI) involves detailing the key developments of this widely used psychological assessment tool. The MMPI, developed originally by Starke R. Hathaway and J. C. McKinley, is a standardized psychometric test of adult personality and psychopathology.
#
# Here's the HTML table converted into a Markdown table:
#
# | Year | Milestone                                        | Contributor(s)                            | Original Work Reference                                                                                                          | Key Contributions                                                                | Additional Information                                                                                |
# |------|--------------------------------------------------|-------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------|-------------------------------------------------------------------------------------------------------|
# | 1943 | Introduction of the original MMPI.               | Starke R. Hathaway and J. C. McKinley     | Hathaway, S. R., & McKinley, J. C. (1943). "The Minnesota Multiphasic Personality Inventory".                                   | First comprehensive standardized tool for assessing adult personality and psychopathology. | Originally developed to aid in the assessment of psychiatric patients, it became widely used in various clinical settings. |
# | 1989 | Release of the MMPI-2.                           | University of Minnesota Press             | Butcher, J. N., et al. (1989). "MMPI-2: Minnesota Multiphasic Personality Inventory-2: Manual for Administration and Scoring". Minneapolis: University of Minnesota Press. | Revised version of the MMPI with updated norms and new content reflecting contemporary clinical findings. | MMPI-2 expanded its application to a broader range of contexts, including legal, medical, and employment settings.       |
# | 1992 | Introduction of the MMPI-A (Adolescent version). | James N. Butcher et al.                   | Butcher, J. N., et al. (1992). "MMPI-A: Minnesota Multiphasic Personality Inventory-Adolescent: Manual for Administration, Scoring, and Interpretation". Minneapolis: University of Minnesota Press. | Adapted the MMPI for use with adolescent populations.                                  | Allowed for more appropriate and accurate assessment of personality and psychopathology in adolescents.            |
# | 2008 | Launch of the MMPI-2 Restructured Form (MMPI-2-RF). | Yossef S. Ben-Porath and Auke Tellegen   | Ben-Porath, Y. S., & Tellegen, A. (2008). "MMPI-2-RF (Minnesota Multiphasic Personality Inventory-2 Restructured Form): Manual for administration, scoring, and interpretation". Minneapolis: University of Minnesota Press. | A shorter version with restructured scales for a more efficient assessment process. | Intended to improve the overall utility and effectiveness of the inventory in various assessment settings.          |
# | 2020s | Ongoing research and application.                 | Various Researchers                      | Recent academic publications and studies.                                                                                        | Further validation studies, adaptations for specific populations, and integration with contemporary psychological research. | Continues to be a primary instrument for psychological assessment, with evolving applications and interpretations.  |
#
# This Markdown table should be suitable for display in documentation and tools that support Markdown, providing a structured view of the MMPI development timeline.
# This table provides a comprehensive overview of the major developments in the Minnesota Multiphasic Personality Inventory (MMPI), highlighting key contributions and milestones. Each row represents a significant event in the history of the MMPI, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# The MMPI and its subsequent versions, MMPI-2 and MMPI-2-RF, have been foundational in the field of psychological assessment, widely used for diagnosing mental disorders, screening for psychopathology, and in various other contexts such as forensic evaluations, personnel selection, and clinical research.
#
# Here is the formatted markdown table for the provided .bib file entries:
#
# | ID | Author                                | Year | Title                                                                                                                    | Journal                                            | Volume | Pages      | DOI                                                                                         |
# |----|---------------------------------------|------|--------------------------------------------------------------------------------------------------------------------------|----------------------------------------------------|--------|------------|---------------------------------------------------------------------------------------------|
# | 1  | S. Hathaway, J. McKinley              | 1943 | The Minnesota multiphasic personality inventory, Rev. ed., 2nd printing                                                    | -                                                  | -      | -          | -                                                                                           |
# | 2  | Augustus Floyd, Vikas Gupta           | 2020 | Minnesota Multiphasic Personality Inventory                                                                               | -                                                  | -      | -          | [10.4135/9781483365817.n853](https://doi.org/10.4135/9781483365817.n853)                   |
# | 3  | R. Archer                             | 1997 | MMPI-A: Assessing adolescent psychopathology, 2nd ed.                                                                     | -                                                  | -      | -          | -                                                                                           |
# | 4  | Liberty Pg                            | 1964 | PERCEPTUAL DEFENSE, DISSIMULATION, AND RESPONSE STYLES.                                                                   | Journal of Consulting Psychology                   | 28     | 529-537    | [10.1037/H0044839](https://doi.org/10.1037/H0044839)                                         |
# | 5  | B. Glaser, Georgia B. Calhoun, John V. Petrocelli | 2002 | Personality Characteristics of Male Juvenile Offenders by Adjudicated Offenses as Indicated by the MMPI–A                 | Criminal Justice and Behavior                      | 29     | 183 - 201  | [10.1177/0093854802029002004](https://doi.org/10.1177/0093854802029002004)                 |
# | 6  | P. RobertArcher                       | 2005 | MMPI-A: Assessing Adolescent Psychopathology                                                                              | -                                                  | -      | -          | [10.4324/9781410612847](https://doi.org/10.4324/9781410612847)                             |
# | 7  | S. Hathaway, J. McKinley              | 1989 | MMPI-2 : Minnesota Multiphasic Personality Inventory-2 : manual for administration and scoring                            | -                                                  | -      | -          | -                                                                                           |
# | 8  | Edward A. Toyer, N. C. Weed           | 1998 | Concurrent validity of the MMPI-A in a counseling program for juvenile offenders.                                          | Journal of clinical psychology                     | 54 4   | 395-9      | [10.1002/(SICI)1097-4679(199806)54:4<395::AID-JCLP1>3.0.CO;2-N](https://doi.org/10.1002/(SICI)1097-4679(199806)54:4<395::AID-JCLP1>3.0.CO;2-N) |
# | 9  | T. L. Morton, K. Farris               | 2002 | MMPI-A Structural Summary Characteristics of Male Juvenile Delinquents                                                    | Assessment                                         | 9      | 327 - 333  | [10.1177/1073191102238151](https://doi.org/10.1177/1073191102238151)                       |
# | 10 | R. Hathaway, J. McKinley              | 1951 | Minnesota multiphasic personality inventory : manual                                                                      | -                                                  | -      | -          | -                                                                                           |
# | 11 | R. Archer                             | 1992 | MMPI-A: Assessing Adolescent Psychopathology                                                                              | -                                                  | -      | -          | -                                                                                           |
# | 12 | J. Graham                             | 1990 | MMPI-2 : Assessing Personality and Psychopathology                                                                        | -                                                  | -      | -          | [10.5860/choice.28-2421](https://doi.org/10.5860/choice.28-2421)                           |
# | 13 | P. Britton, R. Savage                 | 1966 | CHAPTER 10 – The Minnesota Multiphasic Personality Inventory                                                              | -                                                  | -      | -          | [10.1016/B978-1-4832-0087-3.50014-0](https://doi.org/10.1016/B978-1-4832-0087-3.50014-0)   |
# | 14 | Jerry S. Wiggins                      | 1966 | Substantive dimensions of self-report in the MMPI item pool.                                                              | Psychological monographs                            | 80 22  | 1-42       | [10.1037/H0093901](https://doi.org/10.1037/H0093901)                                         |
# | 15 | Liana M. Peña, E. Megargee, E. Brody  | 1996 | MMPI-A Patterns of Male Juvenile Delinquents.                                                                             | Psychological Assessment                            | 8      | 388-397    | [10.1037//1040-3590.8.4.388](https://doi.org/10.1037//1040-3590.8.4.388)                   |
# | 16 | D. Jackson, S. Messick                | 1962 | Response styles onthe MMPI: comparison of clinical and normal samples.                                                    | Journal of abnormal and social psychology          | 65     | 285-99     | [10.1037/H0045340](https://doi.org/10.1037/H0045340)                                       |
# | 17 | T. L. Morton, K. Farris, Lisa H Brenowitz | 2002 | MMPI-A scores and high points of male juvenile delinquents: scales 4, 5, and 6 as markers of juvenile delinquency.        | Psychological assessment                            | 14 3   | 311-9      | [10.1037//1040-3590.14.3.311](https://doi.org/10.1037//1040-3590.14.3.311)                 |
# | 18 | M. Cashel, Richard Rogers, K. Sewell, Neil B. Holliman | 1998 | Preliminary validation of the MMPI-A for a male delinquent sample: an investigation of clinical correlates and discriminant validity. | Journal of personality assessment                  | 71 1   | 49-69      | [10.1207/S15327752JPA7101_4](https://doi.org/10.1207/S15327752JPA7101_4)                   |
# | 19 | L. Savitz, S. Hathaway, E. D. Monachesi | 1963 | Adolescent Personality and Behavior: MMPI Patterns of Normal, Delinquent, Dropout, and Other Outcomes                     | -                                                  | -      | -          | [10.2307/2575982](https://doi.org/10.2307/2575982)                                         |
# | 20 | A. Comrey, A. Soufi                   | 1960 | Further Investigation of Some Factors Found in MMPI Items                                                                 | Educational and Psychological Measurement           | 20     | 777 - 786  | [10.1177/001316446002000414](https://doi.org/10.1177/001316446002000414)                   |
# | 21 | A. J. Conger                          | 1969 | A DIMENSIONAL ANALYSIS OF MMPI ITEMS.                                                                                     | Multivariate behavioral research                    | 4 3    | 309-27     | [10.1207/s15327906mbr0403_4](https://doi.org/10.1207/s15327906mbr0403_4)                   |
# | 22 | S. Messick, D. Jackson                | 1960 | Acquiescence and the factorial interpretation of the MMPI.                                                                | Psychological bulletin                              | 58     | 299-304    | [10.1002/J.2333-8504.1960.TB00097.X](https://doi.org/10.1002/J.2333-8504.1960.TB00097.X)   |
# | 23 | P. Dempsey                            | 1963 | THE DIMENSIONALITY OF THE MMPI CLINICAL SCALES AMONG NORMAL SUBJECTS.                                                     | Journal of consulting psychology                    | 27     | 492-7      | [10.1037/H0049185](https://doi.org/10.1037/H0049185)                                       |
# | 24 | A. Comrey                             | 1959 | Comparison of Two Analytic Rotation Procedures                                                                            | Psychological Reports                               | 5      | 201 - 209  | [10.2466/pr0.1959.5.3.201](https://doi.org/10.2466/pr0.1959.5.3.201)                       |
# | 25 | P. Shields                            | 1975 | Use of a Short Form of the Minnesota Multiphasic Personality Inventory with Alcoholics                                    | -                                                  | -      | -          | -                                                                                           |
# | 26 | C. Millimet                           | 1970 | Manifest Anxiety-Defensiveness Scale: First Factor of the MMPI Revisited                                                  | Psychological Reports                               | 27     | 603 - 616  | [10.2466/pr0.1970.27.2.603](https://doi.org/10.2466/pr0.1970.27.2.603)                     |
# | 27 | T. R. Faschingbauer                   | 1974 | A 166-item written short form of the group MMPI: The FAM.                                                                 | Journal of consulting and clinical psychology       | 42 5   | 645-55     | [10.1037/H0037049](https://doi.org/10.1037/H0037049)                                       |
# | 28 | A. L. Edwards, C. J. Diers, Jerald N. Walker | 1962 | Response sets and factor loadings on sixty-one personality scales.                                                        | Journal of Applied Psychology                       | 46     | 220-225    | [10.1037/H0040280](https://doi.org/10.1037/H0040280)                                       |
# | 29 | J. Lingoes                            | 1960 | MMPI factors of the Harris and the Wiener subscales.                                                                      | Journal of Consulting Psychology                    | 24     | 74-83      | [10.1037/H0043201](https://doi.org/10.1037/H0043201)                                       |
# | 30 | R. Cattell, L. Bolton                 | 1969 | What pathological dimensions lie beyond the normal dimensions of the 16 PF? A comparison of MMPI and 16 PF factor domains. | Journal of consulting and clinical psychology       | 33 1   | 18-29      | [10.1037/H0027379](https://doi.org/10.1037/H0027379)                                       |
# | 31 | A. Comrey                             | 1960 | Comparison of Certain Personality Variables in American and Italian Groups                                                | Educational and Psychological Measurement           | 20     | 541 - 550  | [10.1177/001316446002000311](https://doi.org/10.1177/001316446002000311)                   |
# | 32 | A. Heilbrun                           | 1964 | SOCIAL-LEARNING THEORY, SOCIAL DESIRABILITY, AND THE MMPI.                                                                | Psychological bulletin                              | 61     | 377-87     | [10.1037/H0048620](https://doi.org/10.1037/H0048620)                                       |
# | 33 | T. R. Faschingbauer                   | 1976 | Some clinical considerations in selecting a short form of the MMPI.                                                       | Professional Psychology                             | 7      | 167-176    | [10.1037//0735-7028.7.2.167](https://doi.org/10.1037//0735-7028.7.2.167)                   |
# | 34 | C. Newmark, L. Cook, M. Clarke, T. R. Faschingbauer | 1973 | Application of Faschingbauer's abbreviated MMPI to psychiatric inpatients.                                                | Journal of consulting and clinical psychology       | 41 3   | 416-21     | [10.1037/H0035200](https://doi.org/10.1037/H0035200)                                       |
# | 35 | J. Wiggins                            | 1962 | Strategic, method, and stylistic variance in the MMPI.                                                                    | Psychological bulletin                              | 59     | 224-42     | [10.1037/H0048092](https://doi.org/10.1037/H0048092)                                       |
# | 36 | J. Finney                             | 1961 | The MMPI as a measure of character structure as revealed by factor analysis.                                              | Journal of consulting psychology                    | 25     | 327-36     | [10.1037/H0042777](https://doi.org/10.1037/H0042777)                                       |
# | 37 | A. L. Edwards                         | 1964 | Social desirability and performance on the MMPI                                                                           | Psychometrika                                      | 29     | 295-308    | [10.1007/BF02289598](https://doi.org/10.1007/BF02289598)                                   |
# | 38 | R. Stewart                            | 1974 | Factor analysis and rotation of the 566 MMPI items                                                                        | Social Behavior and Personality                    | 2      | 147-156    | [10.2224/SBP.1974.2.2.147](https://doi.org/10.2224/SBP.1974.2.2.147)                       |
# | 39 | A. L. Edwards, J. A. Walsh            | 1963 | The relationship between the intensity of the social desirability keying of a scale and the correlation of the scale with Edwards' SD scale and the first factor loading of the scale | Journal of Clinical Psychology                      | 19     | 200-203    | [10.1002/1097-4679(196304)19:2<200::AID-JCLP2270190216>3.0.CO;2-6](https://doi.org/10.1002/1097-4679(196304)19:2<200::AID-JCLP2270190216>3.0.CO;2-6) |
# | 40 | J. Wiggins, V. R. Lovell             | 1965 | Communality and Favorability as Sources of Method Variance in the MMPI                                                     | Educational and Psychological Measurement           | 25     | 399 - 412  | [10.1177/001316446502500209](https://doi.org/10.1177/001316446502500209)                   |
# | 41 | J. Graham                             | 1978 | The Minnesota Multiphasic Personality Inventory (MMPI)                                                                     | -                                                  | -      | -          | [10.1007/978-1-4684-2490-4_10](https://doi.org/10.1007/978-1-4684-2490-4_10)               |
#
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %% [markdown]
# ##  Steps for MMPI Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (MMPI).
#     * **Actions:**
#         * Define the MMPI dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the MMPI dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the MMPI dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our MMPI Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up MMPI experiment
experiment_name = "MMPI"
mlflow.set_experiment(experiment_name)

# MMPI dataset 

mmpi_dataset = {
    'Hypochondriasis': {
        'Obsessed': {
            'Synonyms': ['Preoccupied', 'Absorbed', 'Engrossed', 'Fixated', 'Compulsive', 'Fanatical'],
            'Verbs': ['Obsess', 'Concentrate', 'Engross', 'Fixate', 'Compel', 'Ponder'],
            'Nouns': ['Obsession', 'Preoccupation', 'Absorption', 'Fixation', 'Compulsion', 'Fascination']
        },
        'Worried': {
            'Synonyms': ['Anxious', 'Nervous', 'Apprehensive', 'Tense', 'Distressed', 'Uneasy'],
            'Verbs': ['Worry', 'Fret', 'Stress', 'Panic', 'Agitate', 'Overthink'],
            'Nouns': ['Worry', 'Anxiety', 'Apprehension', 'Tension', 'Distress', 'Uneasiness']
        },
        'Complaining': {
            'Synonyms': ['Grousing', 'Grumbling', 'Moaning', 'Murmuring', 'Protesting', 'Whining'],
            'Verbs': ['Complain', 'Grumble', 'Moan', 'Murmur', 'Protest', 'Whine'],
            'Nouns': ['Complaint', 'Grumbling', 'Moan', 'Murmur', 'Protest', 'Whine']
        },
        'Fearful': {
            'Synonyms': ['Afraid', 'Panic-stricken', 'Hesitant', 'Cautious', 'Alarmed', 'Timid'],
            'Verbs': ['Fear', 'Dread', 'Tremble', 'Hesitate', 'Cower', 'Shrink'],
            'Nouns': ['Fear', 'Dread', 'Trembling', 'Hesitation', 'Cowardice', 'Timidity']
        },
        'Self-Diagnosing': {
            'Synonyms': ['Hypochondriac', 'Overanalyzing', 'Speculative', 'Worried', 'Fixated', 'Obsessive'],
            'Verbs': ['Diagnose', 'Speculate', 'Overanalyze', 'Fixate', 'Examine', 'Suspect'],
            'Nouns': ['Diagnosis', 'Speculation', 'Overanalysis', 'Fixation', 'Examination', 'Suspicion']
        },
        'Avoidant': {
            'Synonyms': ['Evading', 'Escaping', 'Dodging', 'Fleeing', 'Withdrawing', 'Hiding'],
            'Verbs': ['Avoid', 'Evade', 'Dodge', 'Escape', 'Withdraw', 'Hide'],
            'Nouns': ['Avoidance', 'Evasion', 'Dodging', 'Escape', 'Withdrawal', 'Concealment']
        }
    },
    'Depression': {
        'Sad': {
            'Synonyms': ['Unhappy', 'Downcast', 'Miserable', 'Gloomy', 'Melancholic', 'Dismal'],
            'Verbs': ['Sadden', 'Grieve', 'Mope', 'Despair', 'Lament', 'Mourn'],
            'Nouns': ['Sadness', 'Unhappiness', 'Misery', 'Gloom', 'Melancholy', 'Despondency']
        },
        'Hopeless': {
            'Synonyms': ['Despairing', 'Pessimistic', 'Despondent', 'Dejected', 'Forlorn', 'Resigned'],
            'Verbs': ['Despair', 'Lose hope', 'Depress', 'Demoralize', 'Resign', 'Surrender'],
            'Nouns': ['Hopelessness', 'Despair', 'Pessimism', 'Dejection', 'Forlornness', 'Resignation']
        },
        'Lethargic': {
            'Synonyms': ['Sluggish', 'Lazy', 'Inactive', 'Slow', 'Drowsy', 'Fatigued'],
            'Verbs': ['Languish', 'Stagnate', 'Dawdle', 'Laze', 'Drift', 'Procrastinate'],
            'Nouns': ['Lethargy', 'Sluggishness', 'Inactivity', 'Slowness', 'Fatigue', 'Indolence']
        },
        'Withdrawn': {
            'Synonyms': ['Isolated', 'Detached', 'Reclusive', 'Distant', 'Unresponsive', 'Aloof'],
            'Verbs': ['Withdraw', 'Retreat', 'Recluse', 'Detach', 'Shun', 'Avoid'],
            'Nouns': ['Withdrawal', 'Isolation', 'Reclusion', 'Detachment', 'Avoidance', 'Aloofness']
        },
        'Empty': {
            'Synonyms': ['Hollow', 'Void', 'Drained', 'Numb', 'Emotionless', 'Depleted'],
            'Verbs': ['Empty', 'Drain', 'Numb', 'Desensitize', 'Exhaust', 'Dissolve'],
            'Nouns': ['Emptiness', 'Hollowness', 'Void', 'Numbness', 'Exhaustion', 'Dissolution']
        },
        'Indifferent': {
            'Synonyms': ['Apathetic', 'Uninterested', 'Detached', 'Unconcerned', 'Unmoved', 'Disinterested'],
            'Verbs': ['Ignore', 'Dismiss', 'Neglect', 'Overlook', 'Avoid', 'Disregard'],
            'Nouns': ['Indifference', 'Apathy', 'Unconcern', 'Neglect', 'Disinterest', 'Disregard']
        }
    },
    'Hysteria': {
        'Emotional': {
            'Synonyms': ['Passionate', 'Sensitive', 'Fervent', 'Excitable', 'Expressive', 'Reactive'],
            'Verbs': ['Emote', 'Sensitize', 'Enthuse', 'Excite', 'React', 'Express'],
            'Nouns': ['Emotionality', 'Sensitivity', 'Fervor', 'Excitability', 'Expression', 'Reactivity']
        },
        'Dramatic': {
            'Synonyms': ['Theatrical', 'Showy', 'Exaggerated', 'Melodramatic', 'Flashy', 'Overstated'],
            'Verbs': ['Dramatize', 'Exaggerate', 'Perform', 'Theatricalize', 'Display', 'Amplify'],
            'Nouns': ['Drama', 'Showiness', 'Exaggeration', 'Melodrama', 'Flashiness', 'Overstatement']
        },
        'Erratic': {
            'Synonyms': ['Unpredictable', 'Inconsistent', 'Irregular', 'Variable', 'Capricious', 'Impulsive'],
            'Verbs': ['Fluctuate', 'Vary', 'Alternate', 'Diverge', 'Waver', 'Oscillate'],
            'Nouns': ['Erraticism', 'Inconsistency', 'Irregularity', 'Variability', 'Capriciousness', 'Impulsivity']
        },
        'Attention-Seeking': {
            'Synonyms': ['Needy', 'Craving', 'Seeking validation', 'Showy', 'Exhibitionist', 'Performative'],
            'Verbs': ['Seek attention', 'Crave approval', 'Display', 'Perform', 'Show off', 'Dramatize'],
            'Nouns': ['Attention-seeking', 'Validation-seeking', 'Exhibitionism', 'Performance', 'Display', 'Showmanship']
        },
        'Hyperactive': {
            'Synonyms': ['Overactive', 'Restless', 'Fidgety', 'Agitated', 'Impulsive', 'Tense'],
            'Verbs': ['Fidget', 'Move restlessly', 'Agitate', 'Twitch', 'Bounce', 'Shift'],
            'Nouns': ['Hyperactivity', 'Restlessness', 'Fidgeting', 'Agitation', 'Tension', 'Impulsiveness']
        },
        'Unstable': {
            'Synonyms': ['Volatile', 'Turbulent', 'Erratic', 'Inconstant', 'Unpredictable', 'Moody'],
            'Verbs': ['Shift', 'Waver', 'Unbalance', 'Change suddenly', 'Explode emotionally', 'React impulsively'],
            'Nouns': ['Instability', 'Volatility', 'Turbulence', 'Mood swings', 'Unpredictability', 'Emotional lability']
        }
    },
    'Psychopathic_Deviate': {
        'Rebellious': {
            'Synonyms': ['Defiant', 'Insurgent', 'Dissident', 'Revolutionary', 'Resistant', 'Oppositional'],
            'Verbs': ['Rebel', 'Defy', 'Rise', 'Overthrow', 'Challenge', 'Oppose'],
            'Nouns': ['Rebellion', 'Defiance', 'Insurgence', 'Revolution', 'Resistance', 'Opposition']
        },
        'Unstable': {
            'Synonyms': ['Inconsistent', 'Unpredictable', 'Erratic', 'Fickle', 'Mercurial', 'Capricious'],
            'Verbs': ['Fluctuate', 'Vacillate', 'Oscillate', 'Waver', 'Shift', 'Alter unpredictably'],
            'Nouns': ['Instability', 'Inconsistency', 'Unpredictability', 'Fickleness', 'Mercuriality', 'Capriciousness']
        },
        'Manipulative': {
            'Synonyms': ['Devious', 'Scheming', 'Cunning', 'Machiavellian', 'Calculating', 'Strategic'],
            'Verbs': ['Manipulate', 'Scheme', 'Connive', 'Machinate', 'Influence', 'Control covertly'],
            'Nouns': ['Manipulation', 'Scheming', 'Cunning', 'Machiavellianism', 'Deception', 'Influence']
        },
        'Aggressive': {
            'Synonyms': ['Hostile', 'Confrontational', 'Assertive', 'Violent', 'Antagonistic', 'Forceful'],
            'Verbs': ['Attack', 'Confront', 'Dominate', 'Intimidate', 'Force', 'Threaten'],
            'Nouns': ['Aggression', 'Hostility', 'Confrontation', 'Violence', 'Antagonism', 'Threat']
        },
        'Impulsive': {
            'Synonyms': ['Reckless', 'Spontaneous', 'Unpredictable', 'Hot-headed', 'Careless', 'Unrestrained'],
            'Verbs': ['Act impulsively', 'Rush', 'Jump to action', 'Make rash decisions', 'Ignore consequences', 'React suddenly'],
            'Nouns': ['Impulsivity', 'Recklessness', 'Spontaneity', 'Hot-headedness', 'Carelessness', 'Unrestraint']
        },
        'Risk-Taking': {
            'Synonyms': ['Daring', 'Adventurous', 'Thrill-seeking', 'Bold', 'Fearless', 'Audacious'],
            'Verbs': ['Take risks', 'Push limits', 'Dare', 'Challenge danger', 'Gamble', 'Expose oneself'],
            'Nouns': ['Risk-taking', 'Adventurousness', 'Thrill-seeking', 'Boldness', 'Fearlessness', 'Audacity']
        }
    },
    'Masculinity_Femininity': {
        'Nonconforming': {
            'Synonyms': ['Unorthodox', 'Nonstandard', 'Atypical', 'Unconventional', 'Radical', 'Defiant'],
            'Verbs': ['Diverge', 'Deviate', 'Vary', 'Differ', 'Challenge', 'Resist'],
            'Nouns': ['Nonconformity', 'Unorthodoxy', 'Atypicality', 'Unconventionality', 'Radicalism', 'Defiance']
        },
        'Androgynous': {
            'Synonyms': ['Epicene', 'Hermaphroditic', 'Unisex', 'Bisexual', 'Ambiguous', 'Fluid'],
            'Verbs': ['Blend', 'Mix', 'Combine', 'Merge', 'Unify', 'Balance'],
            'Nouns': ['Androgyny', 'Epicenity', 'Unisexuality', 'Bisexuality', 'Ambiguity', 'Fluidity']
        },
        'Flexible': {
            'Synonyms': ['Adaptable', 'Versatile', 'Accommodating', 'Compliant', 'Open-minded', 'Tolerant'],
            'Verbs': ['Adapt', 'Modify', 'Adjust', 'Accommodate', 'Accept', 'Tolerate'],
            'Nouns': ['Flexibility', 'Adaptability', 'Versatility', 'Compliance', 'Openness', 'Tolerance']
        },
        'Traditional': {
            'Synonyms': ['Conventional', 'Customary', 'Established', 'Orthodox', 'Time-honored', 'Rigid'],
            'Verbs': ['Conform', 'Maintain', 'Preserve', 'Follow', 'Adhere', 'Respect'],
            'Nouns': ['Tradition', 'Custom', 'Establishment', 'Orthodoxy', 'Conformity', 'Rigidity']
        },
        'Assertive': {
            'Synonyms': ['Confident', 'Dominant', 'Strong-willed', 'Decisive', 'Determined', 'Authoritative'],
            'Verbs': ['Assert', 'Command', 'Dominate', 'Decide', 'Lead', 'Direct'],
            'Nouns': ['Assertion', 'Dominance', 'Strength', 'Decision', 'Determination', 'Authority']
        },
        'Nurturing': {
            'Synonyms': ['Caring', 'Supportive', 'Compassionate', 'Empathetic', 'Protective', 'Gentle'],
            'Verbs': ['Nurture', 'Support', 'Care for', 'Protect', 'Guide', 'Encourage'],
            'Nouns': ['Nurturing', 'Support', 'Compassion', 'Empathy', 'Protection', 'Gentleness']
        }
    },
    'Paranoia': {
        'Suspicious': {
            'Synonyms': ['Distrustful', 'Dubious', 'Skeptical', 'Cautious', 'Apprehensive', 'Guarded'],
            'Verbs': ['Suspect', 'Distrust', 'Doubt', 'Question', 'Scrutinize', 'Examine'],
            'Nouns': ['Suspicion', 'Distrust', 'Skepticism', 'Cautiousness', 'Apprehension', 'Wariness']
        },
        'Persecuted': {
            'Synonyms': ['Victimized', 'Oppressed', 'Mistreated', 'Abused', 'Tormented', 'Targeted'],
            'Verbs': ['Persecute', 'Victimize', 'Oppress', 'Abuse', 'Torment', 'Harass'],
            'Nouns': ['Persecution', 'Victimization', 'Oppression', 'Abuse', 'Torment', 'Harassment']
        },
        'Delusional': {
            'Synonyms': ['Fantasist', 'Daydreamer', 'Visionary', 'Idealist', 'Hallucinatory', 'Irrational'],
            'Verbs': ['Delude', 'Fantasize', 'Envision', 'Dream', 'Hallucinate', 'Misinterpret'],
            'Nouns': ['Delusion', 'Fantasy', 'Vision', 'Idealism', 'Hallucination', 'Misinterpretation']
        },
        'Defensive': {
            'Synonyms': ['Protective', 'Wary', 'Guarded', 'Hyper-vigilant', 'Sensitive', 'Reactive'],
            'Verbs': ['Defend', 'Protect', 'React', 'Shield', 'Justify', 'Guard'],
            'Nouns': ['Defensiveness', 'Protection', 'Guarding', 'Reaction', 'Justification', 'Shielding']
        },
        'Isolated': {
            'Synonyms': ['Withdrawn', 'Lonely', 'Detached', 'Aloof', 'Disconnected', 'Distant'],
            'Verbs': ['Isolate', 'Withdraw', 'Detach', 'Alienate', 'Separate', 'Seclude'],
            'Nouns': ['Isolation', 'Withdrawal', 'Detachment', 'Alienation', 'Separation', 'Seclusion']
        },
        'Hypervigilant': {
            'Synonyms': ['Watchful', 'Alert', 'Cautious', 'On edge', 'Nervous', 'Guarded'],
            'Verbs': ['Watch', 'Monitor', 'Scan', 'Survey', 'Observe', 'Analyze'],
            'Nouns': ['Hypervigilance', 'Alertness', 'Caution', 'Edginess', 'Nervousness', 'Surveillance']
        }
    },
    'Psychasthenia': {
        'Obsessive': {
            'Synonyms': ['Compulsive', 'Fixated', 'Preoccupied', 'Consumed', 'Driven', 'Persistent'],
            'Verbs': ['Obsess', 'Compel', 'Fixate', 'Preoccupy', 'Persevere', 'Repeat'],
            'Nouns': ['Obsession', 'Compulsion', 'Fixation', 'Preoccupation', 'Persistence', 'Repetition']
        },
        'Anxious': {
            'Synonyms': ['Worried', 'Apprehensive', 'Nervous', 'Stressed', 'Tense', 'Uneasy'],
            'Verbs': ['Worry', 'Fret', 'Panic', 'Stress', 'Agitate', 'Brood'],
            'Nouns': ['Anxiety', 'Worry', 'Apprehension', 'Stress', 'Tension', 'Uneasiness']
        },
        'Insecure': {
            'Synonyms': ['Uncertain', 'Unconfident', 'Unsure', 'Doubtful', 'Self-conscious', 'Hesitant'],
            'Verbs': ['Doubt', 'Waver', 'Hesitate', 'Falter', 'Question', 'Second-guess'],
            'Nouns': ['Insecurity', 'Uncertainty', 'Doubt', 'Hesitation', 'Self-doubt', 'Ambivalence']
        },
        'Perfectionist': {
            'Synonyms': ['Exacting', 'Fastidious', 'Meticulous', 'Detail-oriented', 'Uncompromising', 'Scrupulous'],
            'Verbs': ['Refine', 'Perfect', 'Critique', 'Adjust', 'Fine-tune', 'Polish'],
            'Nouns': ['Perfectionism', 'Exactness', 'Meticulousness', 'Scrutiny', 'Flawlessness', 'Precision']
        },
        'Rigid': {
            'Synonyms': ['Strict', 'Unyielding', 'Inflexible', 'Dogmatic', 'Stern', 'Uncompromising'],
            'Verbs': ['Enforce', 'Dictate', 'Control', 'Regulate', 'Mandate', 'Restrict'],
            'Nouns': ['Rigidity', 'Strictness', 'Inflexibility', 'Dogmatism', 'Severity', 'Toughness']
        },
        'Overwhelmed': {
            'Synonyms': ['Burdened', 'Overcome', 'Swamped', 'Helpless', 'Distressed', 'Frazzled'],
            'Verbs': ['Overload', 'Drown', 'Exhaust', 'Pressure', 'Struggle', 'Collapse'],
            'Nouns': ['Overwhelm', 'Burden', 'Exhaustion', 'Distress', 'Pressure', 'Strain']
        }
    },
    'Schizophrenia': {
        'Delusional': {
            'Synonyms': ['Illusional', 'Fantasist', 'Visionary', 'Unreal', 'Hallucinatory', 'Misguided'],
            'Verbs': ['Misinterpret', 'Imagine', 'Envision', 'Distort', 'Hallucinate', 'Fabricate'],
            'Nouns': ['Delusion', 'Fantasy', 'Vision', 'Unreality', 'Hallucination', 'Misconception']
        },
        'Disconnected': {
            'Synonyms': ['Detached', 'Aloof', 'Disassociated', 'Unattached', 'Withdrawn', 'Unresponsive'],
            'Verbs': ['Detach', 'Withdraw', 'Disassociate', 'Separate', 'Retreat', 'Isolate'],
            'Nouns': ['Detachment', 'Aloofness', 'Disassociation', 'Separation', 'Withdrawal', 'Isolation']
        },
        'Chaotic': {
            'Synonyms': ['Disordered', 'Confused', 'Disorganized', 'Haphazard', 'Erratic', 'Frantic'],
            'Verbs': ['Disrupt', 'Confuse', 'Disorganize', 'Scramble', 'Derange', 'Scatter'],
            'Nouns': ['Chaos', 'Confusion', 'Disorganization', 'Disarray', 'Turmoil', 'Anarchy']
        },
        'Hallucinatory': {
            'Synonyms': ['Imaginary', 'Unreal', 'Fanciful', 'Dreamlike', 'Surreal', 'Phantasmagoric'],
            'Verbs': ['Hallucinate', 'Envision', 'Perceive falsely', 'Daydream', 'Conjure', 'Misinterpret'],
            'Nouns': ['Hallucination', 'Vision', 'Fantasy', 'Dream', 'Illusion', 'Specter']
        },
        'Disoriented': {
            'Synonyms': ['Confused', 'Lost', 'Dazed', 'Bewildered', 'Perplexed', 'Discombobulated'],
            'Verbs': ['Lose track', 'Forget', 'Wander', 'Drift', 'Space out', 'Misjudge'],
            'Nouns': ['Disorientation', 'Confusion', 'Dizziness', 'Perplexity', 'Unawareness', 'Fog'],
        },
        'Fragmented': {
            'Synonyms': ['Broken', 'Scattered', 'Splintered', 'Disconnected', 'Unstable', 'Disjointed'],
            'Verbs': ['Shatter', 'Separate', 'Scatter', 'Disintegrate', 'Divide', 'Segment'],
            'Nouns': ['Fragmentation', 'Disconnection', 'Splintering', 'Shattering', 'Breakdown', 'Divisiveness']
        }
    },
    'Hypomania': {
        'Energetic': {
            'Synonyms': ['Active', 'Vigorous', 'Dynamic', 'Lively', 'Exuberant', 'Hyperactive'],
            'Verbs': ['Energize', 'Stimulate', 'Activate', 'Animate', 'Invigorate', 'Charge up'],
            'Nouns': ['Energy', 'Vigor', 'Dynamism', 'Vivacity', 'Exuberance', 'Hyperactivity']
        },
        'Impulsive': {
            'Synonyms': ['Rash', 'Reckless', 'Hasty', 'Sudden', 'Unthinking', 'Spontaneous'],
            'Verbs': ['Act impulsively', 'Rush', 'Hasten', 'React', 'Leap', 'Plunge'],
            'Nouns': ['Impulsiveness', 'Recklessness', 'Haste', 'Suddenness', 'Spontaneity', 'Rashness']
        },
        'Excitable': {
            'Synonyms': ['Enthusiastic', 'Passionate', 'Fervent', 'Eager', 'Overzealous', 'Restless'],
            'Verbs': ['Excite', 'Enthuse', 'Stir', 'Arouse', 'Agitate', 'Overreact'],
            'Nouns': ['Excitability', 'Enthusiasm', 'Fervor', 'Eagerness', 'Overzealousness', 'Restlessness']
        },
        'Talkative': {
            'Synonyms': ['Chatty', 'Loquacious', 'Garrulous', 'Expressive', 'Verbose', 'Effusive'],
            'Verbs': ['Talk', 'Chat', 'Express', 'Ramble', 'Gush', 'Elaborate'],
            'Nouns': ['Talkativeness', 'Loquacity', 'Garrulousness', 'Expression', 'Verbosity', 'Effusiveness']
        },
        'Restless': {
            'Synonyms': ['Agitated', 'Fidgety', 'Uneasy', 'Hyperactive', 'Unsettled', 'Tense'],
            'Verbs': ['Fidget', 'Pace', 'Wander', 'Twitch', 'Shift', 'Move about'],
            'Nouns': ['Restlessness', 'Agitation', 'Fidgeting', 'Uneasiness', 'Tension', 'Hyperactivity']
        },
        'Grandiose': {
            'Synonyms': ['Boastful', 'Pompous', 'Exaggerated', 'Inflated', 'Overconfident', 'Pretentious'],
            'Verbs': ['Boast', 'Exaggerate', 'Brag', 'Overestimate', 'Flaunt', 'Declare grandly'],
            'Nouns': ['Grandiosity', 'Boastfulness', 'Pompousness', 'Exaggeration', 'Overconfidence', 'Pretension']
        }
    },
    'Social_Introversion': {
        'Reserved': {
            'Synonyms': ['Restrained', 'Withdrawn', 'Introverted', 'Shy', 'Taciturn', 'Quiet'],
            'Verbs': ['Reserve', 'Withdraw', 'Retreat', 'Inhibit', 'Hold back', 'Restrain'],
            'Nouns': ['Reservation', 'Withdrawal', 'Introversion', 'Shyness', 'Taciturnity', 'Quietness']
        },
        'Shy': {
            'Synonyms': ['Bashful', 'Retiring', 'Modest', 'Self-conscious', 'Timid', 'Hesitant'],
            'Verbs': ['Shy away', 'Retreat', 'Modest', 'Self-monitor', 'Blush', 'Avoid eye contact'],
            'Nouns': ['Shyness', 'Bashfulness', 'Modesty', 'Self-consciousness', 'Timidity', 'Hesitation']
        },
        'Quiet': {
            'Synonyms': ['Silent', 'Still', 'Hushed', 'Muted', 'Soft-spoken', 'Muffled'],
            'Verbs': ['Quiet', 'Silence', 'Still', 'Muffle', 'Whisper', 'Suppress'],
            'Nouns': ['Quietness', 'Silence', 'Stillness', 'Muteness', 'Soft-spokenness', 'Suppression']
        },
        'Aloof': {
            'Synonyms': ['Detached', 'Distant', 'Cold', 'Unapproachable', 'Standoffish', 'Reclusive'],
            'Verbs': ['Detach', 'Withdraw', 'Ignore', 'Remain distant', 'Isolate', 'Avoid'],
            'Nouns': ['Aloofness', 'Detachment', 'Distance', 'Coldness', 'Standoffishness', 'Reclusion']
        },
        'Lonely': {
            'Synonyms': ['Isolated', 'Alone', 'Desolate', 'Solitary', 'Forlorn', 'Abandoned'],
            'Verbs': ['Isolate', 'Withdraw', 'Lament', 'Miss company', 'Feel abandoned', 'Long for connection'],
            'Nouns': ['Loneliness', 'Isolation', 'Solitude', 'Desolation', 'Forlornness', 'Abandonment']
        },
        'Avoidant': {
            'Synonyms': ['Evasive', 'Hesitant', 'Unassertive', 'Fearful', 'Apprehensive', 'Timorous'],
            'Verbs': ['Avoid', 'Evade', 'Withdraw', 'Hesitate', 'Back away', 'Sidestep'],
            'Nouns': ['Avoidance', 'Evasion', 'Hesitation', 'Fearfulness', 'Apprehension', 'Timidity']
        }
    }
}


#Create a list to store the dataset
data = []
for factor, attributes in mmpi_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
mmpi_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/mmpi.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="MMPI Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "MMPI")
    mlflow.log_param("Total Rows", len(mmpi_df))
    mlflow.log_param("Total Factors", len(mmpi_dataset))
    mlflow.log_param("Data Schema", str(mmpi_df.columns.tolist()))
    
    # Save dataset to CSV
    mmpi_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ MMPI dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(mmpi_df.head())
    print("\nDataset shape:", mmpi_df.shape)
    print("\nNumber of unique Factors:", mmpi_df['Factor'].nunique())
    print("Unique Factors:", mmpi_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# 2025/03/18 10:44:12 INFO mlflow.tracking.fluent: Experiment with name 'MMPI' does not exist. Creating a new experiment.
# ✅ MMPI dataset created and saved to ../Datasets/mmpi.csv
# First 5 rows of the dataset:
#             Factor Adjective      Synonym         Verb           Noun
# 0  Hypochondriasis  Obsessed  Preoccupied       Obsess      Obsession
# 1  Hypochondriasis  Obsessed     Absorbed  Concentrate  Preoccupation
# 2  Hypochondriasis  Obsessed    Engrossed      Engross     Absorption
# 3  Hypochondriasis  Obsessed      Fixated       Fixate       Fixation
# 4  Hypochondriasis  Obsessed   Compulsive       Compel     Compulsion
#
# Dataset shape: (360, 5)
#
# Number of unique Factors: 10
# Unique Factors: ['Hypochondriasis' 'Depression' 'Hysteria' 'Psychopathic_Deviate'
#  'Masculinity_Femininity' 'Paranoia' 'Psychasthenia' 'Schizophrenia'
#  'Hypomania' 'Social_Introversion']
# 📌 MLflow tracking active under experiment 'MMPI' (ID: 29)
# 🏃 View run MMPI Dataset Creation at: http://127.0.0.1:5000/#/experiments/29/runs/0a44a66ae4824866b7af78eb0f3b11fa
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="mmpi_page_2"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/29/runs/2e34882e618d44ed95862238d6773374
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="mmpi_page_2"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.01842307485640049, -0.007206822745501995, 0.003606583457440138, -0.05420342832803726, -0.02272433042526245, 0.03694765642285347, 0.02900492399930954, 0.023840880021452904, 0.011241628788411617, -0.02061811089515686]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/29/runs/19a684a2fdea4d259ad1d36adffd744a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create MMPI Embeddings** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved mmpi dataset from a CSV file
dataset_path = '../Datasets/mmpi.csv'
try:
    mmpi_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'mmpi_df' is empty before processing
        if mmpi_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", mmpi_df.shape[0])
            print(f"📊 Processing {mmpi_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        mmpi_df['Embedding'] = mmpi_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/mmpi_embeddings.csv'
        mmpi_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = mmpi_df.shape[0]
        num_columns = mmpi_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in mmpi_df.columns and not mmpi_df['Embedding'].empty:
            embedding_length = len(mmpi_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(mmpi_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/mmpi.csv
# ⏳ Embedding generation started at: 2025-03-18 10:44:15.483383
# 📊 Processing 360 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-18 10:47:40.836993 (Duration: 0:03:25.353610)
# 💾 Embeddings saved to: ../Embeddings/mmpi_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#             Factor Adjective      Synonym         Verb           Noun  \
# 0  Hypochondriasis  Obsessed  Preoccupied       Obsess      Obsession
# 1  Hypochondriasis  Obsessed     Absorbed  Concentrate  Preoccupation
# 2  Hypochondriasis  Obsessed    Engrossed      Engross     Absorption
# 3  Hypochondriasis  Obsessed      Fixated       Fixate       Fixation
# 4  Hypochondriasis  Obsessed   Compulsive       Compel     Compulsion
#
#                                            Embedding
# 0  [0.005175873637199402, -0.012785390019416809, ...
# 1  [-0.0028013763949275017, 0.0016069132834672928...
# 2  [0.010020424611866474, 0.008909480646252632, 0...
# 3  [-0.003477463498711586, 0.004757723771035671, ...
# 4  [0.000840134744066745, 0.004242482595145702, 0...
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5000/#/experiments/29/runs/476b1a6d494a4ed1b8a2d483db970e6e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/mmpi_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/mmpi_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "mmpi_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/mmpi_embeddings.csv
# 💾 Label encoder saved to: ../Models/mmpi_label_encoder.pkl
#
# First 5 rows with encoded labels:
#             Factor  Factor_Encoded
# 0  Hypochondriasis               1
# 1  Hypochondriasis               1
# 2  Hypochondriasis               1
# 3  Hypochondriasis               1
# 4  Hypochondriasis               1
#
# Mapping of original labels to encoded labels:
# Depression: 0
# Hypochondriasis: 1
# Hypomania: 2
# Hysteria: 3
# Masculinity_Femininity: 4
# Paranoia: 5
# Psychasthenia: 6
# Psychopathic_Deviate: 7
# Schizophrenia: 8
# Social_Introversion: 9
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/mmpi_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: mmpi_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/29/runs/934af480b8384ca287a8e3fe8fff5b19
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/mmpi_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/mmpi_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="mmpi Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "mmpi_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "mmpi_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "mmpi_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/mmpi_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/mmpi_embeddings.csv
# ✅ Label encoder loaded from: ../Models/mmpi_label_encoder.pkl
# ⏳ Model training started at: 2025-03-18 10:47:44.610634
# ✅ Model training finished at: 2025-03-18 10:47:45.173518 (Duration: 0:00:00.562884)
# 📊 Classification report saved to: mmpi_classification_report.csv
# 📊 Confusion matrix saved to: mmpi_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: mmpi_confusion_matrix.png
# 💾 Trained model saved to: ../Models/mmpi_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#             Depression       1.00      1.00      1.00         7
#        Hypochondriasis       1.00      1.00      1.00         7
#              Hypomania       1.00      1.00      1.00         7
#               Hysteria       1.00      1.00      1.00         8
# Masculinity_Femininity       1.00      1.00      1.00         7
#               Paranoia       1.00      1.00      1.00         7
#          Psychasthenia       1.00      1.00      1.00         8
#   Psychopathic_Deviate       1.00      1.00      1.00         7
#          Schizophrenia       1.00      1.00      1.00         7
#    Social_Introversion       1.00      1.00      1.00         7
#
#               accuracy                           1.00        72
#              macro avg       1.00      1.00      1.00        72
#           weighted avg       1.00      1.00      1.00        72
#
#
# Confusion Matrix:
#                          Depression  Hypochondriasis  Hypomania  Hysteria  \
# Depression                       7                0          0         0
# Hypochondriasis                  0                7          0         0
# Hypomania                        0                0          7         0
# Hysteria                         0                0          0         8
# Masculinity_Femininity           0                0          0         0
# Paranoia                         0                0          0         0
# Psychasthenia                    0                0          0         0
# Psychopathic_Deviate             0                0          0         0
# Schizophrenia                    0                0          0         0
# Social_Introversion              0                0          0         0
#
#                         Masculinity_Femininity  Paranoia  Psychasthenia  \
# Depression                                   0         0              0
# Hypochondriasis                              0         0              0
# Hypomania                                    0         0              0
# Hysteria                                     0         0              0
# Masculinity_Femininity                       7         0              0
# Paranoia                                     0         7              0
# Psychasthenia                                0         0              8
# Psychopathic_Deviate                         0         0              0
# Schizophrenia                                0         0              0
# Social_Introversion                          0         0              0
#
#                         Psychopathic_Deviate  Schizophrenia  \
# Depression                                 0              0
# Hypochondriasis                            0              0
# Hypomania                                  0              0
# Hysteria                                   0              0
# Masculinity_Femininity                     0              0
# Paranoia                                   0              0
# Psychasthenia                              0              0
# Psychopathic_Deviate                       7              0
# Schizophrenia                              0              7
# Social_Introversion                        0              0
#
#                         Social_Introversion
# Depression                                0
# Hypochondriasis                           0
# Hypomania                                 0
# Hysteria                                  0
# Masculinity_Femininity                    0
# Paranoia                                  0
# Psychasthenia                             0
# Psychopathic_Deviate                      0
# Schizophrenia                             0
# Social_Introversion                       7
# 🏃 View run mmpi Model Training and Evaluation Workflow at: http://127.0.0.1:5000/#/experiments/29/runs/0b40b88a719b4ea382601ada83d02596
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/mmpi_embeddings.csv'
label_encoder_path = "../Models/mmpi_label_encoder.pkl"
model_path = "../Models/mmpi_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate MMPI Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate MMPI Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "mmpi_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "mmpi_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "mmpi_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ MMPI Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/mmpi_embeddings.csv
# ✅ Label encoder loaded from: ../Models/mmpi_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/mmpi_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: mmpi_evaluation_classification_report.csv
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#             Depression       1.00      1.00      1.00         7
#        Hypochondriasis       1.00      1.00      1.00         7
#              Hypomania       1.00      1.00      1.00         7
#               Hysteria       1.00      1.00      1.00         8
# Masculinity_Femininity       1.00      1.00      1.00         7
#               Paranoia       1.00      1.00      1.00         7
#          Psychasthenia       1.00      1.00      1.00         8
#   Psychopathic_Deviate       1.00      1.00      1.00         7
#          Schizophrenia       1.00      1.00      1.00         7
#    Social_Introversion       1.00      1.00      1.00         7
#
#               accuracy                           1.00        72
#              macro avg       1.00      1.00      1.00        72
#           weighted avg       1.00      1.00      1.00        72
#
# 📊 Confusion matrix saved to: mmpi_evaluation_confusion_matrix.csv
#
# Confusion Matrix:
#                          Depression  Hypochondriasis  Hypomania  Hysteria  \
# Depression                       7                0          0         0
# Hypochondriasis                  0                7          0         0
# Hypomania                        0                0          7         0
# Hysteria                         0                0          0         8
# Masculinity_Femininity           0                0          0         0
# Paranoia                         0                0          0         0
# Psychasthenia                    0                0          0         0
# Psychopathic_Deviate             0                0          0         0
# Schizophrenia                    0                0          0         0
# Social_Introversion              0                0          0         0
#
#                         Masculinity_Femininity  Paranoia  Psychasthenia  \
# Depression                                   0         0              0
# Hypochondriasis                              0         0              0
# Hypomania                                    0         0              0
# Hysteria                                     0         0              0
# Masculinity_Femininity                       7         0              0
# Paranoia                                     0         7              0
# Psychasthenia                                0         0              8
# Psychopathic_Deviate                         0         0              0
# Schizophrenia                                0         0              0
# Social_Introversion                          0         0              0
#
#                         Psychopathic_Deviate  Schizophrenia  \
# Depression                                 0              0
# Hypochondriasis                            0              0
# Hypomania                                  0              0
# Hysteria                                   0              0
# Masculinity_Femininity                     0              0
# Paranoia                                   0              0
# Psychasthenia                              0              0
# Psychopathic_Deviate                       7              0
# Schizophrenia                              0              7
# Social_Introversion                        0              0
#
#                         Social_Introversion
# Depression                                0
# Hypochondriasis                           0
# Hypomania                                 0
# Hysteria                                  0
# Masculinity_Femininity                    0
# Paranoia                                  0
# Psychasthenia                             0
# Psychopathic_Deviate                      0
# Schizophrenia                             0
# Social_Introversion                       7
# 🖼️ Confusion matrix plot saved to: mmpi_evaluation_confusion_matrix.png
# 🏃 View run Evaluate MMPI Model at: http://127.0.0.1:5000/#/experiments/29/runs/3dbf1ef2088d40d1bc979471d13e86c6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29
#
# ✅ MMPI Model evaluation on the test set complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/mmpi_label_encoder.pkl"
model_path = "../Models/mmpi_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/mmpi_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/mmpi_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Hypomania
# Predicted Factor for 'I prefer staying home with a good book....': Social_Introversion
# Predicted Factor for 'I often feel anxious and worried....': Paranoia
# Predicted Factor for 'I am generally calm and relaxed....': Paranoia
# Predicted Factor for 'I enjoy taking risks and trying new things....': Hypomania
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/29/runs/c3e969ae288b46a8a57db7ccb44a8845
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/mmpi_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="MMPI Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/mmpi_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "mmpi_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/mmpi_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of MMPI Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/mmpi_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of MMPI Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/18 10:47:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Hypomania
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Hypochondriasis
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Hypomania
# Predicted Factor for 'Organized Meticulous Plan Planner': Psychopathic_Deviate
# Predicted Factor for 'Moody Anxious Worry Worrier': Hypochondriasis
# 🏃 View run MMPI Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/29/runs/6fcdeafa29d44facbafff0b0396d83c8
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/mmpi_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/mmpi_label_encoder.pkl"
        model_path = "../Models/mmpi_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of MMPI Embeddings")

            # Save and log the plot
            pca_plot_path = "mmpi_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "mmpi_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/mmpi_embeddings.csv
#
# DataFrame with Embeddings:
#             Factor Adjective      Synonym         Verb           Noun  \
# 0  Hypochondriasis  Obsessed  Preoccupied       Obsess      Obsession
# 1  Hypochondriasis  Obsessed     Absorbed  Concentrate  Preoccupation
# 2  Hypochondriasis  Obsessed    Engrossed      Engross     Absorption
# 3  Hypochondriasis  Obsessed      Fixated       Fixate       Fixation
# 4  Hypochondriasis  Obsessed   Compulsive       Compel     Compulsion
#
#                                            Embedding
# 0  [0.005175873637199402, -0.012785390019416809, ...
# 1  [-0.0028013763949275017, 0.0016069132834672928...
# 2  [0.010020424611866474, 0.008909480646252632, 0...
# 3  [-0.003477463498711586, 0.004757723771035671, ...
# 4  [0.000840134744066745, 0.004242482595145702, 0...
#
# Shape of DataFrame:
# (360, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.00517587 -0.01278539  0.01384441 ... -0.01235056 -0.01744929
#   0.00983977]
# ✅ Label encoder loaded from: ../Models/mmpi_label_encoder.pkl
#
# Shape of X:
# (360, 1536)
# ✅ PCA visualization saved to: mmpi_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: mmpi_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Hypomania
# 🏃 View run Step 9: Model Application, Visualization, and Analysis at: http://127.0.0.1:5000/#/experiments/29/runs/6e4538d38b2c4b469a6c595e52271745
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29
#
# ✅ Step 10: Save Model Visualization and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean cross-validation score: 1.0

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="mmpi_page_3"></a>
#
# [Back to Top](#mmpi_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/mmpi_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_mmpi.pkl')
clf = joblib.load('../Models/mmpi_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Hypomania
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Depression
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Paranoia
# Predicted Factor for 'Organized Meticulous Plan Planner': Psychopathic_Deviate
# Predicted Factor for 'Moody Anxious Worry Worrier': Hypochondriasis
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Depression

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Hypochondriasis

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Paranoia

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Hypochondriasis

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Depression

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Depression

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="MMPI_page_4"></a>
#
#
# [Back to Top](#MMPI_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("MMPI")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/29/runs/6aa7ce5176cc4e5db711b2379ec4b6a0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create MMPI Schema in Neo4j** <a class="anchor" id="MMPI_page_4"></a>
#
#
# [Back to Top](#MMPI_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("MMPI")

# Load the dataset
dataset_path = "../Embeddings/mmpi_embeddings.csv"
mmpi_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in mmpi_df.columns:
    mmpi_df['Embedding'] = mmpi_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the MMPI schema in Neo4j
def create_mmpi_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with MMPI labels
        graph.run("MERGE (f:MMPI_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:MMPI_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:MMPI_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:MMPI_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:MMPI_Noun {name: $noun})", noun=noun)
        
        # Create relationships with MMPI namespacing
        graph.run("""
            MATCH (f:MMPI_Factor {name: $factor}), (a:MMPI_Adjective {name: $adjective})
            MERGE (f)-[:MMPI_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:MMPI_Adjective {name: $adjective}), (s:MMPI_Synonym {name: $synonym})
            MERGE (a)-[:MMPI_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:MMPI_Adjective {name: $adjective}), (v:MMPI_Verb {name: $verb})
            MERGE (a)-[:MMPI_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:MMPI_Adjective {name: $adjective}), (n:MMPI_Noun {name: $noun})
            MERGE (a)-[:MMPI_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:MMPI_Factor {name: $factor}), (a:MMPI_Adjective {name: $adjective})
                MERGE (e:MMPI_Embedding {value: $embedding})
                MERGE (f)-[:MMPI_HAS_EMBEDDING]->(e)
                MERGE (a)-[:MMPI_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create MMPI Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create MMPI Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the MMPI schema
        create_mmpi_schema(graph, mmpi_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", mmpi_df.shape[0])
        mlflow.log_param("Number of Columns", mmpi_df.shape[1])
        
        # Print the DataFrame
        print(mmpi_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#             Factor Adjective      Synonym         Verb           Noun  \
# 0  Hypochondriasis  Obsessed  Preoccupied       Obsess      Obsession
# 1  Hypochondriasis  Obsessed     Absorbed  Concentrate  Preoccupation
# 2  Hypochondriasis  Obsessed    Engrossed      Engross     Absorption
# 3  Hypochondriasis  Obsessed      Fixated       Fixate       Fixation
# 4  Hypochondriasis  Obsessed   Compulsive       Compel     Compulsion
#
#                                            Embedding
# 0  [0.005175873637199402, -0.012785390019416809, ...
# 1  [-0.0028013763949275017, 0.0016069132834672928...
# 2  [0.010020424611866474, 0.008909480646252632, 0...
# 3  [-0.003477463498711586, 0.004757723771035671, ...
# 4  [0.000840134744066745, 0.004242482595145702, 0...
# 🏃 View run Create MMPI Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/29/runs/c0e71481226f4b35b55972119cb3a8c5
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/29

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:MMPI_Factor OR n:MMPI_Adjective OR n:MMPI_Synonym OR n:MMPI_Verb OR n:MMPI_Noun)
# AND NOT m:MMPI_Embedding
# RETURN n, r, m
# ```
