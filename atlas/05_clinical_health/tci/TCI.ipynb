# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Temperament and Character Inventory (TCI)<a class="anchor" id="PTMD_page_20"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# The **Temperament and Character Inventory (TCI)** is a widely used psychological assessment tool developed by Dr. C. Robert Cloninger, a psychiatrist and researcher, to measure various aspects of an individual's personality and psychological functioning. The TCI is based on Cloninger's psychobiological model of personality, which suggests that personality is influenced by both genetic and environmental factors.
#
# **Key Features and Purpose:**
#
# 1. **Comprehensive Assessment:** The TCI provides a comprehensive assessment of an individual's personality, focusing on two main components: temperament and character.
#
# 2. **Temperament Traits:** The TCI assesses four primary temperament traits:
#    - **Novelty Seeking:** Measures a person's inclination towards seeking new experiences, excitement, and adventure.
#    - **Harm Avoidance:** Evaluates the degree to which an individual is motivated to avoid harm, danger, or punishment.
#    - **Reward Dependence:** Assesses the extent to which a person is responsive to social approval and positive reinforcement.
#    - **Persistence:** Measures an individual's ability to persevere and maintain motivation in the face of frustration or fatigue.
#
# 3. **Character Traits:** The TCI also evaluates three character traits:
#    - **Self-Directedness:** Reflects an individual's autonomy, self-control, and ability to set and achieve personal goals.
#    - **Cooperativeness:** Assesses a person's capacity for empathy, tolerance, and harmonious social interactions.
#    - **Self-Transcendence:** Measures an individual's ability to go beyond their personal concerns and connect with broader, transcendent values and experiences.
#
# 4. **Psychobiological Model:** The TCI is grounded in the idea that personality is influenced by both genetic factors (temperament) and life experiences (character), providing a holistic understanding of an individual's psychological makeup.
#
# 5. **Clinical and Research Use:** Mental health professionals, including psychiatrists and psychologists, use the TCI for clinical assessments, treatment planning, and understanding personality disorders. Researchers also employ it to investigate personality-related phenomena and their links to mental health.
#
# **Clinical Applications:**
#
# - **Diagnosis and Treatment Planning:** The TCI assists clinicians in understanding a patient's personality structure, which can be valuable for diagnosing and developing personalized treatment plans, particularly in the field of psychiatry.
#
# - **Personality Disorders:** It can aid in the assessment and diagnosis of personality disorders, such as borderline personality disorder, narcissistic personality disorder, and others.
#
# - **Psychological Research:** Researchers use the TCI to explore the relationships between personality traits and various psychological phenomena, including mental health disorders, addiction, and well-being.
#
# - **Personal Development:** Some individuals may use the TCI for personal insight and growth, gaining a better understanding of their own temperament and character traits to facilitate personal development.
#
# In summary, the Temperament and Character Inventory (TCI) is a multifaceted psychological assessment tool that delves into an individual's personality structure by examining temperament and character traits. Developed by Dr. C. Robert Cloninger, this instrument has significant applications in clinical practice, aiding in diagnosis and treatment planning, as well as in psychological research to better understand the complexities of human personality and its relationship to mental health.
#
# Timeline and reference table for the Temperament and Character Inventory (TCI) involves outlining the key developments of this psychological assessment tool. Developed by Dr. C. Robert Cloninger, the TCI is a self-report questionnaire designed to measure different components of personality based on Cloninger's psychobiological model of temperament and character. Here's a hypothetical timeline and reference table:
#
# | Year         | Milestone                                 | Contributor(s)                   | Original Work Reference                                                                                           | Key Contributions                                                                                             | Additional Information                                                                                               |
# |--------------|-------------------------------------------|----------------------------------|-------------------------------------------------------------------------------------------------------------------|---------------------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------|
# | 1993         | Introduction of the TCI.                  | C. Robert Cloninger              | Cloninger, C. R., Przybeck, T. R., Svrakic, D. M., & Wetzel, R. D. (1993). "The Temperament and Character Inventory (TCI): A Guide to its Development and Use". | Presented a comprehensive inventory for assessing the seven dimensions of temperament and character.           | The TCI was based on Cloninger’s psychobiological model of personality, distinguishing between heritable temperament traits and character traits influenced by social and environmental factors. |
# | 1994         | Publication of the TCI Manual.            | C. Robert Cloninger              | Cloninger, C. R. (1994). "Temperament and Character Inventory (TCI): A Manual".                                   | Provided detailed information on the administration, scoring, and interpretation of the TCI.                    | The manual facilitated the broader use of the TCI in both research and clinical settings.                             |
# | Late 1990s   | Validation and Adaptation of the TCI.     | Various Researchers              | Multiple studies and publications in academic journals.                                                           | Studies focusing on the validation of the TCI across different cultures and populations.                        | Highlighted the applicability of the TCI in diverse contexts and its reliability as a measure of personality.        |
# | 2000s        | Further Refinements and Updates.          | C. Robert Cloninger and colleagues | Updated versions of the TCI, incorporating new research findings.                                                 | Continuous improvement of the inventory to enhance its accuracy and applicability.                             | Reflected ongoing research in psychobiology and personality theory.                                                  |
# | 2010s-Present | Ongoing Research and Applications.       | Various Scholars and Practitioners | Recent academic publications and studies.                                                                         | Further exploration of the TCI in different areas such as psychiatric research, personality psychology, and neuroscience. | Demonstrates the enduring influence and relevance of the TCI in understanding personality.                           |
#
# This table provides an overview of the major developments in the Temperament and Character Inventory, highlighting key contributions and milestones. Each row represents a significant event in the history of the TCI, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# The TCI, with its basis in Cloninger's psychobiological model, has been instrumental in advancing the understanding of personality. Its applications extend across clinical psychology, psychiatric research, and personality studies, offering insights into the biological and psychological underpinnings of individual differences in temperament and character. The inventory's continued use and research signify its importance in the field of psychological assessment.
#
# | #    | Author(s)                                                   | Year | Title                                                                                                                                                                     | Journal/Source                                                    | Volume | Pages          | DOI                                                            | URL                                                               |
# |------|-------------------------------------------------------------|------|---------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------------------------------------|--------|----------------|----------------------------------------------------------------|-------------------------------------------------------------------|
# | 1    | C. Cloninger                                                 | 1994 | The temperament and character inventory (TCI) : a guide to its development and use                                                                                        | -                                                                 | -      | -              | -                                                              | [Link](https://www.semanticscholar.org/paper/5ad0a428dd0a4cebb6f38ba926c7f3ea572d34a0) |
# | 2    | L. Young, R. Bagby, R. Cooke, J. Parker, A. Levitt, R. Joffe | 1995 | A comparison of Tridimensional Personality Questionnaire dimensions in bipolar disorder and unipolar depression                                                            | Psychiatry Research                                                | 58     | 139-143        | [10.1016/0165-1781(95)02684-O](https://doi.org/10.1016/0165-1781(95)02684-O) | [Link](https://www.semanticscholar.org/paper/b590c1117111f0092f2f71bcdb65152f251ac957) |
# | 3    | J. Richter, S. Brändström, T. Przybeck                      | 1999 | Assessing Personality: The Temperament and Character Inventory in a Cross-Cultural Comparison between Germany, Sweden, and the USA                                         | Psychological Reports                                              | 84     | 1315 - 1330    | [10.2466/pr0.1999.84.3c.1315](https://doi.org/10.2466/pr0.1999.84.3c.1315) | [Link](https://www.semanticscholar.org/paper/af4caa31610d742c37c2de53d0e4a6359237a378) |
# | 4    | M. Hansenne, W. Pitchot, A. González Moreno, P. Machurot, M. Ansseau | 1998 | The tridimensional personality questionnaire (TPQ) and depression                                                                                                         | European Psychiatry                                                | 13     | 101 - 103      | [10.1016/S0924-9338(98)80026-6](https://doi.org/10.1016/S0924-9338(98)80026-6) | [Link](https://www.semanticscholar.org/paper/af72a164e2b35bb6acdd5d58adbf6856b832a288) |
# | 5    | N. Kijima, E. Tanaka, N. Suzuki, Hina Higuchi, T. Kitamura   | 2000 | Reliability and Validity of the Japanese Version of the Temperament and Character Inventory                                                   | Psychological Reports                                              | 86     | 1050 - 1058    | [10.2466/pr0.2000.86.3.1050](https://doi.org/10.2466/pr0.2000.86.3.1050) | [Link](https://www.semanticscholar.org/paper/2f8ec8fc4b4a95aada96d3cc394fbab640499d0b) |
# | 6    | S. Brändström, S. Sigvardsson, P. Nylander, J. Richter       | 2008 | The Swedish version of the Temperament and Character Inventory (TCI)                                                                                                       | European Journal of Psychological Assessment                      | 24     | 14-21          | [10.1027/1015-5759.24.1.14](https://doi.org/10.1027/1015-5759.24.1.14) | [Link](https://www.semanticscholar.org/paper/786b8aa315aa47fb773076b7585bc2dd808e2c02) |
# | 7    | C. Cloninger, T. Przybeck, D. Svrakic                       | 1991 | The Tridimensional Personality Questionnaire: U.S. Normative Data                                                                                                         | Psychological Reports                                              | 69     | 1047 - 1057    | [10.2466/pr0.1991.69.3.1047](https://doi.org/10.2466/pr0.1991.69.3.1047) | [Link](https://www.semanticscholar.org/paper/575cac8366d68815f849f496243bee7e4aa0b099) |
# | 8    | S. Loftus, J. L. Garno, J. Jaeger, A. Malhotra               | 2008 | Temperament and character dimensions in bipolar I disorder: a comparison to healthy controls.                                                                             | Journal of psychiatric research                                    | 42 13  | 1131-6         | [10.1016/j.jpsychires.2007.11.005](https://doi.org/10.1016/j.jpsychires.2007.11.005) | [Link](https://www.semanticscholar.org/paper/4cabe314c150cfe0175e7f6f28bdc926d5aaf10e) |
# | 9    | Seung Mo Sung, Jong Heun Kim, Eunjoo Yang, KELLEY YOST Abrams, I. Lyoo | 2002 | Reliability and validity of the Korean version of the Temperament and Character Inventory.                                                                                  | Comprehensive psychiatry                                           | 43 3   | 235-43         | [10.1053/COMP.2002.30794](https://doi.org/10.1053/COMP.2002.30794) | [Link](https://www.semanticscholar.org/paper/b178157782c40006e94a882ec6747a51c806a3d7) |
# | 10   | H. Soderstrom, M. Råstam, C. Gillberg                        | 2002 | Temperament and Character in Adults with Asperger Syndrome                                                                                                                 | Autism                                                             | 6      | 287 - 297      | [10.1177/1362361302006003006](https://doi.org/10.1177/1362361302006003006) | [Link](https://www.semanticscholar.org/paper/4c6c7a819568ba90cd391218207941020b36afaa) |
# | 11   | F. Gutiérrez, N. Torrens, T. Boget, R. Martín-Santos, J. Sangorrín, G. Pérez, M. Salamero | 2001 | Psychometric properties of the Temperament and Character Inventory (TCI) questionnaire in a Spanish psychiatric population                                                | Acta Psychiatrica Scandinavica                                     | 103    | -              | [10.1034/j.1600-0447.2001.00183.x](https://doi.org/10.1034/j.1600-0447.2001.00183.x) | [Link](https://www.semanticscholar.org/paper/eab73b71eea97216e49a0df84915eddfb8a3d892) |
# | 12   | A. Peirson, J. Heuchert                                   | 2001 | The relationship between personality and mood: comparison of the BDI and the TCI                                                                                          | Personality and Individual Differences                             | 30     | 391-399        | [10.1016/S0191-8869(00)00031-3](https://doi.org/10.1016/S0191-8869(00)00031-3) | [Link](https://www.semanticscholar.org/paper/c22df7cbec71338b3e3aaedf423be5e0aa3322b0) |
# | 13   | N. Waller, S. Lilienfeld, A. Tellegen, D. Lykken            | 1991 | The Tridimensional Personality Questionnaire: Structural Validity and Comparison with the Multidimensional Personality Questionnaire.                                     | Multivariate behavioral research                                   | 26 1   | 1-23           | [10.1207/s15327906mbr2601_1](https://doi.org/10.1207/s15327906mbr2601_1) | [Link](https://www.semanticscholar.org/paper/52e9250bb3a97eca28cab89ee3c0d615eef1638f) |
# | 14   | N. Gillespie, C. Cloninger, A. Heath, N. Martin             | 2003 | The genetic and environmental relationship between Cloninger's dimensions of temperament and character.                                                                   | Personality and individual differences                              | 35 8   | 1931-1946      | [10.1016/S0191-8869(03)00042-4](https://doi.org/10.1016/S0191-8869(03)00042-4) | [Link](https://www.semanticscholar.org/paper/27f291eb5e8479463620600838740e9f27870630) |
# | 15   | M. Hansenne, W. Pitchot, A. Moreno, J. Reggers, P. Machurot, M. Ansseau | 1997 | Harm avoidance dimension of the tridimensional personality questionnaire and serotonin-1A activity in depressed patients                                                  | Biological Psychiatry                                               | 42     | 959-961        | [10.1016/S0006-3223(97)00325-9](https://doi.org/10.1016/S0006-3223(97)00325-9) | [Link](https://www.semanticscholar.org/paper/ab5dd1484d3f9a6bcecd0ff4ac20bb18eed6f708) |
# | 16   | M. Hansenne, J. Reggers, E. Pinto, K. Kjiri, Amar Ajamier, Marc Ansseau | 1999 | Temperament and character inventory (TCI) and depression.                                                                                                                  | Journal of psychiatric research                                     | 33 1   | 31-6           | [10.1016/S0022-3956(98)00036-3](https://doi.org/10.1016/S0022-3956(98)00036-3) | [Link](https://www.semanticscholar.org/paper/85cebd49fcf61132a1fdb31b5bdab5d2555a2678) |
# | 17   | M. Hansenne, M. Delhez, C. Robert Cloninger                 | 2005 | Psychometric Properties of the Temperament and Character Inventory–Revised (TCI–R) in a Belgian Sample                                                                   | Journal of Personality Assessment                                   | 85     | 40 - 49        | [10.1207/s15327752jpa8501_04](https://doi.org/10.1207/s15327752jpa8501_04) | [Link](https://www.semanticscholar.org/paper/15cb7d0493f0e6275595350a8cb0033a72744d3c) |
# | 18   | G. Marijnissen, S. Tuinier, A. Sijben, W. Verhoeven         | 2002 | The temperament and character inventory in major depression.                                                                                                               | Journal of affective disorders                                      | 70 2   | 219-23         | [10.1016/S0165-0327(01)00364-0](https://doi.org/10.1016/S0165-0327(01)00364-0) | [Link](https://www.semanticscholar.org/paper/51e75fafd885ae245df99a023f076759560daa70) |
# | 19   | F. Celikel, S. Kose, B. Cumurcu, U. Erkorkmaz, K. Sayar, J. Borckardt, C. Robert Cloninger | 2009 | Cloninger's temperament and character dimensions of personality in patients with major depressive disorder.                                                                | Comprehensive psychiatry                                           | 50 6   | 556-61         | [10.1016/j.comppsych.2008.11.012](https://doi.org/10.1016/j.comppsych.2008.11.012) | [Link](https://www.semanticscholar.org/paper/6bc4aa8b4f4d4309f128cf6dcf241cdfe8d88f01) |
# | 20   | T. Sato, T. Narita, S. Hirano, K. Kusunoki, M. Goto, K. Sakado, T. Uehara | 2001 | Factor validity of the temperament and character inventory in patients with major depression.                                                                               | Comprehensive psychiatry                                           | 42 4   | 337-41         | [10.1053/COMP.2001.24587](https://doi.org/10.1053/COMP.2001.24587) | [Link](https://www.semanticscholar.org/paper/ae404a179cc9646b5c11e5588c372079325f7402) |
# | 21   | P. Jylhä, E. Isometsä                                      | 2006 | Temperament, character and symptoms of anxiety and depression in the general population                                                                                     | European Psychiatry                                                | 21     | 389 - 395      | [10.1016/j.eurpsy.2005.09.003](https://doi.org/10.1016/j.eurpsy.2005.09.003) | [Link](https://www.semanticscholar.org/paper/03e3f38bc227447f09149181c6b78d2a36e10061) |
# | 22   | M. Naito, N. Kijima, T. Kitamura                           | 2000 | Temperament and Character Inventory (TCI) as predictors of depression among Japanese college students.                                                                     | Journal of clinical psychology                                      | 56 12  | 1579-85        | [10.1002/1097-4679(200012)56:12<1579::AID-8>3.0.CO;2-K](https://doi.org/10.1002/1097-4679(200012)56:12<1579::AID-8>3.0.CO;2-K) | [Link](https://www.semanticscholar.org/paper/492eb4e531dc61c0324cbcbf0b7e8bcae4506bb7) |
# | 23   | K. Black, Y. Sheline                                       | 1997 | Personality disorder scores improve with effective pharmacotherapy of depression.                                                                                         | Journal of affective disorders                                      | 43 1   | 11-8           | [10.1016/S0165-0327(96)00101-2](https://doi.org/10.1016/S0165-0327(96)00101-2) | [Link](https://www.semanticscholar.org/paper/4fe7e3060bd9f95c6868878276d354c7efbdc236) |
# | 24   | S. Hirano, Tetsuya Sato, T. Narita, K. Kusunoki, N. Ozaki, Satoshi Kimura, Toshihiko Takahashi, K. Sakado, T. Uehara | 2002 | Evaluating the state dependency of the Temperament and Character Inventory dimensions in patients with major depression: a methodological contribution.                    | Journal of affective disorders                                      | 69 1-3 | 31-8           | [10.1016/S0165-0327(00)00329-3](https://doi.org/10.1016/S0165-0327(00)00329-3) | [Link](https://www.semanticscholar.org/paper/1e3d42839c8498780a911da4a28a7c318fefaebe) |
# | 25   | J. Richter, T. Polak, M. Eisemann                           | 2003 | Depressive mood and personality in terms of temperament and character among the normal population and depressive inpatients                                                  | Personality and Individual Differences                              | 35     | 917-927        | [10.1016/S0191-8869(02)00308-2](https://doi.org/10.1016/S0191-8869(02)00308-2) | [Link](https://www.semanticscholar.org/paper/337271e1f9ef43fa15d5b6cb0e94841d2343129c) |
# | 26   | C. Bayon, K. Hill, D. Svrakic, T. Przybeck, C. Cloninger    | 1996 | Dimensional assessment of personality in an out-patient sample: relations of the systems of Millon and Cloninger.                                                          | Journal of psychiatric research                                     | 30 5   | 341-52         | [10.1016/0022-3956(96)00024-6](https://doi.org/10.1016/0022-3956(96)00024-6) | [Link](https://www.semanticscholar.org/paper/faf44acd173c2acf724352c076bbb4d04460621f) |
# | 27   | KELLEY YOST Abrams, Sook Kyeong Yune, Seog Ju Kim, H. Jeon, SOO JUNG Han, Jaeuk Hwang, Y. Sung, KYUNG JIN Lee, I. Lyoo | 2004 | Trait and state aspects of harm avoidance and its implication for treatment in major depressive disorder, dysthymic disorder, and depressive personality disorder           | Psychiatry and Clinical Neurosciences                                | 58     | -              | [10.1111/j.1440-1819.2004.01226.x](https://doi.org/10.1111/j.1440-1819.2004.01226.x) | [Link](https://www.semanticscholar.org/paper/ede9d660430cbbb8def8b6d33ad99ca4f8a18e46) |
# | 28   | Danny J. Smith, L. Duffy, Mary E. Stewart, W. Muir, D. Blackwood | 2005 | High harm avoidance and low self-directedness in euthymic young adults with recurrent, early-onset depression.                                                             | Journal of affective disorders                                      | 87 1   | 83-9           | [10.1016/J.JAD.2005.03.014](https://doi.org/10.1016/J.JAD.2005.03.014) | [Link](https://www.semanticscholar.org/paper/c744935ba279fc3c5611ce26f19466ccb152cb2c) |
# | 29   | E. Corruble, C. Duret, A. Pelissolo, B. Falissard, J. Guelfi | 2002 | Early and delayed personality changes associated with depression recovery? a one-year follow-up study                                                                     | Psychiatry Research                                                | 109    | 17-25          | [10.1016/S0165-1781(01)00366-3](https://doi.org/10.1016/S0165-1781(01)00366-3) | [Link](https://www.semanticscholar.org/paper/bef84d87390f7c7d7cac3290357ae54ae7438dbf) |
# | 30   | J. A. Gutiérrez-Zotes, C. Bayon, C. Montserrat, J. Valero, A. Labad, C. Robert Cloninger, F. Fernández-Aranda | 2004 | [Temperament and Character Inventory Revised (TCI-R). Standardization and normative data in a general population sample].                                                  | Actas espanolas de psiquiatria                                     | 32 1   | 8-15           | -                                                              | [Link](https://www.semanticscholar.org/paper/e7f3077b182568976f575ecf381c6e194dafb7d1) |
# | 31   | C. Cloninger, D. Svrakic, T. Przybeck                      | 2006 | Can personality assessment predict future depression? A twelve-month follow-up of 631 subjects.                                                                           | Journal of affective disorders                                      | 92 1   | 35-44          | [10.1016/J.JAD.2005.12.034](https://doi.org/10.1016/J.JAD.2005.12.034) | [Link](https://www.semanticscholar.org/paper/11b16ec947c7d80ef1d249035e8cc71d6f1d854c) |
# | 32   | M. Hansenne, O. Bon, Anne-Karine Gauthier, M. Ansseau       | 2001 | Belgian normative data of the temperament and character inventory                                                                               | European Journal of Psychological Assessment                        | 17     | 56-62          | [10.1027//1015-5759.17.1.56](https://doi.org/10.1027//1015-5759.17.1.56) | [Link](https://www.semanticscholar.org/paper/2676129d10afb77b714f95601c734bb517ddde72) |
# | 33   | J. Miettunen, L. Kantojärvi, J. Ekelund, J. Veijola, J. T. Karvonen, L. Peltonen, M. Järvelin, N. Freimer, D. Lichtermann, M. Joukamaa | 2004 | A large population cohort provides normative data for investigation of temperament                                                             | Acta Psychiatrica Scandinavica                                     | 110    | -              | [10.1111/j.1600-0047.2004.00344.x](https://doi.org/10.1111/j.1600-0047.2004.00344.x) | [Link](https://www.semanticscholar.org/paper/6313121e0f9d58a3dfd48df5a9ab038e42d47313) |
# | 34   | C. Cloninger, T. Przybeck, D. Svrakic, Wetzel Rd            | 2011 | Temperament and Character Inventory                                                                                                                                        | -                                                                 | -      | -              | [10.1037/T03902-000](https://doi.org/10.1037/T03902-000)        | [Link](https://www.semanticscholar.org/paper/3bcf1c4ec20101890c252d30548cd77dbe260b87) |
# | 35   | M. Hansenne, W. Pitchot, E. Pinto, J. Reggers, P. Papart, M. Ansseau | 2000 | P300 event-related brain potential and personality in depression                                                                                | European Psychiatry                                                | 15     | 370 - 377      | [10.1016/S0924-9338(00)00505-8](https://doi.org/10.1016/S0924-9338(00)00505-8) | [Link](https://www.semanticscholar.org/paper/c2d2457e67e02850b64de76bd36e153955d382d1) |
# | 36   | J. Richter, M. Eisemann, G. Richter                         | 2000 | Temperament and character during the course of unipolar depression among inpatients                                                                                        | European Archives of Psychiatry and Clinical Neuroscience          | 250    | 40-47          | [10.1007/PL00007538](https://doi.org/10.1007/PL00007538)         | [Link](https://www.semanticscholar.org/paper/85e1e6e23c262200506302785bad90dbb3c70f68) |
# | 37   | W. Wordsworth, S. Kose                                      | 2003 | PSYCHOBIOLOGICAL MODEL OF TEMPERAMENT AND CHARACTER: TCI                                                                                                                   | -                                                                 | -      | -              | -                                                              | [Link](https://www.semanticscholar.org/paper/f2dd58a5e86fd8a81e76434af9bf7b73c53bc486) |
# | 38   | S. Brändström, P. Schlette, T. Przybeck, M. Lundberg, T. Forsgren, S. Sigvardsson, P. Nylander, L. Nilsson, R. Cloninger, R. Adolfsson | 1998 | Swedish normative data on personality using the Temperament and Character Inventory.                                                                                       | Comprehensive psychiatry                                           | 39 3   | 122-8          | [10.1016/S0010-440X(98)90070-0](https://doi.org/10.1016/S0010-440X(98)90070-0) | [Link](https://www.semanticscholar.org/paper/a3e3f1cbff71cf3b51b6396e21a95e8b1d954e08) |
# | 39   | C. Otter, J. Huber, A. Bonner                               | 1995 | Cloninger's tridimensional personality questionnaire : Reliability in an English sample                                                                                    | Personality and Individual Differences                              | 18     | 471-480        | [10.1016/0191-8869(94)00199-3](https://doi.org/10.1016/0191-8869(94)00199-3) | [Link](https://www.semanticscholar.org/paper/08f7647ed1c39e0e817ad144c503f6c68135a339) |
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %% [markdown]
# ##  Steps for TCI Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (TCI).
#     * **Actions:**
#         * Define the TCI dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the TCI dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the TCI dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our TCI Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up TCI experiment
experiment_name = "TCI"
mlflow.set_experiment(experiment_name)

# TCI dataset 

tci_dataset = {
    'Novelty Seeking': {
        'Adventurous': {
            'Synonyms': ['Bold', 'Daring', 'Enterprising', 'Audacious', 'Intrepid', 'Venturesome'],
            'Verbs': ['Explore', 'Venture', 'Risk', 'Challenge', 'Dare', 'Embark'],
            'Nouns': ['Adventure', 'Venturesomeness', 'Risk-taking', 'Daringness', 'Bravery', 'Exploration']
        },
        'Impulsive': {
            'Synonyms': ['Rash', 'Hasty', 'Reckless', 'Precipitate', 'Unthinking', 'Spontaneous'],
            'Verbs': ['Act hastily', 'React spontaneously', 'Leap impulsively', 'Rush decisions', 'Jump ahead', 'Dive in'],
            'Nouns': ['Impulsiveness', 'Hastiness', 'Recklessness', 'Spontaneity', 'Instinctiveness', 'Quickness']
        },
        'Curious': {
            'Synonyms': ['Inquisitive', 'Investigative', 'Probing', 'Inquiring', 'Questioning', 'Examining'],
            'Verbs': ['Explore', 'Inquire', 'Probe', 'Examine', 'Research', 'Inspect'],
            'Nouns': ['Curiosity', 'Inquisitiveness', 'Inquiry', 'Exploration', 'Discovery', 'Investigation']
        },
        'Explorative': {
            'Synonyms': ['Discovering', 'Searching', 'Examining', 'Inspecting', 'Scrutinizing', 'Investigative'],
            'Verbs': ['Discover', 'Search', 'Examine', 'Investigate', 'Inspect', 'Seek out'],
            'Nouns': ['Exploration', 'Discovery', 'Search', 'Examination', 'Scrutiny', 'Investigation']
        },
        'Excitable': {
            'Synonyms': ['Volatile', 'Mercurial', 'Impetuous', 'Capricious', 'Fickle', 'Overzealous'],
            'Verbs': ['Get excited', 'React sharply', 'Flare up', 'Erupt', 'Overreact', 'Spur into action'],
            'Nouns': ['Excitability', 'Volatile nature', 'Impetuosity', 'Capriciousness', 'Overreaction', 'Restlessness']
        },
        'Thrill-seeking': {
            'Synonyms': ['Risk-taking', 'Daredevil', 'Audacious', 'Reckless', 'Fearless', 'Extreme'],
            'Verbs': ['Seek thrills', 'Take risks', 'Push limits', 'Chase excitement', 'Test boundaries', 'Jump in'],
            'Nouns': ['Thrill-seeking', 'Daring', 'Risk-taking', 'Excitement', 'Adrenaline rush', 'Adventure']
        }
    },
    'Harm Avoidance': {
        'Cautious': {
            'Synonyms': ['Careful', 'Guarded', 'Wary', 'Prudent', 'Circumspect', 'Watchful'],
            'Verbs': ['Be wary', 'Tread carefully', 'Act prudently', 'Guard', 'Stay alert', 'Be vigilant'],
            'Nouns': ['Cautiousness', 'Prudence', 'Wariness', 'Guardedness', 'Alertness', 'Protection']
        },
        'Anxious': {
            'Synonyms': ['Nervous', 'Apprehensive', 'Worried', 'Uneasy', 'Restless', 'Edgy'],
            'Verbs': ['Worry', 'Fret', 'Stress', 'Panic', 'Agitate', 'Overthink'],
            'Nouns': ['Anxiety', 'Nervousness', 'Apprehension', 'Unease', 'Restlessness', 'Tension']
        },
        'Shy': {
            'Synonyms': ['Bashful', 'Timid', 'Reserved', 'Retiring', 'Diffident', 'Self-conscious'],
            'Verbs': ['Withdraw', 'Hesitate', 'Recoil', 'Shrink away', 'Avoid attention', 'Stay quiet'],
            'Nouns': ['Shyness', 'Timidity', 'Reservedness', 'Introversion', 'Reticence', 'Self-doubt']
        },
        'Fearful': {
            'Synonyms': ['Frightened', 'Scared', 'Afraid', 'Trepid', 'Panicky', 'Hesitant'],
            'Verbs': ['Fear', 'Flinch', 'Shudder', 'Cower', 'Avoid risk', 'Hold back'],
            'Nouns': ['Fearfulness', 'Fright', 'Panic', 'Trepidation', 'Nervousness', 'Hesitation']
        },
        'Pessimistic': {
            'Synonyms': ['Cynical', 'Negative', 'Doubtful', 'Gloomy', 'Skeptical', 'Hopeless'],
            'Verbs': ['Doubt', 'Disbelieve', 'Distrust', 'Despair', 'Expect failure', 'Lose hope'],
            'Nouns': ['Pessimism', 'Cynicism', 'Negativity', 'Skepticism', 'Hopelessness', 'Despair']
        },
        'Avoidant': {
            'Synonyms': ['Evasive', 'Unassertive', 'Fearful', 'Apprehensive', 'Timorous', 'Withdrawn'],
            'Verbs': ['Avoid', 'Evade', 'Withdraw', 'Hesitate', 'Back away', 'Sidestep'],
            'Nouns': ['Avoidance', 'Evasion', 'Hesitation', 'Fearfulness', 'Apprehension', 'Timidity']
        }
    },
    'Reward Dependence': {
        'Warm': {
            'Synonyms': ['Friendly', 'Affectionate', 'Loving', 'Cordial', 'Genial', 'Welcoming'],
            'Verbs': ['Embrace', 'Cherish', 'Adore', 'Welcome', 'Accept', 'Include'],
            'Nouns': ['Warmth', 'Friendliness', 'Affection', 'Cordiality', 'Kindness', 'Compassion']
        },
        'Dedicated': {
            'Synonyms': ['Devoted', 'Committed', 'Loyal', 'Faithful', 'Steadfast', 'Dependable'],
            'Verbs': ['Commit', 'Dedicate', 'Engage', 'Pledge', 'Promise', 'Adhere'],
            'Nouns': ['Dedication', 'Commitment', 'Loyalty', 'Faithfulness', 'Steadfastness', 'Dependability']
        },
        'Sensitive': {
            'Synonyms': ['Responsive', 'Receptive', 'Susceptible', 'Touchy', 'Tender', 'Aware'],
            'Verbs': ['Respond', 'Perceive', 'Feel', 'React', 'Absorb', 'Notice'],
            'Nouns': ['Sensitivity', 'Receptiveness', 'Tenderness', 'Responsiveness', 'Awareness', 'Empathy']
        },
        'Approving': {
            'Synonyms': ['Commendatory', 'Positive', 'Favorable', 'Accepting', 'Endorsing', 'Encouraging'],
            'Verbs': ['Approve', 'Praise', 'Endorse', 'Support', 'Encourage', 'Validate'],
            'Nouns': ['Approval', 'Commendation', 'Acceptance', 'Endorsement', 'Encouragement', 'Validation']
        },
        'Sociable': {
            'Synonyms': ['Convivial', 'Companionable', 'Gregarious', 'Social', 'Congenial', 'Outgoing'],
            'Verbs': ['Socialize', 'Interact', 'Mingle', 'Engage', 'Connect', 'Network'],
            'Nouns': ['Sociability', 'Conviviality', 'Companionship', 'Gregariousness', 'Networking', 'Engagement']
        },
        'Supportive': {
            'Synonyms': ['Helpful', 'Encouraging', 'Empathetic', 'Kind', 'Compassionate', 'Uplifting'],
            'Verbs': ['Support', 'Encourage', 'Assist', 'Help', 'Uplift', 'Empower'],
            'Nouns': ['Support', 'Encouragement', 'Empathy', 'Kindness', 'Compassion', 'Assistance']
        }
    },
    'Persistence': {
        'Determined': {
            'Synonyms': ['Resolved', 'Tenacious', 'Steadfast', 'Unwavering', 'Unswerving', 'Firm'],
            'Verbs': ['Persist', 'Persevere', 'Continue', 'Insist', 'Push forward', 'Commit'],
            'Nouns': ['Determination', 'Persistence', 'Tenacity', 'Resolve', 'Willpower', 'Commitment']
        },
        'Industrious': {
            'Synonyms': ['Hardworking', 'Diligent', 'Assiduous', 'Busy', 'Active', 'Productive'],
            'Verbs': ['Work hard', 'Labor', 'Toil', 'Strive', 'Apply oneself', 'Dedicate'],
            'Nouns': ['Industry', 'Diligence', 'Assiduity', 'Laboriousness', 'Productivity', 'Effort']
        },
        'Persistent': {
            'Synonyms': ['Tenacious', 'Dogged', 'Unyielding', 'Stubborn', 'Insistent', 'Resilient'],
            'Verbs': ['Maintain', 'Uphold', 'Continue', 'Endure', 'Push through', 'Hold on'],
            'Nouns': ['Persistence', 'Perseverance', 'Insistence', 'Tenacity', 'Resilience', 'Determination']
        },
        'Resolute': {
            'Synonyms': ['Decisive', 'Firm', 'Unflinching', 'Steady', 'Staunch', 'Committed'],
            'Verbs': ['Resolve', 'Decide', 'Commit', 'Determine', 'Hold firm', 'Stand strong'],
            'Nouns': ['Resolution', 'Firmness', 'Decisiveness', 'Determination', 'Conviction', 'Grit']
        },
        'Enduring': {
            'Synonyms': ['Lasting', 'Persistent', 'Continuous', 'Chronic', 'Long-lasting', 'Steady'],
            'Verbs': ['Endure', 'Last', 'Survive', 'Persist', 'Persevere', 'Sustain'],
            'Nouns': ['Endurance', 'Persistence', 'Permanence', 'Continuity', 'Longevity', 'Survival']
        },
        'Resilient': {
            'Synonyms': ['Strong', 'Adaptable', 'Tough', 'Hardy', 'Robust', 'Flexible'],
            'Verbs': ['Recover', 'Bounce back', 'Adapt', 'Survive', 'Overcome', 'Rebound'],
            'Nouns': ['Resilience', 'Strength', 'Adaptability', 'Toughness', 'Survivability', 'Flexibility']
        }
    },
    'Self-Directedness': {
        'Responsible': {
            'Synonyms': ['Accountable', 'Dependable', 'Reliable', 'Obligated', 'Trustworthy', 'Answerable'],
            'Verbs': ['Take responsibility', 'Uphold', 'Commit', 'Answer', 'Oblige', 'Fulfill'],
            'Nouns': ['Responsibility', 'Dependability', 'Reliability', 'Accountability', 'Obligation', 'Commitment']
        },
        'Goal-oriented': {
            'Synonyms': ['Driven', 'Determined', 'Purposeful', 'Aim-focused', 'Target-minded', 'Ambitious'],
            'Verbs': ['Aim', 'Target', 'Pursue', 'Focus', 'Strive', 'Aspire'],
            'Nouns': ['Goal', 'Objective', 'Purpose', 'Aim', 'Aspiration', 'Ambition']
        },
        'Self-confident': {
            'Synonyms': ['Assured', 'Self-assured', 'Self-trusting', 'Certain', 'Positive', 'Secure'],
            'Verbs': ['Believe in oneself', 'Trust oneself', 'Assert', 'Project', 'Exude', 'Demonstrate'],
            'Nouns': ['Self-confidence', 'Assurance', 'Self-esteem', 'Self-belief', 'Certainty', 'Conviction']
        },
        'Resourceful': {
            'Synonyms': ['Inventive', 'Creative', 'Innovative', 'Cunning', 'Clever', 'Adaptive'],
            'Verbs': ['Utilize', 'Innovate', 'Solve', 'Adapt', 'Devise', 'Improvise'],
            'Nouns': ['Resourcefulness', 'Creativity', 'Innovation', 'Ingenuity', 'Adaptability', 'Inventiveness']
        },
        'Self-reliant': {
            'Synonyms': ['Independent', 'Self-sufficient', 'Autonomous', 'Self-contained', 'Self-standing', 'Unaided'],
            'Verbs': ['Rely on oneself', 'Manage alone', 'Operate independently', 'Function autonomously', 'Sustain', 'Endure'],
            'Nouns': ['Self-reliance', 'Independence', 'Autonomy', 'Self-sufficiency', 'Self-governance', 'Sustenance']
        },
        'Disciplined': {
            'Synonyms': ['Self-controlled', 'Regulated', 'Strict', 'Methodical', 'Ordered', 'Resilient'],
            'Verbs': ['Discipline', 'Regulate', 'Structure', 'Control', 'Maintain', 'Persist'],
            'Nouns': ['Discipline', 'Self-control', 'Regulation', 'Orderliness', 'Persistence', 'Resilience']
        }
    },
    'Cooperativeness': {
        'Helpful': {
            'Synonyms': ['Assisting', 'Supportive', 'Beneficial', 'Useful', 'Aidful', 'Encouraging'],
            'Verbs': ['Assist', 'Support', 'Help', 'Aid', 'Encourage', 'Facilitate'],
            'Nouns': ['Helpfulness', 'Supportiveness', 'Assistance', 'Aid', 'Encouragement', 'Facilitation']
        },
        'Compliant': {
            'Synonyms': ['Conforming', 'Acquiescent', 'Submissive', 'Obedient', 'Docile', 'Agreeing'],
            'Verbs': ['Comply', 'Conform', 'Submit', 'Obey', 'Follow', 'Accommodate'],
            'Nouns': ['Compliance', 'Acquiescence', 'Submission', 'Obedience', 'Agreement', 'Accommodation']
        },
        'Empathetic': {
            'Synonyms': ['Understanding', 'Compassionate', 'Sympathetic', 'Considerate', 'Caring', 'Kind-hearted'],
            'Verbs': ['Empathize', 'Understand', 'Sympathize', 'Support', 'Console', 'Appreciate'],
            'Nouns': ['Empathy', 'Compassion', 'Understanding', 'Sympathy', 'Kindness', 'Consideration']
        },
        'Tolerant': {
            'Synonyms': ['Patient', 'Indulgent', 'Forgiving', 'Understanding', 'Long-suffering', 'Accepting'],
            'Verbs': ['Tolerate', 'Accept', 'Endure', 'Bear', 'Forgive', 'Permit'],
            'Nouns': ['Tolerance', 'Patience', 'Indulgence', 'Forbearance', 'Acceptance', 'Endurance']
        },
        'Agreeable': {
            'Synonyms': ['Pleasant', 'Enjoyable', 'Nice', 'Likable', 'Gratifying', 'Congenial'],
            'Verbs': ['Agree', 'Please', 'Accommodate', 'Cooperate', 'Concur', 'Harmonize'],
            'Nouns': ['Agreeableness', 'Pleasantness', 'Enjoyment', 'Amiability', 'Congeniality', 'Cooperation']
        },
        'Trustworthy': {
            'Synonyms': ['Reliable', 'Loyal', 'Honest', 'Dependable', 'Faithful', 'Sincere'],
            'Verbs': ['Trust', 'Believe', 'Rely on', 'Uphold', 'Keep promises', 'Demonstrate'],
            'Nouns': ['Trustworthiness', 'Reliability', 'Honesty', 'Faithfulness', 'Sincerity', 'Integrity']
        }
    },
    'Self-Transcendence': {
        'Spiritual': {
            'Synonyms': ['Sacred', 'Devout', 'Holy', 'Religious', 'Pious', 'Mystical'],
            'Verbs': ['Worship', 'Pray', 'Meditate', 'Celebrate', 'Seek', 'Contemplate'],
            'Nouns': ['Spirituality', 'Devotion', 'Piety', 'Faith', 'Mysticism', 'Transcendence']
        },
        'Altruistic': {
            'Synonyms': ['Unselfish', 'Selfless', 'Charitable', 'Generous', 'Benevolent', 'Philanthropic'],
            'Verbs': ['Give', 'Share', 'Donate', 'Support', 'Serve', 'Contribute'],
            'Nouns': ['Altruism', 'Generosity', 'Charity', 'Benevolence', 'Service', 'Contribution']
        },
        'Idealistic': {
            'Synonyms': ['Utopian', 'Visionary', 'Romantic', 'Imaginary', 'Dreamy', 'Aspiring'],
            'Verbs': ['Dream', 'Hope', 'Aspire', 'Vision', 'Envision', 'Strive'],
            'Nouns': ['Idealism', 'Vision', 'Utopianism', 'Romanticism', 'Aspiration', 'Imagination']
        },
        'Patient': {
            'Synonyms': ['Tolerant', 'Forbearing', 'Long-suffering', 'Enduring', 'Persevering', 'Resilient'],
            'Verbs': ['Wait', 'Endure', 'Tolerate', 'Persevere', 'Persist', 'Sustain'],
            'Nouns': ['Patience', 'Endurance', 'Tolerance', 'Perseverance', 'Resilience', 'Fortitude']
        },
        'Humble': {
            'Synonyms': ['Modest', 'Unassuming', 'Unpretentious', 'Demure', 'Lowly', 'Meek'],
            'Verbs': ['Submit', 'Yield', 'Defer', 'Lower oneself', 'Humble', 'Acknowledge'],
            'Nouns': ['Humility', 'Modesty', 'Unpretentiousness', 'Demureness', 'Meekness', 'Submissiveness']
        },
        'Insightful': {
            'Synonyms': ['Perceptive', 'Intuitive', 'Enlightened', 'Wise', 'Deep-thinking', 'Astute'],
            'Verbs': ['Discern', 'Understand deeply', 'Perceive', 'Comprehend', 'Analyze', 'Reflect'],
            'Nouns': ['Insight', 'Perception', 'Intuition', 'Enlightenment', 'Wisdom', 'Astuteness']
        }
    }
}


#Create a list to store the dataset
data = []
for factor, attributes in tci_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
tci_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/tci.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="TCI Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "TCI")
    mlflow.log_param("Total Rows", len(tci_df))
    mlflow.log_param("Total Factors", len(tci_dataset))
    mlflow.log_param("Data Schema", str(tci_df.columns.tolist()))
    
    # Save dataset to CSV
    tci_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ TCI dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(tci_df.head())
    print("\nDataset shape:", tci_df.shape)
    print("\nNumber of unique Factors:", tci_df['Factor'].nunique())
    print("Unique Factors:", tci_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# 2025/03/18 11:27:05 INFO mlflow.tracking.fluent: Experiment with name 'TCI' does not exist. Creating a new experiment.
# ✅ TCI dataset created and saved to ../Datasets/tci.csv
# First 5 rows of the dataset:
#             Factor    Adjective       Synonym       Verb             Noun
# 0  Novelty Seeking  Adventurous          Bold    Explore        Adventure
# 1  Novelty Seeking  Adventurous        Daring    Venture  Venturesomeness
# 2  Novelty Seeking  Adventurous  Enterprising       Risk      Risk-taking
# 3  Novelty Seeking  Adventurous     Audacious  Challenge       Daringness
# 4  Novelty Seeking  Adventurous      Intrepid       Dare          Bravery
#
# Dataset shape: (252, 5)
#
# Number of unique Factors: 7
# Unique Factors: ['Novelty Seeking' 'Harm Avoidance' 'Reward Dependence' 'Persistence'
#  'Self-Directedness' 'Cooperativeness' 'Self-Transcendence']
# 📌 MLflow tracking active under experiment 'TCI' (ID: 30)
# 🏃 View run TCI Dataset Creation at: http://127.0.0.1:5000/#/experiments/30/runs/a3be40f5855e46ddb513f5ca5c7df9a6
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="tci_page_2"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/30/runs/2b4e7986f7b049e09bac9e4ea2b44cea
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="tci_page_2"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018421143293380737, -0.007218753919005394, 0.003606205340474844, -0.05419774353504181, -0.022721948102116585, 0.036969155073165894, 0.02902725711464882, 0.023901814594864845, 0.011240449734032154, -0.020641323179006577]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/30/runs/238030839e1441bd95ac55410d991d81
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create TCI Embeddings** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved tci dataset from a CSV file
dataset_path = '../Datasets/tci.csv'
try:
    tci_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'tci_df' is empty before processing
        if tci_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", tci_df.shape[0])
            print(f"📊 Processing {tci_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        tci_df['Embedding'] = tci_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/tci_embeddings.csv'
        tci_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = tci_df.shape[0]
        num_columns = tci_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in tci_df.columns and not tci_df['Embedding'].empty:
            embedding_length = len(tci_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(tci_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/tci.csv
# ⏳ Embedding generation started at: 2025-03-18 11:27:07.592996
# 📊 Processing 252 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-18 11:30:29.224344 (Duration: 0:03:21.631348)
# 💾 Embeddings saved to: ../Embeddings/tci_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#             Factor    Adjective       Synonym       Verb             Noun  \
# 0  Novelty Seeking  Adventurous          Bold    Explore        Adventure
# 1  Novelty Seeking  Adventurous        Daring    Venture  Venturesomeness
# 2  Novelty Seeking  Adventurous  Enterprising       Risk      Risk-taking
# 3  Novelty Seeking  Adventurous     Audacious  Challenge       Daringness
# 4  Novelty Seeking  Adventurous      Intrepid       Dare          Bravery
#
#                                            Embedding
# 0  [0.030557826161384583, -0.0011083099525421858,...
# 1  [0.029390983283519745, 0.003119290340691805, 0...
# 2  [0.03672308847308159, 0.007397698704153299, 0....
# 3  [0.035199157893657684, -0.004690453875809908, ...
# 4  [0.030614614486694336, 0.0063546388410031796, ...
# 🏃 View run Generate Embeddings at: http://127.0.0.1:5000/#/experiments/30/runs/ef2f2f7b590547e5a6a1feb4fa2bfc54
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/tci_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/tci_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "tci_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/tci_embeddings.csv
# 💾 Label encoder saved to: ../Models/tci_label_encoder.pkl
#
# First 5 rows with encoded labels:
#             Factor  Factor_Encoded
# 0  Novelty Seeking               2
# 1  Novelty Seeking               2
# 2  Novelty Seeking               2
# 3  Novelty Seeking               2
# 4  Novelty Seeking               2
#
# Mapping of original labels to encoded labels:
# Cooperativeness: 0
# Harm Avoidance: 1
# Novelty Seeking: 2
# Persistence: 3
# Reward Dependence: 4
# Self-Directedness: 5
# Self-Transcendence: 6
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/tci_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: tci_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/30/runs/6686a8ab0aa84b949e502d466297a473
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/tci_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/tci_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="tci Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "tci_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "tci_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "tci_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/tci_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/tci_embeddings.csv
# ✅ Label encoder loaded from: ../Models/tci_label_encoder.pkl
# ⏳ Model training started at: 2025-03-18 11:30:32.209801
# ✅ Model training finished at: 2025-03-18 11:30:32.569431 (Duration: 0:00:00.359630)
# 📊 Classification report saved to: tci_classification_report.csv
# 📊 Confusion matrix saved to: tci_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: tci_confusion_matrix.png
# 💾 Trained model saved to: ../Models/tci_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#    Cooperativeness       1.00      1.00      1.00         7
#     Harm Avoidance       1.00      1.00      1.00         7
#    Novelty Seeking       1.00      1.00      1.00         7
#        Persistence       1.00      1.00      1.00         8
#  Reward Dependence       1.00      1.00      1.00         7
#  Self-Directedness       1.00      1.00      1.00         7
# Self-Transcendence       1.00      1.00      1.00         8
#
#           accuracy                           1.00        51
#          macro avg       1.00      1.00      1.00        51
#       weighted avg       1.00      1.00      1.00        51
#
#
# Confusion Matrix:
#                      Cooperativeness  Harm Avoidance  Novelty Seeking  \
# Cooperativeness                   7               0                0
# Harm Avoidance                    0               7                0
# Novelty Seeking                   0               0                7
# Persistence                       0               0                0
# Reward Dependence                 0               0                0
# Self-Directedness                 0               0                0
# Self-Transcendence                0               0                0
#
#                     Persistence  Reward Dependence  Self-Directedness  \
# Cooperativeness               0                  0                  0
# Harm Avoidance                0                  0                  0
# Novelty Seeking               0                  0                  0
# Persistence                   8                  0                  0
# Reward Dependence             0                  7                  0
# Self-Directedness             0                  0                  7
# Self-Transcendence            0                  0                  0
#
#                     Self-Transcendence
# Cooperativeness                      0
# Harm Avoidance                       0
# Novelty Seeking                      0
# Persistence                          0
# Reward Dependence                    0
# Self-Directedness                    0
# Self-Transcendence                   8
# 🏃 View run tci Model Training and Evaluation Workflow at: http://127.0.0.1:5000/#/experiments/30/runs/ce29df0ce931420197d1c13bfe597f0b
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/tci_embeddings.csv'
label_encoder_path = "../Models/tci_label_encoder.pkl"
model_path = "../Models/tci_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate TCI Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate TCI Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "tci_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "tci_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "tci_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ TCI Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/tci_embeddings.csv
# ✅ Label encoder loaded from: ../Models/tci_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/tci_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: tci_evaluation_classification_report.csv
#
# Classification Report:
#                      precision    recall  f1-score   support
#
#    Cooperativeness       1.00      1.00      1.00         7
#     Harm Avoidance       1.00      1.00      1.00         7
#    Novelty Seeking       1.00      1.00      1.00         7
#        Persistence       1.00      1.00      1.00         8
#  Reward Dependence       1.00      1.00      1.00         7
#  Self-Directedness       1.00      1.00      1.00         7
# Self-Transcendence       1.00      1.00      1.00         8
#
#           accuracy                           1.00        51
#          macro avg       1.00      1.00      1.00        51
#       weighted avg       1.00      1.00      1.00        51
#
# 📊 Confusion matrix saved to: tci_evaluation_confusion_matrix.csv
#
# Confusion Matrix:
#                      Cooperativeness  Harm Avoidance  Novelty Seeking  \
# Cooperativeness                   7               0                0
# Harm Avoidance                    0               7                0
# Novelty Seeking                   0               0                7
# Persistence                       0               0                0
# Reward Dependence                 0               0                0
# Self-Directedness                 0               0                0
# Self-Transcendence                0               0                0
#
#                     Persistence  Reward Dependence  Self-Directedness  \
# Cooperativeness               0                  0                  0
# Harm Avoidance                0                  0                  0
# Novelty Seeking               0                  0                  0
# Persistence                   8                  0                  0
# Reward Dependence             0                  7                  0
# Self-Directedness             0                  0                  7
# Self-Transcendence            0                  0                  0
#
#                     Self-Transcendence
# Cooperativeness                      0
# Harm Avoidance                       0
# Novelty Seeking                      0
# Persistence                          0
# Reward Dependence                    0
# Self-Directedness                    0
# Self-Transcendence                   8
# 🖼️ Confusion matrix plot saved to: tci_evaluation_confusion_matrix.png
# 🏃 View run Evaluate TCI Model at: http://127.0.0.1:5000/#/experiments/30/runs/fcb759b67d874277874d63d919423b75
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30
#
# ✅ TCI Model evaluation on the test set complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/tci_label_encoder.pkl"
model_path = "../Models/tci_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/tci_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/tci_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Self-Directedness
# Predicted Factor for 'I prefer staying home with a good book....': Harm Avoidance
# Predicted Factor for 'I often feel anxious and worried....': Harm Avoidance
# Predicted Factor for 'I am generally calm and relaxed....': Self-Transcendence
# Predicted Factor for 'I enjoy taking risks and trying new things....': Novelty Seeking
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/30/runs/8193c90312894d7fa9b1e1753589a053
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/tci_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="TCI Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/tci_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "tci_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/tci_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of TCI Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/tci_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of TCI Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/18 11:30:42 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Persistence
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Harm Avoidance
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Persistence
# Predicted Factor for 'Organized Meticulous Plan Planner': Persistence
# Predicted Factor for 'Moody Anxious Worry Worrier': Harm Avoidance
# 🏃 View run TCI Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/30/runs/b4159c4d79914cd3a2a3c5b21d645d62
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/tci_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/tci_label_encoder.pkl"
        model_path = "../Models/tci_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of TCI Embeddings")

            # Save and log the plot
            pca_plot_path = "tci_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "tci_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/tci_embeddings.csv
#
# DataFrame with Embeddings:
#             Factor    Adjective       Synonym       Verb             Noun  \
# 0  Novelty Seeking  Adventurous          Bold    Explore        Adventure
# 1  Novelty Seeking  Adventurous        Daring    Venture  Venturesomeness
# 2  Novelty Seeking  Adventurous  Enterprising       Risk      Risk-taking
# 3  Novelty Seeking  Adventurous     Audacious  Challenge       Daringness
# 4  Novelty Seeking  Adventurous      Intrepid       Dare          Bravery
#
#                                            Embedding
# 0  [0.030557826161384583, -0.0011083099525421858,...
# 1  [0.029390983283519745, 0.003119290340691805, 0...
# 2  [0.03672308847308159, 0.007397698704153299, 0....
# 3  [0.035199157893657684, -0.004690453875809908, ...
# 4  [0.030614614486694336, 0.0063546388410031796, ...
#
# Shape of DataFrame:
# (252, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.03055783 -0.00110831  0.01032523 ...  0.00101049 -0.04297242
#   0.00428129]
# ✅ Label encoder loaded from: ../Models/tci_label_encoder.pkl
#
# Shape of X:
# (252, 1536)
# ✅ PCA visualization saved to: tci_embeddings_pca.png
# ✅ K-Means clustering performed. Clustered data saved to: tci_clustered_embeddings.csv
# Predicted Factor for 'I love going to parties and meeting new people.': Self-Directedness
# 🏃 View run Step 9: Model Application, Visualization, and Analysis at: http://127.0.0.1:5000/#/experiments/30/runs/34a276c1baa44f0892ed21a14b337086
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30
#
# ✅ Step 10: Save Model Visualization and Analysis complete.

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [1. 1. 1. 1. 1.]
# Mean cross-validation score: 1.0

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="tci_page_3"></a>
#
# [Back to Top](#tci_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/tci_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_tci.pkl')
clf = joblib.load('../Models/tci_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Self-Directedness
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Self-Transcendence
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Novelty Seeking
# Predicted Factor for 'Organized Meticulous Plan Planner': Self-Directedness
# Predicted Factor for 'Moody Anxious Worry Worrier': Harm Avoidance
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Harm Avoidance

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Novelty Seeking

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Reward Dependence

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Harm Avoidance

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Reward Dependence

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Reward Dependence

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="TCI_page_4"></a>
#
#
# [Back to Top](#TCI_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("TCI")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/30/runs/9a328aad116c49a7ae791c125a872f73
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create TCI Schema in Neo4j** <a class="anchor" id="TCI_page_4"></a>
#
#
# [Back to Top](#TCI_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("TCI")

# Load the dataset
dataset_path = "../Embeddings/tci_embeddings.csv"
tci_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in tci_df.columns:
    tci_df['Embedding'] = tci_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the TCI schema in Neo4j
def create_tci_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with TCI labels
        graph.run("MERGE (f:TCI_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:TCI_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:TCI_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:TCI_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:TCI_Noun {name: $noun})", noun=noun)
        
        # Create relationships with TCI namespacing
        graph.run("""
            MATCH (f:TCI_Factor {name: $factor}), (a:TCI_Adjective {name: $adjective})
            MERGE (f)-[:TCI_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:TCI_Adjective {name: $adjective}), (s:TCI_Synonym {name: $synonym})
            MERGE (a)-[:TCI_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:TCI_Adjective {name: $adjective}), (v:TCI_Verb {name: $verb})
            MERGE (a)-[:TCI_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:TCI_Adjective {name: $adjective}), (n:TCI_Noun {name: $noun})
            MERGE (a)-[:TCI_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:TCI_Factor {name: $factor}), (a:TCI_Adjective {name: $adjective})
                MERGE (e:TCI_Embedding {value: $embedding})
                MERGE (f)-[:TCI_HAS_EMBEDDING]->(e)
                MERGE (a)-[:TCI_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create TCI Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create TCI Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the TCI schema
        create_tci_schema(graph, tci_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", tci_df.shape[0])
        mlflow.log_param("Number of Columns", tci_df.shape[1])
        
        # Print the DataFrame
        print(tci_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#             Factor    Adjective       Synonym       Verb             Noun  \
# 0  Novelty Seeking  Adventurous          Bold    Explore        Adventure
# 1  Novelty Seeking  Adventurous        Daring    Venture  Venturesomeness
# 2  Novelty Seeking  Adventurous  Enterprising       Risk      Risk-taking
# 3  Novelty Seeking  Adventurous     Audacious  Challenge       Daringness
# 4  Novelty Seeking  Adventurous      Intrepid       Dare          Bravery
#
#                                            Embedding
# 0  [0.030557826161384583, -0.0011083099525421858,...
# 1  [0.029390983283519745, 0.003119290340691805, 0...
# 2  [0.03672308847308159, 0.007397698704153299, 0....
# 3  [0.035199157893657684, -0.004690453875809908, ...
# 4  [0.030614614486694336, 0.0063546388410031796, ...
# 🏃 View run Create TCI Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/30/runs/02be5caf537142418dbdf734352e69fc
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/30

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:TCI_Factor OR n:TCI_Adjective OR n:TCI_Synonym OR n:TCI_Verb OR n:TCI_Noun)
# AND NOT m:TCI_Embedding
# RETURN n, r, m
# ```
