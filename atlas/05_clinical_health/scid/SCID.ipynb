# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Structured Clinical Interview for DSM (SCID)<a class="anchor" id="PTMD_page_20.4"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# The **Structured Clinical Interview for DSM-5 (SCID-5)** is a comprehensive diagnostic tool used to assess and diagnose major DSM-5 disorders. It is divided into several modules, each targeting different types of disorders. Here are the major categories of disorders typically assessed using the SCID-5:
#
# 1. **Mood Episodes**
#    - Major Depressive Episode
#    - Manic Episode
#    - Hypomanic Episode
#
# 2. **Psychotic Symptoms and Disorders**
#    - Schizophrenia
#    - Schizoaffective Disorder
#    - Schizophreniform Disorder
#    - Brief Psychotic Disorder
#    - Delusional Disorder
#
# 3. **Mood Disorders**
#    - Major Depressive Disorder
#    - Bipolar I Disorder
#    - Bipolar II Disorder
#    - Cyclothymic Disorder
#
# 4. **Substance Use Disorders**
#    - Alcohol Use Disorder
#    - Cannabis Use Disorder
#    - Hallucinogen Use Disorder
#    - Inhalant Use Disorder
#    - Opioid Use Disorder
#    - Sedative, Hypnotic, or Anxiolytic Use Disorder
#    - Stimulant Use Disorder
#    - Tobacco Use Disorder
#
# 5. **Anxiety Disorders**
#    - Panic Disorder
#    - Agoraphobia
#    - Specific Phobia
#    - Social Anxiety Disorder (Social Phobia)
#    - Generalized Anxiety Disorder
#
# 6. **Obsessive-Compulsive and Related Disorders**
#    - Obsessive-Compulsive Disorder
#    - Body Dysmorphic Disorder
#    - Hoarding Disorder
#    - Trichotillomania (Hair-Pulling Disorder)
#    - Excoriation (Skin-Picking) Disorder
#
# 7. **Trauma- and Stressor-Related Disorders**
#    - Posttraumatic Stress Disorder (PTSD)
#    - Acute Stress Disorder
#    - Adjustment Disorders
#
# 8. **Dissociative Disorders**
#    - Dissociative Identity Disorder
#    - Dissociative Amnesia
#    - Depersonalization/Derealization Disorder
#
# 9. **Somatic Symptom and Related Disorders**
#    - Somatic Symptom Disorder
#    - Illness Anxiety Disorder
#
# 10. **Feeding and Eating Disorders**
#     - Anorexia Nervosa
#     - Bulimia Nervosa
#     - Binge-Eating Disorder
#
# 11. **Elimination Disorders**
#     - Enuresis
#     - Encopresis
#
# 12. **Sleep-Wake Disorders**
#     - Insomnia Disorder
#     - Hypersomnolence Disorder
#     - Narcolepsy
#     - Breathing-Related Sleep Disorders
#     - Circadian Rhythm Sleep-Wake Disorders
#
# 13. **Sexual Dysfunctions**
#     - Delayed Ejaculation
#     - Erectile Disorder
#     - Female Orgasmic Disorder
#     - Female Sexual Interest/Arousal Disorder
#     - Male Hypoactive Sexual Desire Disorder
#     - Premature (Early) Ejaculation
#     - Genito-Pelvic Pain/Penetration Disorder
#
# 14. **Gender Dysphoria**
#
# 15. **Disruptive, Impulse-Control, and Conduct Disorders**
#     - Oppositional Defiant Disorder
#     - Intermittent Explosive Disorder
#     - Conduct Disorder
#     - Antisocial Personality Disorder
#
# 16. **Neurocognitive Disorders**
#     - Delirium
#     - Major and Mild Neurocognitive Disorders due to various causes (e.g., Alzheimer's Disease, Vascular Disease)
#
# 17. **Personality Disorders**
#     - Cluster A (Paranoid, Schizoid, Schizotypal)
#     - Cluster B (Antisocial, Borderline, Histrionic, Narcissistic)
#     - Cluster C (Avoidant, Dependent, Obsessive-Compulsive)
#
#
# ## 2. DSM-5-TR Major Chapters (21)
#
# Here is the widely recognized **DSM-5-TR** high-level outline:
#
# 1. **Neurodevelopmental Disorders**
# 2. **Schizophrenia Spectrum and Other Psychotic Disorders**
# 3. **Bipolar and Related Disorders**
# 4. **Depressive Disorders**
# 5. **Anxiety Disorders**
# 6. **Obsessive-Compulsive and Related Disorders**
# 7. **Trauma- and Stressor-Related Disorders**
# 8. **Dissociative Disorders**
# 9. **Somatic Symptom and Related Disorders**
# 10. **Feeding and Eating Disorders**
# 11. **Elimination Disorders**
# 12. **Sleep-Wake Disorders**
# 13. **Sexual Dysfunctions**
# 14. **Gender Dysphoria**
# 15. **Disruptive, Impulse-Control, and Conduct Disorders**
# 16. **Substance-Related and Addictive Disorders**
# 17. **Neurocognitive Disorders**
# 18. **Personality Disorders**
# 19. **Paraphilic Disorders**
# 20. **Medication-Induced Movement Disorders and Other Adverse Effects of Medication**
# 21. **Other Conditions That May Be a Focus of Clinical Attention**
#
# This list provides an overview of the disorders typically included in the SCID-5, reflecting the wide range of psychiatric conditions covered by this diagnostic tool.
#
# Timeline and reference table for the Structured Clinical Interview for DSM (SCID) involves outlining the key developments of this diagnostic tool. The SCID is a semi-structured interview guide used for making major DSM (Diagnostic and Statistical Manual of Mental Disorders) diagnoses. It's a vital tool in clinical psychology and psychiatry.
#
# | Year      | Milestone                             | Contributor(s)                                             | Original Work Reference                                                                                                 | Key Contributions                                                                              | Additional Information                                                                                      |
# |-----------|---------------------------------------|------------------------------------------------------------|-------------------------------------------------------------------------------------------------------------------------|------------------------------------------------------------------------------------------------|-----------------------------------------------------------------------------------------------------------|
# | 1980s     | Development of the initial SCID.      | Robert L. Spitzer, Janet B.W. Williams, Michael B. First, and others | Spitzer, R. L., Williams, J. B. W., Gibbon, M., & First, M. B. (1980s). "Structured Clinical Interview for DSM-III-R (SCID)". | First structured interview guide for DSM-III-R to assist clinicians in making psychiatric diagnoses. | Greatly improved the reliability of psychiatric diagnoses by providing a standardized interview process. |
# | 1990s     | Revision for DSM-IV.                  | Michael B. First, Robert L. Spitzer, Miriam Gibbon, and Janet B.W. Williams | First, M. B., Spitzer, R. L., Gibbon, M., & Williams, J. B. W. (1990s). "Structured Clinical Interview for DSM-IV (SCID)".   | Updated to align with the diagnostic criteria of the DSM-IV.                                     | SCID became a crucial tool in both clinical and research settings for DSM-IV diagnoses.                    |
# | 2013      | Update for DSM-5.                     | Michael B. First, Janet B.W. Williams, Rhonda S. Karg, and others | First, M. B., Williams, J. B. W., Karg, R. S., & Spitzer, R. L. (2013). "Structured Clinical Interview for DSM-5 (SCID-5)". | Revised to reflect changes in the DSM-5, including new diagnoses and criteria.                   | Continued to be an essential instrument for diagnosis, treatment planning, and research in mental health. |
# | Post-2013 | Ongoing adaptations and research.     | Various Researchers and Clinicians                           | Continued research and publications on the use and adaptation of the SCID-5.                                             | Further validation studies and adaptations for specific populations and settings.                 | SCID remains a fundamental tool in psychiatric diagnosis and research, adapting to the evolving field of mental health. |
#
# This table provides an overview of the major developments in the Structured Clinical Interview for DSM (SCID), highlighting the contributions of key figures and milestones. Each row represents a significant event in the history of the SCID, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# The SCID has been instrumental in standardizing the diagnostic process for psychiatric disorders, ensuring consistency and reliability across various clinical and research settings. Its evolution mirrors the changes in the DSM, reflecting the growth and adaptation of psychiatric diagnostic criteria over time.
#
# | #  | Author(s)                                                      | Year | Title                                                                                                  | Journal/Source                               | Volume | Pages      | DOI                                                                                                          |
# |----|----------------------------------------------------------------|------|------------------------------------------------------------------------------------------------------|----------------------------------------------|--------|-----------|----------------------------------------------------------------------------------------------------------------|
# | 1  | M. First, Janet B W Williams, R. Karg, R. Spitzer              | 2016 | User's guide for the SCID-5-CV: structured clinical interview for DSM-5 disorders: clinician version | [Semanticscholar](https://www.semanticscholar.org/paper/cff6c3c6c35e5108cc14e8eeccebe4a9ea91f2e0)               | -      | -         | -                                                                                                              |
# | 2  | L. Dell’Osso, R. Dalle Luche, M. Maj                           | 2015 | Adult autism spectrum as a transnosographic dimension                                                | CNS Spectrums                                | 21     | 131-133   | [10.1017/S1092852915000450](https://doi.org/10.1017/S1092852915000450)                                        |
# | 3  | L. Dell’Osso, D. Muti, B. Carpita, I. Cremone, E. Bui, et al.  | -    | The Adult Autism Subthreshold Spectrum (AdAS) model: a neurodevelopmental approach to mental disorders | -                                             | -      | -         | -                                                                                                              |
# | 4  | A. Shabani, S. Masoumian, S. Zamirinejad, Maryam Hejri, et al. | 2020 | Psychometric properties of Structured Clinical Interview for DSM-5 Disorders-Clinician Version (SCID-5-CV) | Brain and Behavior                          | 11     | -         | [10.1002/brb3.1894](https://doi.org/10.1002/brb3.1894)                                                         |
# | 5  | L. Dell’Osso, B. Carpita, C. Gesi, I. Cremone, et al.          | 2018 | Subthreshold autism spectrum disorder in patients with eating disorders                             | Comprehensive psychiatry                     | 81     | 66-72     | [10.1016/j.comppsych.2017.11.007](https://doi.org/10.1016/j.comppsych.2017.11.007)                             |
# | 6  | B. First                                                     | 2017 | STRUCTURED CLINICAL INTERVIEW FOR DSM-5 DISORDERS SCID-5-CV                                         | [Semanticscholar](https://www.semanticscholar.org/paper/00e1c10ff9d6d44c68b4a06a0abd15e05b30e051)               | -      | -         | -                                                                                                              |
# | 7  | D. Marazziti, M. Abelli, S. Baroni, B. Carpita, et al.        | 2014 | Neurobiological correlates of social anxiety disorder: an update                                     | CNS Spectrums                                | 20     | 100-111   | [10.1017/S109285291400008X](https://doi.org/10.1017/S109285291400008X)                                        |
# | 8  | L. Dell’Osso, R. D. Luche, C. Gesi, I. Moroni, et al.         | 2016 | From Asperger's Autistischen Psychopathen to DSM-5 Autism Spectrum Disorder and Beyond: A Subthreshold Autism Spectrum Model | Clinical Practice and Epidemiology in Mental Health | 12     | 120-131   | [10.2174/1745017901612010120](https://doi.org/10.2174/1745017901612010120)                                   |
# | 9  | Amir Shabani, Samira Masoumian, Somayeh Zamirinejad, et al.   | 2020 | Author response for "Psychometric properties of Structured Clinical Interview for DSM‐5 Disorders‐Clinician Version (SCID‐5‐CV)" | -                                             | -      | -         | [10.1002/brb3.1894/v2/response1](https://doi.org/10.1002/brb3.1894/v2/response1)                             |
# | 10 | A. Monteleone, J. Treasure, C. Kan, V. Cardi                 | 2018 | Reactivity to interpersonal stress in patients with eating disorders: A systematic review and meta-analysis of studies using an experimental paradigm | Neuroscience & Biobehavioral Reviews         | 87     | 133-150   | [10.1016/j.neubiorev.2018.02.002](https://doi.org/10.1016/j.neubiorev.2018.02.002)                           |
# | 11 | L. Dell’Osso, C. Conversano, M. Corsi, C. Bertelloni, et al. | 2018 | Polysubstance and Behavioral Addictions in a Patient with Bipolar Disorder: Role of Lifetime Subthreshold Autism Spectrum | Case Reports in Psychiatry                  | 2018   | -         | [10.1155/2018/1547975](https://doi.org/10.1155/2018/1547975)                                                  |
# | 12 | A. Monteleone, V. Ruzzi, G. Patriciello, G. Cascino, et al.  | 2020 | Emotional reactivity and eating disorder related attitudes in response to the trier social stress test: An experimental study in people with anorexia nervosa and with bulimia nervosa. | Journal of affective disorders                | 274    | 23-30     | [10.1016/j.jad.2020.05.051](https://doi.org/10.1016/j.jad.2020.05.051)                                        |
# | 13 | L. Dell’Osso, C. Gesi, E. Massimetti, I. Cremone, et al.      | 2017 | Adult Autism Subthreshold Spectrum (AdAS Spectrum): Validation of a questionnaire investigating subthreshold autism spectrum | Comprehensive psychiatry                     | 73     | 61-83     | [10.1016/j.comppsych.2016.11.001](https://doi.org/10.1016/j.comppsych.2016.11.001)                            |
# | 14 | L. Dell’Osso, I. Cremone, B. Carpita, A. Fagiolini, et al.   | 2018 | Correlates of autistic traits among patients with borderline personality disorder.                   | Comprehensive psychiatry                     | 83     | 7-11      | [10.1016/j.comppsych.2018.01.002](https://doi.org/10.1016/j.comppsych.2018.01.002)                            |
# | 15 | L. Dell’Osso, B. Carpita, I. Cremone, D. Muti, et al.        | 2019 | The mediating effect of trauma and stressor related symptoms and ruminations on the relationship between autistic traits and mood spectrum | Psychiatry Research                        | 279    | 123-129   | [10.1016/j.psychres.2018.10.040](https://doi.org/10.1016/j.psychres.2018.10.040)                              |
# | 16 | V. Cardi, N. Mallorquí-Bagué, G. Albano, A. Monteleone, et al. | 2018 | Social Difficulties As Risk and Maintaining Factors in Anorexia Nervosa: A Mixed-Method Investigation | Frontiers in Psychiatry                     | 9      | -         | [10.3389/fpsyt.2018.00012](https://doi.org/10.3389/fpsyt.2018.00012)                                          |
# | 17 | F. de Lima Osório, S. Loureiro, J. Hallak, et al.             | 2019 | Clinical validity and intrarater and test–retest reliability of the Structured Clinical Interview for DSM‐5 – Clinician Version (SCID‐5‐CV) | Psychiatry and Clinical Neurosciences       | 73     | -         | [10.1111/pcn.12931](https://doi.org/10.1111/pcn.12931)                                                       |
# | 18 | D. Marazziti, M. Abelli, S. Baroni, B. Carpita, et al.        | 2014 | Recent findings on the pathophysiology of social anxiety disorder                                     | -                                             | -      | -         | [10.1017/S109285291400008X](https://doi.org/10.1017/S109285291400008X)                                       |
# | 19 | L. Billeci, S. Calderoni, E. Conti, et al.                    | 2016 | The Broad Autism (Endo)Phenotype: Neurostructural and Neurofunctional Correlates in Parents of Individuals with Autism Spectrum Disorders | Frontiers in Neuroscience                   | 10     | -         | [10.3389/fnins.2016.00346](https://doi.org/10.3389/fnins.2016.00346)                                         |
# | 20 | V. Cardi, K. Tchanturia, J. Treasure                          | 2018 | Premorbid and Illness-related Social Difficulties in Eating Disorders: An Overview of the Literature and Treatment Developments | Current Neuropharmacology                   | 16     | 1122-1130 | [10.2174/1570159X16666180118100028](https://doi.org/10.2174/1570159X16666180118100028)                       |
# | 21 | D. R. Beike, N. R. Brandon, H. E. Cole                        | 2016 | Is sharing specific autobiographical memories a distinct form of self-disclosure?                    | Journal of experimental psychology. General | 145    | 434-450   | [10.1037/xge0000143](https://doi.org/10.1037/xge0000143)                                                     |
# | 22 | B. Dritschel, S. Beltsos, S. McClintock                       | 2014 | An “alternating instructions” version of the Autobiographical Memory Test for assessing autobiographical memory specificity in non-clinical populations | Memory                                      | 22     | 881-889   | [10.1080/09658211.2013.839710](https://doi.org/10.1080/09658211.2013.839710)                                 |
# | 23 | C. Hitchcock, C. Rees, T. Dalgleish                           | 2017 | The Devil’s in the Detail: Accessibility of Specific Personal Memories Supports Rose-Tinted Self-Generalizations in Mental Health and Toxic Self-Generalizations in Clinical Depression | Journal of experimental psychology. General | 146    | 1286-1295 | [10.1037/xge0000343](https://doi.org/10.1037/xge0000343)                                                     |
# | 24 | C. Hitchcock, V. Mueller, E. Hammond, et al.                  | 2016 | The effects of autobiographical memory flexibility (MemFlex) training: An uncontrolled trial in individuals in remission from depression. | Journal of behavior therapy and experimental psychiatry | 52 | 92-98   | [10.1016/j.jbtep.2016.03.012](https://doi.org/10.1016/j.jbtep.2016.03.012)                                   |
# | 25 | C. Hitchcock, S. Gormley, C. Rees, et al.                     | 2015 | Memory Flexibility training (MemFlex) to reduce depressive symptomatology in individuals with major depressive disorder: study protocol for a randomised controlled trial | Trials                                      | 16     | -         | [10.1186/s13063-015-1029-y](https://doi.org/10.1186/s13063-015-1029-y)                                       |
# | 26 | S. Het, S. Vocks, J. Wolf, et al.                              | 2015 | Blunted neuroendocrine stress reactivity in young women with eating disorders.                         | Journal of psychosomatic research            | 78     | 260-267     | [10.1016/j.jpsychores.2014.11.001](https://doi.org/10.1016/j.jpsychores.2014.11.001)                         |
# | 27 | J. Treasure, V. Cardi                                          | 2017 | Anorexia Nervosa, Theory and Treatment: Where Are We 35 Years on from Hilde Bruch's Foundation Lecture? | European Eating Disorders Review           | 25     | 139-147     | [10.1002/erv.2511](https://doi.org/10.1002/erv.2511)                                                         |
# | 28 | A. Monteleone, G. Cascino, V. Ruzzi, et al.                    | 2020 | Multiple levels assessment of the RDoC "system for social process" in Eating Disorders: Biological, emotional and cognitive responses to the Trier Social Stress Test. | Journal of psychiatric research            | 130    | 160-166     | [10.1016/j.jpsychires.2020.07.039](https://doi.org/10.1016/j.jpsychires.2020.07.039)                         |
# | 29 | B. Carpita, D. Muti, I. Cremone, et al.                        | 2020 | Eating disorders and autism spectrum: links and risks                                                 | CNS Spectrums                               | 27     | 272-280     | [10.1017/S1092852920002011](https://doi.org/10.1017/S1092852920002011)                                      |
# | 30 | V. Cardi, R. Turton, S. Schifano, et al.                       | 2017 | Biased Interpretation of Ambiguous Social Scenarios in Anorexia Nervosa                                | European Eating Disorders Review           | 25     | 60-64       | [10.1002/erv.2493](https://doi.org/10.1002/erv.2493)                                                         |
# | 31 | L. Dell’Osso, C. Carmassi, I. Cremone, et al.                  | 2020 | Defining the Optimal Threshold Scores for Adult Autism Subthreshold Spectrum (AdAS Spectrum) in Clinical and General Population | Clinical Practice and Epidemiology in Mental Health | 16 | 204-211 | [10.2174/1745017902016010204](https://doi.org/10.2174/1745017902016010204)                                  |
# | 32 | L. Dell’Osso, P. Lorenzi, B. Carpita                           | 2019 | Autistic Traits and Illness Trajectories                                                               | Clinical Practice and Epidemiology in Mental Health | 15 | 94-98    | [10.2174/1745017901915010094](https://doi.org/10.2174/1745017901915010094)                                  |
# | 33 | L. Dell’Osso, B. Carpita, C. Bertelloni, et al.                | 2019 | Subthreshold autism spectrum in bipolar disorder: Prevalence and clinical correlates                  | Psychiatry Research                         | 281    | -           | [10.1016/j.psychres.2019.112605](https://doi.org/10.1016/j.psychres.2019.112605)                            |
# | 34 | L. Dell’Osso, I. Cremone, G. Amatori, et al.                   | 2021 | Investigating the Relationship between Autistic Traits, Ruminative Thinking, and Suicidality in a Clinical Sample of Subjects with Bipolar Disorder and Borderline Personality Disorder | Brain Sciences                           | 11     | -           | [10.3390/brainsci11050621](https://doi.org/10.3390/brainsci11050621)                                         |
# | 35 | B. Carpita, C. Carmassi, S. Calderoni, et al.                  | 2019 | The broad autism phenotype in real-life: clinical and functional correlates of autism spectrum symptoms and rumination among parents of patients with autism spectrum disorder | CNS Spectrums                         | 25 | 765-773 | [10.1017/S1092852919001615](https://doi.org/10.1017/S1092852919001615) |
#
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %%
# Taxonomy based on DSM-5-TR Chapters as top-level Factors
scid_taxonomy = {

    # 1. Neurodevelopmental Disorders
    "Neurodevelopmental Disorders": {
        "Intellectual Disability (Intellectual Developmental Disorder)": {
            "Synonyms": ["Cognitive Impairment", "Mental Retardation", "Developmental Delay"],
            "Verbs": ["Exhibit", "Demonstrate", "Experience", "Show", "Struggle with"],
            "Nouns": ["Deficits", "Limitations", "Impairment", "Challenges", "Difficulties"]
        },
        "Global Developmental Delay": {
            "Synonyms": ["Developmental Delay", "Delayed Development", "Developmental Disabilities"],
            "Verbs": ["Demonstrate", "Show", "Exhibit", "Struggle with", "Experience"],
            "Nouns": ["Delays", "Limitations", "Impairment", "Difficulties", "Challenges"]
        },
        "Unspecified Intellectual Disability": {
            "Synonyms": ["Cognitive Impairment", "Developmental Delay", "Unspecified Delay"],
            "Verbs": ["Show", "Exhibit", "Struggle with", "Experience", "Demonstrate"],
            "Nouns": ["Impairment", "Delay", "Limitation", "Challenge", "Difficulty"]
        },
        "Language Disorder": {
            "Synonyms": ["Language Impairment", "Communication Disorder", "Language Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Experience", "Have"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Speech Sound Disorder": {
            "Synonyms": ["Articulation Disorder", "Phonological Disorder", "Speech Impairment"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Errors", "Limitations", "Challenges"]
        },
        "Childhood-Onset Fluency Disorder (Stuttering)": {
            "Synonyms": ["Stuttering", "Fluency Disorder", "Speech Hesitation"],
            "Verbs": ["Stutter", "Hesiate", "Repeat", "Prolong", "Block"],
            "Nouns": ["Stutter", "Hesitation", "Repetition", "Prolongation", "Block"]
        },
        "Social (Pragmatic) Communication Disorder": { # DSM-5-TR term updated
            "Synonyms": ["Pragmatic Communication Disorder", "Social Language Deficit", "Communication Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Deficits", "Impairment", "Limitations", "Challenges"]
        },
         "Attention-Deficit/Hyperactivity Disorder": { # Grouping ADHD
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            # Combining verbs/nouns from specified/unspecified for the general category
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
            # Note: DSM-5 specifies presentations (inattentive, hyperactive/impulsive, combined)
            # and other/unspecified which could be nested further if needed.
            # Included original Other Specified/Unspecified from dataset below for completeness for now:
        },
       "Other Specified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity", "Atypical ADHD"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Unspecified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity", "Undifferentiated ADHD"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Specific Learning Disorder": {
            "Synonyms": ["Learning Disability", "Reading Disorder", "Dyslexia", "Mathematics Disorder", "Dyscalculia", "Disorder of Written Expression"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Impairment", "Deficit", "Limitation", "Challenge"]
            # Note: DSM-5 specifies impairment in reading, written expression, or mathematics
        },
        "Developmental Coordination Disorder": {
            "Synonyms": ["Dyspraxia", "Motor Coordination Disorder", "Clumsiness"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Stereotypic Movement Disorder": {
            "Synonyms": ["Repetitive Movement Disorder", "Stereotypies", "Motor Stereotypies"],
            "Verbs": ["Exhibit", "Show", "Engage in", "Perform", "Demonstrate"],
            "Nouns": ["Movements", "Behaviors", "Stereotypies", "Repetitions", "Mannerisms"]
        },
        "Tic Disorders": { # Grouping Tic Disorders
            "Synonyms": ["Tics", "Involuntary Movements", "Vocalizations"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"],
             # Original dataset entries nested below for detail:
             "Tourette's Disorder": {
                "Synonyms": ["Tic Disorder", "Motor Tics", "Vocal Tics", "Tourette Syndrome"],
                "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
                "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
            },
            "Persistent (Chronic) Motor or Vocal Tic Disorder": {
                "Synonyms": ["Chronic Tic Disorder", "Persistent Tic Disorder", "Motor Tics", "Vocal Tics"],
                "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
                "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
            },
            "Provisional Tic Disorder": {
                "Synonyms": ["Tic Disorder", "Transient Tic Disorder", "Motor Tics", "Vocal Tics"],
                "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
                "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
            },
            "Other Specified Tic Disorder": {
                "Synonyms": ["Tic Disorder", "Atypical Tic Disorder", "Motor Tics", "Vocal Tics"],
                "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
                "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
            },
            "Unspecified Tic Disorder": {
                "Synonyms": ["Tic Disorder", "Unspecified Tics", "Motor Tics", "Vocal Tics"],
                "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
                "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
            }
        }
    },

    # 2. Schizophrenia Spectrum and Other Psychotic Disorders
    "Schizophrenia Spectrum and Other Psychotic Disorders": {
        "Schizotypal (Personality) Disorder": { # Note: Also listed under Personality Disorders in DSM-5
            "Synonyms": ["Eccentric Personality", "Odd Personality", "Schizotypy"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Eccentricity", "Oddity", "Peculiarity", "Distortions", "Deficits"]
        },
        "Delusional Disorder": {
            "Synonyms": ["Delusions", "Fixed Beliefs", "False Beliefs"],
            "Verbs": ["Experience", "Have", "Hold", "Believe", "Exhibit"],
            "Nouns": ["Delusions", "Beliefs", "Ideas", "Paranoia", "Suspicion"]
        },
        "Brief Psychotic Disorder": {
            "Synonyms": ["Brief Psychosis", "Psychotic Episode", "Transient Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophreniform Disorder": {
            "Synonyms": ["Schizophrenia-like Psychosis", "Short-term Schizophrenia", "Psychotic Episode"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophrenia": {
            "Synonyms": ["Psychosis", "Schizophrenia Spectrum Disorder", "Thought Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Delusions", "Hallucinations", "Disorganized Thinking", "Negative Symptoms", "Psychotic Symptoms"]
        },
        "Schizoaffective Disorder": {
            "Synonyms": ["Schizophrenia and Mood Disorder", "Psychotic and Affective Symptoms", "Mixed Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Mood Episodes", "Symptoms", "Delusions", "Hallucinations"]
        },
        "Substance/Medication-Induced Psychotic Disorder": { # From Substance section, relevant here too
            "Synonyms": ["Drug-Induced Psychosis", "Medication-Caused Psychotic Symptoms"],
            "Verbs": ["Experience (delusions and/or hallucinations after substance intoxication/withdrawal or medication exposure)", "Exhibit (psychotic symptoms judged etiologically related to substance/medication)"],
            "Nouns": ["Delusions", "Hallucinations", "Substance intoxication/withdrawal context", "Medication exposure context", "Symptoms developed during or soon after substance intoxication/withdrawal or after exposure to a medication", "Clinically significant psychotic symptoms"]
        },
        "Psychotic Disorder Due to Another Medical Condition": { # Placeholder based on DSM structure
             "Synonyms": ["Secondary Psychosis", "Psychosis due to illness"],
             "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
             "Nouns": ["Psychosis", "Symptoms", "Delusions", "Hallucinations", "Underlying condition"]
        },
        "Other Specified Schizophrenia Spectrum and Other Psychotic Disorder": {
             "Synonyms": ["Atypical Psychosis", "Subthreshold Psychosis", "Unspecified Psychotic Symptoms", "Attenuated Psychosis Syndrome"],
             "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
             "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
         },
         "Unspecified Schizophrenia Spectrum and Other Psychotic Disorder": {
             "Synonyms": ["Unspecified Psychosis", "Psychotic Symptoms", "Undifferentiated Psychosis"],
             "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
             "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
         },
        "Catatonia": { # Catatonia associated with another mental disorder, due to another medical condition, or unspecified
            "Synonyms": ["Catatonic State", "Motor Immobility/Excitement", "Mutism"],
            "Verbs": ["Exhibit", "Show", "Maintain", "Resist", "Mimic"],
            "Nouns": ["Stupor", "Catalepsy", "Waxy flexibility", "Mutism", "Negativism", "Posturing", "Stereotypy", "Agitation", "Echolalia", "Echopraxia"]
         }
    },

    # 3. Bipolar and Related Disorders
    "Bipolar and Related Disorders": {
        "Bipolar I Disorder": {
            "Synonyms": ["Bipolar Disorder", "Mania", "Manic-Depressive Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Bipolar II Disorder": {
            "Synonyms": ["Bipolar Disorder", "Hypomania", "Recurrent Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Hypomania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Cyclothymic Disorder": {
            "Synonyms": ["Cyclothymia", "Mood Instability", "Mild Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Swings", "Hypomanic Symptoms", "Depressive Symptoms", "Mood Instability", "Symptoms"]
        },
        "Substance/Medication-Induced Bipolar and Related Disorder": {
            "Synonyms": ["Substance-Induced Mood Disorder", "Medication-Induced Mood Disorder", "Secondary Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Hypomania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Bipolar and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Bipolar Disorder", "Medical Condition-Induced Mood Disorder", "Mood Disorder Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Hypomania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Other Specified Bipolar and Related Disorder": {
            "Synonyms": ["Atypical Bipolar Disorder", "Subthreshold Bipolar Disorder", "Unspecified Mood Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Hypomania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Unspecified Bipolar and Related Disorder": {
            "Synonyms": ["Unspecified Mood Disorder", "Bipolar Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Hypomania", "Depression", "Mood Swings", "Symptoms"]
        }
    },

    # 4. Depressive Disorders
    "Depressive Disorders": {
        "Disruptive Mood Dysregulation Disorder": {
            "Synonyms": ["DMDD", "Childhood Mood Disorder", "Temper Dysregulation"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Temper Outbursts", "Irritability", "Mood Dysregulation", "Emotional Lability", "Symptoms"]
        },
        "Major Depressive Disorder": {
            "Synonyms": ["MDD", "Clinical Depression", "Unipolar Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Sleep Disturbance", "Appetite Changes", "Fatigue", "Worthlessness", "Suicidal Ideation", "Symptoms"]
            # Note: SCID-5 also lists Major Depressive Episode separately
        },
        "Persistent Depressive Disorder (Dysthymia)": {
            "Synonyms": ["Dysthymia", "Chronic Depression", "Persistent Low Mood"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Low Self-Esteem", "Fatigue", "Hopelessness", "Symptoms"]
        },
        "Premenstrual Dysphoric Disorder (PMDD)": {
            "Synonyms": ["PMDD", "Premenstrual Mood Disorder", "Severe PMS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Lability", "Irritability", "Depressed Mood", "Anxiety", "Symptoms"]
        },
        "Substance/Medication-Induced Depressive Disorder": {
            "Synonyms": ["Substance-Induced Depression", "Medication-Induced Depression", "Secondary Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Depressive Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Depression", "Medical Condition-Induced Depression", "Depression Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Other Specified Depressive Disorder": {
            "Synonyms": ["Atypical Depression", "Subthreshold Depression", "Unspecified Depressive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Unspecified Depressive Disorder": {
            "Synonyms": ["Unspecified Depression", "Depressive Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        }
    },

    # 5. Anxiety Disorders
    "Anxiety Disorders": {
        "Separation Anxiety Disorder": {
            "Synonyms": ["Separation Anxiety", "Anxiety About Separation", "Fear of Separation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Distress", "Worry", "Symptoms"]
        },
        "Selective Mutism": {
            "Synonyms": ["Situational Mutism", "Selective Non-Speaking", "Social Mutism"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Mutism", "Non-Speaking", "Silence", "Anxiety", "Fear"]
        },
        "Specific Phobia": {
            "Synonyms": ["Phobia", "Fear", "Anxiety Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Fear", "Anxiety", "Avoidance", "Distress", "Symptoms"]
        },
        "Social Anxiety Disorder (Social Phobia)": {
            "Synonyms": ["Social Phobia", "Social Anxiety", "Fear of Social Situations"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Distress", "Symptoms"]
        },
        "Panic Disorder": {
            "Synonyms": ["Panic Attacks", "Anxiety Disorder", "Panic"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Panic Attacks", "Anxiety", "Fear", "Distress", "Symptoms"]
        },
        "Agoraphobia": {
            "Synonyms": ["Fear of Open Spaces", "Anxiety Disorder", "Avoidance of Public Places"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Distress", "Symptoms"]
        },
        "Generalized Anxiety Disorder (GAD)": {
            "Synonyms": ["GAD", "Excessive Worry", "Chronic Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Apprehension"]
        },
        "Substance/Medication-Induced Anxiety Disorder": {
            "Synonyms": ["Substance-Induced Anxiety", "Medication-Induced Anxiety", "Secondary Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Mood Changes", "Agitation"]
        },
        "Anxiety Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Anxiety", "Medical Condition-Induced Anxiety", "Anxiety Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Mood Changes", "Apprehension"]
        },
        "Other Specified Anxiety Disorder": {
            "Synonyms": ["Atypical Anxiety", "Subthreshold Anxiety", "Unspecified Anxiety Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Worry", "Apprehension"]
        },
        "Unspecified Anxiety Disorder": {
            "Synonyms": ["Unspecified Anxiety", "Anxiety Symptoms", "Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Worry", "Apprehension"]
        }
    },

    # 6. Obsessive-Compulsive and Related Disorders
    "Obsessive-Compulsive and Related Disorders": {
        "Obsessive-Compulsive Disorder (OCD)": {
            "Synonyms": ["OCD", "Obsessions and Compulsions", "Obsessive Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Rituals"]
        },
        "Body Dysmorphic Disorder": {
            "Synonyms": ["BDD", "Body Image Disorder", "Dysmorphophobia"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Preoccupation", "Distress", "Concern", "Flaws", "Defects"]
        },
        "Hoarding Disorder": {
            "Synonyms": ["Compulsive Hoarding", "Hoarding", "Collecting Disorder"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Manifest"],
            "Nouns": ["Clutter", "Accumulation", "Difficulty Discarding", "Distress", "Possessions"]
        },
        "Trichotillomania (Hair-Pulling Disorder)": {
            "Synonyms": ["Hair-Pulling Disorder", "Trichotillomania", "Hair Pulling"],
            "Verbs": ["Pull", "Experience", "Have", "Show", "Exhibit"],
            "Nouns": ["Hair Pulling", "Urges", "Behaviors", "Distress", "Hair Loss"]
        },
        "Excoriation (Skin-Picking) Disorder": {
            "Synonyms": ["Skin-Picking Disorder", "Excoriation", "Dermatillomania"],
            "Verbs": ["Pick", "Experience", "Have", "Show", "Exhibit"],
            "Nouns": ["Skin Picking", "Urges", "Behaviors", "Distress", "Lesions"]
        },
        "Substance/Medication-Induced Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Substance-Induced OCD", "Medication-Induced OCD", "Secondary OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Obsessive-Compulsive and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Medical Condition-Induced OCD", "Secondary OCD", "OCD Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Other Specified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Atypical OCD", "Subthreshold OCD", "Unspecified OCD Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Unspecified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Unspecified OCD", "OCD Symptoms", "Obsessive-Compulsive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        }
    },

    # 7. Trauma- and Stressor-Related Disorders
    "Trauma- and Stressor-Related Disorders": {
        "Reactive Attachment Disorder": { # Added from DSM-5 chapter
            "Synonyms": ["Attachment Difficulties", "Inhibited Attachment", "Withdrawn Behavior"],
            "Verbs": ["Withdraw", "Inhibit", "Avoid", "Lack", "Fail to seek comfort"],
            "Nouns": ["Inhibition", "Withdrawal", "Lack of attachment", "Emotional disturbance", "Social neglect"]
        },
        "Disinhibited Social Engagement Disorder": { # Added from DSM-5 chapter
            "Synonyms": ["Indiscriminate Friendliness", "Overly Familiar Behavior", "Lack of Reticence"],
            "Verbs": ["Approach strangers", "Act overly familiar", "Lack boundaries", "Show disinhibition"],
            "Nouns": ["Disinhibition", "Overfamiliarity", "Lack of reticence", "Indiscriminate attachment", "Social neglect history"]
        },
        "Posttraumatic Stress Disorder (PTSD)": {
            "Synonyms": ["PTSD", "Trauma Disorder", "Stress Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Memories", "Avoidance", "Hyperarousal", "Negative Mood", "Symptoms"]
        },
        "Acute Stress Disorder": {
            "Synonyms": ["ASD", "Acute Stress Reaction", "Trauma Response"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Symptoms", "Dissociation", "Avoidance", "Arousal Symptoms", "Symptoms"]
        },
        "Adjustment Disorders": {
            "Synonyms": ["Adjustment Disorder", "Stress Response Syndrome", "Situational Distress"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Emotional Symptoms", "Behavioral Symptoms", "Distress", "Impairment", "Reactions"]
        },
         "Prolonged Grief Disorder": { # Added from DSM-5-TR
            "Synonyms": ["Complicated Grief", "Persistent Grief", "Intense Bereavement"],
            "Verbs": ["Yearn", "Pine", "Experience intense sorrow", "Preoccupy", "Feel numb"],
            "Nouns": ["Intense yearning", "Preoccupation with deceased", "Identity disruption", "Disbelief", "Avoidance of reminders", "Intense emotional pain", "Loneliness", "Meaninglessness"]
        },
        "Other Specified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Atypical Trauma Disorder", "Subthreshold Stress Disorder", "Unspecified Trauma Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Trauma Response", "Stress Symptoms", "Reactions"]
        },
        "Unspecified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Unspecified Trauma Disorder", "Trauma Symptoms", "Stress Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Trauma Response", "Stress Symptoms", "Reactions"]
        }
    },

    # 8. Dissociative Disorders
    "Dissociative Disorders": {
        "Dissociative Identity Disorder": {
            "Synonyms": ["DID", "Multiple Personality Disorder", "Identity Fragmentation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Multiple Identities", "Memory Gaps", "Amnesia", "Dissociation", "Alters"]
        },
        "Dissociative Amnesia": {
            "Synonyms": ["Dissociative Amnesia", "Amnesia", "Memory Loss"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Memory Gaps", "Amnesia", "Forgetfulness", "Identity Loss", "Fugue"]
        },
        "Depersonalization/Derealization Disorder": {
            "Synonyms": ["Depersonalization Disorder", "Derealization Disorder", "Detachment Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depersonalization", "Derealization", "Detachment", "Unreality", "Dissociation"]
        },
        "Other Specified Dissociative Disorder": {
            "Synonyms": ["Atypical Dissociation", "Subthreshold Dissociation", "Unspecified Dissociative Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        },
        "Unspecified Dissociative Disorder": {
            "Synonyms": ["Unspecified Dissociation", "Dissociative Symptoms", "Dissociation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        }
    },

    # 9. Somatic Symptom and Related Disorders
    "Somatic Symptom and Related Disorders": {
        "Somatic Symptom Disorder": {
            "Synonyms": ["Somatization Disorder", "Somatic Symptoms", "Physical Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        },
        "Illness Anxiety Disorder": {
            "Synonyms": ["Hypochondriasis", "Health Anxiety", "Illness Worry"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Fear", "Illness Concern", "Symptoms"]
        },
        "Conversion Disorder (Functional Neurological Symptom Disorder)": {
            "Synonyms": ["Functional Neurological Disorder", "Conversion Disorder", "Psychogenic Symptoms"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Manifest"],
            "Nouns": ["Neurological Symptoms", "Motor Symptoms", "Sensory Symptoms", "Weakness", "Paralysis"]
        },
        "Psychological Factors Affecting Other Medical Conditions": {
            "Synonyms": ["Psychological Factors Affecting Medical Conditions", "Mind-Body Interaction", "Stress-Related Illness"],
            "Verbs": ["Affect", "Influence", "Exacerbate", "Contribute to", "Impact"],
            "Nouns": ["Psychological Factors", "Stress", "Emotions", "Behaviors", "Medical Conditions"]
        },
         "Factitious Disorder": { # Added from DSM-5 chapter
            "Synonyms": ["Munchausen Syndrome", "Feigned Illness", "Induced Illness"],
            "Verbs": ["Falsify", "Feigne", "Induce", "Deceive", "Present"],
            "Nouns": ["Deception", "Falsification", "Feigning", "Induction of injury/disease", "Absence of external reward"]
         },
        "Other Specified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Atypical Somatic Symptom Disorder", "Subthreshold Somatic Symptom Disorder", "Unspecified Somatic Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        },
        "Unspecified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Unspecified Somatic Symptoms", "Somatic Symptoms", "Physical Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        }
    },

    # 10. Feeding and Eating Disorders
    "Feeding and Eating Disorders": {
        "Pica": {
            "Synonyms": ["Unusual Eating Habits", "Non-Food Consumption", "Abnormal Appetite"],
            "Verbs": ["Eat", "Consume", "Ingest", "Crave", "Desire"],
            "Nouns": ["Non-Nutritive Substances", "Non-Food Items", "Unusual Substances", "Cravings", "Consumption"]
        },
        "Rumination Disorder": {
            "Synonyms": ["Regurgitation Disorder", "Repeated Regurgitation", "Spitting Up"],
            "Verbs": ["Regurgitate", "Bring Up", "Re-Chew", "Re-Swallow", "Expel"],
            "Nouns": ["Regurgitation", "Vomit", "Food", "Stomach Contents", "Behavior"]
        },
        "Avoidant/Restrictive Food Intake Disorder": {
            "Synonyms": ["ARFID", "Selective Eating Disorder", "Food Avoidance"],
            "Verbs": ["Avoid", "Restrict", "Limit", "Refuse", "Fear"],
            "Nouns": ["Food", "Intake", "Eating", "Avoidance", "Restriction"]
        },
        "Anorexia Nervosa": {
            "Synonyms": ["Anorexia", "Restrictive Eating", "Fear of Weight Gain"],
            "Verbs": ["Restrict", "Fear", "Avoid", "Lose Weight", "Control"],
            "Nouns": ["Weight", "Body Image", "Food", "Eating", "Restriction"]
        },
        "Bulimia Nervosa": {
            "Synonyms": ["Bulimia", "Binge Eating", "Purging Disorder"],
            "Verbs": ["Binge", "Purge", "Eat", "Compensate", "Control"],
            "Nouns": ["Binge Eating", "Purging", "Weight", "Food", "Body Shape"]
        },
        "Binge-Eating Disorder": {
            "Synonyms": ["Binge Eating", "Compulsive Overeating", "Emotional Eating"],
            "Verbs": ["Binge", "Overeat", "Consume", "Feel", "Experience"],
            "Nouns": ["Binge Eating", "Food", "Weight", "Control", "Distress"]
        },
        "Other Specified Feeding or Eating Disorder": {
            "Synonyms": ["Atypical Eating Disorder", "Subthreshold Eating Disorder", "Unspecified Eating Symptoms"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Worry"],
            "Nouns": ["Eating", "Food", "Weight", "Body Image", "Symptoms"]
        },
        "Unspecified Feeding or Eating Disorder": {
            "Synonyms": ["Unspecified Eating Disorder", "Eating Symptoms", "Disordered Eating"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Worry"],
            "Nouns": ["Eating", "Food", "Weight", "Body Image", "Symptoms"]
        }
    },

    # 11. Elimination Disorders
    "Elimination Disorders": {
        "Enuresis": {
            "Synonyms": ["Bedwetting", "Urinary Incontinence", "Nocturnal Enuresis"],
            "Verbs": ["Wet", "Urinate", "Void", "Leak", "Experience"],
            "Nouns": ["Urine", "Bedwetting", "Incontinence", "Urination", "Accidents"]
        },
        "Encopresis": {
            "Synonyms": ["Fecal Incontinence", "Soiling", "Bowel Incontinence"],
            "Verbs": ["Defecate", "Soil", "Pass", "Leak", "Experience"],
            "Nouns": ["Feces", "Incontinence", "Soiling", "Bowel Movements", "Accidents"]
        },
        "Other Specified Elimination Disorder": { # Added placeholder
            "Synonyms": [], "Verbs": [], "Nouns": []
        },
        "Unspecified Elimination Disorder": { # Added placeholder
            "Synonyms": [], "Verbs": [], "Nouns": []
        }
    },

    # 12. Sleep-Wake Disorders
    "Sleep-Wake Disorders": {
        "Insomnia Disorder": {
            "Synonyms": ["Insomnia", "Sleeplessness", "Difficulty Initiating/Maintaining Sleep", "Nonrestorative Sleep"],
            "Verbs": ["Struggle to sleep", "Have trouble sleeping", "Wake up (frequently/early)", "Experience (difficulty falling/staying asleep)", "Suffer from (poor sleep quality)", "Report (daytime fatigue)"],
            "Nouns": ["Difficulty initiating sleep", "Difficulty maintaining sleep", "Early-morning awakening", "Nonrestorative sleep", "Daytime fatigue", "Impaired functioning", "Sleep dissatisfaction", "Irritability", "Cognitive impairment (due to sleep loss)"]
        },
        "Hypersomnolence Disorder": {
            "Synonyms": ["Excessive Sleepiness", "Hypersomnia", "Prolonged Sleep", "Daytime Drowsiness"],
            "Verbs": ["Feel excessively sleepy", "Sleep excessively (prolonged nocturnal/daytime)", "Nap frequently (unrefreshing)", "Struggle to stay awake", "Experience (sleep inertia/drunkenness)", "Report (nonrestorative sleep despite long duration)"],
            "Nouns": ["Excessive sleepiness", "Prolonged nocturnal sleep", "Sleep inertia (sleep drunkenness)", "Nonrestorative sleep", "Unintentional daytime naps", "Impaired alertness", "Automatic behavior", "Difficulty waking up"]
        },
        "Narcolepsy": {
            "Synonyms": ["Excessive Daytime Sleepiness with Cataplexy", "Sleep Attacks", "Hypnagogic Hallucinations"],
            "Verbs": ["Experience (recurrent irresistible sleep/lapses into sleep)", "Have (cataplexy)", "Exhibit (hypocretin deficiency)", "Report (hypnagogic/hypnopompic hallucinations)", "Suffer (sleep paralysis)"],
            "Nouns": ["Irrepressible need to sleep", "Sleep attacks", "Cataplexy", "Hypocretin deficiency (in CSF)", "REM sleep latency reduction", "Hypnagogic hallucinations", "Hypnopompic hallucinations", "Sleep paralysis", "Fragmented nighttime sleep"]
            # Note: DSM-5 specifies types based on cataplexy and hypocretin deficiency
        },
        "Breathing-Related Sleep Disorders": { # Grouping
             "Synonyms": ["Sleep Apnea", "Hypoventilation", "Sleep-Disordered Breathing"],
             "Verbs": ["Stop breathing", "Snore", "Gasp", "Hypoventilate", "Experience (apneas/hypopneas)"],
             "Nouns": ["Apneas", "Hypopneas", "Snoring", "Hypoventilation", "Daytime sleepiness", "Oxygen desaturation"],
              # Original dataset entries nested below:
             "Obstructive Sleep Apnea Hypopnea": {
                "Synonyms": ["OSA", "Sleep Apnea", "Breathing-Related Sleep Disorder"],
                "Verbs": ["Experience (apneas/hypopneas)", "Snore (loudly)", "Gasp (for air during sleep)", "Report (daytime sleepiness/fatigue)", "Have (witnessed apneas)"],
                "Nouns": ["Apneas", "Hypopneas", "Snoring", "Gasping/choking (during sleep)", "Nocturnal breathing disturbances", "Daytime sleepiness", "Fatigue", "Unrefreshing sleep", "Morning headaches", "Impaired concentration"]
            },
            "Central Sleep Apnea": {
                "Synonyms": ["CSA", "Cessation of Airflow without Obstruction", "Breathing-Related Sleep Disorder"],
                "Verbs": ["Experience (apneas without respiratory effort)", "Report (insomnia/daytime sleepiness)", "Exhibit (Cheyne-Stokes breathing - specific type)"],
                "Nouns": ["Recurrent apneas (central origin)", "Absence of respiratory effort (during apnea)", "Daytime sleepiness", "Insomnia complaints", "Fragmented sleep", "Cheyne-Stokes breathing pattern (for idiopathic CSA or CSA with specific comorbidities)"]
            },
            "Sleep-Related Hypoventilation": {
                "Synonyms": ["Nocturnal Hypoventilation", "Breathing-Related Sleep Disorder"],
                "Verbs": ["Exhibit (decreased respiration with elevated CO2)", "Report (daytime sleepiness/insomnia/headaches)", "Experience (shallow breathing during sleep)"],
                "Nouns": ["Decreased respiration", "Elevated CO2 levels (hypercapnia)", "Shallow breathing (during sleep)", "Daytime sleepiness", "Morning headaches", "Insomnia", "Fatigue", "Cardiopulmonary complications (potential)"]
            }
        },
        "Circadian Rhythm Sleep-Wake Disorders": { # Grouping
             "Synonyms": ["Circadian Misalignment", "Body Clock Disorder", "Sleep Timing Issues"],
             "Verbs": ["Delay sleep", "Advance sleep", "Have irregular sleep", "Free-run", "Experience (shift work difficulties)"],
             "Nouns": ["Misaligned sleep-wake cycle", "Delayed phase", "Advanced phase", "Irregular pattern", "Non-24 pattern", "Shift work pattern", "Jet lag"],
             # Original dataset entries nested below:
             "Delayed Sleep Phase Type": {
                "Synonyms": ["Delayed Sleep Onset", "Night Owl Chronotype (extreme)", "Circadian Rhythm Disorder"],
                "Verbs": ["Delay (sleep onset/wake times significantly)", "Struggle (waking at desired times)", "Feel (most alert late at night)", "Report (difficulty falling asleep until late)"],
                "Nouns": ["Persistent delay (sleep-wake schedule)", "Late sleep onset", "Late wake time", "Sleep-onset insomnia (when trying to sleep earlier)", "Difficulty waking", "Daytime sleepiness (if schedule is forced early)", "Social/occupational impairment"]
            },
            "Advanced Sleep Phase Type": {
                "Synonyms": ["Early Sleep Onset", "Early Bird Chronotype (extreme)", "Circadian Rhythm Disorder"],
                "Verbs": ["Advance (sleep onset/wake times significantly)", "Wake (very early)", "Feel (sleepy early evening)", "Report (inability to stay asleep until desired time)"],
                "Nouns": ["Persistent advance (sleep-wake schedule)", "Early sleep onset", "Early morning awakening", "Evening sleepiness", "Inability to maintain sleep later", "Social/occupational impairment (if schedule is forced later)"]
            },
            "Irregular Sleep-Wake Type": {
                "Synonyms": ["Disorganized Sleep Pattern", "Fragmented Sleep Across 24 Hours", "Circadian Rhythm Disorder"],
                "Verbs": ["Exhibit (temporally disorganized sleep/wake pattern)", "Lack (a clear circadian rhythm)", "Nap (frequently/irregularly)", "Experience (insomnia at night/excessive sleepiness during day)"],
                "Nouns": ["Lack of discernible circadian rhythm", "Fragmented sleep (at least three episodes in 24h)", "Irregular sleep-wake times", "Insomnia (during conventional sleep period)", "Excessive daytime sleepiness", "Social/occupational impairment"]
            },
            "Non-24-Hour Sleep-Wake Type": {
                "Synonyms": ["Free-Running Disorder", "N24SWD", "Circadian Rhythm Disorder (blind individuals common)"],
                "Verbs": ["Exhibit (sleep-wake cycle not entrained to 24-hour day)", "Drift (sleep times progressively later)", "Experience (periods of insomnia/daytime sleepiness cyclically)"],
                "Nouns": ["Non-entrained circadian rhythm (typically >24h)", "Progressive daily delay (sleep/wake times)", "Cyclical insomnia", "Cyclical excessive sleepiness", "Impairment (due to misalignment with societal schedules)", "Common in blind individuals"]
            },
            "Shift Work Type": { # Added from DSM-5 chapter
                 "Synonyms": ["Shift Work Sleep Disorder", "SWSD", "Sleep Problems due to Work Schedule"],
                 "Verbs": ["Experience (insomnia/excessive sleepiness due to work schedule)", "Struggle (to adjust sleep to shift work)", "Report (fatigue/impaired performance)"],
                 "Nouns": ["Insomnia", "Excessive sleepiness", "Work schedule conflict (with endogenous circadian rhythm)", "Reduced sleep time", "Impairment in functioning", "Fatigue"]
            },
             "Jet Lag Type": { # Added from DSM-5 chapter
                 "Synonyms": ["Jet Lag Disorder", "Time Zone Change Syndrome"],
                 "Verbs": ["Experience (sleepiness/insomnia after rapid travel)", "Struggle (to align sleep to new time zone)", "Report (fatigue/impaired functioning)"],
                 "Nouns": ["Sleep disturbance", "Daytime fatigue", "Malaise", "Impaired performance", "Gastrointestinal disturbance", "Travel across time zones"]
            }
        },
        "Parasomnias": { # Grouping
             "Synonyms": ["Abnormal Sleep Events", "Undesirable Sleep Behaviors"],
             "Verbs": ["Sleepwalk", "Have night terrors", "Have nightmares", "Act out dreams", "Experience (sleep paralysis)"],
             "Nouns": ["Sleepwalking", "Sleep terrors", "Nightmares", "REM sleep behavior disorder", "Sleep paralysis", "Confusional arousals"],
             # Original dataset entries nested below:
            "Non-Rapid Eye Movement Sleep Arousal Disorders": {
                "Synonyms": ["NREM Sleep Parasomnias", "Sleepwalking", "Sleep Terrors", "Confusional Arousals"],
                "Verbs": ["Experience (recurrent episodes of incomplete awakening)", "Exhibit (sleepwalking/sleep terrors)", "Have (amnesia for episodes)", "Report (difficulty awakening during episode/confusion if awakened)"],
                "Nouns": ["Incomplete awakening from NREM sleep", "Sleepwalking (somnambulism)", "Sleep terrors (pavor nocturnus)", "Relative unresponsiveness (during episode)", "Amnesia for episode content", "Confusion upon awakening", "Potential for injury"]
                # Note: DSM-5 specifies Sleepwalking Type and Sleep Terror Type
            },
             "Nightmare Disorder": {
                "Synonyms": ["Dream Anxiety Disorder", "Recurrent Nightmares"],
                "Verbs": ["Experience (recurrent extended/extremely dysphoric dreams)", "Recall (dreams vividly)", "Become (rapidly oriented/alert upon awakening)", "Report (significant distress/impairment from nightmares)"],
                "Nouns": ["Repeated extended dysphoric dreams", "Well-remembered dream content (threatening)", "Rapid alertness upon awakening", "Significant distress (from dreams)", "Impairment in functioning (due to sleep disturbance/fear of sleep)"]
            },
            "Rapid Eye Movement Sleep Behavior Disorder": {
                "Synonyms": ["RBD", "REM Sleep Without Atonia", "Dream-Enacting Behavior"],
                "Verbs": ["Experience (repeated episodes of arousal with vocalization/complex motor behaviors during REM)", "Act out (dreams)", "Recall (dream content if awakened)", "Lack (normal REM sleep atonia)"],
                "Nouns": ["Arousal during REM sleep", "Vocalization (talking/shouting)", "Complex motor behaviors (dream-enactment)", "Absence of REM sleep atonia (polysomnography finding)", "Injury potential (to self/bed partner)", "Vivid dream recall (if awakened)"]
            },
        },
        "Restless Legs Syndrome": {
            "Synonyms": ["RLS", "Willis-Ekbom Disease", "Urge to Move Legs"],
            "Verbs": ["Experience (urge to move legs with uncomfortable sensations)", "Feel (relief with movement)", "Report (worsening symptoms at rest/evening/night)"],
            "Nouns": ["Urge to move legs", "Unpleasant leg sensations (creeping/crawling/tingling)", "Symptoms worse at rest", "Symptoms worse in evening/night", "Relief with movement", "Sleep disturbance", "Daytime fatigue"]
        },
        "Substance/Medication-Induced Sleep Disorder": {
            "Synonyms": ["Drug-Induced Sleep Problems", "Sleep Disturbance from Medication/Substance"],
            "Verbs": ["Experience (prominent sleep disturbance due to substance/medication use/withdrawal)", "Report (insomnia/hypersomnia/parasomnia/mixed)", "Correlate (sleep problem with substance exposure)"],
            "Nouns": ["Clinically significant sleep disturbance (insomnia/hypersomnia/parasomnia/circadian rhythm disruption)", "Evidence of substance intoxication/withdrawal or medication exposure", "Temporal association (between substance/medication and sleep disturbance)", "Distress/impairment"]
        },
         "Other Specified Insomnia Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Insomnia Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
          "Other Specified Hypersomnolence Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Hypersomnolence Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Other Specified Sleep-Wake Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Sleep-Wake Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         }
    },

    # 13. Sexual Dysfunctions
    "Sexual Dysfunctions": {
        "Delayed Ejaculation": {
            "Synonyms": ["Male Orgasmic Disorder (historic)", "Retarded Ejaculation", "Ejaculatory Inhibition"],
            "Verbs": ["Experience difficulty", "Delay (ejaculation)", "Struggle to (ejaculate)", "Require (prolonged stimulation)", "Report (distress)"],
            "Nouns": ["Delay (in ejaculation)", "Infrequent orgasm", "Absence of orgasm", "Marked distress", "Interpersonal difficulty", "Reduced satisfaction"]
        },
        "Erectile Disorder": {
            "Synonyms": ["Impotence (colloquial)", "Erectile Dysfunction", "Difficulty Achieving/Maintaining Erection"],
            "Verbs": ["Fail to (obtain/maintain erection)", "Experience (decreased rigidity)", "Report (distress)", "Avoid (sexual activity)"],
            "Nouns": ["Erectile difficulty", "Insufficient rigidity", "Maintenance failure", "Reduced confidence", "Performance anxiety", "Relationship strain"]
        },
        "Female Orgasmic Disorder": {
            "Synonyms": ["Anorgasmia (in females)", "Difficulty Reaching Orgasm", "Inhibited Female Orgasm"],
            "Verbs": ["Experience (delay/infrequency/absence of orgasm)", "Report (reduced intensity)", "Feel (distress)", "Require (specific stimulation)"],
            "Nouns": ["Orgasmic difficulty", "Delayed orgasm", "Absent orgasm", "Reduced intensity", "Sexual dissatisfaction", "Marked distress"]
        },
        "Female Sexual Interest/Arousal Disorder": {
            "Synonyms": ["Low Libido (female)", "Reduced Sexual Excitement", "Lack of Sexual Interest/Arousal"],
            "Verbs": ["Lack (interest/arousal/thoughts/fantasies)", "Fail to (initiate/respond to)", "Experience (reduced lubrication/sensation)"],
            "Nouns": ["Reduced interest", "Absent arousal", "Lack of sexual thoughts", "Reduced initiation", "Genital insensitivity", "Marked distress"]
        },
        "Genito-Pelvic Pain/Penetration Disorder": {
            "Synonyms": ["Dyspareunia (historic)", "Vaginismus (historic)", "Painful Intercourse", "Sexual Pain Disorder"],
            "Verbs": ["Experience (pain during intercourse/penetration)", "Fear (pain)", "Tense (pelvic floor muscles)", "Avoid (penetration)"],
            "Nouns": ["Genital pain", "Pelvic pain", "Penetration difficulty", "Fear of pain", "Muscle tension", "Marked distress", "Avoidance"]
        },
        "Male Hypoactive Sexual Desire Disorder": {
            "Synonyms": ["Low Libido (male)", "Reduced Sexual Interest", "Lack of Sexual Desire"],
            "Verbs": ["Lack (sexual thoughts/fantasies/desire)", "Show (deficient interest)", "Report (distress)"],
            "Nouns": ["Reduced desire", "Absent thoughts/fantasies", "Deficient interest", "Lack of motivation", "Interpersonal difficulty", "Marked distress"]
        },
        "Premature (Early) Ejaculation": {
            "Synonyms": ["Rapid Ejaculation", "Early Climax"],
            "Verbs": ["Ejaculate (rapidly/early)", "Experience (lack of control)", "Feel (distress/frustration)"],
            "Nouns": ["Early ejaculation", "Rapid climax", "Lack of control", "Reduced satisfaction", "Interpersonal distress", "Frustration"]
        },
        "Substance/Medication-Induced Sexual Dysfunction": {
             "Synonyms": ["Drug-Induced Sexual Problems", "Medication-Caused Sexual Difficulties"],
             "Verbs": ["Experience (clinically significant sexual dysfunction after substance intoxication/withdrawal or medication exposure)", "Report (impaired sexual desire/arousal/orgasm/pain linked to substance/medication)"],
             "Nouns": ["Clinically significant sexual dysfunction", "Impaired desire", "Impaired arousal", "Orgasmic dysfunction", "Sexual pain", "Substance intoxication/withdrawal context", "Medication exposure context"]
         },
        "Other Specified Sexual Dysfunction": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Sexual Dysfunction": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         }
    },

    # 14. Gender Dysphoria
    "Gender Dysphoria": {
        "Gender Dysphoria in Children": {
            "Synonyms": ["Gender Incongruence in Children", "Cross-Gender Identification (children)"],
            "Verbs": ["Express (desire to be other gender)", "State (one is other gender)", "Prefer (cross-gender roles/toys/attire)", "Reject (assigned gender)", "Experience (distress)"],
            "Nouns": ["Gender incongruence", "Strong desire (to be other gender)", "Aversion (to own anatomy)", "Cross-gender preferences", "Clinically significant distress", "Impairment in functioning"]
        },
        "Gender Dysphoria in Adolescents and Adults": {
            "Synonyms": ["Gender Incongruence", "Transgender Identity (associated distress/impairment)", "Gender Identity Disorder (historic)"],
            "Verbs": ["Experience (marked incongruence)", "Express (strong desire for other gender characteristics)", "Feel (gender does not match assigned sex)", "Seek (transition)", "Report (significant distress)"],
            "Nouns": ["Marked incongruence (experienced/expressed gender and assigned gender)", "Desire to rid primary/secondary sex characteristics", "Desire for other gender's sex characteristics", "Conviction of being other gender", "Clinically significant distress", "Impairment in social/occupational functioning"]
        },
        "Other Specified Gender Dysphoria": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Gender Dysphoria": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         }
    },

    # 15. Disruptive, Impulse-Control, and Conduct Disorders
    "Disruptive, Impulse-Control, and Conduct Disorders": {
        "Oppositional Defiant Disorder": {
            "Synonyms": ["ODD", "Defiant Behavior", "Argumentativeness"],
            "Verbs": ["Argue (with authority)", "Defy (rules)", "Annoy (deliberately)", "Blame (others)", "Lose (temper)", "Act (spiteful/vindictive)"],
            "Nouns": ["Angry/irritable mood", "Argumentative/defiant behavior", "Vindictiveness", "Temper outbursts", "Noncompliance", "Resentfulness"]
        },
        "Intermittent Explosive Disorder": {
            "Synonyms": ["IED", "Aggressive Outbursts", "Impulsive Aggression"],
            "Verbs": ["Fail to (control aggressive impulses)", "Exhibit (verbal aggression/physical aggression)", "Damage (property)", "Assault (others)"],
            "Nouns": ["Recurrent behavioral outbursts", "Impulsive aggression", "Grossly out of proportion reactions", "Verbal aggression", "Physical assault", "Property destruction", "Significant distress/impairment"]
        },
        "Conduct Disorder": {
            "Synonyms": ["Antisocial Behavior (childhood/adolescence)", "Delinquency"],
            "Verbs": ["Violate (rights of others/societal norms)", "Aggress (towards people/animals)", "Destroy (property)", "Deceive", "Steal", "Run away"],
            "Nouns": ["Aggression to people/animals", "Destruction of property", "Deceitfulness or theft", "Serious violations of rules", "Callous-unemotional traits (specifier)", "Repetitive/persistent pattern"]
             # Note: DSM specifies childhood-onset, adolescent-onset, or unspecified onset types
        },
        "Antisocial Personality Disorder": { # Note: Also listed under Personality Disorders
            "Synonyms": ["ASPD", "Sociopathy (colloquial)", "Psychopathy (related construct)"],
            "Verbs": ["Disregard (rights of others)", "Violate (rights of others)", "Deceive", "Manipulate", "Act (impulsively)", "Lack (remorse)"],
            "Nouns": ["Pervasive pattern of disregard for/violation of rights of others", "Deceitfulness", "Impulsivity", "Irritability/aggressiveness", "Irresponsibility", "Lack of remorse", "Conduct disorder history"]
        },
        "Pyromania": {
            "Synonyms": ["Fire Setting (compulsive)"],
            "Verbs": ["Set (fires deliberately/purposefully)", "Experience (tension/affective arousal before act)", "Feel (pleasure/gratification/relief when setting/witnessing fires)"],
            "Nouns": ["Deliberate fire setting", "Tension before act", "Fascination with fire", "Gratification from fire", "Not for monetary gain/ideology"]
        },
        "Kleptomania": {
            "Synonyms": ["Compulsive Stealing"],
            "Verbs": ["Fail to (resist impulses to steal)", "Steal (objects not needed for personal use/monetary value)", "Experience (tension before act)", "Feel (pleasure/gratification/relief during theft)"],
            "Nouns": ["Recurrent failure to resist stealing", "Objects stolen not needed", "Tension before theft", "Pleasure/gratification during theft", "Not to express anger/vengeance"]
        },
        "Other Specified Disruptive, Impulse-Control, and Conduct Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         },
         "Unspecified Disruptive, Impulse-Control, and Conduct Disorder": { # Added placeholder
             "Synonyms": [], "Verbs": [], "Nouns": []
         }
    },

    # 16. Substance-Related and Addictive Disorders
    "Substance-Related and Addictive Disorders": {
         # Substance Use Disorders (SUDs) - Grouped by substance class
         "Alcohol-Related Disorders": {
             "Alcohol Use Disorder": {
                "Synonyms": ["Alcoholism (colloquial)", "Alcohol Dependence", "Problematic Alcohol Use", "Alcohol Abuse"],
                "Verbs": [
                    "Consume (alcohol in larger amounts or over longer period than intended)", "Express (persistent desire or unsuccessful efforts to cut down or control alcohol use)",
                    "Spend (a great deal of time obtaining, using, or recovering from alcohol effects)", "Experience (craving or strong desire/urge to use alcohol)",
                    "Fail (to fulfill major role obligations at work, school, or home due to recurrent use)", "Continue (alcohol use despite persistent social/interpersonal problems caused/exacerbated by alcohol)",
                    "Give up (important social, occupational, or recreational activities because of alcohol use)", "Use (alcohol in situations where it is physically hazardous)",
                    "Continue (alcohol use despite knowledge of having persistent physical/psychological problem likely caused/exacerbated by alcohol)", "Develop (tolerance for alcohol)",
                    "Experience (alcohol withdrawal symptoms or use alcohol to relieve/avoid withdrawal)"
                ],
                "Nouns": [
                    "Alcohol taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control use",
                    "Significant time spent in activities to obtain/use/recover from alcohol", "Craving or strong desire/urge to use alcohol",
                    "Recurrent alcohol use resulting in failure to fulfill major role obligations",
                    "Continued alcohol use despite persistent or recurrent social/interpersonal problems",
                    "Important activities given up or reduced due to alcohol use", "Recurrent alcohol use in physically hazardous situations",
                    "Continued use despite knowledge of persistent physical/psychological problem related to alcohol",
                    "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or alcohol taken to relieve/avoid symptoms)"
                ]
             },
            "Alcohol Intoxication": {
                "Synonyms": ["Drunkenness", "Alcohol Inebriation", "Being Drunk"],
                "Verbs": ["Exhibit (slurred speech after recent alcohol ingestion)", "Show (incoordination following alcohol use)", "Demonstrate (unsteady gait after drinking)", "Have (nystagmus due to alcohol)", "Manifest (impaired attention or memory post-alcohol)", "Become (stuporous or comatose from alcohol)", "Behave (inappropriately or aggressively post-ingestion)"],
                "Nouns": ["Recent ingestion of alcohol", "Clinically significant problematic behavioral or psychological changes (e.g., inappropriate sexual/aggressive behavior, mood lability, impaired judgment)", "Slurred speech", "Incoordination", "Unsteady gait", "Nystagmus", "Impairment in attention or memory", "Stupor or coma"]
            },
            "Alcohol Withdrawal": {
                "Synonyms": ["Alcohol Withdrawal Syndrome", "The Shakes (colloquial)", "Delirium Tremens (severe form, DTs)"],
                "Verbs": ["Experience (autonomic hyperactivity like sweating or tachycardia after cessation/reduction of alcohol)", "Exhibit (increased hand tremor following alcohol cessation/reduction)", "Report (insomnia after stopping/reducing alcohol)", "Suffer (from nausea or vomiting post-alcohol cessation/reduction)", "Have (transient visual, tactile, or auditory hallucinations or illusions)", "Show (psychomotor agitation after alcohol cessation/reduction)", "Feel (anxious after stopping/reducing alcohol)", "Develop (generalized tonic-clonic seizures)"],
                "Nouns": ["Cessation of (or reduction in) alcohol use that has been heavy and prolonged", "Autonomic hyperactivity (e.g., sweating, pulse rate greater than 100 bpm)", "Increased hand tremor", "Insomnia", "Nausea or vomiting", "Transient visual, tactile, or auditory hallucinations or illusions", "Psychomotor agitation", "Anxiety", "Generalized tonic-clonic seizures", "Delirium Tremens (as a severe manifestation)"]
            },
            "Other Alcohol-Induced Disorders": { # Placeholder for induced mental disorders specific to alcohol if needed, often covered under general induced categories below
                "Synonyms": [], "Verbs": [], "Nouns": []
            },
            "Unspecified Alcohol-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
         "Caffeine-Related Disorders": {
             "Caffeine Intoxication": {
                "Synonyms": ["Caffeine Overdose", "Coffee Jitters (severe)"],
                "Verbs": ["Experience (restlessness/nervousness/excitement/insomnia/flushed face/diuresis/gastrointestinal disturbance after recent high caffeine consumption)", "Exhibit (muscle twitching/rambling thought/speech/tachycardia/cardiac arrhythmia/periods of inexhaustibility/psychomotor agitation)"],
                "Nouns": ["Recent consumption of caffeine (typically >250 mg)", "Restlessness", "Nervousness", "Excitement", "Insomnia", "Flushed face", "Diuresis", "Gastrointestinal disturbance", "Muscle twitching", "Rambling flow of thought and speech", "Tachycardia or cardiac arrhythmia", "Periods of inexhaustibility", "Psychomotor agitation"]
            },
            "Caffeine Withdrawal": {
                "Synonyms": ["Caffeine Headache", "Coffee Withdrawal Symptoms"],
                "Verbs": ["Experience (headache after abrupt cessation/reduction of caffeine)", "Report (marked fatigue/drowsiness/dysphoric mood/depressed mood/irritability/difficulty concentrating/flu-like symptoms like nausea/vomiting/muscle pain/stiffness)"],
                "Nouns": ["Prolonged daily use of caffeine with abrupt cessation/reduction", "Headache (characteristic)", "Marked fatigue or drowsiness", "Dysphoric mood, depressed mood, or irritability", "Difficulty concentrating", "Flu-like symptoms (nausea, vomiting, or muscle pain/stiffness)"]
            },
            "Other Caffeine-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Unspecified Caffeine-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
         "Cannabis-Related Disorders": {
             "Cannabis Use Disorder": {
                "Synonyms": ["Marijuana Addiction (colloquial)", "Cannabis Dependence", "Problematic Cannabis Use"],
                "Verbs": [ "Use (cannabis in larger amounts or over longer period than intended)", "Express (persistent desire or unsuccessful efforts to cut down or control cannabis use)", "Spend (a great deal of time obtaining, using, or recovering from cannabis effects)", "Experience (craving or strong desire/urge to use cannabis)", "Fail (to fulfill major role obligations due to recurrent cannabis use)", "Continue (cannabis use despite persistent social/interpersonal problems caused/exacerbated by cannabis)", "Give up (important activities because of cannabis use)", "Use (cannabis in situations where it is physically hazardous)", "Continue (cannabis use despite knowledge of physical/psychological problem related to cannabis)", "Develop (tolerance for cannabis)", "Experience (cannabis withdrawal symptoms, if applicable)" ],
                "Nouns": [ "Cannabis taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control cannabis use", "Significant time spent in activities to obtain/use/recover from cannabis", "Craving or strong desire/urge to use cannabis", "Recurrent cannabis use resulting in failure to fulfill major role obligations", "Continued cannabis use despite persistent or recurrent social/interpersonal problems", "Important activities given up or reduced due to cannabis use", "Recurrent cannabis use in physically hazardous situations", "Continued use despite knowledge of persistent physical/psychological problem related to cannabis", "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome for some users)" ]
            },
            "Cannabis Intoxication": {
                "Synonyms": ["Being High (on marijuana)", "Cannabis Inebriation", "Marijuana Intoxication"],
                "Verbs": ["Exhibit (impaired motor coordination after recent cannabis use)", "Feel (euphoric or anxious post-cannabis use)", "Perceive (time as slowed following cannabis use)", "Show (impaired judgment after cannabis)", "Develop (conjunctival injection from cannabis)", "Experience (increased appetite or dry mouth due to cannabis)", "Have (tachycardia post-cannabis)"],
                "Nouns": ["Recent use of cannabis", "Clinically significant problematic behavioral or psychological changes (e.g., impaired motor coordination, euphoria, anxiety, sensation of slowed time, impaired judgment, social withdrawal)", "Conjunctival injection", "Increased appetite", "Dry mouth", "Tachycardia", "Perceptual disturbances (at high doses)"]
            },
            "Cannabis Withdrawal": {
                "Synonyms": ["Marijuana Withdrawal Syndrome", "Cannabis Abstinence Syndrome"],
                "Verbs": ["Experience (irritability, anger, or aggression after cannabis cessation)", "Feel (nervous or anxious upon stopping cannabis)", "Have (sleep difficulty like insomnia or disturbing dreams)", "Report (decreased appetite or weight loss)", "Exhibit (restlessness after cannabis cessation)", "Become (depressed in mood)", "Suffer (from physical symptoms like abdominal pain, shakiness, sweating, fever, chills, or headache)"],
                "Nouns": ["Cessation of cannabis use that has been heavy and prolonged", "Irritability, anger, or aggression", "Nervousness or anxiety", "Sleep difficulty (e.g., insomnia, disturbing dreams)", "Decreased appetite or weight loss", "Restlessness", "Depressed mood", "Physical symptoms (e.g., abdominal pain, shakiness/tremors, sweating, fever, chills, headache) causing significant discomfort"]
            },
            "Other Cannabis-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Unspecified Cannabis-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
          "Hallucinogen-Related Disorders": {
             "Phencyclidine Use Disorder": {
                "Synonyms": ["PCP Addiction", "Angel Dust Dependence", "Problematic PCP Use"],
                "Verbs": ["Use (phencyclidine repeatedly leading to impairment/distress)", "Develop (tolerance to effects of PCP)", "Experience (craving for PCP)", "Continue (PCP use despite negative consequences)"],
                "Nouns": ["Problematic pattern of phencyclidine use", "Impaired control over PCP use", "Craving for PCP", "Tolerance to PCP effects", "Use resulting in failure to fulfill major roles", "Continued use despite social/physical problems"]
             },
             "Other Hallucinogen Use Disorder": {
                "Synonyms": ["LSD Addiction (colloquial, dependence is more accurate)", "Psychedelic Dependence", "Problematic Hallucinogen Use (non-PCP)"],
                "Verbs": ["Use (hallucinogen other than PCP repeatedly leading to impairment/distress)", "Develop (tolerance to effects, for some hallucinogens)", "Experience (craving, for some hallucinogens)", "Continue (hallucinogen use despite negative psychological/social consequences)"],
                "Nouns": ["Problematic pattern of use of a hallucinogen (other than phencyclidine)", "Impaired control over hallucinogen use", "Craving (for some hallucinogens like MDMA)", "Tolerance (rapid for some, e.g., LSD)", "Continued use despite psychological problems (e.g., anxiety, flashbacks)"]
             },
             "Phencyclidine Intoxication": {
                "Synonyms": ["PCP Intoxication", "Angel Dust High"],
                "Verbs": ["Exhibit (vertical/horizontal nystagmus after recent PCP use)", "Show (hypertension/tachycardia, numbness/diminished pain response, ataxia, dysarthria)", "Manifest (muscle rigidity, seizures/coma, hyperacusis)"],
                "Nouns": ["Recent use of phencyclidine (or a related substance)", "Clinically significant problematic behavioral changes (e.g., belligerence, assaultiveness, impulsiveness, unpredictability, psychomotor agitation, impaired judgment)", "Vertical or horizontal nystagmus", "Hypertension or tachycardia", "Numbness or diminished responsiveness to pain", "Ataxia", "Dysarthria", "Muscle rigidity", "Seizures or coma", "Hyperacusis"]
             },
             "Other Hallucinogen Intoxication": {
                "Synonyms": ["LSD Trip", "Psychedelic Intoxication", "Shroom High", "Ecstasy Intoxication (MDMA)"],
                "Verbs": ["Experience (perceptual changes like illusions/hallucinations/synesthesias after recent use)", "Exhibit (pupillary dilation, tachycardia, sweating, palpitations, blurred vision, tremors, incoordination)"],
                "Nouns": ["Recent use of a hallucinogen (other than phencyclidine)", "Clinically significant problematic behavioral or psychological changes (e.g., marked anxiety/depression, ideas of reference, fear of losing one’s mind, paranoid ideation, impaired judgment)", "Perceptual changes (e.g., subjective intensification of perceptions, depersonalization, derealization, illusions, hallucinations, synesthesias)", "Pupillary dilation", "Tachycardia", "Sweating", "Palpitations", "Blurred vision", "Tremors", "Incoordination"]
             },
             "Hallucinogen Persisting Perception Disorder (HPPD)": {
                "Synonyms": ["Flashbacks (hallucinogen-induced)", "Persistent Visual Disturbances after Hallucinogen Use"],
                "Verbs": ["Re-experience (perceptual symptoms experienced during hallucinogen intoxication after cessation of use)", "Report (geometric forms, peripheral field flashes, intensified colors, trails of images, halos, macropsia, micropsia)"],
                "Nouns": ["Re-experiencing of perceptual symptoms (following cessation of hallucinogen use)", "Visual disturbances (geometric hallucinations, flashes of color, intensified colors, trails of images of moving objects, positive afterimages, halos around objects, macropsia, micropsia)", "Symptoms cause clinically significant distress or impairment", "Not attributable to another medical/mental condition"]
            },
            "Other Phencyclidine-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Other Hallucinogen-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Unspecified Phencyclidine-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            },
            "Unspecified Hallucinogen-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
         "Inhalant-Related Disorders": {
             "Inhalant Use Disorder": {
                "Synonyms": ["Huffing Addiction", "Solvent Abuse Dependence", "Problematic Inhalant Use"],
                "Verbs": ["Use (inhalants repeatedly leading to impairment/distress)", "Develop (tolerance to effects of inhalants)", "Experience (craving for inhalants)", "Continue (inhalant use despite negative health/social consequences)", "Spend (significant time obtaining/using/recovering from inhalants)"],
                "Nouns": ["Problematic pattern of use of a volatile hydrocarbon substance (inhalant)", "Impaired control over inhalant use", "Craving for inhalants", "Tolerance to inhalant effects", "Use resulting in failure to fulfill major roles", "Continued use despite social/physical problems (e.g., neurological damage, liver/kidney damage)", "Use in hazardous situations"]
            },
            "Inhalant Intoxication": {
                "Synonyms": ["Huffing High", "Solvent Intoxication", "Glue Sniffing Effects"],
                "Verbs": ["Exhibit (dizziness/nystagmus/incoordination/slurred speech/unsteady gait/lethargy after recent inhalant exposure)", "Show (depressed reflexes/psychomotor retardation/tremor/generalized muscle weakness/blurred vision/diplopia/stupor/coma/euphoria)"],
                "Nouns": ["Recent intentional exposure to inhalant substances (volatile hydrocarbons)", "Clinically significant problematic behavioral or psychological changes (e.g., belligerence, assaultiveness, apathy, impaired judgment)", "Dizziness", "Nystagmus", "Incoordination", "Slurred speech", "Unsteady gait", "Lethargy", "Depressed reflexes", "Psychomotor retardation", "Tremor", "Generalized muscle weakness", "Blurred vision or diplopia", "Stupor or coma", "Euphoria"]
            },
            "Other Inhalant-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Unspecified Inhalant-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
         "Opioid-Related Disorders": {
             "Opioid Use Disorder": {
                "Synonyms": ["Opioid Addiction", "Heroin Addiction", "Painkiller Addiction", "Narcotic Dependence"],
                "Verbs": [ "Take (opioids in larger amounts or over longer period than intended)", "Express (persistent desire or unsuccessful efforts to cut down or control opioid use)", "Spend (a great deal of time obtaining, using, or recovering from opioid effects)", "Experience (craving or strong desire/urge to use opioids)", "Fail (to fulfill major role obligations due to recurrent opioid use)", "Continue (opioid use despite persistent social/interpersonal problems caused/exacerbated by opioids)", "Give up (important activities because of opioid use)", "Use (opioids in situations where it is physically hazardous)", "Continue (opioid use despite knowledge of physical/psychological problem related to opioids)", "Develop (tolerance for opioids)", "Experience (opioid withdrawal symptoms or use opioids to relieve/avoid withdrawal)" ],
                "Nouns": [ "Opioids taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control opioid use", "Significant time spent in activities to obtain/use/recover from opioids", "Craving or strong desire/urge to use opioids", "Recurrent opioid use resulting in failure to fulfill major role obligations", "Continued opioid use despite persistent or recurrent social/interpersonal problems", "Important activities given up or reduced due to opioid use", "Recurrent opioid use in physically hazardous situations", "Continued use despite knowledge of persistent physical/psychological problem related to opioids", "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or opioids taken to relieve/avoid symptoms)" ]
            },
            "Opioid Intoxication": {
                "Synonyms": ["Narcotic Intoxication", "Opioid Overdose (can lead to coma/death)", "Being High (on opioids)"],
                "Verbs": ["Exhibit (pupillary constriction or dilation in severe anoxia after recent opioid use)", "Become (drowsy or comatose post-opioid use)", "Show (slurred speech following opioid use)", "Manifest (impaired attention or memory due to opioids)"],
                "Nouns": ["Recent use of an opioid", "Clinically significant problematic behavioral or psychological changes (e.g., initial euphoria followed by apathy, dysphoria, psychomotor agitation or retardation, impaired judgment)", "Pupillary constriction (or dilation due to anoxia from severe overdose)", "Drowsiness or coma", "Slurred speech", "Impairment in attention or memory", "Respiratory depression (clinically significant)"]
            },
            "Opioid Withdrawal": {
                "Synonyms": ["Dopesickness (colloquial)", "Opioid Abstinence Syndrome", "Kicking (colloquial)"],
                "Verbs": ["Experience (dysphoric mood after opioid cessation/reduction)", "Suffer (from nausea or vomiting)", "Have (muscle aches or lacrimation or rhinorrhea)", "Exhibit (pupillary dilation, piloerection, or sweating)", "Report (diarrhea, yawning, fever, or insomnia)"],
                "Nouns": ["Cessation of (or reduction in) opioid use that has been heavy and prolonged (or administration of an opioid antagonist)", "Dysphoric mood", "Nausea or vomiting", "Muscle aches", "Lacrimation or rhinorrhea", "Pupillary dilation, piloerection, or sweating", "Diarrhea", "Yawning", "Fever", "Insomnia"]
            },
            "Other Opioid-Induced Disorders": { # Placeholder
                 "Synonyms": [], "Verbs": [], "Nouns": []
             },
            "Unspecified Opioid-Related Disorder": { # Added placeholder
                "Synonyms": [], "Verbs": [], "Nouns": []
            }
         },
         "Sedative-, Hypnotic-, or Anxiolytic-Related Disorders": {
             "Sedative, Hypnotic, or Anxiolytic Use Disorder": {
                "Synonyms": ["Benzodiazepine Addiction", "Barbiturate Addiction", "Sleeping Pill Addiction", "Anti-Anxiety Medication Dependence"],
                "Verbs": ["Use (sedatives/hypnotics/anxiolytics in larger amounts or over longer period than intended)", "Express (persistent desire or unsuccessful efforts to cut down or control use)", "Spend (a great deal of time obtaining, using, or recovering from effects)", "Experience (craving or strong desire/urge to use)", "Fail (to fulfill major role obligations due to recurrent use)", "Continue (use despite persistent social/interpersonal problems caused/exacerbated by effects)", "Give up (important social, occupational, or recreational activities because of use)", "Use (in situations where it is physically hazardous)", "Continue (use despite knowledge of having persistent physical/psychological problem likely caused/exacerbated by the substance)", "Develop (tolerance)", "Experience (withdrawal symptoms or use substance to relieve/avoid withdrawal)"],
                "Nouns": ["Problematic pattern of sedative, hypnotic, or anxiolytic use leading to clinically significant impairment or distress", "Substance taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control use", "Significant time spent in activities to obtain/use/recover", "Craving or strong desire/urge to use", "Recurrent use resulting in failure to fulfill major role obligations", "Continued use despite persistent or recurrent social/interpersonal problems", "Important activities given up or reduced due to use", "Recurrent use in physically hazardous situations", "Continued use despite knowledge of persistent physical/psychological problem related to the substance", "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or substance taken to relieve/avoid symptoms)"]
            },
            "Sedative, Hypnotic, or Anxiolytic Intoxication": {
                "Synonyms": ["Tranquilizer Overdose Effects", "Sleeping Pill Intoxication", "Benzo Intoxication"],
                "Verbs": ["Exhibit (slurred speech after recent use)", "Show (incoordination or unsteady gait)", "Manifest (nystagmus or impaired cognition like attention/memory)", "Become (stuporous or comatose)"],
                "Nouns": ["Recent use of a sedative, hypnotic, or anxiolytic", "Clinically significant maladaptive behavioral or psychological changes (e.g., inappropriate sexual/aggressive behavior, mood lability, impaired judgment)", "Slurred speech", "Incoordination", "Unsteady gait", "Nystagmus", "Impairment in cognition (e.g., attention, memory)", "Stupor or coma", "Respiratory depression (in severe cases)"]
            },
            "Sedative, Hypnotic, or Anxiolytic Withdrawal": {
                "Synonyms": ["Benzo Withdrawal", "Barbiturate Withdrawal", "Sleeping Pill Withdrawal Symptoms"],
                "Verbs": ["Experience (autonomic hyperactivity like sweating or tachycardia after cessation/reduction)", "Have (hand tremor, insomnia, nausea, or vomiting)", "Report (transient visual, tactile, or auditory hallucinations/illusions)", "Exhibit (psychomotor agitation or anxiety)", "Develop (generalized tonic-clonic seizures)"],
                "Nouns": ["Cessation of (or reduction in) use that has been heavy and prolonged", "Autonomic hyperactivity (e.g., sweating, pulse rate >100 bpm)", "Hand tremor", "Insomnia", "Nausea or vomiting", "Transient visual, tactile, or auditory hallucinations or illusions", "Psychomotor agitation", "Anxiety", "Grand mal seizures"]

# %%
scid_dataset = {
    "Neurodevelopmental Disorders": {  # Factor
        "Intellectual Disability (Intellectual Developmental Disorder)": {  # Adjective
            "Synonyms": ["Cognitive Impairment", "Mental Retardation", "Developmental Delay"],
            "Verbs": ["Exhibit", "Demonstrate", "Experience", "Show", "Struggle with"],
            "Nouns": ["Deficits", "Limitations", "Impairment", "Challenges", "Difficulties"]
        },
        "Global Developmental Delay": {  # Adjective
            "Synonyms": ["Developmental Delay", "Delayed Development", "Developmental Disabilities"],
            "Verbs": ["Demonstrate", "Show", "Exhibit", "Struggle with", "Experience"],
            "Nouns": ["Delays", "Limitations", "Impairment", "Difficulties", "Challenges"]
        },
        "Unspecified Intellectual Disability": {  # Adjective
            "Synonyms": ["Cognitive Impairment", "Developmental Delay", "Unspecified Delay"],
            "Verbs": ["Show", "Exhibit", "Struggle with", "Experience", "Demonstrate"],
            "Nouns": ["Impairment", "Delay", "Limitation", "Challenge", "Difficulty"]
        },
        "Language Disorder": {  # Adjective
            "Synonyms": ["Language Impairment", "Communication Disorder", "Language Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Experience", "Have"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Speech Sound Disorder": {  # Adjective
            "Synonyms": ["Articulation Disorder", "Phonological Disorder", "Speech Impairment"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Errors", "Limitations", "Challenges"]
        },
        "Childhood-Onset Fluency Disorder (Stuttering)": {  # Adjective
            "Synonyms": ["Stuttering", "Fluency Disorder", "Speech Hesitation"],
            "Verbs": ["Stutter", "Hesiate", "Repeat", "Prolong", "Block"],
            "Nouns": ["Stutter", "Hesitation", "Repetition", "Prolongation", "Block"]
        },
        "Social Communication Disorder": {  # Adjective
            "Synonyms": ["Pragmatic Communication Disorder", "Social Language Deficit", "Communication Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Deficits", "Impairment", "Limitations", "Challenges"]
        },
        "Other Specified Attention-Deficit/Hyperactivity Disorder": {  # Adjective
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Unspecified Attention-Deficit/Hyperactivity Disorder": {  # Adjective
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Specific Learning Disorder": {  # Adjective
            "Synonyms": ["Learning Disability", "Reading Disorder", "Dyslexia", "Mathematics Disorder", "Dyscalculia", "Disorder of Written Expression"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Impairment", "Deficit", "Limitation", "Challenge"]
        },
        "Developmental Coordination Disorder": {  # Adjective
            "Synonyms": ["Dyspraxia", "Motor Coordination Disorder", "Clumsiness"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Stereotypic Movement Disorder": {  # Adjective
            "Synonyms": ["Repetitive Movement Disorder", "Stereotypies", "Motor Stereotypies"],
            "Verbs": ["Exhibit", "Show", "Engage in", "Perform", "Demonstrate"],
            "Nouns": ["Movements", "Behaviors", "Stereotypies", "Repetitions", "Mannerisms"]
        },
        "Tourette's Disorder": {  # Adjective
            "Synonyms": ["Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Persistent (Chronic) Motor or Vocal Tic Disorder": {  # Adjective
            "Synonyms": ["Chronic Tic Disorder", "Persistent Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Provisional Tic Disorder": {  # Adjective
            "Synonyms": ["Tic Disorder", "Transient Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Other Specified Tic Disorder": {  # Adjective
            "Synonyms": ["Tic Disorder", "Atypical Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Unspecified Tic Disorder": {  # Adjective
            "Synonyms": ["Tic Disorder", "Unspecified Tics", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        }
    },
    "Schizophrenia Spectrum and Other Psychotic Disorders": {  # Factor
        "Schizotypal (Personality) Disorder": {  # Adjective
            "Synonyms": ["Eccentric Personality", "Odd Personality", "Schizotypy"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Eccentricity", "Oddity", "Peculiarity", "Distortions", "Deficits"]
        },
        "Delusional Disorder": {  # Adjective
            "Synonyms": ["Delusions", "Fixed Beliefs", "False Beliefs"],
            "Verbs": ["Experience", "Have", "Hold", "Believe", "Exhibit"],
            "Nouns": ["Delusions", "Beliefs", "Ideas", "Paranoia", "Suspicion"]
        },
        "Brief Psychotic Disorder": {  # Adjective
            "Synonyms": ["Brief Psychosis", "Psychotic Episode", "Transient Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophreniform Disorder": {  # Adjective
            "Synonyms": ["Schizophrenia-like Psychosis", "Short-term Schizophrenia", "Psychotic Episode"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophrenia": {  # Adjective
            "Synonyms": ["Psychosis", "Schizophrenia Spectrum Disorder", "Thought Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Delusions", "Hallucinations", "Disorganized Thinking", "Negative Symptoms", "Psychotic Symptoms"]
        },
        "Schizoaffective Disorder": {  # Adjective
            "Synonyms": ["Schizophrenia and Mood Disorder", "Psychotic and Affective Symptoms", "Mixed Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Mood Episodes", "Symptoms", "Delusions", "Hallucinations"]
        },
        "Other Specified Schizophrenia Spectrum and Other Psychotic Disorder": {  # Adjective
            "Synonyms": ["Atypical Psychosis", "Subthreshold Psychosis", "Unspecified Psychotic Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        },
        "Unspecified Schizophrenia Spectrum and Other Psychotic Disorder": {  # Adjective
            "Synonyms": ["Unspecified Psychosis", "Psychotic Symptoms", "Undifferentiated Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        }
    },
    "Bipolar and Related Disorders": {  # Factor
        "Bipolar I Disorder": {  # Adjective
            "Synonyms": ["Bipolar Disorder", "Mania", "Manic-Depressive Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Bipolar II Disorder": {  # Adjective
            "Synonyms": ["Bipolar Disorder", "Hypomania", "Recurrent Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Hypomania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Cyclothymic Disorder": {  # Adjective
            "Synonyms": ["Cyclothymia", "Mood Instability", "Mild Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Swings", "Hypomanic Symptoms", "Depressive Symptoms", "Mood Instability", "Symptoms"]
        },
        "Substance/Medication-Induced Bipolar and Related Disorder": {  # Adjective
            "Synonyms": ["Substance-Induced Mood Disorder", "Medication-Induced Mood Disorder", "Secondary Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Bipolar and Related Disorder Due to Another Medical Condition": {  # Adjective
            "Synonyms": ["Secondary Bipolar Disorder", "Medical Condition-Induced Mood Disorder", "Mood Disorder Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Other Specified Bipolar and Related Disorder": {  # Adjective
            "Synonyms": ["Atypical Bipolar Disorder", "Subthreshold Bipolar Disorder", "Unspecified Mood Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Unspecified Bipolar and Related Disorder": {  # Adjective
            "Synonyms": ["Unspecified Mood Disorder", "Bipolar Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        }
    },
    "Depressive Disorders": {  # Factor
        "Disruptive Mood Dysregulation Disorder": {  # Adjective
            "Synonyms": ["DMDD", "Childhood Mood Disorder", "Temper Dysregulation"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Temper Outbursts", "Irritability", "Mood Dysregulation", "Emotional Lability", "Symptoms"]
        },
        "Major Depressive Disorder": {  # Adjective
            "Synonyms": ["MDD", "Clinical Depression", "Unipolar Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Sleep Disturbance", "Appetite Changes", "Fatigue", "Worthlessness", "Suicidal Ideation", "Symptoms"]
        },
        "Persistent Depressive Disorder (Dysthymia)": {  # Adjective
            "Synonyms": ["Dysthymia", "Chronic Depression", "Persistent Low Mood"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Low Self-Esteem", "Fatigue", "Hopelessness", "Symptoms"]
        },
        "Premenstrual Dysphoric Disorder (PMDD)": {  # Adjective
            "Synonyms": ["PMDD", "Premenstrual Mood Disorder", "Severe PMS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Lability", "Irritability", "Depressed Mood", "Anxiety", "Symptoms"]
        },
        "Substance/Medication-Induced Depressive Disorder": {  # Adjective
            "Synonyms": ["Substance-Induced Depression", "Medication-Induced Depression", "Secondary Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Depressive Disorder Due to Another Medical Condition": {  # Adjective
            "Synonyms": ["Secondary Depression", "Medical Condition-Induced Depression", "Depression Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Other Specified Depressive Disorder": {  # Adjective
            "Synonyms": ["Atypical Depression", "Subthreshold Depression", "Unspecified Depressive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Unspecified Depressive Disorder": {  # Adjective
            "Synonyms": ["Unspecified Depression", "Depressive Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        }
    },
    "Anxiety Disorders": {  # Factor
        "Separation Anxiety Disorder": {  # Adjective
            "Synonyms": ["Separation Anxiety", "Anxiety About Separation", "Fear of Separation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Distress", "Worry", "Symptoms"]
        },
        "Selective Mutism": {  # Adjective
            "Synonyms": ["Situational Mutism", "Selective Non-Speaking", "Social Mutism"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Mutism", "Non-Speaking", "Silence", "Anxiety", "Fear"]
        },
        "Specific Phobia": {  # Adjective
            "Synonyms": ["Phobia", "Fear", "Anxiety Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Fear", "Anxiety", "Avoidance", "Distress", "Symptoms"]
        },
        "Social Anxiety Disorder (Social Phobia)": {  # Adjective
            "Synonyms": ["Social Phobia", "Social Anxiety", "Fear of Social Situations"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Distress", "Symptoms"]
        },
        "Panic Disorder": {  # Adjective
            "Synonyms": ["Panic Attacks", "Anxiety Disorder", "Panic"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Panic Attacks", "Anxiety", "Fear", "Distress", "Symptoms"]
        },
        "Agoraphobia": {  # Adjective
            "Synonyms": ["Fear of Open Spaces", "Anxiety Disorder", "Avoidance of Public Places"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Distress", "Symptoms"]
        },
        "Generalized Anxiety Disorder (GAD)": {  # Adjective
            "Synonyms": ["GAD", "Excessive Worry", "Chronic Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Apprehension"]
        },
        "Substance/Medication-Induced Anxiety Disorder": {  # Adjective
            "Synonyms": ["Substance-Induced Anxiety", "Medication-Induced Anxiety", "Secondary Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Mood Changes", "Agitation"]
        },
        "Anxiety Disorder Due to Another Medical Condition": {  # Adjective
            "Synonyms": ["Secondary Anxiety", "Medical Condition-Induced Anxiety", "Anxiety Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Mood Changes", "Apprehension"]
        },
        "Other Specified Anxiety Disorder": {  # Adjective
            "Synonyms": ["Atypical Anxiety", "Subthreshold Anxiety", "Unspecified Anxiety Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Worry", "Apprehension"]
        },
        "Unspecified Anxiety Disorder": {  # Adjective
            "Synonyms": ["Unspecified Anxiety", "Anxiety Symptoms", "Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Symptoms", "Distress", "Worry", "Apprehension"]
        }
    },
    "Obsessive-Compulsive and Related Disorders": {  # Factor
        "Obsessive-Compulsive Disorder (OCD)": {  # Adjective
            "Synonyms": ["OCD", "Obsessions and Compulsions", "Obsessive Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Rituals"]
        },
        "Body Dysmorphic Disorder": {  # Adjective
            "Synonyms": ["BDD", "Body Image Disorder", "Dysmorphophobia"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Preoccupation", "Distress", "Concern", "Flaws", "Defects"]
        },
        "Hoarding Disorder": {  # Adjective
            "Synonyms": ["Compulsive Hoarding", "Hoarding", "Collecting Disorder"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Manifest"],
            "Nouns": ["Clutter", "Accumulation", "Difficulty Discarding", "Distress", "Possessions"]
        },
        "Trichotillomania (Hair-Pulling Disorder)": {  # Adjective
            "Synonyms": ["Hair-Pulling Disorder", "Trichotillomania", "Hair Pulling"],
            "Verbs": ["Pull", "Experience", "Have", "Show", "Exhibit"],
            "Nouns": ["Hair Pulling", "Urges", "Behaviors", "Distress", "Hair Loss"]
        },
        "Excoriation (Skin-Picking) Disorder": {  # Adjective
            "Synonyms": ["Skin-Picking Disorder", "Excoriation", "Dermatillomania"],
            "Verbs": ["Pick", "Experience", "Have", "Show", "Exhibit"],
            "Nouns": ["Skin Picking", "Urges", "Behaviors", "Distress", "Lesions"]
        },
        "Substance/Medication-Induced Obsessive-Compulsive and Related Disorder": {  # Adjective
            "Synonyms": ["Substance-Induced OCD", "Medication-Induced OCD", "Secondary OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Obsessive-Compulsive and Related Disorder Due to Another Medical Condition": {  # Adjective
            "Synonyms": ["Medical Condition-Induced OCD", "Secondary OCD", "OCD Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Other Specified Obsessive-Compulsive and Related Disorder": {  # Adjective
            "Synonyms": ["Atypical OCD", "Subthreshold OCD", "Unspecified OCD Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        },
        "Unspecified Obsessive-Compulsive and Related Disorder": {  # Adjective
            "Synonyms": ["Unspecified OCD", "OCD Symptoms", "Obsessive-Compulsive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Symptoms"]
        }
    },
    "Trauma- and Stressor-Related Disorders": {  # Factor
        "Posttraumatic Stress Disorder (PTSD)": {  # Adjective
            "Synonyms": ["PTSD", "Trauma Disorder", "Stress Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Memories", "Avoidance", "Hyperarousal", "Negative Mood", "Symptoms"]
        },
        "Acute Stress Disorder": {  # Adjective
            "Synonyms": ["ASD", "Acute Stress Reaction", "Trauma Response"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Symptoms", "Dissociation", "Avoidance", "Arousal Symptoms", "Symptoms"]
        },
        "Adjustment Disorders": {  # Adjective
            "Synonyms": ["Adjustment Disorder", "Stress Response Syndrome", "Situational Distress"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Emotional Symptoms", "Behavioral Symptoms", "Distress", "Impairment", "Reactions"]
        },
        "Other Specified Trauma- and Stressor-Related Disorder": {  # Adjective
            "Synonyms": ["Atypical Trauma Disorder", "Subthreshold Stress Disorder", "Unspecified Trauma Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Trauma Response", "Stress Symptoms", "Reactions"]
        },
        "Unspecified Trauma- and Stressor-Related Disorder": {  # Adjective
            "Synonyms": ["Unspecified Trauma Disorder", "Trauma Symptoms", "Stress Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Trauma Response", "Stress Symptoms", "Reactions"]
        }
    },
    "Dissociative Disorders": {  # Factor
        "Dissociative Identity Disorder": {  # Adjective
            "Synonyms": ["DID", "Multiple Personality Disorder", "Identity Fragmentation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Multiple Identities", "Memory Gaps", "Amnesia", "Dissociation", "Alters"]
        },
        "Dissociative Amnesia": {  # Adjective
            "Synonyms": ["Dissociative Amnesia", "Amnesia", "Memory Loss"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Memory Gaps", "Amnesia", "Forgetfulness", "Identity Loss", "Fugue"]
        },
        "Depersonalization/Derealization Disorder": {  # Adjective
            "Synonyms": ["Depersonalization Disorder", "Derealization Disorder", "Detachment Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depersonalization", "Derealization", "Detachment", "Unreality", "Dissociation"]
        },
        "Other Specified Dissociative Disorder": {  # Adjective
            "Synonyms": ["Atypical Dissociation", "Subthreshold Dissociation", "Unspecified Dissociative Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        },
        "Unspecified Dissociative Disorder": {  # Adjective
            "Synonyms": ["Unspecified Dissociation", "Dissociative Symptoms", "Dissociation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        }
    },
    "Somatic Symptom and Related Disorders": {  # Factor
        "Somatic Symptom Disorder": {  # Adjective
            "Synonyms": ["Somatization Disorder", "Somatic Symptoms", "Physical Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        },
        "Illness Anxiety Disorder": {  # Adjective
            "Synonyms": ["Hypochondriasis", "Health Anxiety", "Illness Worry"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Fear", "Illness Concern", "Symptoms"]
        },
        "Conversion Disorder (Functional Neurological Symptom Disorder)": {  # Adjective
            "Synonyms": ["Functional Neurological Disorder", "Conversion Disorder", "Psychogenic Symptoms"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Manifest"],
            "Nouns": ["Neurological Symptoms", "Motor Symptoms", "Sensory Symptoms", "Weakness", "Paralysis"]
        },
        "Psychological Factors Affecting Other Medical Conditions": {  # Adjective
            "Synonyms": ["Psychological Factors Affecting Medical Conditions", "Mind-Body Interaction", "Stress-Related Illness"],
            "Verbs": ["Affect", "Influence", "Exacerbate", "Contribute to", "Impact"],
            "Nouns": ["Psychological Factors", "Stress", "Emotions", "Behaviors", "Medical Conditions"]
        },
        "Other Specified Somatic Symptom and Related Disorder": {  # Adjective
            "Synonyms": ["Atypical Somatic Symptom Disorder", "Subthreshold Somatic Symptom Disorder", "Unspecified Somatic Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        },
        "Unspecified Somatic Symptom and Related Disorder": {  # Adjective
            "Synonyms": ["Unspecified Somatic Symptoms", "Somatic Symptoms", "Physical Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        }
    },
    "Feeding and Eating Disorders": {  # Factor
        "Pica": {  # Adjective
            "Synonyms": ["Unusual Eating Habits", "Non-Food Consumption", "Abnormal Appetite"],
            "Verbs": ["Eat", "Consume", "Ingest", "Crave", "Desire"],
            "Nouns": ["Non-Nutritive Substances", "Non-Food Items", "Unusual Substances", "Cravings", "Consumption"]
        },
        "Rumination Disorder": {  # Adjective
            "Synonyms": ["Regurgitation Disorder", "Repeated Regurgitation", "Spitting Up"],
            "Verbs": ["Regurgitate", "Bring Up", "Re-Chew", "Re-Swallow", "Expel"],
            "Nouns": ["Regurgitation", "Vomit", "Food", "Stomach Contents", "Behavior"]
        },
        "Avoidant/Restrictive Food Intake Disorder": {  # Adjective
            "Synonyms": ["ARFID", "Selective Eating Disorder", "Food Avoidance"],
            "Verbs": ["Avoid", "Restrict", "Limit", "Refuse", "Fear"],
            "Nouns": ["Food", "Intake", "Eating", "Avoidance", "Restriction"]
        },
        "Anorexia Nervosa": {  # Adjective
            "Synonyms": ["Anorexia", "Restrictive Eating", "Fear of Weight Gain"],
            "Verbs": ["Restrict", "Fear", "Avoid", "Lose Weight", "Control"],
            "Nouns": ["Weight", "Body Image", "Food", "Eating", "Restriction"]
        },
        "Bulimia Nervosa": {  # Adjective
            "Synonyms": ["Bulimia", "Binge Eating", "Purging Disorder"],
            "Verbs": ["Binge", "Purge", "Eat", "Compensate", "Control"],
            "Nouns": ["Binge Eating", "Purging", "Weight", "Food", "Body Shape"]
        },
        "Binge-Eating Disorder": {  # Adjective
            "Synonyms": ["Binge Eating", "Compulsive Overeating", "Emotional Eating"],
            "Verbs": ["Binge", "Overeat", "Consume", "Feel", "Experience"],
            "Nouns": ["Binge Eating", "Food", "Weight", "Control", "Distress"]
        },
        "Other Specified Feeding or Eating Disorder": {  # Adjective
            "Synonyms": ["Atypical Eating Disorder", "Subthreshold Eating Disorder", "Unspecified Eating Symptoms"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Worry"],
            "Nouns": ["Eating", "Food", "Weight", "Body Image", "Symptoms"]
        },
        "Unspecified Feeding or Eating Disorder": {  # Adjective
            "Synonyms": ["Unspecified Eating Disorder", "Eating Symptoms", "Disordered Eating"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Worry"],
            "Nouns": ["Eating", "Food", "Weight", "Body Image", "Symptoms"]
        }
    },
    "Elimination Disorders": {  # Factor
        "Enuresis": {  # Adjective
            "Synonyms": ["Bedwetting", "Urinary Incontinence", "Nocturnal Enuresis"],
            "Verbs": ["Wet", "Urinate", "Void", "Leak", "Experience"],
            "Nouns": ["Urine", "Bedwetting", "Incontinence", "Urination", "Accidents"]
        },
        "Encopresis": {  # Adjective
            "Synonyms": ["Fecal Incontinence", "Soiling", "Bowel Incontinence"],
            "Verbs": ["Defecate", "Soil", "Pass", "Leak", "Experience"],
            "Nouns": ["Feces", "Incontinence", "Soiling", "Bowel Movements", "Accidents"]
        }
    },
    "Sleep-Wake Disorders": {  # Factor (DSM-5-TR Chapter 12)
        "Insomnia Disorder": {  # Adjective (DisorderName)
            "Synonyms": ["Insomnia", "Sleeplessness", "Difficulty Initiating/Maintaining Sleep", "Nonrestorative Sleep"],
            "Verbs": ["Struggle to sleep", "Have trouble sleeping", "Wake up (frequently/early)", "Experience (difficulty falling/staying asleep)", "Suffer from (poor sleep quality)", "Report (daytime fatigue)"],
            "Nouns": ["Difficulty initiating sleep", "Difficulty maintaining sleep", "Early-morning awakening", "Nonrestorative sleep", "Daytime fatigue", "Impaired functioning", "Sleep dissatisfaction", "Irritability", "Cognitive impairment (due to sleep loss)"]
        },
        "Hypersomnolence Disorder": {  # Adjective (DisorderName)
            "Synonyms": ["Excessive Sleepiness", "Hypersomnia", "Prolonged Sleep", "Daytime Drowsiness"],
            "Verbs": ["Feel excessively sleepy", "Sleep excessively (prolonged nocturnal/daytime)", "Nap frequently (unrefreshing)", "Struggle to stay awake", "Experience (sleep inertia/drunkenness)", "Report (nonrestorative sleep despite long duration)"],
            "Nouns": ["Excessive sleepiness", "Prolonged nocturnal sleep", "Sleep inertia (sleep drunkenness)", "Nonrestorative sleep", "Unintentional daytime naps", "Impaired alertness", "Automatic behavior", "Difficulty waking up"]
        },
        "Narcolepsy": { # Adjective (DisorderName)
            "Synonyms": ["Excessive Daytime Sleepiness with Cataplexy", "Sleep Attacks", "Hypnagogic Hallucinations"],
            "Verbs": ["Experience (recurrent irresistible sleep/lapses into sleep)", "Have (cataplexy)", "Exhibit (hypocretin deficiency)", "Report (hypnagogic/hypnopompic hallucinations)", "Suffer (sleep paralysis)"],
            "Nouns": ["Irrepressible need to sleep", "Sleep attacks", "Cataplexy", "Hypocretin deficiency (in CSF)", "REM sleep latency reduction", "Hypnagogic hallucinations", "Hypnopompic hallucinations", "Sleep paralysis", "Fragmented nighttime sleep"]
        },
        "Obstructive Sleep Apnea Hypopnea": { # Adjective (DisorderName)
            "Synonyms": ["OSA", "Sleep Apnea", "Breathing-Related Sleep Disorder"],
            "Verbs": ["Experience (apneas/hypopneas)", "Snore (loudly)", "Gasp (for air during sleep)", "Report (daytime sleepiness/fatigue)", "Have (witnessed apneas)"],
            "Nouns": ["Apneas", "Hypopneas", "Snoring", "Gasping/choking (during sleep)", "Nocturnal breathing disturbances", "Daytime sleepiness", "Fatigue", "Unrefreshing sleep", "Morning headaches", "Impaired concentration"]
        },
        "Central Sleep Apnea": { # Adjective (DisorderName)
            "Synonyms": ["CSA", "Cessation of Airflow without Obstruction", "Breathing-Related Sleep Disorder"],
            "Verbs": ["Experience (apneas without respiratory effort)", "Report (insomnia/daytime sleepiness)", "Exhibit (Cheyne-Stokes breathing - specific type)"],
            "Nouns": ["Recurrent apneas (central origin)", "Absence of respiratory effort (during apnea)", "Daytime sleepiness", "Insomnia complaints", "Fragmented sleep", "Cheyne-Stokes breathing pattern (for idiopathic CSA or CSA with specific comorbidities)"]
        },
        "Sleep-Related Hypoventilation": { # Adjective (DisorderName)
            "Synonyms": ["Nocturnal Hypoventilation", "Breathing-Related Sleep Disorder"],
            "Verbs": ["Exhibit (decreased respiration with elevated CO2)", "Report (daytime sleepiness/insomnia/headaches)", "Experience (shallow breathing during sleep)"],
            "Nouns": ["Decreased respiration", "Elevated CO2 levels (hypercapnia)", "Shallow breathing (during sleep)", "Daytime sleepiness", "Morning headaches", "Insomnia", "Fatigue", "Cardiopulmonary complications (potential)"]
        },
        "Delayed Sleep Phase Type (Circadian Rhythm Sleep-Wake Disorder)": { # Adjective (DisorderName)
            "Synonyms": ["Delayed Sleep Onset", "Night Owl Chronotype (extreme)", "Circadian Rhythm Disorder"],
            "Verbs": ["Delay (sleep onset/wake times significantly)", "Struggle (waking at desired times)", "Feel (most alert late at night)", "Report (difficulty falling asleep until late)"],
            "Nouns": ["Persistent delay (sleep-wake schedule)", "Late sleep onset", "Late wake time", "Sleep-onset insomnia (when trying to sleep earlier)", "Difficulty waking", "Daytime sleepiness (if schedule is forced early)", "Social/occupational impairment"]
        },
        "Advanced Sleep Phase Type (Circadian Rhythm Sleep-Wake Disorder)": { # Adjective (DisorderName)
            "Synonyms": ["Early Sleep Onset", "Early Bird Chronotype (extreme)", "Circadian Rhythm Disorder"],
            "Verbs": ["Advance (sleep onset/wake times significantly)", "Wake (very early)", "Feel (sleepy early evening)", "Report (inability to stay asleep until desired time)"],
            "Nouns": ["Persistent advance (sleep-wake schedule)", "Early sleep onset", "Early morning awakening", "Evening sleepiness", "Inability to maintain sleep later", "Social/occupational impairment (if schedule is forced later)"]
        },
        "Irregular Sleep-Wake Type (Circadian Rhythm Sleep-Wake Disorder)": { # Adjective (DisorderName)
            "Synonyms": ["Disorganized Sleep Pattern", "Fragmented Sleep Across 24 Hours", "Circadian Rhythm Disorder"],
            "Verbs": ["Exhibit (temporally disorganized sleep/wake pattern)", "Lack (a clear circadian rhythm)", "Nap (frequently/irregularly)", "Experience (insomnia at night/excessive sleepiness during day)"],
            "Nouns": ["Lack of discernible circadian rhythm", "Fragmented sleep (at least three episodes in 24h)", "Irregular sleep-wake times", "Insomnia (during conventional sleep period)", "Excessive daytime sleepiness", "Social/occupational impairment"]
        },
        "Non-24-Hour Sleep-Wake Type (Circadian Rhythm Sleep-Wake Disorder)": { # Adjective (DisorderName)
            "Synonyms": ["Free-Running Disorder", "N24SWD", "Circadian Rhythm Disorder (blind individuals common)"],
            "Verbs": ["Exhibit (sleep-wake cycle not entrained to 24-hour day)", "Drift (sleep times progressively later)", "Experience (periods of insomnia/daytime sleepiness cyclically)"],
            "Nouns": ["Non-entrained circadian rhythm (typically >24h)", "Progressive daily delay (sleep/wake times)", "Cyclical insomnia", "Cyclical excessive sleepiness", "Impairment (due to misalignment with societal schedules)", "Common in blind individuals"]
        },
        "Nightmare Disorder (Parasomnia)": { # Adjective (DisorderName)
            "Synonyms": ["Dream Anxiety Disorder", "Recurrent Nightmares"],
            "Verbs": ["Experience (recurrent extended/extremely dysphoric dreams)", "Recall (dreams vividly)", "Become (rapidly oriented/alert upon awakening)", "Report (significant distress/impairment from nightmares)"],
            "Nouns": ["Repeated extended dysphoric dreams", "Well-remembered dream content (threatening)", "Rapid alertness upon awakening", "Significant distress (from dreams)", "Impairment in functioning (due to sleep disturbance/fear of sleep)"]
        },
        "Non-Rapid Eye Movement Sleep Arousal Disorders (Parasomnia)": { # Adjective (DisorderName) - This can be further split into Sleepwalking and Sleep Terrors
            "Synonyms": ["NREM Sleep Parasomnias", "Sleepwalking", "Sleep Terrors", "Confusional Arousals"],
            "Verbs": ["Experience (recurrent episodes of incomplete awakening)", "Exhibit (sleepwalking/sleep terrors)", "Have (amnesia for episodes)", "Report (difficulty awakening during episode/confusion if awakened)"],
            "Nouns": ["Incomplete awakening from NREM sleep", "Sleepwalking (somnambulism)", "Sleep terrors (pavor nocturnus)", "Relative unresponsiveness (during episode)", "Amnesia for episode content", "Confusion upon awakening", "Potential for injury"]
        },
        "Rapid Eye Movement Sleep Behavior Disorder (Parasomnia)": { # Adjective (DisorderName)
            "Synonyms": ["RBD", "REM Sleep Without Atonia", "Dream-Enacting Behavior"],
            "Verbs": ["Experience (repeated episodes of arousal with vocalization/complex motor behaviors during REM)", "Act out (dreams)", "Recall (dream content if awakened)", "Lack (normal REM sleep atonia)"],
            "Nouns": ["Arousal during REM sleep", "Vocalization (talking/shouting)", "Complex motor behaviors (dream-enactment)", "Absence of REM sleep atonia (polysomnography finding)", "Injury potential (to self/bed partner)", "Vivid dream recall (if awakened)"]
        },
        "Restless Legs Syndrome": { # Adjective (DisorderName)
            "Synonyms": ["RLS", "Willis-Ekbom Disease", "Urge to Move Legs"],
            "Verbs": ["Experience (urge to move legs with uncomfortable sensations)", "Feel (relief with movement)", "Report (worsening symptoms at rest/evening/night)"],
            "Nouns": ["Urge to move legs", "Unpleasant leg sensations (creeping/crawling/tingling)", "Symptoms worse at rest", "Symptoms worse in evening/night", "Relief with movement", "Sleep disturbance", "Daytime fatigue"]
        },
        "Substance/Medication-Induced Sleep Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Drug-Induced Sleep Problems", "Sleep Disturbance from Medication/Substance"],
            "Verbs": ["Experience (prominent sleep disturbance due to substance/medication use/withdrawal)", "Report (insomnia/hypersomnia/parasomnia/mixed)", "Correlate (sleep problem with substance exposure)"],
            "Nouns": ["Clinically significant sleep disturbance (insomnia/hypersomnia/parasomnia/circadian rhythm disruption)", "Evidence of substance intoxication/withdrawal or medication exposure", "Temporal association (between substance/medication and sleep disturbance)", "Distress/impairment"]
        },
    },
    "Sexual Dysfunctions": { # Factor (DSM-5-TR Chapter 13)
        "Delayed Ejaculation": { # Adjective (DisorderName)
            "Synonyms": ["Male Orgasmic Disorder (historic)", "Retarded Ejaculation", "Ejaculatory Inhibition"],
            "Verbs": ["Experience difficulty", "Delay (ejaculation)", "Struggle to (ejaculate)", "Require (prolonged stimulation)", "Report (distress)"],
            "Nouns": ["Delay (in ejaculation)", "Infrequent orgasm", "Absence of orgasm", "Marked distress", "Interpersonal difficulty", "Reduced satisfaction"]
        },
        "Erectile Disorder": {
            "Synonyms": ["Impotence (colloquial)", "Erectile Dysfunction", "Difficulty Achieving/Maintaining Erection"],
            "Verbs": ["Fail to (obtain/maintain erection)", "Experience (decreased rigidity)", "Report (distress)", "Avoid (sexual activity)"],
            "Nouns": ["Erectile difficulty", "Insufficient rigidity", "Maintenance failure", "Reduced confidence", "Performance anxiety", "Relationship strain"]
        },
        "Female Orgasmic Disorder": {
            "Synonyms": ["Anorgasmia (in females)", "Difficulty Reaching Orgasm", "Inhibited Female Orgasm"],
            "Verbs": ["Experience (delay/infrequency/absence of orgasm)", "Report (reduced intensity)", "Feel (distress)", "Require (specific stimulation)"],
            "Nouns": ["Orgasmic difficulty", "Delayed orgasm", "Absent orgasm", "Reduced intensity", "Sexual dissatisfaction", "Marked distress"]
        },
        "Female Sexual Interest/Arousal Disorder": {
            "Synonyms": ["Low Libido (female)", "Reduced Sexual Excitement", "Lack of Sexual Interest/Arousal"],
            "Verbs": ["Lack (interest/arousal/thoughts/fantasies)", "Fail to (initiate/respond to)", "Experience (reduced lubrication/sensation)"],
            "Nouns": ["Reduced interest", "Absent arousal", "Lack of sexual thoughts", "Reduced initiation", "Genital insensitivity", "Marked distress"]
        },
        "Genito-Pelvic Pain/Penetration Disorder": {
            "Synonyms": ["Dyspareunia (historic)", "Vaginismus (historic)", "Painful Intercourse", "Sexual Pain Disorder"],
            "Verbs": ["Experience (pain during intercourse/penetration)", "Fear (pain)", "Tense (pelvic floor muscles)", "Avoid (penetration)"],
            "Nouns": ["Genital pain", "Pelvic pain", "Penetration difficulty", "Fear of pain", "Muscle tension", "Marked distress", "Avoidance"]
        },
        "Male Hypoactive Sexual Desire Disorder": {
            "Synonyms": ["Low Libido (male)", "Reduced Sexual Interest", "Lack of Sexual Desire"],
            "Verbs": ["Lack (sexual thoughts/fantasies/desire)", "Show (deficient interest)", "Report (distress)"],
            "Nouns": ["Reduced desire", "Absent thoughts/fantasies", "Deficient interest", "Lack of motivation", "Interpersonal difficulty", "Marked distress"]
        },
        "Premature (Early) Ejaculation": {
            "Synonyms": ["Rapid Ejaculation", "Early Climax"],
            "Verbs": ["Ejaculate (rapidly/early)", "Experience (lack of control)", "Feel (distress/frustration)"],
            "Nouns": ["Early ejaculation", "Rapid climax", "Lack of control", "Reduced satisfaction", "Interpersonal distress", "Frustration"]
        }
        # Other Specified/Unspecified Sexual Dysfunction would follow a similar pattern
    },
    "Gender Dysphoria": { # Factor (DSM-5-TR Chapter 14)
        "Gender Dysphoria in Children": { # Adjective (DisorderName) - Note: SCID typically focuses on adults/adolescents for many sections, but DSM chapter covers it.
            "Synonyms": ["Gender Incongruence in Children", "Cross-Gender Identification (children)"],
            "Verbs": ["Express (desire to be other gender)", "State (one is other gender)", "Prefer (cross-gender roles/toys/attire)", "Reject (assigned gender)", "Experience (distress)"],
            "Nouns": ["Gender incongruence", "Strong desire (to be other gender)", "Aversion (to own anatomy)", "Cross-gender preferences", "Clinically significant distress", "Impairment in functioning"]
        },
        "Gender Dysphoria in Adolescents and Adults": {
            "Synonyms": ["Gender Incongruence", "Transgender Identity (associated distress/impairment)", "Gender Identity Disorder (historic)"],
            "Verbs": ["Experience (marked incongruence)", "Express (strong desire for other gender characteristics)", "Feel (gender does not match assigned sex)", "Seek (transition)", "Report (significant distress)"],
            "Nouns": ["Marked incongruence (experienced/expressed gender and assigned gender)", "Desire to rid primary/secondary sex characteristics", "Desire for other gender's sex characteristics", "Conviction of being other gender", "Clinically significant distress", "Impairment in social/occupational functioning"]
        }
        # Other Specified/Unspecified Gender Dysphoria would follow a similar pattern
    },
    "Disruptive, Impulse-Control, and Conduct Disorders": { # Factor (DSM-5-TR Chapter 15)
        "Oppositional Defiant Disorder": { # Adjective (DisorderName)
            "Synonyms": ["ODD", "Defiant Behavior", "Argumentativeness"],
            "Verbs": ["Argue (with authority)", "Defy (rules)", "Annoy (deliberately)", "Blame (others)", "Lose (temper)", "Act (spiteful/vindictive)"],
            "Nouns": ["Angry/irritable mood", "Argumentative/defiant behavior", "Vindictiveness", "Temper outbursts", "Noncompliance", "Resentfulness"]
        },
        "Intermittent Explosive Disorder": {
            "Synonyms": ["IED", "Aggressive Outbursts", "Impulsive Aggression"],
            "Verbs": ["Fail to (control aggressive impulses)", "Exhibit (verbal aggression/physical aggression)", "Damage (property)", "Assault (others)"],
            "Nouns": ["Recurrent behavioral outbursts", "Impulsive aggression", "Grossly out of proportion reactions", "Verbal aggression", "Physical assault", "Property destruction", "Significant distress/impairment"]
        },
        "Conduct Disorder": {
            "Synonyms": ["Antisocial Behavior (childhood/adolescence)", "Delinquency"],
            "Verbs": ["Violate (rights of others/societal norms)", "Aggress (towards people/animals)", "Destroy (property)", "Deceive", "Steal", "Run away"],
            "Nouns": ["Aggression to people/animals", "Destruction of property", "Deceitfulness or theft", "Serious violations of rules", "Callous-unemotional traits (specifier)", "Repetitive/persistent pattern"]
        },
        "Antisocial Personality Disorder": { # Note: Also in Personality Disorders, but SCID covers it here for continuity with Conduct Disorder if relevant
            "Synonyms": ["ASPD", "Sociopathy (colloquial)", "Psychopathy (related construct)"],
            "Verbs": ["Disregard (rights of others)", "Violate (rights of others)", "Deceive", "Manipulate", "Act (impulsively)", "Lack (remorse)"],
            "Nouns": ["Pervasive pattern of disregard for/violation of rights of others", "Deceitfulness", "Impulsivity", "Irritability/aggressiveness", "Irresponsibility", "Lack of remorse", "Conduct disorder history"]
        },
        "Pyromania": {
            "Synonyms": ["Fire Setting (compulsive)"],
            "Verbs": ["Set (fires deliberately/purposefully)", "Experience (tension/affective arousal before act)", "Feel (pleasure/gratification/relief when setting/witnessing fires)"],
            "Nouns": ["Deliberate fire setting", "Tension before act", "Fascination with fire", "Gratification from fire", "Not for monetary gain/ideology"]
        },
        "Kleptomania": {
            "Synonyms": ["Compulsive Stealing"],
            "Verbs": ["Fail to (resist impulses to steal)", "Steal (objects not needed for personal use/monetary value)", "Experience (tension before act)", "Feel (pleasure/gratification/relief during theft)"],
            "Nouns": ["Recurrent failure to resist stealing", "Objects stolen not needed", "Tension before theft", "Pleasure/gratification during theft", "Not to express anger/vengeance"]
        }
        # Other Specified/Unspecified Disruptive, Impulse-Control, and Conduct Disorder
    }
    scid_dataset_continued_formatted = {
    # ... (previous categories like Neurodevelopmental, ... Sleep-Wake Disorders, etc.)

    "Substance-Related and Addictive Disorders": {  # Factor (DSM-5-TR Chapter 16)
        # --- Alcohol-Related Disorders ---
        "Alcohol Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Alcoholism (colloquial)", "Alcohol Dependence", "Problematic Alcohol Use", "Alcohol Abuse"],
            "Verbs": [
                "Consume (alcohol in larger amounts or over longer period than intended)", 
                "Express (persistent desire or unsuccessful efforts to cut down or control alcohol use)", 
                "Spend (a great deal of time obtaining, using, or recovering from alcohol effects)", 
                "Experience (craving or strong desire/urge to use alcohol)", 
                "Fail (to fulfill major role obligations at work, school, or home due to recurrent use)", 
                "Continue (alcohol use despite persistent social/interpersonal problems caused/exacerbated by alcohol)", 
                "Give up (important social, occupational, or recreational activities because of alcohol use)", 
                "Use (alcohol in situations where it is physically hazardous)", 
                "Continue (alcohol use despite knowledge of having persistent physical/psychological problem likely caused/exacerbated by alcohol)", 
                "Develop (tolerance for alcohol)", 
                "Experience (alcohol withdrawal symptoms or use alcohol to relieve/avoid withdrawal)"
            ],
            "Nouns": [
                "Alcohol taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control use", 
                "Significant time spent in activities to obtain/use/recover from alcohol", "Craving or strong desire/urge to use alcohol", 
                "Recurrent alcohol use resulting in failure to fulfill major role obligations", 
                "Continued alcohol use despite persistent or recurrent social/interpersonal problems", 
                "Important activities given up or reduced due to alcohol use", "Recurrent alcohol use in physically hazardous situations", 
                "Continued use despite knowledge of persistent physical/psychological problem related to alcohol", 
                "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or alcohol taken to relieve/avoid symptoms)"
            ]
        },
        "Alcohol Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Drunkenness", "Alcohol Inebriation", "Being Drunk"],
            "Verbs": [
                "Exhibit (slurred speech after recent alcohol ingestion)", "Show (incoordination following alcohol use)", 
                "Demonstrate (unsteady gait after drinking)", "Have (nystagmus due to alcohol)", 
                "Manifest (impaired attention or memory post-alcohol)", "Become (stuporous or comatose from alcohol)",
                "Behave (inappropriately or aggressively post-ingestion)"
            ],
            "Nouns": [
                "Recent ingestion of alcohol", "Clinically significant problematic behavioral or psychological changes (e.g., inappropriate sexual/aggressive behavior, mood lability, impaired judgment)", 
                "Slurred speech", "Incoordination", "Unsteady gait", "Nystagmus", 
                "Impairment in attention or memory", "Stupor or coma"
            ]
        },
        "Alcohol Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Alcohol Withdrawal Syndrome", "The Shakes (colloquial)", "Delirium Tremens (severe form, DTs)"],
            "Verbs": [
                "Experience (autonomic hyperactivity like sweating or tachycardia after cessation/reduction of alcohol)", 
                "Exhibit (increased hand tremor following alcohol cessation/reduction)", "Report (insomnia after stopping/reducing alcohol)", 
                "Suffer (from nausea or vomiting post-alcohol cessation/reduction)", 
                "Have (transient visual, tactile, or auditory hallucinations or illusions)", 
                "Show (psychomotor agitation after alcohol cessation/reduction)", "Feel (anxious after stopping/reducing alcohol)", 
                "Develop (generalized tonic-clonic seizures)"
            ],
            "Nouns": [
                "Cessation of (or reduction in) alcohol use that has been heavy and prolonged", 
                "Autonomic hyperactivity (e.g., sweating, pulse rate greater than 100 bpm)", "Increased hand tremor", "Insomnia", 
                "Nausea or vomiting", "Transient visual, tactile, or auditory hallucinations or illusions", "Psychomotor agitation", 
                "Anxiety", "Generalized tonic-clonic seizures", "Delirium Tremens (as a severe manifestation)"
            ]
        },

        # --- Cannabis-Related Disorders ---
        "Cannabis Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Marijuana Addiction (colloquial)", "Cannabis Dependence", "Problematic Cannabis Use"],
            "Verbs": [
                "Use (cannabis in larger amounts or over longer period than intended)", 
                "Express (persistent desire or unsuccessful efforts to cut down or control cannabis use)", 
                "Spend (a great deal of time obtaining, using, or recovering from cannabis effects)", 
                "Experience (craving or strong desire/urge to use cannabis)", 
                "Fail (to fulfill major role obligations due to recurrent cannabis use)", 
                "Continue (cannabis use despite persistent social/interpersonal problems caused/exacerbated by cannabis)", 
                "Give up (important activities because of cannabis use)", 
                "Use (cannabis in situations where it is physically hazardous)", 
                "Continue (cannabis use despite knowledge of physical/psychological problem related to cannabis)", 
                "Develop (tolerance for cannabis)", 
                "Experience (cannabis withdrawal symptoms, if applicable)"
            ],
            "Nouns": [
                "Cannabis taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control cannabis use", 
                "Significant time spent in activities to obtain/use/recover from cannabis", "Craving or strong desire/urge to use cannabis", 
                "Recurrent cannabis use resulting in failure to fulfill major role obligations", 
                "Continued cannabis use despite persistent or recurrent social/interpersonal problems", 
                "Important activities given up or reduced due to cannabis use", "Recurrent cannabis use in physically hazardous situations", 
                "Continued use despite knowledge of persistent physical/psychological problem related to cannabis", 
                "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome for some users)"
            ]
        },
        "Cannabis Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Being High (on marijuana)", "Cannabis Inebriation", "Marijuana Intoxication"],
            "Verbs": [
                "Exhibit (impaired motor coordination after recent cannabis use)", "Feel (euphoric or anxious post-cannabis use)", 
                "Perceive (time as slowed following cannabis use)", "Show (impaired judgment after cannabis)", 
                "Develop (conjunctival injection from cannabis)", "Experience (increased appetite or dry mouth due to cannabis)", "Have (tachycardia post-cannabis)"
            ],
            "Nouns": [
                "Recent use of cannabis", "Clinically significant problematic behavioral or psychological changes (e.g., impaired motor coordination, euphoria, anxiety, sensation of slowed time, impaired judgment, social withdrawal)", 
                "Conjunctival injection", "Increased appetite", "Dry mouth", "Tachycardia", "Perceptual disturbances (at high doses)"
            ]
        },
        "Cannabis Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Marijuana Withdrawal Syndrome", "Cannabis Abstinence Syndrome"],
            "Verbs": [
                "Experience (irritability, anger, or aggression after cannabis cessation)", 
                "Feel (nervous or anxious upon stopping cannabis)", "Have (sleep difficulty like insomnia or disturbing dreams)", 
                "Report (decreased appetite or weight loss)", "Exhibit (restlessness after cannabis cessation)", 
                "Become (depressed in mood)", "Suffer (from physical symptoms like abdominal pain, shakiness, sweating, fever, chills, or headache)"
            ],
            "Nouns": [
                "Cessation of cannabis use that has been heavy and prolonged", 
                "Irritability, anger, or aggression", "Nervousness or anxiety", "Sleep difficulty (e.g., insomnia, disturbing dreams)", 
                "Decreased appetite or weight loss", "Restlessness", "Depressed mood", 
                "Physical symptoms (e.g., abdominal pain, shakiness/tremors, sweating, fever, chills, headache) causing significant discomfort"
            ]
        },

        # --- Opioid-Related Disorders ---
        "Opioid Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Opioid Addiction", "Heroin Addiction", "Painkiller Addiction", "Narcotic Dependence"],
            "Verbs": [
                "Take (opioids in larger amounts or over longer period than intended)", 
                "Express (persistent desire or unsuccessful efforts to cut down or control opioid use)", 
                "Spend (a great deal of time obtaining, using, or recovering from opioid effects)", 
                "Experience (craving or strong desire/urge to use opioids)", 
                "Fail (to fulfill major role obligations due to recurrent opioid use)", 
                "Continue (opioid use despite persistent social/interpersonal problems caused/exacerbated by opioids)", 
                "Give up (important activities because of opioid use)", 
                "Use (opioids in situations where it is physically hazardous)", 
                "Continue (opioid use despite knowledge of physical/psychological problem related to opioids)", 
                "Develop (tolerance for opioids)", 
                "Experience (opioid withdrawal symptoms or use opioids to relieve/avoid withdrawal)"
            ],
            "Nouns": [
                "Opioids taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control opioid use", 
                "Significant time spent in activities to obtain/use/recover from opioids", "Craving or strong desire/urge to use opioids", 
                "Recurrent opioid use resulting in failure to fulfill major role obligations", 
                "Continued opioid use despite persistent or recurrent social/interpersonal problems", 
                "Important activities given up or reduced due to opioid use", "Recurrent opioid use in physically hazardous situations", 
                "Continued use despite knowledge of persistent physical/psychological problem related to opioids", 
                "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or opioids taken to relieve/avoid symptoms)"
            ]
        },
        "Opioid Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Narcotic Intoxication", "Opioid Overdose (can lead to coma/death)", "Being High (on opioids)"],
            "Verbs": [
                "Exhibit (pupillary constriction or dilation in severe anoxia after recent opioid use)", 
                "Become (drowsy or comatose post-opioid use)", "Show (slurred speech following opioid use)", 
                "Manifest (impaired attention or memory due to opioids)"
            ],
            "Nouns": [
                "Recent use of an opioid", "Clinically significant problematic behavioral or psychological changes (e.g., initial euphoria followed by apathy, dysphoria, psychomotor agitation or retardation, impaired judgment)", 
                "Pupillary constriction (or dilation due to anoxia from severe overdose)", "Drowsiness or coma", "Slurred speech", 
                "Impairment in attention or memory", "Respiratory depression (clinically significant)"
            ]
        },
        "Opioid Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Dopesickness (colloquial)", "Opioid Abstinence Syndrome", "Kicking (colloquial)"],
            "Verbs": [
                "Experience (dysphoric mood after opioid cessation/reduction)", "Suffer (from nausea or vomiting)", 
                "Have (muscle aches or lacrimation or rhinorrhea)", "Exhibit (pupillary dilation, piloerection, or sweating)", 
                "Report (diarrhea, yawning, fever, or insomnia)"
            ],
            "Nouns": [
                "Cessation of (or reduction in) opioid use that has been heavy and prolonged (or administration of an opioid antagonist)", 
                "Dysphoric mood", "Nausea or vomiting", "Muscle aches", "Lacrimation or rhinorrhea", 
                "Pupillary dilation, piloerection, or sweating", "Diarrhea", "Yawning", "Fever", "Insomnia"
            ]
        },

        # --- Stimulant-Related Disorders (e.g., Amphetamine-type, Cocaine) ---
        "Stimulant Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Stimulant Addiction", "Cocaine Addiction", "Methamphetamine Addiction", "Speed Freak (colloquial)"],
            "Verbs": [
                "Use (stimulants in larger amounts or over longer period than intended)", 
                "Express (persistent desire or unsuccessful efforts to cut down or control stimulant use)", 
                "Spend (a great deal of time obtaining, using, or recovering from stimulant effects)", 
                "Experience (craving or strong desire/urge to use stimulants)", 
                "Fail (to fulfill major role obligations due to recurrent stimulant use)", 
                "Continue (stimulant use despite persistent social/interpersonal problems caused/exacerbated by stimulants)", 
                "Give up (important activities because of stimulant use)", 
                "Use (stimulants in situations where it is physically hazardous)", 
                "Continue (stimulant use despite knowledge of physical/psychological problem related to stimulants)", 
                "Develop (tolerance for stimulants)", 
                "Experience (stimulant withdrawal symptoms)"
            ],
            "Nouns": [
                "Stimulants taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control stimulant use", 
                "Significant time spent in activities to obtain/use/recover from stimulants", "Craving or strong desire/urge to use stimulants", 
                "Recurrent stimulant use resulting in failure to fulfill major role obligations", 
                "Continued stimulant use despite persistent or recurrent social/interpersonal problems", 
                "Important activities given up or reduced due to stimulant use", "Recurrent stimulant use in physically hazardous situations", 
                "Continued use despite knowledge of persistent physical/psychological problem related to stimulants", 
                "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome)"
            ]
        },
        "Stimulant Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Cocaine High", "Meth High", "Amphetamine Buzz", "Stimulant Overamping"],
            "Verbs": [
                "Exhibit (tachycardia or bradycardia after recent stimulant use)", "Show (pupillary dilation or changes in blood pressure)", 
                "Experience (perspiration or chills, nausea or vomiting, or weight loss)", 
                "Manifest (psychomotor agitation or retardation, muscular weakness, respiratory depression, chest pain, or cardiac arrhythmias)",
                "Become (confused, or develop seizures, dyskinesias, dystonias, or coma)"
            ],
            "Nouns": [
                "Recent use of an amphetamine-type substance, cocaine, or other stimulant", 
                "Clinically significant problematic behavioral or psychological changes (e.g., euphoria or affective blunting; changes in sociability; hypervigilance; interpersonal sensitivity; anxiety, tension, or anger; stereotyped behaviors; impaired judgment)", 
                "Tachycardia or bradycardia", "Pupillary dilation", "Elevated or lowered blood pressure", "Perspiration or chills", 
                "Nausea or vomiting", "Evidence of weight loss", "Psychomotor agitation or retardation", "Muscular weakness, respiratory depression, chest pain, or cardiac arrhythmias", 
                "Confusion, seizures, dyskinesias, dystonias, or coma"
            ]
        },
        "Stimulant Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Cocaine Crash", "Meth Crash", "Stimulant Come-down", "Post-stimulant Depression"],
            "Verbs": [
                "Experience (fatigue after cessation/reduction of stimulant use)", "Have (vivid, unpleasant dreams)", 
                "Suffer (from insomnia or hypersomnia)", "Report (increased appetite)", "Exhibit (psychomotor retardation or agitation)"
            ],
            "Nouns": [
                "Cessation of (or reduction in) prolonged stimulant use", 
                "Dysphoric mood", "Fatigue", "Vivid, unpleasant dreams", "Insomnia or hypersomnia", "Increased appetite", 
                "Psychomotor retardation or agitation", "Anhedonia"
            ]
        },

        # --- Tobacco-Related Disorders ---
        "Tobacco Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Nicotine Addiction", "Smoking Addiction", "Problematic Tobacco Use", "Compulsive Smoking"],
            "Verbs": [
                "Use (tobacco in larger amounts or over longer period than intended)", 
                "Express (persistent desire or unsuccessful efforts to cut down or quit tobacco use)", 
                "Spend (a great deal of time obtaining or using tobacco)", 
                "Experience (craving or strong desire/urge to use tobacco)", 
                "Fail (to fulfill major role obligations due to recurrent tobacco use, less common but can occur)", 
                "Continue (tobacco use despite persistent social/interpersonal problems exacerbated by tobacco use effects)", 
                "Give up (important activities because of tobacco use)", 
                "Continue (tobacco use despite knowledge of having persistent physical problem likely caused/exacerbated by tobacco)", 
                "Develop (tolerance for nicotine)", 
                "Experience (tobacco withdrawal symptoms or use tobacco to relieve/avoid withdrawal)"
            ],
            "Nouns": [
                "Tobacco used in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/quit tobacco use", 
                "Significant time spent in activities to obtain/use tobacco", "Craving or strong desire/urge to use tobacco", 
                "Continued tobacco use despite knowledge of persistent or recurrent physical health problem caused/exacerbated by tobacco", 
                "Tolerance (need for increased amounts for desired effect, or diminished effect with same amount)", 
                "Withdrawal (characteristic syndrome or tobacco used to relieve/avoid symptoms)", "Use in hazardous situations (less direct, but e.g., smoking in bed)"
            ]
        },
        "Tobacco Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Nicotine Withdrawal Syndrome", "Quitting Symptoms"],
            "Verbs": [
                "Experience (irritability, frustration, or anger after daily tobacco use cessation/reduction)", 
                "Feel (anxious or have difficulty concentrating)", "Report (increased appetite or restlessness)", 
                "Become (depressed in mood)", "Suffer (from insomnia)"
            ],
            "Nouns": [
                "Daily use of tobacco for at least several weeks with abrupt cessation/reduction", 
                "Irritability, frustration, or anger", "Anxiety", "Difficulty concentrating", "Increased appetite", 
                "Restlessness", "Depressed mood", "Insomnia"
            ]
        },

        # --- Non-Substance-Related Disorder ---
        "Gambling Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Compulsive Gambling", "Pathological Gambling (older term)", "Problem Gambling", "Gambling Addiction"],
            "Verbs": [
                "Need (to gamble with increasing amounts of money to achieve desired excitement)", 
                "Become (restless or irritable when attempting to cut down or stop gambling)", 
                "Make (repeated unsuccessful efforts to control, cut back, or stop gambling)", 
                "Be (often preoccupied with gambling)", 
                "Gamble (when feeling distressed like helpless, guilty, anxious, depressed)", 
                "Chase (one's losses by returning another day to get even)", 
                "Lie (to conceal the extent of involvement with gambling)", 
                "Jeopardize (or lose a significant relationship, job, or educational/career opportunity because of gambling)", 
                "Rely (on others to provide money to relieve desperate financial situations caused by gambling)"
            ],
            "Nouns": [
                "Persistent and recurrent problematic gambling behavior leading to clinically significant impairment or distress", 
                "Need to gamble with increasing amounts of money (tolerance-like)", "Restlessness or irritability when attempting to stop/cut down (withdrawal-like)", 
                "Repeated unsuccessful efforts to control/stop gambling", "Preoccupation with gambling", 
                "Gambling when feeling distressed", "Chasing one's losses", "Lying to conceal gambling involvement", 
                "Jeopardized/lost significant relationship, job, or opportunity", "Reliance on others for money (bailout)"
            ]
        }
        # --- Sedative-, Hypnotic-, or Anxiolytic-Related Disorders ---
        "Sedative, Hypnotic, or Anxiolytic Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Benzodiazepine Addiction", "Barbiturate Addiction", "Sleeping Pill Addiction", "Anti-Anxiety Medication Dependence"],
            "Verbs": [
                "Use (sedatives/hypnotics/anxiolytics in larger amounts or over longer period than intended)",
                "Express (persistent desire or unsuccessful efforts to cut down or control use)",
                "Spend (a great deal of time obtaining, using, or recovering from effects)",
                "Experience (craving or strong desire/urge to use)",
                "Fail (to fulfill major role obligations due to recurrent use)",
                "Continue (use despite persistent social/interpersonal problems caused/exacerbated by effects)",
                "Give up (important social, occupational, or recreational activities because of use)",
                "Use (in situations where it is physically hazardous)",
                "Continue (use despite knowledge of having persistent physical/psychological problem likely caused/exacerbated by the substance)",
                "Develop (tolerance)",
                "Experience (withdrawal symptoms or use substance to relieve/avoid withdrawal)"
            ],
            "Nouns": [
                "Problematic pattern of sedative, hypnotic, or anxiolytic use leading to clinically significant impairment or distress",
                "Substance taken in larger amounts or over longer period", "Persistent desire or unsuccessful efforts to cut down/control use",
                "Significant time spent in activities to obtain/use/recover", "Craving or strong desire/urge to use",
                "Recurrent use resulting in failure to fulfill major role obligations",
                "Continued use despite persistent or recurrent social/interpersonal problems",
                "Important activities given up or reduced due to use", "Recurrent use in physically hazardous situations",
                "Continued use despite knowledge of persistent physical/psychological problem related to the substance",
                "Tolerance (need for increased amounts or diminished effect)", "Withdrawal (characteristic syndrome or substance taken to relieve/avoid symptoms)"
            ]
        },
        "Sedative, Hypnotic, or Anxiolytic Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Tranquilizer Overdose Effects", "Sleeping Pill Intoxication", "Benzo Intoxication"],
            "Verbs": [
                "Exhibit (slurred speech after recent use)", "Show (incoordination or unsteady gait)",
                "Manifest (nystagmus or impaired cognition like attention/memory)", "Become (stuporous or comatose)"
            ],
            "Nouns": [
                "Recent use of a sedative, hypnotic, or anxiolytic",
                "Clinically significant maladaptive behavioral or psychological changes (e.g., inappropriate sexual/aggressive behavior, mood lability, impaired judgment)",
                "Slurred speech", "Incoordination", "Unsteady gait", "Nystagmus",
                "Impairment in cognition (e.g., attention, memory)", "Stupor or coma", "Respiratory depression (in severe cases)"
            ]
        },
        "Sedative, Hypnotic, or Anxiolytic Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Benzo Withdrawal", "Barbiturate Withdrawal", "Sleeping Pill Withdrawal Symptoms"],
            "Verbs": [
                "Experience (autonomic hyperactivity like sweating or tachycardia after cessation/reduction)",
                "Have (hand tremor, insomnia, nausea, or vomiting)", "Report (transient visual, tactile, or auditory hallucinations/illusions)",
                "Exhibit (psychomotor agitation or anxiety)", "Develop (generalized tonic-clonic seizures)"
            ],
            "Nouns": [
                "Cessation of (or reduction in) use that has been heavy and prolonged",
                "Autonomic hyperactivity (e.g., sweating, pulse rate >100 bpm)", "Hand tremor", "Insomnia",
                "Nausea or vomiting", "Transient visual, tactile, or auditory hallucinations or illusions",
                "Psychomotor agitation", "Anxiety", "Grand mal seizures"
            ]
        },

        # --- Hallucinogen-Related Disorders ---
        "Phencyclidine Use Disorder": { # Adjective (DisorderName)
             "Synonyms": ["PCP Addiction", "Angel Dust Dependence", "Problematic PCP Use"],
             "Verbs": ["Use (phencyclidine repeatedly leading to impairment/distress)", "Develop (tolerance to effects of PCP)", "Experience (craving for PCP)", "Continue (PCP use despite negative consequences)"],
             "Nouns": ["Problematic pattern of phencyclidine use", "Impaired control over PCP use", "Craving for PCP", "Tolerance to PCP effects", "Use resulting in failure to fulfill major roles", "Continued use despite social/physical problems"]
        },
        "Other Hallucinogen Use Disorder": { # Adjective (DisorderName) (e.g., LSD, psilocybin, mescaline, MDMA)
             "Synonyms": ["LSD Addiction (colloquial, dependence is more accurate)", "Psychedelic Dependence", "Problematic Hallucinogen Use (non-PCP)"],
             "Verbs": ["Use (hallucinogen other than PCP repeatedly leading to impairment/distress)", "Develop (tolerance to effects, for some hallucinogens)", "Experience (craving, for some hallucinogens)", "Continue (hallucinogen use despite negative psychological/social consequences)"],
             "Nouns": ["Problematic pattern of use of a hallucinogen (other than phencyclidine)", "Impaired control over hallucinogen use", "Craving (for some hallucinogens like MDMA)", "Tolerance (rapid for some, e.g., LSD)", "Continued use despite psychological problems (e.g., anxiety, flashbacks)"]
        },
        "Phencyclidine Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["PCP Intoxication", "Angel Dust High"],
            "Verbs": ["Exhibit (vertical/horizontal nystagmus after recent PCP use)", "Show (hypertension/tachycardia, numbness/diminished pain response, ataxia, dysarthria)", "Manifest (muscle rigidity, seizures/coma, hyperacusis)"],
            "Nouns": ["Recent use of phencyclidine (or a related substance)", "Clinically significant problematic behavioral changes (e.g., belligerence, assaultiveness, impulsiveness, unpredictability, psychomotor agitation, impaired judgment)", "Vertical or horizontal nystagmus", "Hypertension or tachycardia", "Numbness or diminished responsiveness to pain", "Ataxia", "Dysarthria", "Muscle rigidity", "Seizures or coma", "Hyperacusis"]
        },
        "Other Hallucinogen Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["LSD Trip", "Psychedelic Intoxication", "Shroom High", "Ecstasy Intoxication (MDMA)"],
            "Verbs": ["Experience (perceptual changes like illusions/hallucinations/synesthesias after recent use)", "Exhibit (pupillary dilation, tachycardia, sweating, palpitations, blurred vision, tremors, incoordination)"],
            "Nouns": ["Recent use of a hallucinogen (other than phencyclidine)", "Clinically significant problematic behavioral or psychological changes (e.g., marked anxiety/depression, ideas of reference, fear of losing one’s mind, paranoid ideation, impaired judgment)", "Perceptual changes (e.g., subjective intensification of perceptions, depersonalization, derealization, illusions, hallucinations, synesthesias)", "Pupillary dilation", "Tachycardia", "Sweating", "Palpitations", "Blurred vision", "Tremors", "Incoordination"]
        },
        "Hallucinogen Persisting Perception Disorder (HPPD)": { # Adjective (DisorderName)
            "Synonyms": ["Flashbacks (hallucinogen-induced)", "Persistent Visual Disturbances after Hallucinogen Use"],
            "Verbs": ["Re-experience (perceptual symptoms experienced during hallucinogen intoxication after cessation of use)", "Report (geometric forms, peripheral field flashes, intensified colors, trails of images, halos, macropsia, micropsia)"],
            "Nouns": ["Re-experiencing of perceptual symptoms (following cessation of hallucinogen use)", "Visual disturbances (geometric hallucinations, flashes of color, intensified colors, trails of images of moving objects, positive afterimages, halos around objects, macropsia, micropsia)", "Symptoms cause clinically significant distress or impairment", "Not attributable to another medical/mental condition"]
        },
        
        # --- Inhalant-Related Disorders ---
        "Inhalant Use Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Huffing Addiction", "Solvent Abuse Dependence", "Problematic Inhalant Use"],
            "Verbs": [
                "Use (inhalants repeatedly leading to impairment/distress)", "Develop (tolerance to effects of inhalants)", 
                "Experience (craving for inhalants)", "Continue (inhalant use despite negative health/social consequences)", 
                "Spend (significant time obtaining/using/recovering from inhalants)"
            ],
            "Nouns": [
                "Problematic pattern of use of a volatile hydrocarbon substance (inhalant)", "Impaired control over inhalant use", 
                "Craving for inhalants", "Tolerance to inhalant effects", "Use resulting in failure to fulfill major roles", 
                "Continued use despite social/physical problems (e.g., neurological damage, liver/kidney damage)", 
                "Use in hazardous situations"
            ]
        },
        "Inhalant Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Huffing High", "Solvent Intoxication", "Glue Sniffing Effects"],
            "Verbs": [
                "Exhibit (dizziness/nystagmus/incoordination/slurred speech/unsteady gait/lethargy after recent inhalant exposure)", 
                "Show (depressed reflexes/psychomotor retardation/tremor/generalized muscle weakness/blurred vision/diplopia/stupor/coma/euphoria)"
            ],
            "Nouns": [
                "Recent intentional exposure to inhalant substances (volatile hydrocarbons)", 
                "Clinically significant problematic behavioral or psychological changes (e.g., belligerence, assaultiveness, apathy, impaired judgment)", 
                "Dizziness", "Nystagmus", "Incoordination", "Slurred speech", "Unsteady gait", "Lethargy", "Depressed reflexes", 
                "Psychomotor retardation", "Tremor", "Generalized muscle weakness", "Blurred vision or diplopia", "Stupor or coma", "Euphoria"
            ]
        },

        # --- Caffeine-Related Disorders ---
        "Caffeine Intoxication": { # Adjective (DisorderName)
            "Synonyms": ["Caffeine Overdose", "Coffee Jitters (severe)"],
            "Verbs": ["Experience (restlessness/nervousness/excitement/insomnia/flushed face/diuresis/gastrointestinal disturbance after recent high caffeine consumption)", "Exhibit (muscle twitching/rambling thought/speech/tachycardia/cardiac arrhythmia/periods of inexhaustibility/psychomotor agitation)"],
            "Nouns": ["Recent consumption of caffeine (typically >250 mg)", "Restlessness", "Nervousness", "Excitement", "Insomnia", "Flushed face", "Diuresis", "Gastrointestinal disturbance", "Muscle twitching", "Rambling flow of thought and speech", "Tachycardia or cardiac arrhythmia", "Periods of inexhaustibility", "Psychomotor agitation"]
        },
        "Caffeine Withdrawal": { # Adjective (DisorderName)
            "Synonyms": ["Caffeine Headache", "Coffee Withdrawal Symptoms"],
            "Verbs": ["Experience (headache after abrupt cessation/reduction of caffeine)", "Report (marked fatigue/drowsiness/dysphoric mood/depressed mood/irritability/difficulty concentrating/flu-like symptoms like nausea/vomiting/muscle pain/stiffness)"],
            "Nouns": ["Prolonged daily use of caffeine with abrupt cessation/reduction", "Headache (characteristic)", "Marked fatigue or drowsiness", "Dysphoric mood, depressed mood, or irritability", "Difficulty concentrating", "Flu-like symptoms (nausea, vomiting, or muscle pain/stiffness)"]
        },

        # --- Generic Other Specified / Unspecified Categories for Substances ---
        "Other Specified Substance-Related Disorder": { # Adjective (DisorderName) - Clinician specifies the substance and reason
            "Synonyms": ["Atypical substance use problem (specified)", "Subthreshold [Substance] Use Disorder (specified reason)", "Clinically significant substance issue (not fully classifiable)"],
            "Verbs": ["Present with (substance-related symptoms causing distress/impairment)", "Not meet (full criteria for a specific [Substance]-Related Disorder, reason specified)", "Exhibit (atypical substance effects)"],
            "Nouns": ["Substance-related symptoms (distress/impairment)", "Atypical presentation (substance-related)", "Partial criteria fulfillment ([Substance]-Related Disorder)", "Specified substance", "Specified reason for atypicality"]
        },
        "Unspecified Substance-Related Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Substance problem NOS (older term)", "Undifferentiated substance-related issue", "Insufficient information for specific substance diagnosis"],
            "Verbs": ["Experience (problematic substance involvement)", "Report (substance-related difficulties without full details)", "Present with (undifferentiated substance-related symptoms)"],
            "Nouns": ["Substance-related problem (unspecified)", "Undifferentiated substance symptoms", "Insufficient diagnostic information (substance-related)", "Clinically significant substance issue (unclear type)"]
        },

        # --- Substance/Medication-Induced Mental Disorders ---
        "Substance/Medication-Induced Psychotic Disorder": {
            "Synonyms": ["Drug-Induced Psychosis", "Medication-Caused Psychotic Symptoms"],
            "Verbs": ["Experience (delusions and/or hallucinations after substance intoxication/withdrawal or medication exposure)", "Exhibit (psychotic symptoms judged etiologically related to substance/medication)"],
            "Nouns": ["Delusions", "Hallucinations", "Substance intoxication/withdrawal context", "Medication exposure context", "Symptoms developed during or soon after substance intoxication/withdrawal or after exposure to a medication", "Clinically significant psychotic symptoms"]
        },
        "Substance/Medication-Induced Bipolar and Related Disorder": {
            "Synonyms": ["Drug-Induced Mania/Hypomania", "Medication-Caused Bipolar Symptoms"],
            "Verbs": ["Experience (elevated/expansive/irritable mood and increased activity/energy after substance intoxication/withdrawal or medication exposure)", "Exhibit (manic/hypomanic symptoms etiologically related to substance/medication)"],
            "Nouns": ["Elevated/expansive/irritable mood", "Increased activity/energy", "Manic symptoms", "Hypomanic symptoms", "Substance intoxication/withdrawal context", "Medication exposure context", "Clinically significant mood disturbance (bipolar type)"]
        },
        "Substance/Medication-Induced Depressive Disorder": {
            "Synonyms": ["Drug-Induced Depression", "Medication-Caused Depressive Symptoms"],
            "Verbs": ["Experience (depressed mood or markedly diminished interest/pleasure after substance intoxication/withdrawal or medication exposure)", "Exhibit (depressive symptoms etiologically related to substance/medication)"],
            "Nouns": ["Depressed mood", "Markedly diminished interest/pleasure (anhedonia)", "Substance intoxication/withdrawal context", "Medication exposure context", "Clinically significant depressive symptoms"]
        },
        "Substance/Medication-Induced Anxiety Disorder": {
            "Synonyms": ["Drug-Induced Anxiety", "Medication-Caused Anxiety Symptoms"],
            "Verbs": ["Experience (panic attacks or anxiety after substance intoxication/withdrawal or medication exposure)", "Exhibit (anxiety symptoms etiologically related to substance/medication)"],
            "Nouns": ["Panic attacks", "Anxiety (generalized/phobic)", "Substance intoxication/withdrawal context", "Medication exposure context", "Clinically significant anxiety symptoms"]
        },
        "Substance/Medication-Induced Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Drug-Induced OCD Symptoms", "Medication-Caused Compulsions/Obsessions"],
            "Verbs": ["Experience (obsessions/compulsions/preoccupations/repetitive behaviors after substance intoxication/withdrawal or medication exposure)", "Exhibit (OCD-like symptoms etiologically related to substance/medication)"],
            "Nouns": ["Obsessions", "Compulsions", "Preoccupations (e.g., with appearance)", "Repetitive body-focused behaviors (e.g., hair pulling, skin picking)", "Substance intoxication/withdrawal context", "Medication exposure context", "Clinically significant OCD-related symptoms"]
        },
        "Substance/Medication-Induced Sleep Disorder": { # Already covered in Sleep-Wake, but important for SCID to link to substance
            "Synonyms": ["Drug-Induced Insomnia/Hypersomnia", "Medication-Caused Sleep Problems"],
            "Verbs": ["Experience (prominent sleep disturbance like insomnia/hypersomnia/parasomnia after substance intoxication/withdrawal or medication exposure)", "Report (sleep problems linked to substance/medication)"],
            "Nouns": ["Significant sleep disturbance (insomnia/hypersomnia/parasomnia/circadian disruption)", "Substance intoxication/withdrawal context", "Medication exposure context", "Clinically significant sleep problem"]
        },
        "Substance/Medication-Induced Sexual Dysfunction": {
            "Synonyms": ["Drug-Induced Sexual Problems", "Medication-Caused Sexual Difficulties"],
            "Verbs": ["Experience (clinically significant sexual dysfunction after substance intoxication/withdrawal or medication exposure)", "Report (impaired sexual desire/arousal/orgasm/pain linked to substance/medication)"],
            "Nouns": ["Clinically significant sexual dysfunction", "Impaired desire", "Impaired arousal", "Orgasmic dysfunction", "Sexual pain", "Substance intoxication/withdrawal context", "Medication exposure context"]
        },
        "Substance/Medication-Induced Neurocognitive Disorder": { # For Mild/Major NCD due to substances
            "Synonyms": ["Drug-Induced Cognitive Impairment", "Alcoholic Dementia (example)", "Medication-Caused Cognitive Deficits"],
            "Verbs": ["Exhibit (significant cognitive decline from previous level in one or more domains after substance use/medication exposure)", "Experience (cognitive deficits interfering with independence/daily activities)"],
            "Nouns": ["Significant cognitive decline (attention/executive function/learning/memory/language/perceptual-motor/social cognition)", "Substance use history consistent with etiology", "Medication exposure consistent with etiology", "Impairment in everyday activities (for Major NCD)", "Clinically significant cognitive deficits"]
        },
        "Substance/Medication-Induced Delirium": { # SCID screens for delirium
            "Synonyms": ["Drug-Induced Confusional State", "Medication-Caused Delirium"],
            "Verbs": ["Develop (disturbance in attention/awareness/cognition rapidly after substance intoxication/withdrawal or medication exposure)", "Exhibit (fluctuating severity of cognitive impairment)"],
            "Nouns": ["Disturbance in attention and awareness", "Rapid onset", "Fluctuating course", "Additional cognitive disturbance (memory/disorientation/language/visuospatial/perception)", "Direct physiological consequence of substance/medication"]
        }
    },
    "Neurocognitive Disorders": {  # Factor (DSM-5-TR Chapter 17)
        "Delirium": { # Adjective (DisorderName)
            "Synonyms": ["Acute Confusional State", "Encephalopathy (if underlying brain dysfunction)", "Toxic Psychosis (if substance-induced, less precise)"],
            "Verbs": [
                "Develop (disturbance in attention and awareness over short period)", 
                "Exhibit (fluctuating severity of cognitive disturbance)", 
                "Show (additional disturbance in cognition like memory deficit, disorientation, language, visuospatial ability, or perception)",
                "Evidence (disturbance as direct physiological consequence of another medical condition, substance intoxication/withdrawal, or toxin exposure)"
            ],
            "Nouns": [
                "Disturbance in attention (i.e., reduced ability to direct, focus, sustain, and shift attention)", 
                "Disturbance in awareness (reduced orientation to the environment)", 
                "Rapid onset (usually hours to a few days)", 
                "Fluctuating course (severity tends to fluctuate during the day)", 
                "Additional cognitive disturbance (e.g., memory deficit, disorientation, language, visuospatial ability, or perception like hallucinations/illusions)",
                "Direct physiological consequence (of another medical condition, substance intoxication or withdrawal, or exposure to a toxin)",
                "Multiple etiologies (possible)"
            ]
        },
        "Major Neurocognitive Disorder": { # Adjective (DisorderName) - General category, etiology specified separately
            "Synonyms": ["Dementia (older term, still used colloquially)", "Significant Cognitive Decline", "Severe Cognitive Impairment"],
            "Verbs": [
                "Demonstrate (significant cognitive decline from a previous level of performance in one or more cognitive domains)",
                "Interfere (with independence in everyday activities due to cognitive deficits)",
                "Require (assistance with complex instrumental activities of daily living)",
                "Report (concern about significant cognitive decline by individual, informant, or clinician)"
            ],
            "Nouns": [
                "Evidence of significant cognitive decline (from a previous level in one or more domains: complex attention, executive function, learning and memory, language, perceptual-motor, or social cognition)",
                "Concern from the individual, a knowledgeable informant, or the clinician (regarding significant cognitive decline)",
                "Substantial impairment in cognitive performance (preferably documented by standardized neuropsychological testing or quantified clinical assessment)",
                "Interference with independence in everyday activities (e.g., requiring assistance with complex IADLs like paying bills or managing medications)",
                "Cognitive deficits not occurring exclusively in context of delirium",
                "Cognitive deficits not better explained by another mental disorder"
            ]
        },
        "Mild Neurocognitive Disorder": { # Adjective (DisorderName) - General category, etiology specified separately
            "Synonyms": ["Mild Cognitive Impairment (MCI - often used, though NCD is broader)", "Modest Cognitive Decline", "Early Stage Cognitive Impairment"],
            "Verbs": [
                "Demonstrate (modest cognitive decline from a previous level of performance in one or more cognitive domains)",
                "Not interfere (with capacity for independence in everyday activities, though greater effort/strategies may be required)",
                "Report (concern about mild cognitive decline by individual, informant, or clinician)"
            ],
            "Nouns": [
                "Evidence of modest cognitive decline (from a previous level in one or more domains: complex attention, executive function, learning and memory, language, perceptual-motor, or social cognition)",
                "Concern from the individual, a knowledgeable informant, or the clinician (regarding mild cognitive decline)",
                "Modest impairment in cognitive performance (preferably documented by standardized neuropsychological testing or quantified clinical assessment)",
                "No interference with independence in everyday activities (complex IADLs like paying bills or managing medications are preserved, but may take greater effort, compensatory strategies, or accommodation)",
                "Cognitive deficits not occurring exclusively in context of delirium",
                "Cognitive deficits not better explained by another mental disorder"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Alzheimer's Disease": { # Adjective (DisorderName)
            "Synonyms": ["Alzheimer's Dementia (for Major NCD)", "Early Alzheimer's (for Mild NCD)", "AD"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)", 
                "Exhibit (insidious onset and gradual progression of impairment in one or more cognitive domains, typically memory and learning first)",
                "Show (evidence of Alzheimer's genetic mutation or biomarker evidence for probable AD diagnosis)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Insidious onset", "Gradual progression of cognitive impairment",
                "Probable Alzheimer's disease (if evidence of AD genetic mutation or biomarkers like CSF amyloid/tau or positive PET amyloid/tau imaging)", 
                "Possible Alzheimer's disease (if no genetic/biomarker evidence but typical clinical presentation without other etiologies)",
                "Impairment in learning and memory (typically prominent early feature)", "Steady decline in other cognitive domains (e.g., language, visuospatial function, executive function)"
            ]
        },
        "Major or Mild Vascular Neurocognitive Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Vascular Dementia (for Major NCD)", "Multi-infarct Dementia (older term)", "Vascular Cognitive Impairment (VCI)"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)", 
                "Establish (temporal relationship between cerebrovascular event(s) and onset/worsening of cognitive deficits)",
                "Show (evidence of cerebrovascular disease from history, physical examination, and/or neuroimaging)",
                "Exhibit (decline prominent in complex attention or frontal-executive function)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Onset of cognitive deficits temporally related to one or more cerebrovascular events",
                "Evidence for decline prominent in complex attention (including processing speed) and/or frontal-executive function",
                "Evidence of cerebrovascular disease (from neuroimaging indicating infarcts, white matter ischemic lesions, or clinical history of stroke(s))",
                "Stepwise decline (common but not required)", "Fluctuating course (sometimes observed)", "Focal neurological signs (often present)"
            ]
        },
        "Major or Mild Neurocognitive Disorder with Lewy Bodies": { # Adjective (DisorderName)
            "Synonyms": ["Lewy Body Dementia (LBD - for Major NCD)", "Dementia with Lewy Bodies (DLB)"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)", 
                "Exhibit (fluctuating cognition with pronounced variations in attention and alertness)", 
                "Have (recurrent, well-formed visual hallucinations)", 
                "Develop (spontaneous features of parkinsonism, with onset at or subsequent to cognitive decline)",
                "Show (REM sleep behavior disorder as a suggestive feature)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Insidious onset", "Gradual progression",
                "Core diagnostic features: Fluctuating cognition (with pronounced variations in attention/alertness); Recurrent visual hallucinations (typically well-formed and detailed); Spontaneous features of parkinsonism (with onset at or subsequent to cognitive decline)",
                "Suggestive diagnostic features: REM sleep behavior disorder; Severe neuroleptic sensitivity", "Repeated falls", "Syncope", "Transient, unexplained loss of consciousness"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Parkinson's Disease": { # Adjective (DisorderName)
            "Synonyms": ["Parkinson's Disease Dementia (PDD - for Major NCD)", "Cognitive Impairment in Parkinson's"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Have (diagnosed Parkinson's disease established prior to NCD onset)",
                "Exhibit (insidious onset and gradual progression of cognitive decline after Parkinson's diagnosis)",
                "Show (deficits typically in executive function, attention, visuospatial skills, and memory retrieval)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Diagnosed Parkinson's disease (preceding NCD onset by at least 1 year typically)",
                "Insidious onset", "Gradual progression of cognitive impairment",
                "Characteristic cognitive profile (prominent executive dysfunction, visuospatial deficits, attentional problems, memory retrieval difficulties more than encoding deficits)",
                "Fluctuating attention (may occur)", "Visual hallucinations (may occur, especially with medication)", "Apathy", "Depression", "Anxiety"
            ]
        },
        "Major or Mild Frontotemporal Neurocognitive Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Frontotemporal Dementia (FTD)", "Pick's Disease (a specific pathology)", "Behavioral Variant FTD (bvFTD)", "Primary Progressive Aphasia (PPA - language variant)"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Exhibit (insidious onset and gradual progression of behavioral or language changes)",
                "Present with (behavioral variant involving decline in social cognition/executive abilities OR language variant involving decline in language ability)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Insidious onset", "Gradual progression",
                "Behavioral variant criteria: (Three or more) Behavioral disinhibition (e.g., socially inappropriate behavior, loss of manners); Apathy or inertia; Loss of sympathy or empathy; Perseverative, stereotyped or compulsive/ritualistic behavior; Hyperorality and dietary changes. Prominent decline in social cognition and/or executive abilities.",
                "Language variant criteria: Prominent decline in language ability (in speech production, word finding, object naming, grammar, or word comprehension). Relative sparing of learning/memory and perceptual-motor function initially."
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Traumatic Brain Injury": { # Adjective (DisorderName)
            "Synonyms": ["Post-TBI Cognitive Impairment", "Dementia Pugilistica (related to repeated TBI, Chronic Traumatic Encephalopathy)"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Have (history of one or more traumatic brain injuries (TBI) with loss of consciousness, posttraumatic amnesia, disorientation/confusion, or neurological signs)",
                "Present (with neurocognitive deficits immediately after TBI or when consciousness is regained, and persisting past the acute post-injury period)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Evidence of a traumatic brain injury (TBI) of sufficient severity to be a plausible cause",
                "Neurocognitive disorder presents immediately after the TBI or after recovery of consciousness and persists past the acute post-injury period",
                "Commonly affected cognitive domains: Complex attention, executive function, learning and memory, processing speed", 
                "Associated symptoms: Irritability, apathy, anxiety, depression, personality changes (e.g., emotional lability, aggression), headache, sleep disturbance, dizziness, photosensitivity"
            ]
        },
        "Substance/Medication-Induced Major or Mild Neurocognitive Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Drug-Induced Dementia/Cognitive Impairment", "Alcohol-Related Dementia", "Medication-Caused Cognitive Decline", "Persistent Substance-Induced NCD"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Relate (cognitive deficits etiologically to persistent effects of substance use, intoxication, or withdrawal, or medication exposure)",
                "Document (temporal course of cognitive deficits consistent with timing of substance/medication use and persistence beyond typical intoxication/withdrawal period)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder",
                "Cognitive deficits persist beyond the usual duration of intoxication and acute withdrawal (for substances of abuse)",
                "Involved substance or medication and duration/extent of use are capable of producing the neurocognitive impairment",
                "Temporal course of neurocognitive deficits is consistent with timing of substance use/cessation or medication initiation/cessation",
                "Commonly affected cognitive domains (vary by substance, e.g., memory and executive functions for alcohol, attention/processing speed for others)",
                "Not attributable to NCD due to another medical condition or another mental disorder"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to HIV Infection": { # Adjective (DisorderName)
            "Synonyms": ["HIV-Associated Neurocognitive Disorder (HAND)", "AIDS Dementia Complex (ADC - older term, for severe cases)"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Have (documented HIV infection)",
                "Attribute (cognitive deficits not better explained by non-HIV conditions like opportunistic infections, CNS lymphoma, or other medical conditions)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Documented HIV infection",
                "Neurocognitive impairment not better explained by non-HIV-related conditions (e.g., opportunistic brain infection, CNS lymphoma, cerebrovascular disease, substance use)",
                "Characteristic cognitive profile (often subcortical pattern: impaired executive function, slowed processing speed, impaired attention, difficulties with learning new information, motor slowing)",
                "Associated features: Apathy, social withdrawal, depression, irritability, motor symptoms (e.g., clumsiness, tremor, weakness)"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Prion Disease": { # Adjective (DisorderName)
            "Synonyms": ["Creutzfeldt-Jakob Disease (CJD)", "Rapidly Progressive Dementia due to Prions", "Spongiform Encephalopathy Cognitive Effects"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Exhibit (insidious onset and rapid progression of cognitive decline)",
                "Develop (motor features such as myoclonus or ataxia, or other neurological signs)",
                "Show (biomarker evidence or genetic mutation indicative of prion disease for probable diagnosis)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Insidious onset", "Rapidly progressive course (typically leading to Major NCD within months)",
                "Motor features (e.g., myoclonus, ataxia, parkinsonism)", "Behavioral or mood changes (e.g., apathy, depression, anxiety, irritability)",
                "Probable prion disease (if characteristic EEG findings, positive 14-3-3 in CSF, specific MRI lesions, or pathogenic prion protein gene mutation)",
                "Definite prion disease (if confirmed by neuropathological examination or specific genetic testing)"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Huntington's Disease": { # Adjective (DisorderName)
            "Synonyms": ["Huntington's Chorea Cognitive Decline", "Dementia in Huntington's Disease"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Have (clinically established Huntington's disease, or risk for HD based on genetic testing or family history)",
                "Exhibit (insidious onset and gradual progression of cognitive and motor changes)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder", "Insidious onset", "Gradual progression",
                "Clinically established Huntington's disease or risk based on positive genetic test for CAG repeat expansion in HTT gene",
                "Prominent decline in executive function (e.g., planning, decision-making, cognitive flexibility)",
                "Slowed processing speed", "Impaired attention", "Memory retrieval difficulties (recognition often better than free recall)",
                "Motor symptoms (chorea, bradykinesia, dystonia, impaired coordination)",
                "Psychiatric symptoms (depression, apathy, irritability, anxiety, obsessions, psychosis)"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Another Medical Condition": { # Adjective (DisorderName)
            "Synonyms": ["Secondary Cognitive Impairment (due to specified illness)", "NCD from General Medical Condition"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Establish (a direct pathophysiological link between the NCD and another medical condition not listed elsewhere)",
                "Show (temporal association or clinical evidence connecting the medical condition to the cognitive decline)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder",
                "Evidence from history, physical examination, or laboratory findings (that the NCD is a direct pathophysiological consequence of another medical condition, e.g., endocrine disorders, metabolic conditions, vitamin deficiencies, organ failure, autoimmune diseases, neurological conditions not otherwise specified)",
                "Temporal relationship (between onset/exacerbation of medical condition and NCD)",
                "Cognitive profile consistent with the effects of the specific medical condition",
                "NCD not better explained by another mental disorder or delirium"
            ]
        },
        "Major or Mild Neurocognitive Disorder due to Multiple Etiologies": { # Adjective (DisorderName)
            "Synonyms": ["Mixed Dementia", "Cognitive Impairment from Combined Causes", "NCD with Multiple Pathologies"],
            "Verbs": [
                "Meet (criteria for Major or Mild NCD)",
                "Establish (evidence for more than one etiological medical condition significantly contributing to the NCD)",
                "Identify (each contributing etiology, e.g., Alzheimer's disease plus vascular disease)"
            ],
            "Nouns": [
                "Criteria met for Major or Mild Neurocognitive Disorder",
                "Evidence from history, physical examination, or laboratory/neuroimaging findings (that the NCD is the consequence of more than one etiological process)",
                "Each identified etiology (e.g., Alzheimer's disease, vascular disease, Lewy bodies, TBI) independently capable of causing NCD or strong evidence of its contribution",
                "Cognitive deficits characteristic of the combined effects of the multiple etiologies (or one predominates)"
            ]
        },
        "Unspecified Neurocognitive Disorder": { # Adjective (DisorderName)
            "Synonyms": ["Cognitive Impairment NOS (Not Otherwise Specified)", "Dementia NOS", "Undetermined NCD"],
            "Verbs": [
                "Experience (clinically significant cognitive decline causing impairment)", 
                "Not meet (full criteria for any specific Major or Mild NCD category or its etiological subtypes)",
                "Lack (sufficient information to make a more specific NCD diagnosis or determine etiology)"
            ],
            "Nouns": [
                "Clinically significant cognitive decline (from a previous level of functioning)", 
                "Symptoms characteristic of a neurocognitive disorder but do not meet full criteria for any specific type",
                "Insufficient information to determine etiology or make a more specific diagnosis (e.g., in emergency settings, or early in evaluation)",
                "Atypical presentation of NCD (where clinician chooses not to specify further)"
            ]
        }
    },
            scid_dataset_continued = {
    "Personality Disorders": {  # Factor (DSM-5-TR Chapter 18)
        "Paranoid Personality Disorder": {
            "Synonyms": ["Distrustfulness", "Suspiciousness", "Paranoid Traits"],
            "Verbs": ["Suspect", "Doubt", "Fear", "Interpret", "Hold grudges"],
            "Nouns": ["Suspicion", "Distrust", "Paranoia", "Hostility", "Hypervigilance"]
        },
        "Schizoid Personality Disorder": {
            "Synonyms": ["Social Detachment", "Emotional Coldness", "Solitary Personality"],
            "Verbs": ["Withdraw", "Avoid", "Prefer", "Lack", "Show indifference"],
            "Nouns": ["Isolation", "Detachment", "Indifference", "Coldness", "Solitude"]
        },
        "Schizotypal Personality Disorder": {
            "Synonyms": ["Odd Beliefs", "Magical Thinking", "Social Anxiety"],
            "Verbs": ["Exhibit", "Believe", "Experience", "Behave oddly", "Feel discomfort"],
            "Nouns": ["Eccentricity", "Oddness", "Magical thinking", "Perceptual distortions", "Social anxiety"]
        },
        "Antisocial Personality Disorder": {
            "Synonyms": ["Sociopathy", "Psychopathy", "Disregard for others"],
            "Verbs": ["Manipulate", "Exploit", "Violate", "Deceive", "Disregard"],
            "Nouns": ["Deceitfulness", "Impulsivity", "Aggression", "Irresponsibility", "Lack of remorse"]
        },
        "Borderline Personality Disorder": {
            "Synonyms": ["Emotionally Unstable", "Impulsive Behavior", "Fear of Abandonment"],
            "Verbs": ["Experience", "Feel empty", "Idealize", "Devalue", "Act impulsively"],
            "Nouns": ["Instability", "Emptiness", "Abandonment fears", "Impulsivity", "Self-harm"]
        },
        "Histrionic Personality Disorder": {
            "Synonyms": ["Attention Seeking", "Excessive Emotionality", "Dramatic Behavior"],
            "Verbs": ["Seek attention", "Act dramatically", "Exaggerate", "Seduce", "Crave approval"],
            "Nouns": ["Attention seeking", "Dramatic displays", "Excessive emotionality", "Seductiveness", "Suggestibility"]
        },
        "Narcissistic Personality Disorder": {
            "Synonyms": ["Grandiosity", "Self-Importance", "Lack of Empathy"],
            "Verbs": ["Demand admiration", "Expect entitlement", "Exploit", "Show arrogance", "Exaggerate achievements"],
            "Nouns": ["Grandiosity", "Entitlement", "Arrogance", "Exploitation", "Lack of empathy"]
        },
        "Avoidant Personality Disorder": {
            "Synonyms": ["Social Inhibition", "Feelings of Inadequacy", "Hypersensitivity"],
            "Verbs": ["Avoid", "Fear rejection", "Feel inadequate", "Hesitate", "Withdraw"],
            "Nouns": ["Avoidance", "Hypersensitivity", "Inadequacy", "Social inhibition", "Fear of rejection"]
        },
        "Dependent Personality Disorder": {
            "Synonyms": ["Excessive Reliance", "Clinginess", "Fear of Separation"],
            "Verbs": ["Rely on others", "Cling", "Seek reassurance", "Submit", "Fear abandonment"],
            "Nouns": ["Dependence", "Clinginess", "Submissiveness", "Helplessness", "Fear of separation"]
        },
        "Obsessive-Compulsive Personality Disorder": {
            "Synonyms": ["Perfectionism", "Rigidity", "Control Obsession"],
            "Verbs": ["Insist on perfection", "Control", "Rigidly adhere", "Focus on details", "Resist delegating"],
            "Nouns": ["Perfectionism", "Rigidity", "Control", "Orderliness", "Preoccupation with details"]
        }
    },

    "Paraphilic Disorders": {  # Factor (DSM-5-TR Chapter 19)
        "Voyeuristic Disorder": {
            "Synonyms": ["Peeping Behavior", "Secret Observation", "Voyeurism"],
            "Verbs": ["Spy", "Watch secretly", "Experience arousal", "Intrude", "Observe secretly"],
            "Nouns": ["Voyeurism", "Observation", "Peeping", "Intrusion", "Secret watching"]
        },
        "Exhibitionistic Disorder": {
            "Synonyms": ["Exposing oneself", "Indecent Exposure", "Exhibitionism"],
            "Verbs": ["Expose", "Flash", "Show oneself", "Seek reaction", "Experience arousal"],
            "Nouns": ["Exhibitionism", "Exposure", "Flashing", "Arousal", "Reaction seeking"]
        },
        "Frotteuristic Disorder": {
            "Synonyms": ["Touching without Consent", "Groping", "Frotteurism"],
            "Verbs": ["Rub against", "Touch", "Grope", "Seek contact", "Experience arousal"],
            "Nouns": ["Frotteurism", "Unwanted touching", "Rubbing", "Arousal", "Non-consensual contact"]
        },
        "Sexual Masochism Disorder": {
            "Synonyms": ["Receiving Pain", "Masochism", "Humiliation Seeking"],
            "Verbs": ["Seek pain", "Enjoy suffering", "Desire humiliation", "Engage in masochistic acts", "Experience arousal"],
            "Nouns": ["Masochism", "Pain", "Suffering", "Humiliation", "Submission"]
        },
        "Sexual Sadism Disorder": {
            "Synonyms": ["Inflicting Pain", "Sadism", "Dominance"],
            "Verbs": ["Inflict pain", "Dominate", "Humiliate", "Control", "Experience arousal"],
            "Nouns": ["Sadism", "Pain infliction", "Dominance", "Control", "Cruelty"]
        },
        "Pedophilic Disorder": {
            "Synonyms": ["Child Attraction", "Pedophilia", "Sexual Interest in Minors"],
            "Verbs": ["Desire children", "Feel attraction", "Engage sexually", "Fantasize", "Experience arousal"],
            "Nouns": ["Pedophilia", "Attraction to minors", "Fantasies", "Abuse", "Arousal"]
        },
        "Fetishistic Disorder": {
            "Synonyms": ["Fetishism", "Object Attraction", "Nonliving Object Desire"],
            "Verbs": ["Fixate", "Desire objects", "Fantasize", "Rely on fetish", "Experience arousal"],
            "Nouns": ["Fetishism", "Object fixation", "Nonliving object", "Arousal", "Dependency"]
        },
        "Transvestic Disorder": {
            "Synonyms": ["Cross-Dressing", "Transvestism", "Clothing Fetish"],
            "Verbs": ["Dress", "Cross-dress", "Wear clothing", "Fantasize", "Experience arousal"],
            "Nouns": ["Transvestism", "Cross-dressing", "Clothing fetish", "Arousal", "Fantasies"]
        }
    },

    "Medication-Induced Movement Disorders and Other Adverse Effects of Medication": {  # Factor (DSM-5-TR Chapter 20)
        "Neuroleptic-Induced Parkinsonism": {
            "Synonyms": ["Drug-Induced Parkinsonism", "Medication-Induced Movement Disorder"],
            "Verbs": ["Exhibit rigidity", "Show tremor", "Experience bradykinesia", "Develop movement slowing"],
            "Nouns": ["Parkinsonism", "Rigidity", "Tremor", "Bradykinesia", "Movement slowing"]
        },
        "Tardive Dyskinesia": {
            "Synonyms": ["Involuntary Movements", "Persistent Dyskinesia", "Medication-Induced Dyskinesia"],
            "Verbs": ["Experience", "Show involuntary movements", "Develop dyskinesia", "Manifest symptoms"],
            "Nouns": ["Dyskinesia", "Involuntary movements", "Choreoathetoid movements", "Medication effects"]
        }
        # Additional conditions follow similar patterns
    },

    "Other Conditions That May Be a Focus of Clinical Attention": {  # Factor (DSM-5-TR Chapter 21)
        "Relational Problems": {
            "Synonyms": ["Relationship Issues", "Marital Conflict", "Family Conflict"],
            "Verbs": ["Argue", "Conflict", "Struggle", "Miscommunicate", "Disagree"],
            "Nouns": ["Conflict", "Relationship stress", "Marital discord", "Family tension", "Communication problems"]
        },
        "Abuse and Neglect": {
            "Synonyms": ["Mistreatment", "Physical Abuse", "Neglect"],
            "Verbs": ["Abuse", "Neglect", "Harm", "Mistreat", "Endanger"],
            "Nouns": ["Abuse", "Neglect", "Maltreatment", "Harm", "Endangerment"]
        }
        # Additional conditions follow similar patterns
    }
}
# Out:
#         Disorder                    Factor                     Adjective  \
# 0  Mood Episodes  Major Depressive Episode                Depressed Mood
# 1  Mood Episodes  Major Depressive Episode                Depressed Mood
# 2  Mood Episodes  Major Depressive Episode                Depressed Mood
# 3  Mood Episodes  Major Depressive Episode  Loss of Interest or Pleasure
# 4  Mood Episodes  Major Depressive Episode  Loss of Interest or Pleasure
#
#      Synonym        Verb         Noun ICD-10 Code
# 0        Sad        Feel      Despair       F32.9
# 1   Hopeless  Experience       Sorrow       F32.9
# 2        Low      Suffer      Sadness       F32.9
# 3  Anhedonia        Lose  Disinterest       F32.9
# 4                   Lack       Apathy       F32.9

# %%
```python
scid_dataset = {
    # Chapter 1: Neurodevelopmental Disorders
    "Neurodevelopmental Disorders": {
        "Intellectual Disability (Intellectual Developmental Disorder)": {
            "Synonyms": ["Cognitive Impairment", "Mental Retardation", "Developmental Delay"],
            "Verbs": ["Exhibit", "Demonstrate", "Experience", "Show", "Struggle with"],
            "Nouns": ["Deficits", "Limitations", "Impairment", "Challenges", "Difficulties"]
        },
        # ... other Neurodevelopmental Disorders
    },

    # Chapter 2: Schizophrenia Spectrum and Other Psychotic Disorders
    "Schizophrenia Spectrum and Other Psychotic Disorders": {
        "Schizotypal (Personality) Disorder": {
            "Synonyms": ["Eccentric Personality", "Odd Personality", "Schizotypy"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Eccentricity", "Oddity", "Peculiarity", "Distortions", "Deficits"]
        },
        # ... other Psychotic Disorders
    },

    # Chapter 3: Bipolar and Related Disorders
    "Bipolar and Related Disorders": {
        "Bipolar I Disorder": {
            "Synonyms": ["Bipolar Disorder", "Mania", "Manic-Depressive Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        # ... other Bipolar Disorders
    },

    # Chapter 4: Depressive Disorders
    "Depressive Disorders": {
        "Major Depressive Disorder": {
            "Synonyms": ["MDD", "Clinical Depression", "Unipolar Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Sleep Disturbance", "Appetite Changes", "Fatigue"]
        },
        # ... other Depressive Disorders
    },

    # Chapter 5: Anxiety Disorders
    "Anxiety Disorders": {
        "Generalized Anxiety Disorder (GAD)": {
            "Synonyms": ["GAD", "Excessive Worry", "Chronic Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Apprehension"]
        },
        # ... other Anxiety Disorders
    },

    # Chapter 6: Obsessive-Compulsive and Related Disorders
    "Obsessive-Compulsive and Related Disorders": {
        "Obsessive-Compulsive Disorder (OCD)": {
            "Synonyms": ["OCD", "Obsessions and Compulsions", "Obsessive Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Rituals"]
        },
        # ... other OCRD
    },

    # Chapter 7: Trauma- and Stressor-Related Disorders
    "Trauma- and Stressor-Related Disorders": {
        "Posttraumatic Stress Disorder (PTSD)": {
            "Synonyms": ["PTSD", "Trauma Disorder", "Stress Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Memories", "Avoidance", "Hyperarousal", "Negative Mood", "Symptoms"]
        },
        # ... other Trauma Disorders
    },

    # Chapter 8: Dissociative Disorders
    "Dissociative Disorders": {
        "Dissociative Identity Disorder": {
            "Synonyms": ["DID", "Multiple Personality Disorder", "Identity Fragmentation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Multiple Identities", "Memory Gaps", "Amnesia", "Dissociation", "Alters"]
        },
        # ... other Dissociative Disorders
    },

    # Chapter 9: Somatic Symptom and Related Disorders
    "Somatic Symptom and Related Disorders": {
        "Somatic Symptom Disorder": {
            "Synonyms": ["Somatization Disorder", "Somatic Symptoms", "Physical Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Bodily Distress", "Physical Complaints", "Health Anxiety", "Worry"]
        },
        # ... other Somatic Disorders
    },

    # Chapter 10: Feeding and Eating Disorders
    "Feeding and Eating Disorders": {
        "Anorexia Nervosa": {
            "Synonyms": ["Anorexia", "Restrictive Eating", "Fear of Weight Gain"],
            "Verbs": ["Restrict", "Fear", "Avoid", "Lose Weight", "Control"],
            "Nouns": ["Weight", "Body Image", "Food", "Eating", "Restriction"]
        },
        # ... other Eating Disorders
    },

    # Chapter 11: Elimination Disorders
    "Elimination Disorders": {
        "Enuresis": {
            "Synonyms": ["Bedwetting", "Urinary Incontinence", "Nocturnal Enuresis"],
            "Verbs": ["Wet", "Urinate", "Void", "Leak", "Experience"],
            "Nouns": ["Urine", "Bedwetting", "Incontinence", "Urination", "Accidents"]
        },
        "Encopresis": {
            "Synonyms": ["Fecal Incontinence", "Soiling", "Bowel Incontinence"],
            "Verbs": ["Defecate", "Soil", "Pass", "Leak", "Experience"],
            "Nouns": ["Feces", "Incontinence", "Soiling", "Bowel Movements", "Accidents"]
        }
    },

    # Chapter 12: Sleep-Wake Disorders
    "Sleep-Wake Disorders": {
        "Insomnia Disorder": {
            "Synonyms": ["Insomnia", "Sleeplessness", "Nonrestorative Sleep"],
            "Verbs": ["Struggle to sleep", "Wake up early", "Experience difficulty falling/staying asleep"],
            "Nouns": ["Difficulty initiating sleep", "Nonrestorative sleep", "Daytime fatigue", "Impaired functioning"]
        },
        # ... other Sleep-Wake Disorders
    },

    # Chapter 13: Sexual Dysfunctions
    "Sexual Dysfunctions": {
        "Erectile Disorder": {
            "Synonyms": ["Impotence", "Erectile Dysfunction", "Difficulty Achieving/Maintaining Erection"],
            "Verbs": ["Fail to obtain/maintain erection", "Experience decreased rigidity", "Report distress"],
            "Nouns": ["Erectile difficulty", "Insufficient rigidity", "Performance anxiety"]
        },
        # ... other Sexual Dysfunctions
    },

    # Chapter 14: Gender Dysphoria
    "Gender Dysphoria": {
        "Gender Dysphoria in Adolescents and Adults": {
            "Synonyms": ["Gender Incongruence", "Transgender Identity Disorder (historic)"],
            "Verbs": ["Experience marked incongruence", "Express desire for other gender characteristics"],
            "Nouns": ["Clinically significant distress", "Impairment in functioning"]
        }
    },

    # Chapter 15: Disruptive, Impulse-Control, and Conduct Disorders
    "Disruptive, Impulse-Control, and Conduct Disorders": {
        "Oppositional Defiant Disorder": {
            "Synonyms": ["ODD", "Defiant Behavior", "Argumentativeness"],
            "Verbs": ["Argue with authority", "Defy rules", "Lose temper"],
            "Nouns": ["Angry mood", "Defiant behavior", "Vindictiveness"]
        },
        # ... other DICCD
    },

    # Chapter 16: Substance-Related and Addictive Disorders
    "Substance-Related and Addictive Disorders": {
        "Alcohol Use Disorder": {
            "Synonyms": ["Alcoholism", "Alcohol Dependence", "Problematic Alcohol Use"],
            "Verbs": ["Consume alcohol in larger amounts than intended", "Experience craving", "Develop tolerance"],
            "Nouns": ["Craving", "Tolerance", "Withdrawal symptoms"]
        },
        # ... other Substance Disorders
    },

    # Chapter 17: Neurocognitive Disorders
    "Neurocognitive Disorders": {
        "Major Neurocognitive Disorder": {
            "Synonyms": ["Dementia", "Significant Cognitive Decline"],
            "Verbs": ["Demonstrate cognitive decline", "Interfere with independence"],
            "Nouns": ["Memory impairment", "Executive dysfunction"]
        },
        # ... other NCD categories
    },

    # Chapter 18: Personality Disorders
    "Personality Disorders": {
        "Borderline Personality Disorder": {
            "Synonyms": ["Emotionally Unstable", "Impulsive Behavior"],
            "Verbs": ["Act impulsively", "Fear abandonment"],
            "Nouns": ["Instability", "Self-harm"]
        },
        # ... other Personality Disorders
    },

    # Chapter 19: Paraphilic Disorders
    "Paraphilic Disorders": {
        "Voyeuristic Disorder": {
            "Synonyms": ["Voyeurism", "Peeping Behavior"],
            "Verbs": ["Spy", "Watch secretly"],
            "Nouns": ["Observation", "Intrusion"]
        },
        # ... other Paraphilic Disorders
    },

    # Chapter 20: Medication-Induced Movement Disorders and Other Adverse Effects of Medication
    "Medication-Induced Movement Disorders and Other Adverse Effects": {
        "Tardive Dyskinesia": {
            "Synonyms": ["Involuntary Movements", "Persistent Dyskinesia"],
            "Verbs": ["Experience dyskinesia", "Show involuntary movements"],
            "Nouns": ["Choreoathetoid movements", "Medication effects"]
        },
        # ... other Medication-Induced Movement Disorders
    },

    # Chapter 21: Other Conditions That May Be a Focus of Clinical Attention
    "Other Conditions That May Be a Focus of Clinical Attention": {
        "Relational Problems": {
            "Synonyms": ["Relationship Issues", "Family Conflict"],
            "Verbs": ["Argue", "Miscommunicate"],
            "Nouns": ["Conflict", "Tension"]
        },
        "Abuse and Neglect": {
            "Synonyms": ["Maltreatment", "Neglect"],
            "Verbs": ["Abuse", "Neglect"],
            "Nouns": ["Harm", "Endangerment"]
        },
        # ... other conditions
    }
}
```

# %%
```python
scid_dataset = {
    # Chapter 1: Neurodevelopmental Disorders
    "Neurodevelopmental Disorders": {
        "Intellectual Disability (Intellectual Developmental Disorder)": {
            "Synonyms": ["Cognitive Impairment", "Mental Retardation", "Developmental Delay"],
            "Verbs": ["Exhibit", "Demonstrate", "Experience", "Show", "Struggle with"],
            "Nouns": ["Deficits", "Limitations", "Impairment", "Challenges", "Difficulties"]
        },
        "Global Developmental Delay": {
            "Synonyms": ["Developmental Delay", "Delayed Development", "Developmental Disabilities"],
            "Verbs": ["Demonstrate", "Show", "Exhibit", "Struggle with", "Experience"],
            "Nouns": ["Delays", "Limitations", "Impairment", "Difficulties", "Challenges"]
        },
        "Unspecified Intellectual Disability": {
            "Synonyms": ["Cognitive Impairment", "Developmental Delay", "Unspecified Delay"],
            "Verbs": ["Show", "Exhibit", "Struggle with", "Experience", "Demonstrate"],
            "Nouns": ["Impairment", "Delay", "Limitation", "Challenge", "Difficulty"]
        },
        "Language Disorder": {
            "Synonyms": ["Language Impairment", "Communication Disorder", "Language Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Experience", "Have"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Speech Sound Disorder": {
            "Synonyms": ["Articulation Disorder", "Phonological Disorder", "Speech Impairment"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Errors", "Limitations", "Challenges"]
        },
        "Childhood-Onset Fluency Disorder (Stuttering)": {
            "Synonyms": ["Stuttering", "Fluency Disorder", "Speech Hesitation"],
            "Verbs": ["Stutter", "Hesitate", "Repeat", "Prolong", "Block"],
            "Nouns": ["Stutter", "Hesitation", "Repetition", "Prolongation", "Block"]
        },
        "Social Communication Disorder": {
            "Synonyms": ["Pragmatic Communication Disorder", "Social Language Deficit", "Communication Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Deficits", "Impairment", "Limitations", "Challenges"]
        },
        "Other Specified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Unspecified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Specific Learning Disorder": {
            "Synonyms": ["Learning Disability", "Reading Disorder", "Dyslexia", "Mathematics Disorder", "Dyscalculia", "Disorder of Written Expression"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Impairment", "Deficit", "Limitation", "Challenge"]
        },
        "Developmental Coordination Disorder": {
            "Synonyms": ["Dyspraxia", "Motor Coordination Disorder", "Clumsiness"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Stereotypic Movement Disorder": {
            "Synonyms": ["Repetitive Movement Disorder", "Stereotypies", "Motor Stereotypies"],
            "Verbs": ["Exhibit", "Show", "Engage in", "Perform", "Demonstrate"],
            "Nouns": ["Movements", "Behaviors", "Stereotypies", "Repetitions", "Mannerisms"]
        },
        "Tourette's Disorder": {
            "Synonyms": ["Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Persistent (Chronic) Motor or Vocal Tic Disorder": {
            "Synonyms": ["Chronic Tic Disorder", "Persistent Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Provisional Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Transient Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Other Specified Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Atypical Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Unspecified Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Unspecified Tics", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        }
    },
    
    # Chapter 2: Schizophrenia Spectrum and Other Psychotic Disorders
    "Schizophrenia Spectrum and Other Psychotic Disorders": {
        "Schizotypal (Personality) Disorder": {
            "Synonyms": ["Eccentric Personality", "Odd Personality", "Schizotypy"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Eccentricity", "Oddity", "Peculiarity", "Distortions", "Deficits"]
        },
        "Delusional Disorder": {
            "Synonyms": ["Delusions", "Fixed Beliefs", "False Beliefs"],
            "Verbs": ["Experience", "Have", "Hold", "Believe", "Exhibit"],
            "Nouns": ["Delusions", "Beliefs", "Ideas", "Paranoia", "Suspicion"]
        },
        "Brief Psychotic Disorder": {
            "Synonyms": ["Brief Psychosis", "Psychotic Episode", "Transient Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophreniform Disorder": {
            "Synonyms": ["Schizophrenia-like Psychosis", "Short-term Schizophrenia", "Psychotic Episode"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophrenia": {
            "Synonyms": ["Psychosis", "Schizophrenia Spectrum Disorder", "Thought Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Delusions", "Hallucinations", "Disorganized Thinking", "Negative Symptoms", "Psychotic Symptoms"]
        },
        "Schizoaffective Disorder": {
            "Synonyms": ["Schizophrenia and Mood Disorder", "Psychotic and Affective Symptoms", "Mixed Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Mood Episodes", "Symptoms", "Delusions", "Hallucinations"]
        },
        "Other Specified Schizophrenia Spectrum and Other Psychotic Disorder": {
            "Synonyms": ["Atypical Psychosis", "Subthreshold Psychosis", "Unspecified Psychotic Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        },
        "Unspecified Schizophrenia Spectrum and Other Psychotic Disorder": {
            "Synonyms": ["Unspecified Psychosis", "Psychotic Symptoms", "Undifferentiated Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        }
    },
    
    # Chapter 3: Bipolar and Related Disorders
    "Bipolar and Related Disorders": {
        "Bipolar I Disorder": {
            "Synonyms": ["Bipolar Disorder", "Mania", "Manic-Depressive Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Bipolar II Disorder": {
            "Synonyms": ["Bipolar Disorder", "Hypomania", "Recurrent Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Hypomania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Cyclothymic Disorder": {
            "Synonyms": ["Cyclothymia", "Mood Instability", "Mild Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Swings", "Hypomanic Symptoms", "Depressive Symptoms", "Mood Instability", "Symptoms"]
        },
        "Substance/Medication-Induced Bipolar and Related Disorder": {
            "Synonyms": ["Substance-Induced Mood Disorder", "Medication-Induced Mood Disorder", "Secondary Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Bipolar and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Bipolar Disorder", "Medical Condition-Induced Mood Disorder", "Mood Disorder Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Other Specified Bipolar and Related Disorder": {
            "Synonyms": ["Atypical Bipolar Disorder", "Subthreshold Bipolar Disorder", "Unspecified Mood Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Unspecified Bipolar and Related Disorder": {
            "Synonyms": ["Unspecified Mood Disorder", "Bipolar Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        }
    },
    
    # Chapter 4: Depressive Disorders
    "Depressive Disorders": {
        "Disruptive Mood Dysregulation Disorder": {
            "Synonyms": ["DMDD", "Childhood Mood Disorder", "Temper Dysregulation"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Temper Outbursts", "Irritability", "Mood Dysregulation", "Emotional Lability", "Symptoms"]
        },
        "Major Depressive Disorder": {
            "Synonyms": ["MDD", "Clinical Depression", "Unipolar Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Sleep Disturbance", "Appetite Changes", "Fatigue"]
        },
        "Persistent Depressive Disorder (Dysthymia)": {
            "Synonyms": ["Dysthymia", "Chronic Depression", "Persistent Low Mood"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Low Self-Esteem", "Fatigue", "Hopelessness", "Symptoms"]
        },
        "Premenstrual Dysphoric Disorder (PMDD)": {
            "Synonyms": ["PMDD", "Premenstrual Mood Disorder", "Severe PMS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Lability", "Irritability", "Depressed Mood", "Anxiety", "Symptoms"]
        },
        "Substance/Medication-Induced Depressive Disorder": {
            "Synonyms": ["Substance-Induced Depression", "Medication-Induced Depression", "Secondary Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Depressive Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Depression", "Medical Condition-Induced Depression", "Depression Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Other Specified Depressive Disorder": {
            "Synonyms": ["Atypical Depression", "Subthreshold Depression", "Unspecified Depressive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Unspecified Depressive Disorder": {
            "Synonyms": ["Unspecified Depression", "Depressive Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        }
    },
        # Chapter 5: Anxiety Disorders
    "Anxiety Disorders": {
        "Separation Anxiety Disorder": {
            "Synonyms": ["Separation Anxiety", "Fear of Separation", "Attachment Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Distress", "Worry", "Symptoms"]
        },
        "Selective Mutism": {
            "Synonyms": ["Situational Mutism", "Social Mutism", "Non-speaking in Specific Situations"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Mutism", "Silence", "Anxiety", "Fear", "Inhibition"]
        },
        "Specific Phobia": {
            "Synonyms": ["Phobia", "Irrational Fear", "Specific Fear"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Fear", "Anxiety", "Avoidance", "Distress", "Symptoms"]
        },
        "Social Anxiety Disorder (Social Phobia)": {
            "Synonyms": ["Social Phobia", "Social Fear", "Performance Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Panic", "Symptoms"]
        },
        "Panic Disorder": {
            "Synonyms": ["Panic Attacks", "Anxiety Disorder", "Acute Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Panic Attacks", "Palpitations", "Sweating", "Shortness of Breath", "Fear"]
        },
        "Agoraphobia": {
            "Synonyms": ["Fear of Public Places", "Open Spaces Anxiety", "Crowd Phobia"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Avoidance", "Panic", "Distress", "Symptoms"]
        },
        "Generalized Anxiety Disorder (GAD)": {
            "Synonyms": ["GAD", "Worry Disorder", "Chronic Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Worry", "Tension", "Sleep Disturbance", "Fatigue", "Symptoms"]
        },
        "Substance/Medication-Induced Anxiety Disorder": {
            "Synonyms": ["Drug-Induced Anxiety", "Medication Anxiety", "Secondary Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Panic", "Tremor", "Insomnia", "Symptoms"]
        },
        "Anxiety Disorder Due to Another Medical Condition": {
            "Synonyms": ["Medical Anxiety", "Secondary Medical Anxiety", "Illness Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Somatic Symptoms", "Distress", "Symptoms"]
        },
        "Other Specified Anxiety Disorder": {
            "Synonyms": ["Atypical Anxiety", "Subthreshold Anxiety", "Unspecified Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Avoidance"]
        },
        "Unspecified Anxiety Disorder": {
            "Synonyms": ["Unspecified Anxiety", "Non-specific Anxiety", "Anxiety NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Avoidance"]
        }
    },

    # Chapter 6: Obsessive-Compulsive and Related Disorders
    "Obsessive-Compulsive and Related Disorders": {
        "Obsessive-Compulsive Disorder (OCD)": {
            "Synonyms": ["OCD", "Obsessions", "Compulsions"],
            "Verbs": ["Experience", "Perform", "Repeat", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Rituals"]
        },
        "Body Dysmorphic Disorder": {
            "Synonyms": ["BDD", "Body Image Disorder", "Dysmorphophobia"],
            "Verbs": ["Preoccupy", "Obsess", "Compensate", "Check", "Avoid"],
            "Nouns": ["Preoccupation", "Distress", "Appearance Concerns", "Rituals", "Checking"]
        },
        "Hoarding Disorder": {
            "Synonyms": ["Compulsive Hoarding", "Clutter Disorder", "Hoarding"],
            "Verbs": ["Collect", "Fail to Discard", "Acquire", "Save", "Avoid"],
            "Nouns": ["Clutter", "Difficulty Discarding", "Distress", "Acquisition", "Possessions"]
        },
        "Trichotillomania (Hair-Pulling) Disorder": {
            "Synonyms": ["Hair Pulling Disorder", "Trichotillomania", "Hair-Pulling"],
            "Verbs": ["Pull", "Experience Urges", "Compel", "Engage", "Resist"],
            "Nouns": ["Hair Pulling", "Urges", "Bald Patches", "Distress", "Consequences"]
        },
        "Excoriation (Skin-Picking) Disorder": {
            "Synonyms": ["Skin-Picking Disorder", "Dermatillomania", "Skin Excoriation"],
            "Verbs": ["Pick", "Scratch", "Compel", "Engage", "Resist"],
            "Nouns": ["Skin Lesions", "Urges", "Distress", "Scarring", "Complications"]
        },
        "Substance/Medication-Induced Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Drug-Induced OCD", "Medication-Caused Compulsions"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Medication Context", "Symptoms"]
        },
        "Obsessive-Compulsive and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Medical Condition-Induced OCD", "Secondary OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Medical Context", "Symptoms"]
        },
        "Other Specified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Atypical OCD", "Subthreshold OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Symptoms", "Impairment"]
        },
        "Unspecified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Unspecified OCD", "OCD NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Symptoms", "Impairment"]
        }
    },

    # Chapter 7: Trauma- and Stressor-Related Disorders
    "Trauma- and Stressor-Related Disorders": {
        "Posttraumatic Stress Disorder (PTSD)": {
            "Synonyms": ["PTSD", "Trauma Disorder", "Stress Disorder"],
            "Verbs": ["Experience", "Re-experience", "Avoid", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Memories", "Avoidance", "Hyperarousal", "Negative Mood", "Symptoms"]
        },
        "Acute Stress Disorder": {
            "Synonyms": ["ASD", "Acute Trauma Response", "Stress Reaction"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Symptoms", "Dissociation", "Avoidance", "Arousal Symptoms", "Distress"]
        },
        "Adjustment Disorders": {
            "Synonyms": ["Adjustment Disorder", "Stress Response Syndrome", "Situational Distress"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Emotional Symptoms", "Behavioral Symptoms", "Distress", "Impairment", "Reactions"]
        },
        "Other Specified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Atypical Trauma Disorder", "Subthreshold Stress Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Reactions", "Impairment", "Arousal"]
        },
        "Unspecified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Unspecified Trauma Disorder", "Stress Symptoms NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Reactions", "Impairment", "Arousal"]
        }
    },

    # Chapter 8: Dissociative Disorders
    "Dissociative Disorders": {
        "Dissociative Identity Disorder": {
            "Synonyms": ["DID", "Multiple Personality Disorder", "Identity Fragmentation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Multiple Identities", "Memory Gaps", "Amnesia", "Dissociation", "Alters"]
        },
        "Dissociative Amnesia": {
            "Synonyms": ["Psychogenic Amnesia", "Selective Amnesia", "Localized Amnesia"],
            "Verbs": ["Forget", "Have memory gaps", "Experience amnesia", "Show impairment", "Manifest dissociation"],
            "Nouns": ["Memory Loss", "Amnesia", "Fugue", "Identity Loss", "Dissociation"]
        },
        "Depersonalization/Derealization Disorder": {
            "Synonyms": ["Depersonalization", "Derealization", "Detachment Disorder"],
            "Verbs": ["Feel detached", "Perceive unreality", "Experience disconnection", "Show derealization", "Manifest depersonalization"],
            "Nouns": ["Detachment", "Unreality", "Distortion", "Dissociation", "Emotional Numbing"]
        },
        "Other Specified Dissociative Disorder": {
            "Synonyms": ["Atypical Dissociation", "Subthreshold Dissociation", "Unspecified Dissociative Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        },
        "Unspecified Dissociative Disorder": {
            "Synonyms": ["Dissociative Symptoms NOS", "Undifferentiated Dissociation", "Dissociation Unspecified"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Confusion", "Memory Gaps", "Impairment"]
        }
    },

    # Chapter 9: Somatic Symptom and Related Disorders
    "Somatic Symptom and Related Disorders": {
        "Somatic Symptom Disorder": {
            "Synonyms": ["Somatization Disorder", "Somatic Symptoms", "Physical Complaints"],
            "Verbs": ["Experience", "Report", "Exhibit", "Demonstrate", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Bodily Distress", "Health Anxiety", "Preoccupation", "Functional Impairment"]
        },
        "Illness Anxiety Disorder": {
            "Synonyms": ["Hypochondriasis", "Health Anxiety", "Illness Phobia"],
            "Verbs": ["Worry", "Preoccupy", "Fear", "Monitor", "Interpret"],
            "Nouns": ["Health Anxiety", "Preoccupation with Illness", "Fear of Disease", "Seeking Reassurance", "Somatic Focus"]
        },
        "Conversion Disorder (Functional Neurological Symptom Disorder)": {
            "Synonyms": ["Functional Neurological Disorder", "Psychogenic Neurological Symptoms"],
            "Verbs": ["Exhibit", "Demonstrate", "Report", "Manifest", "Experience"],
            "Nouns": ["Neurological Symptoms", "Motor Deficits", "Sensory Deficits", "Seizures", "Paralysis"]
        },
        "Psychological Factors Affecting Other Medical Conditions": {
            "Synonyms": ["Psychosomatic Factors", "Mind-Body Interaction", "Stress-Related Physical Illness"],
            "Verbs": ["Influence", "Exacerbate", "Contribute to", "Affect", "Modify"],
            "Nouns": ["Medical Condition", "Psychological Factors", "Symptom Severity", "Functional Impact", "Health Outcomes"]
        },
        "Other Specified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Atypical Somatic Disorder", "Subthreshold Somatic Symptoms"],
            "Verbs": ["Experience", "Report", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Distress", "Functional Impairment", "Health Anxiety", "Preoccupation"]
        },
        "Unspecified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Somatic Symptoms NOS", "Unspecified Somatic Disorder"],
            "Verbs": ["Experience", "Report", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Distress", "Impairment", "Health Concerns", "Functional Impact"]
        }
    },

    # Chapter 10: Feeding and Eating Disorders
    "Feeding and Eating Disorders": {
        "Pica": {
            "Synonyms": ["Nonfood Eating", "Unusual Cravings", "Pica Behavior"],
            "Verbs": ["Eat", "Consume", "Ingest", "Crave", "Desire"],
            "Nouns": ["Non-nutritive Substances", "Cravings", "Consumption", "Behavioral Pattern", "Health Risk"]
        },
        "Rumination Disorder": {
            "Synonyms": ["Regurgitation Disorder", "Chronic Regurgitation", "Rumination"],
            "Verbs": ["Regurgitate", "Re-chew", "Swallow", "Expel", "Repeat"],
            "Nouns": ["Regurgitation", "Re-chewing", "Repeated Behavior", "Gastric Contents", "Behavioral Pattern"]
        },
        "Avoidant/Restrictive Food Intake Disorder": {
            "Synonyms": ["ARFID", "Selective Eating", "Eating Avoidance"],
            "Verbs": ["Avoid", "Restrict", "Refuse", "Limit", "Fear"],
            "Nouns": ["Restricted Intake", "Weight Loss", "Nutritional Deficiency", "Concern Avoidance", "Impact on Health"]
        },
        "Anorexia Nervosa": {
            "Synonyms": ["Anorexia", "Self-Starvation", "Fear of Weight Gain"],
            "Verbs": ["Restrict", "Lose Weight", "Fear", "Exercise", "Control"],
            "Nouns": ["Low Body Weight", "Intense Fear of Weight Gain", "Body Image Disturbance", "Amenorrhea (in females)", "Health Consequences"]
        },
        "Bulimia Nervosa": {
            "Synonyms": ["Bulimia", "Binge-Purge Syndrome", "Purging Disorder"],
            "Verbs": ["Binge", "Purge", "Compensate", "Restrict", "Vomit"],
            "Nouns": ["Recurrent Binge Eating", "Inappropriate Compensatory Behaviors", "Self-Evaluation Influenced by Body Shape", "Health Risks", "Electrolyte Imbalance"]
        },
        "Binge-Eating Disorder": {
            "Synonyms": ["BED", "Compulsive Overeating", "Emotional Eating"],
            "Verbs": ["Binge", "Overeat", "Consume", "Experience Loss of Control", "Feel Distressed"],
            "Nouns": ["Binge Episodes", "Distress", "Obesity Risk", "Feelings of Guilt", "Health Impact"]
        },
        "Other Specified Feeding or Eating Disorder": {
            "Synonyms": ["OSFED", "Subthreshold Eating Disorder", "Atypical Eating Disorder"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Fear"],
            "Nouns": ["Eating Behaviors", "Distress", "Body Image Concern", "Health Impact", "Atypical Features"]
        },
        "Unspecified Feeding or Eating Disorder": {
            "Synonyms": ["UFED", "Eating Disorder NOS", "Unspecified Eating Pathology"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Distress"],
            "Nouns": ["Eating Behaviors", "Distress", "Functional Impairment", "Health Concerns", "Diagnostic Uncertainty"]
        }
    },

    # Chapter 11: Elimination Disorders
    "Elimination Disorders": {
        "Enuresis": {
            "Synonyms": ["Bedwetting", "Urinary Incontinence", "Nocturnal Enuresis"],
            "Verbs": ["Wet", "Urinate", "Void", "Leak", "Have Accident"],
            "Nouns": ["Urine", "Incontinence", "Accidents", "Bedwetting", "Distress"]
        },
        "Encopresis": {
            "Synonyms": ["Soiling", "Fecal Incontinence", "Bowel Incontinence"],
            "Verbs": ["Soil", "Defecate", "Leak", "Have Accident", "Inadvertently Pass Stool"],
            "Nouns": ["Feces", "Soiling", "Incontinence", "Accidents", "Distress"]
        }
    },

    # Chapter 12: Sleep-Wake Disorders
    "Sleep-Wake Disorders": {
        "Insomnia Disorder": {
            "Synonyms": ["Insomnia", "Sleeplessness", "Nonrestorative Sleep"],
            "Verbs": ["Struggle to sleep", "Wake up early", "Experience nonrestorative sleep"],
            "Nouns": ["Difficulty Initiating Sleep", "Nonrestorative Sleep", "Daytime Fatigue", "Irritability", "Impaired Functioning"]
        },
        "Hypersomnolence Disorder": {
            "Synonyms": ["Hypersomnia", "Excessive Sleepiness", "Sleep Inertia"],
            "Verbs": ["Feel excessively sleepy", "Nap unintentionally", "Experience sleep inertia"],
            "Nouns": ["Excessive Sleepiness", "Unrefreshing Naps", "Sleep Inertia", "Impaired Alertness", "Difficulty Waking"]
        },
        "Narcolepsy": {
            "Synonyms": ["Narcolepsy", "Sleep Attacks", "Cataplexy"],
            "Verbs": ["Experience sleep attacks", "Have cataplexy", "Report hallucinations"],
            "Nouns": ["Irresistible Sleep Episodes", "Cataplexy", "Hypnagogic Hallucinations", "Sleep Paralysis", "Fragmented Sleep"]
        },
        "Obstructive Sleep Apnea Hypopnea": {
            "Synonyms": ["OSA", "Sleep Apnea", "Breathing-Related Sleep Disorder"],
            "Verbs": ["Snore", "Gasp", "Experience apneas"],
            "Nouns": ["Apneas", "Hypopneas", "Snoring", "Daytime Sleepiness", "Fatigue"]
        },
        "Central Sleep Apnea": {
            "Synonyms": ["Central Sleep Apnea", "CSA"],
            "Verbs": ["Experience central apneas", "Report daytime sleepiness"],
            "Nouns": ["Central Apneas", "Lack of Respiratory Effort", "Daytime Sleepiness", "Insomnia", "Cheyne-Stokes Breathing"]
        },
        "Sleep-Related Hypoventilation": {
            "Synonyms": ["Hypoventilation", "Nocturnal Hypoventilation"],
            "Verbs": ["Exhibit hypoventilation", "Have elevated CO2 levels"],
            "Nouns": ["Hypoventilation", "Hypercapnia", "Daytime Sleepiness", "Morning Headache", "Fatigue"]
        },
        "Circadian Rhythm Sleep-Wake Disorders": {
            "Synonyms": ["CRSWD", "Circadian Disorders"],
            "Verbs": ["Experience misaligned sleep", "Have irregular sleep patterns"],
            "Nouns": ["Phase Delay", "Phase Advance", "Irregular Schedule", "Non-24-Hour Rhythm", "Sleep-Wake Inversion"]
        },
        "Parasomnias": {
            "Synonyms": ["Nightmare Disorder", "REM Behavior Disorder", "NREM Arousals"],
            "Verbs": ["Experience nightmares", "Act out dreams", "Have night terrors"],
            "Nouns": ["Nightmares", "Dream Enactment", "Sleepwalking", "Sleep Terrors", "Confusional Arousals"]
        },
        "Restless Legs Syndrome": {
            "Synonyms": ["RLS", "Willis-Ekbom Disease"],
            "Verbs": ["Feel urge to move legs", "Experience unpleasant sensations"],
            "Nouns": ["Urge to Move", "Creeping Sensation", "Evening Worsening", "Sleep Disruption", "Daytime Fatigue"]
        },
        "Substance/Medication-Induced Sleep Disorder": {
            "Synonyms": ["Drug-Induced Sleep Problems"],
            "Verbs": ["Experience insomnia", "Have hypersomnia", "Develop parasomnias"],
            "Nouns": ["Sleep Disturbance", "Medication Context", "Insomnia", "Hypersomnia", "Parasomnia"]
        }
    },

    # Chapter 13: Sexual Dysfunctions
    "Sexual Dysfunctions": {
        "Delayed Ejaculation": {
            "Synonyms": ["Male Orgasmic Disorder", "Retarded Ejaculation", "Ejaculatory Inhibition"],
            "Verbs": ["Experience difficulty ejaculating", "Delay ejaculation", "Require prolonged stimulation", "Report distress", "Have infrequent orgasms"],
            "Nouns": ["Delay in ejaculation", "Infrequency of orgasm", "Reduced intensity of orgasm", "Marked distress", "Interpersonal Difficulty"]
        },
        "Erectile Disorder": {
            "Synonyms": ["Impotence", "Erectile Dysfunction", "Difficulty Achieving/Maintaining Erection"],
            "Verbs": ["Fail to achieve erection", "Fail to maintain erection", "Experience decreased rigidity", "Avoid sexual activity", "Report distress"],
            "Nouns": ["Erectile Difficulty", "Insufficient Rigidity", "Performance Anxiety", "Marked Distress", "Interpersonal Strain"]
        },
        "Female Orgasmic Disorder": {
            "Synonyms": ["Anorgasmia", "Inhibited Female Orgasm", "Difficulty Reaching Orgasm"],
            "Verbs": ["Experience delay or absence of orgasm", "Have reduced intensity of orgasm", "Require specific stimulation", "Report distress", "Feel frustration"],
            "Nouns": ["Orgasmic Difficulty", "Delayed Orgasm", "Absent Orgasm", "Reduced Intensity", "Marked Distress"]
        },
        "Female Sexual Interest/Arousal Disorder": {
            "Synonyms": ["Low Female Libido", "Reduced Sexual Arousal", "Hypoactive Sexual Desire"],
            "Verbs": ["Lack sexual interest", "Have reduced arousal", "Fail to respond to sexual stimulation", "Report distress", "Avoid sexual activity"],
            "Nouns": ["Reduced Interest", "Absent Arousal", "Lack of Desire", "Marked Distress", "Functional Impairment"]
        },
        "Genito-Pelvic Pain/Penetration Disorder": {
            "Synonyms": ["Dyspareunia", "Vaginismus", "Painful Intercourse"],
            "Verbs": ["Experience pain during intercourse", "Tense pelvic floor muscles", "Avoid penetration", "Fear pain", "Report distress"],
            "Nouns": ["Genital Pain", "Pelvic Pain", "Fear of Penetration", "Muscle Tension", "Marked Distress"]
        },
        "Male Hypoactive Sexual Desire Disorder": {
            "Synonyms": ["Low Male Libido", "Reduced Sexual Desire"],
            "Verbs": ["Lack sexual desire", "Have reduced fantasies", "Report distress", "Avoid sexual activity", "Feel frustration"],
            "Nouns": ["Reduced Desire", "Absent Fantasies", "Deficient Interest", "Marked Distress", "Functional Impact"]
        },
        "Premature (Early) Ejaculation": {
            "Synonyms": ["Rapid Ejaculation", "Early Climax"],
            "Verbs": ["Ejaculate prematurely", "Experience lack of control", "Feel distress", "Avoid intercourse", "Report frustration"],
            "Nouns": ["Early Ejaculation", "Lack of Control", "Marked Distress", "Interpersonal Difficulty", "Frustration"]
        },
        "Other Specified Sexual Dysfunction": {
            "Synonyms": ["Atypical Sexual Dysfunction", "Subthreshold Sexual Dysfunction"],
            "Verbs": ["Experience sexual difficulties", "Report distress", "Have impaired desire or arousal"],
            "Nouns": ["Sexual Dysfunction Symptoms", "Distress", "Interpersonal Impact", "Atypical Features", "Functional Impairment"]
        },
        "Unspecified Sexual Dysfunction": {
            "Synonyms": ["Sexual Dysfunction NOS", "Unspecified Sexual Disorder"],
            "Verbs": ["Experience sexual issues", "Report distress", "Present unspecified dysfunction"],
            "Nouns": ["Sexual Dysfunction Symptoms", "Distress", "Interpersonal Impact", "Diagnostic Uncertainty", "Functional Impairment"]
        }
    },

    # Chapter 14: Gender Dysphoria
    "Gender Dysphoria": {
        "Gender Dysphoria in Children": {
            "Synonyms": ["Childhood Gender Dysphoria", "Early-Onset Gender Incongruence"],
            "Verbs": ["Express", "Insist", "Demonstrate", "Feel", "Desire"],
            "Nouns": ["Incongruence", "Distress", "Discomfort", "Cross‑gender Identification", "Desire to Be Other Gender"]
        },
        "Gender Dysphoria in Adolescents and Adults": {
            "Synonyms": ["Adolescent Gender Dysphoria", "Adult Gender Dysphoria", "Persistent Gender Incongruence"],
            "Verbs": ["Experience", "Express", "Desire", "Identify as", "Feel"],
            "Nouns": ["Incongruence", "Distress", "Identity Conflict", "Discomfort", "Desire for Transition"]
        },
        "Other Specified Gender Dysphoria": {
            "Synonyms": ["Atypical Gender Dysphoria", "Subthreshold Gender Incongruence"],
            "Verbs": ["Exhibit", "Show", "Experience", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Incongruence", "Distress", "Identity Concerns", "Discomfort"]
        },
        "Unspecified Gender Dysphoria": {
            "Synonyms": ["Gender Incongruence NOS", "Undefined Gender Dysphoria"],
            "Verbs": ["Experience", "Manifest", "Show", "Have", "Demonstrate"],
            "Nouns": ["Incongruence", "Distress", "Discomfort", "Identity Concern", "Dysphoria"]
        }
    },
    # Chapter 15: Disruptive, Impulse-Control, and Conduct Disorders
    "Disruptive, Impulse-Control, and Conduct Disorders": {
        "Oppositional Defiant Disorder": {
            "Synonyms": ["ODD", "Defiant Behavior", "Argumentative Behavior"],
            "Verbs": ["Argue", "Defy", "Deliberately Annoy", "Blame", "Refuse"],
            "Nouns": ["Defiance", "Irritability", "Vindictiveness", "Anger", "Blaming"]
        },
        "Intermittent Explosive Disorder": {
            "Synonyms": ["IED", "Impulse Aggression", "Anger Outbursts"],
            "Verbs": ["Explode", "Rage", "Outburst", "Lose Control", "Aggress"],
            "Nouns": ["Anger", "Outbursts", "Aggression", "Impulsivity", "Regret"]
        },
        "Conduct Disorder": {
            "Synonyms": ["CD", "Antisocial Behavior", "Rule-Breaking"],
            "Verbs": ["Steal", "Destroy", "Aggress", "Deceive", "Violate"],
            "Nouns": ["Aggression", "Property Destruction", "Theft", "Deceit", "Rule Violations"]
        },
        "Pyromania": {
            "Synonyms": ["Fire-Setting Disorder", "Arsonistic Impulse"],
            "Verbs": ["Set Fire", "Fascinated by Fire", "Observe Flames", "Plan Arson", "Ignite"],
            "Nouns": ["Fire-Setting", "Fascination", "Tension Before", "Relief After", "Arson"]
        },
        "Kleptomania": {
            "Synonyms": ["Stealing Impulse", "Shoplifting Disorder"],
            "Verbs": ["Steal", "Impulse Steal", "Pocket", "Conceal", "Experience Urge"],
            "Nouns": ["Urge", "Stealing", "Tension", "Relief", "Shame"]
        },
        "Other Specified Disruptive, Impulse-Control, and Conduct Disorder": {
            "Synonyms": ["Atypical Disruptive Disorder", "Subthreshold Conduct"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Behaviors", "Aggression", "Defiance", "Impulsivity"]
        },
        "Unspecified Disruptive, Impulse-Control, and Conduct Disorder": {
            "Synonyms": ["Unspecified Disruptive Behavior"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Behaviors", "Aggression", "Defiance", "Impulsivity"]
        }
    },
    
    # Chapter 16: Substance-Related and Addictive Disorders
    "Substance-Related and Addictive Disorders": {
        "Alcohol Use Disorder": {
            "Synonyms": ["AUD", "Alcohol Dependence", "Alcohol Abuse"],
            "Verbs": ["Drink", "Crave", "Binge", "Continue Despite", "Experience Withdrawal"],
            "Nouns": ["Craving", "Tolerance", "Withdrawal", "Impaired Control", "Use Despite Harm"]
        },
        "Caffeine Use Disorder": {
            "Synonyms": ["Caffeine Dependence", "Caffeine Abuse"],
            "Verbs": ["Consume", "Crave", "Overuse", "Experience Withdrawal", "Require Dose"],
            "Nouns": ["Tolerance", "Withdrawal", "Overuse", "Craving", "Headache"]
        },
        "Cannabis Use Disorder": {
            "Synonyms": ["Marijuana Use Disorder", "Cannabis Dependence"],
            "Verbs": ["Smoke", "Vape", "Crave", "Overuse", "Experience Withdrawal"],
            "Nouns": ["Tolerance", "Withdrawal", "Craving", "Impaired Control", "Use Despite Harm"]
        },
        "Gambling Disorder": {
            "Synonyms": ["Compulsive Gambling", "Pathological Gambling"],
            "Verbs": ["Gamble", "Chase Losses", "Lie", "Borrow", "Feel Urge"],
            "Nouns": ["Craving", "Loss Chasing", "Impulsivity", "Preoccupation", "Financial Harm"]
        },
        "Other Specified Substance-Related and Addictive Disorder": {
            "Synonyms": ["Atypical Use Disorder"],
            "Verbs": ["Use", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Tolerance", "Withdrawal", "Craving", "Impairment"]
        },
        "Unspecified Substance-Related and Addictive Disorder": {
            "Synonyms": ["Substance Use NOS"],
            "Verbs": ["Use", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Tolerance", "Withdrawal", "Craving", "Impairment"]
        }
    },
    
    # Chapter 17: Neurocognitive Disorders
    "Neurocognitive Disorders": {
        "Delirium": {
            "Synonyms": ["Acute Confusional State", "Toxic Encephalopathy"],
            "Verbs": ["Fluctuate", "Disorient", "Hallucinate", "Be Confused", "Show Inattention"],
            "Nouns": ["Disorientation", "Hallucinations", "Inattention", "Fluctuating Consciousness", "Confusion"]
        },
        "Major Neurocognitive Disorder": {
            "Synonyms": ["Major NCD", "Dementia"],
            "Verbs": ["Forget", "Confuse", "Lose", "Impair", "Repeat"],
            "Nouns": ["Memory Loss", "Impairment", "Aphasia", "Apraxia", "Agnosia"]
        },
        "Mild Neurocognitive Disorder": {
            "Synonyms": ["Mild NCD", "Mild Cognitive Impairment"],
            "Verbs": ["Forget", "Misplace", "Struggle", "Notice", "Experience"],
            "Nouns": ["Memory Complaints", "Reduced Function", "Impairment", "Attention Problems", "Executive Dysfunction"]
        },
        "Other Specified Neurocognitive Disorder": {
            "Synonyms": ["Atypical NCD"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Impairment", "Memory", "Attention", "Executive Dysfunction"]
        },
        "Unspecified Neurocognitive Disorder": {
            "Synonyms": ["Unspecified Cognitive Disorder"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Impairment", "Memory", "Attention", "Executive Dysfunction"]
        }
    },
    
    # Chapter 18: Personality Disorders
    "Personality Disorders": {
        "Paranoid Personality Disorder": {
            "Synonyms": ["Paranoid PD", "Suspicious Personality"],
            "Verbs": ["Suspect", "Mistrust", "Bear Grudges", "Read Hidden Meanings", "Be Vigilant"],
            "Nouns": ["Distrust", "Suspicion", "Grudges", "Hypervigilance", "Hostility"]
        },
        "Schizoid Personality Disorder": {
            "Synonyms": ["Schizoid PD", "Detached Personality"],
            "Verbs": ["Withdraw", "Prefer Solitude", "Be Indifferent", "Show Flat Affect", "Avoid Relationships"],
            "Nouns": ["Detachment", "Emotional Coldness", "Solitude", "Indifference", "Aloofness"]
        },
        "Schizotypal Personality Disorder": {
            "Synonyms": ["Schizotypal PD", "Eccentric Personality"],
            "Verbs": ["Magical Thinking", "Be Eccentric", "Be Suspicious", "Show Odd Speech", "Isolate"],
            "Nouns": ["Eccentricity", "Odd Beliefs", "Suspicion", "Oddness", "Social Anxiety"]
        },
        "Antisocial Personality Disorder": {
            "Synonyms": ["ASPD", "Psychopathy", "Sociopathy"],
            "Verbs": ["Deceive", "Exploit", "Violate Rights", "Be Irresponsible", "Aggress"],
            "Nouns": ["Deceit", "Impulsivity", "Lack of Remorse", "Aggression", "Irresponsibility"]
        },
        "Borderline Personality Disorder": {
            "Synonyms": ["BPD", "Emotionally Unstable Personality"],
            "Verbs": ["Idealize", "Devalue", "Self-Harm", "Fear Abandonment", "Mood Swing"],
            "Nouns": ["Instability", "Impulsivity", "Fear of Abandonment", "Identity Disturbance", "Affective Dysregulation"]
        },
        "Histrionic Personality Disorder": {
            "Synonyms": ["HPD", "Dramatic Personality"],
            "Verbs": ["Seek Attention", "Be Seductive", "Show Shallow Emotions", "Use Appearance", "Be Theatrical"],
            "Nouns": ["Attention-Seeking", "Shallowness", "Seductiveness", "Drama", "Suggestibility"]
        },
        "Narcissistic Personality Disorder": {
            "Synonyms": ["NPD", "Grandiose Personality"],
            "Verbs": ["Grandstand", "Require Admiration", "Exploit", "Envy", "Lack Empathy"],
            "Nouns": ["Grandiosity", "Entitlement", "Need for Admiration", "Envy", "Lack of Empathy"]
        },
        "Avoidant Personality Disorder": {
            "Synonyms": ["AvPD", "Social Inhibition"],
            "Verbs": ["Avoid", "Be Hypersensitive", "Fear Criticism", "Be Shy", "Be Inhibited"],
            "Nouns": ["Avoidance", "Hypersensitivity", "Shyness", "Inhibition", "Low Self-Esteem"]
        },
        "Dependent Personality Disorder": {
            "Synonyms": ["DPD", "Submissive Personality"],
            "Verbs": ["Depend", "Cling", "Be Submissive", "Seek Reassurance", "Be Passive"],
            "Nouns": ["Dependency", "Clinging", "Submissiveness", "Fear of Separation", "Helplessness"]
        },
        "Obsessive-Compulsive Personality Disorder": {
            "Synonyms": ["OCPD", "Perfectionistic Personality"],
            "Verbs": ["Order", "Control", "Be Rigorous", "Be Inflexible", "Preoccupy"],
            "Nouns": ["Preoccupation with Order", "Perfectionism", "Rigidity", "Control", "Overconscientiousness"]
        },
        "Other Specified Personality Disorder": {
            "Synonyms": ["Atypical PD"],
            "Verbs": ["Exhibit", "Show", "Demonstrate"],
            "Nouns": ["Symptoms", "Personality Traits", "Impairment"]
        },
        "Unspecified Personality Disorder": {
            "Synonyms": ["Personality Disorder NOS"],
            "Verbs": ["Exhibit", "Show", "Demonstrate"],
            "Nouns": ["Symptoms", "Personality Traits", "Impairment"]
        }
    },
    
    # Chapter 19: Paraphilic Disorders
    "Paraphilic Disorders": {
        "Voyeuristic Disorder": {
            "Synonyms": ["Peeping Tom Disorder"],
            "Verbs": ["Observe", "Spying", "Peep", "Expose Behavior", "Experience Arousal"],
            "Nouns": ["Observation", "Voyeurism", "Arousal", "Risk", "Secrecy"]
        },
        "Exhibitionistic Disorder": {
            "Synonyms": ["Flasher Disorder"],
            "Verbs": ["Expose", "Flash", "Reveal", "Experience Arousal", "Be Excited"],
            "Nouns": ["Exposure", "Arousal", "Shock", "Risk", "Secrecy"]
        },
        "Frotteuristic Disorder": {
            "Synonyms": ["Toucher Disorder"],
            "Verbs": ["Rub", "Touch", "Graze", "Experience Arousal", "Be Excited"],
            "Nouns": ["Touching", "Arousal", "Risk", "Violation", "Secrecy"]
        },
        "Sexual Masochism Disorder": {
            "Synonyms": ["Masochism"],
            "Verbs": ["Experience Pain", "Be Humiliated", "Arouse", "Seek Pain", "Consent"],
            "Nouns": ["Pain", "Humiliation", "Arousal", "Consent", "Fantasy"]
        },
        "Sexual Sadism Disorder": {
            "Synonyms": ["Sadism"],
            "Verbs": ["Inflict Pain", "Arouse", "Dominate", "Degrade", "Consent"],
            "Nouns": ["Pain", "Dominance", "Arousal", "Consent", "Fantasy"]
        },
        "Pedophilic Disorder": {
            "Synonyms": ["Pedophilia"],
            "Verbs": ["Arouse", "Have Fantasies", "Plan", "Seek Contact", "Experience Distress"],
            "Nouns": ["Attraction", "Fantasy", "Risk", "Distress", "Illegal Behavior"]
        },
        "Fetishistic Disorder": {
            "Synonyms": ["Fetish"],
            "Verbs": ["Use Object", "Arouse", "Collect", "Focus", "Experience Arousal"],
            "Nouns": ["Object", "Arousal", "Fetish", "Fantasy", "Impairment"]
        },
        "Transvestic Disorder": {
            "Synonyms": ["Cross-Dressing Disorder"],
            "Verbs": ["Dress", "Arouse", "Experience Arousal", "Focus", "Fantasy"],
            "Nouns": ["Cross-Dressing", "Arousal", "Fantasy", "Distress", "Impairment"]
        },
        "Other Specified Paraphilic Disorder": {
            "Synonyms": ["Atypical Paraphilia"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Arousal", "Distress"]
        },
        "Unspecified Paraphilic Disorder": {
            "Synonyms": ["Paraphilia NOS"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Arousal", "Distress"]
        }
    },
    
    # Chapter 20: Medication-Induced Movement Disorders and Other Adverse Effects
    "Medication-Induced Movement Disorders and Other Adverse Effects of Medication": {
        "Neuroleptic-Induced Parkinsonism": {
            "Synonyms": ["Medication-Induced Parkinsonism"],
            "Verbs": ["Tremble", "Stiffen", "Move Slowly", "Be Rigid", "Shamble"],
            "Nouns": ["Tremor", "Rigidity", "Bradykinesia", "Shuffling Gait", "Mask-like Face"]
        },
        "Acute Dystonia": {
            "Synonyms": ["Dystonic Reaction"],
            "Verbs": ["Spasm", "Twist", "Contract", "Distort", "Experience Pain"],
            "Nouns": ["Spasm", "Contraction", "Torticollis", "Oculogyric Crisis", "Pain"]
        },
        "Akathisia": {
            "Synonyms": ["Restlessness"],
            "Verbs": ["Pace", "Fidget", "Be Restless", "Shift Weight", "Feel Inner Tension"],
            "Nouns": ["Restlessness", "Agitation", "Inner Tension", "Pacing", "Fidgeting"]
        },
        "Tardive Dyskinesia": {
            "Synonyms": ["Late-Onset Dyskinesia"],
            "Verbs": ["Grimace", "Lip-Smack", "Chew", "Chatter", "Involuntary Movement"],
            "Nouns": ["Grimacing", "Lip Smacking", "Chewing Movements", "Chorea", "Tardive Dyskinesia"]
        },
        "Medication-Induced Postural Tremor": {
            "Synonyms": ["Action Tremor"],
            "Verbs": ["Tremble", "Shake", "Hold Position", "Be Unsteady"],
            "Nouns": ["Tremor", "Shaking", "Postural Instability", "Unsteadiness"]
        },
        "Other Specified Medication-Induced Movement Disorder": {
            "Synonyms": ["Atypical MED Disorder"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Movement", "Adverse Effect"]
        },
        "Unspecified Medication-Induced Movement Disorder": {
            "Synonyms": ["MED Disorder NOS"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Movement", "Adverse Effect"]
        }
    },
    
    # Chapter 21: Other Conditions That May Be a Focus of Clinical Attention
    "Other Conditions That May Be a Focus of Clinical Attention": {
        "Relational Problems": {
            "Synonyms": ["Relationship Issues", "Interpersonal Difficulties"],
            "Verbs": ["Argue", "Withdraw", "Miscommunicate", "Strain", "Conflict"],
            "Nouns": ["Conflict", "Tension", "Misunderstanding", "Separation", "Alienation"]
        },
        "Abuse and Neglect": {
            "Synonyms": ["Maltreatment", "Child Abuse", "Elder Neglect"],
            "Verbs": ["Harm", "Neglect", "Abuse", "Exploit", "Witness"],
            "Nouns": ["Abuse", "Neglect", "Trauma", "Maltreatment", "Violation"]
        },
        "Educational and Occupational Problems": {
            "Synonyms": ["School Issues", "Work Issues"],
            "Verbs": ["Struggle", "Fail", "Be Absent", "Conflict", "Underperform"],
            "Nouns": ["Underachievement", "Absenteeism", "Conflict", "Discipline", "Stress"]
        },
        "Housing and Economic Problems": {
            "Synonyms": ["Homelessness", "Financial Strain"],
            "Verbs": ["Struggle", "Lack", "Default", "Evicted", "Worry"],
            "Nouns": ["Homelessness", "Financial Hardship", "Eviction", "Poverty", "Debt"]
        },
        "Other Health Service Encounters for Counseling and Medical Advice": {
            "Synonyms": ["Z-Codes", "Counseling Encounters"],
            "Verbs": ["Seek", "Receive", "Attend", "Consult"],
            "Nouns": ["Encounter", "Counseling", "Advice", "Referral"]
        },
        "Other Specified Condition": {
            "Synonyms": ["Atypical Clinical Focus"],
            "Verbs": ["Exhibit", "Show", "Have"],
            "Nouns": ["Problem", "Concern", "Issue"]
        },
        "Unspecified Condition": {
            "Synonyms": ["Clinical Issue NOS"],
            "Verbs": ["Exhibit", "Show", "Have"],
            "Nouns": ["Problem", "Concern", "Issue"]
        }
    }
}

# %% [markdown]
# ## 2. DSM-5-TR Major Chapters (21)
#
# Here is the widely recognized **DSM-5-TR** high-level outline:
#
# 1. **Neurodevelopmental Disorders**
# 2. **Schizophrenia Spectrum and Other Psychotic Disorders**
# 3. **Bipolar and Related Disorders**
# 4. **Depressive Disorders**
# 5. **Anxiety Disorders**
# 6. **Obsessive-Compulsive and Related Disorders**
# 7. **Trauma- and Stressor-Related Disorders**
# 8. **Dissociative Disorders**
# 9. **Somatic Symptom and Related Disorders**
# 10. **Feeding and Eating Disorders**
# 11. **Elimination Disorders**
# 12. **Sleep-Wake Disorders**
# 13. **Sexual Dysfunctions**
# 14. **Gender Dysphoria**
# 15. **Disruptive, Impulse-Control, and Conduct Disorders**
# 16. **Substance-Related and Addictive Disorders**
# 17. **Neurocognitive Disorders**
# 18. **Personality Disorders**
# 19. **Paraphilic Disorders**
# 20. **Medication-Induced Movement Disorders and Other Adverse Effects of Medication**
# 21. **Other Conditions That May Be a Focus of Clinical Attention**

# %% [markdown]
# Timeline and reference table for the Generalized Anxiety Disorder 7 (GAD-7) involves outlining key developments of this assessment tool. The GAD-7 is a self-report questionnaire widely used for screening and measuring the severity of generalized anxiety disorder.
#
# | Year          | Milestone                               | Contributor(s)                                               | Original Work Reference                                                                                                          | Key Contributions                                                                               | Additional Information                                                                                   |
# |---------------|-----------------------------------------|--------------------------------------------------------------|----------------------------------------------------------------------------------------------------------------------------------|--------------------------------------------------------------------------------------------------|----------------------------------------------------------------------------------------------------------|
# | 2006          | Introduction of the GAD-7.             | Robert L. Spitzer, Kurt Kroenke, Janet B. W. Williams, and colleagues | Spitzer, R. L., Kroenke, K., Williams, J. B. W., & Löwe, B. (2006). "A brief measure for assessing generalized anxiety disorder: the GAD-7". Archives of Internal Medicine. | Developed as a brief measure for screening generalized anxiety disorder and assessing its severity. | The GAD-7 quickly became a standard tool in both clinical practice and research for anxiety-related assessments. |
# | 2000s Onwards | Validation and Adaptation in Various Settings. | Various Researchers                                           | Studies conducted to validate the GAD-7 in different populations and settings.                                                   | Research confirmed the reliability and validity of the GAD-7 across diverse demographic and clinical groups. | Highlighted the tool’s applicability in primary care, mental health settings, and research studies.           |
# | 2010s-Present | Ongoing Research and Applications.     | Various Scholars and Practitioners                            | Recent studies exploring the use of GAD-7 in new contexts and with emerging technologies like digital health platforms.           | Further exploration of the GAD-7's utility in monitoring treatment progress and outcomes.            | Demonstrates the continued relevance and adaptability of the GAD-7 in evolving healthcare landscapes.       |
#
#
# This table provides an overview of the major developments in the Generalized Anxiety Disorder 7 (GAD-7), highlighting key contributions and milestones. Each row represents a significant event in the history of the GAD-7, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# The GAD-7 is recognized for its brevity and effectiveness in assessing anxiety, particularly in primary care and mental health settings. Its development and widespread adoption underscore its importance as a practical tool for the screening and measurement of anxiety symptoms.
#
#
# | #    | Author(s)                                           | Year | Title                                                                                                                                                                                                                          | Journal/Source                          | Volume | Pages       | DOI                                                                                               |
# |------|-----------------------------------------------------|------|--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-----------------------------------------|--------|-------------|---------------------------------------------------------------------------------------------------|
# | 1    | R. Spitzer, K. Kroenke, Janet B W Williams, B. Löwe | 2006 | A brief measure for assessing generalized anxiety disorder: the GAD-7.                                                                                                                                                        | Archives of Internal Medicine            | 166 10 | 1092-7      | [10.1001/ARCHINTE.166.10.1092](https://doi.org/10.1001/ARCHINTE.166.10.1092)                      |
# | 2    | K. Kroenke                                         | 2002 | A 75-year-old man with depression.                                                                                                                                                                                            | JAMA                                    | 287 12 | 1568-76     | [10.1001/JAMA.287.12.1568](https://doi.org/10.1001/JAMA.287.12.1568)                              |
# | 3    | T. Greco, G. Eckert, K. Kroenke                     | 2004 | The outcome of physical symptoms with treatment of depression                                                                                                         | Journal of General Internal Medicine     | 19     | 813-818     | [10.1111/j.1525-1497.2004.30531.x](https://doi.org/10.1111/j.1525-1497.2004.30531.x)              |
# | 4    | B. Löwe, K. Gräfe, S. Zipfel, S. Witte, Bernd Loerch, W. Herzog | 2004 | Diagnosing ICD-10 Depressive Episodes: Superior Criterion Validity of the Patient Health Questionnaire                                                               | Psychotherapy and Psychosomatics        | 73     | 386-390     | [10.1159/000080393](https://doi.org/10.1159/000080393)                                            |
# | 5    | G. Simon, E. Ludman, S. Tutty, B. Operskalski, M. Von Korff | 2004 | Telephone psychotherapy and telephone care management for primary care patients starting antidepressant treatment: a randomized controlled trial                      | JAMA                                    | 292 8  | 935-42      | [10.1001/JAMA.292.8.935](https://doi.org/10.1001/JAMA.292.8.935)                                  |
# | 6    | Pamela W. Lee, H. Schulberg, P. Raue, K. Kroenke    | 2007 | Concordance between the PHQ-9 and the HSCL-20 in depressed primary care patients                                                                                     | Journal of Affective Disorders          | 99 1-3 | 139-45      | [10.1016/J.JAD.2006.09.002](https://doi.org/10.1016/J.JAD.2006.09.002)                            |
# | 7    | A. Picardi, D. Adler, D. Abeni, Hong Chang, P. Pasquini, W. Rogers, K. Bungay | 2005 | Screening for depressive disorders in patients with skin diseases: a comparison of three screeners                                                                   | Acta Dermato-Venereologica              | 85 5   | 414-9       | [10.1080/00015550510034966](https://doi.org/10.1080/00015550510034966)                            |
# | 8    | K. Kroenke, R. Spitzer                             | 2002 | The PHQ-9: A new depression diagnostic and severity measure                                                                                                          | Psychiatric Annals                      | 32     | 509-515     | [10.3928/0048-5713-20020901-06](https://doi.org/10.3928/0048-5713-20020901-06)                    |
# | 9    | B. Löwe, K. Kroenke, K. Gräfe                      | 2005 | Detecting and monitoring depression with a two-item questionnaire (PHQ-2).                                                                                            | Journal of Psychosomatic Research       | 58 2   | 163-71      | [10.1016/J.JPSYCHORES.2004.09.006](https://doi.org/10.1016/J.JPSYCHORES.2004.09.006)              |
# | 10   | D. Gjerdingen, S. Crow, P. McGovern, M. Miner, B. Center | 2009 | Postpartum Depression Screening at Well-Child Visits: Validity of a 2-Question Screen and the PHQ-9                                                                  | The Annals of Family Medicine           | 7      | 63-70       | [10.1370/afm.933](https://doi.org/10.1370/afm.933)                                                |
# | 11   | Cuiyan Wang, R. Pan, X. Wan, Y. Tan, Linkang Xu, C. Ho, R. Ho | 2020 | Immediate Psychological Responses and Associated Factors during the Initial Stage of the 2019 Coronavirus Disease (COVID-19) Epidemic among the General Population in China | International Journal of Environmental Research and Public Health | 17     | null        | [10.3390/ijerph17051729](https://doi.org/10.3390/ijerph17051729)                                  |
# | 12   | Kurt Kroenke, Zhangsheng Yu, Jingwei Wu, Jacob Kean, Patrick O. Monahan | 2014 | Operating characteristics of PROMIS four-item depression and anxiety scales in primary care patients with chronic pain                                                | Pain Medicine                           | 15 11  | 1892-901    | [10.1111/pme.12537](https://doi.org/10.1111/pme.12537)                                            |
# | 13   | K. Kroenke, R. Spitzer, Janet B W Williams | 2003 | The Patient Health Questionnaire-2: Validity of a Two-Item Depression Screener                                                                                       | Medical Care                            | 41     | 1284-1292   | [10.1097/01.MLR.0000093487.78664.3C](https://doi.org/10.1097/01.MLR.0000093487.78664.3C)          |
# | 14   | Faye Plummer, L. Manea, D. Trépel, D. McMillan     | 2016 | Screening for anxiety disorders with the GAD-7 and GAD-2: a systematic review and diagnostic metaanalysis                                                            | General Hospital Psychiatry             | 39     | 24-31       | [10.1016/j.genhosppsych.2015.11.005](https://doi.org/10.1016/j.genhosppsych.2015.11.005)          |
# | 15   | D. Reuland, A. Cherrington, Garth S Watkins, D. Bradford, Roberto A Blanco, B. Gaynes | 2009 | Diagnostic Accuracy of Spanish Language Depression-Screening Instruments                                                                                             | The Annals of Family Medicine           | 7      | 455-462     | [10.1370/afm.981](https://doi.org/10.1370/afm.981)                                                |
# | 16   | Alexandra Martin, W. Rief, Antje Klaiberg, E. Braehler | 2006 | Validity of the Brief Patient Health Questionnaire Mood Scale (PHQ-9) in the general population                                                                      | General Hospital Psychiatry             | 28 1   | 71-7        | [10.1016/J.GENHOSPPSYCH.2005.07.003](https://doi.org/10.1016/J.GENHOSPPSYCH.2005.07.003)          |
# | 17   | K. Kroenke                                         | 2003 | Patients presenting with somatic complaints: epidemiology, psychiatric co‐morbidity and management                                                                   | International Journal of Methods in Psychiatric Research | 12     | null        | [10.1002/MPR.140](https://doi.org/10.1002/MPR.140)                                                |
# | 18   | Christy A. Blevins, F. Weathers, Margaret T. Davis, Tracy K. Witte, Jessica L. Domino | 2015 | The Posttraumatic Stress Disorder Checklist for DSM-5 (PCL-5): Development and Initial Psychometric Evaluation                                                      | Journal of Traumatic Stress             | 28 6   | 489-98      | [10.1002/jts.22059](https://doi.org/10.1002/jts.22059)                                            |
# | 19   | L. Manea, S. Gilbody, D. McMillan                   | 2015 | A diagnostic meta-analysis of the Patient Health Questionnaire-9 (PHQ-9) algorithm scoring method as a screen for depression                                        | General Hospital Psychiatry             | 37 1   | 67-75       | [10.1016/j.genhosppsych.2014.09.009](https://doi.org/10.1016/j.genhosppsych.2014.09.009)          |
# | 20   | K. Kroenke, R. Spitzer, Janet B W Williams, B. Löwe | 2010 | The Patient Health Questionnaire Somatic, Anxiety, and Depressive Symptom Scales: a systematic review                                                               | General Hospital Psychiatry             | 32 4   | 345-59      | [10.1016/j.genhosppsych.2010.03.006](https://doi.org/10.1016/j.genhosppsych.2010.03.006)          |
# | 21   | B. Löwe, R. Spitzer, K. Gräfe, K. Kroenke, Andrea Quenter, S. Zipfel, C. Buchholz, S. Witte, W. Herzog | 2004 | Comparative validity of three screening questionnaires for DSM-IV depressive disorders and physicians' diagnoses                                                   | Journal of Affective Disorders          | 78 2   | 131-40      | [10.1016/S0165-0327(02)00237-9](https://doi.org/10.1016/S0165-0327(02)00237-9)                    |
# | 22   | B. Löwe, L. Willand, W. Eich, S. Zipfel, A. Ho, W. Herzog, C. Fiehn | 2004 | Psychiatric Comorbidity and Work Disability in Patients With Inflammatory Rheumatic Diseases                                                                          | Psychosomatic Medicine                  | 66     | 395-402     | [10.1097/01.PSY.0000126203.89941.A3](https://doi.org/10.1097/01.PSY.0000126203.89941.A3)          |
# | 23   | K. Kroenke, R. Spitzer, Janet B W Williams         | 2002 | The PHQ-15: Validity of a New Measure for Evaluating the Severity of Somatic Symptoms                                                                                | Psychosomatic Medicine                  | 64     | 258-266     | [10.1097/00006842-200203000-00008](https://doi.org/10.1097/00006842-200203000-00008)              |
# | 24   | L. Wulsin, E. Somoza, J. Heck                       | 2002 | The Feasibility of Using the Spanish PHQ-9 to Screen for Depression in Primary Care in Honduras                                                                      | Primary Care Companion to the Journal of Clinical Psychiatry | 4 5    | 191-195     | [10.4088/PCC.V04N0504](https://doi.org/10.4088/PCC.V04N0504)                                      |
# | 25   | K. Kroenke, Jingwei Wu, Zhangsheng Yu, M. Bair, J. Kean, T. Stump, P. Monahan | 2016 | Patient Health Questionnaire Anxiety and Depression Scale: Initial Validation in Three Clinical Trials                                                              | Psychosomatic Medicine                  | 78     | 716–727    | [10.1097/PSY.0000000000000322](https://doi.org/10.1097/PSY.0000000000000322)                      |
# | 26   | Xin Qin, H. Liao, Xiaoming Zheng, Xin Liu          | 2019 | Stock Market Exposure and Anxiety in a Turbulent Market: Evidence From China                                                                                        | Frontiers in Psychology                 | 10     | null        | [10.3389/fpsyg.2019.00328](https://doi.org/10.3389/fpsyg.2019.00328)                              |
# | 27   | Joo-Eon Park, 유범희, 채정호, 이승환, 류성곤, 김찬형, 오강섭, 김율리 | 2006 | The Effectiveness of 6-Month Treatment with Venlafaxine Extended Release in Generalized Anxiety Disorder: Prospective, Multi-Center, Open-Labeled Trial              | Not specified                           |        |             |                                                                                                   |
# | 28   | D. Ehde                                                | 2018 | Patient Health Questionnaire                                                                                                                                           | Not specified                           |        |             | [10.1007/978-3-319-57111-9_2002](https://doi.org/10.1007/978-3-319-57111-9_2002)                  |
# | 29   | K. Kroenke, M. Sharpe, R. Sykes                      | 2007 | Revising the classification of somatoform disorders: key questions and preliminary recommendations                                                                     | Psychosomatics                          | 48 4   | 277-85      | [10.1176/APPI.PSY.48.4.277](https://doi.org/10.1176/APPI.PSY.48.4.277)                            |
# | 30   | B. Löwe, R. Spitzer, Janet B W Williams, M. Mussell, D. Schellberg, K. Kroenke | 2008 | Depression, anxiety and somatization in primary care: syndrome overlap and functional impairment                                                                        | General Hospital Psychiatry             | 30 3   | 191-9       | [10.1016/j.genhosppsych.2008.01.001](https://doi.org/10.1016/j.genhosppsych.2008.01.001)          |
# | 31   | R. Spitzer, K. Kroenke, Janet B W Williams          | 1999 | Validation and utility of a self-report version of PRIME-MD: the PHQ primary care study. Primary Care Evaluation of Mental Disorders. Patient Health Questionnaire     | JAMA                                    | 282 18 | 1737-44     | [10.1001/JAMA.282.18.1737](https://doi.org/10.1001/JAMA.282.18.1737)                              |
# | 32   | A. Pinto-Meza, A. Serrano-Blanco, Maria T. Peñarrubia, E. Blanco, J. Haro | 2005 | Assessing depression in primary care with the PHQ-9: Can it be carried out over the telephone?                                                                         | Journal of General Internal Medicine    | 20     | 738-742     | [10.1111/j.1525-1497.2005.0144.x](https://doi.org/10.1111/j.1525-1497.2005.0144.x)                |
# | 33   | Jianbo Lai, Simeng Ma, Ying Wang, Zhongxiang Cai, Jianbo Hu, N. Wei, Jiang Wu, Hui Du, Tingting Chen, Ruiting Li, Huawei Tan, Lijun Kang, L. Yao, Manli Huang, Huafen Wang, Gaohua Wang, Zhongchun Liu, Shao-hua Hu | 2020 | Factors Associated With Mental Health Outcomes Among Health Care Workers Exposed to Coronavirus Disease 2019                                                          | JAMA Network Open                       | 3      | null        | [10.1001/jamanetworkopen.2020.3976](https://doi.org/10.1001/jamanetworkopen.2020.3976)            |
# | 34   | S. Gilbody, D. Richards, S. Brealey, C. Hewitt      | 2007 | Screening for Depression in Medical Settings with the Patient Health Questionnaire (PHQ): A Diagnostic Meta-Analysis                                                  | Journal of General Internal Medicine    | 22     | 1596-1602   | [10.1007/s11606-007-0333-y](https://doi.org/10.1007/s11606-007-0333-y)                            |
# | 35   | B. Löwe, J. Unützer, C. Callahan, A. Perkins, K. Kroenke | 2004 | Monitoring Depression Treatment Outcomes With the Patient Health Questionnaire-9                                                                                     | Medical Care                            | 42     | 1194-1201   | [10.1097/00005650-200412000-00006](https://doi.org/10.1097/00005650-200412000-00006)              |
# | 36   | K. Kroenke, R. Spitzer, Janet B W Williams          | 2001 | The PHQ-9: validity of a brief depression severity measure.                                                                                                           | Journal of General Internal Medicine    | 16 9   | 606-13      |                                                                                                   |
# | 37   | Frederick Y. Huang, Henry Chung, K. Kroenke, K. Delucchi, R. Spitzer | 2006 | Using the patient health questionnaire-9 to measure depression among racially and ethnically diverse primary care patients                                            | Journal of General Internal Medicine    | 21     | 547-552     | [10.1111/j.1525-1497.2006.00409.x](https://doi.org/10.1111/j.1525-1497.2006.00409.x)              |
# | 38   | B. Dear, N. Titov, M. Sunderland, D. McMillan,
#
#  T. Anderson, Carolyn N. Lorian, Emma Robinson | 2011 | Psychometric Comparison of the Generalized Anxiety Disorder Scale-7 and the Penn State Worry Questionnaire for Measuring Response during Treatment of Generalised Anxiety Disorder | Cognitive Behaviour Therapy             | 40     | 216 - 227   | [10.1080/16506073.2011.582138](https://doi.org/10.1080/16506073.2011.582138)                      |
# | 39   | N. Lossnitzer, Thomas Müller‐Tasch, B. Löwe, C. Zugck, M. Nelles, A. Remppis, M. Haass, B. Rauch, J. Jünger, W. Herzog, B. Wild | 2009 | Exploring potential associations of suicidal ideation and ideas of self‐harm in patients with congestive heart failure                                                 | Depression and Anxiety                  | 26     | null        | [10.1002/da.20587](https://doi.org/10.1002/da.20587)                                              |
# | 40   | H. Pincus, L. Hough, Jeanie Knox Houtsinger, B. Rollman, R. Frank | 2003 | Emerging models of depression care: multi‐level (‘6 P’) strategies                                                                                                    | International Journal of Methods in Psychiatric Research | 12     | null        | [10.1002/mpr.142](https://doi.org/10.1002/mpr.142)                                                |
# | 41   | L. Manea, S. Gilbody, D. McMillan                   | 2012 | Optimal cut-off score for diagnosing depression with the Patient Health Questionnaire (PHQ-9): a meta-analysis                                                        | Canadian Medical Association Journal    | 184    | E191 - E196 | [10.1503/cmaj.110829](https://doi.org/10.1503/cmaj.110829)                                        |
#
# ### Taxonomy
# ```
# - Factor
#     |__ Adjective
#         |__ Synonym
#         |__ Verb
#         |__ Noun
# ```

# %% [markdown]
# ##  Steps for SCID Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (SCID).
#     * **Actions:**
#         * Define the SCID dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the SCID dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the SCID dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our SCID Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5001/")

# Set up SCID experiment
experiment_name = "SCID"
mlflow.set_experiment(experiment_name)

# SCID dataset 


scid_dataset = {
    # Chapter 1: Neurodevelopmental Disorders
    "Neurodevelopmental Disorders": {
        "Intellectual Disability (Intellectual Developmental Disorder)": {
            "Synonyms": ["Cognitive Impairment", "Mental Retardation", "Developmental Delay"],
            "Verbs": ["Exhibit", "Demonstrate", "Experience", "Show", "Struggle with"],
            "Nouns": ["Deficits", "Limitations", "Impairment", "Challenges", "Difficulties"]
        },
        "Global Developmental Delay": {
            "Synonyms": ["Developmental Delay", "Delayed Development", "Developmental Disabilities"],
            "Verbs": ["Demonstrate", "Show", "Exhibit", "Struggle with", "Experience"],
            "Nouns": ["Delays", "Limitations", "Impairment", "Difficulties", "Challenges"]
        },
        "Unspecified Intellectual Disability": {
            "Synonyms": ["Cognitive Impairment", "Developmental Delay", "Unspecified Delay"],
            "Verbs": ["Show", "Exhibit", "Struggle with", "Experience", "Demonstrate"],
            "Nouns": ["Impairment", "Delay", "Limitation", "Challenge", "Difficulty"]
        },
        "Language Disorder": {
            "Synonyms": ["Language Impairment", "Communication Disorder", "Language Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Experience", "Have"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Speech Sound Disorder": {
            "Synonyms": ["Articulation Disorder", "Phonological Disorder", "Speech Impairment"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Errors", "Limitations", "Challenges"]
        },
        "Childhood-Onset Fluency Disorder (Stuttering)": {
            "Synonyms": ["Stuttering", "Fluency Disorder", "Speech Hesitation"],
            "Verbs": ["Stutter", "Hesitate", "Repeat", "Prolong", "Block"],
            "Nouns": ["Stutter", "Hesitation", "Repetition", "Prolongation", "Block"]
        },
        "Social Communication Disorder": {
            "Synonyms": ["Pragmatic Communication Disorder", "Social Language Deficit", "Communication Difficulties"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Deficits", "Impairment", "Limitations", "Challenges"]
        },
        "Other Specified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Unspecified Attention-Deficit/Hyperactivity Disorder": {
            "Synonyms": ["ADHD", "Attention Deficit", "Hyperactivity", "Impulsivity"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Inattention", "Hyperactivity", "Impulsivity", "Distractibility", "Challenges"]
        },
        "Specific Learning Disorder": {
            "Synonyms": ["Learning Disability", "Reading Disorder", "Dyslexia", "Mathematics Disorder", "Dyscalculia", "Disorder of Written Expression"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Difficulties", "Impairment", "Deficit", "Limitation", "Challenge"]
        },
        "Developmental Coordination Disorder": {
            "Synonyms": ["Dyspraxia", "Motor Coordination Disorder", "Clumsiness"],
            "Verbs": ["Struggle with", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Impairment", "Difficulties", "Deficits", "Limitations", "Challenges"]
        },
        "Stereotypic Movement Disorder": {
            "Synonyms": ["Repetitive Movement Disorder", "Stereotypies", "Motor Stereotypies"],
            "Verbs": ["Exhibit", "Show", "Engage in", "Perform", "Demonstrate"],
            "Nouns": ["Movements", "Behaviors", "Stereotypies", "Repetitions", "Mannerisms"]
        },
        "Tourette's Disorder": {
            "Synonyms": ["Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Persistent (Chronic) Motor or Vocal Tic Disorder": {
            "Synonyms": ["Chronic Tic Disorder", "Persistent Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Provisional Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Transient Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Other Specified Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Atypical Tic Disorder", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        },
        "Unspecified Tic Disorder": {
            "Synonyms": ["Tic Disorder", "Unspecified Tics", "Motor Tics", "Vocal Tics"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Tics", "Movements", "Vocalizations", "Behaviors", "Symptoms"]
        }
    },
    
    # Chapter 2: Schizophrenia Spectrum and Other Psychotic Disorders
    "Schizophrenia Spectrum and Other Psychotic Disorders": {
        "Schizotypal (Personality) Disorder": {
            "Synonyms": ["Eccentric Personality", "Odd Personality", "Schizotypy"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Eccentricity", "Oddity", "Peculiarity", "Distortions", "Deficits"]
        },
        "Delusional Disorder": {
            "Synonyms": ["Delusions", "Fixed Beliefs", "False Beliefs"],
            "Verbs": ["Experience", "Have", "Hold", "Believe", "Exhibit"],
            "Nouns": ["Delusions", "Beliefs", "Ideas", "Paranoia", "Suspicion"]
        },
        "Brief Psychotic Disorder": {
            "Synonyms": ["Brief Psychosis", "Psychotic Episode", "Transient Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophreniform Disorder": {
            "Synonyms": ["Schizophrenia-like Psychosis", "Short-term Schizophrenia", "Psychotic Episode"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Symptoms", "Episode", "Delusions", "Hallucinations"]
        },
        "Schizophrenia": {
            "Synonyms": ["Psychosis", "Schizophrenia Spectrum Disorder", "Thought Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Delusions", "Hallucinations", "Disorganized Thinking", "Negative Symptoms", "Psychotic Symptoms"]
        },
        "Schizoaffective Disorder": {
            "Synonyms": ["Schizophrenia and Mood Disorder", "Psychotic and Affective Symptoms", "Mixed Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Psychosis", "Mood Episodes", "Symptoms", "Delusions", "Hallucinations"]
        },
        "Other Specified Schizophrenia Spectrum and Other Psychotic Disorder": {
            "Synonyms": ["Atypical Psychosis", "Subthreshold Psychosis", "Unspecified Psychotic Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        },
        "Unspecified Schizophrenia Spectrum and Other Psychotic Disorder": {
            "Synonyms": ["Unspecified Psychosis", "Psychotic Symptoms", "Undifferentiated Psychosis"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Psychosis", "Delusions", "Hallucinations", "Thought Disorder"]
        }
    },
    
    # Chapter 3: Bipolar and Related Disorders
    "Bipolar and Related Disorders": {
        "Bipolar I Disorder": {
            "Synonyms": ["Bipolar Disorder", "Mania", "Manic-Depressive Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Bipolar II Disorder": {
            "Synonyms": ["Bipolar Disorder", "Hypomania", "Recurrent Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Hypomania", "Depression", "Mood Episodes", "Mood Swings", "Symptoms"]
        },
        "Cyclothymic Disorder": {
            "Synonyms": ["Cyclothymia", "Mood Instability", "Mild Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Swings", "Hypomanic Symptoms", "Depressive Symptoms", "Mood Instability", "Symptoms"]
        },
        "Substance/Medication-Induced Bipolar and Related Disorder": {
            "Synonyms": ["Substance-Induced Mood Disorder", "Medication-Induced Mood Disorder", "Secondary Bipolar Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Bipolar and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Bipolar Disorder", "Medical Condition-Induced Mood Disorder", "Mood Disorder Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Other Specified Bipolar and Related Disorder": {
            "Synonyms": ["Atypical Bipolar Disorder", "Subthreshold Bipolar Disorder", "Unspecified Mood Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        },
        "Unspecified Bipolar and Related Disorder": {
            "Synonyms": ["Unspecified Mood Disorder", "Bipolar Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Episodes", "Mania", "Depression", "Mood Swings", "Symptoms"]
        }
    },
    
    # Chapter 4: Depressive Disorders
    "Depressive Disorders": {
        "Disruptive Mood Dysregulation Disorder": {
            "Synonyms": ["DMDD", "Childhood Mood Disorder", "Temper Dysregulation"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Temper Outbursts", "Irritability", "Mood Dysregulation", "Emotional Lability", "Symptoms"]
        },
        "Major Depressive Disorder": {
            "Synonyms": ["MDD", "Clinical Depression", "Unipolar Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Sleep Disturbance", "Appetite Changes", "Fatigue"]
        },
        "Persistent Depressive Disorder (Dysthymia)": {
            "Synonyms": ["Dysthymia", "Chronic Depression", "Persistent Low Mood"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Low Self-Esteem", "Fatigue", "Hopelessness", "Symptoms"]
        },
        "Premenstrual Dysphoric Disorder (PMDD)": {
            "Synonyms": ["PMDD", "Premenstrual Mood Disorder", "Severe PMS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Mood Lability", "Irritability", "Depressed Mood", "Anxiety", "Symptoms"]
        },
        "Substance/Medication-Induced Depressive Disorder": {
            "Synonyms": ["Substance-Induced Depression", "Medication-Induced Depression", "Secondary Depression"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Depressive Disorder Due to Another Medical Condition": {
            "Synonyms": ["Secondary Depression", "Medical Condition-Induced Depression", "Depression Due to Illness"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Other Specified Depressive Disorder": {
            "Synonyms": ["Atypical Depression", "Subthreshold Depression", "Unspecified Depressive Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        },
        "Unspecified Depressive Disorder": {
            "Synonyms": ["Unspecified Depression", "Depressive Symptoms", "Mood Disturbance"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Depressed Mood", "Anhedonia", "Symptoms", "Mood Disturbance", "Affective Symptoms"]
        }
    },
        # Chapter 5: Anxiety Disorders
    "Anxiety Disorders": {
        "Separation Anxiety Disorder": {
            "Synonyms": ["Separation Anxiety", "Fear of Separation", "Attachment Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Distress", "Worry", "Symptoms"]
        },
        "Selective Mutism": {
            "Synonyms": ["Situational Mutism", "Social Mutism", "Non-speaking in Specific Situations"],
            "Verbs": ["Exhibit", "Show", "Have", "Experience", "Demonstrate"],
            "Nouns": ["Mutism", "Silence", "Anxiety", "Fear", "Inhibition"]
        },
        "Specific Phobia": {
            "Synonyms": ["Phobia", "Irrational Fear", "Specific Fear"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Fear", "Anxiety", "Avoidance", "Distress", "Symptoms"]
        },
        "Social Anxiety Disorder (Social Phobia)": {
            "Synonyms": ["Social Phobia", "Social Fear", "Performance Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Avoidance", "Panic", "Symptoms"]
        },
        "Panic Disorder": {
            "Synonyms": ["Panic Attacks", "Anxiety Disorder", "Acute Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Panic Attacks", "Palpitations", "Sweating", "Shortness of Breath", "Fear"]
        },
        "Agoraphobia": {
            "Synonyms": ["Fear of Public Places", "Open Spaces Anxiety", "Crowd Phobia"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Avoidance", "Panic", "Distress", "Symptoms"]
        },
        "Generalized Anxiety Disorder (GAD)": {
            "Synonyms": ["GAD", "Worry Disorder", "Chronic Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Worry", "Tension", "Sleep Disturbance", "Fatigue", "Symptoms"]
        },
        "Substance/Medication-Induced Anxiety Disorder": {
            "Synonyms": ["Drug-Induced Anxiety", "Medication Anxiety", "Secondary Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Panic", "Tremor", "Insomnia", "Symptoms"]
        },
        "Anxiety Disorder Due to Another Medical Condition": {
            "Synonyms": ["Medical Anxiety", "Secondary Medical Anxiety", "Illness Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Fear", "Somatic Symptoms", "Distress", "Symptoms"]
        },
        "Other Specified Anxiety Disorder": {
            "Synonyms": ["Atypical Anxiety", "Subthreshold Anxiety", "Unspecified Anxiety"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Avoidance"]
        },
        "Unspecified Anxiety Disorder": {
            "Synonyms": ["Unspecified Anxiety", "Non-specific Anxiety", "Anxiety NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Anxiety", "Worry", "Distress", "Symptoms", "Avoidance"]
        }
    },

    # Chapter 6: Obsessive-Compulsive and Related Disorders
    "Obsessive-Compulsive and Related Disorders": {
        "Obsessive-Compulsive Disorder (OCD)": {
            "Synonyms": ["OCD", "Obsessions", "Compulsions"],
            "Verbs": ["Experience", "Perform", "Repeat", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Anxiety", "Distress", "Rituals"]
        },
        "Body Dysmorphic Disorder": {
            "Synonyms": ["BDD", "Body Image Disorder", "Dysmorphophobia"],
            "Verbs": ["Preoccupy", "Obsess", "Compensate", "Check", "Avoid"],
            "Nouns": ["Preoccupation", "Distress", "Appearance Concerns", "Rituals", "Checking"]
        },
        "Hoarding Disorder": {
            "Synonyms": ["Compulsive Hoarding", "Clutter Disorder", "Hoarding"],
            "Verbs": ["Collect", "Fail to Discard", "Acquire", "Save", "Avoid"],
            "Nouns": ["Clutter", "Difficulty Discarding", "Distress", "Acquisition", "Possessions"]
        },
        "Trichotillomania (Hair-Pulling) Disorder": {
            "Synonyms": ["Hair Pulling Disorder", "Trichotillomania", "Hair-Pulling"],
            "Verbs": ["Pull", "Experience Urges", "Compel", "Engage", "Resist"],
            "Nouns": ["Hair Pulling", "Urges", "Bald Patches", "Distress", "Consequences"]
        },
        "Excoriation (Skin-Picking) Disorder": {
            "Synonyms": ["Skin-Picking Disorder", "Dermatillomania", "Skin Excoriation"],
            "Verbs": ["Pick", "Scratch", "Compel", "Engage", "Resist"],
            "Nouns": ["Skin Lesions", "Urges", "Distress", "Scarring", "Complications"]
        },
        "Substance/Medication-Induced Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Drug-Induced OCD", "Medication-Caused Compulsions"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Medication Context", "Symptoms"]
        },
        "Obsessive-Compulsive and Related Disorder Due to Another Medical Condition": {
            "Synonyms": ["Medical Condition-Induced OCD", "Secondary OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Medical Context", "Symptoms"]
        },
        "Other Specified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Atypical OCD", "Subthreshold OCD"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Symptoms", "Impairment"]
        },
        "Unspecified Obsessive-Compulsive and Related Disorder": {
            "Synonyms": ["Unspecified OCD", "OCD NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Obsessions", "Compulsions", "Distress", "Symptoms", "Impairment"]
        }
    },

    # Chapter 7: Trauma- and Stressor-Related Disorders
    "Trauma- and Stressor-Related Disorders": {
        "Posttraumatic Stress Disorder (PTSD)": {
            "Synonyms": ["PTSD", "Trauma Disorder", "Stress Disorder"],
            "Verbs": ["Experience", "Re-experience", "Avoid", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Memories", "Avoidance", "Hyperarousal", "Negative Mood", "Symptoms"]
        },
        "Acute Stress Disorder": {
            "Synonyms": ["ASD", "Acute Trauma Response", "Stress Reaction"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Intrusive Symptoms", "Dissociation", "Avoidance", "Arousal Symptoms", "Distress"]
        },
        "Adjustment Disorders": {
            "Synonyms": ["Adjustment Disorder", "Stress Response Syndrome", "Situational Distress"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Emotional Symptoms", "Behavioral Symptoms", "Distress", "Impairment", "Reactions"]
        },
        "Other Specified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Atypical Trauma Disorder", "Subthreshold Stress Disorder"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Reactions", "Impairment", "Arousal"]
        },
        "Unspecified Trauma- and Stressor-Related Disorder": {
            "Synonyms": ["Unspecified Trauma Disorder", "Stress Symptoms NOS"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Symptoms", "Distress", "Reactions", "Impairment", "Arousal"]
        }
    },

    # Chapter 8: Dissociative Disorders
    "Dissociative Disorders": {
        "Dissociative Identity Disorder": {
            "Synonyms": ["DID", "Multiple Personality Disorder", "Identity Fragmentation"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Multiple Identities", "Memory Gaps", "Amnesia", "Dissociation", "Alters"]
        },
        "Dissociative Amnesia": {
            "Synonyms": ["Psychogenic Amnesia", "Selective Amnesia", "Localized Amnesia"],
            "Verbs": ["Forget", "Have memory gaps", "Experience amnesia", "Show impairment", "Manifest dissociation"],
            "Nouns": ["Memory Loss", "Amnesia", "Fugue", "Identity Loss", "Dissociation"]
        },
        "Depersonalization/Derealization Disorder": {
            "Synonyms": ["Depersonalization", "Derealization", "Detachment Disorder"],
            "Verbs": ["Feel detached", "Perceive unreality", "Experience disconnection", "Show derealization", "Manifest depersonalization"],
            "Nouns": ["Detachment", "Unreality", "Distortion", "Dissociation", "Emotional Numbing"]
        },
        "Other Specified Dissociative Disorder": {
            "Synonyms": ["Atypical Dissociation", "Subthreshold Dissociation", "Unspecified Dissociative Symptoms"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Identity Confusion", "Altered Consciousness", "Memory Problems"]
        },
        "Unspecified Dissociative Disorder": {
            "Synonyms": ["Dissociative Symptoms NOS", "Undifferentiated Dissociation", "Dissociation Unspecified"],
            "Verbs": ["Experience", "Have", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Dissociation", "Symptoms", "Confusion", "Memory Gaps", "Impairment"]
        }
    },

    # Chapter 9: Somatic Symptom and Related Disorders
    "Somatic Symptom and Related Disorders": {
        "Somatic Symptom Disorder": {
            "Synonyms": ["Somatization Disorder", "Somatic Symptoms", "Physical Complaints"],
            "Verbs": ["Experience", "Report", "Exhibit", "Demonstrate", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Bodily Distress", "Health Anxiety", "Preoccupation", "Functional Impairment"]
        },
        "Illness Anxiety Disorder": {
            "Synonyms": ["Hypochondriasis", "Health Anxiety", "Illness Phobia"],
            "Verbs": ["Worry", "Preoccupy", "Fear", "Monitor", "Interpret"],
            "Nouns": ["Health Anxiety", "Preoccupation with Illness", "Fear of Disease", "Seeking Reassurance", "Somatic Focus"]
        },
        "Conversion Disorder (Functional Neurological Symptom Disorder)": {
            "Synonyms": ["Functional Neurological Disorder", "Psychogenic Neurological Symptoms"],
            "Verbs": ["Exhibit", "Demonstrate", "Report", "Manifest", "Experience"],
            "Nouns": ["Neurological Symptoms", "Motor Deficits", "Sensory Deficits", "Seizures", "Paralysis"]
        },
        "Psychological Factors Affecting Other Medical Conditions": {
            "Synonyms": ["Psychosomatic Factors", "Mind-Body Interaction", "Stress-Related Physical Illness"],
            "Verbs": ["Influence", "Exacerbate", "Contribute to", "Affect", "Modify"],
            "Nouns": ["Medical Condition", "Psychological Factors", "Symptom Severity", "Functional Impact", "Health Outcomes"]
        },
        "Other Specified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Atypical Somatic Disorder", "Subthreshold Somatic Symptoms"],
            "Verbs": ["Experience", "Report", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Distress", "Functional Impairment", "Health Anxiety", "Preoccupation"]
        },
        "Unspecified Somatic Symptom and Related Disorder": {
            "Synonyms": ["Somatic Symptoms NOS", "Unspecified Somatic Disorder"],
            "Verbs": ["Experience", "Report", "Show", "Exhibit", "Manifest"],
            "Nouns": ["Somatic Symptoms", "Distress", "Impairment", "Health Concerns", "Functional Impact"]
        }
    },

    # Chapter 10: Feeding and Eating Disorders
    "Feeding and Eating Disorders": {
        "Pica": {
            "Synonyms": ["Nonfood Eating", "Unusual Cravings", "Pica Behavior"],
            "Verbs": ["Eat", "Consume", "Ingest", "Crave", "Desire"],
            "Nouns": ["Non-nutritive Substances", "Cravings", "Consumption", "Behavioral Pattern", "Health Risk"]
        },
        "Rumination Disorder": {
            "Synonyms": ["Regurgitation Disorder", "Chronic Regurgitation", "Rumination"],
            "Verbs": ["Regurgitate", "Re-chew", "Swallow", "Expel", "Repeat"],
            "Nouns": ["Regurgitation", "Re-chewing", "Repeated Behavior", "Gastric Contents", "Behavioral Pattern"]
        },
        "Avoidant/Restrictive Food Intake Disorder": {
            "Synonyms": ["ARFID", "Selective Eating", "Eating Avoidance"],
            "Verbs": ["Avoid", "Restrict", "Refuse", "Limit", "Fear"],
            "Nouns": ["Restricted Intake", "Weight Loss", "Nutritional Deficiency", "Concern Avoidance", "Impact on Health"]
        },
        "Anorexia Nervosa": {
            "Synonyms": ["Anorexia", "Self-Starvation", "Fear of Weight Gain"],
            "Verbs": ["Restrict", "Lose Weight", "Fear", "Exercise", "Control"],
            "Nouns": ["Low Body Weight", "Intense Fear of Weight Gain", "Body Image Disturbance", "Amenorrhea (in females)", "Health Consequences"]
        },
        "Bulimia Nervosa": {
            "Synonyms": ["Bulimia", "Binge-Purge Syndrome", "Purging Disorder"],
            "Verbs": ["Binge", "Purge", "Compensate", "Restrict", "Vomit"],
            "Nouns": ["Recurrent Binge Eating", "Inappropriate Compensatory Behaviors", "Self-Evaluation Influenced by Body Shape", "Health Risks", "Electrolyte Imbalance"]
        },
        "Binge-Eating Disorder": {
            "Synonyms": ["BED", "Compulsive Overeating", "Emotional Eating"],
            "Verbs": ["Binge", "Overeat", "Consume", "Experience Loss of Control", "Feel Distressed"],
            "Nouns": ["Binge Episodes", "Distress", "Obesity Risk", "Feelings of Guilt", "Health Impact"]
        },
        "Other Specified Feeding or Eating Disorder": {
            "Synonyms": ["OSFED", "Subthreshold Eating Disorder", "Atypical Eating Disorder"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Fear"],
            "Nouns": ["Eating Behaviors", "Distress", "Body Image Concern", "Health Impact", "Atypical Features"]
        },
        "Unspecified Feeding or Eating Disorder": {
            "Synonyms": ["UFED", "Eating Disorder NOS", "Unspecified Eating Pathology"],
            "Verbs": ["Restrict", "Binge", "Purge", "Avoid", "Distress"],
            "Nouns": ["Eating Behaviors", "Distress", "Functional Impairment", "Health Concerns", "Diagnostic Uncertainty"]
        }
    },

    # Chapter 11: Elimination Disorders
    "Elimination Disorders": {
        "Enuresis": {
            "Synonyms": ["Bedwetting", "Urinary Incontinence", "Nocturnal Enuresis"],
            "Verbs": ["Wet", "Urinate", "Void", "Leak", "Have Accident"],
            "Nouns": ["Urine", "Incontinence", "Accidents", "Bedwetting", "Distress"]
        },
        "Encopresis": {
            "Synonyms": ["Soiling", "Fecal Incontinence", "Bowel Incontinence"],
            "Verbs": ["Soil", "Defecate", "Leak", "Have Accident", "Inadvertently Pass Stool"],
            "Nouns": ["Feces", "Soiling", "Incontinence", "Accidents", "Distress"]
        }
    },

    # Chapter 12: Sleep-Wake Disorders
    "Sleep-Wake Disorders": {
        "Insomnia Disorder": {
            "Synonyms": ["Insomnia", "Sleeplessness", "Nonrestorative Sleep"],
            "Verbs": ["Struggle to sleep", "Wake up early", "Experience nonrestorative sleep"],
            "Nouns": ["Difficulty Initiating Sleep", "Nonrestorative Sleep", "Daytime Fatigue", "Irritability", "Impaired Functioning"]
        },
        "Hypersomnolence Disorder": {
            "Synonyms": ["Hypersomnia", "Excessive Sleepiness", "Sleep Inertia"],
            "Verbs": ["Feel excessively sleepy", "Nap unintentionally", "Experience sleep inertia"],
            "Nouns": ["Excessive Sleepiness", "Unrefreshing Naps", "Sleep Inertia", "Impaired Alertness", "Difficulty Waking"]
        },
        "Narcolepsy": {
            "Synonyms": ["Narcolepsy", "Sleep Attacks", "Cataplexy"],
            "Verbs": ["Experience sleep attacks", "Have cataplexy", "Report hallucinations"],
            "Nouns": ["Irresistible Sleep Episodes", "Cataplexy", "Hypnagogic Hallucinations", "Sleep Paralysis", "Fragmented Sleep"]
        },
        "Obstructive Sleep Apnea Hypopnea": {
            "Synonyms": ["OSA", "Sleep Apnea", "Breathing-Related Sleep Disorder"],
            "Verbs": ["Snore", "Gasp", "Experience apneas"],
            "Nouns": ["Apneas", "Hypopneas", "Snoring", "Daytime Sleepiness", "Fatigue"]
        },
        "Central Sleep Apnea": {
            "Synonyms": ["Central Sleep Apnea", "CSA"],
            "Verbs": ["Experience central apneas", "Report daytime sleepiness"],
            "Nouns": ["Central Apneas", "Lack of Respiratory Effort", "Daytime Sleepiness", "Insomnia", "Cheyne-Stokes Breathing"]
        },
        "Sleep-Related Hypoventilation": {
            "Synonyms": ["Hypoventilation", "Nocturnal Hypoventilation"],
            "Verbs": ["Exhibit hypoventilation", "Have elevated CO2 levels"],
            "Nouns": ["Hypoventilation", "Hypercapnia", "Daytime Sleepiness", "Morning Headache", "Fatigue"]
        },
        "Circadian Rhythm Sleep-Wake Disorders": {
            "Synonyms": ["CRSWD", "Circadian Disorders"],
            "Verbs": ["Experience misaligned sleep", "Have irregular sleep patterns"],
            "Nouns": ["Phase Delay", "Phase Advance", "Irregular Schedule", "Non-24-Hour Rhythm", "Sleep-Wake Inversion"]
        },
        "Parasomnias": {
            "Synonyms": ["Nightmare Disorder", "REM Behavior Disorder", "NREM Arousals"],
            "Verbs": ["Experience nightmares", "Act out dreams", "Have night terrors"],
            "Nouns": ["Nightmares", "Dream Enactment", "Sleepwalking", "Sleep Terrors", "Confusional Arousals"]
        },
        "Restless Legs Syndrome": {
            "Synonyms": ["RLS", "Willis-Ekbom Disease"],
            "Verbs": ["Feel urge to move legs", "Experience unpleasant sensations"],
            "Nouns": ["Urge to Move", "Creeping Sensation", "Evening Worsening", "Sleep Disruption", "Daytime Fatigue"]
        },
        "Substance/Medication-Induced Sleep Disorder": {
            "Synonyms": ["Drug-Induced Sleep Problems"],
            "Verbs": ["Experience insomnia", "Have hypersomnia", "Develop parasomnias"],
            "Nouns": ["Sleep Disturbance", "Medication Context", "Insomnia", "Hypersomnia", "Parasomnia"]
        }
    },

    # Chapter 13: Sexual Dysfunctions
    "Sexual Dysfunctions": {
        "Delayed Ejaculation": {
            "Synonyms": ["Male Orgasmic Disorder", "Retarded Ejaculation", "Ejaculatory Inhibition"],
            "Verbs": ["Experience difficulty ejaculating", "Delay ejaculation", "Require prolonged stimulation", "Report distress", "Have infrequent orgasms"],
            "Nouns": ["Delay in ejaculation", "Infrequency of orgasm", "Reduced intensity of orgasm", "Marked distress", "Interpersonal Difficulty"]
        },
        "Erectile Disorder": {
            "Synonyms": ["Impotence", "Erectile Dysfunction", "Difficulty Achieving/Maintaining Erection"],
            "Verbs": ["Fail to achieve erection", "Fail to maintain erection", "Experience decreased rigidity", "Avoid sexual activity", "Report distress"],
            "Nouns": ["Erectile Difficulty", "Insufficient Rigidity", "Performance Anxiety", "Marked Distress", "Interpersonal Strain"]
        },
        "Female Orgasmic Disorder": {
            "Synonyms": ["Anorgasmia", "Inhibited Female Orgasm", "Difficulty Reaching Orgasm"],
            "Verbs": ["Experience delay or absence of orgasm", "Have reduced intensity of orgasm", "Require specific stimulation", "Report distress", "Feel frustration"],
            "Nouns": ["Orgasmic Difficulty", "Delayed Orgasm", "Absent Orgasm", "Reduced Intensity", "Marked Distress"]
        },
        "Female Sexual Interest/Arousal Disorder": {
            "Synonyms": ["Low Female Libido", "Reduced Sexual Arousal", "Hypoactive Sexual Desire"],
            "Verbs": ["Lack sexual interest", "Have reduced arousal", "Fail to respond to sexual stimulation", "Report distress", "Avoid sexual activity"],
            "Nouns": ["Reduced Interest", "Absent Arousal", "Lack of Desire", "Marked Distress", "Functional Impairment"]
        },
        "Genito-Pelvic Pain/Penetration Disorder": {
            "Synonyms": ["Dyspareunia", "Vaginismus", "Painful Intercourse"],
            "Verbs": ["Experience pain during intercourse", "Tense pelvic floor muscles", "Avoid penetration", "Fear pain", "Report distress"],
            "Nouns": ["Genital Pain", "Pelvic Pain", "Fear of Penetration", "Muscle Tension", "Marked Distress"]
        },
        "Male Hypoactive Sexual Desire Disorder": {
            "Synonyms": ["Low Male Libido", "Reduced Sexual Desire"],
            "Verbs": ["Lack sexual desire", "Have reduced fantasies", "Report distress", "Avoid sexual activity", "Feel frustration"],
            "Nouns": ["Reduced Desire", "Absent Fantasies", "Deficient Interest", "Marked Distress", "Functional Impact"]
        },
        "Premature (Early) Ejaculation": {
            "Synonyms": ["Rapid Ejaculation", "Early Climax"],
            "Verbs": ["Ejaculate prematurely", "Experience lack of control", "Feel distress", "Avoid intercourse", "Report frustration"],
            "Nouns": ["Early Ejaculation", "Lack of Control", "Marked Distress", "Interpersonal Difficulty", "Frustration"]
        },
        "Other Specified Sexual Dysfunction": {
            "Synonyms": ["Atypical Sexual Dysfunction", "Subthreshold Sexual Dysfunction"],
            "Verbs": ["Experience sexual difficulties", "Report distress", "Have impaired desire or arousal"],
            "Nouns": ["Sexual Dysfunction Symptoms", "Distress", "Interpersonal Impact", "Atypical Features", "Functional Impairment"]
        },
        "Unspecified Sexual Dysfunction": {
            "Synonyms": ["Sexual Dysfunction NOS", "Unspecified Sexual Disorder"],
            "Verbs": ["Experience sexual issues", "Report distress", "Present unspecified dysfunction"],
            "Nouns": ["Sexual Dysfunction Symptoms", "Distress", "Interpersonal Impact", "Diagnostic Uncertainty", "Functional Impairment"]
        }
    },

    # Chapter 14: Gender Dysphoria
    "Gender Dysphoria": {
        "Gender Dysphoria in Children": {
            "Synonyms": ["Childhood Gender Dysphoria", "Early-Onset Gender Incongruence"],
            "Verbs": ["Express", "Insist", "Demonstrate", "Feel", "Desire"],
            "Nouns": ["Incongruence", "Distress", "Discomfort", "Cross‑gender Identification", "Desire to Be Other Gender"]
        },
        "Gender Dysphoria in Adolescents and Adults": {
            "Synonyms": ["Adolescent Gender Dysphoria", "Adult Gender Dysphoria", "Persistent Gender Incongruence"],
            "Verbs": ["Experience", "Express", "Desire", "Identify as", "Feel"],
            "Nouns": ["Incongruence", "Distress", "Identity Conflict", "Discomfort", "Desire for Transition"]
        },
        "Other Specified Gender Dysphoria": {
            "Synonyms": ["Atypical Gender Dysphoria", "Subthreshold Gender Incongruence"],
            "Verbs": ["Exhibit", "Show", "Experience", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Incongruence", "Distress", "Identity Concerns", "Discomfort"]
        },
        "Unspecified Gender Dysphoria": {
            "Synonyms": ["Gender Incongruence NOS", "Undefined Gender Dysphoria"],
            "Verbs": ["Experience", "Manifest", "Show", "Have", "Demonstrate"],
            "Nouns": ["Incongruence", "Distress", "Discomfort", "Identity Concern", "Dysphoria"]
        }
    },
    # Chapter 15: Disruptive, Impulse-Control, and Conduct Disorders
    "Disruptive, Impulse-Control, and Conduct Disorders": {
        "Oppositional Defiant Disorder": {
            "Synonyms": ["ODD", "Defiant Behavior", "Argumentative Behavior"],
            "Verbs": ["Argue", "Defy", "Deliberately Annoy", "Blame", "Refuse"],
            "Nouns": ["Defiance", "Irritability", "Vindictiveness", "Anger", "Blaming"]
        },
        "Intermittent Explosive Disorder": {
            "Synonyms": ["IED", "Impulse Aggression", "Anger Outbursts"],
            "Verbs": ["Explode", "Rage", "Outburst", "Lose Control", "Aggress"],
            "Nouns": ["Anger", "Outbursts", "Aggression", "Impulsivity", "Regret"]
        },
        "Conduct Disorder": {
            "Synonyms": ["CD", "Antisocial Behavior", "Rule-Breaking"],
            "Verbs": ["Steal", "Destroy", "Aggress", "Deceive", "Violate"],
            "Nouns": ["Aggression", "Property Destruction", "Theft", "Deceit", "Rule Violations"]
        },
        "Pyromania": {
            "Synonyms": ["Fire-Setting Disorder", "Arsonistic Impulse"],
            "Verbs": ["Set Fire", "Fascinated by Fire", "Observe Flames", "Plan Arson", "Ignite"],
            "Nouns": ["Fire-Setting", "Fascination", "Tension Before", "Relief After", "Arson"]
        },
        "Kleptomania": {
            "Synonyms": ["Stealing Impulse", "Shoplifting Disorder"],
            "Verbs": ["Steal", "Impulse Steal", "Pocket", "Conceal", "Experience Urge"],
            "Nouns": ["Urge", "Stealing", "Tension", "Relief", "Shame"]
        },
        "Other Specified Disruptive, Impulse-Control, and Conduct Disorder": {
            "Synonyms": ["Atypical Disruptive Disorder", "Subthreshold Conduct"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Behaviors", "Aggression", "Defiance", "Impulsivity"]
        },
        "Unspecified Disruptive, Impulse-Control, and Conduct Disorder": {
            "Synonyms": ["Unspecified Disruptive Behavior"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Behaviors", "Aggression", "Defiance", "Impulsivity"]
        }
    },
    
    # Chapter 16: Substance-Related and Addictive Disorders
    "Substance-Related and Addictive Disorders": {
        "Alcohol Use Disorder": {
            "Synonyms": ["AUD", "Alcohol Dependence", "Alcohol Abuse"],
            "Verbs": ["Drink", "Crave", "Binge", "Continue Despite", "Experience Withdrawal"],
            "Nouns": ["Craving", "Tolerance", "Withdrawal", "Impaired Control", "Use Despite Harm"]
        },
        "Caffeine Use Disorder": {
            "Synonyms": ["Caffeine Dependence", "Caffeine Abuse"],
            "Verbs": ["Consume", "Crave", "Overuse", "Experience Withdrawal", "Require Dose"],
            "Nouns": ["Tolerance", "Withdrawal", "Overuse", "Craving", "Headache"]
        },
        "Cannabis Use Disorder": {
            "Synonyms": ["Marijuana Use Disorder", "Cannabis Dependence"],
            "Verbs": ["Smoke", "Vape", "Crave", "Overuse", "Experience Withdrawal"],
            "Nouns": ["Tolerance", "Withdrawal", "Craving", "Impaired Control", "Use Despite Harm"]
        },
        "Gambling Disorder": {
            "Synonyms": ["Compulsive Gambling", "Pathological Gambling"],
            "Verbs": ["Gamble", "Chase Losses", "Lie", "Borrow", "Feel Urge"],
            "Nouns": ["Craving", "Loss Chasing", "Impulsivity", "Preoccupation", "Financial Harm"]
        },
        "Other Specified Substance-Related and Addictive Disorder": {
            "Synonyms": ["Atypical Use Disorder"],
            "Verbs": ["Use", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Tolerance", "Withdrawal", "Craving", "Impairment"]
        },
        "Unspecified Substance-Related and Addictive Disorder": {
            "Synonyms": ["Substance Use NOS"],
            "Verbs": ["Use", "Exhibit", "Show", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Tolerance", "Withdrawal", "Craving", "Impairment"]
        }
    },
    
    # Chapter 17: Neurocognitive Disorders
    "Neurocognitive Disorders": {
        "Delirium": {
            "Synonyms": ["Acute Confusional State", "Toxic Encephalopathy"],
            "Verbs": ["Fluctuate", "Disorient", "Hallucinate", "Be Confused", "Show Inattention"],
            "Nouns": ["Disorientation", "Hallucinations", "Inattention", "Fluctuating Consciousness", "Confusion"]
        },
        "Major Neurocognitive Disorder": {
            "Synonyms": ["Major NCD", "Dementia"],
            "Verbs": ["Forget", "Confuse", "Lose", "Impair", "Repeat"],
            "Nouns": ["Memory Loss", "Impairment", "Aphasia", "Apraxia", "Agnosia"]
        },
        "Mild Neurocognitive Disorder": {
            "Synonyms": ["Mild NCD", "Mild Cognitive Impairment"],
            "Verbs": ["Forget", "Misplace", "Struggle", "Notice", "Experience"],
            "Nouns": ["Memory Complaints", "Reduced Function", "Impairment", "Attention Problems", "Executive Dysfunction"]
        },
        "Other Specified Neurocognitive Disorder": {
            "Synonyms": ["Atypical NCD"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Impairment", "Memory", "Attention", "Executive Dysfunction"]
        },
        "Unspecified Neurocognitive Disorder": {
            "Synonyms": ["Unspecified Cognitive Disorder"],
            "Verbs": ["Exhibit", "Show", "Manifest", "Have", "Demonstrate"],
            "Nouns": ["Symptoms", "Impairment", "Memory", "Attention", "Executive Dysfunction"]
        }
    },
    
    # Chapter 18: Personality Disorders
    "Personality Disorders": {
        "Paranoid Personality Disorder": {
            "Synonyms": ["Paranoid PD", "Suspicious Personality"],
            "Verbs": ["Suspect", "Mistrust", "Bear Grudges", "Read Hidden Meanings", "Be Vigilant"],
            "Nouns": ["Distrust", "Suspicion", "Grudges", "Hypervigilance", "Hostility"]
        },
        "Schizoid Personality Disorder": {
            "Synonyms": ["Schizoid PD", "Detached Personality"],
            "Verbs": ["Withdraw", "Prefer Solitude", "Be Indifferent", "Show Flat Affect", "Avoid Relationships"],
            "Nouns": ["Detachment", "Emotional Coldness", "Solitude", "Indifference", "Aloofness"]
        },
        "Schizotypal Personality Disorder": {
            "Synonyms": ["Schizotypal PD", "Eccentric Personality"],
            "Verbs": ["Magical Thinking", "Be Eccentric", "Be Suspicious", "Show Odd Speech", "Isolate"],
            "Nouns": ["Eccentricity", "Odd Beliefs", "Suspicion", "Oddness", "Social Anxiety"]
        },
        "Antisocial Personality Disorder": {
            "Synonyms": ["ASPD", "Psychopathy", "Sociopathy"],
            "Verbs": ["Deceive", "Exploit", "Violate Rights", "Be Irresponsible", "Aggress"],
            "Nouns": ["Deceit", "Impulsivity", "Lack of Remorse", "Aggression", "Irresponsibility"]
        },
        "Borderline Personality Disorder": {
            "Synonyms": ["BPD", "Emotionally Unstable Personality"],
            "Verbs": ["Idealize", "Devalue", "Self-Harm", "Fear Abandonment", "Mood Swing"],
            "Nouns": ["Instability", "Impulsivity", "Fear of Abandonment", "Identity Disturbance", "Affective Dysregulation"]
        },
        "Histrionic Personality Disorder": {
            "Synonyms": ["HPD", "Dramatic Personality"],
            "Verbs": ["Seek Attention", "Be Seductive", "Show Shallow Emotions", "Use Appearance", "Be Theatrical"],
            "Nouns": ["Attention-Seeking", "Shallowness", "Seductiveness", "Drama", "Suggestibility"]
        },
        "Narcissistic Personality Disorder": {
            "Synonyms": ["NPD", "Grandiose Personality"],
            "Verbs": ["Grandstand", "Require Admiration", "Exploit", "Envy", "Lack Empathy"],
            "Nouns": ["Grandiosity", "Entitlement", "Need for Admiration", "Envy", "Lack of Empathy"]
        },
        "Avoidant Personality Disorder": {
            "Synonyms": ["AvPD", "Social Inhibition"],
            "Verbs": ["Avoid", "Be Hypersensitive", "Fear Criticism", "Be Shy", "Be Inhibited"],
            "Nouns": ["Avoidance", "Hypersensitivity", "Shyness", "Inhibition", "Low Self-Esteem"]
        },
        "Dependent Personality Disorder": {
            "Synonyms": ["DPD", "Submissive Personality"],
            "Verbs": ["Depend", "Cling", "Be Submissive", "Seek Reassurance", "Be Passive"],
            "Nouns": ["Dependency", "Clinging", "Submissiveness", "Fear of Separation", "Helplessness"]
        },
        "Obsessive-Compulsive Personality Disorder": {
            "Synonyms": ["OCPD", "Perfectionistic Personality"],
            "Verbs": ["Order", "Control", "Be Rigorous", "Be Inflexible", "Preoccupy"],
            "Nouns": ["Preoccupation with Order", "Perfectionism", "Rigidity", "Control", "Overconscientiousness"]
        },
        "Other Specified Personality Disorder": {
            "Synonyms": ["Atypical PD"],
            "Verbs": ["Exhibit", "Show", "Demonstrate"],
            "Nouns": ["Symptoms", "Personality Traits", "Impairment"]
        },
        "Unspecified Personality Disorder": {
            "Synonyms": ["Personality Disorder NOS"],
            "Verbs": ["Exhibit", "Show", "Demonstrate"],
            "Nouns": ["Symptoms", "Personality Traits", "Impairment"]
        }
    },
    
    # Chapter 19: Paraphilic Disorders
    "Paraphilic Disorders": {
        "Voyeuristic Disorder": {
            "Synonyms": ["Peeping Tom Disorder"],
            "Verbs": ["Observe", "Spying", "Peep", "Expose Behavior", "Experience Arousal"],
            "Nouns": ["Observation", "Voyeurism", "Arousal", "Risk", "Secrecy"]
        },
        "Exhibitionistic Disorder": {
            "Synonyms": ["Flasher Disorder"],
            "Verbs": ["Expose", "Flash", "Reveal", "Experience Arousal", "Be Excited"],
            "Nouns": ["Exposure", "Arousal", "Shock", "Risk", "Secrecy"]
        },
        "Frotteuristic Disorder": {
            "Synonyms": ["Toucher Disorder"],
            "Verbs": ["Rub", "Touch", "Graze", "Experience Arousal", "Be Excited"],
            "Nouns": ["Touching", "Arousal", "Risk", "Violation", "Secrecy"]
        },
        "Sexual Masochism Disorder": {
            "Synonyms": ["Masochism"],
            "Verbs": ["Experience Pain", "Be Humiliated", "Arouse", "Seek Pain", "Consent"],
            "Nouns": ["Pain", "Humiliation", "Arousal", "Consent", "Fantasy"]
        },
        "Sexual Sadism Disorder": {
            "Synonyms": ["Sadism"],
            "Verbs": ["Inflict Pain", "Arouse", "Dominate", "Degrade", "Consent"],
            "Nouns": ["Pain", "Dominance", "Arousal", "Consent", "Fantasy"]
        },
        "Pedophilic Disorder": {
            "Synonyms": ["Pedophilia"],
            "Verbs": ["Arouse", "Have Fantasies", "Plan", "Seek Contact", "Experience Distress"],
            "Nouns": ["Attraction", "Fantasy", "Risk", "Distress", "Illegal Behavior"]
        },
        "Fetishistic Disorder": {
            "Synonyms": ["Fetish"],
            "Verbs": ["Use Object", "Arouse", "Collect", "Focus", "Experience Arousal"],
            "Nouns": ["Object", "Arousal", "Fetish", "Fantasy", "Impairment"]
        },
        "Transvestic Disorder": {
            "Synonyms": ["Cross-Dressing Disorder"],
            "Verbs": ["Dress", "Arouse", "Experience Arousal", "Focus", "Fantasy"],
            "Nouns": ["Cross-Dressing", "Arousal", "Fantasy", "Distress", "Impairment"]
        },
        "Other Specified Paraphilic Disorder": {
            "Synonyms": ["Atypical Paraphilia"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Arousal", "Distress"]
        },
        "Unspecified Paraphilic Disorder": {
            "Synonyms": ["Paraphilia NOS"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Arousal", "Distress"]
        }
    },
    
    # Chapter 20: Medication-Induced Movement Disorders and Other Adverse Effects
    "Medication-Induced Movement Disorders and Other Adverse Effects of Medication": {
        "Neuroleptic-Induced Parkinsonism": {
            "Synonyms": ["Medication-Induced Parkinsonism"],
            "Verbs": ["Tremble", "Stiffen", "Move Slowly", "Be Rigid", "Shamble"],
            "Nouns": ["Tremor", "Rigidity", "Bradykinesia", "Shuffling Gait", "Mask-like Face"]
        },
        "Acute Dystonia": {
            "Synonyms": ["Dystonic Reaction"],
            "Verbs": ["Spasm", "Twist", "Contract", "Distort", "Experience Pain"],
            "Nouns": ["Spasm", "Contraction", "Torticollis", "Oculogyric Crisis", "Pain"]
        },
        "Akathisia": {
            "Synonyms": ["Restlessness"],
            "Verbs": ["Pace", "Fidget", "Be Restless", "Shift Weight", "Feel Inner Tension"],
            "Nouns": ["Restlessness", "Agitation", "Inner Tension", "Pacing", "Fidgeting"]
        },
        "Tardive Dyskinesia": {
            "Synonyms": ["Late-Onset Dyskinesia"],
            "Verbs": ["Grimace", "Lip-Smack", "Chew", "Chatter", "Involuntary Movement"],
            "Nouns": ["Grimacing", "Lip Smacking", "Chewing Movements", "Chorea", "Tardive Dyskinesia"]
        },
        "Medication-Induced Postural Tremor": {
            "Synonyms": ["Action Tremor"],
            "Verbs": ["Tremble", "Shake", "Hold Position", "Be Unsteady"],
            "Nouns": ["Tremor", "Shaking", "Postural Instability", "Unsteadiness"]
        },
        "Other Specified Medication-Induced Movement Disorder": {
            "Synonyms": ["Atypical MED Disorder"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Movement", "Adverse Effect"]
        },
        "Unspecified Medication-Induced Movement Disorder": {
            "Synonyms": ["MED Disorder NOS"],
            "Verbs": ["Exhibit", "Show", "Manifest"],
            "Nouns": ["Symptoms", "Movement", "Adverse Effect"]
        }
    },
    
    # Chapter 21: Other Conditions That May Be a Focus of Clinical Attention
    "Other Conditions That May Be a Focus of Clinical Attention": {
        "Relational Problems": {
            "Synonyms": ["Relationship Issues", "Interpersonal Difficulties"],
            "Verbs": ["Argue", "Withdraw", "Miscommunicate", "Strain", "Conflict"],
            "Nouns": ["Conflict", "Tension", "Misunderstanding", "Separation", "Alienation"]
        },
        "Abuse and Neglect": {
            "Synonyms": ["Maltreatment", "Child Abuse", "Elder Neglect"],
            "Verbs": ["Harm", "Neglect", "Abuse", "Exploit", "Witness"],
            "Nouns": ["Abuse", "Neglect", "Trauma", "Maltreatment", "Violation"]
        },
        "Educational and Occupational Problems": {
            "Synonyms": ["School Issues", "Work Issues"],
            "Verbs": ["Struggle", "Fail", "Be Absent", "Conflict", "Underperform"],
            "Nouns": ["Underachievement", "Absenteeism", "Conflict", "Discipline", "Stress"]
        },
        "Housing and Economic Problems": {
            "Synonyms": ["Homelessness", "Financial Strain"],
            "Verbs": ["Struggle", "Lack", "Default", "Evicted", "Worry"],
            "Nouns": ["Homelessness", "Financial Hardship", "Eviction", "Poverty", "Debt"]
        },
        "Other Health Service Encounters for Counseling and Medical Advice": {
            "Synonyms": ["Z-Codes", "Counseling Encounters"],
            "Verbs": ["Seek", "Receive", "Attend", "Consult"],
            "Nouns": ["Encounter", "Counseling", "Advice", "Referral"]
        },
        "Other Specified Condition": {
            "Synonyms": ["Atypical Clinical Focus"],
            "Verbs": ["Exhibit", "Show", "Have"],
            "Nouns": ["Problem", "Concern", "Issue"]
        },
        "Unspecified Condition": {
            "Synonyms": ["Clinical Issue NOS"],
            "Verbs": ["Exhibit", "Show", "Have"],
            "Nouns": ["Problem", "Concern", "Issue"]
        }
    }
}


#Create a list to store the dataset
data = []
for factor, attributes in scid_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
scid_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/scid.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="SCID Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "SCID")
    mlflow.log_param("Total Rows", len(scid_df))
    mlflow.log_param("Total Factors", len(scid_dataset))
    mlflow.log_param("Data Schema", str(scid_df.columns.tolist()))
    
    # Save dataset to CSV
    scid_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ SCID dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(scid_df.head())
    print("\nDataset shape:", scid_df.shape)
    print("\nNumber of unique Factors:", scid_df['Factor'].nunique())
    print("Unique Factors:", scid_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# 2025/05/12 18:45:00 INFO mlflow.tracking.fluent: Experiment with name 'SCID' does not exist. Creating a new experiment.
# ✅ SCID dataset created and saved to ../Datasets/scid.csv
# First 5 rows of the dataset:
#                          Factor  \
# 0  Neurodevelopmental Disorders
# 1  Neurodevelopmental Disorders
# 2  Neurodevelopmental Disorders
# 3  Neurodevelopmental Disorders
# 4  Neurodevelopmental Disorders
#
#                                            Adjective               Synonym  \
# 0  Intellectual Disability (Intellectual Developm...  Cognitive Impairment
# 1  Intellectual Disability (Intellectual Developm...    Mental Retardation
# 2  Intellectual Disability (Intellectual Developm...   Developmental Delay
# 3                         Global Developmental Delay   Developmental Delay
# 4                         Global Developmental Delay   Delayed Development
#
#           Verb         Noun
# 0      Exhibit     Deficits
# 1  Demonstrate  Limitations
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="scid_page_2"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5001/#/experiments/1/runs/a3249e98b164403da6c6c5aa58c5df01
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="scid_page_2"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.01842353865504265, -0.00725775770843029, 0.0036669441033154726, -0.0542047917842865, -0.022724902257323265, 0.03694858402013779, 0.02903103083372116, 0.023866858333349228, 0.011229223571717739, -0.020618630573153496]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5001/#/experiments/1/runs/1230c33ad34c483abe4fc46591496960
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create SCID Embeddings** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved scid dataset from a CSV file
dataset_path = '../Datasets/scid.csv'
try:
    scid_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'scid_df' is empty before processing
        if scid_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", scid_df.shape[0])
            print(f"📊 Processing {scid_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        scid_df['Embedding'] = scid_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/scid_embeddings.csv'
        scid_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = scid_df.shape[0]
        num_columns = scid_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in scid_df.columns and not scid_df['Embedding'].empty:
            embedding_length = len(scid_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(scid_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/scid.csv
# ⏳ Embedding generation started at: 2025-05-12 18:45:38.655501
# 📊 Processing 401 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-05-12 18:47:48.608502 (Duration: 0:02:09.953001)
# 💾 Embeddings saved to: ../Embeddings/scid_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#                          Factor  \
# 0  Neurodevelopmental Disorders
# 1  Neurodevelopmental Disorders
# 2  Neurodevelopmental Disorders
# 3  Neurodevelopmental Disorders
# 4  Neurodevelopmental Disorders
#
#                                            Adjective               Synonym  \
# 0  Intellectual Disability (Intellectual Developm...  Cognitive Impairment
# 1  Intellectual Disability (Intellectual Developm...    Mental Retardation
# 2  Intellectual Disability (Intellectual Developm...   Developmental Delay
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/scid_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/scid_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "scid_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/scid_embeddings.csv
# 💾 Label encoder saved to: ../Models/scid_label_encoder.pkl
#
# First 5 rows with encoded labels:
#                          Factor  Factor_Encoded
# 0  Neurodevelopmental Disorders              10
# 1  Neurodevelopmental Disorders              10
# 2  Neurodevelopmental Disorders              10
# 3  Neurodevelopmental Disorders              10
# 4  Neurodevelopmental Disorders              10
#
# Mapping of original labels to encoded labels:
# Anxiety Disorders: 0
# Bipolar and Related Disorders: 1
# Depressive Disorders: 2
# Disruptive, Impulse-Control, and Conduct Disorders: 3
# Dissociative Disorders: 4
# Elimination Disorders: 5
# Feeding and Eating Disorders: 6
# Gender Dysphoria: 7
# Medication-Induced Movement Disorders and Other Adverse Effects of Medication: 8
# Neurocognitive Disorders: 9
# Neurodevelopmental Disorders: 10
# Obsessive-Compulsive and Related Disorders: 11
# ...

# %%
#%pip install seaborn

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/scid_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/scid_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="scid Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "scid_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "scid_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "scid_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/scid_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/scid_embeddings.csv
# ✅ Label encoder loaded from: ../Models/scid_label_encoder.pkl
# ⏳ Model training started at: 2025-05-12 18:48:38.407530
# ✅ Model training finished at: 2025-05-12 18:48:39.341488 (Duration: 0:00:00.933958)
# 📊 Classification report saved to: scid_classification_report.csv
# 📊 Confusion matrix saved to: scid_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: scid_confusion_matrix.png
# 💾 Trained model saved to: ../Models/scid_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                                                                                 precision    recall  f1-score   support
#
#                                                             Anxiety Disorders       1.00      1.00      1.00         7
#                                                 Bipolar and Related Disorders       1.00      1.00      1.00         4
# ...

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/scid_embeddings.csv'
label_encoder_path = "../Models/scid_label_encoder.pkl"
model_path = "../Models/scid_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate SCID Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate SCID Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "scid_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "scid_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "scid_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ SCID Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/scid_embeddings.csv
# ✅ Label encoder loaded from: ../Models/scid_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/scid_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: scid_evaluation_classification_report.csv
#
# Classification Report:
#                                                                                 precision    recall  f1-score   support
#
#                                                             Anxiety Disorders       1.00      1.00      1.00         7
#                                                 Bipolar and Related Disorders       1.00      1.00      1.00         4
#                                                          Depressive Disorders       1.00      1.00      1.00         5
#                            Disruptive, Impulse-Control, and Conduct Disorders       1.00      1.00      1.00         3
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/scid_label_encoder.pkl"
model_path = "../Models/scid_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/scid_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/scid_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Neurodevelopmental Disorders
# Predicted Factor for 'I prefer staying home with a good book....': Sleep-Wake Disorders
# Predicted Factor for 'I often feel anxious and worried....': Anxiety Disorders
# Predicted Factor for 'I am generally calm and relaxed....': Neurodevelopmental Disorders
# Predicted Factor for 'I enjoy taking risks and trying new things....': Anxiety Disorders
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5001/#/experiments/1/runs/6db5ba35f44348fb9aa8ea2e355cb341
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/scid_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="SCID Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/scid_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "scid_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/scid_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of SCID Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/scid_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of SCID Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/05/12 18:49:37 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Neurodevelopmental Disorders
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Sleep-Wake Disorders
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Neurodevelopmental Disorders
# Predicted Factor for 'Organized Meticulous Plan Planner': Anxiety Disorders
# Predicted Factor for 'Moody Anxious Worry Worrier': Anxiety Disorders
# 🏃 View run SCID Model Visualization and Evaluation at: http://127.0.0.1:5001/#/experiments/1/runs/47701fcee22e490998d822190ee1e8e0
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/scid_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/scid_label_encoder.pkl"
        model_path = "../Models/scid_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of SCID Embeddings")

            # Save and log the plot
            pca_plot_path = "scid_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "scid_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/gad7_embeddings.csv
#
# DataFrame with Embeddings:
#                                  Factor Adjective       Synonym    Verb  \
# 0  Feeling Nervous, Anxious, or On Edge   Anxious  Apprehensive   Worry
# 1  Feeling Nervous, Anxious, or On Edge   Anxious        Uneasy    Fret
# 2  Feeling Nervous, Anxious, or On Edge   Anxious    Distressed  Stress
# 3  Feeling Nervous, Anxious, or On Edge   Anxious      Agitated  Obsess
# 4  Feeling Nervous, Anxious, or On Edge   Anxious     Concerned   Panic
#
#            Noun                                          Embedding
# 0       Anxiety  [-0.015006320551037788, -0.019211668521165848,...
# 1      Distress  [-0.0035604897420853376, -0.021904608234763145...
# 2     Agitation  [0.0007335240370593965, -0.017836129292845726,...
# 3        Unease  [-0.006110618822276592, -0.014834330417215824,...
# 4  Apprehension  [0.0022602148819714785, -0.03806403651833534, ...
#
# Shape of DataFrame:
# (252, 6)
# ...

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [0.97530864 0.975      1.         0.9625     0.975     ]
# Mean cross-validation score: 0.9775617283950616

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="scid_page_3"></a>
#
# [Back to Top](#scid_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/scid_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_scid.pkl')
clf = joblib.load('../Models/scid_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Neurodevelopmental Disorders
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Anxiety Disorders
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Neurodevelopmental Disorders
# Predicted Factor for 'Organized Meticulous Plan Planner': Neurodevelopmental Disorders
# Predicted Factor for 'Moody Anxious Worry Worrier': Anxiety Disorders
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Neurodevelopmental Disorders

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Neurodevelopmental Disorders

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Anxiety Disorders

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Anxiety Disorders

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Depressive Disorders

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Personality Disorders

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="SCID_page_4"></a>
#
#
# [Back to Top](#SCID_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("SCID")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5001/#/experiments/1/runs/78f40c6b116e46c3b303988c352fe384
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/1

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create SCID Schema in Neo4j** <a class="anchor" id="SCID_page_4"></a>
#
#
# [Back to Top](#SCID_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("SCID")

# Load the dataset
dataset_path = "../Embeddings/scid_embeddings.csv"
scid_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in scid_df.columns:
    scid_df['Embedding'] = scid_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the SCID schema in Neo4j
def create_scid_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with SCID labels
        graph.run("MERGE (f:SCID_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:SCID_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:SCID_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:SCID_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:SCID_Noun {name: $noun})", noun=noun)
        
        # Create relationships with SCID namespacing
        graph.run("""
            MATCH (f:SCID_Factor {name: $factor}), (a:SCID_Adjective {name: $adjective})
            MERGE (f)-[:SCID_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:SCID_Adjective {name: $adjective}), (s:SCID_Synonym {name: $synonym})
            MERGE (a)-[:SCID_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:SCID_Adjective {name: $adjective}), (v:SCID_Verb {name: $verb})
            MERGE (a)-[:SCID_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:SCID_Adjective {name: $adjective}), (n:SCID_Noun {name: $noun})
            MERGE (a)-[:SCID_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:SCID_Factor {name: $factor}), (a:SCID_Adjective {name: $adjective})
                MERGE (e:SCID_Embedding {value: $embedding})
                MERGE (f)-[:SCID_HAS_EMBEDDING]->(e)
                MERGE (a)-[:SCID_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create SCID Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create SCID Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the SCID schema
        create_scid_schema(graph, scid_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", scid_df.shape[0])
        mlflow.log_param("Number of Columns", scid_df.shape[1])
        
        # Print the DataFrame
        print(scid_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#                          Factor  \
# 0  Neurodevelopmental Disorders
# 1  Neurodevelopmental Disorders
# 2  Neurodevelopmental Disorders
# 3  Neurodevelopmental Disorders
# 4  Neurodevelopmental Disorders
#
#                                            Adjective               Synonym  \
# 0  Intellectual Disability (Intellectual Developm...  Cognitive Impairment
# 1  Intellectual Disability (Intellectual Developm...    Mental Retardation
# 2  Intellectual Disability (Intellectual Developm...   Developmental Delay
# 3                         Global Developmental Delay   Developmental Delay
# 4                         Global Developmental Delay   Delayed Development
#
#           Verb         Noun                                          Embedding
# 0      Exhibit     Deficits  [0.04625442624092102, 0.02743430621922016, -0....
# 1  Demonstrate  Limitations  [0.06036397069692612, 0.025935035198926926, -0...
# 2   Experience   Impairment  [0.02333744242787361, 0.02177761308848858, -0....
# ...

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:SCID_Factor OR n:SCID_Adjective OR n:SCID_Synonym OR n:SCID_Verb OR n:SCID_Noun)
# AND NOT m:SCID_Embedding
# RETURN n, r, m
# ```
