# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# ## Clifton Strengths <a class="anchor" id="PTMD_page_14.5"></a>
#
# [Back to Top](#PTMD_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %% [markdown]
# ## **Unleashing Human Potential: Clifton Strengths**
#
# In the realm of personal and professional development, the Clifton Strengths model stands as a beacon, illuminating the unique talents and abilities that reside within each individual. Grounded in positive psychology, this framework empowers individuals to discover, nurture, and leverage their innate strengths, fostering personal growth and success.
#
# The Clifton Strengths model, also known as the Clifton StrengthsFinder or StrengthsQuest, was created by Dr. Donald O. Clifton. Dr. Clifton was a psychologist and educator known for his pioneering work in the field of positive psychology. He was a prominent figure in the study of strengths and positive attributes in individuals, organizations, and communities.
#
# The development of the Clifton Strengths model involved extensive research and assessment of human strengths and talents. The result of this work was a psychometric assessment tool designed to identify an individual's top strengths or talents, often referred to as their "signature strengths." This tool aims to help individuals and organizations leverage their strengths for personal and professional development.
#
# Dr. Donald O. Clifton's work on strengths-based psychology has had a significant impact on fields such as psychology, education, leadership, and organizational development. His legacy continues through the use of the Clifton Strengths model, which is widely used in personal and professional development programs, coaching, and organizational settings to help individuals recognize and maximize their unique strengths.
#
# **Journey through the Clifton Strengths Dataset:**
#
# The Clifton Strengths dataset is a treasure trove of human qualities, meticulously organized into four domains:
#
# **1. Executing**:
#    - **Achiever**: Driven, productive, persistent, and energetic individuals are relentless in their pursuit of goals.
#    - **Arranger**: Organized, flexible, adaptive, and efficient individuals excel in orchestrating order amidst complexity.
#    - **Belief**: Values-driven, principled, ethical, and faithful individuals anchor their actions in unwavering principles.
#    - **Consistency**: Fair, equal, unbiased, and predictable individuals ensure fairness and even-handedness in their pursuits.
#    - **Deliberative**: Thoughtful, cautious, meticulous, and analytical individuals approach decisions with careful consideration.
#    - **Discipline**: Structured, controlled, focused, and systematic individuals exhibit unwavering determination in their endeavors.
#    - **Focus**: Concentrated, determined, centered, and selective individuals channel their energy with pinpoint precision.
#    - **Responsibility**: Accountable, reliable, dependable, and obliged individuals embrace their duties with unwavering commitment.
#    - **Restorative**: Problem-solving, fixing, analyzing, and repairing individuals excel at resolving challenges and issues.
#
# **2. Influencing**:
#    - **Activator**: Energetic, proactive, spontaneous, and catalytic individuals drive change and action.
#    - **Command**: Authoritative, decisive, direct, and bold individuals assertively lead and make impactful decisions.
#    - **Communication**: Expressive, articulate, charismatic, and persuasive individuals captivate audiences with their words.
#    - **Competition**: Challenging, ambitious, driven, and comparative individuals thrive in competitive environments.
#    - **Maximizer**: Excellence-oriented, refining, developing, and optimizing individuals elevate performance and outcomes.
#    - **Self-Assurance**: Confident, assured, fearless, and bold individuals exhibit unwavering self-belief.
#    - **Significance**: Important, distinct, noteworthy, and impactful individuals leave a lasting mark on their endeavors.
#    - **Woo**: Charming, social, outgoing, and influential individuals excel in winning others over.
#
# **3. Relationship Building**:
#    - **Adaptability**: Flexible, adjustable, versatile, and easygoing individuals embrace change with grace.
#    - **Connectedness**: Interconnected, unified, relational, and compassionate individuals foster harmonious connections.
#    - **Developer**: Growth-focused, encouraging, supportive, and nurturing individuals nurture others' potential.
#    - **Empathy**: Understanding, compassionate, sensitive, and caring individuals connect deeply with others' emotions.
#    - **Harmony**: Peaceful, agreeable, mediating, and conciliatory individuals cultivate balance and unity.
#    - **Includer**: Inclusive, accepting, welcoming, and open-hearted individuals create a sense of belonging.
#    - **Individualization**: Unique, specialized, personalized, and differentiated individuals celebrate individuality.
#    - **Positivity**: Optimistic, cheerful, enthusiastic, and upbeat individuals infuse optimism into their relationships.
#    - **Relator**: Genuine, authentic, close, and relational individuals build deep, meaningful connections.
#
# **4. Strategic Thinking**:
#    - **Analytical**: Logical, thoughtful, inquisitive, and reasoning individuals dissect problems with precision.
#    - **Context**: Historical, ancestral, background, and past-oriented individuals value historical perspective.
#    - **Futuristic**: Forward-thinking, visionary, imaginative, and anticipatory individuals envision future possibilities.
#    - **Ideation**: Creative, inventive, original, and brainstorming individuals generate innovative ideas.
#    - **Input**: Curious, collecting, gathering, and accumulating individuals possess a thirst for knowledge.
#    - **Intellection**: Reflective, intellectual, contemplative, and thoughtful individuals engage in deep thinking.
#    - **Learner**: Curious, acquiring, absorbing, and educational individuals thrive on continuous learning.
#    - **Strategic**: Planning, intelligent, tactical, and clever individuals excel in devising effective strategies.
#
# This dataset serves as a roadmap for personal and professional growth, allowing individuals, educators, coaches, and organizations to tap into the vast potential of human strengths. By exploring this dataset, one embarks on a transformative journey to uncover, celebrate, and harness the unique talents that define human excellence.
#
# In the world of Clifton Strengths, each individual is a masterpiece waiting to be unveiled, a symphony of strengths waiting to be played. This dataset is an invitation to embark on a voyage of self-discovery and empowerment, unlocking the full spectrum of human potential.
#
# ## Clifton Strengths dataset into a recommender system
#
# Incorporating the Clifton Strengths dataset into a recommender system can enhance its ability to provide personalized recommendations and guidance across various domains, including career development, personal growth, team building, and more. Here's how this dataset can assist in a recommender system:
#
# 1. **Personalized Career Guidance**:
#    - **Job Matching**: For career-related recommender systems, understanding an individual's strengths can help match them with job roles that align with their natural abilities and inclinations.
# 2. **Team Building and Collaboration**:
#    - **Team Composition**: In organizational settings, the recommender system can suggest team compositions based on complementary strengths, leading to more effective and harmonious collaboration.
# 3. **Learning and Development**:
#    - **Training and Courses**: Recommending training programs, courses, or workshops that align with an individual's strengths can enhance their learning experience and skill development.
# 4. **Leadership Development**:
#    - **Leadership Training**: Recommending leadership development programs tailored to an individual's strengths can help nurture effective leaders within an organization.
# 5. **Personal Growth and Well-Being**:
#    - **Personal Development Plans**: Recommending self-help books, wellness activities, or mindfulness practices based on an individual's strengths can aid in personal growth and well-being.
# 6. **Motivation and Productivity**:
#    - **Task Assignment**: Recommending tasks or projects that align with an individual's strengths can boost motivation and productivity.
# 7. **Team Building Workshops**:
#    - **Team Building Activities**: Recommending team building workshops or activities can be based on the strengths of team members to enhance teamwork and cohesion.
# 8. **Conflict Resolution**:
#    - **Conflict Resolution Strategies**: Recommending conflict resolution strategies based on the strengths of individuals involved can lead to more effective conflict resolution.
# 9. **Coaching and Mentoring**:
#    - **Mentor-Mentee Matching**: Recommending mentors or mentees based on strengths can facilitate meaningful mentorship relationships.
# 10. **Performance Reviews**:
#     - **Performance Feedback**: Recommending feedback and performance evaluation strategies that consider an individual's strengths can lead to more constructive reviews.
# 11. **Leadership Roles**:
#     - **Leadership Recommendations**: Recommending leadership roles within an organization based on an individual's strengths can help identify future leaders.
# 12. **Entrepreneurship**:
#     - **Startup Ideas**: Recommending startup ideas that align with an entrepreneur's strengths can increase the chances of business success.
# 13. **Personalized Marketing**:
#     - **Product Recommendations**: In e-commerce, recommending products or services based on an individual's strengths or values can lead to more relevant and appealing offers.
# 14. **Content Recommendations**:
#     - **Content Discovery**: Recommending articles, videos, or other content that resonates with an individual's strengths and interests can enhance user engagement.
# 15. **Networking and Social Interaction**:
#     - **Networking Recommendations**: Recommending networking events or social gatherings where an individual is likely to connect with like-minded individuals based on their strengths.
# 16. **Work-Life Balance**:
#     - **Recommendations for Balance**: Recommending strategies and activities to maintain a healthy work-life balance that aligns with an individual's strengths.
#
# Integrating the Clifton Strengths dataset into a recommender system allows for a more holistic and individualized approach to recommendations. By considering an individual's unique strengths and qualities, the system can provide tailored guidance and suggestions, ultimately leading to more meaningful and impactful experiences in various aspects of life and work.
#
# Creating a timeline and reference table for Clifton Strengths, also known as StrengthsFinder, involves charting the key developments related to this strengths-based psychological assessment tool. Developed by Donald O. Clifton and later expanded by Gallup, Clifton Strengths focuses on identifying and leveraging individual talents and strengths in personal and professional contexts.
# Here's the conversion of your HTML table into markdown format for the "Clifton Strengths Timeline and Reference Table":
#
# ### Clifton Strengths Timeline and Reference Table
#
# | Year  | Milestone                                                      | Contributor(s)                        | Original Work Reference                                   | Key Contributions                                                  | Additional Information                                              |
# |-------|----------------------------------------------------------------|---------------------------------------|----------------------------------------------------------|--------------------------------------------------------------------|----------------------------------------------------------------------|
# | 1998  | Initial release of StrengthsFinder.                            | Donald O. Clifton, Gallup             | Clifton, D. O. (1998). "StrengthsFinder 1.0".             | Introduction of the StrengthsFinder assessment tool to identify individual talents. | Marked a shift in focus from weaknesses to strengths in personal and professional development. |
# | 2001  | Publication of "Now, Discover Your Strengths".                | Marcus Buckingham and Donald O. Clifton| Buckingham, M., & Clifton, D. O. (2001). "Now, Discover Your Strengths". | Popularized the concept of strengths-based development in a wider audience. | Helped individuals and organizations to understand and apply their strengths for better performance and satisfaction. |
# | 2007  | Launch of StrengthsFinder 2.0.                                 | Tom Rath, Gallup                      | Rath, T. (2007). "StrengthsFinder 2.0".                  | Updated version of the assessment with new and revised strengths.   | StrengthsFinder 2.0 became a bestseller and was widely adopted in corporate and educational settings. |
# | 2010s | Integration of Clifton Strengths in organizational development programs. | Various Organizations and Coaches     | Multiple case studies and corporate reports.             | Application of StrengthsFinder in team building, leadership development, and employee engagement. | Highlighted the practical utility of strengths-based approaches in various organizational contexts. |
# | 2020s | Ongoing research and adaptation of the StrengthsFinder framework. | Various Researchers and Practitioners  | Recent academic and professional publications.           | Continued exploration and validation of the strengths-based approach in diverse fields. | Reflects the evolving nature of the strengths-based approach in response to changing workplace and societal needs. |
#
# This table succinctly organizes the milestones related to the development and influence of Clifton Strengths and the StrengthsFinder tool, highlighting the contributions and additional context for each significant development. If there are more details or other modifications needed, feel free to let me know!
#
# This table provides an overview of the key milestones in the development and application of Clifton Strengths (StrengthsFinder). Each row represents a significant event, detailing the year, milestone, contributors, original work references, key contributions, and additional information.
#
# Clifton Strengths has significantly influenced the approach to personal and professional development, emphasizing the importance of focusing on and leveraging individual strengths rather than solely addressing weaknesses. Its widespread adoption in various sectors underscores its impact and relevance in contemporary psychology and organizational development.
#
# | ID | Author | Year | Title | Journal | Volume | Pages | DOI |
# |----|--------|------|-------|---------|--------|-------|-----|
# | 1 | D. O. Clifton, Marcus Buckingham | 2005 | Now, Discover Your Strengths How to Develop Your Talents and Those of the People You Manage | - | - | - | - |
# | 2 | Hadassah Littman-Ovadia, S. Lavy, Maayan Boiman-Meshita | 2017 | When Theory and Research Collide: Examining Correlates of Signature Strengths Use at Work | Journal of Happiness Studies | 18 | 527-548 | [10.1007/S10902-016-9739-8](https://doi.org/10.1007/S10902-016-9739-8) |
# | 3 | M. van Woerkom, K. Mostert, Crizelle Els, A. Bakker, L. D. de Beer, Sebastiaan Rothmann Jr. | 2016 | Strengths use and deficit correction in organizations: development and validation of a questionnaire | European Journal of Work and Organizational Psychology | 25 | 960-975 | [10.1080/1359432X.2016.1193010](https://doi.org/10.1080/1359432X.2016.1193010) |
# | 4 | C. Harzer, W. Ruch | 2012 | When the job is a calling: The role of applying one's signature strengths at work | The Journal of Positive Psychology | 7 | 362-371 | [10.1080/17439760.2012.702784](https://doi.org/10.1080/17439760.2012.702784) |
# | 5 | C. Harzer, W. Ruch | 2013 | The Application of Signature Character Strengths and Positive Experiences at Work | Journal of Happiness Studies | 14 | 965-983 | [10.1007/S10902-012-9364-0](https://doi.org/10.1007/S10902-012-9364-0) |
# | 6 | D. Quinlan, N. Swain, C. Cameron, D. Vella-Brodrick | 2015 | How ‘other people matter’ in a classroom-based strengths intervention: Exploring interpersonal strategies and classroom outcomes | The Journal of Positive Psychology | 10 | 77-89 | [10.1080/17439760.2014.920407](https://doi.org/10.1080/17439760.2014.920407) |
# | 7 | D. Aspy, C. Aspy, G. Russel, M. Wedel | 2000 | Carkhuff's Human Technology: A Verification and Extension of Kelly's (1997) Suggestion to Integrate the Humanistic and Technical Components of Counseling | Journal of Counseling and Development | 78 | 29-37 | [10.1002/J.1556-6676.2000.TB02557.X](https://doi.org/10.1002/J.1556-6676.2000.TB02557.X) |
# | 8 | Carmel Proctor, J. Maltby, P. Linley | 2011 | Strengths Use as a Predictor of Well-Being and Health-Related Quality of Life | Journal of Happiness Studies | 12 | 153-169 | [10.1007/S10902-009-9181-2](https://doi.org/10.1007/S10902-009-9181-2) |
# | 9 | P. Linley, S. Harrington | 2006 | Strengths Coaching: A potential-guided approach to coaching psychology | International Coaching Psychology Review | - | - | [10.53841/bpsicpr.2006.1.1.37](https://doi.org/10.53841/bpsicpr.2006.1.1.37) |
# | 10 | C. Harzer, W. Ruch | 2014 | The Role of Character Strengths for Task Performance, Job Dedication, Interpersonal Facilitation, and Organizational Support | Human Performance | 27 | 183-205 | [10.1080/08959285.2014.913592](https://doi.org/10.1080/08959285.2014.913592) |
# | 11 | S. Rothmann, G. V. D. M. Sieberhagen | 1997 | Die samestelling en evaluering van 'n groepfasiliteringskursus | Sa Journal of Industrial Psychology | 23 | 9-14 | [10.4102/SAJIP.V23I3.632](https://doi.org/10.4102/SAJIP.V23I3.632) |
# | 12 | Reena Govindji, P. Linley | 2007 | Strengths use, self-concordance and well-being: Implications for Strengths Coaching and Coaching Psychologists | International Coaching Psychology Review | - | - | [10.53841/bpsicpr.2007.2.2.143](https://doi.org/10.53841/bpsicpr.2007.2.2.143) |
# | 13 | P. Linley, Linda Woolston, R. Biswas-Diener | 2009 | Strengths coaching with leaders | International Coaching Psychology Review | - | - | [10.53841/bpsicpr.2009.4.1.37](https://doi.org/10.53841/bpsicpr.2009.4.1.37) |
# | 15 | Ernest Baumgarten, Tony Roffers | 2003 | Implementing and Expanding on Carkhuff's Training Technology | Journal of Counseling and Development | 81 | 285-291 | [10.1002/J.1556-6678.2003.TB00255.X](https://doi.org/10.1002/J.1556-6678.2003.TB00255.X) |
# | 16 | Philippe Dubreuil, Jacques Forest, François Courcy | 2014 | From strengths use to work performance: The role of harmonious passion, subjective vitality, and concentration | The Journal of Positive Psychology | 9 | 335-349 | [10.1080/17439760.2014.898318](https://doi.org/10.1080/17439760.2014.898318) |
# | 17 | F. Gander, R. Proyer, W. Ruch, Tobias Wyss | 2013 | Strength-Based Positive Interventions: Further Evidence for Their Potential in Enhancing Well-Being and Alleviating Depression | Journal of Happiness Studies | 14 | 1241-1259 | [10.1007/S10902-012-9380-0](https://doi.org/10.1007/S10902-012-9380-0) |
# | 19 | R. Biswas-Diener | 2009 | Average to A+: realising strengths in yourself and others, by A. Linley | The Journal of Positive Psychology | 4 | 423-425 | [10.1080/17439760902992480](https://doi.org/10.1080/17439760902992480) |
# | 20 | M. Woerkom, M. Meyers | 2015 | My strengths count!: Effects of a strengths-based psychological climate on positive affect and job performance | Human Resource Management | 54 | 81-103 | [10.1002/HRM.21623](https://doi.org/10.1002/HRM.21623) |
# | 21 | Carmel Proctor, Eli Tsukayama, A. Wood, J. Maltby, J. Eades, P. Linley | 2011 | Strengths Gym: The impact of a character strengths-based intervention on the life satisfaction and well-being of adolescents | The Journal of Positive Psychology | 6 | 377-388 | [10.1080/17439760.2011.594079](https://doi.org/10.1080/17439760.2011.594079) |
# | 22 | E. M. Keenan, K. Mostert | 2013 | Perceived organisational support for strengths use: The factorial validity and reliability of a new scale in the banking industry | Sa Journal of Industrial Psychology | 39 | 12 | [10.4102/SAJIP.V39I1.1052](https://doi.org/10.4102/SAJIP.V39I1.1052) |
# | 23 | Hadassah Littman-Ovadia, M. Steger | 2010 | Character strengths and well-being among volunteers and employees: Toward an integrative model | The Journal of Positive Psychology | 5 | 419-430 | [10.1080/17439760.2010.516765](https://doi.org/10.1080/17439760.2010.516765) |
# | 24 | Alex M. Wood, P. A. Linley, J. Maltby, T. Kashdan, R. Hurling | 2011 | Using personal and psychological strengths leads to increases in well-being over time: A longitudinal study and the development of the strengths use questionnaire | Personality and Individual Differences | 50 | 15-19 | [10.1016/J.PAID.2010.08.004](https://doi.org/10.1016/J.PAID.2010.08.004) |
# | 25 | P. Linley, K. Nielsen, A. Wood, R. Gillett, R. Biswas-Diener | 2010 | Using signature strengths in pursuit of goals: Effects on goal progress, need satisfaction, and well-being, and implications for coaching psychologists | International Coaching Psychology Review | - | - | [10.53841/bpsicpr.2010.5.1.6](https://doi.org/10.53841/bpsicpr.2010.5.1.6) |
# | 26 | Richard P Douglass, Ryan D. Duffy | 2015 | Strengths Use and Life Satisfaction: A Moderated Mediation Approach | Journal of Happiness Studies | 16 | 619-632 | [10.1007/S10902-014-9525-4](https://doi.org/10.1007/S10902-014-9525-4) |
# | 27 | Philippe Dubreuil, G. Lavigne, Jacques Forest, Geneviève A. Mageau, Laurence Crevier-Braud, Éliane Bergeron | 2012 | Harmonious passion as an explanation of the relation between signature strengths' use and well-being at work: Test of an intervention program | Human Relations | 65 | 1233-1252 | [10.1177/0018726711433134](https://doi.org/10.1177/0018726711433134) |
# | 28 | I. Brdar, T. Kashdan | 2010 | Character strengths and well-being in Croatia: An empirical investigation of structure and correlates | Journal of Research in Personality | 44 | 151-154 | [10.1016/J.JRP.2009.12.001](https://doi.org/10.1016/J.JRP.2009.12.001) |
#
#
#
#
# Here is the completion of the markdown table for the given .bib citations:
#
# | ID   | Author                                              | Year | Title                                                                                                    | Journal                                                        | Volume | Pages         | DOI                                               |
# |------|-----------------------------------------------------|------|----------------------------------------------------------------------------------------------------------|----------------------------------------------------------------|--------|---------------|---------------------------------------------------|
# | 30   | D. O. Clifton, M. Buckingham                        | 2001 | Now, Discover Your Strengths                                                                             | -                                                              | -      | -             | [Link](https://www.semanticscholar.org/paper/271b0707c6d6948037ec6029e0047bb5543609bb) |
# | 31   | M. van Woerkom, K. Mostert, et al.                  | 2016 | Strengths use and deficit correction in organizations: development and validation of a questionnaire     | European Journal of Work and Organizational Psychology         | 25     | 960 - 975     | [10.1080/1359432X.2016.1193010](https://doi.org/10.1080/1359432X.2016.1193010) |
# | 32   | C. Harzer, W. Ruch                                  | 2013 | The Application of Signature Character Strengths and Positive Experiences at Work                         | Journal of Happiness Studies                                  | 14     | 965-983       | [10.1007/S10902-012-9364-0](https://doi.org/10.1007/S10902-012-9364-0) |
# | 33   | Carmel Proctor, J. Maltby, P. Linley                | 2011 | Strengths Use as a Predictor of Well-Being and Health-Related Quality of Life                            | Journal of Happiness Studies                                  | 12     | 153-169       | [10.1007/S10902-009-9181-2](https://doi.org/10.1007/S10902-009-9181-2) |
# | 34   | F. Gander, R. Proyer, W. Ruch, Tobias Wyss          | 2013 | Strength-Based Positive Interventions: Further Evidence for Their Potential in Enhancing Well-Being and Alleviating Depression | Journal of Happiness Studies                                  | 14     | 1241-1259     | [10.1007/S10902-012-9380-0](https://doi.org/10.1007/S10902-012-9380-0) |
# | 35   | Carmel Proctor, Eli Tsukayama, et al.               | 2011 | Strengths Gym: The impact of a character strengths-based intervention on the life satisfaction and well-being of adolescents | The Journal of Positive Psychology                             | 6      | 377 - 388     | [10.1080/17439760.2011.594079](https://doi.org/10.1080/17439760.2011.594079) |
# | 36   | Wenjie Duan, S. Ho, et al.                          | 2014 | Character Strength-Based Intervention to Promote Satisfaction with Life in the Chinese University Context | Journal of Happiness Studies                                  | 15     | 1347-1361     | [10.1007/S10902-013-9479-Y](https://doi.org/10.1007/S10902-013-9479-Y) |
# | 37   | Philippe Dubreuil, G. Lavigne, et al.               | 2012 | Harmonious passion as an explanation of the relation between signature strengths' use and well-being at work | Human Relations                                                | 65     | 1233 - 1252   | [10.1177/0018726711433134](https://doi.org/10.1177/0018726711433134) |
# | 38   | Richard P Douglass, Ryan D. Duffy                   | 2015 | Strengths Use and Life Satisfaction: A Moderated Mediation Approach                                      | Journal of Happiness Studies                                  | 16     | 619-632       | [10.1007/S10902-014-9525-4](https://doi.org/10.1007/S10902-014-9525-4) |
# | 39   | D. Quinlan, N. Swain, et al.                        | 2010 | Character strengths and well-being among volunteers and employees: Toward an integrative model            | The Journal of Positive Psychology                             | 5      | 419 - 430     | [10.1080/17439760.2010.516765](https://doi.org/10.1080/17439760.2010.516765) |
# | 40   | Alex M. Wood, P. A. Linley, et al.                  | 2011 | Using personal and psychological strengths leads to increases in well-being over time: A longitudinal study and the development of the strengths use questionnaire | Personality and Individual Differences                         | 50     | 15-19         | [10.1016/J.PAID.2010.08.004](https://doi.org/10.1016/J.PAID.2010.08.004) |
# | 41   | W. Ruch, R. Proyer, C. Harzer, et al.                      | 2010 | Values in Action Inventory of Strengths (VIA-IS): Adaptation and Validation of the German Version and the Development of a Peer-Rating Form | Journal of Individual Differences                                    | 31     | 138-149    | [10.1027/1614-0001/A000022](https://doi.org/10.1027/1614-0001/A000022)                             |
# | 42   | C. Harzer, W. Ruch                                         | 2014 | The Role of Character Strengths for Task Performance, Job Dedication, Interpersonal Facilitation, and Organizational Support | Human Performance                                                     | 27     | 183 - 205  | [10.1080/08959285.2014.913592](https://doi.org/10.1080/08959285.2014.913592)                       |
# | 43   | P. Linley, K. Nielsen, et al.                              | 2010 | Using signature strengths in pursuit of goals: Effects on goal progress, need satisfaction, and well-being, and implications for coaching psychologists | International Coaching Psychology Review                              | null   | null       | [10.53841/bpsicpr.2010.5.1.6](https://doi.org/10.53841/bpsicpr.2010.5.1.6)                         |
# | 44   | Jacques Forest, et al.                                     | 2012 | Harmonious passion as an explanation of the relation between signature strengths' use and well-being at work: Test of an intervention program | Human Relations                                                      | 65     | 1233 - 1252 | [10.1177/0018726711433134](https://doi.org/10.1177/0018726711433134)                               |
# | 45   | R. Biswas-Diener, Todd B. Kashdan, et al.                  | null | A Dynamic Approach to Psychological Strength Development and Intervention | The Journal of Positive Psychology                                    | null   | null       | -                                                                                                   |
# | 46   | C. Harzer, W. Ruch                                         | 2012 | When the job is a calling: The role of applying one's signature strengths at work | The Journal of Positive Psychology                                    | 7      | 362 - 371  | [10.1080/17439760.2012.702784](https://doi.org/10.1080/17439760.2012.702784)                       |
# | 47   | C. Botha, K. Mostert                                       | 2014 | A structural model of job resources, organisational and individual strengths use and work engagement | Sa Journal of Industrial Psychology                                  | 40     | 1-11       | [10.4102/SAJIP.V40I1.1135](https://doi.org/10.4102/SAJIP.V40I1.1135)                               |
# | 48   | Reena Govindji, P. Linley                                  | 2007 | Strengths use, self-concordance and well-being: Implications for Strengths Coaching and Coaching Psychologists | International Coaching Psychology Review                              | null   | null       | [10.53841/bpsicpr.2007.2.2.143](https://doi.org/10.53841/bpsicpr.2007.2.2.143)                     |
# | 49   | T. Rust, R. Diessner, Lindsay Reade                        | 2009 | Strengths Only or Strengths and Relative Weaknesses? A Preliminary Study | The Journal of Psychology                                               | 143    | 465 - 476  | [10.3200/JRL.143.5.465-476](https://doi.org/10.3200/JRL.143.5.465-476)                             |
# | 50   | Ryan M. Niemiec                                            | 2013 | VIA Character Strengths: Research and Practice (The First 10 Years) | -                                                                     | null   | null       | [10.1007/978-94-007-4611-4_2](https://doi.org/10.1007/978-94-007-4611-4_2)                         |
# | 51   | I. Brdar, T. Kashdan                                       | 2010 | Character strengths and well-being in Croatia: An empirical investigation of structure and correlates | Journal of Research in Personality                                    | 44     | 151-154    | [10.1016/J.JRP.2009.12.001](https://doi.org/10.1016/J.JRP.2009.12.001)                             |
# | 52   | C. Peterson, W. Ruch, et al.                               | 2007 | Strengths of character, orientations to happiness, and life satisfaction | The Journal of Positive Psychology                                    | 2      | 149 - 156  | [10.1080/17439760701228938](https://doi.org/10.1080/17439760701228938)                             |
# | 53   | L. Roberts, J. Dutton, et al.                              | 2005 | Composing The Reflected Best-Self Portrait: Building Pathways For Becoming Extraordinary In Work Organizations | Academy of Management Review                                          | 30     | 712-736    | [10.5465/AMR.2005.18378874](https://doi.org/10.5465/AMR.2005.18378874)                             |
# | 54   | D. Kong, Violet T. Ho                                      | 2016 | A self-determination perspective of strengths use at work: Examining its determinant and performance implications | The Journal of Positive Psychology                                    | 11     | 15 - 25    | [10.1080/17439760.2015.1004555](https://doi.org/10.1080/17439760.2015.1004555)                     |
# | 55   | Philippe Dubreuil, Jacques Forest, et al.                  | 2014 | From strengths use to work performance: The role of harmonious passion, subjective vitality, and concentration | The Journal of Positive Psychology                                    | 9      | 335 - 349  | [10.1080/17439760.2014.898318](https://doi.org/10.1080/17439760.2014.898318)                       |
# | 56   | M. Buckingham, Curt W. Coffman                             | 1999 | First, Break All the Rules: What the World's Greatest Managers Do Differently | -                                                                     | -      | -          | -                                                                                                   |
# | 57   | J. Asplund                                                 | 2009 | The Clifton StrengthsFinder ® 2.0 Technical Report: Development and Validation | -                                                                     | -      | -          | -                                                                                                   |
# | 58   | D. Quinlan, N. Swain, et al.                               | 2015 | How ‘other people matter’ in a classroom-based strengths intervention: Exploring interpersonal strategies and classroom outcomes | The Journal of Positive Psychology                                    | 10     | 77 - 89    | [10.1080/17439760.2014.920407](https://doi.org/10.1080/17439760.2014.920407)                       |
# | 59   | N. Skelton                                                 | 2019 | Playing to your strengths | An Architect’s Guide to Public Procurement                             | -      | -          | [10.4324/9780429346910-10](https://doi.org/10.4324/9780429346910-10)                               |
# | 60   | A. Wood, Judith Johnson                                    | null | Positive Clinical Psychology An Introduction | -                                                                     | -      | -          | -                                                                                                   |
# | 61   | A. Wood, Judith Johnson                                   | 2016 | Positive Clinical Psychology                                                                                               | -                                                                     | -      | -          | [10.1002/9781118468197.CH1](https://doi.org/10.1002/9781118468197.CH1)                             |
# | 62   | M. Buckingham                                             | 2007 | Go Put Your Strengths To Work: 6 Powerful Steps To Achieve Outstanding Performance                                         | -                                                                     | -      | -          | -                                                                                                   |
# | 63   | M. Woerkom, M. Meyers                                     | 2015 | My strengths count!: Effects of a strengths-based psychological climate on positive affect and job performance              | Human Resource Management                                            | 54     | 81-103     | [10.1002/HRM.21623](https://doi.org/10.1002/HRM.21623)                                             |
# | 64   | Hadassah Littman-Ovadia, M. Steger                        | 2010 | Character strengths and well-being among volunteers and employees: Toward an integrative model                              | The Journal of Positive Psychology                                    | 5      | 419 - 430  | [10.1080/17439760.2010.516765](https://doi.org/10.1080/17439760.2010.516765)                       |
# | 65   | Alex M. Wood, et al.                                      | 2011 | Using personal and psychological strengths leads to increases in well-being over time: A longitudinal study and the development of the strengths use questionnaire                   | Personality and Individual Differences                                | 50     | 15-19      | [10.1016/J.PAID.2010.08.004](https://doi.org/10.1016/J.PAID.2010.08.004)                           |
# | 66   | Philippe Dubreuil, et al.                                 | 2012 | Harmonious passion as an explanation of the relation between signature strengths’ use and well-being at work: Test of an intervention program                                         | Human Relations                                                      | 65     | 1233 - 1252| [10.1177/0018726711433134](https://doi.org/10.1177/0018726711433134)                               |
# | 67   | Richard P Douglass, Ryan D. Duffy                         | 2015 | Strengths Use and Life Satisfaction: A Moderated Mediation Approach                                                       | Journal of Happiness Studies                                          | 16     | 619-632    | [10.1007/S10902-014-9525-4](https://doi.org/10.1007/S10902-014-9525-4)                             |
# | 68   | D. Quinlan, et al.                                        | 2011 | Character Strengths Interventions: Building on What We Know for Improved Outcomes                                          | Journal of Happiness Studies                                          | 13     | 1145 - 1163 | [10.1007/s10902-011-9311-5](https://doi.org/10.1007/s10902-011-9311-5)                             |
# | 69   | A. Bakker, M. van Woerkom                                 | 2017 | Strengths Use in Organizations: A Positive Approach of Occupational Health                                                 | Canadian Psychology/Psychologie canadienne                            | 59     | 38–46       | [10.1037/cap0000120](https://doi.org/10.1037/cap0000120)                                           |
# | 70   | M. van Woerkom, et al.                                    | 2016 | Strengths use and work engagement: a weekly diary study                                                                   | European Journal of Work and Organizational Psychology                | 25     | 384 - 397  | [10.1080/1359432X.2015.1089862](https://doi.org/10.1080/1359432X.2015.1089862)                     |
#
# This list now completes the citations you requested based on the entries provided. If you need any more help or adjustments to these entries, feel free to ask!
#
#
#
# ### Taxonomy
# ```
# - Domain / Factor
#         |__ Adjective
#             |__ Synonym
#             |__ Verb
#             |__ Noun
# ```

# %% [markdown]
# ##  Steps for CLIFTON Personality Modeling Workflow
#
# 1.  **Step 1: Create the Personality Dataset**
#
#     * **Purpose:** This initial step involves defining and generating the dataset that represents the Eysenck Personality Model (CLIFTON).
#     * **Actions:**
#         * Define the CLIFTON dataset structure (e.g., using a dictionary to represent factors, adjectives, synonyms, etc.).
#         * Generate the dataset by organizing the data into a Pandas DataFrame.
#         * Save the dataset to a CSV file.
#         * Log dataset metadata (e.g., number of rows, factors, data schema) and the dataset file itself as an artifact in MLflow.
#     * **Importance:** This step creates the raw data that will be used for embedding generation and model training.
#
# 2.  **Step 2: API Key Handling and Initialization**
#
#     * **Purpose:** This critical step ensures that your OpenAI API key is securely loaded and the OpenAI client is initialized. This sets the foundation for using the OpenAI API in subsequent steps.
#     * **Actions:**
#         * Load the OpenAI API key from a secure location (e.g., a file in the user's home directory).
#         * Validate the API key (e.g., check for existence, emptiness, and potentially a basic API call).
#         * Initialize the OpenAI client (`client`).
#         * Log the API key handling process and its outcome in MLflow.
#     * **Importance:** This step must succeed for the rest of the workflow that utilizes the OpenAI API (like embedding generation) to function. It's essential to handle potential errors (e.g., file not found, invalid key) gracefully.
#
# 3.  **Step 3: Test Embedding API**
#
#     * **Purpose:** This step verifies that the OpenAI Embedding API is accessible and functioning correctly.
#     * **Actions:**
#         * Use the initialized OpenAI client (`client`) to make a test call to the Embedding API (e.g., by embedding a sample text).
#         * Check the API response for validity.
#         * Log the API call details and the outcome (success or failure) in MLflow.
#     * **Importance:** This step ensures that you can successfully generate embeddings before proceeding to the next step.
#
# 4.  **Step 4: Create Embeddings for the Dataset**
#
#     * **Purpose:** This step generates numerical representations (embeddings) for the text data in the CLIFTON dataset using the OpenAI Embedding API.
#     * **Actions:**
#         * Load the CLIFTON dataset (created in Step 2).
#         * Use the OpenAI client (`client`) to generate embeddings for the relevant text fields (e.g., combining factor, adjective, synonym, verb, noun).
#         * Add the generated embeddings as a new column in the Pandas DataFrame.
#         * Save the DataFrame with embeddings to a new CSV file.
#         * Log embedding generation parameters (e.g., embedding model used), statistics (e.g., embedding length), and the embeddings file as an artifact in MLflow.
#     * **Importance:** This step transforms the text data into a numerical format that can be used for machine learning models.
#
# 5.  **Step 5: Create and Visualize a Label Encoder**
#
#     * **Purpose:** This step prepares the categorical labels (personality factors) for model training by encoding them into numerical values and provides a visualization of this encoding.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Initialize a `LabelEncoder` from scikit-learn.
#         * Fit the `LabelEncoder` to the 'Factor' column to create the mapping between personality factors and numerical codes.
#         * Transform the 'Factor' column using the fitted `LabelEncoder` to create a new 'Factor_Encoded' column.
#         * Save the fitted `LabelEncoder` object.
#         * Generate a visualization (e.g., a bar chart) to show the mapping between original factors and encoded values.
#         * Save the visualization as an image file.
#         * Log the label encoder object and the visualization as artifacts in MLflow.
#         * Log the mapping between original factors and encoded values as a dictionary in MLflow.
#     * **Importance:** This step prepares the target variable for model training and provides a clear representation of the encoding.
#
# 6.  **Step 6: Create our CLIFTON Model (Model Training and Evaluation)**
#
#     * **Purpose:** This step trains a machine learning model on the generated embeddings to predict personality factors and evaluates its performance.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Prepare the data for model training:
#             * Extract the embeddings as features (`X`).
#             * Encode the 'Factor' column using the loaded `LabelEncoder` to get the target variable (`y`).
#             * Split the data into training and testing sets.
#         * Initialize a machine learning model (e.g., `RandomForestClassifier`).
#         * Train the model on the training data.
#         * Make predictions on the test data.
#         * Evaluate the model's performance using appropriate metrics (e.g., accuracy, classification report, confusion matrix).
#         * Generate visualizations of the evaluation results (e.g., confusion matrix plot).
#         * Save the trained model.
#         * Log model training parameters (e.g., hyperparameters), evaluation metrics, visualizations, and the trained model as artifacts in MLflow.
#     * **Importance:** This step is the core of the machine learning process, where the model learns to predict personality factors from the embeddings.
#
# 7.  **Step 7: Model Testing (Inference on New Data)**
#
#     * **Purpose:** This step demonstrates how to use the trained model to predict personality factors for new, unseen text inputs.
#     * **Actions:**
#         * Load the trained model (saved in Step 6).
#         * Load the saved `LabelEncoder` (created in Step 5).
#         * Define a function that:
#             * Takes new text as input.
#             * Generates an embedding for the new text using the OpenAI API.
#             * Uses the loaded model to predict the personality factor.
#             * Uses the loaded `LabelEncoder` to decode the numerical prediction back to the original factor name.
#         * Provide example new text inputs.
#         * Use the function to predict personality factors for the example texts.
#         * Print the predictions.
#         * Log the test inputs and predictions in MLflow.
#     * **Importance:** This step demonstrates the practical application of the trained model for making predictions on new data.
#
# 8.  **Step 8: Model Application, Visualization, and Analysis**
#
#     * **Purpose:** This step provides additional visualization and analysis of the data and model.
#     * **Actions:**
#         * Load the dataset with embeddings (created in Step 4).
#         * Apply PCA for dimensionality reduction and visualization of the embeddings.
#         * Generate and log PCA plots to visualize the embedding distribution.
#         * Perform K-Means clustering on the embeddings to identify potential groupings or clusters of similar personality traits.
#         * Add cluster labels to the dataset and save the clustered data.
#         * Log clustering parameters (e.g., number of clusters) and the clustered data as artifacts in MLflow.
#     * **Importance:** This step offers valuable insights into the data and model:
#         * PCA visualization helps understand the distribution of embeddings.
#         * Clustering can reveal underlying patterns in the data.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 1: Create Dataset** <a class="anchor" id="OCEAN_page_1"></a>
#
# Data Preparation and Cleaning: Ensure the dataset is cleaned and preprocessed properly. Handle missing values, duplicates, and outliers.
#
# [Back to Top](#OCEAN_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import pandas as pd
import mlflow

# Set the MLflow tracking URI
mlflow.set_tracking_uri("http://127.0.0.1:5000/")

# Set up CLIFTON experiment
experiment_name = "CLIFTON"
mlflow.set_experiment(experiment_name)

clifton_dataset = {
    'Executing': {
        'Achiever': {
            'Synonyms': ['Ambitious', 'Motivated', 'Determined', 'Productive'],
            'Verbs': ['Strive', 'Motivate', 'Resolve', 'Produce'],
            'Nouns': ['Ambition', 'Motivation', 'Determination', 'Productivity']
        },
        'Arranger': {
            'Synonyms': ['Organized', 'Flexible', 'Adaptive', 'Efficient'],
            'Verbs': ['Arrange', 'Adapt', 'Streamline', 'Optimize'],
            'Nouns': ['Arrangement', 'Adaptability', 'Efficiency', 'Coordination']
        },
        'Belief': {
            'Synonyms': ['Principled', 'Ethical', 'Faithful', 'Values-driven'],
            'Verbs': ['Value', 'Uphold', 'Commit', 'Believe'],
            'Nouns': ['Principle', 'Ethics', 'Faithfulness', 'Values']
        },
        'Consistency': {
            'Synonyms': ['Fair', 'Unbiased', 'Predictable', 'Equitable'],
            'Verbs': ['Equalize', 'Stabilize', 'Regulate', 'Harmonize'],
            'Nouns': ['Fairness', 'Equity', 'Consistency', 'Standardization']
        },
        'Deliberative': {
            'Synonyms': ['Cautious', 'Meticulous', 'Analytical', 'Prudent'],
            'Verbs': ['Deliberate', 'Analyze', 'Reflect', 'Evaluate'],
            'Nouns': ['Cautiousness', 'Meticulousness', 'Analysis', 'Prudence']
        },
        'Discipline': {
            'Synonyms': ['Controlled', 'Organized', 'Focused', 'Systematic'],
            'Verbs': ['Organize', 'Control', 'Focus', 'Systematize'],
            'Nouns': ['Discipline', 'Control', 'Focus', 'System']
        },
        'Focus': {
            'Synonyms': ['Concentrated', 'Determined', 'Centered', 'Selective'],
            'Verbs': ['Concentrate', 'Determine', 'Focus', 'Prioritize'],
            'Nouns': ['Concentration', 'Determination', 'Focus', 'Priority']
        },
        'Responsibility': {
            'Synonyms': ['Accountable', 'Dependable', 'Obliged', 'Reliable'],
            'Verbs': ['Commit', 'Uphold', 'Answer', 'Ensure'],
            'Nouns': ['Responsibility', 'Dependability', 'Obligation', 'Reliability']
        },
        'Restorative': {
            'Synonyms': ['Problem-solving', 'Fixing', 'Analyzing', 'Repairing'],
            'Verbs': ['Restore', 'Repair', 'Solve', 'Reconstruct'],
            'Nouns': ['Restoration', 'Repair', 'Solution', 'Reconstruction']
        }
    },
    'Influencing': {
        'Activator': {
            'Synonyms': ['Energetic', 'Proactive', 'Spontaneous', 'Catalyst'],
            'Verbs': ['Activate', 'Provoke', 'Initiate', 'Stimulate'],
            'Nouns': ['Energy', 'Proactivity', 'Spontaneity', 'Catalysis']
        },
        'Command': {
            'Synonyms': ['Authoritative', 'Decisive', 'Direct', 'Bold'],
            'Verbs': ['Command', 'Decide', 'Direct', 'Assert'],
            'Nouns': ['Authority', 'Decision', 'Directness', 'Boldness']
        },
        'Communication': {
            'Synonyms': ['Expressive', 'Articulate', 'Charismatic', 'Persuasive'],
            'Verbs': ['Communicate', 'Articulate', 'Influence', 'Persuade'],
            'Nouns': ['Expression', 'Articulation', 'Charisma', 'Persuasion']
        },
        'Competition': {
            'Synonyms': ['Competitive', 'Ambitious', 'Driven', 'Comparative'],
            'Verbs': ['Compete', 'Strive', 'Pursue', 'Challenge'],
            'Nouns': ['Competition', 'Ambition', 'Drive', 'Comparison']
        },
        'Maximizer': {
            'Synonyms': ['Optimizing', 'Enhancing', 'Perfecting', 'Elevating'],
            'Verbs': ['Maximize', 'Enhance', 'Perfect', 'Elevate'],
            'Nouns': ['Optimization', 'Enhancement', 'Perfection', 'Elevation']
        },
        'Self-Assurance': {
            'Synonyms': ['Confident', 'Assured', 'Fearless', 'Bold'],
            'Verbs': ['Assure', 'Confide', 'Dare', 'Venture'],
            'Nouns': ['Confidence', 'Assurance', 'Fearlessness', 'Boldness']
        },
        'Significance': {
            'Synonyms': ['Prominent', 'Influential', 'Prestigious', 'Notable'],
            'Verbs': ['Influence', 'Impact', 'Distinguish', 'Promote'],
            'Nouns': ['Prominence', 'Influence', 'Prestige', 'Notability']
        },
        'Woo': {
            'Synonyms': ['Charming', 'Sociable', 'Outgoing', 'Influential'],
            'Verbs': ['Charm', 'Socialize', 'Engage', 'Influence'],
            'Nouns': ['Charm', 'Sociability', 'Outgoingness', 'Influence']
        }
    },
    'Relationship Building': {
        'Adaptability': {
            'Synonyms': ['Flexible', 'Adjustable', 'Versatile', 'Accommodating'],
            'Verbs': ['Adapt', 'Adjust', 'Modify', 'Accommodate'],
            'Nouns': ['Adaptability', 'Flexibility', 'Versatility', 'Accommodation']
        },
        'Connectedness': {
            'Synonyms': ['Interconnected', 'Unified', 'Relational', 'Compassionate'],
            'Verbs': ['Connect', 'Unify', 'Relate', 'Empathize'],
            'Nouns': ['Connectedness', 'Unity', 'Relationship', 'Compassion']
        },
        'Developer': {
            'Synonyms': ['Encouraging', 'Supportive', 'Nurturing', 'Motivating'],
            'Verbs': ['Develop', 'Support', 'Nurture', 'Encourage'],
            'Nouns': ['Development', 'Support', 'Nurturing', 'Encouragement']
        },
        'Empathy': {
            'Synonyms': ['Understanding', 'Compassionate', 'Sensitive', 'Caring'],
            'Verbs': ['Empathize', 'Understand', 'Comfort', 'Care'],
            'Nouns': ['Empathy', 'Understanding', 'Sensitivity', 'Care']
        },
        'Harmony': {
            'Synonyms': ['Peaceful', 'Mediating', 'Balancing', 'Agreeable'],
            'Verbs': ['Harmonize', 'Mediate', 'Balance', 'Agree'],
            'Nouns': ['Harmony', 'Mediation', 'Balance', 'Agreement']
        },
        'Includer': {
            'Synonyms': ['Inclusive', 'Welcoming', 'Accepting', 'Open'],
            'Verbs': ['Include', 'Welcome', 'Accept', 'Embrace'],
            'Nouns': ['Inclusion', 'Welcoming', 'Acceptance', 'Openness']
        },
        'Individualization': {
            'Synonyms': ['Unique', 'Personalized', 'Customized', 'Tailored'],
            'Verbs': ['Individualize', 'Personalize', 'Customize', 'Tailor'],
            'Nouns': ['Individuality', 'Personalization', 'Customization', 'Tailoring']
        },
        'Positivity': {
            'Synonyms': ['Optimistic', 'Cheerful', 'Uplifting', 'Energetic'],
            'Verbs': ['Energize', 'Cheer', 'Motivate', 'Uplift'],
            'Nouns': ['Optimism', 'Cheerfulness', 'Uplift', 'Energy']
        },
        'Relator': {
            'Synonyms': ['Genuine', 'Trustworthy', 'Loyal', 'Close'],
            'Verbs': ['Relate', 'Connect', 'Bond', 'Trust'],
            'Nouns': ['Relatability', 'Trustworthiness', 'Loyalty', 'Closeness']
        }
    },
    'Strategic Thinking': {
        'Analytical': {
            'Synonyms': ['Logical', 'Reasoning', 'Inquisitive', 'Rational'],
            'Verbs': ['Analyze', 'Reason', 'Investigate', 'Assess'],
            'Nouns': ['Analysis', 'Reasoning', 'Inquisitiveness', 'Rationality']
        },
        'Context': {
            'Synonyms': ['Historical', 'Cultural', 'Foundational', 'Ancestral'],
            'Verbs': ['Contextualize', 'Refer', 'Relate', 'Analyze'],
            'Nouns': ['Context', 'Culture', 'Foundation', 'Ancestry']
        },
        'Futuristic': {
            'Synonyms': ['Visionary', 'Progressive', 'Pioneering', 'Innovative'],
            'Verbs': ['Forecast', 'Envision', 'Innovate', 'Pioneer'],
            'Nouns': ['Futurism', 'Progressiveness', 'Pioneering', 'Innovation']
        },
        'Ideation': {
            'Synonyms': ['Creative', 'Inventive', 'Original', 'Innovative'],
            'Verbs': ['Ideate', 'Create', 'Invent', 'Innovate'],
            'Nouns': ['Ideation', 'Creativity', 'Invention', 'Innovation']
        },
        'Input': {
            'Synonyms': ['Curious', 'Collective', 'Resourceful', 'Inquisitive'],
            'Verbs': ['Collect', 'Gather', 'Amass', 'Research'],
            'Nouns': ['Collection', 'Gathering', 'Resourcefulness', 'Curiosity']
        },
        'Intellection': {
            'Synonyms': ['Thoughtful', 'Philosophical', 'Reflective', 'Contemplative'],
            'Verbs': ['Reflect', 'Philosophize', 'Ponder', 'Consider'],
            'Nouns': ['Reflection', 'Philosophy', 'Contemplation', 'Intellection']
        },
        'Learner': {
            'Synonyms': ['Studious', 'Educational', 'Inquisitive', 'Knowledgeable'],
            'Verbs': ['Learn', 'Study', 'Explore', 'Absorb'],
            'Nouns': ['Learning', 'Education', 'Exploration', 'Knowledge']
        },
        'Strategic': {
            'Synonyms': ['Tactical', 'Planned', 'Methodical', 'Calculated'],
            'Verbs': ['Strategize', 'Plan', 'Scheme', 'Design'],
            'Nouns': ['Strategy', 'Planning', 'Methodology', 'Calculation']
        }
    }
}
#Create a list to store the dataset
data = []
for factor, attributes in clifton_dataset.items():
    for adjective, details in attributes.items():
        synonyms = details['Synonyms']
        verbs = details['Verbs']
        nouns = details['Nouns']
        # Iterate through each corresponding synonym, verb, and noun
        for synonym, verb, noun in zip(synonyms, verbs, nouns):
            data.append((factor, adjective, synonym, verb, noun))

# Create a DataFrame from the data list
clifton_df = pd.DataFrame(data, columns=['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun'])

# Define the dataset path
dataset_path = "../Datasets/cs.csv"

# Start an MLflow run for dataset creation
with mlflow.start_run(run_name="CLIFTON Dataset Creation"):
    # Log dataset metadata
    mlflow.log_param("Experiment", "CLIFTON")
    mlflow.log_param("Total Rows", len(clifton_df))
    mlflow.log_param("Total Factors", len(clifton_dataset))
    mlflow.log_param("Data Schema", str(clifton_df.columns.tolist()))
    
    # Save dataset to CSV
    clifton_df.to_csv(dataset_path, index=False)
    mlflow.log_artifact(dataset_path, artifact_path="data")  # Logs the dataset to MLflow

    # Evaluation: Basic dataset inspection
    print(f"✅ CLIFTON dataset created and saved to {dataset_path}")
    print("First 5 rows of the dataset:")
    print(clifton_df.head())
    print("\nDataset shape:", clifton_df.shape)
    print("\nNumber of unique Factors:", clifton_df['Factor'].nunique())
    print("Unique Factors:", clifton_df['Factor'].unique())

    # Confirm MLflow tracking
    experiment = mlflow.get_experiment_by_name(experiment_name)
    if experiment:
        print(f"📌 MLflow tracking active under experiment '{experiment_name}' (ID: {experiment.experiment_id})")
    else:
        print("❌ Failed to track experiment in MLflow.")
# Out:
# ✅ CLIFTON dataset created and saved to ../Datasets/cs.csv
# First 5 rows of the dataset:
#       Factor Adjective     Synonym      Verb           Noun
# 0  Executing  Achiever   Ambitious    Strive       Ambition
# 1  Executing  Achiever   Motivated  Motivate     Motivation
# 2  Executing  Achiever  Determined   Resolve  Determination
# 3  Executing  Achiever  Productive   Produce   Productivity
# 4  Executing  Arranger   Organized   Arrange    Arrangement
#
# Dataset shape: (136, 5)
#
# Number of unique Factors: 4
# Unique Factors: ['Executing' 'Influencing' 'Relationship Building' 'Strategic Thinking']
# 📌 MLflow tracking active under experiment 'CLIFTON' (ID: 24)
# 🏃 View run CLIFTON Dataset Creation at: http://127.0.0.1:5000/#/experiments/24/runs/d8a35c41ec2c41de9bbe6ace4ff6bcc1
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 2: API key setup** <a class="anchor" id="clifton_page_2"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import openai
import os
import mlflow

# Start an MLFlow run for API key setup
with mlflow.start_run(run_name="API Key Handling and Initialization") as run:
    try:
        # Log the environment setup process
        mlflow.log_param("Step", "API Key Handling and Initialization")

        # Define the path to your API key file
        api_key_file_path = os.path.expanduser('~/openai_api_key.txt')
        mlflow.log_param("API Key File Path", api_key_file_path)

        # Evaluation: Check if the API key file exists
        if not os.path.exists(api_key_file_path):
            error_message = f"API key file not found at: {api_key_file_path}. Please ensure the file exists."
            mlflow.log_param("API Key Status", "Error: File not found")
            mlflow.log_param("Error", error_message)
            raise FileNotFoundError(error_message)
        else:
            mlflow.log_param("API Key File Existence", "Confirmed")
            print(f"✅ API key file found at: {api_key_file_path}")

        # Read the API key from the file
        with open(api_key_file_path, 'r') as file:
            api_key = file.read().strip()

        # Evaluation: Check if the read API key is empty
        if not api_key:
            error_message = f"API key file at: {api_key_file_path} is empty. Please ensure your API key is in the file."
            mlflow.log_param("API Key Status", "Error: Empty file")
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("API Key Status", "Read successfully")
            mlflow.log_param("API Key Length", len(api_key)) # Log the length as a basic sanity check
            print("🔑 API key read successfully.")

        # Set up your OpenAI API key
        openai.api_key = api_key
        client = openai.OpenAI(api_key=api_key)
        mlflow.log_param("OpenAI API Client", "Initialized successfully")
        print("🤖 OpenAI API client initialized.")

        # Evaluation: Attempt a basic API call to verify the key (optional, but recommended for immediate feedback)
        try:
            response = client.models.list()  # Removed the 'limit' argument
            mlflow.log_param("API Key Verification", "Successful (models list)")
            print("✅ OpenAI API key verified successfully with a basic API call.")
        except openai.AuthenticationError as auth_error:
            mlflow.log_param("API Key Verification", "Failed (AuthenticationError)")
            mlflow.log_param("Error", str(auth_error))
            raise openai.AuthenticationError(f"OpenAI API key authentication failed: {auth_error}")
        except openai.OpenAIError as general_error:
            mlflow.log_param("API Key Verification", "Failed (OpenAIError)")
            mlflow.log_param("Error", str(general_error))
            print(f"⚠️ Warning: OpenAI API client initialized, but a test call failed with: {general_error}. Further API calls might fail.")
            mlflow.log_param("API Key Verification Warning", str(general_error))

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        print(f"❌ Error: {e}")
        raise
    except openai.AuthenticationError as e:
        mlflow.log_param("Error Type", "AuthenticationError")
        print(f"❌ Error: {e}")
        raise
    except openai.OpenAIError as e:
        mlflow.log_param("Error Type", "OpenAIError")
        print(f"⚠️ Warning during API initialization: {e}")
        raise
    except Exception as e:
        # Log the error if any other unexpected issue occurs
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
# ✅ API key file found at: /Users/jsr/openai_api_key.txt
# 🔑 API key read successfully.
# 🤖 OpenAI API client initialized.
# ✅ OpenAI API key verified successfully with a basic API call.
# 🏃 View run API Key Handling and Initialization at: http://127.0.0.1:5000/#/experiments/24/runs/d13b797b9d694faaa24caf4aae5a77c0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 3: Test Embedding** <a class="anchor" id="clifton_page_2"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
import openai
import mlflow

# Function to test the OpenAI Embedding API
def test_openai_embedding_api():
    with mlflow.start_run(run_name="Test Embedding API") as run:
        try:
            # Log the step name
            mlflow.log_param("Step", "Test Embedding API")

            # Evaluation: Check if the OpenAI client is initialized
            if 'client' not in globals() or not isinstance(client, openai.OpenAI):
                error_message = "OpenAI client is not initialized. Ensure the API key setup step was executed successfully."
                mlflow.log_param("API Client Status", "Not Initialized")
                mlflow.log_param("Error", error_message)
                raise RuntimeError(error_message)
            else:
                mlflow.log_param("API Client Status", "Initialized")
                print("✅ OpenAI client found and ready.")

            # Example text to embed
            text = "The quick brown fox jumps over the lazy dog."
            mlflow.log_param("Test Text", text)
            print(f"📝 Testing embedding for text: '{text}'")

            # Evaluation: Check if the specified embedding model is available (optional, but good practice)
            embedding_model = "text-embedding-3-small"
            mlflow.log_param("Embedding Model", embedding_model)
            try:
                model_info = client.models.retrieve(embedding_model)
                mlflow.log_param("Embedding Model Availability", "Confirmed")
                print(f"✅ Embedding model '{embedding_model}' is available.")
            except openai.NotFoundError:
                error_message = f"Embedding model '{embedding_model}' not found. Please check the model name."
                mlflow.log_param("Embedding Model Availability", "Not Found")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            except Exception as e:
                error_message = f"Error checking embedding model availability: {e}"
                mlflow.log_param("Embedding Model Availability Check Error", str(e))
                mlflow.log_param("Error", error_message)
                print(f"⚠️ Warning: Error checking model availability: {e}. Proceeding with embedding request.")

            # Request to generate embeddings
            response = client.embeddings.create(
                input=[text],  # The input should be a list of strings
                model=embedding_model
            )

            # Evaluation: Check if the embedding response contains data
            if not response.data:
                error_message = "Embedding API response does not contain any data."
                mlflow.log_param("Embedding API Response Status", "No Data")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding API Response Status", "Data Received")

            # Extract the embedding
            embedding = response.data[0].embedding

            # Evaluation: Check if the extracted embedding is not empty
            if not embedding:
                error_message = "Extracted embedding is empty."
                mlflow.log_param("Embedding Extraction Status", "Empty Embedding")
                mlflow.log_param("Error", error_message)
                raise ValueError(error_message)
            else:
                mlflow.log_param("Embedding Extraction Status", "Success")

            # Log the embedding length and a snippet
            embedding_length = len(embedding)
            mlflow.log_param("Embedding Length", embedding_length)
            mlflow.log_param("Embedding Snippet", embedding[:10])

            # Print the embedding length and a snippet
            print(f"Embedding length: {embedding_length}")
            print(f"Embedding snippet: {embedding[:10]}")  # Print the first 10 elements of the embedding

            print("✅ Embedding API test successful.")

        except RuntimeError as e:
            mlflow.log_param("Error Type", "RuntimeError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except ValueError as e:
            mlflow.log_param("Error Type", "ValueError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.NotFoundError as e:
            mlflow.log_param("Error Type", "NotFoundError")
            mlflow.log_param("Error", str(e))
            print(f"❌ Error: {e}")
            raise
        except openai.OpenAIError as e:
            mlflow.log_param("Error Type", "OpenAIError")
            mlflow.log_param("Error", str(e))
            print(f"❌ OpenAI API error: {e}")
            raise
        except Exception as e:
            # Log the error if any other unexpected issue occurs
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", str(e))
            print(f"❌ An unexpected error occurred: {e}")
            raise

        finally:
            # End the MLFlow run
            mlflow.end_run()

# Test the OpenAI Embedding API
test_openai_embedding_api()
# Out:
# ✅ OpenAI client found and ready.
# 📝 Testing embedding for text: 'The quick brown fox jumps over the lazy dog.'
# ✅ Embedding model 'text-embedding-3-small' is available.
# Embedding length: 1536
# Embedding snippet: [-0.018421143293380737, -0.007218753919005394, 0.003606205340474844, -0.05419774353504181, -0.022721948102116585, 0.036969155073165894, 0.02902725711464882, 0.023901814594864845, 0.011240449734032154, -0.020641323179006577]
# ✅ Embedding API test successful.
# 🏃 View run Test Embedding API at: http://127.0.0.1:5000/#/experiments/24/runs/a9f41781fda64683868f3bf2afeb0458
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 4: Create CLIFTON Embeddings** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import numpy as np
import pandas as pd
from datetime import datetime
from openai import OpenAI
import os
import mlflow
from dotenv import load_dotenv
import joblib

load_dotenv(override=True)

# Function to get the OpenAI API key from the saved file
def get_openai_api_key_from_file(filepath='~/openai_api_key.txt'):
    filepath = os.path.expanduser(filepath)
    try:
        with open(filepath, 'r') as f:
            api_key = f.read().strip()
        if not api_key:
            raise ValueError(f"API key file at '{filepath}' is empty.")
        return api_key
    except FileNotFoundError:
        raise FileNotFoundError(f"API key file not found at '{filepath}'.")
    except Exception as e:
        raise RuntimeError(f"Error reading API key from file '{filepath}': {e}")

# Initialize OpenAI client using the function
try:
    openai_api_key = get_openai_api_key_from_file()
    client = OpenAI(api_key=openai_api_key)
    print("✅ OpenAI client initialized using API key from file.")
except (FileNotFoundError, ValueError, RuntimeError) as e:
    print(f"❌ Error initializing OpenAI client: {e}")
    # It's crucial to handle this error, perhaps by exiting or using a default behavior
    exit()

# Load the previously saved rft dataset from a CSV file
dataset_path = '../Datasets/rft.csv'
try:
    clifton_df = pd.read_csv(dataset_path)
    print(f"✅ Dataset loaded successfully from: {dataset_path}")
except FileNotFoundError:
    error_message = f"Error: Dataset not found at: {dataset_path}. Ensure the previous step (dataset creation) was successful."
    print(f"❌ {error_message}")
    raise FileNotFoundError(error_message)

# Function to generate embeddings using the latest OpenAI API
def get_embedding(text, model="text-embedding-3-small"):
    try:
        response = client.embeddings.create(
            input=[text],  # The input should be a list of strings
            model=model
        )
        embedding = response.data[0].embedding
        return embedding
    except openai.APIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise
    except Exception as e:
        print(f"❌ An unexpected error occurred during embedding generation: {e}")
        raise

with mlflow.start_run(run_name="Generate Embeddings") as run:
    try:
        mlflow.log_param("Step", "Generate Embeddings")
        mlflow.log_param("Model", "text-embedding-3-small")
        mlflow.log_param("Dataset", dataset_path)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Embedding generation started at: {start_time}")

        # Evaluation: Check if the 'clifton_df' is empty before processing
        if clifton_df.empty:
            error_message = "Error: Loaded dataset is empty. Check the dataset file."
            mlflow.log_param("Error", error_message)
            raise ValueError(error_message)
        else:
            mlflow.log_param("Dataset Row Count", clifton_df.shape[0])
            print(f"📊 Processing {clifton_df.shape[0]} rows for embedding generation.")

        # Embedding Generation
        clifton_df['Embedding'] = clifton_df.apply(
            lambda row: get_embedding(f"{row['Factor']} {row['Adjective']} {row['Synonym']} {row['Verb']} {row['Noun']}"),
            axis=1
        )

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Embedding generation finished at: {end_time} (Duration: {end_time - start_time})")

        # Save the embeddings to a new CSV file
        embeddings_csv_path = '../Embeddings/clifton_embeddings.csv'
        clifton_df[['Factor', 'Adjective', 'Synonym', 'Verb', 'Noun', 'Embedding']].to_csv(embeddings_csv_path, index=False)
        mlflow.log_artifact(embeddings_csv_path, artifact_path="embeddings")
        mlflow.log_param("Embeddings CSV Path", embeddings_csv_path)
        print(f"💾 Embeddings saved to: {embeddings_csv_path}")

        # Log statistical information
        num_rows = clifton_df.shape[0]
        num_columns = clifton_df.shape[1]
        # Evaluation: Check if the 'Embedding' column was successfully created and has at least one embedding
        if 'Embedding' in clifton_df.columns and not clifton_df['Embedding'].empty:
            embedding_length = len(clifton_df['Embedding'].iloc[0])
            mlflow.log_param("Embedding Length", embedding_length)
            print(f"📏 Length of the first embedding: {embedding_length}")
        else:
            mlflow.log_param("Embedding Length", "N/A (Embedding column missing or empty)")
            print("⚠️ Warning: Embedding column is missing or empty. Check for errors during embedding generation.")

        mlflow.log_param("Number of Rows", num_rows)
        mlflow.log_param("Number of Columns", num_columns)

        # Evaluation: Print the first few rows with the new 'Embedding' column
        print("\nFirst 5 rows with embeddings:")
        print(clifton_df.head())

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except ValueError as e:
        mlflow.log_param("Error Type", "ValueError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except openai.APIError as e:
        mlflow.log_param("Error Type", "OpenAI APIError")
        mlflow.log_param("Error", str(e))
        print(f"❌ OpenAI API error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An unexpected error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ OpenAI client initialized using API key from file.
# ✅ Dataset loaded successfully from: ../Datasets/rft.csv
# ⏳ Embedding generation started at: 2025-03-17 18:01:48.441041
# 📊 Processing 136 rows for embedding generation.
# ✅ Embedding generation finished at: 2025-03-17 18:02:37.070777 (Duration: 0:00:48.629736)
# 💾 Embeddings saved to: ../Embeddings/clifton_embeddings.csv
# 📏 Length of the first embedding: 1536
#
# First 5 rows with embeddings:
#       Factor Adjective     Synonym      Verb           Noun  \
# 0  Executing  Achiever   Ambitious    Strive       Ambition
# 1  Executing  Achiever   Motivated  Motivate     Motivation
# 2  Executing  Achiever  Determined   Resolve  Determination
# 3  Executing  Achiever  Productive   Produce   Productivity
# 4  Executing  Arranger   Organized   Arrange    Arrangement
#
#                                            Embedding
# 0  [0.04571199417114258, -0.00386609835550189, 0....
# 1  [0.0439743846654892, -0.005997475236654282, -0...
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 5: Create Label Embeddings** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import joblib
import mlflow
import matplotlib.pyplot as plt
import seaborn as sns
import os  # Import the os module

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/clifton_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the previous embedding generation step was successful.")
    exit()

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Fit the encoder to the 'Factor' column and transform it
df['Factor_Encoded'] = label_encoder.fit_transform(df['Factor'])

# Save the fitted LabelEncoder
label_encoder_path = "../Models/clifton_label_encoder.pkl"
joblib.dump(label_encoder, label_encoder_path)
print(f"💾 Label encoder saved to: {label_encoder_path}")

# Define the visualization function here (no import needed)
def visualize_label_encoder(label_encoder, artifact_path="visualization"):
    """
    Visualizes the label encoder mapping using a bar chart.

    Args:
        label_encoder: The fitted LabelEncoder object.
        artifact_path: Path within MLflow to save the visualization.
    """
    try:
        # mlflow.log_param("Step", "Visualize Label Encoder")  # REMOVE THIS LINE

        classes = label_encoder.classes_
        encoded_values = label_encoder.transform(classes)

        plt.figure(figsize=(10, 6))
        sns.barplot(x=classes, y=encoded_values)
        plt.xlabel("Original Factor")
        plt.ylabel("Encoded Value")
        plt.title("Label Encoder Mapping")
        plt.xticks(rotation=45, ha="right")  # Rotate x-axis labels

        # Save and log the plot with the desired filename
        label_encoder_plot_path = "clifton_label_encoder_mapping.png"
        plt.savefig(label_encoder_plot_path)
        print(f"✅ Label encoder visualization saved to: {os.path.abspath(label_encoder_plot_path)}")
        mlflow.log_artifact(
            label_encoder_plot_path, artifact_path=artifact_path
        )
        plt.close()

        print(f"✅ Label encoder visualization saved to: {label_encoder_plot_path}")

    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param(
            "Error", f"An error occurred during Label Encoder visualization: {e}"
        )
        print(f"❌ An error occurred during Label Encoder visualization: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Create and Visualize Label Encoder") as run:
    mlflow.log_param("Step", "Create and Visualize Label Encoder")  # Log the overall step
    mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")

    # Evaluation: Inspect the encoded labels
    print("\nFirst 5 rows with encoded labels:")
    print(df[['Factor', 'Factor_Encoded']].head())
    print("\nMapping of original labels to encoded labels:")
    for original, encoded in zip(label_encoder.classes_, range(len(label_encoder.classes_))):
        print(f"{original}: {encoded}")

    # Log the class mapping as a dictionary
    label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
    mlflow.log_dict(label_mapping, "label_encoder/mapping.json")

    # Visualize the label encoder
    visualize_label_encoder(label_encoder)

print("\n✅ Label encoding completed and encoder saved.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/clifton_embeddings.csv
# 💾 Label encoder saved to: ../Models/clifton_label_encoder.pkl
#
# First 5 rows with encoded labels:
#       Factor  Factor_Encoded
# 0  Executing               0
# 1  Executing               0
# 2  Executing               0
# 3  Executing               0
# 4  Executing               0
#
# Mapping of original labels to encoded labels:
# Executing: 0
# Influencing: 1
# Relationship Building: 2
# Strategic Thinking: 3
# ✅ Label encoder visualization saved to: /Users/jsr/Documents/GitHub/Personality-Trait-Models/Notebooks/clifton_label_encoder_mapping.png
# ✅ Label encoder visualization saved to: clifton_label_encoder_mapping.png
# 🏃 View run Create and Visualize Label Encoder at: http://127.0.0.1:5000/#/experiments/24/runs/1d96b4624a494840a70f4bbc3a94f30c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24
#
# ✅ Label encoding completed and encoder saved.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 6: Create Model** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import joblib
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Load the dataset with embeddings
embeddings_csv_path = '../Embeddings/clifton_embeddings.csv'
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
label_encoder_path = "../Models/clifton_label_encoder.pkl"
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLFlow run
with mlflow.start_run(run_name="rft Model Training and Evaluation Workflow") as run:
    try:
        mlflow.log_param("Step", "Detailed Model Training and Evaluation Workflow")
        mlflow.log_param("Model Type", "RandomForestClassifier")
        mlflow.log_param("Dataset", embeddings_csv_path)
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_param("Test Size", 0.2)
        mlflow.log_param("Random State", 42)
        mlflow.log_param("Stratify", True)

        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))
        print(f"⏳ Model training started at: {start_time}")

        # Train a RandomForestClassifier on the training data
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X_train, y_train)

        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))
        print(f"✅ Model training finished at: {end_time} (Duration: {end_time - start_time})")

        # Make predictions on the test set
        y_pred = clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)

        # Log classification report and confusion matrix as artifacts
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "clifton_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="metrics")
        print(f"📊 Classification report saved to: {class_report_path}")

        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "clifton_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="metrics")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        conf_matrix_img_path = "clifton_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="metrics")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

        # Save the model
        model_path = "../Models/clifton_rf_model.pkl"
        joblib.dump(clf, model_path)
        mlflow.log_artifact(model_path, artifact_path="models")
        print(f"💾 Trained model saved to: {model_path}")

        # Log additional parameters
        mlflow.log_param("Train Set Size", X_train.shape[0])
        mlflow.log_param("Test Set Size", X_test.shape[0])
        mlflow.log_param("Number of Features", X_train.shape[1])

        print(f"✅ Model training complete. Accuracy: {accuracy}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))
        print("\nConfusion Matrix:\n", conf_matrix_df)

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred: {e}")
        raise

    finally:
        # End MLFlow run
        mlflow.end_run()
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/clifton_embeddings.csv
# ✅ Label encoder loaded from: ../Models/clifton_label_encoder.pkl
# ⏳ Model training started at: 2025-03-17 18:02:39.499284
# ✅ Model training finished at: 2025-03-17 18:02:39.720388 (Duration: 0:00:00.221104)
# 📊 Classification report saved to: clifton_classification_report.csv
# 📊 Confusion matrix saved to: clifton_confusion_matrix.csv
# 🖼️ Confusion matrix plot saved to: clifton_confusion_matrix.png
# 💾 Trained model saved to: ../Models/clifton_rf_model.pkl
# ✅ Model training complete. Accuracy: 1.0
#
# Classification Report:
#                         precision    recall  f1-score   support
#
#             Executing       1.00      1.00      1.00         7
#           Influencing       1.00      1.00      1.00         7
# Relationship Building       1.00      1.00      1.00         7
#    Strategic Thinking       1.00      1.00      1.00         7
#
# ...

# %% [markdown]
# This block of code is a comprehensive step-by-step process focusing specifically on:
# 1. **Data Loading and Preprocessing**: Parsing and preparing embeddings from a CSV file for machine learning.
# 2. **Model Training**: Using a RandomForestClassifier to train on the embeddings.
# 3. **Model Evaluation**: Calculating and logging metrics such as accuracy, alongside detailed classification reports and confusion matrices.
# 4. **Visualization and Logging**: Visualizing the confusion matrix and logging both the visual representation and numerical data as artifacts in MLflow.
# 5. **Model Persistence**: Saving the trained model for future use or deployment.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 7: Evaluate Model** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Define paths
embeddings_csv_path = '../Embeddings/clifton_embeddings.csv'
label_encoder_path = "../Models/clifton_label_encoder.pkl"
model_path = "../Models/clifton_rf_model.pkl"

# Load the dataset with embeddings
try:
    df = pd.read_csv(embeddings_csv_path)
    print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
except FileNotFoundError:
    print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}. Ensure the embedding generation step was successful.")
    exit()

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.array(eval(embedding_str))

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Load the pre-fitted label encoder
try:
    label_encoder = joblib.load(label_encoder_path)
    print(f"✅ Label encoder loaded from: {label_encoder_path}")
except FileNotFoundError:
    print(f"❌ Error: Label encoder not found at: {label_encoder_path}. Ensure the label encoding step was successful.")
    exit()

# Load the trained model
try:
    loaded_clf = joblib.load(model_path)
    print(f"✅ Trained model loaded from: {model_path}")
except FileNotFoundError:
    print(f"❌ Error: Trained model not found at: {model_path}. Ensure the model training step was successful.")
    exit()

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values

# Encode the categorical labels using the loaded label encoder
y_encoded = label_encoder.transform(y)

# Split the data into training and testing sets (using the same random state for consistency)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

# Start MLflow run
with mlflow.start_run(run_name="Evaluate CLIFTON Model") as run:
    try:
        mlflow.log_param("Step", "Evaluate CLIFTON Model")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")
        mlflow.log_param("Test Set Size", X_test.shape[0])

        print("\n--- Evaluating Model on Test Set ---")

        # Make predictions on the test set using the loaded model
        y_pred = loaded_clf.predict(X_test)

        # Evaluate the model
        accuracy = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, target_names=label_encoder.classes_, output_dict=True)
        conf_matrix = confusion_matrix(y_test, y_pred)

        mlflow.log_metric("Accuracy", accuracy)
        print(f"✅ Test Accuracy: {accuracy:.4f}")

        # Log classification report as an artifact
        class_report_df = pd.DataFrame(class_report).transpose()
        class_report_path = "clifton_evaluation_classification_report.csv"
        class_report_df.to_csv(class_report_path, index=True)
        mlflow.log_artifact(class_report_path, artifact_path="evaluation")
        print(f"📊 Classification report saved to: {class_report_path}")
        print("\nClassification Report:\n", classification_report(y_test, y_pred, target_names=label_encoder.classes_))

        # Log confusion matrix as an artifact
        conf_matrix_df = pd.DataFrame(conf_matrix, index=label_encoder.classes_, columns=label_encoder.classes_)
        conf_matrix_path = "clifton_evaluation_confusion_matrix.csv"
        conf_matrix_df.to_csv(conf_matrix_path, index=True)
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")
        print(f"📊 Confusion matrix saved to: {conf_matrix_path}")
        print("\nConfusion Matrix:\n", conf_matrix_df)

        # Visualize and log confusion matrix
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='Blues',
                    xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix (Test Set)')
        conf_matrix_img_path = "clifton_evaluation_confusion_matrix.png"
        plt.savefig(conf_matrix_img_path)
        mlflow.log_artifact(conf_matrix_img_path, artifact_path="evaluation")
        plt.close()
        print(f"🖼️ Confusion matrix plot saved to: {conf_matrix_img_path}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during evaluation: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ CLIFTON Model evaluation on the test set complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/clifton_embeddings.csv
# ✅ Label encoder loaded from: ../Models/clifton_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/clifton_rf_model.pkl
#
# --- Evaluating Model on Test Set ---
# ✅ Test Accuracy: 1.0000
# 📊 Classification report saved to: clifton_evaluation_classification_report.csv
#
# Classification Report:
#                         precision    recall  f1-score   support
#
#             Executing       1.00      1.00      1.00         7
#           Influencing       1.00      1.00      1.00         7
# Relationship Building       1.00      1.00      1.00         7
#    Strategic Thinking       1.00      1.00      1.00         7
#
#              accuracy                           1.00        28
#             macro avg       1.00      1.00      1.00        28
#          weighted avg       1.00      1.00      1.00        28
#
# 📊 Confusion matrix saved to: clifton_evaluation_confusion_matrix.csv
#
# Confusion Matrix:
# ...

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 8: Test and Evaluate Model** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import mlflow
import joblib
from openai import OpenAI  # Keep this import for type hinting or other openai functions
import os

# Define paths
label_encoder_path = "../Models/clifton_label_encoder.pkl"
model_path = "../Models/clifton_rf_model.pkl"

# -------------------- Utility Function --------------------

def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    return np.fromstring(embedding_str.strip(""), sep=", ")

# -------------------- Embedding Function --------------------

def get_embedding(text, model="text-embedding-3-small"):
    """
    Generates an embedding for the given text using the OpenAI API.

    Args:
        text: The text to embed.
        model: The name of the embedding model to use.

    Returns:
        The generated embedding as a list.
    """
    try:
        response = client.embeddings.create(input=[text], model=model)
        embedding = response.data[0].embedding
        return embedding
    except openai.OpenAIError as e:
        print(f"❌ OpenAI API error during embedding generation: {e}")
        raise

# Start MLflow run
with mlflow.start_run(run_name="Step 7: Model Testing (Inference on New Data)") as run:
    try:
        mlflow.log_param("Step", "Model Testing (Inference on New Data)")
        mlflow.log_artifact(label_encoder_path, artifact_path="label_encoder")
        mlflow.log_artifact(model_path, artifact_path="model")

        print("\n--- Model Testing (Inference on New Data) ---")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # Load the trained model
        try:
            loaded_clf = joblib.load(model_path)
            print(f"✅ Trained model loaded from: {model_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", f"Model not found at: {model_path}")
            print(f"❌ Error: {e}")
            raise

        # -------------------- Model Application/Inference --------------------

        def predict_factor(new_text):
            """
            Predicts the personality factor for new text using the trained model
            and the saved label encoder.

            Args:
                new_text: The text to predict the personality factor for.

            Returns:
                The predicted personality factor.
            """
            try:
                # Get the embedding for the new text
                new_embedding = get_embedding(new_text)

                # Predict the factor
                predicted_factor_encoded = loaded_clf.predict([new_embedding])

                # Decode the prediction using the label encoder
                predicted_factor = label_encoder.inverse_transform(
                    predicted_factor_encoded
                )[0]

                return predicted_factor

            except Exception as e:
                print(f"❌ An error occurred during prediction: {e}")
                raise

        # Example usage:
        test_texts = [
            "I love going to parties and meeting new people.",
            "I prefer staying home with a good book.",
            "I often feel anxious and worried.",
            "I am generally calm and relaxed.",
            "I enjoy taking risks and trying new things."
        ]
        mlflow.log_param("Number of Test Inputs", len(test_texts))

        print("\n--- Testing Model on New Data ---")
        for i, text in enumerate(test_texts):
            try:
                predicted_factor = predict_factor(text)
                print(f"Predicted Factor for '{text[:50]}...': {predicted_factor}")
                mlflow.log_param(f"New Text {i+1}", text)
                mlflow.log_param(f"Predicted Factor {i+1}", predicted_factor)
            except Exception as e:
                mlflow.log_param("Error Type", type(e).__name__)
                mlflow.log_param(
                    "Error", f"Error predicting for text: {text[:50]}...: {e}"
                )
                print(f"❌ Error predicting for text: {text[:50]}...: {e}")

    except FileNotFoundError as e:
        mlflow.log_param("Error Type", "FileNotFoundError")
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise
    except Exception as e:
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", str(e))
        print(f"❌ An error occurred during model testing: {e}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Model testing (inference on new data) complete.")
# Out:
# --- Model Testing (Inference on New Data) ---
# ✅ Label encoder loaded from: ../Models/clifton_label_encoder.pkl
# ✅ Trained model loaded from: ../Models/clifton_rf_model.pkl
#
# --- Testing Model on New Data ---
# Predicted Factor for 'I love going to parties and meeting new people....': Relationship Building
# Predicted Factor for 'I prefer staying home with a good book....': Executing
# Predicted Factor for 'I often feel anxious and worried....': Executing
# Predicted Factor for 'I am generally calm and relaxed....': Executing
# Predicted Factor for 'I enjoy taking risks and trying new things....': Executing
# 🏃 View run Step 7: Model Testing (Inference on New Data) at: http://127.0.0.1:5000/#/experiments/24/runs/bcd63c6a520a476f8d968e1338f1e52a
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24
#
# ✅ Model testing (inference on new data) complete.

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 9: Visualize and Evaluate Model** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.cluster import KMeans
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
import mlflow
import mlflow.sklearn
from datetime import datetime
import openai

# Load the dataset containing embeddings
df = pd.read_csv('../Embeddings/clifton_embeddings.csv')

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    # Remove brackets and split the string by commas, then convert to a numpy array
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Apply the function to each row in the 'Embedding' column to convert all data
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Stack arrays (embeddings) vertically into a matrix for model input (features)
X = np.stack(df['Embedding'].values)
# Extract labels for prediction from the dataframe
y = df['Factor'].values  

# Convert categorical labels into integers for model processing
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Start tracking the experiment with MLflow
with mlflow.start_run(run_name="CLIFTON Model Visualization and Evaluation") as run:
    try:
        # Log basic parameters like the step and dataset being used
        mlflow.log_param("Step", "Visualize model and evaluate")
        mlflow.log_param("Dataset", "../Embeddings/clifton_embeddings.csv")

        # Record the start time of the model run
        start_time = datetime.now()
        mlflow.log_param("Start Time", str(start_time))

        # Initialize and train a RandomForestClassifier
        clf = RandomForestClassifier(n_estimators=100, random_state=42)
        clf.fit(X, y_encoded)

        # Log the model to MLflow for later access or deployment
        mlflow.sklearn.log_model(clf, "clifton_random_forest_model")

        # Predict on the training set to evaluate the model
        y_pred = clf.predict(X)
        # Generate a confusion matrix to visualize classification accuracy
        conf_matrix = confusion_matrix(y_encoded, y_pred)
        plt.figure(figsize=(10, 8))
        sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.title('Confusion Matrix')
        plt.show()

        # Calculate and log accuracy to MLflow
        accuracy = accuracy_score(y_encoded, y_pred)
        mlflow.log_metric("Accuracy", accuracy)

        # Generate and log a detailed classification report
        class_report = classification_report(y_encoded, y_pred, output_dict=True)
        for label, metrics in class_report.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)
            else:
                mlflow.log_metric(f"{label}", metrics)

        # Save and log the confusion matrix as an artifact for record-keeping
        conf_matrix_path = "../Embeddings/clifton_confusion_matrix.csv"
        np.savetxt(conf_matrix_path, conf_matrix, delimiter=",")
        mlflow.log_artifact(conf_matrix_path, artifact_path="evaluation")

        # Use PCA for dimensionality reduction to visualize the embedding distribution
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X)
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis')
        plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('PCA of CLIFTON Embeddings')
        plt.show()

        # Cluster embeddings to identify groups with similar traits
        kmeans = KMeans(n_clusters=5, random_state=42)
        clusters = kmeans.fit_predict(X)

        # Add cluster information to the DataFrame and save it
        df['Cluster'] = clusters
        clustered_csv_path = '../Embeddings/clifton_clustered_embeddings.csv'
        df.to_csv(clustered_csv_path, index=False)
        mlflow.log_artifact(clustered_csv_path, artifact_path="clustered_data")

        # Visualize clusters to understand data segmentation
        plt.figure(figsize=(12, 8))
        scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=clusters, cmap='tab10')
        plt.colorbar(scatter, ticks=range(5))
        plt.xlabel('PCA Component 1')
        plt.ylabel('PCA Component 2')
        plt.title('K-Means Clusters of CLIFTON Embeddings')
        plt.show()

        # Record the end time of the experiment
        end_time = datetime.now()
        mlflow.log_param("End Time", str(end_time))

        # Function to predict the personality trait based on new text embeddings
        def predict_factor(new_text):
            # Assume `get_embedding` is a function to convert text to embedding
            new_embedding = get_embedding(new_text)
            predicted_factor = clf.predict([new_embedding])
            return label_encoder.inverse_transform(predicted_factor)[0]

        # Demonstrate the model's application on new text data
        test_texts = [
            "Active Energetic Activate Activator",
            "Calm Relaxed Soothing Pacify",
            "Curious Inquisitive Explore Investigator",
            "Organized Meticulous Plan Planner",
            "Moody Anxious Worry Worrier"
        ]

        for text in test_texts:
            predicted_factor = predict_factor(text)
            print(f"Predicted Factor for '{text}': {predicted_factor}")
            param_name = f"Predicted_Factor_for_{text.replace(' ', '_')}"
            mlflow.log_param(param_name, predicted_factor)

    except Exception as e:
        # Log any errors that occur during the model run
        mlflow.log_param("Error", str(e))
        print(f"An error occurred: {e}")
        raise e

    finally:
        # Ensure the MLflow run is properly closed even if an error occurs
        mlflow.end_run()
# Out:
# 2025/03/17 18:02:46 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# Predicted Factor for 'Active Energetic Activate Activator': Executing
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Influencing
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Executing
# Predicted Factor for 'Organized Meticulous Plan Planner': Executing
# Predicted Factor for 'Moody Anxious Worry Worrier': Executing
# 🏃 View run CLIFTON Model Visualization and Evaluation at: http://127.0.0.1:5000/#/experiments/24/runs/c856b70227da4d3786d16aee9228516e
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 10: Save Visualization and Evaluation of Model** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import joblib
import mlflow
from openai import OpenAI
import os
from dotenv import load_dotenv
import ast  # Import ast for literal_eval

# Load the dataset containing embeddings
embeddings_csv_path = '../Embeddings/clifton_embeddings.csv'

# Define a function to parse string representations of embeddings into numpy arrays
def parse_embedding(embedding_str):
    """
    Converts a string representation of an embedding (from the CSV)
    into a NumPy array using ast.literal_eval.

    Args:
        embedding_str: The string representation of the embedding.

    Returns:
        A NumPy array representing the embedding.
    """
    try:
        return np.array(ast.literal_eval(embedding_str))
    except (ValueError, SyntaxError):
        return np.array()  # Or handle the error as appropriate

with mlflow.start_run(run_name="Step 9: Model Application, Visualization, and Analysis") as run:
    try:
        mlflow.log_param("Step", "Model Application, Visualization, and Analysis")

        # Define paths
        label_encoder_path = "../Models/clifton_label_encoder.pkl"
        model_path = "../Models/clifton_rf_model.pkl"

        mlflow.log_param("Embeddings CSV", embeddings_csv_path)
        mlflow.log_param("Label Encoder", label_encoder_path)
        mlflow.log_param("Model", model_path)

        # -------------------- Load Data and Artifacts --------------------

        # Load the dataset containing embeddings
        try:
            df = pd.read_csv(embeddings_csv_path)
            print(f"✅ Embeddings dataset loaded from: {embeddings_csv_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Embeddings dataset not found at: {embeddings_csv_path}"
            )
            print(f"❌ Error: Embeddings dataset not found at: {embeddings_csv_path}")
            raise

        # Apply the parsing function
        df['Embedding'] = df['Embedding'].apply(parse_embedding)

        # Print for debugging
        print("\nDataFrame with Embeddings:")
        print(df.head())
        print("\nShape of DataFrame:")
        print(df.shape)
        print("\nType of 'Embedding' column:")
        print(df['Embedding'].dtype)
        print("\nFirst Embedding:")
        if not df['Embedding'].empty:
            print(df['Embedding'].iloc[0])
        else:
            print("No embeddings found in DataFrame")

        # Load the pre-fitted label encoder
        try:
            label_encoder = joblib.load(label_encoder_path)
            print(f"✅ Label encoder loaded from: {label_encoder_path}")
        except FileNotFoundError:
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param(
                "Error", f"Label encoder not found at: {label_encoder_path}"
            )
            print(f"❌ Error: Label encoder not found at: {label_encoder_path}")
            raise

        # -------------------- PCA Visualization --------------------

        mlflow.log_param("Visualization", "PCA")

        try:
            # Stack embeddings
            X = np.stack(df['Embedding'].values)

            # Print shape of X
            print("\nShape of X:")
            print(X.shape)

            # Encode Factor
            y_encoded = label_encoder.transform(df['Factor'].values)

            # Use PCA for dimensionality reduction
            pca = PCA(n_components=2)
            X_pca = pca.fit_transform(X)

            # Create the visualization
            plt.figure(figsize=(12, 8))
            scatter = plt.scatter(
                X_pca[:, 0], X_pca[:, 1], c=y_encoded, cmap='viridis'
            )
            plt.colorbar(scatter, ticks=range(len(set(y_encoded))))
            plt.xlabel("PCA Component 1")
            plt.ylabel("PCA Component 2")
            plt.title("PCA of CLIFTON Embeddings")

            # Save and log the plot
            pca_plot_path = "clifton_embeddings_pca.png"
            plt.savefig(pca_plot_path)
            mlflow.log_artifact(pca_plot_path, artifact_path="visualization")
            plt.close()  # Close the plot to release memory

            print(f"✅ PCA visualization saved to: {pca_plot_path}")

        except Exception as e:
            mlflow_error = f"An error occurred during PCA visualization: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- K-Means Clustering --------------------

        mlflow.log_param("Clustering", "K-Means")

        try:
            n_clusters = 5  # You can parameterize this
            mlflow.log_param("n_clusters", n_clusters)

            # Stack embeddings (if not already done)
            if "X" not in locals():
                X = np.stack(df["Embedding"].values)

            # Cluster embeddings
            kmeans = KMeans(n_clusters=n_clusters, random_state=42)
            clusters = kmeans.fit_predict(X)

            # Add cluster information to the DataFrame and save it
            df["Cluster"] = clusters
            clustered_csv_path = "clifton_clustered_embeddings.csv"
            df.to_csv(clustered_csv_path, index=False)
            mlflow.log_artifact(clustered_csv_path, artifact_path="clustering")

            print(
                f"✅ K-Means clustering performed. Clustered data saved to: {clustered_csv_path}"
            )

        except Exception as e:
            mlflow_error = f"An error occurred during K-Means clustering: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ {mlflow_error}")
            raise

        # -------------------- Model Application/Inference --------------------

        mlflow.log_param("Model Application", "Inference")

        try:
            # Load the trained model
            loaded_clf = joblib.load(model_path)

            def predict_factor(new_text):
                """
                Predicts the personality factor for new text using the trained model
                and the saved label encoder.

                Args:
                    new_text: The text to predict the personality factor for.

                Returns:
                    The predicted personality factor.
                """
                try:
                    # Get the embedding for the new text
                    new_embedding = get_embedding(new_text)

                    # Predict the factor
                    predicted_factor_encoded = loaded_clf.predict([new_embedding])

                    # Decode the prediction using the label encoder
                    predicted_factor = label_encoder.inverse_transform(
                        predicted_factor_encoded
                    )[0]

                    return predicted_factor

                except Exception as e:
                    print(f"❌ An error occurred during prediction: {e}")
                    raise

            # Example usage:
            new_text = "I love going to parties and meeting new people."
            predicted_factor = predict_factor(new_text)
            print(f"Predicted Factor for '{new_text}': {predicted_factor}")
            mlflow.log_param("New Text", new_text)
            mlflow.log_param("Predicted Factor", predicted_factor)

        except FileNotFoundError as e:
            mlflow_error = f"Model not found at: {model_path}"
            mlflow.log_param("Error Type", "FileNotFoundError")
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ Error: {e}")
            raise

        except Exception as e:
            mlflow_error = f"An error occurred during prediction: {e}"
            mlflow.log_param("Error Type", type(e).__name__)
            mlflow.log_param("Error", mlflow_error)
            print(f"❌ An error occurred during prediction: {e}")
            raise

    except Exception as e:
        # Catch any unexpected errors
        mlflow_error = f"An unexpected error occurred: {e}"
        mlflow.log_param("Error Type", type(e).__name__)
        mlflow.log_param("Error", mlflow_error)
        print(f"❌ {mlflow_error}")
        raise

    finally:
        mlflow.end_run()

print("\n✅ Step 10: Save Model Visualization and Analysis complete.")
# Out:
# ✅ Embeddings dataset loaded from: ../Embeddings/clifton_embeddings.csv
#
# DataFrame with Embeddings:
#       Factor Adjective     Synonym      Verb           Noun  \
# 0  Executing  Achiever   Ambitious    Strive       Ambition
# 1  Executing  Achiever   Motivated  Motivate     Motivation
# 2  Executing  Achiever  Determined   Resolve  Determination
# 3  Executing  Achiever  Productive   Produce   Productivity
# 4  Executing  Arranger   Organized   Arrange    Arrangement
#
#                                            Embedding
# 0  [0.04571199417114258, -0.00386609835550189, 0....
# 1  [0.0439743846654892, -0.005997475236654282, -0...
# 2  [0.04133903980255127, 0.003840571967884898, 0....
# 3  [0.05429932102560997, 0.010195175185799599, 0....
# 4  [-0.0056319101713597775, -0.027571363374590874...
#
# Shape of DataFrame:
# (136, 6)
#
# Type of 'Embedding' column:
# object
#
# First Embedding:
# [ 0.04571199 -0.0038661   0.0226241  ... -0.00757277 -0.01073232
#   0.01755143]
# ...

# %% [markdown]
# This block of code integrates several stages that not only include training but also applying the model to new data and exploring the data through clustering:
# 1. **Data Loading and Feature Parsing**: Similar to Block 1, with an additional step of displaying the parsed data.
# 2. **Model Creation and Logging**: Training a RandomForestClassifier and logging the model directly with MLflow for possibly immediate deployment.
# 3. **Model Evaluation and Reporting**: Assessing model performance with metrics and detailed reports, and logging these evaluations.
# 4. **Clustering Analysis**: Utilizing KMeans to perform clustering on the embeddings, which adds an exploratory data analysis component.
# 5. **Model Application on New Data**: Demonstrating a practical application of the trained model to predict factors for new text inputs.
# 6. **End-to-End Experiment Tracking**: From the beginning of the run to its completion, tracking all parameters, artifacts, and outcomes, emphasizing a full-cycle view of the modeling process.
#
# This provides a broader overview of how a model can be developed and applied within a workflow that includes prediction and clustering alongside the fundamental steps.

# %% [markdown]
# The results show that the RandomForestClassifier model trained on the dataset of embeddings has achieved an accuracy of 1.0 on the test set, which means it has correctly classified all the test samples. Here is the breakdown of the evaluation:
#
# ### Accuracy:
# - **1.0**: The model has 100% accuracy, meaning it correctly classified every instance in the test set.
#
# ### Classification Report:
# - **Precision, Recall, and F1-score** for each class (0 through 4) are all 1.00.
# - **Support** indicates the number of actual occurrences of each class in the test set.
#
# ### Interpretation:
# - **Precision**: This is the ratio of true positive predictions to the total predicted positives. A precision of 1.0 means that all instances predicted as a specific class were actually of that class.
# - **Recall**: This is the ratio of true positive predictions to the total actual positives. A recall of 1.0 means that all actual instances of a specific class were correctly predicted.
# - **F1-score**: This is the harmonic mean of precision and recall. An F1-score of 1.0 indicates perfect precision and recall.
# - **Support**: This indicates the number of true instances for each label in the test set.
#
# ### Considerations:
# 1. **Model Overfitting**: The perfect score could indicate overfitting, especially if the test set is small or not representative of unseen data.
# 2. **Test Set Size**: The test set has only 24 samples, which is relatively small. It's important to ensure that the test set is large enough and representative to get a reliable estimate of model performance.
# 3. **Data Leakage**: Double-check that there's no data leakage, meaning that no information from the test set was used during training.
# 4. **Cross-Validation**: To better assess the model's performance, consider using cross-validation to ensure the model performs well across different subsets of the data.
#
# ### Next Steps:
# - **Cross-validation**: Implement cross-validation to get a more robust evaluation of model performance.
# - **Larger Test Set**: If possible, increase the size of the test set to ensure the performance metrics are reliable.
# - **Feature Analysis**: Examine feature importance scores from the RandomForestClassifier to understand which parts of the embeddings contribute most to the predictions.
#
# ### Updated Code for Cross-Validation:
#
# ```python
# from sklearn.model_selection import cross_val_score
#
# # Perform cross-validation
# cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
# print(f"Cross-validation scores: {cv_scores}")
# print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# ```
#
# We added this cross-validation step will help us verify that the model generalizes well and is not just performing well on a small or potentially non-representative test set.

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(clf, X, y_encoded, cv=5)  # 5-fold cross-validation
print(f"Cross-validation scores: {cv_scores}")
print(f"Mean cross-validation score: {np.mean(cv_scores)}")
# Out:
# Cross-validation scores: [0.96428571 1.         1.         1.         1.        ]
# Mean cross-validation score: 0.9928571428571429

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 11: Test Model Directly** <a class="anchor" id="clifton_page_3"></a>
#
# [Back to Top](#clifton_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
#Test the model directly

# Load the dataset with embeddings
df = pd.read_csv('../Embeddings/clifton_embeddings.csv')

# Function to convert embedding strings back to lists of floats
def parse_embedding(embedding_str):
    return np.fromstring(embedding_str.strip('[]'), sep=', ')

# Convert the embedding column from strings to lists of floats
df['Embedding'] = df['Embedding'].apply(parse_embedding)

# Extract embeddings and labels
X = np.stack(df['Embedding'].values)
y = df['Factor'].values  # Assuming we want to predict the Factor

# Encode the categorical labels as numerical values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Load the pretrained RandomForestClassifier model
#clf = joblib.load('../Models/random_forest_rft.pkl')
clf = joblib.load('../Models/clifton_rf_model.pkl')

# Predicting a New Text Factor
def get_embedding(text, model="text-embedding-3-small"):
    response = client.embeddings.create(
        input=[text],  # The input should be a list of strings
        model=model
    )
    embedding = response.data[0].embedding
    return embedding

def predict_factor(new_text):
    new_embedding = get_embedding(new_text)
    predicted_factor = clf.predict([new_embedding])
    return label_encoder.inverse_transform(predicted_factor)[0]

# Example usage: predicting new texts
test_texts = [
    "Active Energetic Activate Activator",
    "Calm Relaxed Soothing Pacify",
    "Curious Inquisitive Explore Investigator",
    "Organized Meticulous Plan Planner",
    "Moody Anxious Worry Worrier",
    "Unfriendly Stoic Indifferent Apathetic" 
]

for text in test_texts:
    predicted_factor = predict_factor(text)
    print(f"Predicted Factor for '{text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Active Energetic Activate Activator': Influencing
# Predicted Factor for 'Calm Relaxed Soothing Pacify': Executing
# Predicted Factor for 'Curious Inquisitive Explore Investigator': Executing
# Predicted Factor for 'Organized Meticulous Plan Planner': Executing
# Predicted Factor for 'Moody Anxious Worry Worrier': Executing
# Predicted Factor for 'Unfriendly Stoic Indifferent Apathetic': Influencing

# %%
# Test a single word or phrase
test_text = "Curious"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'Curious': Executing

# %%
# Test a single word or phrase
test_text = "afraid"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'afraid': Executing

# %%
# Test a single word or phrase
test_text = "scared"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'scared': Executing

# %%
# Test a single word or phrase
test_text = "sad"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'sad': Executing

# %%
# Test a single word or phrase
test_text = "unemotional"
predicted_factor = predict_factor(test_text)
print(f"Predicted Factor for '{test_text}': {predicted_factor}")
# Out:
# Predicted Factor for 'unemotional': Executing

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 12: Test Neo4j Connection** <a class="anchor" id="CLIFTON_page_4"></a>
#
#
# [Back to Top](#CLIFTON_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import webbrowser
from IPython.display import display, HTML

# Define Neo4j Browser URL
neo4j_browser_url = "http://localhost:7474/browser/"

# Create a clickable link
html_code = f'<a href="{neo4j_browser_url}" target="_blank">🔗 Open Neo4j Bolt Connection</a>'

# Display the clickable link in Jupyter Notebook
display(HTML(html_code))

# Open the Neo4j Browser in a new tab automatically
webbrowser.open_new_tab(neo4j_browser_url)
# Out:
# <a href="http://localhost:7474/browser/" target="_blank">🔗 Open Neo4j Bolt Connection</a>
# True

# %%
import socket

HOST = "localhost"
PORT = 7687

sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
result = sock.connect_ex((HOST, PORT))

if result == 0:
    print(f"✅ Bolt port {PORT} is reachable!")
else:
    print(f"❌ Bolt port {PORT} is NOT reachable!")

sock.close()
# Out:
# ✅ Bolt port 7687 is reachable!

# %%
from py2neo import Graph

# Attempt connection with neo4j://
NEO4J_URI = "neo4j://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "yourpass123"

try:
    graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
    result = graph.run("RETURN 'Connection successful!' AS message").data()
    print("✅ Python Connected Successfully:", result[0]["message"])
except Exception as e:
    print("❌ Python Connection Failed:", e)
# Out:
# ✅ Python Connected Successfully: Connection successful!

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import mlflow

# Load environment variables
load_dotenv()

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME")
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("CLIFTON")
#mlflow.set_experiment(experiment_name)

# Function to test database connection
def test_neo4j_connection(uri, user, password):
    try:
        # Connect to Neo4j
        graph = Graph(uri, auth=(user, password))
        # Run a simple query to test the connection
        greeting = graph.run("RETURN 'Connection successful!' AS greeting").data()
        return greeting[0]['greeting']
    except Exception as e:
        return str(e)

# Start an MLFlow run
with mlflow.start_run(run_name="Test Neo4j Connection"):
    # Log the test start
    mlflow.log_param("Test", "Neo4j Connection")
    
    # Test the Neo4j database connection
    result = test_neo4j_connection(NEO4J_URI, NEO4J_USER, NEO4J_PASSWORD)
    
    # Log the result of the connection test
    mlflow.log_param("Connection Result", result)
    
    # Output the result
    print(result)
# Out:
# Connection successful!
# 🏃 View run Test Neo4j Connection at: http://127.0.0.1:5000/#/experiments/24/runs/628d8f2f5ba04de0ab5fd1b5514f24ae
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">
#
# # **Step 13: Create CLIFTON Schema in Neo4j** <a class="anchor" id="CLIFTON_page_4"></a>
#
#
# [Back to Top](#CLIFTON_toc)
#
# <hr style="height:3px;border-width:0;color:Blue;background-color:Blue">

# %%
import os
from dotenv import load_dotenv
from py2neo import Graph
import pandas as pd
import mlflow
import ast  # Convert string embeddings to lists

# Load environment variables
load_dotenv(override=True)

# MLflow and Neo4j connection settings
NEO4J_URI = os.getenv("NEO4J_URI")
NEO4J_USER = os.getenv("NEO4J_USERNAME") 
NEO4J_PASSWORD = os.getenv("NEO4J_PASSWORD")
MLFLOW_TRACKING_URI = os.getenv("MLFLOW_TRACKING_URI")

# Set the MLflow tracking URI
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# Set an experiment name
mlflow.set_experiment("CLIFTON")

# Load the dataset
dataset_path = "../Embeddings/clifton_embeddings.csv"
clifton_df = pd.read_csv(dataset_path)

# Convert Embeddings (if stored as strings)
if 'Embedding' in clifton_df.columns:
    clifton_df['Embedding'] = clifton_df['Embedding'].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Function to create the CLIFTON schema in Neo4j
def create_clifton_schema(graph, dataframe):
    for index, row in dataframe.iterrows():
        # Extract data safely
        factor = row.get('Factor', 'Unknown')
        adjective = row.get('Adjective', 'Unknown')
        synonym = row.get('Synonym', 'Unknown')
        verb = row.get('Verb', 'Unknown')
        noun = row.get('Noun', 'Unknown')
        embedding = row.get('Embedding', [])

        # Ensure values exist before inserting
        if not factor or not adjective or not synonym or not verb or not noun:
            continue  # Skip if any critical value is missing

        # Create nodes with CLIFTON labels
        graph.run("MERGE (f:CLIFTON_Factor {name: $factor})", factor=factor)
        graph.run("MERGE (a:CLIFTON_Adjective {name: $adjective})", adjective=adjective)
        graph.run("MERGE (s:CLIFTON_Synonym {name: $synonym})", synonym=synonym)
        graph.run("MERGE (v:CLIFTON_Verb {name: $verb})", verb=verb)
        graph.run("MERGE (n:CLIFTON_Noun {name: $noun})", noun=noun)
        
        # Create relationships with CLIFTON namespacing
        graph.run("""
            MATCH (f:CLIFTON_Factor {name: $factor}), (a:CLIFTON_Adjective {name: $adjective})
            MERGE (f)-[:CLIFTON_HAS_ADJECTIVE]->(a)
        """, factor=factor, adjective=adjective)
        
        graph.run("""
            MATCH (a:CLIFTON_Adjective {name: $adjective}), (s:CLIFTON_Synonym {name: $synonym})
            MERGE (a)-[:CLIFTON_HAS_SYNONYM]->(s)
        """, adjective=adjective, synonym=synonym)
        
        graph.run("""
            MATCH (a:CLIFTON_Adjective {name: $adjective}), (v:CLIFTON_Verb {name: $verb})
            MERGE (a)-[:CLIFTON_HAS_VERB]->(v)
        """, adjective=adjective, verb=verb)
        
        graph.run("""
            MATCH (a:CLIFTON_Adjective {name: $adjective}), (n:CLIFTON_Noun {name: $noun})
            MERGE (a)-[:CLIFTON_HAS_NOUN]->(n)
        """, adjective=adjective, noun=noun)
        
        # Log the embedding if present
        if embedding:
            graph.run("""
                MATCH (f:CLIFTON_Factor {name: $factor}), (a:CLIFTON_Adjective {name: $adjective})
                MERGE (e:CLIFTON_Embedding {value: $embedding})
                MERGE (f)-[:CLIFTON_HAS_EMBEDDING]->(e)
                MERGE (a)-[:CLIFTON_HAS_EMBEDDING]->(e)
            """, factor=factor, adjective=adjective, embedding=embedding)

# Start an MLFlow run
with mlflow.start_run(run_name="Create CLIFTON Schema in Neo4j"):
    try:
        # Log the dataset creation process
        mlflow.log_param("Step", "Create CLIFTON Schema in Neo4j")
        
        # Connect to Neo4j
        graph = Graph(NEO4J_URI, auth=(NEO4J_USER, NEO4J_PASSWORD))
        
        # Create the CLIFTON schema
        create_clifton_schema(graph, clifton_df)
        
        # Log the dataset as an artifact
        mlflow.log_artifact(dataset_path, artifact_path="datasets")

        # Log the number of rows and columns in the dataset
        mlflow.log_param("Number of Rows", clifton_df.shape[0])
        mlflow.log_param("Number of Columns", clifton_df.shape[1])
        
        # Print the DataFrame
        print(clifton_df.head())

    except Exception as e:
        # Log the error if any occurs
        mlflow.log_param("Error", str(e))
        print(f"❌ Error: {e}")
        raise e

    finally:
        # End the MLFlow run
        mlflow.end_run()
# Out:
#       Factor Adjective     Synonym      Verb           Noun  \
# 0  Executing  Achiever   Ambitious    Strive       Ambition
# 1  Executing  Achiever   Motivated  Motivate     Motivation
# 2  Executing  Achiever  Determined   Resolve  Determination
# 3  Executing  Achiever  Productive   Produce   Productivity
# 4  Executing  Arranger   Organized   Arrange    Arrangement
#
#                                            Embedding
# 0  [0.04571199417114258, -0.00386609835550189, 0....
# 1  [0.0439743846654892, -0.005997475236654282, -0...
# 2  [0.04133903980255127, 0.003840571967884898, 0....
# 3  [0.05429932102560997, 0.010195175185799599, 0....
# 4  [-0.0056319101713597775, -0.027571363374590874...
# 🏃 View run Create CLIFTON Schema in Neo4j at: http://127.0.0.1:5000/#/experiments/24/runs/b6548403e77a4301bf054283b7b4f46c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/24

# %% [markdown]
# ```cypher
# MATCH (n)-[r]->(m)
# WHERE (n:CLIFTON_Factor OR n:CLIFTON_Adjective OR n:CLIFTON_Synonym OR n:CLIFTON_Verb OR n:CLIFTON_Noun)
# AND NOT m:CLIFTON_Embedding
# RETURN n, r, m
# ```
